# %%
import meep as mp
import numpy as np
import math
import matplotlib.pyplot as plt

resolution = 500  # pixels/μm

dpml = 1.0  # PML thickness
dsub = 0.5  # substrate thickness
dcaa = 0.06  # air rigion for alpha structure
# alpha structure is that one period = 200nm，sigle cell width = 80nm locate at center
dcab = 0.025 # air rigion for beta structure 
# beta structure is that one period = 200nm，sigle cell width = 150nm locate at center
gp = 0.2  # grating periodicity
gh = 0.6  # grating height
gwa = 0.08 # alpha grating cell width
gwb = 0.15 # beta grating cell width

num_cells = 3  # number of grating unit cells

# air region thickness adjacent to grating
dair = 14 

wvl = 0.532  # center wavelength
fcen = 1 / wvl  # center frequency

k_point = mp.Vector3()

glass = mp.Medium(index= 2.6678)

pml_layers = [mp.PML(thickness=dpml, direction = mp.X )]

symmetries = [mp.Mirror(mp.Y)]

sx = dpml + dsub + gh + dair + dpml
sy = gp*num_cells
cell_size = mp.Vector3(sx, sy)

sources = [
    mp.Source(
        mp.ContinuousSource(frequency = 2), # frequemcy = 2原因是 meep 的 C=1，所以 1/? = 0.5 um，?即是2
        component = mp.Ez,
        center = mp.Vector3(-0.5 * sx + dpml ),
        size = mp.Vector3(y=sy),
    )
]

geometry = [
    mp.Block(
        material=glass,
        size=mp.Vector3(dsub, mp.inf, mp.inf),
        center=mp.Vector3(-0.5 * sx + dpml + 0.04 + dsub/2),
    )
]

# %%
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwa, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp/2 + (j * 3 * gp),
                #-0.5 * sy + gp/2 ,
            ),
        )
    )

for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + gp + gp/2 ,
            ),
        )
    )

for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + 2*gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + 2*gp + gp/2  ,
            ),
        )
    )

# %%
k_point = mp.Vector3()  # Gamma 點表示週期邊界條件
k_points = [k_point]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
    k_point = mp.Vector3(),
)

# %matplotlib inline
plt.figure(dpi = 125)
sim.plot2D()
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (-7.26,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.77556e-17,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.6,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.8,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
sim.run(until = 100)
plt.figure(dpi = 100)
sim.plot2D(fields=mp.Ez)
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000706911 s
# Working in 2D dimensions.
# Computational cell is 17.1 x 0.6 x 0 with resolution 500
#      block, center = (-7.26,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.77556e-17,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.6,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.8,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
# time for set_epsilon = 2.22071 s
# -----------
# Meep progress: 0.20700000000000002/100.0 = 0.2% done in 4.0s, 1931.0s to go
# on time step 207 (time=0.207), 0.019351 s/step
# Meep progress: 0.419/100.0 = 0.4% done in 8.0s, 1905.2s to go
# on time step 419 (time=0.419), 0.0189167 s/step
# Meep progress: 0.624/100.0 = 0.6% done in 12.0s, 1916.6s to go
# on time step 624 (time=0.624), 0.0195992 s/step
# Meep progress: 0.8320000000000001/100.0 = 0.8% done in 16.0s, 1912.0s to go
# on time step 832 (time=0.832), 0.0192578 s/step
# Meep progress: 1.043/100.0 = 1.0% done in 20.1s, 1903.2s to go
# on time step 1043 (time=1.043), 0.0190434 s/step
# Meep progress: 1.243/100.0 = 1.2% done in 24.1s, 1912.8s to go
# on time step 1243 (time=1.243), 0.0200779 s/step
# Meep progress: 1.44/100.0 = 1.4% done in 28.1s, 1921.8s to go
# on time step 1440 (time=1.44), 0.0203155 s/step
# Meep progress: 1.6440000000000001/100.0 = 1.6% done in 32.1s, 1919.5s to go
# on time step 1644 (time=1.644), 0.0196326 s/step
# Meep progress: 1.848/100.0 = 1.8% done in 36.1s, 1917.4s to go
# on time step 1848 (time=1.848), 0.0196841 s/step
# Meep progress: 2.052/100.0 = 2.1% done in 40.1s, 1914.5s to go
# on time step 2052 (time=2.052), 0.0196395 s/step
# Meep progress: 2.2600000000000002/100.0 = 2.3% done in 44.1s, 1907.7s to go
# on time step 2260 (time=2.26), 0.0192426 s/step
# Meep progress: 2.459/100.0 = 2.5% done in 48.1s, 1908.6s to go
# on time step 2459 (time=2.459), 0.0201235 s/step
# Meep progress: 2.6670000000000003/100.0 = 2.7% done in 52.1s, 1902.7s to go
# on time step 2667 (time=2.667), 0.0193151 s/step
# Meep progress: 2.878/100.0 = 2.9% done in 56.1s, 1894.4s to go
# on time step 2878 (time=2.878), 0.0189699 s/step
# Meep progress: 3.081/100.0 = 3.1% done in 60.1s, 1891.9s to go
# on time step 3081 (time=3.081), 0.0197222 s/step
# Meep progress: 3.2920000000000003/100.0 = 3.3% done in 64.1s, 1884.4s to go
# on time step 3292 (time=3.292), 0.0189795 s/step
# Meep progress: 3.492/100.0 = 3.5% done in 68.1s, 1883.4s to go
# on time step 3492 (time=3.492), 0.0200107 s/step
# Meep progress: 3.701/100.0 = 3.7% done in 72.2s, 1877.3s to go
# on time step 3701 (time=3.701), 0.0191415 s/step
# Meep progress: 3.8770000000000002/100.0 = 3.9% done in 76.2s, 1888.3s to go
# on time step 3877 (time=3.877), 0.0227952 s/step
# Meep progress: 4.041/100.0 = 4.0% done in 80.2s, 1903.8s to go
# on time step 4041 (time=4.041), 0.0244315 s/step
# Meep progress: 4.204/100.0 = 4.2% done in 84.2s, 1918.5s to go
# on time step 4204 (time=4.204), 0.0246718 s/step
# Meep progress: 4.365/100.0 = 4.4% done in 88.2s, 1932.5s to go
# on time step 4365 (time=4.365), 0.0249125 s/step
# Meep progress: 4.5280000000000005/100.0 = 4.5% done in 92.2s, 1944.6s to go
# on time step 4528 (time=4.528), 0.0246725 s/step
# Meep progress: 4.696/100.0 = 4.7% done in 96.2s, 1953.1s to go
# on time step 4696 (time=4.696), 0.0238666 s/step
# Meep progress: 4.862/100.0 = 4.9% done in 100.3s, 1961.7s to go
# on time step 4862 (time=4.862), 0.0241744 s/step
# Meep progress: 5.032/100.0 = 5.0% done in 104.3s, 1967.6s to go
# on time step 5032 (time=5.032), 0.0235529 s/step
# Meep progress: 5.2/100.0 = 5.2% done in 108.3s, 1973.7s to go
# on time step 5200 (time=5.2), 0.0238273 s/step
# Meep progress: 5.369/100.0 = 5.4% done in 112.3s, 1978.8s to go
# on time step 5369 (time=5.369), 0.0237025 s/step
# Meep progress: 5.538/100.0 = 5.5% done in 116.3s, 1983.5s to go
# on time step 5538 (time=5.538), 0.0237719 s/step
# Meep progress: 5.706/100.0 = 5.7% done in 120.3s, 1987.8s to go
# on time step 5706 (time=5.706), 0.0238234 s/step
# Meep progress: 5.873/100.0 = 5.9% done in 124.3s, 1992.2s to go
# on time step 5873 (time=5.873), 0.0240193 s/step
# Meep progress: 6.038/100.0 = 6.0% done in 128.3s, 1996.7s to go
# on time step 6038 (time=6.038), 0.0242913 s/step
# Meep progress: 6.206/100.0 = 6.2% done in 132.3s, 1999.7s to go
# on time step 6206 (time=6.206), 0.0238214 s/step
# Meep progress: 6.377/100.0 = 6.4% done in 136.3s, 2001.5s to go
# on time step 6377 (time=6.377), 0.0234769 s/step
# Meep progress: 6.547/100.0 = 6.5% done in 140.3s, 2003.3s to go
# on time step 6547 (time=6.547), 0.0236307 s/step
# Meep progress: 6.7090000000000005/100.0 = 6.7% done in 144.4s, 2007.4s to go
# on time step 6709 (time=6.709), 0.0248012 s/step
# Meep progress: 6.873/100.0 = 6.9% done in 148.4s, 2010.5s to go
# on time step 6873 (time=6.873), 0.0244605 s/step
# Meep progress: 7.037/100.0 = 7.0% done in 152.4s, 2013.2s to go
# on time step 7037 (time=7.037), 0.0244679 s/step
# Meep progress: 7.207/100.0 = 7.2% done in 156.4s, 2013.8s to go
# on time step 7207 (time=7.207), 0.0236201 s/step
# Meep progress: 7.37/100.0 = 7.4% done in 160.4s, 2016.3s to go
# on time step 7370 (time=7.37), 0.0246284 s/step
# Meep progress: 7.539000000000001/100.0 = 7.5% done in 164.4s, 2016.8s to go
# on time step 7539 (time=7.539), 0.0237765 s/step
# Meep progress: 7.69/100.0 = 7.7% done in 168.5s, 2022.2s to go
# on time step 7690 (time=7.69), 0.0266394 s/step
# Meep progress: 7.827/100.0 = 7.8% done in 172.5s, 2031.2s to go
# on time step 7827 (time=7.827), 0.0293297 s/step
# Meep progress: 7.958/100.0 = 8.0% done in 176.5s, 2041.3s to go
# on time step 7958 (time=7.958), 0.0306033 s/step
# Meep progress: 8.09/100.0 = 8.1% done in 180.5s, 2050.8s to go
# on time step 8090 (time=8.09), 0.0304459 s/step
# Meep progress: 8.226/100.0 = 8.2% done in 184.5s, 2058.7s to go
# on time step 8226 (time=8.226), 0.0295318 s/step
# Meep progress: 8.36/100.0 = 8.4% done in 188.6s, 2066.9s to go
# on time step 8360 (time=8.36), 0.0300194 s/step
# Meep progress: 8.494/100.0 = 8.5% done in 192.6s, 2074.5s to go
# on time step 8494 (time=8.494), 0.0298998 s/step
# Meep progress: 8.635/100.0 = 8.6% done in 196.6s, 2079.8s to go
# on time step 8635 (time=8.635), 0.0283711 s/step
# Meep progress: 8.798/100.0 = 8.8% done in 200.6s, 2079.2s to go
# on time step 8798 (time=8.798), 0.0246032 s/step
# Meep progress: 8.962/100.0 = 9.0% done in 204.6s, 2078.1s to go
# on time step 8962 (time=8.962), 0.024403 s/step
# Meep progress: 9.120000000000001/100.0 = 9.1% done in 208.6s, 2078.6s to go
# on time step 9120 (time=9.12), 0.025407 s/step
# Meep progress: 9.274000000000001/100.0 = 9.3% done in 212.6s, 2079.9s to go
# on time step 9274 (time=9.274), 0.0260431 s/step
# Meep progress: 9.412/100.0 = 9.4% done in 216.6s, 2084.9s to go
# on time step 9412 (time=9.412), 0.0291313 s/step
# Meep progress: 9.549/100.0 = 9.5% done in 220.7s, 2090.1s to go
# on time step 9549 (time=9.549), 0.0293883 s/step
# Meep progress: 9.688/100.0 = 9.7% done in 224.7s, 2094.3s to go
# on time step 9688 (time=9.688), 0.0288602 s/step
# Meep progress: 9.826/100.0 = 9.8% done in 228.7s, 2098.5s to go
# on time step 9826 (time=9.826), 0.0290248 s/step
# Meep progress: 9.962/100.0 = 10.0% done in 232.7s, 2103.0s to go
# on time step 9962 (time=9.962), 0.0295007 s/step
# Meep progress: 10.1/100.0 = 10.1% done in 236.7s, 2106.8s to go
# on time step 10100 (time=10.1), 0.0290564 s/step
# Meep progress: 10.238/100.0 = 10.2% done in 240.7s, 2110.5s to go
# on time step 10238 (time=10.238), 0.0291485 s/step
# Meep progress: 10.377/100.0 = 10.4% done in 244.7s, 2113.7s to go
# on time step 10377 (time=10.377), 0.0289184 s/step
# Meep progress: 10.515/100.0 = 10.5% done in 248.8s, 2117.0s to go
# on time step 10515 (time=10.515), 0.0291142 s/step
# Meep progress: 10.65/100.0 = 10.7% done in 252.8s, 2120.6s to go
# on time step 10650 (time=10.65), 0.0296819 s/step
# Meep progress: 10.786/100.0 = 10.8% done in 256.8s, 2124.0s to go
# on time step 10786 (time=10.786), 0.0296064 s/step
# Meep progress: 10.918000000000001/100.0 = 10.9% done in 260.8s, 2127.8s to go
# on time step 10919 (time=10.919), 0.0302914 s/step
# Meep progress: 11.049/100.0 = 11.0% done in 264.8s, 2131.9s to go
# on time step 11050 (time=11.05), 0.0306924 s/step
# Meep progress: 11.183/100.0 = 11.2% done in 268.8s, 2135.0s to go
# on time step 11184 (time=11.184), 0.0299615 s/step
# Meep progress: 11.317/100.0 = 11.3% done in 272.8s, 2138.0s to go
# on time step 11318 (time=11.318), 0.0298989 s/step
# Meep progress: 11.456/100.0 = 11.5% done in 276.8s, 2139.8s to go
# on time step 11457 (time=11.457), 0.0288605 s/step
# Meep progress: 11.594/100.0 = 11.6% done in 280.9s, 2141.7s to go
# on time step 11595 (time=11.595), 0.0291591 s/step
# Meep progress: 11.733/100.0 = 11.7% done in 284.9s, 2143.3s to go
# on time step 11734 (time=11.734), 0.0289771 s/step
# Meep progress: 11.867/100.0 = 11.9% done in 288.9s, 2145.7s to go
# on time step 11868 (time=11.868), 0.0299837 s/step
# Meep progress: 12.004/100.0 = 12.0% done in 292.9s, 2147.4s to go
# on time step 12005 (time=12.005), 0.0292965 s/step
# Meep progress: 12.142/100.0 = 12.1% done in 297.0s, 2148.7s to go
# on time step 12143 (time=12.143), 0.0291008 s/step
# Meep progress: 12.278/100.0 = 12.3% done in 301.0s, 2150.3s to go
# on time step 12279 (time=12.279), 0.0295344 s/step
# Meep progress: 12.413/100.0 = 12.4% done in 305.0s, 2151.9s to go
# on time step 12414 (time=12.414), 0.0296432 s/step
# Meep progress: 12.547/100.0 = 12.5% done in 309.0s, 2153.7s to go
# on time step 12548 (time=12.548), 0.0300476 s/step
# Meep progress: 12.682/100.0 = 12.7% done in 313.0s, 2155.3s to go
# on time step 12682 (time=12.682), 0.0298961 s/step
# Meep progress: 12.812/100.0 = 12.8% done in 317.1s, 2157.6s to go
# on time step 12812 (time=12.812), 0.0309418 s/step
# Meep progress: 12.938/100.0 = 12.9% done in 321.1s, 2160.6s to go
# on time step 12938 (time=12.938), 0.0319484 s/step
# Meep progress: 13.069/100.0 = 13.1% done in 325.1s, 2162.5s to go
# on time step 13069 (time=13.069), 0.0306823 s/step
# Meep progress: 13.195/100.0 = 13.2% done in 329.1s, 2165.2s to go
# on time step 13195 (time=13.195), 0.0319648 s/step
# Meep progress: 13.315/100.0 = 13.3% done in 333.1s, 2168.8s to go
# on time step 13315 (time=13.315), 0.0333746 s/step
# Meep progress: 13.441/100.0 = 13.4% done in 337.2s, 2171.2s to go
# on time step 13441 (time=13.441), 0.0318494 s/step
# Meep progress: 13.576/100.0 = 13.6% done in 341.2s, 2171.9s to go
# on time step 13576 (time=13.576), 0.0297647 s/step
# Meep progress: 13.713000000000001/100.0 = 13.7% done in 345.2s, 2172.1s to go
# on time step 13713 (time=13.713), 0.0293744 s/step
# Meep progress: 13.847/100.0 = 13.8% done in 349.2s, 2172.8s to go
# on time step 13847 (time=13.847), 0.0300408 s/step
# Meep progress: 13.982000000000001/100.0 = 14.0% done in 353.2s, 2173.1s to go
# on time step 13982 (time=13.982), 0.0297398 s/step
# Meep progress: 14.111/100.0 = 14.1% done in 357.2s, 2174.4s to go
# on time step 14111 (time=14.111), 0.0310678 s/step
# Meep progress: 14.242/100.0 = 14.2% done in 361.3s, 2175.4s to go
# on time step 14242 (time=14.242), 0.0306764 s/step
# Meep progress: 14.375/100.0 = 14.4% done in 365.3s, 2175.8s to go
# on time step 14375 (time=14.375), 0.0302121 s/step
# Meep progress: 14.508000000000001/100.0 = 14.5% done in 369.3s, 2176.2s to go
# on time step 14508 (time=14.508), 0.0302188 s/step
# Meep progress: 14.644/100.0 = 14.6% done in 373.3s, 2176.0s to go
# on time step 14644 (time=14.644), 0.0295396 s/step
# Meep progress: 14.777000000000001/100.0 = 14.8% done in 377.3s, 2176.2s to go
# on time step 14777 (time=14.777), 0.0301915 s/step
# Meep progress: 14.914/100.0 = 14.9% done in 381.3s, 2175.6s to go
# on time step 14914 (time=14.914), 0.0292055 s/step
# Meep progress: 15.047/100.0 = 15.0% done in 385.4s, 2175.7s to go
# on time step 15047 (time=15.047), 0.0302172 s/step
# Meep progress: 15.18/100.0 = 15.2% done in 389.4s, 2175.7s to go
# on time step 15180 (time=15.18), 0.030234 s/step
# Meep progress: 15.319/100.0 = 15.3% done in 393.4s, 2174.7s to go
# on time step 15319 (time=15.319), 0.0289393 s/step
# Meep progress: 15.453000000000001/100.0 = 15.5% done in 397.4s, 2174.5s to go
# on time step 15453 (time=15.453), 0.0300315 s/step
# Meep progress: 15.588000000000001/100.0 = 15.6% done in 401.5s, 2174.0s to go
# on time step 15588 (time=15.588), 0.0297812 s/step
# Meep progress: 15.715/100.0 = 15.7% done in 405.5s, 2174.8s to go
# on time step 15715 (time=15.715), 0.0317205 s/step
# Meep progress: 15.843/100.0 = 15.8% done in 409.5s, 2175.2s to go
# on time step 15843 (time=15.843), 0.0313453 s/step
# Meep progress: 15.973/100.0 = 16.0% done in 413.5s, 2175.4s to go
# on time step 15973 (time=15.973), 0.0309416 s/step
# Meep progress: 16.105/100.0 = 16.1% done in 417.5s, 2175.1s to go
# on time step 16105 (time=16.105), 0.0304464 s/step
# Meep progress: 16.236/100.0 = 16.2% done in 421.6s, 2174.9s to go
# on time step 16236 (time=16.236), 0.0306405 s/step
# Meep progress: 16.37/100.0 = 16.4% done in 425.6s, 2174.1s to go
# on time step 16370 (time=16.37), 0.0298547 s/step
# Meep progress: 16.5/100.0 = 16.5% done in 429.6s, 2173.9s to go
# on time step 16500 (time=16.5), 0.0309008 s/step
# Meep progress: 16.633/100.0 = 16.6% done in 433.6s, 2173.2s to go
# on time step 16633 (time=16.633), 0.0302298 s/step
# Meep progress: 16.767/100.0 = 16.8% done in 437.6s, 2172.4s to go
# on time step 16767 (time=16.767), 0.03 s/step
# Meep progress: 16.889/100.0 = 16.9% done in 441.6s, 2173.4s to go
# on time step 16889 (time=16.889), 0.0330291 s/step
# Meep progress: 17.016000000000002/100.0 = 17.0% done in 445.7s, 2173.5s to go
# on time step 17016 (time=17.016), 0.0318048 s/step
# Meep progress: 17.142/100.0 = 17.1% done in 449.7s, 2173.7s to go
# on time step 17142 (time=17.142), 0.0319404 s/step
# Meep progress: 17.278/100.0 = 17.3% done in 453.7s, 2172.4s to go
# on time step 17278 (time=17.278), 0.0296158 s/step
# Meep progress: 17.416/100.0 = 17.4% done in 457.7s, 2170.6s to go
# on time step 17416 (time=17.416), 0.0289986 s/step
# Meep progress: 17.547/100.0 = 17.5% done in 461.7s, 2169.7s to go
# on time step 17547 (time=17.547), 0.0305556 s/step
# Meep progress: 17.684/100.0 = 17.7% done in 465.8s, 2168.0s to go
# on time step 17684 (time=17.684), 0.0292289 s/step
# Meep progress: 17.813/100.0 = 17.8% done in 469.8s, 2167.5s to go
# on time step 17813 (time=17.813), 0.0311308 s/step
# Meep progress: 17.943/100.0 = 17.9% done in 473.8s, 2166.7s to go
# on time step 17943 (time=17.943), 0.0308143 s/step
# Meep progress: 18.071/100.0 = 18.1% done in 477.8s, 2166.2s to go
# on time step 18071 (time=18.071), 0.0314589 s/step
# Meep progress: 18.198/100.0 = 18.2% done in 481.8s, 2165.9s to go
# on time step 18198 (time=18.198), 0.0317431 s/step
# Meep progress: 18.329/100.0 = 18.3% done in 485.9s, 2164.9s to go
# on time step 18329 (time=18.329), 0.0307104 s/step
# Meep progress: 18.462/100.0 = 18.5% done in 489.9s, 2163.6s to go
# on time step 18462 (time=18.462), 0.0301928 s/step
# Meep progress: 18.593/100.0 = 18.6% done in 493.9s, 2162.4s to go
# on time step 18593 (time=18.593), 0.0305429 s/step
# Meep progress: 18.727/100.0 = 18.7% done in 497.9s, 2160.8s to go
# on time step 18727 (time=18.727), 0.0298785 s/step
# Meep progress: 18.855/100.0 = 18.9% done in 501.9s, 2160.0s to go
# on time step 18855 (time=18.855), 0.0313672 s/step
# Meep progress: 18.982/100.0 = 19.0% done in 505.9s, 2159.3s to go
# on time step 18982 (time=18.982), 0.0315025 s/step
# Meep progress: 19.102/100.0 = 19.1% done in 509.9s, 2159.6s to go
# on time step 19102 (time=19.102), 0.03356 s/step
# Meep progress: 19.225/100.0 = 19.2% done in 513.9s, 2159.3s to go
# on time step 19225 (time=19.225), 0.0325638 s/step
# Meep progress: 19.353/100.0 = 19.4% done in 517.9s, 2158.3s to go
# on time step 19353 (time=19.353), 0.0312592 s/step
# Meep progress: 19.484/100.0 = 19.5% done in 522.0s, 2157.0s to go
# on time step 19484 (time=19.484), 0.0307365 s/step
# Meep progress: 19.612000000000002/100.0 = 19.6% done in 526.0s, 2156.0s to go
# on time step 19612 (time=19.612), 0.0314291 s/step
# Meep progress: 19.737000000000002/100.0 = 19.7% done in 530.0s, 2155.4s to go
# on time step 19737 (time=19.737), 0.0322562 s/step
# Meep progress: 19.863/100.0 = 19.9% done in 534.0s, 2154.6s to go
# on time step 19863 (time=19.863), 0.0319172 s/step
# Meep progress: 19.991/100.0 = 20.0% done in 538.1s, 2153.4s to go
# on time step 19991 (time=19.991), 0.0312964 s/step
# Meep progress: 20.117/100.0 = 20.1% done in 542.1s, 2152.5s to go
# on time step 20117 (time=20.117), 0.0317902 s/step
# Meep progress: 20.252/100.0 = 20.3% done in 546.1s, 2150.3s to go
# on time step 20252 (time=20.252), 0.0297571 s/step
# Meep progress: 20.379/100.0 = 20.4% done in 550.1s, 2149.2s to go
# on time step 20379 (time=20.379), 0.0315916 s/step
# Meep progress: 20.518/100.0 = 20.5% done in 554.1s, 2146.5s to go
# on time step 20518 (time=20.518), 0.0289367 s/step
# Meep progress: 20.650000000000002/100.0 = 20.7% done in 558.1s, 2144.6s to go
# on time step 20650 (time=20.65), 0.0303186 s/step
# Meep progress: 20.787/100.0 = 20.8% done in 562.1s, 2142.1s to go
# on time step 20787 (time=20.787), 0.0292372 s/step
# Meep progress: 20.921/100.0 = 20.9% done in 566.1s, 2139.9s to go
# on time step 20921 (time=20.921), 0.0299208 s/step
# Meep progress: 21.051000000000002/100.0 = 21.1% done in 570.2s, 2138.3s to go
# on time step 21051 (time=21.051), 0.0309758 s/step
# Meep progress: 21.185/100.0 = 21.2% done in 574.2s, 2136.1s to go
# on time step 21185 (time=21.185), 0.0299314 s/step
# Meep progress: 21.321/100.0 = 21.3% done in 578.2s, 2133.7s to go
# on time step 21321 (time=21.321), 0.0296014 s/step
# Meep progress: 21.456/100.0 = 21.5% done in 582.2s, 2131.4s to go
# on time step 21456 (time=21.456), 0.0298514 s/step
# Meep progress: 21.589000000000002/100.0 = 21.6% done in 586.2s, 2129.2s to go
# on time step 21589 (time=21.589), 0.0301293 s/step
# Meep progress: 21.724/100.0 = 21.7% done in 590.2s, 2126.8s to go
# on time step 21724 (time=21.724), 0.0296431 s/step
# Meep progress: 21.857/100.0 = 21.9% done in 594.3s, 2124.6s to go
# on time step 21857 (time=21.857), 0.0301545 s/step
# Meep progress: 21.994/100.0 = 22.0% done in 598.3s, 2121.9s to go
# on time step 21994 (time=21.994), 0.0293611 s/step
# Meep progress: 22.125/100.0 = 22.1% done in 602.3s, 2120.0s to go
# on time step 22125 (time=22.125), 0.0308761 s/step
# Meep progress: 22.257/100.0 = 22.3% done in 606.3s, 2117.9s to go
# on time step 22257 (time=22.257), 0.0303116 s/step
# Meep progress: 22.385/100.0 = 22.4% done in 610.3s, 2116.2s to go
# on time step 22385 (time=22.385), 0.0313897 s/step
# Meep progress: 22.516000000000002/100.0 = 22.5% done in 614.4s, 2114.2s to go
# on time step 22516 (time=22.516), 0.0306618 s/step
# Meep progress: 22.650000000000002/100.0 = 22.7% done in 618.4s, 2111.8s to go
# on time step 22650 (time=22.65), 0.0300342 s/step
# Meep progress: 22.783/100.0 = 22.8% done in 622.4s, 2109.4s to go
# on time step 22784 (time=22.784), 0.0301007 s/step
# Meep progress: 22.919/100.0 = 22.9% done in 626.4s, 2106.7s to go
# on time step 22920 (time=22.92), 0.0295646 s/step
# Meep progress: 23.051000000000002/100.0 = 23.1% done in 630.4s, 2104.4s to go
# on time step 23053 (time=23.053), 0.0302454 s/step
# Meep progress: 23.183/100.0 = 23.2% done in 634.4s, 2102.2s to go
# on time step 23184 (time=23.184), 0.0306389 s/step
# Meep progress: 23.317/100.0 = 23.3% done in 638.5s, 2099.7s to go
# on time step 23318 (time=23.318), 0.0298529 s/step
# Meep progress: 23.449/100.0 = 23.4% done in 642.5s, 2097.3s to go
# on time step 23450 (time=23.45), 0.0304152 s/step
# Meep progress: 23.581/100.0 = 23.6% done in 646.5s, 2095.0s to go
# on time step 23582 (time=23.582), 0.030386 s/step
# Meep progress: 23.714000000000002/100.0 = 23.7% done in 650.5s, 2092.5s to go
# on time step 23716 (time=23.716), 0.0300818 s/step
# Meep progress: 23.846/100.0 = 23.8% done in 654.5s, 2090.1s to go
# on time step 23848 (time=23.848), 0.0303075 s/step
# Meep progress: 23.981/100.0 = 24.0% done in 658.5s, 2087.4s to go
# on time step 23983 (time=23.983), 0.0298863 s/step
# Meep progress: 24.115000000000002/100.0 = 24.1% done in 662.5s, 2084.8s to go
# on time step 24118 (time=24.118), 0.0297704 s/step
# Meep progress: 24.253/100.0 = 24.3% done in 666.5s, 2081.7s to go
# on time step 24256 (time=24.256), 0.0291853 s/step
# Meep progress: 24.388/100.0 = 24.4% done in 670.5s, 2078.9s to go
# on time step 24391 (time=24.391), 0.029672 s/step
# Meep progress: 24.524/100.0 = 24.5% done in 674.6s, 2076.1s to go
# on time step 24527 (time=24.527), 0.0295524 s/step
# Meep progress: 24.655/100.0 = 24.7% done in 678.6s, 2073.7s to go
# on time step 24658 (time=24.658), 0.0306094 s/step
# Meep progress: 24.793/100.0 = 24.8% done in 682.6s, 2070.5s to go
# on time step 24796 (time=24.796), 0.0290734 s/step
# Meep progress: 24.919/100.0 = 24.9% done in 686.6s, 2068.7s to go
# on time step 24922 (time=24.922), 0.0317715 s/step
# Meep progress: 25.048000000000002/100.0 = 25.0% done in 690.6s, 2066.6s to go
# on time step 25050 (time=25.05), 0.0313314 s/step
# Meep progress: 25.184/100.0 = 25.2% done in 694.6s, 2063.6s to go
# on time step 25187 (time=25.187), 0.0293467 s/step
# Meep progress: 25.324/100.0 = 25.3% done in 698.6s, 2060.2s to go
# on time step 25327 (time=25.327), 0.0287078 s/step
# Meep progress: 25.461000000000002/100.0 = 25.5% done in 702.6s, 2057.1s to go
# on time step 25464 (time=25.464), 0.029254 s/step
# Meep progress: 25.596/100.0 = 25.6% done in 706.7s, 2054.2s to go
# on time step 25599 (time=25.599), 0.0297764 s/step
# Meep progress: 25.723/100.0 = 25.7% done in 710.7s, 2052.1s to go
# on time step 25726 (time=25.726), 0.0315311 s/step
# Meep progress: 25.855/100.0 = 25.9% done in 714.7s, 2049.6s to go
# on time step 25858 (time=25.858), 0.0304663 s/step
# Meep progress: 25.986/100.0 = 26.0% done in 718.7s, 2047.1s to go
# on time step 25989 (time=25.989), 0.0306974 s/step
# Meep progress: 26.122/100.0 = 26.1% done in 722.7s, 2044.0s to go
# on time step 26125 (time=26.125), 0.0294939 s/step
# Meep progress: 26.257/100.0 = 26.3% done in 726.8s, 2041.1s to go
# on time step 26260 (time=26.26), 0.0297757 s/step
# Meep progress: 26.394000000000002/100.0 = 26.4% done in 730.8s, 2037.9s to go
# on time step 26397 (time=26.397), 0.0292051 s/step
# Meep progress: 26.522000000000002/100.0 = 26.5% done in 734.8s, 2035.7s to go
# on time step 26525 (time=26.525), 0.0313918 s/step
# Meep progress: 26.66/100.0 = 26.7% done in 738.8s, 2032.4s to go
# on time step 26662 (time=26.662), 0.0292196 s/step
# Meep progress: 26.798000000000002/100.0 = 26.8% done in 742.8s, 2029.1s to go
# on time step 26800 (time=26.8), 0.029104 s/step
# Meep progress: 26.939/100.0 = 26.9% done in 746.8s, 2025.5s to go
# on time step 26941 (time=26.941), 0.0283917 s/step
# Meep progress: 27.068/100.0 = 27.1% done in 750.8s, 2023.1s to go
# on time step 27070 (time=27.07), 0.0311594 s/step
# Meep progress: 27.199/100.0 = 27.2% done in 754.9s, 2020.4s to go
# on time step 27201 (time=27.201), 0.0305466 s/step
# Meep progress: 27.332/100.0 = 27.3% done in 758.9s, 2017.6s to go
# on time step 27334 (time=27.334), 0.0301701 s/step
# Meep progress: 27.46/100.0 = 27.5% done in 762.9s, 2015.3s to go
# on time step 27462 (time=27.462), 0.0315689 s/step
# Meep progress: 27.59/100.0 = 27.6% done in 766.9s, 2012.7s to go
# on time step 27593 (time=27.593), 0.0306016 s/step
# Meep progress: 27.727/100.0 = 27.7% done in 770.9s, 2009.4s to go
# on time step 27730 (time=27.73), 0.0293215 s/step
# Meep progress: 27.858/100.0 = 27.9% done in 774.9s, 2006.7s to go
# on time step 27861 (time=27.861), 0.0307791 s/step
# Meep progress: 27.986/100.0 = 28.0% done in 778.9s, 2004.4s to go
# on time step 27990 (time=27.99), 0.0310731 s/step
# Meep progress: 28.112000000000002/100.0 = 28.1% done in 782.9s, 2002.1s to go
# on time step 28116 (time=28.116), 0.0318483 s/step
# Meep progress: 28.242/100.0 = 28.2% done in 786.9s, 1999.5s to go
# on time step 28247 (time=28.247), 0.0307025 s/step
# Meep progress: 28.376/100.0 = 28.4% done in 790.9s, 1996.4s to go
# on time step 28381 (time=28.381), 0.0299867 s/step
# Meep progress: 28.513/100.0 = 28.5% done in 795.0s, 1993.1s to go
# on time step 28518 (time=28.518), 0.0292021 s/step
# Meep progress: 28.651/100.0 = 28.7% done in 799.0s, 1989.7s to go
# on time step 28656 (time=28.656), 0.0291873 s/step
# Meep progress: 28.789/100.0 = 28.8% done in 803.0s, 1986.3s to go
# on time step 28793 (time=28.793), 0.029216 s/step
# Meep progress: 28.922/100.0 = 28.9% done in 807.0s, 1983.3s to go
# on time step 28926 (time=28.926), 0.0302026 s/step
# Meep progress: 29.053/100.0 = 29.1% done in 811.0s, 1980.5s to go
# on time step 29057 (time=29.057), 0.0306729 s/step
# Meep progress: 29.188/100.0 = 29.2% done in 815.1s, 1977.4s to go
# on time step 29192 (time=29.192), 0.0297748 s/step
# Meep progress: 29.315/100.0 = 29.3% done in 819.1s, 1975.0s to go
# on time step 29319 (time=29.319), 0.0316342 s/step
# Meep progress: 29.441/100.0 = 29.4% done in 823.1s, 1972.6s to go
# on time step 29445 (time=29.445), 0.0317591 s/step
# Meep progress: 29.573/100.0 = 29.6% done in 827.1s, 1969.7s to go
# on time step 29577 (time=29.577), 0.0304124 s/step
# Meep progress: 29.712/100.0 = 29.7% done in 831.1s, 1966.1s to go
# on time step 29716 (time=29.716), 0.0288227 s/step
# Meep progress: 29.848/100.0 = 29.8% done in 835.1s, 1962.9s to go
# on time step 29851 (time=29.851), 0.0297578 s/step
# Meep progress: 29.98/100.0 = 30.0% done in 839.2s, 1959.9s to go
# on time step 29983 (time=29.983), 0.0303542 s/step
# Meep progress: 30.116/100.0 = 30.1% done in 843.2s, 1956.6s to go
# on time step 30119 (time=30.119), 0.0296306 s/step
# Meep progress: 30.245/100.0 = 30.2% done in 847.2s, 1953.9s to go
# on time step 30249 (time=30.249), 0.030988 s/step
# Meep progress: 30.375/100.0 = 30.4% done in 851.2s, 1951.2s to go
# on time step 30379 (time=30.379), 0.0309807 s/step
# Meep progress: 30.503/100.0 = 30.5% done in 855.2s, 1948.5s to go
# on time step 30507 (time=30.507), 0.0314206 s/step
# Meep progress: 30.625/100.0 = 30.6% done in 859.3s, 1946.5s to go
# on time step 30629 (time=30.629), 0.0330555 s/step
# Meep progress: 30.749000000000002/100.0 = 30.7% done in 863.3s, 1944.2s to go
# on time step 30753 (time=30.753), 0.0323396 s/step
# Meep progress: 30.879/100.0 = 30.9% done in 867.3s, 1941.4s to go
# on time step 30883 (time=30.883), 0.0308814 s/step
# Meep progress: 31.006/100.0 = 31.0% done in 871.3s, 1938.8s to go
# on time step 31011 (time=31.011), 0.0313005 s/step
# Meep progress: 31.135/100.0 = 31.1% done in 875.3s, 1936.0s to go
# on time step 31140 (time=31.14), 0.0311434 s/step
# Meep progress: 31.266000000000002/100.0 = 31.3% done in 879.3s, 1933.1s to go
# on time step 31270 (time=31.27), 0.0309604 s/step
# Meep progress: 31.393/100.0 = 31.4% done in 883.3s, 1930.5s to go
# on time step 31398 (time=31.398), 0.0314441 s/step
# Meep progress: 31.524/100.0 = 31.5% done in 887.4s, 1927.5s to go
# on time step 31528 (time=31.528), 0.0308161 s/step
# Meep progress: 31.646/100.0 = 31.6% done in 891.4s, 1925.4s to go
# on time step 31650 (time=31.65), 0.033037 s/step
# Meep progress: 31.777/100.0 = 31.8% done in 895.4s, 1922.4s to go
# on time step 31782 (time=31.782), 0.0305572 s/step
# Meep progress: 31.899/100.0 = 31.9% done in 899.4s, 1920.2s to go
# on time step 31904 (time=31.904), 0.0329259 s/step
# Meep progress: 32.025/100.0 = 32.0% done in 903.4s, 1917.6s to go
# on time step 32030 (time=32.03), 0.0317472 s/step
# Meep progress: 32.159/100.0 = 32.2% done in 907.5s, 1914.3s to go
# on time step 32163 (time=32.163), 0.03018 s/step
# Meep progress: 32.295/100.0 = 32.3% done in 911.5s, 1910.9s to go
# on time step 32300 (time=32.3), 0.0293901 s/step
# Meep progress: 32.42/100.0 = 32.4% done in 915.5s, 1908.4s to go
# on time step 32425 (time=32.425), 0.0320538 s/step
# Meep progress: 32.552/100.0 = 32.6% done in 919.5s, 1905.2s to go
# on time step 32557 (time=32.557), 0.0303807 s/step
# Meep progress: 32.679/100.0 = 32.7% done in 923.5s, 1902.5s to go
# on time step 32683 (time=32.683), 0.0318093 s/step
# Meep progress: 32.805/100.0 = 32.8% done in 927.6s, 1899.9s to go
# on time step 32808 (time=32.808), 0.0320609 s/step
# Meep progress: 32.934/100.0 = 32.9% done in 931.6s, 1897.0s to go
# on time step 32938 (time=32.938), 0.0308805 s/step
# Meep progress: 33.065/100.0 = 33.1% done in 935.6s, 1894.0s to go
# on time step 33069 (time=33.069), 0.0305613 s/step
# Meep progress: 33.197/100.0 = 33.2% done in 939.6s, 1890.8s to go
# on time step 33200 (time=33.2), 0.0307347 s/step
# Meep progress: 33.323/100.0 = 33.3% done in 943.6s, 1888.1s to go
# on time step 33326 (time=33.326), 0.0318842 s/step
# Meep progress: 33.447/100.0 = 33.4% done in 947.6s, 1885.6s to go
# on time step 33451 (time=33.451), 0.0323192 s/step
# Meep progress: 33.578/100.0 = 33.6% done in 951.6s, 1882.5s to go
# on time step 33583 (time=33.583), 0.0304128 s/step
# Meep progress: 33.709/100.0 = 33.7% done in 955.7s, 1879.4s to go
# on time step 33714 (time=33.714), 0.0306587 s/step
# Meep progress: 33.845/100.0 = 33.8% done in 959.7s, 1875.8s to go
# on time step 33850 (time=33.85), 0.0294933 s/step
# Meep progress: 33.983000000000004/100.0 = 34.0% done in 963.7s, 1872.1s to go
# on time step 33988 (time=33.988), 0.0291136 s/step
# Meep progress: 34.121/100.0 = 34.1% done in 967.7s, 1868.4s to go
# on time step 34127 (time=34.127), 0.0288652 s/step
# Meep progress: 34.26/100.0 = 34.3% done in 971.7s, 1864.6s to go
# on time step 34266 (time=34.266), 0.0289276 s/step
# Meep progress: 34.397/100.0 = 34.4% done in 975.7s, 1860.9s to go
# on time step 34403 (time=34.403), 0.0293189 s/step
# Meep progress: 34.534/100.0 = 34.5% done in 979.7s, 1857.3s to go
# on time step 34540 (time=34.54), 0.0293033 s/step
# Meep progress: 34.660000000000004/100.0 = 34.7% done in 983.7s, 1854.5s to go
# on time step 34666 (time=34.666), 0.0318573 s/step
# Meep progress: 34.787/100.0 = 34.8% done in 987.8s, 1851.7s to go
# on time step 34793 (time=34.793), 0.0315494 s/step
# Meep progress: 34.913000000000004/100.0 = 34.9% done in 991.8s, 1849.0s to go
# on time step 34917 (time=34.917), 0.032282 s/step
# Meep progress: 35.019/100.0 = 35.0% done in 995.8s, 1847.8s to go
# on time step 35023 (time=35.023), 0.0379816 s/step
# Meep progress: 35.137/100.0 = 35.1% done in 999.8s, 1845.7s to go
# on time step 35141 (time=35.141), 0.0339934 s/step
# Meep progress: 35.256/100.0 = 35.3% done in 1003.8s, 1843.5s to go
# on time step 35260 (time=35.26), 0.0336801 s/step
# Meep progress: 35.378/100.0 = 35.4% done in 1007.9s, 1841.0s to go
# on time step 35381 (time=35.381), 0.0331081 s/step
# Meep progress: 35.498/100.0 = 35.5% done in 1011.9s, 1838.7s to go
# on time step 35501 (time=35.501), 0.0334563 s/step
# Meep progress: 35.616/100.0 = 35.6% done in 1015.9s, 1836.5s to go
# on time step 35618 (time=35.618), 0.0341898 s/step
# Meep progress: 35.731/100.0 = 35.7% done in 1020.0s, 1834.6s to go
# on time step 35733 (time=35.733), 0.0350036 s/step
# Meep progress: 35.843/100.0 = 35.8% done in 1024.0s, 1832.8s to go
# on time step 35846 (time=35.846), 0.035575 s/step
# Meep progress: 35.951/100.0 = 36.0% done in 1028.0s, 1831.4s to go
# on time step 35953 (time=35.953), 0.0375858 s/step
# Meep progress: 36.062/100.0 = 36.1% done in 1032.0s, 1829.8s to go
# on time step 36064 (time=36.064), 0.0361124 s/step
# Meep progress: 36.182/100.0 = 36.2% done in 1036.1s, 1827.4s to go
# on time step 36183 (time=36.183), 0.0336433 s/step
# Meep progress: 36.297000000000004/100.0 = 36.3% done in 1040.1s, 1825.4s to go
# on time step 36298 (time=36.298), 0.0349558 s/step
# Meep progress: 36.415/100.0 = 36.4% done in 1044.1s, 1823.1s to go
# on time step 36416 (time=36.416), 0.0339085 s/step
# Meep progress: 36.533/100.0 = 36.5% done in 1048.1s, 1820.8s to go
# on time step 36534 (time=36.534), 0.0339991 s/step
# Meep progress: 36.651/100.0 = 36.7% done in 1052.1s, 1818.5s to go
# on time step 36651 (time=36.651), 0.0341927 s/step
# Meep progress: 36.769/100.0 = 36.8% done in 1056.2s, 1816.3s to go
# on time step 36769 (time=36.769), 0.0341255 s/step
# Meep progress: 36.889/100.0 = 36.9% done in 1060.2s, 1813.8s to go
# on time step 36889 (time=36.889), 0.0335416 s/step
# Meep progress: 37.006/100.0 = 37.0% done in 1064.2s, 1811.6s to go
# on time step 37006 (time=37.006), 0.0343723 s/step
# Meep progress: 37.125/100.0 = 37.1% done in 1068.2s, 1809.1s to go
# on time step 37125 (time=37.125), 0.0337169 s/step
# Meep progress: 37.244/100.0 = 37.2% done in 1072.2s, 1806.7s to go
# on time step 37244 (time=37.244), 0.0337756 s/step
# Meep progress: 37.363/100.0 = 37.4% done in 1076.2s, 1804.3s to go
# on time step 37363 (time=37.363), 0.0336399 s/step
# Meep progress: 37.477000000000004/100.0 = 37.5% done in 1080.2s, 1802.2s to go
# on time step 37477 (time=37.477), 0.0351092 s/step
# Meep progress: 37.598/100.0 = 37.6% done in 1084.3s, 1799.6s to go
# on time step 37598 (time=37.598), 0.0331796 s/step
# Meep progress: 37.716/100.0 = 37.7% done in 1088.3s, 1797.2s to go
# on time step 37716 (time=37.716), 0.0340788 s/step
# Meep progress: 37.833/100.0 = 37.8% done in 1092.3s, 1794.9s to go
# on time step 37833 (time=37.833), 0.0343216 s/step
# Meep progress: 37.95/100.0 = 38.0% done in 1096.3s, 1792.5s to go
# on time step 37950 (time=37.95), 0.0344198 s/step
# Meep progress: 38.069/100.0 = 38.1% done in 1100.4s, 1790.1s to go
# on time step 38069 (time=38.069), 0.0338462 s/step
# Meep progress: 38.189/100.0 = 38.2% done in 1104.4s, 1787.5s to go
# on time step 38189 (time=38.189), 0.0336503 s/step
# Meep progress: 38.301/100.0 = 38.3% done in 1108.4s, 1785.6s to go
# on time step 38301 (time=38.301), 0.0359472 s/step
# Meep progress: 38.418/100.0 = 38.4% done in 1112.4s, 1783.2s to go
# on time step 38418 (time=38.418), 0.0343433 s/step
# Meep progress: 38.529/100.0 = 38.5% done in 1116.5s, 1781.2s to go
# on time step 38529 (time=38.529), 0.0361331 s/step
# Meep progress: 38.645/100.0 = 38.6% done in 1120.5s, 1778.9s to go
# on time step 38645 (time=38.645), 0.0347189 s/step
# Meep progress: 38.77/100.0 = 38.8% done in 1124.5s, 1775.9s to go
# on time step 38770 (time=38.77), 0.0320446 s/step
# Meep progress: 38.902/100.0 = 38.9% done in 1128.5s, 1772.4s to go
# on time step 38902 (time=38.902), 0.0304447 s/step
# Meep progress: 39.039/100.0 = 39.0% done in 1132.5s, 1768.5s to go
# on time step 39039 (time=39.039), 0.0293475 s/step
# Meep progress: 39.178/100.0 = 39.2% done in 1136.5s, 1764.4s to go
# on time step 39178 (time=39.178), 0.0287952 s/step
# Meep progress: 39.315/100.0 = 39.3% done in 1140.5s, 1760.5s to go
# on time step 39315 (time=39.315), 0.0292084 s/step
# Meep progress: 39.44/100.0 = 39.4% done in 1144.6s, 1757.5s to go
# on time step 39440 (time=39.44), 0.032141 s/step
# Meep progress: 39.563/100.0 = 39.6% done in 1148.6s, 1754.6s to go
# on time step 39563 (time=39.563), 0.0325911 s/step
# Meep progress: 39.684/100.0 = 39.7% done in 1152.6s, 1751.8s to go
# on time step 39684 (time=39.684), 0.03318 s/step
# Meep progress: 39.807/100.0 = 39.8% done in 1156.6s, 1748.9s to go
# on time step 39807 (time=39.807), 0.0327852 s/step
# Meep progress: 39.929/100.0 = 39.9% done in 1160.6s, 1746.1s to go
# on time step 39929 (time=39.929), 0.0329388 s/step
# Meep progress: 40.047000000000004/100.0 = 40.0% done in 1164.6s, 1743.6s to go
# on time step 40047 (time=40.047), 0.0340252 s/step
# Meep progress: 40.159/100.0 = 40.2% done in 1168.7s, 1741.4s to go
# on time step 40159 (time=40.159), 0.0358119 s/step
# Meep progress: 40.271/100.0 = 40.3% done in 1172.7s, 1739.3s to go
# on time step 40271 (time=40.271), 0.0357193 s/step
# Meep progress: 40.382/100.0 = 40.4% done in 1176.7s, 1737.2s to go
# on time step 40382 (time=40.382), 0.0361324 s/step
# Meep progress: 40.502/100.0 = 40.5% done in 1180.7s, 1734.4s to go
# on time step 40502 (time=40.502), 0.0334468 s/step
# Meep progress: 40.623/100.0 = 40.6% done in 1184.7s, 1731.6s to go
# on time step 40623 (time=40.623), 0.0331136 s/step
# Meep progress: 40.742/100.0 = 40.7% done in 1188.7s, 1728.9s to go
# on time step 40742 (time=40.742), 0.0336712 s/step
# Meep progress: 40.866/100.0 = 40.9% done in 1192.7s, 1725.9s to go
# on time step 40866 (time=40.866), 0.0323838 s/step
# Meep progress: 40.985/100.0 = 41.0% done in 1196.7s, 1723.2s to go
# on time step 40985 (time=40.985), 0.0337238 s/step
# Meep progress: 41.104/100.0 = 41.1% done in 1200.8s, 1720.5s to go
# on time step 41104 (time=41.104), 0.0339024 s/step
# Meep progress: 41.226/100.0 = 41.2% done in 1204.8s, 1717.6s to go
# on time step 41226 (time=41.226), 0.0329197 s/step
# Meep progress: 41.346000000000004/100.0 = 41.3% done in 1208.8s, 1714.8s to go
# on time step 41346 (time=41.346), 0.0335255 s/step
# Meep progress: 41.469/100.0 = 41.5% done in 1212.8s, 1711.8s to go
# on time step 41470 (time=41.47), 0.0325606 s/step
# Meep progress: 41.594/100.0 = 41.6% done in 1216.8s, 1708.7s to go
# on time step 41595 (time=41.595), 0.0320019 s/step
# Meep progress: 41.715/100.0 = 41.7% done in 1220.8s, 1705.8s to go
# on time step 41716 (time=41.716), 0.033296 s/step
# Meep progress: 41.837/100.0 = 41.8% done in 1224.9s, 1702.9s to go
# on time step 41838 (time=41.838), 0.0329466 s/step
# Meep progress: 41.958/100.0 = 42.0% done in 1228.9s, 1700.0s to go
# on time step 41959 (time=41.959), 0.0333209 s/step
# Meep progress: 42.074/100.0 = 42.1% done in 1232.9s, 1697.4s to go
# on time step 42076 (time=42.076), 0.0345424 s/step
# Meep progress: 42.191/100.0 = 42.2% done in 1236.9s, 1694.8s to go
# on time step 42194 (time=42.194), 0.0341351 s/step
# Meep progress: 42.31/100.0 = 42.3% done in 1240.9s, 1692.0s to go
# on time step 42313 (time=42.313), 0.0337568 s/step
# Meep progress: 42.429/100.0 = 42.4% done in 1245.0s, 1689.2s to go
# on time step 42432 (time=42.432), 0.0338274 s/step
# Meep progress: 42.550000000000004/100.0 = 42.6% done in 1249.0s, 1686.3s to go
# on time step 42553 (time=42.553), 0.0333107 s/step
# Meep progress: 42.672000000000004/100.0 = 42.7% done in 1253.0s, 1683.3s to go
# on time step 42675 (time=42.675), 0.0329504 s/step
# Meep progress: 42.792/100.0 = 42.8% done in 1257.0s, 1680.5s to go
# on time step 42795 (time=42.795), 0.0334417 s/step
# Meep progress: 42.908/100.0 = 42.9% done in 1261.0s, 1677.9s to go
# on time step 42911 (time=42.911), 0.0344894 s/step
# Meep progress: 43.021/100.0 = 43.0% done in 1265.1s, 1675.5s to go
# on time step 43023 (time=43.023), 0.0359664 s/step
# Meep progress: 43.13/100.0 = 43.1% done in 1269.1s, 1673.3s to go
# on time step 43133 (time=43.133), 0.0365866 s/step
# Meep progress: 43.24/100.0 = 43.2% done in 1273.1s, 1671.1s to go
# on time step 43244 (time=43.244), 0.0362557 s/step
# Meep progress: 43.354/100.0 = 43.4% done in 1277.1s, 1668.6s to go
# on time step 43359 (time=43.359), 0.0350414 s/step
# Meep progress: 43.475/100.0 = 43.5% done in 1281.1s, 1665.6s to go
# on time step 43480 (time=43.48), 0.0333205 s/step
# Meep progress: 43.593/100.0 = 43.6% done in 1285.1s, 1662.8s to go
# on time step 43599 (time=43.599), 0.0338496 s/step
# Meep progress: 43.702/100.0 = 43.7% done in 1289.1s, 1660.7s to go
# on time step 43707 (time=43.707), 0.0371784 s/step
# Meep progress: 43.817/100.0 = 43.8% done in 1293.1s, 1658.1s to go
# on time step 43822 (time=43.822), 0.034914 s/step
# Meep progress: 43.93/100.0 = 43.9% done in 1297.2s, 1655.6s to go
# on time step 43935 (time=43.935), 0.0355281 s/step
# Meep progress: 44.048/100.0 = 44.0% done in 1301.2s, 1652.9s to go
# on time step 44052 (time=44.052), 0.0342722 s/step
# Meep progress: 44.154/100.0 = 44.2% done in 1305.2s, 1650.9s to go
# on time step 44157 (time=44.157), 0.0383481 s/step
# Meep progress: 44.268/100.0 = 44.3% done in 1309.3s, 1648.3s to go
# on time step 44271 (time=44.271), 0.0350976 s/step
# Meep progress: 44.382/100.0 = 44.4% done in 1313.3s, 1645.7s to go
# on time step 44385 (time=44.385), 0.0352322 s/step
# Meep progress: 44.491/100.0 = 44.5% done in 1317.3s, 1643.5s to go
# on time step 44495 (time=44.495), 0.0363854 s/step
# Meep progress: 44.608000000000004/100.0 = 44.6% done in 1321.3s, 1640.7s to go
# on time step 44611 (time=44.611), 0.0345089 s/step
# Meep progress: 44.726/100.0 = 44.7% done in 1325.3s, 1637.9s to go
# on time step 44729 (time=44.729), 0.034038 s/step
# Meep progress: 44.841/100.0 = 44.8% done in 1329.3s, 1635.2s to go
# on time step 44844 (time=44.844), 0.0350529 s/step
# Meep progress: 44.953/100.0 = 45.0% done in 1333.3s, 1632.7s to go
# on time step 44957 (time=44.957), 0.0355752 s/step
# Meep progress: 45.085/100.0 = 45.1% done in 1337.4s, 1628.9s to go
# on time step 45090 (time=45.09), 0.030304 s/step
# Meep progress: 45.217/100.0 = 45.2% done in 1341.4s, 1625.1s to go
# on time step 45222 (time=45.222), 0.0303655 s/step
# Meep progress: 45.35/100.0 = 45.4% done in 1345.4s, 1621.3s to go
# on time step 45355 (time=45.355), 0.0301675 s/step
# Meep progress: 45.482/100.0 = 45.5% done in 1349.4s, 1617.5s to go
# on time step 45487 (time=45.487), 0.0304253 s/step
# Meep progress: 45.617000000000004/100.0 = 45.6% done in 1353.4s, 1613.5s to go
# on time step 45621 (time=45.621), 0.0298696 s/step
# Meep progress: 45.75/100.0 = 45.8% done in 1357.4s, 1609.6s to go
# on time step 45755 (time=45.755), 0.0299257 s/step
# Meep progress: 45.887/100.0 = 45.9% done in 1361.4s, 1605.5s to go
# on time step 45891 (time=45.891), 0.0295375 s/step
# Meep progress: 46.021/100.0 = 46.0% done in 1365.5s, 1601.6s to go
# on time step 46025 (time=46.025), 0.0298525 s/step
# Meep progress: 46.156/100.0 = 46.2% done in 1369.5s, 1597.6s to go
# on time step 46160 (time=46.16), 0.0296796 s/step
# Meep progress: 46.287/100.0 = 46.3% done in 1373.5s, 1593.8s to go
# on time step 46291 (time=46.291), 0.0307055 s/step
# Meep progress: 46.414/100.0 = 46.4% done in 1377.5s, 1590.4s to go
# on time step 46417 (time=46.417), 0.0319017 s/step
# Meep progress: 46.548/100.0 = 46.5% done in 1381.5s, 1586.4s to go
# on time step 46552 (time=46.552), 0.0298302 s/step
# Meep progress: 46.689/100.0 = 46.7% done in 1385.6s, 1582.1s to go
# on time step 46693 (time=46.693), 0.0284973 s/step
# Meep progress: 46.83/100.0 = 46.8% done in 1389.6s, 1577.7s to go
# on time step 46835 (time=46.835), 0.0283179 s/step
# Meep progress: 46.966/100.0 = 47.0% done in 1393.6s, 1573.6s to go
# on time step 46971 (time=46.971), 0.0295676 s/step
# Meep progress: 47.105000000000004/100.0 = 47.1% done in 1397.6s, 1569.4s to go
# on time step 47110 (time=47.11), 0.0288494 s/step
# Meep progress: 47.238/100.0 = 47.2% done in 1401.6s, 1565.5s to go
# on time step 47243 (time=47.243), 0.0302611 s/step
# Meep progress: 47.374/100.0 = 47.4% done in 1405.6s, 1561.5s to go
# on time step 47379 (time=47.379), 0.0294848 s/step
# Meep progress: 47.506/100.0 = 47.5% done in 1409.7s, 1557.7s to go
# on time step 47510 (time=47.51), 0.0306556 s/step
# Meep progress: 47.639/100.0 = 47.6% done in 1413.7s, 1553.8s to go
# on time step 47644 (time=47.644), 0.0300089 s/step
# Meep progress: 47.769/100.0 = 47.8% done in 1417.7s, 1550.1s to go
# on time step 47774 (time=47.774), 0.0308854 s/step
# Meep progress: 47.901/100.0 = 47.9% done in 1421.7s, 1546.3s to go
# on time step 47906 (time=47.906), 0.0304587 s/step
# Meep progress: 48.029/100.0 = 48.0% done in 1425.7s, 1542.7s to go
# on time step 48034 (time=48.034), 0.0313975 s/step
# Meep progress: 48.162/100.0 = 48.2% done in 1429.7s, 1538.8s to go
# on time step 48167 (time=48.167), 0.0301315 s/step
# Meep progress: 48.299/100.0 = 48.3% done in 1433.7s, 1534.7s to go
# on time step 48304 (time=48.304), 0.0293162 s/step
# Meep progress: 48.441/100.0 = 48.4% done in 1437.7s, 1530.3s to go
# on time step 48447 (time=48.447), 0.0280946 s/step
# Meep progress: 48.584/100.0 = 48.6% done in 1441.8s, 1525.8s to go
# on time step 48590 (time=48.59), 0.0280312 s/step
# Meep progress: 48.727000000000004/100.0 = 48.7% done in 1445.8s, 1521.3s to go
# on time step 48734 (time=48.734), 0.027877 s/step
# Meep progress: 48.877/100.0 = 48.9% done in 1449.8s, 1516.4s to go
# on time step 48884 (time=48.884), 0.0267061 s/step
# Meep progress: 49.033/100.0 = 49.0% done in 1453.8s, 1511.1s to go
# on time step 49041 (time=49.041), 0.025614 s/step
# Meep progress: 49.198/100.0 = 49.2% done in 1457.8s, 1505.3s to go
# on time step 49206 (time=49.206), 0.0242523 s/step
# Meep progress: 49.361000000000004/100.0 = 49.4% done in 1461.8s, 1499.6s to go
# on time step 49369 (time=49.369), 0.024651 s/step
# Meep progress: 49.521/100.0 = 49.5% done in 1465.8s, 1494.2s to go
# on time step 49529 (time=49.529), 0.0250949 s/step
# Meep progress: 49.673/100.0 = 49.7% done in 1469.8s, 1489.2s to go
# on time step 49680 (time=49.68), 0.0265655 s/step
# Meep progress: 49.82/100.0 = 49.8% done in 1473.8s, 1484.5s to go
# on time step 49828 (time=49.828), 0.0271559 s/step
# Meep progress: 49.978/100.0 = 50.0% done in 1477.8s, 1479.1s to go
# on time step 49986 (time=49.986), 0.0253329 s/step
# Meep progress: 50.134/100.0 = 50.1% done in 1481.9s, 1473.9s to go
# on time step 50142 (time=50.142), 0.0257805 s/step
# Meep progress: 50.302/100.0 = 50.3% done in 1485.9s, 1468.1s to go
# on time step 50309 (time=50.309), 0.0240429 s/step
# Meep progress: 50.465/100.0 = 50.5% done in 1489.9s, 1462.5s to go
# on time step 50471 (time=50.471), 0.0247268 s/step
# Meep progress: 50.618/100.0 = 50.6% done in 1493.9s, 1457.4s to go
# on time step 50625 (time=50.625), 0.0260218 s/step
# Meep progress: 50.78/100.0 = 50.8% done in 1497.9s, 1451.9s to go
# on time step 50788 (time=50.788), 0.0246502 s/step
# Meep progress: 50.936/100.0 = 50.9% done in 1501.9s, 1446.7s to go
# on time step 50943 (time=50.943), 0.0259273 s/step
# Meep progress: 51.092/100.0 = 51.1% done in 1505.9s, 1441.6s to go
# on time step 51100 (time=51.1), 0.0255541 s/step
# Meep progress: 51.258/100.0 = 51.3% done in 1510.0s, 1435.8s to go
# on time step 51266 (time=51.266), 0.0242374 s/step
# Meep progress: 51.426/100.0 = 51.4% done in 1514.0s, 1430.0s to go
# on time step 51434 (time=51.434), 0.0238879 s/step
# Meep progress: 51.589/100.0 = 51.6% done in 1518.0s, 1424.5s to go
# on time step 51596 (time=51.596), 0.0247387 s/step
# Meep progress: 51.754/100.0 = 51.8% done in 1522.0s, 1418.8s to go
# on time step 51762 (time=51.762), 0.0243195 s/step
# Meep progress: 51.92/100.0 = 51.9% done in 1526.0s, 1413.1s to go
# on time step 51929 (time=51.929), 0.0240133 s/step
# Meep progress: 52.087/100.0 = 52.1% done in 1530.0s, 1407.4s to go
# on time step 52096 (time=52.096), 0.0239814 s/step
# Meep progress: 52.257/100.0 = 52.3% done in 1534.0s, 1401.5s to go
# on time step 52266 (time=52.266), 0.0236206 s/step
# Meep progress: 52.424/100.0 = 52.4% done in 1538.1s, 1395.8s to go
# on time step 52433 (time=52.433), 0.0240509 s/step
# Meep progress: 52.588/100.0 = 52.6% done in 1542.1s, 1390.3s to go
# on time step 52597 (time=52.597), 0.0245427 s/step
# Meep progress: 52.754/100.0 = 52.8% done in 1546.1s, 1384.6s to go
# on time step 52765 (time=52.765), 0.0239269 s/step
# Meep progress: 52.921/100.0 = 52.9% done in 1550.1s, 1379.0s to go
# on time step 52931 (time=52.931), 0.0241266 s/step
# Meep progress: 53.083/100.0 = 53.1% done in 1554.1s, 1373.6s to go
# on time step 53094 (time=53.094), 0.0246719 s/step
# Meep progress: 53.25/100.0 = 53.2% done in 1558.1s, 1367.9s to go
# on time step 53260 (time=53.26), 0.0241287 s/step
# ...
# Meep progress: 81.514/100.0 = 81.5% done in 2308.7s, 523.6s to go
# on time step 81518 (time=81.518), 0.027768 s/step
# Meep progress: 81.664/100.0 = 81.7% done in 2312.8s, 519.3s to go
# on time step 81668 (time=81.668), 0.026754 s/step
# Meep progress: 81.812/100.0 = 81.8% done in 2316.8s, 515.1s to go
# on time step 81816 (time=81.816), 0.0271694 s/step
# Meep progress: 81.962/100.0 = 82.0% done in 2320.8s, 510.8s to go
# on time step 81966 (time=81.966), 0.0267274 s/step
# Meep progress: 82.111/100.0 = 82.1% done in 2324.8s, 506.5s to go
# on time step 82115 (time=82.115), 0.026921 s/step
# Meep progress: 82.261/100.0 = 82.3% done in 2328.8s, 502.2s to go
# on time step 82266 (time=82.266), 0.0266772 s/step
# Meep progress: 82.413/100.0 = 82.4% done in 2332.8s, 497.8s to go
# on time step 82418 (time=82.418), 0.0264647 s/step
# Meep progress: 82.566/100.0 = 82.6% done in 2336.9s, 493.4s to go
# on time step 82570 (time=82.57), 0.0264553 s/step
# Meep progress: 82.718/100.0 = 82.7% done in 2340.9s, 489.1s to go
# on time step 82723 (time=82.723), 0.0261923 s/step
# Meep progress: 82.865/100.0 = 82.9% done in 2344.9s, 484.9s to go
# on time step 82869 (time=82.869), 0.0274306 s/step
# Meep progress: 83.007/100.0 = 83.0% done in 2348.9s, 480.9s to go
# on time step 83011 (time=83.011), 0.0282282 s/step
# Meep progress: 83.146/100.0 = 83.1% done in 2352.9s, 476.9s to go
# on time step 83150 (time=83.15), 0.0288346 s/step
# Meep progress: 83.288/100.0 = 83.3% done in 2356.9s, 472.9s to go
# on time step 83291 (time=83.291), 0.0284252 s/step
# Meep progress: 83.428/100.0 = 83.4% done in 2360.9s, 469.0s to go
# on time step 83432 (time=83.432), 0.0285193 s/step
# Meep progress: 83.57600000000001/100.0 = 83.6% done in 2365.0s, 464.8s to go
# on time step 83581 (time=83.581), 0.0269772 s/step
# Meep progress: 83.726/100.0 = 83.7% done in 2369.0s, 460.5s to go
# on time step 83730 (time=83.73), 0.0268529 s/step
# Meep progress: 83.874/100.0 = 83.9% done in 2373.0s, 456.2s to go
# on time step 83878 (time=83.878), 0.0271948 s/step
# Meep progress: 84.018/100.0 = 84.0% done in 2377.0s, 452.2s to go
# on time step 84022 (time=84.022), 0.0278555 s/step
# Meep progress: 84.164/100.0 = 84.2% done in 2381.0s, 448.0s to go
# on time step 84168 (time=84.168), 0.0274838 s/step
# Meep progress: 84.315/100.0 = 84.3% done in 2385.0s, 443.7s to go
# on time step 84320 (time=84.32), 0.0264539 s/step
# Meep progress: 84.467/100.0 = 84.5% done in 2389.0s, 439.3s to go
# on time step 84472 (time=84.472), 0.0264868 s/step
# Meep progress: 84.617/100.0 = 84.6% done in 2393.1s, 435.0s to go
# on time step 84622 (time=84.622), 0.0267667 s/step
# Meep progress: 84.764/100.0 = 84.8% done in 2397.1s, 430.9s to go
# on time step 84770 (time=84.77), 0.0271815 s/step
# Meep progress: 84.919/100.0 = 84.9% done in 2401.1s, 426.4s to go
# on time step 84925 (time=84.925), 0.0259176 s/step
# Meep progress: 85.071/100.0 = 85.1% done in 2405.1s, 422.1s to go
# on time step 85077 (time=85.077), 0.0264585 s/step
# Meep progress: 85.223/100.0 = 85.2% done in 2409.1s, 417.7s to go
# on time step 85229 (time=85.229), 0.0263428 s/step
# Meep progress: 85.376/100.0 = 85.4% done in 2413.1s, 413.3s to go
# on time step 85382 (time=85.382), 0.0263135 s/step
# Meep progress: 85.526/100.0 = 85.5% done in 2417.1s, 409.1s to go
# on time step 85533 (time=85.533), 0.0266147 s/step
# Meep progress: 85.679/100.0 = 85.7% done in 2421.2s, 404.7s to go
# on time step 85685 (time=85.685), 0.0264154 s/step
# Meep progress: 85.82900000000001/100.0 = 85.8% done in 2425.2s, 400.4s to go
# on time step 85835 (time=85.835), 0.0268065 s/step
# Meep progress: 85.977/100.0 = 86.0% done in 2429.2s, 396.2s to go
# on time step 85984 (time=85.984), 0.0269107 s/step
# Meep progress: 86.13/100.0 = 86.1% done in 2433.2s, 391.8s to go
# on time step 86137 (time=86.137), 0.0262484 s/step
# Meep progress: 86.282/100.0 = 86.3% done in 2437.2s, 387.5s to go
# on time step 86289 (time=86.289), 0.0263567 s/step
# Meep progress: 86.431/100.0 = 86.4% done in 2441.2s, 383.3s to go
# on time step 86438 (time=86.438), 0.0268459 s/step
# Meep progress: 86.583/100.0 = 86.6% done in 2445.2s, 378.9s to go
# on time step 86589 (time=86.589), 0.0265213 s/step
# Meep progress: 86.733/100.0 = 86.7% done in 2449.2s, 374.6s to go
# on time step 86739 (time=86.739), 0.0267988 s/step
# Meep progress: 86.883/100.0 = 86.9% done in 2453.3s, 370.4s to go
# on time step 86890 (time=86.89), 0.026598 s/step
# Meep progress: 87.034/100.0 = 87.0% done in 2457.3s, 366.1s to go
# on time step 87040 (time=87.04), 0.0267299 s/step
# Meep progress: 87.185/100.0 = 87.2% done in 2461.3s, 361.8s to go
# on time step 87191 (time=87.191), 0.0266068 s/step
# Meep progress: 87.336/100.0 = 87.3% done in 2465.3s, 357.5s to go
# on time step 87343 (time=87.343), 0.0263932 s/step
# Meep progress: 87.488/100.0 = 87.5% done in 2469.3s, 353.1s to go
# on time step 87493 (time=87.493), 0.0266873 s/step
# Meep progress: 87.637/100.0 = 87.6% done in 2473.3s, 348.9s to go
# on time step 87642 (time=87.642), 0.0268585 s/step
# Meep progress: 87.787/100.0 = 87.8% done in 2477.4s, 344.7s to go
# on time step 87792 (time=87.792), 0.0267728 s/step
# Meep progress: 87.93900000000001/100.0 = 87.9% done in 2481.4s, 340.3s to go
# on time step 87944 (time=87.944), 0.0264474 s/step
# Meep progress: 88.08800000000001/100.0 = 88.1% done in 2485.4s, 336.1s to go
# on time step 88094 (time=88.094), 0.026816 s/step
# Meep progress: 88.237/100.0 = 88.2% done in 2489.4s, 331.9s to go
# on time step 88243 (time=88.243), 0.0269774 s/step
# Meep progress: 88.388/100.0 = 88.4% done in 2493.4s, 327.6s to go
# on time step 88394 (time=88.394), 0.0265951 s/step
# Meep progress: 88.538/100.0 = 88.5% done in 2497.4s, 323.3s to go
# on time step 88545 (time=88.545), 0.0266503 s/step
# Meep progress: 88.691/100.0 = 88.7% done in 2501.4s, 319.0s to go
# on time step 88697 (time=88.697), 0.0263166 s/step
# Meep progress: 88.84/100.0 = 88.8% done in 2505.4s, 314.7s to go
# on time step 88846 (time=88.846), 0.0268673 s/step
# Meep progress: 88.988/100.0 = 89.0% done in 2509.4s, 310.5s to go
# on time step 88994 (time=88.994), 0.02706 s/step
# Meep progress: 89.139/100.0 = 89.1% done in 2513.5s, 306.2s to go
# on time step 89145 (time=89.145), 0.0265066 s/step
# Meep progress: 89.289/100.0 = 89.3% done in 2517.5s, 302.0s to go
# on time step 89295 (time=89.295), 0.0268377 s/step
# Meep progress: 89.438/100.0 = 89.4% done in 2521.5s, 297.8s to go
# on time step 89444 (time=89.444), 0.0268994 s/step
# Meep progress: 89.58800000000001/100.0 = 89.6% done in 2525.5s, 293.5s to go
# on time step 89595 (time=89.595), 0.0266989 s/step
# Meep progress: 89.727/100.0 = 89.7% done in 2529.5s, 289.6s to go
# on time step 89733 (time=89.733), 0.0291587 s/step
# Meep progress: 89.868/100.0 = 89.9% done in 2533.5s, 285.6s to go
# on time step 89876 (time=89.876), 0.0280913 s/step
# Meep progress: 90.011/100.0 = 90.0% done in 2537.5s, 281.6s to go
# on time step 90018 (time=90.018), 0.0282138 s/step
# Meep progress: 90.15/100.0 = 90.2% done in 2541.5s, 277.7s to go
# on time step 90157 (time=90.157), 0.0289189 s/step
# Meep progress: 90.289/100.0 = 90.3% done in 2545.6s, 273.8s to go
# on time step 90296 (time=90.296), 0.0287988 s/step
# Meep progress: 90.437/100.0 = 90.4% done in 2549.6s, 269.6s to go
# on time step 90444 (time=90.444), 0.0272156 s/step
# Meep progress: 90.584/100.0 = 90.6% done in 2553.6s, 265.4s to go
# on time step 90589 (time=90.589), 0.0276068 s/step
# Meep progress: 90.736/100.0 = 90.7% done in 2557.6s, 261.1s to go
# on time step 90743 (time=90.743), 0.0260345 s/step
# Meep progress: 90.9/100.0 = 90.9% done in 2561.6s, 256.4s to go
# on time step 90907 (time=90.907), 0.0244722 s/step
# Meep progress: 91.056/100.0 = 91.1% done in 2565.7s, 252.0s to go
# on time step 91062 (time=91.062), 0.0258252 s/step
# Meep progress: 91.218/100.0 = 91.2% done in 2569.7s, 247.4s to go
# on time step 91224 (time=91.224), 0.0247728 s/step
# Meep progress: 91.36200000000001/100.0 = 91.4% done in 2573.7s, 243.3s to go
# on time step 91367 (time=91.367), 0.0280332 s/step
# Meep progress: 91.511/100.0 = 91.5% done in 2577.7s, 239.1s to go
# on time step 91516 (time=91.516), 0.0269444 s/step
# Meep progress: 91.653/100.0 = 91.7% done in 2581.7s, 235.1s to go
# on time step 91658 (time=91.658), 0.0282369 s/step
# Meep progress: 91.81/100.0 = 91.8% done in 2585.7s, 230.7s to go
# on time step 91815 (time=91.815), 0.0254936 s/step
# Meep progress: 91.962/100.0 = 92.0% done in 2589.8s, 226.4s to go
# on time step 91967 (time=91.967), 0.0263205 s/step
# Meep progress: 92.123/100.0 = 92.1% done in 2593.8s, 221.8s to go
# on time step 92128 (time=92.128), 0.0249285 s/step
# Meep progress: 92.288/100.0 = 92.3% done in 2597.8s, 217.1s to go
# on time step 92293 (time=92.293), 0.0242524 s/step
# Meep progress: 92.449/100.0 = 92.4% done in 2601.8s, 212.5s to go
# on time step 92454 (time=92.454), 0.0248832 s/step
# Meep progress: 92.61200000000001/100.0 = 92.6% done in 2605.8s, 207.9s to go
# on time step 92617 (time=92.617), 0.0246158 s/step
# Meep progress: 92.78/100.0 = 92.8% done in 2609.8s, 203.1s to go
# on time step 92784 (time=92.784), 0.0239926 s/step
# Meep progress: 92.94500000000001/100.0 = 92.9% done in 2613.8s, 198.4s to go
# on time step 92949 (time=92.949), 0.0242476 s/step
# Meep progress: 93.111/100.0 = 93.1% done in 2617.8s, 193.7s to go
# on time step 93115 (time=93.115), 0.024182 s/step
# Meep progress: 93.266/100.0 = 93.3% done in 2621.9s, 189.3s to go
# on time step 93269 (time=93.269), 0.0260357 s/step
# Meep progress: 93.406/100.0 = 93.4% done in 2625.9s, 185.4s to go
# on time step 93409 (time=93.409), 0.0287627 s/step
# Meep progress: 93.546/100.0 = 93.5% done in 2629.9s, 181.4s to go
# on time step 93549 (time=93.549), 0.0286503 s/step
# Meep progress: 93.684/100.0 = 93.7% done in 2633.9s, 177.6s to go
# on time step 93687 (time=93.687), 0.0291111 s/step
# Meep progress: 93.828/100.0 = 93.8% done in 2637.9s, 173.5s to go
# on time step 93831 (time=93.831), 0.0279015 s/step
# Meep progress: 93.977/100.0 = 94.0% done in 2642.0s, 169.3s to go
# on time step 93980 (time=93.98), 0.02687 s/step
# Meep progress: 94.126/100.0 = 94.1% done in 2646.0s, 165.1s to go
# on time step 94128 (time=94.128), 0.0270887 s/step
# Meep progress: 94.264/100.0 = 94.3% done in 2650.0s, 161.3s to go
# on time step 94266 (time=94.266), 0.029027 s/step
# Meep progress: 94.408/100.0 = 94.4% done in 2654.0s, 157.2s to go
# on time step 94410 (time=94.41), 0.0278207 s/step
# Meep progress: 94.553/100.0 = 94.6% done in 2658.0s, 153.1s to go
# on time step 94555 (time=94.555), 0.0276785 s/step
# Meep progress: 94.7/100.0 = 94.7% done in 2662.0s, 149.0s to go
# on time step 94702 (time=94.702), 0.0273861 s/step
# Meep progress: 94.845/100.0 = 94.8% done in 2666.0s, 144.9s to go
# on time step 94847 (time=94.847), 0.0276756 s/step
# Meep progress: 94.992/100.0 = 95.0% done in 2670.0s, 140.8s to go
# on time step 94995 (time=94.995), 0.0272014 s/step
# Meep progress: 95.138/100.0 = 95.1% done in 2674.1s, 136.7s to go
# on time step 95141 (time=95.141), 0.027439 s/step
# Meep progress: 95.28/100.0 = 95.3% done in 2678.1s, 132.7s to go
# on time step 95283 (time=95.283), 0.0283175 s/step
# Meep progress: 95.427/100.0 = 95.4% done in 2682.1s, 128.5s to go
# on time step 95429 (time=95.429), 0.0274517 s/step
# Meep progress: 95.571/100.0 = 95.6% done in 2686.1s, 124.5s to go
# on time step 95574 (time=95.574), 0.0277675 s/step
# Meep progress: 95.72/100.0 = 95.7% done in 2690.1s, 120.3s to go
# on time step 95723 (time=95.723), 0.0268588 s/step
# Meep progress: 95.87/100.0 = 95.9% done in 2694.1s, 116.1s to go
# on time step 95873 (time=95.873), 0.0266891 s/step
# Meep progress: 96.015/100.0 = 96.0% done in 2698.1s, 112.0s to go
# on time step 96018 (time=96.018), 0.027691 s/step
# Meep progress: 96.167/100.0 = 96.2% done in 2702.2s, 107.7s to go
# on time step 96171 (time=96.171), 0.0262573 s/step
# Meep progress: 96.35600000000001/100.0 = 96.4% done in 2706.2s, 102.3s to go
# on time step 96360 (time=96.36), 0.0212658 s/step
# Meep progress: 96.547/100.0 = 96.5% done in 2710.2s, 96.9s to go
# on time step 96552 (time=96.552), 0.0209146 s/step
# Meep progress: 96.738/100.0 = 96.7% done in 2714.2s, 91.5s to go
# on time step 96743 (time=96.743), 0.0210175 s/step
# Meep progress: 96.932/100.0 = 96.9% done in 2718.2s, 86.0s to go
# on time step 96937 (time=96.937), 0.020684 s/step
# Meep progress: 97.125/100.0 = 97.1% done in 2722.2s, 80.6s to go
# on time step 97130 (time=97.13), 0.0207274 s/step
# Meep progress: 97.319/100.0 = 97.3% done in 2726.2s, 75.1s to go
# on time step 97324 (time=97.324), 0.0207037 s/step
# Meep progress: 97.51/100.0 = 97.5% done in 2730.2s, 69.7s to go
# on time step 97515 (time=97.515), 0.0209869 s/step
# Meep progress: 97.699/100.0 = 97.7% done in 2734.2s, 64.4s to go
# on time step 97704 (time=97.704), 0.0211691 s/step
# Meep progress: 97.892/100.0 = 97.9% done in 2738.2s, 59.0s to go
# on time step 97898 (time=97.898), 0.0207372 s/step
# Meep progress: 98.08500000000001/100.0 = 98.1% done in 2742.2s, 53.5s to go
# on time step 98091 (time=98.091), 0.0208194 s/step
# Meep progress: 98.279/100.0 = 98.3% done in 2746.3s, 48.1s to go
# on time step 98284 (time=98.284), 0.0207334 s/step
# Meep progress: 98.473/100.0 = 98.5% done in 2750.3s, 42.6s to go
# on time step 98478 (time=98.478), 0.0206646 s/step
# Meep progress: 98.666/100.0 = 98.7% done in 2754.3s, 37.2s to go
# on time step 98672 (time=98.672), 0.0206924 s/step
# Meep progress: 98.857/100.0 = 98.9% done in 2758.3s, 31.9s to go
# on time step 98862 (time=98.862), 0.0211168 s/step
# Meep progress: 99.05/100.0 = 99.0% done in 2762.3s, 26.5s to go
# on time step 99055 (time=99.055), 0.0207573 s/step
# Meep progress: 99.238/100.0 = 99.2% done in 2766.3s, 21.2s to go
# on time step 99243 (time=99.243), 0.0213215 s/step
# Meep progress: 99.421/100.0 = 99.4% done in 2770.3s, 16.1s to go
# on time step 99425 (time=99.425), 0.0220773 s/step
# Meep progress: 99.581/100.0 = 99.6% done in 2774.3s, 11.7s to go
# on time step 99587 (time=99.587), 0.0247345 s/step
# Meep progress: 99.76/100.0 = 99.8% done in 2778.3s, 6.7s to go
# on time step 99766 (time=99.766), 0.0223838 s/step
# Meep progress: 99.95/100.0 = 100.0% done in 2782.3s, 1.4s to go
# on time step 99956 (time=99.956), 0.0211302 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 100.0 (100000 timesteps)
#      block, center = (-7.26,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.77556e-17,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.6,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.8,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
# 取得 Ez 場量在指定位置的振福資訊
amplitude_data = sim.get_array(component=mp.Ez)

# 計算觀測點的相對座標
x_obs = -0.5 * sx + dpml + dsub + gh + 0.01 ##
y_obs_start = -0.5 * sy + gp/2

# 儲存振福資訊的列表
amplitude_list = []

# 遍歷每個觀測點
for j in range(num_cells):
    y_obs = y_obs_start + (j * gp) -0.002
    # 計算觀測點在陣列中的索引位置
    x_index = int(round((x_obs) * sim.resolution))
    y_index = int(round((y_obs) * sim.resolution))
    # 取得振福資訊
    amplitude = np.abs(amplitude_data[x_index, y_index])
    amplitude_list.append(amplitude)
    
    y_obs = y_obs_start + (j * gp)
    # 計算觀測點在陣列中的索引位置
    x_index = int(round((x_obs) * sim.resolution))
    y_index = int(round((y_obs) * sim.resolution))
    # 取得振福資訊
    amplitude = np.abs(amplitude_data[x_index, y_index])
    amplitude_list.append(amplitude)
    
    y_obs = y_obs_start + (j * gp) + 0.002
    # 計算觀測點在陣列中的索引位置
    x_index = int(round((x_obs) * sim.resolution))
    y_index = int(round((y_obs) * sim.resolution))
    # 取得振福資訊
    amplitude = np.abs(amplitude_data[x_index, y_index])
    amplitude_list.append(amplitude)
    
    
   
# 印出觀測點的振福資訊
'''
for j, amplitude in enumerate(amplitude_list):
    print(f"觀測點 {j+1} 的振福資訊: {amplitude/np.max(amplitude_list)}")'''

print(amplitude_list)
# Out:
# [0.4472314882265007, 0.4473138906453859, 0.447130814514293, 0.5400694784768769, 0.5400694784768769, 0.5522381322974284, 0.5665838624153339, 0.5545848681899382, 0.5424005539588606]

# %%
# 取得 Ez 場量在指定位置的相位資訊
phase_data = np.fft.fft(np.array(sim.get_array(component = mp.Ez , cmplx = True)))

# 計算觀測點的相對座標
x_obs = -0.5 * sx + dpml + dsub + gh +0.01
y_obs_start = -0.5 * sy + gp/2 

# 儲存相位資訊的列表
phase_list = []

# 遍歷每個觀測點
for j in range(num_cells):
    y_obs = y_obs_start + (j * gp)
    # 計算觀測點在陣列中的索引位置
    x_index = int(round((x_obs) * sim.resolution))
    y_index = int(round((y_obs) * sim.resolution))
    # 取得相位資訊
    phase = np.angle(phase_data[x_index, y_index])
    phase_list.append(phase)

# 印出觀測點的相位資訊
'''
for j, phase in enumerate(phase_list):
    print(f"觀測點 {j+1} 的相位資訊: {phase}")'''
print(phase_list)
# Out:
# [-2.618575103030427, 0.0, 2.6185751030304285]

# %%
sim.reset_meep()
f = plt.figure(dpi = 125)
Animate = mp.Animate2D(fields=mp.Ez, f=f, realtime=False, normalize=True)
plt.close()

sim.run(mp.at_every(1, Animate), until = 70)
plt.close()

filename = "2 alpha beta beta structure.mp4"
Animate.to_mp4(10, filename)

from IPython.display import Video

Video(filename)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.2016e-05 s
# Working in 2D dimensions.
# Computational cell is 17.1 x 0.6 x 0 with resolution 50
#      block, center = (-7.26,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.77556e-17,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
# time for set_epsilon = 0.0245979 s
# -----------
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# Meep: using complex fields.
#      block, center = (-7.26,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.77556e-17,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
# Normalizing field data...
# run 1 finished at t = 70.0 (7000 timesteps)
# Generating MP4...
# <video src="2 alpha beta beta structure.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
