# %% [markdown]
# Here, we want to how level that the electric near field just above cell affected by adjacent cells. In this simulation, we simulated the structure which we called "Beta_Alpha_Beta structure".

# %%
import meep as mp
import numpy as np
import math
import matplotlib.pyplot as plt

#sim.reset_meep()
resolution = 500  # pixels/μm

dpml = 1.0  # PML thickness
dsub = 0.5  # substrate thickness
dcaa = 0.06  # air rigion for alpha structure
# alpha structure is that one period = 200nm，sigle cell width = 80nm locate at center
dcab = 0.025 # air rigion for beta structure 
# beta structure is that one period = 200nm，sigle cell width = 150nm locate at center
gp = 0.2  # grating periodicity
gh = 0.6  # grating height
gwa = 0.08 # alpha grating cell width
gwb = 0.15 # beta grating cell width

num_cells = 3 # number of grating unit cells

# air region thickness adjacent to grating
dair = 1 

wvl = 0.532  # center wavelength
fcen = 1 / wvl  # center frequency

glass = mp.Medium(index= 2.6678)

pml_layers = [mp.PML(thickness=dpml, direction = mp.X )]

symmetries = [mp.Mirror(mp.Y)]

sx = dpml + dsub + gh + dair + dpml
sy = num_cells*gp
#sy = ((dcaa + gwa + dcaa)*2 + (dcab + gwb + dcab))*num_cells
cell_size = mp.Vector3(sx, sy)

sources = [
    mp.Source(
        mp.ContinuousSource(frequency = fcen), # frequemcy = 2原因是 meep 的 C=1，所以 1/? = 0.5 um，?即是2
        component = mp.Ez,
        center = mp.Vector3(-0.5 * sx + dpml ),
        size = mp.Vector3(y = sy),
    )
]

geometry = [
    mp.Block(
        material=glass,
        size=mp.Vector3(dsub, mp.inf, mp.inf),
        center=mp.Vector3(-0.5 * sx + dpml + 0.04 + dsub/2),
    )
]

# %%
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp/2 + (j * 3 * gp),
                #-0.5 * sy + gp/2,
            ),
        )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwa, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + gp + gp/2,
            ),
        )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + 2*gp + gp/2  + (j * 3 * gp),
                #0.5 * sy - gp/2,
            ),
        )
    )

# %%
k_point = mp.Vector3()  # Gamma 點表示週期邊界條件
k_points = [k_point]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
    symmetries=symmetries,
    k_point = mp.Vector3(),
)


# %matplotlib inline
plt.figure(dpi = 125)
sim.plot2D()
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (-0.76,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
t_xx = (.532) # Air 光速跑完 波長 532 nm 入射光 所需的 meep unit time
dt = (t_xx / 40) # cut 40 sections in a period time
t = 1000 # Total simulation time

x_obs = -0.5 * sx + dpml + dsub + gh + 0.002 # Set up a x coordinate of observed point
# The meaning of down , cen , up are the cordinate in each cell structure. (Reference stucture diagram just show above)
y_obs_down = -0.5 * sy + gp/2
y_obs_cen = -0.5 * sy + 3*gp/2
y_obs_up = 0.5 * sy - gp/2

print(int((t_xx)/dt))
# Out:
# 40

# %%
### ez_data_list = [[] for _ in range(int((t_xx)/dt))]

# 儲存場量數值的列表，定義為擁有 10 列的空二維陣列
ez_data_cen = []
ez_data_up = []
ez_data_down = []
###
def get_slice(sim):
    ez_data_cen.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_cen) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_up.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_up) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_down.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_down) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))

sim.run(mp.at_every(dt , get_slice) , until = t)

plt.figure(dpi = 100)
sim.plot2D(fields=mp.Ez)
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000994921 s
# Working in 2D dimensions.
# Computational cell is 4.1 x 0.6 x 0 with resolution 500
#      block, center = (-0.76,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
# time for set_epsilon = 0.31975 s
# -----------
# Meep progress: 1.899/1000.0 = 0.2% done in 4.0s, 2102.7s to go
# on time step 1899 (time=1.899), 0.00210674 s/step
# Meep progress: 4.005/1000.0 = 0.4% done in 8.0s, 1990.0s to go
# on time step 4005 (time=4.005), 0.00189954 s/step
# Meep progress: 5.9/1000.0 = 0.6% done in 12.0s, 2022.6s to go
# on time step 5900 (time=5.9), 0.00211176 s/step
# Meep progress: 7.8580000000000005/1000.0 = 0.8% done in 16.0s, 2020.8s to go
# on time step 7858 (time=7.858), 0.0020432 s/step
# Meep progress: 9.444/1000.0 = 0.9% done in 20.0s, 2098.6s to go
# on time step 9444 (time=9.444), 0.00252325 s/step
# Meep progress: 10.624/1000.0 = 1.1% done in 24.0s, 2235.9s to go
# on time step 10624 (time=10.624), 0.0033903 s/step
# Meep progress: 12.059000000000001/1000.0 = 1.2% done in 28.0s, 2294.9s to go
# on time step 12059 (time=12.059), 0.00278884 s/step
# Meep progress: 13.561/1000.0 = 1.4% done in 32.0s, 2328.6s to go
# on time step 13562 (time=13.562), 0.00266285 s/step
# Meep progress: 15.025/1000.0 = 1.5% done in 36.0s, 2360.9s to go
# on time step 15026 (time=15.026), 0.00273322 s/step
# Meep progress: 16.531/1000.0 = 1.7% done in 40.0s, 2380.6s to go
# on time step 16532 (time=16.532), 0.00265606 s/step
# Meep progress: 18.038/1000.0 = 1.8% done in 44.0s, 2396.2s to go
# on time step 18039 (time=18.039), 0.00265438 s/step
# Meep progress: 19.554000000000002/1000.0 = 2.0% done in 48.0s, 2407.7s to go
# on time step 19555 (time=19.555), 0.00263976 s/step
# Meep progress: 21.058/1000.0 = 2.1% done in 52.0s, 2418.3s to go
# on time step 21060 (time=21.06), 0.0026594 s/step
# Meep progress: 22.542/1000.0 = 2.3% done in 56.0s, 2429.2s to go
# on time step 22544 (time=22.544), 0.00269617 s/step
# Meep progress: 24.035/1000.0 = 2.4% done in 60.0s, 2437.3s to go
# on time step 24038 (time=24.038), 0.00267886 s/step
# Meep progress: 25.557000000000002/1000.0 = 2.6% done in 64.0s, 2441.1s to go
# on time step 25560 (time=25.56), 0.00262948 s/step
# Meep progress: 27.031/1000.0 = 2.7% done in 68.0s, 2448.5s to go
# on time step 27035 (time=27.035), 0.00271327 s/step
# Meep progress: 28.531000000000002/1000.0 = 2.9% done in 72.0s, 2452.4s to go
# on time step 28535 (time=28.535), 0.00266675 s/step
# Meep progress: 30.028000000000002/1000.0 = 3.0% done in 76.0s, 2455.8s to go
# on time step 30032 (time=30.032), 0.00267222 s/step
# Meep progress: 31.529/1000.0 = 3.2% done in 80.0s, 2458.2s to go
# on time step 31534 (time=31.534), 0.00266431 s/step
# Meep progress: 33.034/1000.0 = 3.3% done in 84.0s, 2459.7s to go
# on time step 33039 (time=33.039), 0.00265803 s/step
# Meep progress: 34.523/1000.0 = 3.5% done in 88.0s, 2461.8s to go
# on time step 34528 (time=34.528), 0.00268659 s/step
# Meep progress: 36.045/1000.0 = 3.6% done in 92.0s, 2461.2s to go
# on time step 36050 (time=36.05), 0.00262909 s/step
# Meep progress: 37.54/1000.0 = 3.8% done in 96.0s, 2462.1s to go
# on time step 37544 (time=37.544), 0.00267741 s/step
# Meep progress: 39.043/1000.0 = 3.9% done in 100.0s, 2462.1s to go
# on time step 39048 (time=39.048), 0.0026603 s/step
# Meep progress: 40.554/1000.0 = 4.1% done in 104.0s, 2461.3s to go
# on time step 40559 (time=40.559), 0.00264766 s/step
# Meep progress: 42.050000000000004/1000.0 = 4.2% done in 108.0s, 2461.2s to go
# on time step 42054 (time=42.054), 0.00267579 s/step
# Meep progress: 43.549/1000.0 = 4.4% done in 112.0s, 2460.7s to go
# on time step 43554 (time=43.554), 0.00266711 s/step
# Meep progress: 45.071/1000.0 = 4.5% done in 116.0s, 2458.5s to go
# on time step 45077 (time=45.077), 0.00262777 s/step
# Meep progress: 46.58/1000.0 = 4.7% done in 120.0s, 2457.0s to go
# on time step 46585 (time=46.585), 0.00265319 s/step
# Meep progress: 47.875/1000.0 = 4.8% done in 124.0s, 2466.9s to go
# on time step 47881 (time=47.881), 0.00308857 s/step
# Meep progress: 49.268/1000.0 = 4.9% done in 128.0s, 2470.9s to go
# on time step 49274 (time=49.274), 0.00287183 s/step
# Meep progress: 50.705/1000.0 = 5.1% done in 132.0s, 2472.1s to go
# on time step 50712 (time=50.712), 0.00278312 s/step
# Meep progress: 52.143/1000.0 = 5.2% done in 136.0s, 2473.1s to go
# on time step 52150 (time=52.15), 0.00278302 s/step
# Meep progress: 53.589/1000.0 = 5.4% done in 140.0s, 2473.3s to go
# on time step 53596 (time=53.596), 0.00276649 s/step
# Meep progress: 55.054/1000.0 = 5.5% done in 144.0s, 2472.5s to go
# on time step 55062 (time=55.062), 0.00273031 s/step
# Meep progress: 56.523/1000.0 = 5.7% done in 148.1s, 2471.3s to go
# on time step 56531 (time=56.531), 0.0027236 s/step
# Meep progress: 58.018/1000.0 = 5.8% done in 152.1s, 2468.7s to go
# on time step 58026 (time=58.026), 0.00267658 s/step
# Meep progress: 59.316/1000.0 = 5.9% done in 156.1s, 2474.9s to go
# on time step 59319 (time=59.319), 0.00309565 s/step
# Meep progress: 60.508/1000.0 = 6.1% done in 160.1s, 2485.2s to go
# on time step 60512 (time=60.512), 0.00335289 s/step
# Meep progress: 61.451/1000.0 = 6.1% done in 164.1s, 2505.8s to go
# on time step 61454 (time=61.454), 0.00424645 s/step
# Meep progress: 62.89/1000.0 = 6.3% done in 168.1s, 2504.3s to go
# on time step 62897 (time=62.897), 0.00277404 s/step
# Meep progress: 64.415/1000.0 = 6.4% done in 172.1s, 2499.2s to go
# on time step 64423 (time=64.423), 0.00262179 s/step
# Meep progress: 65.935/1000.0 = 6.6% done in 176.1s, 2494.3s to go
# on time step 65942 (time=65.942), 0.0026336 s/step
# Meep progress: 67.46300000000001/1000.0 = 6.7% done in 180.1s, 2489.1s to go
# on time step 67470 (time=67.47), 0.00261832 s/step
# Meep progress: 68.99/1000.0 = 6.9% done in 184.1s, 2484.0s to go
# on time step 68996 (time=68.996), 0.00262166 s/step
# Meep progress: 70.498/1000.0 = 7.0% done in 188.1s, 2479.7s to go
# on time step 70506 (time=70.506), 0.00265015 s/step
# Meep progress: 72.017/1000.0 = 7.2% done in 192.1s, 2475.0s to go
# on time step 72024 (time=72.024), 0.00263566 s/step
# Meep progress: 73.535/1000.0 = 7.4% done in 196.1s, 2470.3s to go
# on time step 73544 (time=73.544), 0.00263356 s/step
# Meep progress: 75.062/1000.0 = 7.5% done in 200.1s, 2465.4s to go
# on time step 75072 (time=75.072), 0.00261944 s/step
# Meep progress: 76.589/1000.0 = 7.7% done in 204.1s, 2460.5s to go
# on time step 76599 (time=76.599), 0.00262077 s/step
# Meep progress: 78.106/1000.0 = 7.8% done in 208.1s, 2456.0s to go
# on time step 78117 (time=78.117), 0.00263551 s/step
# Meep progress: 79.63/1000.0 = 8.0% done in 212.1s, 2451.2s to go
# on time step 79642 (time=79.642), 0.00262443 s/step
# Meep progress: 81.152/1000.0 = 8.1% done in 216.1s, 2446.6s to go
# on time step 81164 (time=81.164), 0.00263013 s/step
# Meep progress: 82.679/1000.0 = 8.3% done in 220.1s, 2441.8s to go
# on time step 82691 (time=82.691), 0.00262001 s/step
# Meep progress: 84.185/1000.0 = 8.4% done in 224.1s, 2437.7s to go
# on time step 84197 (time=84.197), 0.00265624 s/step
# Meep progress: 85.727/1000.0 = 8.6% done in 228.1s, 2432.5s to go
# on time step 85740 (time=85.74), 0.00259384 s/step
# Meep progress: 87.248/1000.0 = 8.7% done in 232.1s, 2428.0s to go
# on time step 87261 (time=87.261), 0.00263036 s/step
# Meep progress: 88.775/1000.0 = 8.9% done in 236.1s, 2423.3s to go
# on time step 88789 (time=88.789), 0.00261946 s/step
# Meep progress: 90.302/1000.0 = 9.0% done in 240.1s, 2418.6s to go
# on time step 90316 (time=90.316), 0.00261957 s/step
# Meep progress: 91.81/1000.0 = 9.2% done in 244.1s, 2414.5s to go
# on time step 91825 (time=91.825), 0.00265082 s/step
# Meep progress: 93.327/1000.0 = 9.3% done in 248.1s, 2410.2s to go
# on time step 93341 (time=93.341), 0.00263976 s/step
# Meep progress: 94.857/1000.0 = 9.5% done in 252.1s, 2405.5s to go
# on time step 94872 (time=94.872), 0.00261308 s/step
# Meep progress: 96.39/1000.0 = 9.6% done in 256.1s, 2400.7s to go
# on time step 96404 (time=96.404), 0.00261159 s/step
# Meep progress: 97.914/1000.0 = 9.8% done in 260.1s, 2396.3s to go
# on time step 97929 (time=97.929), 0.00262473 s/step
# Meep progress: 99.435/1000.0 = 9.9% done in 264.1s, 2391.9s to go
# on time step 99451 (time=99.451), 0.00262865 s/step
# Meep progress: 100.934/1000.0 = 10.1% done in 268.1s, 2388.1s to go
# on time step 100951 (time=100.951), 0.00266734 s/step
# Meep progress: 102.444/1000.0 = 10.2% done in 272.1s, 2384.0s to go
# on time step 102461 (time=102.461), 0.00265039 s/step
# Meep progress: 103.964/1000.0 = 10.4% done in 276.1s, 2379.6s to go
# on time step 103981 (time=103.981), 0.00263269 s/step
# Meep progress: 105.467/1000.0 = 10.5% done in 280.1s, 2375.7s to go
# on time step 105484 (time=105.484), 0.00266218 s/step
# Meep progress: 106.983/1000.0 = 10.7% done in 284.1s, 2371.5s to go
# on time step 107002 (time=107.002), 0.00263631 s/step
# Meep progress: 108.507/1000.0 = 10.9% done in 288.1s, 2367.0s to go
# on time step 108525 (time=108.525), 0.00262748 s/step
# Meep progress: 110.015/1000.0 = 11.0% done in 292.1s, 2363.0s to go
# on time step 110034 (time=110.034), 0.00265368 s/step
# Meep progress: 111.531/1000.0 = 11.2% done in 296.1s, 2358.8s to go
# on time step 111552 (time=111.552), 0.00263638 s/step
# Meep progress: 113.04/1000.0 = 11.3% done in 300.1s, 2354.8s to go
# on time step 113060 (time=113.06), 0.00265341 s/step
# Meep progress: 114.547/1000.0 = 11.5% done in 304.1s, 2350.8s to go
# on time step 114570 (time=114.57), 0.00265044 s/step
# Meep progress: 116.058/1000.0 = 11.6% done in 308.1s, 2346.7s to go
# on time step 116081 (time=116.081), 0.00264869 s/step
# Meep progress: 117.57900000000001/1000.0 = 11.8% done in 312.1s, 2342.4s to go
# on time step 117602 (time=117.602), 0.00263004 s/step
# Meep progress: 119.09100000000001/1000.0 = 11.9% done in 316.1s, 2338.2s to go
# on time step 119114 (time=119.114), 0.00264657 s/step
# Meep progress: 120.61200000000001/1000.0 = 12.1% done in 320.1s, 2333.9s to go
# on time step 120634 (time=120.634), 0.00263219 s/step
# Meep progress: 122.122/1000.0 = 12.2% done in 324.1s, 2329.9s to go
# on time step 122144 (time=122.144), 0.00264902 s/step
# Meep progress: 123.644/1000.0 = 12.4% done in 328.1s, 2325.6s to go
# on time step 123668 (time=123.668), 0.00262673 s/step
# Meep progress: 125.155/1000.0 = 12.5% done in 332.1s, 2321.5s to go
# on time step 125177 (time=125.177), 0.00265196 s/step
# Meep progress: 126.671/1000.0 = 12.7% done in 336.1s, 2317.4s to go
# on time step 126695 (time=126.695), 0.00263515 s/step
# Meep progress: 128.183/1000.0 = 12.8% done in 340.1s, 2313.3s to go
# on time step 128206 (time=128.206), 0.00264903 s/step
# Meep progress: 129.711/1000.0 = 13.0% done in 344.1s, 2308.9s to go
# on time step 129734 (time=129.734), 0.00261818 s/step
# Meep progress: 131.237/1000.0 = 13.1% done in 348.1s, 2304.5s to go
# on time step 131261 (time=131.261), 0.00262095 s/step
# Meep progress: 132.758/1000.0 = 13.3% done in 352.1s, 2300.3s to go
# on time step 132784 (time=132.784), 0.00262766 s/step
# Meep progress: 134.26500000000001/1000.0 = 13.4% done in 356.1s, 2296.3s to go
# on time step 134290 (time=134.29), 0.00265845 s/step
# Meep progress: 135.781/1000.0 = 13.6% done in 360.1s, 2292.1s to go
# on time step 135808 (time=135.808), 0.00263641 s/step
# Meep progress: 137.312/1000.0 = 13.7% done in 364.1s, 2287.7s to go
# on time step 137339 (time=137.339), 0.00261412 s/step
# Meep progress: 138.826/1000.0 = 13.9% done in 368.1s, 2283.6s to go
# on time step 138854 (time=138.854), 0.00264196 s/step
# Meep progress: 140.281/1000.0 = 14.0% done in 372.1s, 2280.6s to go
# on time step 140307 (time=140.307), 0.00275305 s/step
# Meep progress: 141.79/1000.0 = 14.2% done in 376.1s, 2276.6s to go
# on time step 141819 (time=141.819), 0.00264675 s/step
# Meep progress: 143.309/1000.0 = 14.3% done in 380.1s, 2272.4s to go
# on time step 143338 (time=143.338), 0.00263494 s/step
# Meep progress: 144.82/1000.0 = 14.5% done in 384.1s, 2268.4s to go
# on time step 144850 (time=144.85), 0.00264721 s/step
# Meep progress: 146.121/1000.0 = 14.6% done in 388.1s, 2268.1s to go
# on time step 146150 (time=146.15), 0.00307695 s/step
# Meep progress: 147.496/1000.0 = 14.7% done in 392.1s, 2266.5s to go
# on time step 147523 (time=147.523), 0.00291435 s/step
# Meep progress: 148.994/1000.0 = 14.9% done in 396.1s, 2262.6s to go
# on time step 149025 (time=149.025), 0.00266414 s/step
# Meep progress: 150.50300000000001/1000.0 = 15.1% done in 400.1s, 2258.5s to go
# on time step 150536 (time=150.536), 0.00264791 s/step
# Meep progress: 152.029/1000.0 = 15.2% done in 404.1s, 2254.2s to go
# on time step 152061 (time=152.061), 0.00262431 s/step
# Meep progress: 153.54500000000002/1000.0 = 15.4% done in 408.1s, 2250.0s to go
# on time step 153580 (time=153.58), 0.00263505 s/step
# Meep progress: 155.071/1000.0 = 15.5% done in 412.1s, 2245.6s to go
# on time step 155105 (time=155.105), 0.00262297 s/step
# Meep progress: 156.579/1000.0 = 15.7% done in 416.1s, 2241.6s to go
# on time step 156613 (time=156.613), 0.00265258 s/step
# Meep progress: 158.097/1000.0 = 15.8% done in 420.1s, 2237.4s to go
# on time step 158130 (time=158.13), 0.00263807 s/step
# Meep progress: 159.617/1000.0 = 16.0% done in 424.1s, 2233.1s to go
# on time step 159653 (time=159.653), 0.00262798 s/step
# Meep progress: 161.145/1000.0 = 16.1% done in 428.1s, 2228.7s to go
# on time step 161181 (time=161.181), 0.0026184 s/step
# Meep progress: 162.671/1000.0 = 16.3% done in 432.1s, 2224.4s to go
# on time step 162708 (time=162.708), 0.00262091 s/step
# Meep progress: 164.16400000000002/1000.0 = 16.4% done in 436.1s, 2220.6s to go
# on time step 164200 (time=164.2), 0.00268147 s/step
# Meep progress: 165.672/1000.0 = 16.6% done in 440.1s, 2216.6s to go
# on time step 165709 (time=165.709), 0.00265135 s/step
# Meep progress: 167.29/1000.0 = 16.7% done in 444.2s, 2210.8s to go
# on time step 167330 (time=167.33), 0.00246767 s/step
# Meep progress: 168.992/1000.0 = 16.9% done in 448.2s, 2203.8s to go
# on time step 169033 (time=169.033), 0.00234988 s/step
# Meep progress: 170.687/1000.0 = 17.1% done in 452.2s, 2196.9s to go
# on time step 170726 (time=170.726), 0.0023639 s/step
# Meep progress: 172.404/1000.0 = 17.2% done in 456.2s, 2189.7s to go
# on time step 172446 (time=172.446), 0.00232655 s/step
# Meep progress: 174.149/1000.0 = 17.4% done in 460.2s, 2182.2s to go
# on time step 174193 (time=174.193), 0.00228965 s/step
# Meep progress: 175.872/1000.0 = 17.6% done in 464.2s, 2175.0s to go
# on time step 175913 (time=175.913), 0.00232572 s/step
# Meep progress: 177.614/1000.0 = 17.8% done in 468.2s, 2167.7s to go
# on time step 177657 (time=177.657), 0.00229377 s/step
# Meep progress: 179.353/1000.0 = 17.9% done in 472.2s, 2160.4s to go
# on time step 179398 (time=179.398), 0.00229865 s/step
# Meep progress: 181.106/1000.0 = 18.1% done in 476.2s, 2153.0s to go
# on time step 181148 (time=181.148), 0.0022875 s/step
# Meep progress: 182.889/1000.0 = 18.3% done in 480.2s, 2145.3s to go
# on time step 182935 (time=182.935), 0.00223947 s/step
# Meep progress: 184.67000000000002/1000.0 = 18.5% done in 484.2s, 2137.6s to go
# on time step 184717 (time=184.717), 0.00224493 s/step
# Meep progress: 186.361/1000.0 = 18.6% done in 488.2s, 2131.3s to go
# on time step 186400 (time=186.4), 0.00237831 s/step
# Meep progress: 187.91/1000.0 = 18.8% done in 492.2s, 2127.0s to go
# on time step 187950 (time=187.95), 0.00258122 s/step
# Meep progress: 189.464/1000.0 = 18.9% done in 496.2s, 2122.6s to go
# on time step 189507 (time=189.507), 0.0025696 s/step
# Meep progress: 191.0/1000.0 = 19.1% done in 500.2s, 2118.5s to go
# on time step 191040 (time=191.04), 0.00260938 s/step
# Meep progress: 192.537/1000.0 = 19.3% done in 504.2s, 2114.4s to go
# on time step 192577 (time=192.577), 0.0026042 s/step
# Meep progress: 194.079/1000.0 = 19.4% done in 508.2s, 2110.2s to go
# on time step 194121 (time=194.121), 0.00259118 s/step
# Meep progress: 195.63/1000.0 = 19.6% done in 512.2s, 2105.9s to go
# on time step 195673 (time=195.673), 0.00257744 s/step
# Meep progress: 197.175/1000.0 = 19.7% done in 516.2s, 2101.7s to go
# on time step 197220 (time=197.22), 0.00258716 s/step
# Meep progress: 198.708/1000.0 = 19.9% done in 520.2s, 2097.6s to go
# on time step 198753 (time=198.753), 0.00261011 s/step
# Meep progress: 200.26/1000.0 = 20.0% done in 524.2s, 2093.3s to go
# on time step 200303 (time=200.303), 0.00258195 s/step
# Meep progress: 201.805/1000.0 = 20.2% done in 528.2s, 2089.1s to go
# on time step 201850 (time=201.85), 0.00258588 s/step
# Meep progress: 203.357/1000.0 = 20.3% done in 532.2s, 2084.8s to go
# on time step 203404 (time=203.404), 0.00257546 s/step
# Meep progress: 204.919/1000.0 = 20.5% done in 536.2s, 2080.4s to go
# on time step 204965 (time=204.965), 0.00256383 s/step
# Meep progress: 206.46/1000.0 = 20.6% done in 540.2s, 2076.2s to go
# on time step 206507 (time=206.507), 0.00259475 s/step
# Meep progress: 207.998/1000.0 = 20.8% done in 544.2s, 2072.1s to go
# on time step 208046 (time=208.046), 0.00260041 s/step
# Meep progress: 209.542/1000.0 = 21.0% done in 548.2s, 2067.9s to go
# on time step 209588 (time=209.588), 0.00259413 s/step
# Meep progress: 211.085/1000.0 = 21.1% done in 552.2s, 2063.7s to go
# on time step 211131 (time=211.131), 0.00259279 s/step
# Meep progress: 212.636/1000.0 = 21.3% done in 556.2s, 2059.5s to go
# on time step 212685 (time=212.685), 0.00257407 s/step
# Meep progress: 214.18800000000002/1000.0 = 21.4% done in 560.2s, 2055.2s to go
# on time step 214234 (time=214.234), 0.00258264 s/step
# Meep progress: 215.72400000000002/1000.0 = 21.6% done in 564.2s, 2051.1s to go
# on time step 215771 (time=215.771), 0.00260336 s/step
# Meep progress: 217.27/1000.0 = 21.7% done in 568.2s, 2046.9s to go
# on time step 217318 (time=217.318), 0.00258594 s/step
# Meep progress: 218.80700000000002/1000.0 = 21.9% done in 572.2s, 2042.9s to go
# on time step 218855 (time=218.855), 0.00260406 s/step
# Meep progress: 220.35500000000002/1000.0 = 22.0% done in 576.2s, 2038.6s to go
# on time step 220404 (time=220.404), 0.00258244 s/step
# Meep progress: 221.907/1000.0 = 22.2% done in 580.2s, 2034.4s to go
# on time step 221955 (time=221.955), 0.00258023 s/step
# Meep progress: 223.455/1000.0 = 22.3% done in 584.2s, 2030.2s to go
# on time step 223502 (time=223.502), 0.00258576 s/step
# Meep progress: 225.007/1000.0 = 22.5% done in 588.2s, 2025.9s to go
# on time step 225054 (time=225.054), 0.00257778 s/step
# Meep progress: 226.562/1000.0 = 22.7% done in 592.2s, 2021.6s to go
# on time step 226612 (time=226.612), 0.00256869 s/step
# Meep progress: 228.109/1000.0 = 22.8% done in 596.2s, 2017.5s to go
# on time step 228159 (time=228.159), 0.00258644 s/step
# Meep progress: 229.647/1000.0 = 23.0% done in 600.2s, 2013.4s to go
# on time step 229696 (time=229.696), 0.00260284 s/step
# Meep progress: 231.18800000000002/1000.0 = 23.1% done in 604.2s, 2009.3s to go
# on time step 231239 (time=231.239), 0.00259339 s/step
# Meep progress: 232.74/1000.0 = 23.3% done in 608.2s, 2005.0s to go
# on time step 232789 (time=232.789), 0.00258252 s/step
# Meep progress: 234.284/1000.0 = 23.4% done in 612.2s, 2000.9s to go
# on time step 234336 (time=234.336), 0.00258726 s/step
# Meep progress: 235.836/1000.0 = 23.6% done in 616.2s, 1996.7s to go
# on time step 235888 (time=235.888), 0.00257811 s/step
# Meep progress: 237.38/1000.0 = 23.7% done in 620.2s, 1992.5s to go
# on time step 237432 (time=237.432), 0.00259132 s/step
# Meep progress: 238.929/1000.0 = 23.9% done in 624.2s, 1988.3s to go
# on time step 238979 (time=238.979), 0.00258583 s/step
# Meep progress: 240.46/1000.0 = 24.0% done in 628.2s, 1984.3s to go
# on time step 240511 (time=240.511), 0.0026113 s/step
# Meep progress: 242.02100000000002/1000.0 = 24.2% done in 632.2s, 1980.0s to go
# on time step 242074 (time=242.074), 0.00256045 s/step
# Meep progress: 243.56/1000.0 = 24.4% done in 636.2s, 1975.9s to go
# on time step 243612 (time=243.612), 0.00260135 s/step
# Meep progress: 245.119/1000.0 = 24.5% done in 640.2s, 1971.6s to go
# on time step 245170 (time=245.17), 0.00256746 s/step
# Meep progress: 246.645/1000.0 = 24.7% done in 644.2s, 1967.7s to go
# on time step 246698 (time=246.698), 0.00261905 s/step
# Meep progress: 248.109/1000.0 = 24.8% done in 648.2s, 1964.4s to go
# on time step 248159 (time=248.159), 0.00273834 s/step
# Meep progress: 249.566/1000.0 = 25.0% done in 652.2s, 1961.2s to go
# on time step 249616 (time=249.616), 0.00274683 s/step
# Meep progress: 251.101/1000.0 = 25.1% done in 656.2s, 1957.1s to go
# on time step 251156 (time=251.156), 0.00259752 s/step
# Meep progress: 252.654/1000.0 = 25.3% done in 660.2s, 1952.9s to go
# on time step 252708 (time=252.708), 0.0025777 s/step
# Meep progress: 254.201/1000.0 = 25.4% done in 664.2s, 1948.8s to go
# on time step 254255 (time=254.255), 0.00258715 s/step
# Meep progress: 255.76000000000002/1000.0 = 25.6% done in 668.2s, 1944.5s to go
# on time step 255814 (time=255.814), 0.00256726 s/step
# Meep progress: 257.309/1000.0 = 25.7% done in 672.2s, 1940.3s to go
# on time step 257364 (time=257.364), 0.00258086 s/step
# Meep progress: 258.87/1000.0 = 25.9% done in 676.2s, 1936.0s to go
# on time step 258927 (time=258.927), 0.00255976 s/step
# Meep progress: 260.42/1000.0 = 26.0% done in 680.2s, 1931.8s to go
# on time step 260475 (time=260.475), 0.00258429 s/step
# Meep progress: 261.978/1000.0 = 26.2% done in 684.2s, 1927.6s to go
# on time step 262037 (time=262.037), 0.00256278 s/step
# Meep progress: 263.508/1000.0 = 26.4% done in 688.2s, 1923.6s to go
# on time step 263562 (time=263.562), 0.00262368 s/step
# Meep progress: 264.985/1000.0 = 26.5% done in 692.2s, 1920.1s to go
# on time step 265038 (time=265.038), 0.00271122 s/step
# Meep progress: 266.5/1000.0 = 26.6% done in 696.2s, 1916.3s to go
# on time step 266558 (time=266.558), 0.00263265 s/step
# Meep progress: 268.061/1000.0 = 26.8% done in 700.2s, 1912.0s to go
# on time step 268118 (time=268.118), 0.00256423 s/step
# Meep progress: 269.607/1000.0 = 27.0% done in 704.2s, 1907.9s to go
# on time step 269664 (time=269.664), 0.00258814 s/step
# Meep progress: 271.154/1000.0 = 27.1% done in 708.2s, 1903.7s to go
# on time step 271208 (time=271.208), 0.00259103 s/step
# Meep progress: 272.694/1000.0 = 27.3% done in 712.2s, 1899.6s to go
# on time step 272750 (time=272.75), 0.00259437 s/step
# Meep progress: 274.24/1000.0 = 27.4% done in 716.2s, 1895.5s to go
# on time step 274294 (time=274.294), 0.00259153 s/step
# Meep progress: 275.787/1000.0 = 27.6% done in 720.2s, 1891.4s to go
# on time step 275843 (time=275.843), 0.00258299 s/step
# Meep progress: 277.326/1000.0 = 27.7% done in 724.2s, 1887.3s to go
# on time step 277385 (time=277.385), 0.00259485 s/step
# Meep progress: 278.885/1000.0 = 27.9% done in 728.2s, 1883.0s to go
# on time step 278929 (time=278.929), 0.00259403 s/step
# Meep progress: 280.484/1000.0 = 28.0% done in 732.2s, 1878.4s to go
# on time step 280546 (time=280.546), 0.00247454 s/step
# Meep progress: 282.144/1000.0 = 28.2% done in 736.3s, 1873.2s to go
# on time step 282207 (time=282.207), 0.00240832 s/step
# Meep progress: 283.79/1000.0 = 28.4% done in 740.3s, 1868.2s to go
# on time step 283854 (time=283.854), 0.00242916 s/step
# Meep progress: 285.451/1000.0 = 28.5% done in 744.3s, 1863.0s to go
# on time step 285516 (time=285.516), 0.00240807 s/step
# Meep progress: 287.116/1000.0 = 28.7% done in 748.3s, 1857.8s to go
# on time step 287182 (time=287.182), 0.00240199 s/step
# Meep progress: 288.791/1000.0 = 28.9% done in 752.3s, 1852.6s to go
# on time step 288857 (time=288.857), 0.00238893 s/step
# Meep progress: 290.452/1000.0 = 29.0% done in 756.3s, 1847.5s to go
# on time step 290519 (time=290.519), 0.00240729 s/step
# Meep progress: 292.121/1000.0 = 29.2% done in 760.3s, 1842.3s to go
# on time step 292187 (time=292.187), 0.00239897 s/step
# Meep progress: 293.76300000000003/1000.0 = 29.4% done in 764.3s, 1837.4s to go
# on time step 293827 (time=293.827), 0.00244031 s/step
# Meep progress: 295.419/1000.0 = 29.5% done in 768.3s, 1832.3s to go
# on time step 295484 (time=295.484), 0.00241428 s/step
# Meep progress: 297.081/1000.0 = 29.7% done in 772.3s, 1827.2s to go
# on time step 297148 (time=297.148), 0.00240446 s/step
# Meep progress: 298.754/1000.0 = 29.9% done in 776.3s, 1822.1s to go
# on time step 298818 (time=298.818), 0.00239559 s/step
# Meep progress: 300.419/1000.0 = 30.0% done in 780.3s, 1817.0s to go
# on time step 300488 (time=300.488), 0.00239545 s/step
# Meep progress: 302.085/1000.0 = 30.2% done in 784.3s, 1811.9s to go
# on time step 302153 (time=302.153), 0.00240323 s/step
# Meep progress: 303.747/1000.0 = 30.4% done in 788.3s, 1806.9s to go
# on time step 303814 (time=303.814), 0.00240875 s/step
# Meep progress: 305.41200000000003/1000.0 = 30.5% done in 792.3s, 1801.8s to go
# on time step 305477 (time=305.477), 0.00240656 s/step
# Meep progress: 307.076/1000.0 = 30.7% done in 796.3s, 1796.8s to go
# on time step 307142 (time=307.142), 0.00240309 s/step
# Meep progress: 308.741/1000.0 = 30.9% done in 800.3s, 1791.8s to go
# on time step 308808 (time=308.808), 0.002401 s/step
# Meep progress: 310.399/1000.0 = 31.0% done in 804.3s, 1786.8s to go
# on time step 310466 (time=310.466), 0.00241411 s/step
# Meep progress: 312.055/1000.0 = 31.2% done in 808.3s, 1781.9s to go
# on time step 312124 (time=312.124), 0.00241376 s/step
# Meep progress: 313.733/1000.0 = 31.4% done in 812.3s, 1776.8s to go
# on time step 313803 (time=313.803), 0.00238336 s/step
# Meep progress: 315.395/1000.0 = 31.5% done in 816.3s, 1771.8s to go
# on time step 315464 (time=315.464), 0.00240869 s/step
# Meep progress: 317.026/1000.0 = 31.7% done in 820.3s, 1767.1s to go
# on time step 317094 (time=317.094), 0.00245421 s/step
# Meep progress: 318.699/1000.0 = 31.9% done in 824.3s, 1762.1s to go
# on time step 318767 (time=318.767), 0.00239191 s/step
# Meep progress: 320.366/1000.0 = 32.0% done in 828.3s, 1757.1s to go
# on time step 320436 (time=320.436), 0.00239694 s/step
# Meep progress: 322.017/1000.0 = 32.2% done in 832.3s, 1752.3s to go
# on time step 322086 (time=322.086), 0.00242527 s/step
# Meep progress: 323.673/1000.0 = 32.4% done in 836.3s, 1747.5s to go
# on time step 323740 (time=323.74), 0.00241849 s/step
# Meep progress: 325.336/1000.0 = 32.5% done in 840.3s, 1742.5s to go
# on time step 325407 (time=325.407), 0.00240012 s/step
# Meep progress: 326.999/1000.0 = 32.7% done in 844.3s, 1737.6s to go
# on time step 327071 (time=327.071), 0.00240416 s/step
# Meep progress: 328.664/1000.0 = 32.9% done in 848.3s, 1732.7s to go
# on time step 328734 (time=328.734), 0.00240557 s/step
# Meep progress: 330.323/1000.0 = 33.0% done in 852.3s, 1727.9s to go
# on time step 330392 (time=330.392), 0.00241323 s/step
# Meep progress: 331.978/1000.0 = 33.2% done in 856.3s, 1723.1s to go
# on time step 332048 (time=332.048), 0.00241604 s/step
# Meep progress: 333.642/1000.0 = 33.4% done in 860.3s, 1718.2s to go
# on time step 333713 (time=333.713), 0.00240252 s/step
# Meep progress: 335.308/1000.0 = 33.5% done in 864.3s, 1713.3s to go
# on time step 335379 (time=335.379), 0.00240151 s/step
# Meep progress: 336.964/1000.0 = 33.7% done in 868.3s, 1708.5s to go
# on time step 337038 (time=337.038), 0.00241149 s/step
# Meep progress: 338.628/1000.0 = 33.9% done in 872.3s, 1703.7s to go
# on time step 338698 (time=338.698), 0.00241122 s/step
# Meep progress: 340.28000000000003/1000.0 = 34.0% done in 876.3s, 1698.9s to go
# on time step 340355 (time=340.355), 0.00241416 s/step
# Meep progress: 341.948/1000.0 = 34.2% done in 880.3s, 1694.1s to go
# on time step 342019 (time=342.019), 0.0024043 s/step
# Meep progress: 343.588/1000.0 = 34.4% done in 884.3s, 1689.4s to go
# on time step 343660 (time=343.66), 0.00243839 s/step
# Meep progress: 345.25600000000003/1000.0 = 34.5% done in 888.3s, 1684.6s to go
# on time step 345330 (time=345.33), 0.00239573 s/step
# Meep progress: 346.92400000000004/1000.0 = 34.7% done in 892.3s, 1679.7s to go
# on time step 346997 (time=346.997), 0.00240033 s/step
# Meep progress: 348.581/1000.0 = 34.9% done in 896.3s, 1675.0s to go
# on time step 348655 (time=348.655), 0.00241359 s/step
# Meep progress: 350.233/1000.0 = 35.0% done in 900.3s, 1670.3s to go
# on time step 350309 (time=350.309), 0.00241925 s/step
# Meep progress: 351.913/1000.0 = 35.2% done in 904.3s, 1665.4s to go
# on time step 351989 (time=351.989), 0.00238177 s/step
# Meep progress: 353.575/1000.0 = 35.4% done in 908.3s, 1660.6s to go
# on time step 353652 (time=353.652), 0.00240567 s/step
# Meep progress: 355.199/1000.0 = 35.5% done in 912.3s, 1656.1s to go
# on time step 355277 (time=355.277), 0.00246218 s/step
# Meep progress: 356.89300000000003/1000.0 = 35.7% done in 916.3s, 1651.2s to go
# on time step 356972 (time=356.972), 0.00236045 s/step
# Meep progress: 358.84000000000003/1000.0 = 35.9% done in 920.3s, 1644.4s to go
# on time step 358925 (time=358.925), 0.00204858 s/step
# Meep progress: 360.813/1000.0 = 36.1% done in 924.3s, 1637.4s to go
# on time step 360905 (time=360.905), 0.00202118 s/step
# Meep progress: 362.765/1000.0 = 36.3% done in 928.3s, 1630.7s to go
# on time step 362860 (time=362.86), 0.00204632 s/step
# Meep progress: 364.754/1000.0 = 36.5% done in 932.3s, 1623.7s to go
# on time step 364844 (time=364.844), 0.00201677 s/step
# Meep progress: 366.732/1000.0 = 36.7% done in 936.3s, 1616.8s to go
# on time step 366824 (time=366.824), 0.00202027 s/step
# Meep progress: 368.70300000000003/1000.0 = 36.9% done in 940.3s, 1610.0s to go
# on time step 368796 (time=368.796), 0.00202861 s/step
# Meep progress: 370.66700000000003/1000.0 = 37.1% done in 944.3s, 1603.3s to go
# on time step 370763 (time=370.763), 0.00203436 s/step
# Meep progress: 372.63800000000003/1000.0 = 37.3% done in 948.3s, 1596.6s to go
# on time step 372733 (time=372.733), 0.00203129 s/step
# Meep progress: 374.601/1000.0 = 37.5% done in 952.3s, 1589.9s to go
# on time step 374696 (time=374.696), 0.00203796 s/step
# Meep progress: 376.568/1000.0 = 37.7% done in 956.3s, 1583.2s to go
# on time step 376663 (time=376.663), 0.00203423 s/step
# Meep progress: 378.533/1000.0 = 37.9% done in 960.3s, 1576.6s to go
# on time step 378629 (time=378.629), 0.00203481 s/step
# Meep progress: 380.493/1000.0 = 38.0% done in 964.3s, 1570.1s to go
# on time step 380588 (time=380.588), 0.00204195 s/step
# Meep progress: 382.451/1000.0 = 38.2% done in 968.3s, 1563.6s to go
# on time step 382545 (time=382.545), 0.00204472 s/step
# Meep progress: 384.403/1000.0 = 38.4% done in 972.3s, 1557.1s to go
# on time step 384501 (time=384.501), 0.00204519 s/step
# Meep progress: 386.382/1000.0 = 38.6% done in 976.3s, 1550.5s to go
# on time step 386477 (time=386.477), 0.00202483 s/step
# Meep progress: 388.35200000000003/1000.0 = 38.8% done in 980.3s, 1544.0s to go
# on time step 388448 (time=388.448), 0.00202987 s/step
# Meep progress: 390.344/1000.0 = 39.0% done in 984.3s, 1537.4s to go
# on time step 390443 (time=390.443), 0.00200602 s/step
# Meep progress: 392.308/1000.0 = 39.2% done in 988.3s, 1530.9s to go
# on time step 392404 (time=392.404), 0.00204026 s/step
# Meep progress: 394.26/1000.0 = 39.4% done in 992.3s, 1524.6s to go
# on time step 394355 (time=394.355), 0.00205105 s/step
# Meep progress: 396.249/1000.0 = 39.6% done in 996.3s, 1518.1s to go
# on time step 396348 (time=396.348), 0.00200767 s/step
# Meep progress: 398.225/1000.0 = 39.8% done in 1000.3s, 1511.6s to go
# on time step 398324 (time=398.324), 0.00202462 s/step
# Meep progress: 400.16700000000003/1000.0 = 40.0% done in 1004.3s, 1505.4s to go
# on time step 400265 (time=400.265), 0.00206113 s/step
# Meep progress: 402.141/1000.0 = 40.2% done in 1008.3s, 1499.1s to go
# on time step 402240 (time=402.24), 0.00202567 s/step
# Meep progress: 404.113/1000.0 = 40.4% done in 1012.3s, 1492.7s to go
# on time step 404212 (time=404.212), 0.00202886 s/step
# Meep progress: 406.084/1000.0 = 40.6% done in 1016.3s, 1486.4s to go
# on time step 406186 (time=406.186), 0.00202675 s/step
# Meep progress: 408.058/1000.0 = 40.8% done in 1020.3s, 1480.1s to go
# on time step 408161 (time=408.161), 0.00202577 s/step
# Meep progress: 410.031/1000.0 = 41.0% done in 1024.3s, 1473.9s to go
# on time step 410128 (time=410.128), 0.00203388 s/step
# Meep progress: 412.016/1000.0 = 41.2% done in 1028.3s, 1467.5s to go
# on time step 412117 (time=412.117), 0.00201182 s/step
# Meep progress: 413.997/1000.0 = 41.4% done in 1032.3s, 1461.2s to go
# on time step 414104 (time=414.104), 0.00201317 s/step
# Meep progress: 415.976/1000.0 = 41.6% done in 1036.3s, 1455.0s to go
# on time step 416073 (time=416.073), 0.00203218 s/step
# Meep progress: 417.922/1000.0 = 41.8% done in 1040.3s, 1449.0s to go
# on time step 418023 (time=418.023), 0.0020516 s/step
# Meep progress: 419.907/1000.0 = 42.0% done in 1044.3s, 1442.7s to go
# on time step 420011 (time=420.011), 0.00201208 s/step
# Meep progress: 421.868/1000.0 = 42.2% done in 1048.3s, 1436.7s to go
# on time step 421971 (time=421.971), 0.00204167 s/step
# Meep progress: 423.842/1000.0 = 42.4% done in 1052.3s, 1430.5s to go
# on time step 423943 (time=423.943), 0.00202931 s/step
# Meep progress: 425.805/1000.0 = 42.6% done in 1056.3s, 1424.5s to go
# on time step 425907 (time=425.907), 0.00203737 s/step
# Meep progress: 427.783/1000.0 = 42.8% done in 1060.3s, 1418.3s to go
# on time step 427891 (time=427.891), 0.00201698 s/step
# Meep progress: 429.753/1000.0 = 43.0% done in 1064.3s, 1412.3s to go
# on time step 429848 (time=429.848), 0.00204485 s/step
# Meep progress: 431.716/1000.0 = 43.2% done in 1068.3s, 1406.3s to go
# on time step 431823 (time=431.823), 0.00202543 s/step
# Meep progress: 433.696/1000.0 = 43.4% done in 1072.3s, 1400.2s to go
# on time step 433800 (time=433.8), 0.00202456 s/step
# Meep progress: 435.661/1000.0 = 43.6% done in 1076.3s, 1394.3s to go
# on time step 435768 (time=435.768), 0.00203348 s/step
# Meep progress: 437.635/1000.0 = 43.8% done in 1080.3s, 1388.3s to go
# on time step 437739 (time=437.739), 0.00203011 s/step
# Meep progress: 439.607/1000.0 = 44.0% done in 1084.3s, 1382.3s to go
# on time step 439718 (time=439.718), 0.00202205 s/step
# Meep progress: 441.593/1000.0 = 44.2% done in 1088.3s, 1376.2s to go
# on time step 441706 (time=441.706), 0.00201284 s/step
# Meep progress: 443.051/1000.0 = 44.3% done in 1092.3s, 1373.2s to go
# on time step 443150 (time=443.15), 0.00277054 s/step
# Meep progress: 444.546/1000.0 = 44.5% done in 1096.3s, 1369.9s to go
# on time step 444621 (time=444.621), 0.00272081 s/step
# Meep progress: 446.105/1000.0 = 44.6% done in 1100.4s, 1366.2s to go
# on time step 446193 (time=446.193), 0.002546 s/step
# Meep progress: 447.883/1000.0 = 44.8% done in 1104.4s, 1361.4s to go
# on time step 447990 (time=447.99), 0.00222599 s/step
# Meep progress: 449.709/1000.0 = 45.0% done in 1108.4s, 1356.2s to go
# on time step 449812 (time=449.812), 0.00219594 s/step
# Meep progress: 451.547/1000.0 = 45.2% done in 1112.4s, 1351.1s to go
# on time step 451647 (time=451.647), 0.00218069 s/step
# Meep progress: 453.358/1000.0 = 45.3% done in 1116.4s, 1346.1s to go
# on time step 453464 (time=453.464), 0.00220173 s/step
# Meep progress: 455.195/1000.0 = 45.5% done in 1120.4s, 1340.9s to go
# on time step 455297 (time=455.297), 0.00218267 s/step
# Meep progress: 457.017/1000.0 = 45.7% done in 1124.4s, 1335.9s to go
# on time step 457119 (time=457.119), 0.00219656 s/step
# Meep progress: 458.841/1000.0 = 45.9% done in 1128.4s, 1330.8s to go
# on time step 458948 (time=458.948), 0.00218803 s/step
# Meep progress: 460.659/1000.0 = 46.1% done in 1132.4s, 1325.8s to go
# on time step 460765 (time=460.765), 0.00220201 s/step
# Meep progress: 462.498/1000.0 = 46.2% done in 1136.4s, 1320.6s to go
# on time step 462603 (time=462.603), 0.00217632 s/step
# Meep progress: 464.324/1000.0 = 46.4% done in 1140.4s, 1315.6s to go
# on time step 464433 (time=464.433), 0.0021859 s/step
# Meep progress: 466.166/1000.0 = 46.6% done in 1144.4s, 1310.5s to go
# on time step 466274 (time=466.274), 0.00217375 s/step
# Meep progress: 468.017/1000.0 = 46.8% done in 1148.4s, 1305.3s to go
# on time step 468126 (time=468.126), 0.00216014 s/step
# Meep progress: 469.862/1000.0 = 47.0% done in 1152.4s, 1300.2s to go
# on time step 469970 (time=469.97), 0.00216984 s/step
# Meep progress: 471.695/1000.0 = 47.2% done in 1156.4s, 1295.1s to go
# on time step 471799 (time=471.799), 0.00218741 s/step
# Meep progress: 473.528/1000.0 = 47.4% done in 1160.4s, 1290.1s to go
# on time step 473638 (time=473.638), 0.00217535 s/step
# Meep progress: 475.378/1000.0 = 47.5% done in 1164.4s, 1285.0s to go
# on time step 475489 (time=475.489), 0.00216128 s/step
# Meep progress: 477.207/1000.0 = 47.7% done in 1168.4s, 1280.0s to go
# on time step 477313 (time=477.313), 0.00219424 s/step
# Meep progress: 479.043/1000.0 = 47.9% done in 1172.4s, 1274.9s to go
# on time step 479151 (time=479.151), 0.00217707 s/step
# Meep progress: 480.778/1000.0 = 48.1% done in 1176.4s, 1270.4s to go
# on time step 480881 (time=480.881), 0.002313 s/step
# Meep progress: 482.543/1000.0 = 48.3% done in 1180.4s, 1265.8s to go
# on time step 482653 (time=482.653), 0.00225758 s/step
# Meep progress: 484.38300000000004/1000.0 = 48.4% done in 1184.4s, 1260.7s to go
# on time step 484493 (time=484.493), 0.0021741 s/step
# Meep progress: 486.223/1000.0 = 48.6% done in 1188.4s, 1255.7s to go
# on time step 486331 (time=486.331), 0.0021768 s/step
# Meep progress: 488.053/1000.0 = 48.8% done in 1192.4s, 1250.7s to go
# on time step 488163 (time=488.163), 0.00218388 s/step
# Meep progress: 489.901/1000.0 = 49.0% done in 1196.4s, 1245.7s to go
# on time step 490014 (time=490.014), 0.00216184 s/step
# Meep progress: 491.737/1000.0 = 49.2% done in 1200.4s, 1240.7s to go
# on time step 491852 (time=491.852), 0.00217694 s/step
# Meep progress: 493.587/1000.0 = 49.4% done in 1204.4s, 1235.7s to go
# on time step 493700 (time=493.7), 0.00216517 s/step
# Meep progress: 495.428/1000.0 = 49.5% done in 1208.4s, 1230.7s to go
# on time step 495540 (time=495.54), 0.00217485 s/step
# Meep progress: 497.257/1000.0 = 49.7% done in 1212.4s, 1225.8s to go
# on time step 497370 (time=497.37), 0.00218596 s/step
# Meep progress: 499.095/1000.0 = 49.9% done in 1216.4s, 1220.8s to go
# on time step 499199 (time=499.199), 0.00218771 s/step
# Meep progress: 500.913/1000.0 = 50.1% done in 1220.4s, 1215.9s to go
# on time step 501025 (time=501.025), 0.00219064 s/step
# Meep progress: 502.761/1000.0 = 50.3% done in 1224.4s, 1210.9s to go
# on time step 502874 (time=502.874), 0.00216391 s/step
# Meep progress: 504.581/1000.0 = 50.5% done in 1228.4s, 1206.1s to go
# on time step 504685 (time=504.685), 0.00221001 s/step
# Meep progress: 506.422/1000.0 = 50.6% done in 1232.4s, 1201.1s to go
# on time step 506537 (time=506.537), 0.00215993 s/step
# Meep progress: 508.261/1000.0 = 50.8% done in 1236.4s, 1196.2s to go
# on time step 508375 (time=508.375), 0.00217674 s/step
# Meep progress: 510.099/1000.0 = 51.0% done in 1240.4s, 1191.3s to go
# on time step 510214 (time=510.214), 0.00217574 s/step
# Meep progress: 511.958/1000.0 = 51.2% done in 1244.4s, 1186.3s to go
# on time step 512070 (time=512.07), 0.00215575 s/step
# Meep progress: 513.806/1000.0 = 51.4% done in 1248.4s, 1181.3s to go
# on time step 513920 (time=513.92), 0.00216308 s/step
# Meep progress: 515.641/1000.0 = 51.6% done in 1252.4s, 1176.4s to go
# on time step 515752 (time=515.752), 0.00218343 s/step
# Meep progress: 517.486/1000.0 = 51.7% done in 1256.4s, 1171.5s to go
# on time step 517603 (time=517.603), 0.00216209 s/step
# Meep progress: 519.326/1000.0 = 51.9% done in 1260.4s, 1166.6s to go
# on time step 519440 (time=519.44), 0.00217755 s/step
# Meep progress: 521.1800000000001/1000.0 = 52.1% done in 1264.4s, 1161.6s to go
# on time step 521294 (time=521.294), 0.00215794 s/step
# Meep progress: 523.027/1000.0 = 52.3% done in 1268.4s, 1156.7s to go
# on time step 523143 (time=523.143), 0.00216359 s/step
# Meep progress: 524.862/1000.0 = 52.5% done in 1272.4s, 1151.9s to go
# on time step 524977 (time=524.977), 0.00218233 s/step
# Meep progress: 526.708/1000.0 = 52.7% done in 1276.4s, 1147.0s to go
# on time step 526814 (time=526.814), 0.00217846 s/step
# Meep progress: 528.54/1000.0 = 52.9% done in 1280.4s, 1142.1s to go
# on time step 528656 (time=528.656), 0.00217221 s/step
# Meep progress: 530.385/1000.0 = 53.0% done in 1284.4s, 1137.2s to go
# on time step 530501 (time=530.501), 0.00216845 s/step
# Meep progress: 532.212/1000.0 = 53.2% done in 1288.4s, 1132.4s to go
# on time step 532326 (time=532.326), 0.00219266 s/step
# Meep progress: 534.061/1000.0 = 53.4% done in 1292.4s, 1127.6s to go
# on time step 534177 (time=534.177), 0.00216172 s/step
# Meep progress: 535.892/1000.0 = 53.6% done in 1296.4s, 1122.8s to go
# on time step 536012 (time=536.012), 0.00218044 s/step
# Meep progress: 537.7330000000001/1000.0 = 53.8% done in 1300.4s, 1117.9s to go
# on time step 537853 (time=537.853), 0.00217338 s/step
# Meep progress: 539.571/1000.0 = 54.0% done in 1304.4s, 1113.1s to go
# on time step 539690 (time=539.69), 0.00217775 s/step
# Meep progress: 541.424/1000.0 = 54.1% done in 1308.4s, 1108.2s to go
# on time step 541546 (time=541.546), 0.00215577 s/step
# Meep progress: 543.2620000000001/1000.0 = 54.3% done in 1312.4s, 1103.4s to go
# on time step 543378 (time=543.378), 0.00218369 s/step
# Meep progress: 545.105/1000.0 = 54.5% done in 1316.4s, 1098.6s to go
# on time step 545224 (time=545.224), 0.00216795 s/step
# Meep progress: 546.96/1000.0 = 54.7% done in 1320.4s, 1093.7s to go
# on time step 547080 (time=547.08), 0.00215582 s/step
# Meep progress: 548.788/1000.0 = 54.9% done in 1324.4s, 1088.9s to go
# on time step 548904 (time=548.904), 0.00219356 s/step
# Meep progress: 550.62/1000.0 = 55.1% done in 1328.4s, 1084.2s to go
# on time step 550744 (time=550.744), 0.00217544 s/step
# Meep progress: 552.863/1000.0 = 55.3% done in 1332.4s, 1077.6s to go
# on time step 553027 (time=553.027), 0.00175252 s/step
# Meep progress: 555.343/1000.0 = 55.5% done in 1336.4s, 1070.1s to go
# on time step 555502 (time=555.502), 0.00161634 s/step
# Meep progress: 557.778/1000.0 = 55.8% done in 1340.4s, 1062.7s to go
# on time step 557933 (time=557.933), 0.00164645 s/step
# Meep progress: 560.2280000000001/1000.0 = 56.0% done in 1344.4s, 1055.4s to go
# on time step 560392 (time=560.392), 0.00162672 s/step
# Meep progress: 562.6850000000001/1000.0 = 56.3% done in 1348.4s, 1048.0s to go
# on time step 562840 (time=562.84), 0.00163458 s/step
# Meep progress: 565.131/1000.0 = 56.5% done in 1352.4s, 1040.7s to go
# on time step 565298 (time=565.298), 0.00162737 s/step
# Meep progress: 567.646/1000.0 = 56.8% done in 1356.4s, 1033.1s to go
# on time step 567819 (time=567.819), 0.00158719 s/step
# Meep progress: 570.133/1000.0 = 57.0% done in 1360.4s, 1025.7s to go
# on time step 570302 (time=570.302), 0.00161113 s/step
# Meep progress: 572.672/1000.0 = 57.3% done in 1364.4s, 1018.1s to go
# on time step 572842 (time=572.842), 0.00157524 s/step
# Meep progress: 574.761/1000.0 = 57.5% done in 1368.4s, 1012.4s to go
# on time step 574888 (time=574.888), 0.00195509 s/step
# Meep progress: 576.622/1000.0 = 57.7% done in 1372.4s, 1007.7s to go
# on time step 576749 (time=576.749), 0.00215056 s/step
# Meep progress: 578.4830000000001/1000.0 = 57.8% done in 1376.4s, 1003.0s to go
# on time step 578610 (time=578.61), 0.00214995 s/step
# Meep progress: 580.336/1000.0 = 58.0% done in 1380.4s, 998.2s to go
# on time step 580464 (time=580.464), 0.0021585 s/step
# Meep progress: 582.207/1000.0 = 58.2% done in 1384.4s, 993.5s to go
# on time step 582336 (time=582.336), 0.00213765 s/step
# Meep progress: 584.073/1000.0 = 58.4% done in 1388.4s, 988.7s to go
# on time step 584202 (time=584.202), 0.00214468 s/step
# Meep progress: 585.942/1000.0 = 58.6% done in 1392.4s, 984.0s to go
# on time step 586073 (time=586.073), 0.00213885 s/step
# Meep progress: 587.802/1000.0 = 58.8% done in 1396.4s, 979.3s to go
# on time step 587925 (time=587.925), 0.00216053 s/step
# Meep progress: 589.635/1000.0 = 59.0% done in 1400.4s, 974.7s to go
# on time step 589766 (time=589.766), 0.00217288 s/step
# Meep progress: 591.509/1000.0 = 59.2% done in 1404.4s, 969.9s to go
# on time step 591643 (time=591.643), 0.00213121 s/step
# Meep progress: 593.378/1000.0 = 59.3% done in 1408.4s, 965.2s to go
# on time step 593504 (time=593.504), 0.00214954 s/step
# Meep progress: 595.249/1000.0 = 59.5% done in 1412.4s, 960.4s to go
# on time step 595375 (time=595.375), 0.00213883 s/step
# Meep progress: 597.097/1000.0 = 59.7% done in 1416.4s, 955.8s to go
# on time step 597227 (time=597.227), 0.00216014 s/step
# Meep progress: 598.95/1000.0 = 59.9% done in 1420.4s, 951.1s to go
# on time step 599054 (time=599.054), 0.00218971 s/step
# Meep progress: 600.766/1000.0 = 60.1% done in 1424.4s, 946.6s to go
# on time step 600897 (time=600.897), 0.00217152 s/step
# Meep progress: 602.629/1000.0 = 60.3% done in 1428.4s, 941.9s to go
# on time step 602755 (time=602.755), 0.00215287 s/step
# Meep progress: 604.481/1000.0 = 60.4% done in 1432.4s, 937.3s to go
# on time step 604613 (time=604.613), 0.00215286 s/step
# Meep progress: 606.363/1000.0 = 60.6% done in 1436.4s, 932.5s to go
# on time step 606497 (time=606.497), 0.00212432 s/step
# Meep progress: 608.243/1000.0 = 60.8% done in 1440.4s, 927.8s to go
# on time step 608376 (time=608.376), 0.00212981 s/step
# Meep progress: 610.116/1000.0 = 61.0% done in 1444.4s, 923.1s to go
# on time step 610244 (time=610.244), 0.00214234 s/step
# Meep progress: 611.955/1000.0 = 61.2% done in 1448.5s, 918.5s to go
# on time step 612090 (time=612.09), 0.00216746 s/step
# Meep progress: 613.821/1000.0 = 61.4% done in 1452.5s, 913.8s to go
# on time step 613955 (time=613.955), 0.00214595 s/step
# Meep progress: 615.679/1000.0 = 61.6% done in 1456.5s, 909.2s to go
# on time step 615808 (time=615.808), 0.00215931 s/step
# Meep progress: 617.532/1000.0 = 61.8% done in 1460.5s, 904.5s to go
# on time step 617667 (time=617.667), 0.0021518 s/step
# Meep progress: 619.414/1000.0 = 61.9% done in 1464.5s, 899.8s to go
# on time step 619550 (time=619.55), 0.00212465 s/step
# Meep progress: 621.266/1000.0 = 62.1% done in 1468.5s, 895.2s to go
# on time step 621393 (time=621.393), 0.00217102 s/step
# Meep progress: 623.123/1000.0 = 62.3% done in 1472.5s, 890.6s to go
# on time step 623256 (time=623.256), 0.00214787 s/step
# Meep progress: 624.986/1000.0 = 62.5% done in 1476.5s, 885.9s to go
# on time step 625122 (time=625.122), 0.00214383 s/step
# Meep progress: 626.845/1000.0 = 62.7% done in 1480.5s, 881.3s to go
# on time step 626982 (time=626.982), 0.00215059 s/step
# Meep progress: 628.716/1000.0 = 62.9% done in 1484.5s, 876.6s to go
# on time step 628855 (time=628.855), 0.00213583 s/step
# Meep progress: 630.577/1000.0 = 63.1% done in 1488.5s, 872.0s to go
# on time step 630715 (time=630.715), 0.00215081 s/step
# Meep progress: 632.441/1000.0 = 63.2% done in 1492.5s, 867.4s to go
# on time step 632573 (time=632.573), 0.0021529 s/step
# Meep progress: 634.3100000000001/1000.0 = 63.4% done in 1496.5s, 862.7s to go
# on time step 634448 (time=634.448), 0.00213333 s/step
# ...
# Meep progress: 784.995/1000.0 = 78.5% done in 1820.6s, 498.6s to go
# on time step 785155 (time=785.155), 0.00212963 s/step
# Meep progress: 786.894/1000.0 = 78.7% done in 1824.6s, 494.1s to go
# on time step 787040 (time=787.04), 0.00212238 s/step
# Meep progress: 788.775/1000.0 = 78.9% done in 1828.6s, 489.7s to go
# on time step 788929 (time=788.929), 0.00211832 s/step
# Meep progress: 790.671/1000.0 = 79.1% done in 1832.6s, 485.2s to go
# on time step 790832 (time=790.832), 0.00210234 s/step
# Meep progress: 792.5790000000001/1000.0 = 79.3% done in 1836.6s, 480.6s to go
# on time step 792738 (time=792.738), 0.00209909 s/step
# Meep progress: 794.469/1000.0 = 79.4% done in 1840.6s, 476.2s to go
# on time step 794631 (time=794.631), 0.00211398 s/step
# Meep progress: 796.369/1000.0 = 79.6% done in 1844.6s, 471.7s to go
# on time step 796532 (time=796.532), 0.00210422 s/step
# Meep progress: 798.279/1000.0 = 79.8% done in 1848.6s, 467.1s to go
# on time step 798437 (time=798.437), 0.00209985 s/step
# Meep progress: 800.1700000000001/1000.0 = 80.0% done in 1852.6s, 462.6s to go
# on time step 800330 (time=800.33), 0.0021131 s/step
# Meep progress: 802.072/1000.0 = 80.2% done in 1856.6s, 458.1s to go
# on time step 802230 (time=802.23), 0.00210638 s/step
# Meep progress: 803.982/1000.0 = 80.4% done in 1860.6s, 453.6s to go
# on time step 804144 (time=804.144), 0.00209055 s/step
# Meep progress: 805.885/1000.0 = 80.6% done in 1864.6s, 449.1s to go
# on time step 806046 (time=806.046), 0.00210313 s/step
# Meep progress: 807.791/1000.0 = 80.8% done in 1868.6s, 444.6s to go
# on time step 807944 (time=807.944), 0.00210758 s/step
# Meep progress: 809.683/1000.0 = 81.0% done in 1872.6s, 440.1s to go
# on time step 809845 (time=809.845), 0.00210487 s/step
# Meep progress: 811.589/1000.0 = 81.2% done in 1876.6s, 435.6s to go
# on time step 811750 (time=811.75), 0.00210039 s/step
# Meep progress: 813.493/1000.0 = 81.3% done in 1880.6s, 431.2s to go
# on time step 813659 (time=813.659), 0.00209544 s/step
# Meep progress: 815.409/1000.0 = 81.5% done in 1884.6s, 426.6s to go
# on time step 815569 (time=815.569), 0.00209493 s/step
# Meep progress: 817.293/1000.0 = 81.7% done in 1888.6s, 422.2s to go
# on time step 817459 (time=817.459), 0.00211665 s/step
# Meep progress: 819.203/1000.0 = 81.9% done in 1892.6s, 417.7s to go
# on time step 819371 (time=819.371), 0.00209238 s/step
# Meep progress: 821.112/1000.0 = 82.1% done in 1896.6s, 413.2s to go
# on time step 821275 (time=821.275), 0.00210137 s/step
# Meep progress: 823.014/1000.0 = 82.3% done in 1900.6s, 408.7s to go
# on time step 823177 (time=823.177), 0.00210309 s/step
# Meep progress: 824.914/1000.0 = 82.5% done in 1904.6s, 404.2s to go
# on time step 825078 (time=825.078), 0.00210469 s/step
# Meep progress: 826.804/1000.0 = 82.7% done in 1908.6s, 399.8s to go
# on time step 826967 (time=826.967), 0.00211845 s/step
# Meep progress: 828.7090000000001/1000.0 = 82.9% done in 1912.6s, 395.3s to go
# on time step 828872 (time=828.872), 0.00210067 s/step
# Meep progress: 830.604/1000.0 = 83.1% done in 1916.6s, 390.9s to go
# on time step 830771 (time=830.771), 0.00210688 s/step
# Meep progress: 832.514/1000.0 = 83.3% done in 1920.6s, 386.4s to go
# on time step 832679 (time=832.679), 0.00209727 s/step
# Meep progress: 834.415/1000.0 = 83.4% done in 1924.6s, 381.9s to go
# on time step 834583 (time=834.583), 0.00210194 s/step
# Meep progress: 836.3050000000001/1000.0 = 83.6% done in 1928.6s, 377.5s to go
# on time step 836475 (time=836.475), 0.00211525 s/step
# Meep progress: 838.212/1000.0 = 83.8% done in 1932.6s, 373.0s to go
# on time step 838378 (time=838.378), 0.00210267 s/step
# Meep progress: 840.111/1000.0 = 84.0% done in 1936.6s, 368.6s to go
# on time step 840279 (time=840.279), 0.00210455 s/step
# Meep progress: 841.998/1000.0 = 84.2% done in 1940.6s, 364.2s to go
# on time step 842166 (time=842.166), 0.00212026 s/step
# Meep progress: 843.868/1000.0 = 84.4% done in 1944.6s, 359.8s to go
# on time step 844031 (time=844.031), 0.00214498 s/step
# Meep progress: 845.748/1000.0 = 84.6% done in 1948.6s, 355.4s to go
# on time step 845919 (time=845.919), 0.00211917 s/step
# Meep progress: 847.649/1000.0 = 84.8% done in 1952.6s, 350.9s to go
# on time step 847819 (time=847.819), 0.00210585 s/step
# Meep progress: 849.553/1000.0 = 85.0% done in 1956.6s, 346.5s to go
# on time step 849722 (time=849.722), 0.00210271 s/step
# Meep progress: 851.458/1000.0 = 85.1% done in 1960.6s, 342.0s to go
# on time step 851629 (time=851.629), 0.00209814 s/step
# Meep progress: 853.362/1000.0 = 85.3% done in 1964.6s, 337.6s to go
# on time step 853527 (time=853.527), 0.00210764 s/step
# Meep progress: 855.248/1000.0 = 85.5% done in 1968.6s, 333.2s to go
# on time step 855414 (time=855.414), 0.00211993 s/step
# Meep progress: 857.116/1000.0 = 85.7% done in 1972.6s, 328.8s to go
# on time step 857282 (time=857.282), 0.002142 s/step
# Meep progress: 859.006/1000.0 = 85.9% done in 1976.6s, 324.4s to go
# on time step 859174 (time=859.174), 0.00211469 s/step
# Meep progress: 860.888/1000.0 = 86.1% done in 1980.6s, 320.0s to go
# on time step 861058 (time=861.058), 0.00212363 s/step
# Meep progress: 862.774/1000.0 = 86.3% done in 1984.6s, 315.7s to go
# on time step 862948 (time=862.948), 0.00211726 s/step
# Meep progress: 864.679/1000.0 = 86.5% done in 1988.6s, 311.2s to go
# on time step 864849 (time=864.849), 0.00210467 s/step
# Meep progress: 866.5740000000001/1000.0 = 86.7% done in 1992.6s, 306.8s to go
# on time step 866743 (time=866.743), 0.0021129 s/step
# Meep progress: 868.445/1000.0 = 86.8% done in 1996.6s, 302.5s to go
# on time step 868617 (time=868.617), 0.00213491 s/step
# Meep progress: 870.351/1000.0 = 87.0% done in 2000.6s, 298.0s to go
# on time step 870525 (time=870.525), 0.00209708 s/step
# Meep progress: 872.244/1000.0 = 87.2% done in 2004.6s, 293.6s to go
# on time step 872413 (time=872.413), 0.00211894 s/step
# Meep progress: 874.1320000000001/1000.0 = 87.4% done in 2008.6s, 289.2s to go
# on time step 874305 (time=874.305), 0.00211499 s/step
# Meep progress: 876.027/1000.0 = 87.6% done in 2012.6s, 284.8s to go
# on time step 876191 (time=876.191), 0.00212147 s/step
# Meep progress: 877.924/1000.0 = 87.8% done in 2016.6s, 280.4s to go
# on time step 878089 (time=878.089), 0.00210828 s/step
# Meep progress: 879.8000000000001/1000.0 = 88.0% done in 2020.6s, 276.1s to go
# on time step 879978 (time=879.978), 0.00211757 s/step
# Meep progress: 881.711/1000.0 = 88.2% done in 2024.6s, 271.6s to go
# on time step 881888 (time=881.888), 0.00209506 s/step
# Meep progress: 883.621/1000.0 = 88.4% done in 2028.6s, 267.2s to go
# on time step 883794 (time=883.794), 0.00209939 s/step
# Meep progress: 885.51/1000.0 = 88.6% done in 2032.6s, 262.8s to go
# on time step 885691 (time=885.691), 0.00210879 s/step
# Meep progress: 887.434/1000.0 = 88.7% done in 2036.6s, 258.3s to go
# on time step 887610 (time=887.61), 0.00208497 s/step
# Meep progress: 889.3430000000001/1000.0 = 88.9% done in 2040.6s, 253.9s to go
# on time step 889517 (time=889.517), 0.00209819 s/step
# Meep progress: 891.251/1000.0 = 89.1% done in 2044.6s, 249.5s to go
# on time step 891428 (time=891.428), 0.00209379 s/step
# Meep progress: 893.153/1000.0 = 89.3% done in 2048.6s, 245.1s to go
# on time step 893334 (time=893.334), 0.0020992 s/step
# Meep progress: 895.0600000000001/1000.0 = 89.5% done in 2052.6s, 240.7s to go
# on time step 895237 (time=895.237), 0.00210268 s/step
# Meep progress: 896.961/1000.0 = 89.7% done in 2056.6s, 236.3s to go
# on time step 897142 (time=897.142), 0.00209996 s/step
# Meep progress: 898.865/1000.0 = 89.9% done in 2060.6s, 231.8s to go
# on time step 899042 (time=899.042), 0.0021061 s/step
# Meep progress: 900.764/1000.0 = 90.1% done in 2064.6s, 227.5s to go
# on time step 900932 (time=900.932), 0.00211657 s/step
# Meep progress: 902.634/1000.0 = 90.3% done in 2068.6s, 223.1s to go
# on time step 902803 (time=902.803), 0.00213831 s/step
# Meep progress: 904.534/1000.0 = 90.5% done in 2072.6s, 218.7s to go
# on time step 904713 (time=904.713), 0.00209495 s/step
# Meep progress: 906.441/1000.0 = 90.6% done in 2076.6s, 214.3s to go
# on time step 906617 (time=906.617), 0.00210189 s/step
# Meep progress: 908.344/1000.0 = 90.8% done in 2080.6s, 209.9s to go
# on time step 908522 (time=908.522), 0.0021 s/step
# Meep progress: 910.2470000000001/1000.0 = 91.0% done in 2084.6s, 205.6s to go
# on time step 910426 (time=910.426), 0.002101 s/step
# Meep progress: 912.144/1000.0 = 91.2% done in 2088.6s, 201.2s to go
# on time step 912319 (time=912.319), 0.0021133 s/step
# Meep progress: 914.0310000000001/1000.0 = 91.4% done in 2092.6s, 196.8s to go
# on time step 914203 (time=914.203), 0.00212326 s/step
# Meep progress: 915.917/1000.0 = 91.6% done in 2096.6s, 192.5s to go
# on time step 916091 (time=916.091), 0.00211885 s/step
# Meep progress: 917.8240000000001/1000.0 = 91.8% done in 2100.6s, 188.1s to go
# on time step 918002 (time=918.002), 0.00209412 s/step
# Meep progress: 919.724/1000.0 = 92.0% done in 2104.6s, 183.7s to go
# on time step 919906 (time=919.906), 0.00210171 s/step
# Meep progress: 921.628/1000.0 = 92.2% done in 2108.6s, 179.3s to go
# on time step 921811 (time=921.811), 0.00210069 s/step
# Meep progress: 923.539/1000.0 = 92.4% done in 2112.6s, 174.9s to go
# on time step 923714 (time=923.714), 0.00210265 s/step
# Meep progress: 925.434/1000.0 = 92.5% done in 2116.6s, 170.5s to go
# on time step 925615 (time=925.615), 0.00210431 s/step
# Meep progress: 927.345/1000.0 = 92.7% done in 2120.6s, 166.1s to go
# on time step 927527 (time=927.527), 0.00209245 s/step
# Meep progress: 929.264/1000.0 = 92.9% done in 2124.6s, 161.7s to go
# on time step 929446 (time=929.446), 0.0020848 s/step
# Meep progress: 931.152/1000.0 = 93.1% done in 2128.6s, 157.4s to go
# on time step 931333 (time=931.333), 0.00212137 s/step
# Meep progress: 933.0450000000001/1000.0 = 93.3% done in 2132.6s, 153.0s to go
# on time step 933225 (time=933.225), 0.0021143 s/step
# Meep progress: 934.942/1000.0 = 93.5% done in 2136.6s, 148.7s to go
# on time step 935125 (time=935.125), 0.00210605 s/step
# Meep progress: 936.851/1000.0 = 93.7% done in 2140.6s, 144.3s to go
# on time step 937036 (time=937.036), 0.00209349 s/step
# Meep progress: 938.769/1000.0 = 93.9% done in 2144.6s, 139.9s to go
# on time step 938954 (time=938.954), 0.00208591 s/step
# Meep progress: 940.6850000000001/1000.0 = 94.1% done in 2148.6s, 135.5s to go
# on time step 940867 (time=940.867), 0.0020913 s/step
# Meep progress: 942.577/1000.0 = 94.3% done in 2152.6s, 131.1s to go
# on time step 942764 (time=942.764), 0.00210865 s/step
# Meep progress: 944.488/1000.0 = 94.4% done in 2156.6s, 126.8s to go
# on time step 944668 (time=944.668), 0.00210085 s/step
# Meep progress: 946.388/1000.0 = 94.6% done in 2160.6s, 122.4s to go
# on time step 946567 (time=946.567), 0.00210728 s/step
# Meep progress: 948.274/1000.0 = 94.8% done in 2164.6s, 118.1s to go
# on time step 948460 (time=948.46), 0.00211306 s/step
# Meep progress: 950.1700000000001/1000.0 = 95.0% done in 2168.6s, 113.7s to go
# on time step 950352 (time=950.352), 0.0021149 s/step
# Meep progress: 952.077/1000.0 = 95.2% done in 2172.7s, 109.4s to go
# on time step 952257 (time=952.257), 0.0021 s/step
# Meep progress: 953.962/1000.0 = 95.4% done in 2176.7s, 105.0s to go
# on time step 954147 (time=954.147), 0.00211727 s/step
# Meep progress: 955.878/1000.0 = 95.6% done in 2180.7s, 100.7s to go
# on time step 956064 (time=956.064), 0.00208797 s/step
# Meep progress: 957.773/1000.0 = 95.8% done in 2184.7s, 96.3s to go
# on time step 957957 (time=957.957), 0.0021138 s/step
# Meep progress: 959.671/1000.0 = 96.0% done in 2188.7s, 92.0s to go
# on time step 959853 (time=959.853), 0.0021105 s/step
# Meep progress: 961.566/1000.0 = 96.2% done in 2192.7s, 87.6s to go
# on time step 961749 (time=961.749), 0.00211061 s/step
# Meep progress: 963.465/1000.0 = 96.3% done in 2196.7s, 83.3s to go
# on time step 963650 (time=963.65), 0.0021048 s/step
# Meep progress: 965.36/1000.0 = 96.5% done in 2200.7s, 79.0s to go
# on time step 965551 (time=965.551), 0.00210477 s/step
# Meep progress: 967.267/1000.0 = 96.7% done in 2204.7s, 74.6s to go
# on time step 967452 (time=967.452), 0.00210457 s/step
# Meep progress: 969.169/1000.0 = 96.9% done in 2208.7s, 70.3s to go
# on time step 969356 (time=969.356), 0.00210155 s/step
# Meep progress: 971.072/1000.0 = 97.1% done in 2212.7s, 65.9s to go
# on time step 971246 (time=971.246), 0.0021173 s/step
# Meep progress: 972.955/1000.0 = 97.3% done in 2216.7s, 61.6s to go
# on time step 973142 (time=973.142), 0.00211047 s/step
# Meep progress: 974.857/1000.0 = 97.5% done in 2220.7s, 57.3s to go
# on time step 975043 (time=975.043), 0.00210453 s/step
# Meep progress: 976.722/1000.0 = 97.7% done in 2224.7s, 53.0s to go
# on time step 976914 (time=976.914), 0.00213815 s/step
# Meep progress: 978.628/1000.0 = 97.9% done in 2228.7s, 48.7s to go
# on time step 978816 (time=978.816), 0.00210307 s/step
# Meep progress: 980.535/1000.0 = 98.1% done in 2232.7s, 44.3s to go
# on time step 980720 (time=980.72), 0.00210096 s/step
# Meep progress: 982.434/1000.0 = 98.2% done in 2236.7s, 40.0s to go
# on time step 982624 (time=982.624), 0.00210102 s/step
# Meep progress: 984.322/1000.0 = 98.4% done in 2240.7s, 35.7s to go
# on time step 984509 (time=984.509), 0.00212293 s/step
# Meep progress: 986.139/1000.0 = 98.6% done in 2244.7s, 31.6s to go
# on time step 986318 (time=986.318), 0.00221122 s/step
# Meep progress: 987.963/1000.0 = 98.8% done in 2248.7s, 27.4s to go
# on time step 988156 (time=988.156), 0.00217731 s/step
# Meep progress: 989.865/1000.0 = 99.0% done in 2252.7s, 23.1s to go
# on time step 990056 (time=990.056), 0.00210541 s/step
# Meep progress: 991.764/1000.0 = 99.2% done in 2256.7s, 18.7s to go
# on time step 991949 (time=991.949), 0.00211369 s/step
# Meep progress: 993.662/1000.0 = 99.4% done in 2260.7s, 14.4s to go
# on time step 993839 (time=993.839), 0.00211648 s/step
# Meep progress: 995.554/1000.0 = 99.6% done in 2264.7s, 10.1s to go
# on time step 995745 (time=995.745), 0.0020994 s/step
# Meep progress: 997.477/1000.0 = 99.7% done in 2268.7s, 5.7s to go
# on time step 997666 (time=997.666), 0.00208234 s/step
# Meep progress: 999.389/1000.0 = 99.9% done in 2272.7s, 1.4s to go
# on time step 999582 (time=999.582), 0.00208784 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 1000.0 (1000000 timesteps)
#      block, center = (-0.76,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
ez_data_up = np.array(ez_data_up)
ez_data_cen = np.array(ez_data_cen)
ez_data_down = np.array(ez_data_down)


print(len(ez_data_cen))

print(1 + int(round(t_xx/dt)))
# Out:
# 76923
# 41

# %%
ez_data_cen = np.array(ez_data_cen)
ez_data_up = np.array(ez_data_up)
ez_data_down = np.array(ez_data_down)

#plt.subplot_adjust(hspace = .35)
plt.figure(dpi = 300)
start = round(len(ez_data_cen) / t *1)

for i in range(start,round(len(ez_data_cen) / 75),1):
    plt.subplot(3,1,1)
    plt.plot(i,ez_data_up[i],'k.')
    plt.subplot(3,1,2)
    plt.plot(i,ez_data_cen[i],'k.')
    plt.subplot(3,1,3)
    plt.plot(i,ez_data_down[i],'k.')
    if i ==  (len(ez_data_cen)-1):
        plt.subplot(3,1,1)
        plt.title('upper point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_up[i],'b .')
        plt.subplot(3,1,2)
        plt.title('center point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_cen[i],'b .')
        plt.subplot(3,1,3)
        plt.title('downer point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_down[i],'b .')
# Out:
# /home/henry/miniconda3/envs/mp/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
# index1 and index2 . When we find the target's Electric field amplitude, we want to know where is amplitude value in array. So we set up index variable before running simulation.
index1_up = 0
index1_cen = 0
index1_down = 0

index2_up = 0
index2_cen = 0
index2_down = 0
# Period_max , period_next_mat . I set up those variables because I plan to use variables to store max amplitude value in a peiod in the following simulation. 
period_max_up = 0
period_max_cen = 0
period_max_down = 0
period_next_max_up = 0
period_next_max_cen = 0
period_next_max_down = 0

# Intial_index , end_index. ==>  "for loop" index
initial_index = round(len(ez_data_cen) / t * 200 )
print(initial_index)
end_index = len(ez_data_cen) - 2*( 1 +int(round(t_xx/dt))) 
print(end_index)
# Out:
# 15385
# 76841

# %%
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_up[j])
        period_next.append(ez_data_up[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1 = np.where(ez_data_up == period_max)
        print(index1, '--- upper point index1')
        index2 = np.where(ez_data_up == period_next_max)
        print(index2, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('upper point 到達誤差範圍內的所需 meep time unit' , 17690 / len(ez_data_up) * 500 , '\n')
        print('-----------------------------------------------------')
        break

        
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_cen[j])
        period_next.append(ez_data_cen[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1 = np.where(ez_data_cen == period_max)
        print(index1, '--- upper point index1')
        index2 = np.where(ez_data_cen == period_next_max)
        print(index2, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t')
        print('center point 到達誤差範圍內的所需 meep time unit' , 53826 / len(ez_data_cen) * 500 , '\n')
        print('-----------------------------------------------------')
        break
        
    
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_down[j])
        period_next.append(ez_data_down[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- down point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- down point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1 = np.where(ez_data_down == period_max)
        print(index1, '--- down point index1')
        index2 = np.where(ez_data_down == period_next_max)
        print(index2, '--- down point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('down point 到達誤差範圍內的所需 meep time unit' , 40267 / len(ez_data_down) * 500 , '\n')
        print('-----------------------------------------------------')
        break
# Out:
# (0.17989409727936032+0j) -------- upper point one period 內最大振福
# (0.17989335024876293+0j) ------- upper point one next_period 內最大振福
# (7.470305973811264e-07+0j) ----- 振幅誤差
# (array([17652]),) --- upper point index1
# (array([17690]),) --- upper point index2
# (0.17989409727936032+0j) 	 (0.17989335024876293+0j) 	 (7.470305973811264e-07+0j)
# upper point 到達誤差範圍內的所需 meep time unit 114.98511498511499
#
# -----------------------------------------------------
# (0.19506614299556752+0j) -------- upper point one period 內最大振福
# (0.19506709075293355+0j) ------- upper point one next_period 內最大振福
# (-9.477573660321426e-07+0j) ----- 振幅誤差
# (array([53787]),) --- upper point index1
# (array([53826]),) --- upper point index2
# (0.19506614299556752+0j) 	 (0.19506709075293355+0j) 	 (-9.477573660321426e-07+0j)
# center point 到達誤差範圍內的所需 meep time unit 349.8693498693499
#
# -----------------------------------------------------
# (0.18242525334547802+0j) -------- down point one period 內最大振福
# (0.1824243143177175+0j) ------- down point one next_period 內最大振福
# (9.390277605214603e-07+0j) ----- 振幅誤差
# (array([40190]),) --- down point index1
# (array([40267]),) --- down point index2
# (0.18242525334547802+0j) 	 (0.1824243143177175+0j) 	 (9.390277605214603e-07+0j)
# down point 到達誤差範圍內的所需 meep time unit 261.73576173576174
#
# -----------------------------------------------------

# %%
plt.figure(dpi = 150)
plt.title('Upper point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_up[73320]
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_up[i] , 'b.')
    if max_value < ez_data_up[i] :
        max_value = ez_data_up[i]

print(max_value)
# Out:
# (0.18125654238615385+0j)

# %%
plt.figure(dpi = 150)
plt.title('center point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_cen[73320]
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_cen[i] , 'b.')
    if max_value < ez_data_cen[i] :
        max_value = ez_data_cen[i]

print(max_value)
# Out:
# (0.19496237544520195+0j)

# %%
plt.figure(dpi = 150)
plt.title('downner point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_down[i] , 'b.')

# %% [markdown]
# # Following is Simulation that Cell height = 300 nm

# %%
sim.reset_meep()
resolution = 500  # pixels/μm

dpml = 1.0  # PML thickness
dsub = 0.5  # substrate thickness
dcaa = 0.06  # air rigion for alpha structure
# alpha structure is that one period = 200nm，sigle cell width = 80nm locate at center
dcab = 0.025 # air rigion for beta structure 
# beta structure is that one period = 200nm，sigle cell width = 150nm locate at center
gp = 0.2  # grating periodicity
gh = 0.3  # grating height
gwa = 0.08 # alpha grating cell width
gwb = 0.15 # beta grating cell width

num_cells = 3 # number of grating unit cells

# air region thickness adjacent to grating
dair = 1 

wvl = 0.532  # center wavelength
fcen = 1 / wvl  # center frequency

glass = mp.Medium(index= 2.6678)

pml_layers = [mp.PML(thickness=dpml, direction = mp.X )]

symmetries = [mp.Mirror(mp.Y)]

sx = dpml + dsub + gh + dair + dpml
sy = num_cells*gp
#sy = ((dcaa + gwa + dcaa)*2 + (dcab + gwb + dcab))*num_cells
cell_size = mp.Vector3(sx, sy)

sources = [
    mp.Source(
        mp.ContinuousSource(frequency = 2), # frequemcy = 2原因是 meep 的 C=1，所以 1/? = 0.5 um，?即是2
        component = mp.Ez,
        center = mp.Vector3(-0.5 * sx + dpml ),
        size = mp.Vector3(y = sy),
    )
]

geometry = [
    mp.Block(
        material=glass,
        size=mp.Vector3(dsub, mp.inf, mp.inf),
        center=mp.Vector3(-0.5 * sx + dpml + 0.04 + dsub/2),
    )
]


for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp/2 + (j * 3 * gp),
                #-0.5 * sy + gp/2,
            ),
        )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwa, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + gp + gp/2,
            ),
        )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + 2*gp + gp/2  + (j * 3 * gp),
                #0.5 * sy - gp/2,
            ),
        )
    )

# %%
k_point = mp.Vector3()  # Gamma 點表示週期邊界條件
k_points = [k_point]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
    symmetries=symmetries,
    k_point = mp.Vector3(),
)


# %matplotlib inline
plt.figure(dpi = 125)
sim.plot2D()
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (-0.61,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
t_xx = (.532)
dt = (t_xx / 40)
t = 1000
x_obs = -0.5 * sx + dpml + dsub + gh + 0.002
y_obs_down = -0.5 * sy + gp/2
y_obs_cen = -0.5 * sy + 3*gp/2
y_obs_up = 0.5 * sy - gp/2

print(int((t_xx)/dt))
# Out:
# 40

# %%
# 儲存場量數值的列表
ez_data_cen = []
ez_data_up = []
ez_data_down = []
###
def get_slice(sim):
    ez_data_cen.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_cen) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_up.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_up) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_down.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_down) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))

sim.run(mp.at_every(dt , get_slice) , until = t)

plt.figure(dpi = 100)
sim.plot2D(fields=mp.Ez)
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000794888 s
# Working in 2D dimensions.
# Computational cell is 3.8 x 0.6 x 0 with resolution 500
#      block, center = (-0.61,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
# time for set_epsilon = 0.284423 s
# -----------
# Meep progress: 2.047/1000.0 = 0.2% done in 4.0s, 1950.4s to go
# on time step 2047 (time=2.047), 0.00195448 s/step
# Meep progress: 4.096/1000.0 = 0.4% done in 8.0s, 1945.4s to go
# on time step 4097 (time=4.097), 0.00195223 s/step
# Meep progress: 6.122/1000.0 = 0.6% done in 12.0s, 1948.4s to go
# on time step 6124 (time=6.124), 0.00197407 s/step
# Meep progress: 8.179/1000.0 = 0.8% done in 16.0s, 1940.5s to go
# on time step 8181 (time=8.181), 0.00194468 s/step
# Meep progress: 10.228/1000.0 = 1.0% done in 20.0s, 1935.7s to go
# on time step 10231 (time=10.231), 0.00195224 s/step
# Meep progress: 12.284/1000.0 = 1.2% done in 24.0s, 1930.0s to go
# on time step 12287 (time=12.287), 0.00194553 s/step
# Meep progress: 14.335/1000.0 = 1.4% done in 28.0s, 1925.6s to go
# on time step 14338 (time=14.338), 0.00195042 s/step
# Meep progress: 16.376/1000.0 = 1.6% done in 32.0s, 1922.4s to go
# on time step 16379 (time=16.379), 0.00195996 s/step
# Meep progress: 18.415/1000.0 = 1.8% done in 36.0s, 1919.3s to go
# on time step 18418 (time=18.418), 0.0019621 s/step
# Meep progress: 20.473/1000.0 = 2.0% done in 40.0s, 1914.1s to go
# on time step 20477 (time=20.477), 0.0019435 s/step
# Meep progress: 22.504/1000.0 = 2.3% done in 44.0s, 1911.5s to go
# on time step 22509 (time=22.509), 0.00196907 s/step
# Meep progress: 24.554000000000002/1000.0 = 2.5% done in 48.0s, 1907.2s to go
# on time step 24559 (time=24.559), 0.00195159 s/step
# Meep progress: 26.61/1000.0 = 2.7% done in 52.0s, 1902.5s to go
# on time step 26615 (time=26.615), 0.00194556 s/step
# Meep progress: 28.653000000000002/1000.0 = 2.9% done in 56.0s, 1898.7s to go
# on time step 28658 (time=28.658), 0.00195808 s/step
# Meep progress: 30.668/1000.0 = 3.1% done in 60.0s, 1896.8s to go
# on time step 30674 (time=30.674), 0.00198465 s/step
# Meep progress: 32.723/1000.0 = 3.3% done in 64.0s, 1892.1s to go
# on time step 32730 (time=32.73), 0.00194622 s/step
# Meep progress: 34.761/1000.0 = 3.5% done in 68.0s, 1888.5s to go
# on time step 34768 (time=34.768), 0.00196302 s/step
# Meep progress: 36.821/1000.0 = 3.7% done in 72.0s, 1883.7s to go
# on time step 36829 (time=36.829), 0.00194175 s/step
# Meep progress: 38.878/1000.0 = 3.9% done in 76.0s, 1879.1s to go
# on time step 38887 (time=38.887), 0.00194386 s/step
# Meep progress: 40.93/1000.0 = 4.1% done in 80.0s, 1874.9s to go
# on time step 40939 (time=40.939), 0.00194978 s/step
# Meep progress: 42.998/1000.0 = 4.3% done in 84.0s, 1869.9s to go
# on time step 43007 (time=43.007), 0.00193477 s/step
# Meep progress: 45.043/1000.0 = 4.5% done in 88.0s, 1866.0s to go
# on time step 45052 (time=45.052), 0.00195656 s/step
# Meep progress: 47.098/1000.0 = 4.7% done in 92.0s, 1861.7s to go
# on time step 47107 (time=47.107), 0.00194709 s/step
# Meep progress: 49.163000000000004/1000.0 = 4.9% done in 96.0s, 1857.0s to go
# on time step 49174 (time=49.174), 0.00193561 s/step
# Meep progress: 51.205/1000.0 = 5.1% done in 100.0s, 1853.3s to go
# on time step 51215 (time=51.215), 0.00196006 s/step
# Meep progress: 53.267/1000.0 = 5.3% done in 104.0s, 1848.7s to go
# on time step 53279 (time=53.279), 0.00193872 s/step
# Meep progress: 55.326/1000.0 = 5.5% done in 108.0s, 1844.4s to go
# on time step 55338 (time=55.338), 0.0019431 s/step
# Meep progress: 57.373000000000005/1000.0 = 5.7% done in 112.0s, 1840.5s to go
# on time step 57386 (time=57.386), 0.00195377 s/step
# Meep progress: 59.42/1000.0 = 5.9% done in 116.0s, 1836.5s to go
# on time step 59433 (time=59.433), 0.00195461 s/step
# Meep progress: 61.475/1000.0 = 6.1% done in 120.0s, 1832.3s to go
# on time step 61490 (time=61.49), 0.00194532 s/step
# Meep progress: 63.904/1000.0 = 6.4% done in 124.0s, 1816.7s to go
# on time step 63923 (time=63.923), 0.00164432 s/step
# Meep progress: 66.641/1000.0 = 6.7% done in 128.0s, 1793.0s to go
# on time step 66661 (time=66.661), 0.00146095 s/step
# Meep progress: 69.379/1000.0 = 6.9% done in 132.0s, 1770.9s to go
# on time step 69398 (time=69.398), 0.00146214 s/step
# Meep progress: 72.105/1000.0 = 7.2% done in 136.0s, 1750.4s to go
# on time step 72122 (time=72.122), 0.0014685 s/step
# Meep progress: 74.843/1000.0 = 7.5% done in 140.0s, 1730.9s to go
# on time step 74864 (time=74.864), 0.0014588 s/step
# Meep progress: 77.61/1000.0 = 7.8% done in 144.0s, 1711.7s to go
# on time step 77631 (time=77.631), 0.00144566 s/step
# Meep progress: 80.389/1000.0 = 8.0% done in 148.0s, 1693.3s to go
# on time step 80410 (time=80.41), 0.00143978 s/step
# Meep progress: 83.202/1000.0 = 8.3% done in 152.0s, 1675.2s to go
# on time step 83224 (time=83.224), 0.00142151 s/step
# Meep progress: 85.98100000000001/1000.0 = 8.6% done in 156.0s, 1658.6s to go
# on time step 86000 (time=86), 0.00144123 s/step
# Meep progress: 88.815/1000.0 = 8.9% done in 160.0s, 1641.8s to go
# on time step 88837 (time=88.837), 0.00141043 s/step
# Meep progress: 91.618/1000.0 = 9.2% done in 164.0s, 1626.3s to go
# on time step 91643 (time=91.643), 0.00142552 s/step
# Meep progress: 94.458/1000.0 = 9.4% done in 168.0s, 1610.8s to go
# on time step 94484 (time=94.484), 0.00140821 s/step
# Meep progress: 97.313/1000.0 = 9.7% done in 172.0s, 1595.8s to go
# on time step 97340 (time=97.34), 0.00140064 s/step
# Meep progress: 100.162/1000.0 = 10.0% done in 176.0s, 1581.4s to go
# on time step 100188 (time=100.188), 0.00140463 s/step
# Meep progress: 102.98700000000001/1000.0 = 10.3% done in 180.0s, 1568.1s to go
# on time step 103014 (time=103.014), 0.00141593 s/step
# Meep progress: 105.81700000000001/1000.0 = 10.6% done in 184.0s, 1555.1s to go
# on time step 105844 (time=105.844), 0.00141344 s/step
# Meep progress: 108.653/1000.0 = 10.9% done in 188.0s, 1542.5s to go
# on time step 108682 (time=108.682), 0.00140976 s/step
# Meep progress: 111.49300000000001/1000.0 = 11.1% done in 192.0s, 1530.3s to go
# on time step 111521 (time=111.521), 0.001409 s/step
# Meep progress: 114.342/1000.0 = 11.4% done in 196.0s, 1518.4s to go
# on time step 114368 (time=114.368), 0.00140505 s/step
# Meep progress: 117.197/1000.0 = 11.7% done in 200.0s, 1506.8s to go
# on time step 117226 (time=117.226), 0.00139962 s/step
# Meep progress: 120.042/1000.0 = 12.0% done in 204.0s, 1495.7s to go
# on time step 120069 (time=120.069), 0.00140718 s/step
# Meep progress: 122.82300000000001/1000.0 = 12.3% done in 208.0s, 1485.7s to go
# on time step 122851 (time=122.851), 0.00143847 s/step
# Meep progress: 125.649/1000.0 = 12.6% done in 212.0s, 1475.5s to go
# on time step 125677 (time=125.677), 0.00141572 s/step
# Meep progress: 128.479/1000.0 = 12.8% done in 216.0s, 1465.5s to go
# on time step 128508 (time=128.508), 0.00141297 s/step
# Meep progress: 131.328/1000.0 = 13.1% done in 220.0s, 1455.4s to go
# on time step 131357 (time=131.357), 0.00140401 s/step
# Meep progress: 134.166/1000.0 = 13.4% done in 224.0s, 1445.8s to go
# on time step 134195 (time=134.195), 0.00140955 s/step
# Meep progress: 137.04/1000.0 = 13.7% done in 228.0s, 1436.0s to go
# on time step 137071 (time=137.071), 0.00139113 s/step
# Meep progress: 139.873/1000.0 = 14.0% done in 232.0s, 1426.9s to go
# on time step 139902 (time=139.902), 0.00141333 s/step
# Meep progress: 142.75/1000.0 = 14.3% done in 236.0s, 1417.5s to go
# on time step 142781 (time=142.781), 0.0013896 s/step
# Meep progress: 145.594/1000.0 = 14.6% done in 240.0s, 1408.7s to go
# on time step 145626 (time=145.626), 0.00140661 s/step
# Meep progress: 148.412/1000.0 = 14.8% done in 244.0s, 1400.3s to go
# on time step 148444 (time=148.444), 0.00141968 s/step
# Meep progress: 151.227/1000.0 = 15.1% done in 248.0s, 1392.2s to go
# on time step 151260 (time=151.26), 0.00142073 s/step
# Meep progress: 154.082/1000.0 = 15.4% done in 252.0s, 1383.7s to go
# on time step 154114 (time=154.114), 0.00140208 s/step
# Meep progress: 156.849/1000.0 = 15.7% done in 256.0s, 1376.4s to go
# on time step 156883 (time=156.883), 0.00144493 s/step
# Meep progress: 159.679/1000.0 = 16.0% done in 260.0s, 1368.5s to go
# on time step 159715 (time=159.715), 0.00141252 s/step
# Meep progress: 162.536/1000.0 = 16.3% done in 264.0s, 1360.5s to go
# on time step 162568 (time=162.568), 0.00140214 s/step
# Meep progress: 165.276/1000.0 = 16.5% done in 268.0s, 1353.8s to go
# on time step 165309 (time=165.309), 0.0014594 s/step
# Meep progress: 168.03900000000002/1000.0 = 16.8% done in 272.0s, 1346.9s to go
# on time step 168075 (time=168.075), 0.00144641 s/step
# Meep progress: 170.852/1000.0 = 17.1% done in 276.0s, 1339.7s to go
# on time step 170888 (time=170.888), 0.00142233 s/step
# Meep progress: 173.698/1000.0 = 17.4% done in 280.0s, 1332.2s to go
# on time step 173735 (time=173.735), 0.00140514 s/step
# Meep progress: 176.516/1000.0 = 17.7% done in 284.0s, 1325.1s to go
# on time step 176554 (time=176.554), 0.00141949 s/step
# Meep progress: 179.353/1000.0 = 17.9% done in 288.0s, 1318.0s to go
# on time step 179389 (time=179.389), 0.00141103 s/step
# Meep progress: 182.173/1000.0 = 18.2% done in 292.0s, 1311.1s to go
# on time step 182211 (time=182.211), 0.00141786 s/step
# Meep progress: 185.029/1000.0 = 18.5% done in 296.1s, 1304.0s to go
# on time step 185068 (time=185.068), 0.00140019 s/step
# Meep progress: 187.841/1000.0 = 18.8% done in 300.1s, 1297.3s to go
# on time step 187879 (time=187.879), 0.00142338 s/step
# Meep progress: 190.65800000000002/1000.0 = 19.1% done in 304.1s, 1290.7s to go
# on time step 190694 (time=190.694), 0.00142145 s/step
# Meep progress: 193.52700000000002/1000.0 = 19.4% done in 308.1s, 1283.7s to go
# on time step 193569 (time=193.569), 0.00139159 s/step
# Meep progress: 196.37/1000.0 = 19.6% done in 312.1s, 1277.1s to go
# on time step 196409 (time=196.409), 0.00140881 s/step
# Meep progress: 199.193/1000.0 = 19.9% done in 316.1s, 1270.6s to go
# on time step 199232 (time=199.232), 0.00141732 s/step
# Meep progress: 202.04/1000.0 = 20.2% done in 320.1s, 1264.1s to go
# on time step 202085 (time=202.085), 0.00140231 s/step
# Meep progress: 204.88/1000.0 = 20.5% done in 324.1s, 1257.6s to go
# on time step 204919 (time=204.919), 0.00141154 s/step
# Meep progress: 207.748/1000.0 = 20.8% done in 328.1s, 1251.1s to go
# on time step 207791 (time=207.791), 0.00139314 s/step
# Meep progress: 210.596/1000.0 = 21.1% done in 332.1s, 1244.7s to go
# on time step 210639 (time=210.639), 0.00140452 s/step
# Meep progress: 213.437/1000.0 = 21.3% done in 336.1s, 1238.5s to go
# on time step 213482 (time=213.482), 0.00140732 s/step
# Meep progress: 216.294/1000.0 = 21.6% done in 340.1s, 1232.2s to go
# on time step 216340 (time=216.34), 0.00139979 s/step
# Meep progress: 219.15/1000.0 = 21.9% done in 344.1s, 1225.9s to go
# on time step 219193 (time=219.193), 0.00140209 s/step
# Meep progress: 221.981/1000.0 = 22.2% done in 348.1s, 1219.9s to go
# on time step 222026 (time=222.026), 0.00141212 s/step
# Meep progress: 224.86700000000002/1000.0 = 22.5% done in 352.1s, 1213.6s to go
# on time step 224912 (time=224.912), 0.00138641 s/step
# Meep progress: 227.773/1000.0 = 22.8% done in 356.1s, 1207.2s to go
# on time step 227820 (time=227.82), 0.00137582 s/step
# Meep progress: 230.648/1000.0 = 23.1% done in 360.1s, 1201.0s to go
# on time step 230687 (time=230.687), 0.00139565 s/step
# Meep progress: 233.461/1000.0 = 23.3% done in 364.1s, 1195.4s to go
# on time step 233505 (time=233.505), 0.00141991 s/step
# Meep progress: 236.368/1000.0 = 23.6% done in 368.1s, 1189.1s to go
# on time step 236416 (time=236.416), 0.00137414 s/step
# Meep progress: 239.23000000000002/1000.0 = 23.9% done in 372.1s, 1183.2s to go
# on time step 239275 (time=239.275), 0.00139914 s/step
# Meep progress: 242.08700000000002/1000.0 = 24.2% done in 376.1s, 1177.4s to go
# on time step 242137 (time=242.137), 0.00139798 s/step
# Meep progress: 244.976/1000.0 = 24.5% done in 380.1s, 1171.4s to go
# on time step 245026 (time=245.026), 0.00138483 s/step
# Meep progress: 247.836/1000.0 = 24.8% done in 384.1s, 1165.6s to go
# on time step 247886 (time=247.886), 0.00139868 s/step
# Meep progress: 250.703/1000.0 = 25.1% done in 388.1s, 1159.9s to go
# on time step 250748 (time=250.748), 0.00139763 s/step
# Meep progress: 253.544/1000.0 = 25.4% done in 392.1s, 1154.3s to go
# on time step 253592 (time=253.592), 0.00140647 s/step
# Meep progress: 256.412/1000.0 = 25.6% done in 396.1s, 1148.6s to go
# on time step 256460 (time=256.46), 0.00139479 s/step
# Meep progress: 259.27/1000.0 = 25.9% done in 400.1s, 1143.0s to go
# on time step 259319 (time=259.319), 0.00139934 s/step
# Meep progress: 262.128/1000.0 = 26.2% done in 404.1s, 1137.4s to go
# on time step 262175 (time=262.175), 0.00140092 s/step
# Meep progress: 264.982/1000.0 = 26.5% done in 408.1s, 1131.9s to go
# on time step 265031 (time=265.031), 0.00140089 s/step
# Meep progress: 267.85200000000003/1000.0 = 26.8% done in 412.1s, 1126.4s to go
# on time step 267900 (time=267.9), 0.00139446 s/step
# Meep progress: 270.693/1000.0 = 27.1% done in 416.1s, 1121.0s to go
# on time step 270741 (time=270.741), 0.00140818 s/step
# Meep progress: 273.54/1000.0 = 27.4% done in 420.1s, 1115.6s to go
# on time step 273585 (time=273.585), 0.00140648 s/step
# Meep progress: 276.408/1000.0 = 27.6% done in 424.1s, 1110.2s to go
# on time step 276458 (time=276.458), 0.00139231 s/step
# Meep progress: 279.299/1000.0 = 27.9% done in 428.1s, 1104.6s to go
# on time step 279351 (time=279.351), 0.00138271 s/step
# Meep progress: 282.175/1000.0 = 28.2% done in 432.1s, 1099.2s to go
# on time step 282221 (time=282.221), 0.00139389 s/step
# Meep progress: 285.049/1000.0 = 28.5% done in 436.1s, 1093.8s to go
# on time step 285101 (time=285.101), 0.00138948 s/step
# Meep progress: 287.895/1000.0 = 28.8% done in 440.1s, 1088.5s to go
# on time step 287947 (time=287.947), 0.00140573 s/step
# Meep progress: 290.79200000000003/1000.0 = 29.1% done in 444.1s, 1083.1s to go
# on time step 290846 (time=290.846), 0.00138024 s/step
# Meep progress: 293.69/1000.0 = 29.4% done in 448.1s, 1077.6s to go
# on time step 293741 (time=293.741), 0.00138176 s/step
# Meep progress: 296.526/1000.0 = 29.7% done in 452.1s, 1072.5s to go
# on time step 296582 (time=296.582), 0.00140811 s/step
# Meep progress: 299.426/1000.0 = 29.9% done in 456.1s, 1067.1s to go
# on time step 299479 (time=299.479), 0.00138093 s/step
# Meep progress: 302.3/1000.0 = 30.2% done in 460.1s, 1061.9s to go
# on time step 302355 (time=302.355), 0.00139098 s/step
# Meep progress: 305.154/1000.0 = 30.5% done in 464.1s, 1056.7s to go
# on time step 305211 (time=305.211), 0.00140094 s/step
# Meep progress: 308.028/1000.0 = 30.8% done in 468.1s, 1051.5s to go
# on time step 308084 (time=308.084), 0.00139236 s/step
# Meep progress: 310.849/1000.0 = 31.1% done in 472.1s, 1046.6s to go
# on time step 310896 (time=310.896), 0.00142259 s/step
# Meep progress: 313.716/1000.0 = 31.4% done in 476.1s, 1041.5s to go
# on time step 313772 (time=313.772), 0.00139129 s/step
# Meep progress: 316.61/1000.0 = 31.7% done in 480.1s, 1036.2s to go
# on time step 316669 (time=316.669), 0.00138127 s/step
# Meep progress: 319.348/1000.0 = 31.9% done in 484.1s, 1031.8s to go
# on time step 319402 (time=319.402), 0.0014636 s/step
# Meep progress: 322.132/1000.0 = 32.2% done in 488.1s, 1027.1s to go
# on time step 322192 (time=322.192), 0.00143372 s/step
# Meep progress: 325.01/1000.0 = 32.5% done in 492.1s, 1022.0s to go
# on time step 325067 (time=325.067), 0.00139175 s/step
# Meep progress: 327.889/1000.0 = 32.8% done in 496.1s, 1016.9s to go
# on time step 327951 (time=327.951), 0.0013871 s/step
# Meep progress: 330.613/1000.0 = 33.1% done in 500.1s, 1012.5s to go
# on time step 330666 (time=330.666), 0.00147338 s/step
# Meep progress: 333.466/1000.0 = 33.3% done in 504.1s, 1007.6s to go
# on time step 333525 (time=333.525), 0.00139912 s/step
# Meep progress: 336.273/1000.0 = 33.6% done in 508.1s, 1002.8s to go
# on time step 336330 (time=336.33), 0.00142647 s/step
# Meep progress: 339.002/1000.0 = 33.9% done in 512.1s, 998.5s to go
# on time step 339068 (time=339.068), 0.0014614 s/step
# Meep progress: 341.813/1000.0 = 34.2% done in 516.1s, 993.8s to go
# on time step 341876 (time=341.876), 0.00142462 s/step
# Meep progress: 344.67400000000004/1000.0 = 34.5% done in 520.1s, 988.8s to go
# on time step 344736 (time=344.736), 0.00139861 s/step
# Meep progress: 347.47700000000003/1000.0 = 34.7% done in 524.1s, 984.2s to go
# on time step 347539 (time=347.539), 0.00142736 s/step
# Meep progress: 350.293/1000.0 = 35.0% done in 528.1s, 979.5s to go
# on time step 350360 (time=350.36), 0.00141837 s/step
# Meep progress: 353.116/1000.0 = 35.3% done in 532.1s, 974.8s to go
# on time step 353180 (time=353.18), 0.00141885 s/step
# Meep progress: 355.927/1000.0 = 35.6% done in 536.1s, 970.1s to go
# on time step 355991 (time=355.991), 0.00142337 s/step
# Meep progress: 358.75/1000.0 = 35.9% done in 540.1s, 965.4s to go
# on time step 358800 (time=358.8), 0.00142451 s/step
# Meep progress: 361.572/1000.0 = 36.2% done in 544.1s, 960.7s to go
# on time step 361638 (time=361.638), 0.00140987 s/step
# Meep progress: 364.41200000000003/1000.0 = 36.4% done in 548.1s, 956.0s to go
# on time step 364476 (time=364.476), 0.0014097 s/step
# Meep progress: 367.25/1000.0 = 36.7% done in 552.1s, 951.2s to go
# on time step 367316 (time=367.316), 0.00140859 s/step
# Meep progress: 370.07800000000003/1000.0 = 37.0% done in 556.1s, 946.6s to go
# on time step 370145 (time=370.145), 0.00141433 s/step
# Meep progress: 372.925/1000.0 = 37.3% done in 560.1s, 941.8s to go
# on time step 372995 (time=372.995), 0.00140355 s/step
# Meep progress: 375.765/1000.0 = 37.6% done in 564.1s, 937.1s to go
# on time step 375835 (time=375.835), 0.00140853 s/step
# Meep progress: 378.532/1000.0 = 37.9% done in 568.1s, 932.7s to go
# on time step 378595 (time=378.595), 0.00144972 s/step
# Meep progress: 381.407/1000.0 = 38.1% done in 572.1s, 927.9s to go
# on time step 381478 (time=381.478), 0.00138761 s/step
# Meep progress: 384.225/1000.0 = 38.4% done in 576.1s, 923.3s to go
# on time step 384294 (time=384.294), 0.00142085 s/step
# Meep progress: 387.043/1000.0 = 38.7% done in 580.1s, 918.7s to go
# on time step 387115 (time=387.115), 0.00141803 s/step
# Meep progress: 389.919/1000.0 = 39.0% done in 584.1s, 913.9s to go
# on time step 389990 (time=389.99), 0.00139136 s/step
# Meep progress: 392.738/1000.0 = 39.3% done in 588.1s, 909.3s to go
# on time step 392804 (time=392.804), 0.00142183 s/step
# Meep progress: 395.584/1000.0 = 39.6% done in 592.1s, 904.7s to go
# on time step 395656 (time=395.656), 0.00140272 s/step
# Meep progress: 398.451/1000.0 = 39.8% done in 596.1s, 899.9s to go
# on time step 398521 (time=398.521), 0.00139648 s/step
# Meep progress: 401.237/1000.0 = 40.1% done in 600.1s, 895.5s to go
# on time step 401311 (time=401.311), 0.00143386 s/step
# Meep progress: 404.084/1000.0 = 40.4% done in 604.1s, 890.9s to go
# on time step 404154 (time=404.154), 0.00140746 s/step
# Meep progress: 406.88800000000003/1000.0 = 40.7% done in 608.1s, 886.4s to go
# on time step 406964 (time=406.964), 0.00142351 s/step
# Meep progress: 409.713/1000.0 = 41.0% done in 612.1s, 881.9s to go
# on time step 409786 (time=409.786), 0.00141792 s/step
# Meep progress: 412.487/1000.0 = 41.2% done in 616.1s, 877.5s to go
# on time step 412560 (time=412.56), 0.00144239 s/step
# Meep progress: 415.33/1000.0 = 41.5% done in 620.1s, 872.9s to go
# on time step 415401 (time=415.401), 0.00140831 s/step
# Meep progress: 418.181/1000.0 = 41.8% done in 624.1s, 868.3s to go
# on time step 418251 (time=418.251), 0.00140384 s/step
# Meep progress: 421.023/1000.0 = 42.1% done in 628.1s, 863.8s to go
# on time step 421099 (time=421.099), 0.00140486 s/step
# Meep progress: 423.822/1000.0 = 42.4% done in 632.1s, 859.3s to go
# on time step 423901 (time=423.901), 0.00142761 s/step
# Meep progress: 426.67400000000004/1000.0 = 42.7% done in 636.1s, 854.7s to go
# on time step 426750 (time=426.75), 0.00140401 s/step
# Meep progress: 429.551/1000.0 = 43.0% done in 640.1s, 850.1s to go
# on time step 429625 (time=429.625), 0.00139159 s/step
# Meep progress: 432.38100000000003/1000.0 = 43.2% done in 644.1s, 845.6s to go
# on time step 432462 (time=432.462), 0.00141011 s/step
# Meep progress: 435.228/1000.0 = 43.5% done in 648.1s, 841.0s to go
# on time step 435307 (time=435.307), 0.00140601 s/step
# Meep progress: 438.05400000000003/1000.0 = 43.8% done in 652.1s, 836.5s to go
# on time step 438134 (time=438.134), 0.00141515 s/step
# Meep progress: 440.927/1000.0 = 44.1% done in 656.1s, 831.9s to go
# on time step 441007 (time=441.007), 0.00139232 s/step
# Meep progress: 443.744/1000.0 = 44.4% done in 660.1s, 827.5s to go
# on time step 443816 (time=443.816), 0.00142413 s/step
# Meep progress: 446.53700000000003/1000.0 = 44.7% done in 664.1s, 823.1s to go
# on time step 446613 (time=446.613), 0.0014304 s/step
# Meep progress: 449.362/1000.0 = 44.9% done in 668.1s, 818.7s to go
# on time step 449434 (time=449.434), 0.00141813 s/step
# Meep progress: 452.16200000000003/1000.0 = 45.2% done in 672.1s, 814.3s to go
# on time step 452238 (time=452.238), 0.00142667 s/step
# Meep progress: 454.998/1000.0 = 45.5% done in 676.1s, 809.9s to go
# on time step 455075 (time=455.075), 0.00141035 s/step
# Meep progress: 457.821/1000.0 = 45.8% done in 680.1s, 805.4s to go
# on time step 457903 (time=457.903), 0.00141496 s/step
# Meep progress: 460.682/1000.0 = 46.1% done in 684.1s, 800.9s to go
# on time step 460756 (time=460.756), 0.00140224 s/step
# Meep progress: 463.47200000000004/1000.0 = 46.3% done in 688.1s, 796.6s to go
# on time step 463553 (time=463.553), 0.00143044 s/step
# Meep progress: 466.303/1000.0 = 46.6% done in 692.1s, 792.2s to go
# on time step 466380 (time=466.38), 0.00141496 s/step
# Meep progress: 469.10200000000003/1000.0 = 46.9% done in 696.1s, 787.8s to go
# on time step 469176 (time=469.176), 0.00143117 s/step
# Meep progress: 471.88800000000003/1000.0 = 47.2% done in 700.1s, 783.5s to go
# on time step 471967 (time=471.967), 0.00143355 s/step
# Meep progress: 474.70300000000003/1000.0 = 47.5% done in 704.1s, 779.2s to go
# on time step 474786 (time=474.786), 0.00141935 s/step
# Meep progress: 477.507/1000.0 = 47.8% done in 708.1s, 774.8s to go
# on time step 477590 (time=477.59), 0.00142719 s/step
# Meep progress: 480.331/1000.0 = 48.0% done in 712.1s, 770.4s to go
# on time step 480414 (time=480.414), 0.00141697 s/step
# Meep progress: 483.156/1000.0 = 48.3% done in 716.1s, 766.1s to go
# on time step 483242 (time=483.242), 0.00141458 s/step
# Meep progress: 486.02/1000.0 = 48.6% done in 720.1s, 761.6s to go
# on time step 486107 (time=486.107), 0.00139637 s/step
# Meep progress: 488.85900000000004/1000.0 = 48.9% done in 724.1s, 757.1s to go
# on time step 488946 (time=488.946), 0.00140938 s/step
# Meep progress: 491.713/1000.0 = 49.2% done in 728.1s, 752.7s to go
# on time step 491798 (time=491.798), 0.00140298 s/step
# Meep progress: 494.555/1000.0 = 49.5% done in 732.1s, 748.3s to go
# on time step 494638 (time=494.638), 0.0014087 s/step
# Meep progress: 497.407/1000.0 = 49.7% done in 736.1s, 743.8s to go
# on time step 497497 (time=497.497), 0.00139913 s/step
# Meep progress: 500.241/1000.0 = 50.0% done in 740.1s, 739.4s to go
# on time step 500332 (time=500.332), 0.00141123 s/step
# Meep progress: 503.052/1000.0 = 50.3% done in 744.1s, 735.1s to go
# on time step 503144 (time=503.144), 0.00142258 s/step
# Meep progress: 505.896/1000.0 = 50.6% done in 748.1s, 730.7s to go
# on time step 505986 (time=505.986), 0.00140772 s/step
# Meep progress: 508.731/1000.0 = 50.9% done in 752.1s, 726.3s to go
# on time step 508818 (time=508.818), 0.00141282 s/step
# Meep progress: 511.568/1000.0 = 51.2% done in 756.1s, 721.9s to go
# on time step 511655 (time=511.655), 0.00141002 s/step
# Meep progress: 514.376/1000.0 = 51.4% done in 760.1s, 717.6s to go
# on time step 514466 (time=514.466), 0.00142309 s/step
# Meep progress: 517.231/1000.0 = 51.7% done in 764.1s, 713.2s to go
# on time step 517316 (time=517.316), 0.00140354 s/step
# Meep progress: 520.08/1000.0 = 52.0% done in 768.1s, 708.8s to go
# on time step 520170 (time=520.17), 0.00140175 s/step
# Meep progress: 522.915/1000.0 = 52.3% done in 772.1s, 704.5s to go
# on time step 523007 (time=523.007), 0.00140995 s/step
# Meep progress: 525.746/1000.0 = 52.6% done in 776.1s, 700.1s to go
# on time step 525835 (time=525.835), 0.00141467 s/step
# Meep progress: 528.563/1000.0 = 52.9% done in 780.1s, 695.8s to go
# on time step 528652 (time=528.652), 0.00142011 s/step
# Meep progress: 531.361/1000.0 = 53.1% done in 784.1s, 691.6s to go
# on time step 531454 (time=531.454), 0.00142782 s/step
# Meep progress: 534.1510000000001/1000.0 = 53.4% done in 788.1s, 687.4s to go
# on time step 534241 (time=534.241), 0.00143562 s/step
# Meep progress: 537.004/1000.0 = 53.7% done in 792.1s, 683.0s to go
# on time step 537093 (time=537.093), 0.00140285 s/step
# Meep progress: 539.847/1000.0 = 54.0% done in 796.1s, 678.6s to go
# on time step 539945 (time=539.945), 0.00140272 s/step
# Meep progress: 542.7090000000001/1000.0 = 54.3% done in 800.1s, 674.2s to go
# on time step 542808 (time=542.808), 0.00139747 s/step
# Meep progress: 545.2090000000001/1000.0 = 54.5% done in 804.1s, 670.8s to go
# on time step 545293 (time=545.293), 0.00161012 s/step
# Meep progress: 547.87/1000.0 = 54.8% done in 808.1s, 666.9s to go
# on time step 547969 (time=547.969), 0.00149532 s/step
# Meep progress: 550.672/1000.0 = 55.1% done in 812.1s, 662.7s to go
# on time step 550771 (time=550.771), 0.00142809 s/step
# Meep progress: 553.551/1000.0 = 55.4% done in 816.1s, 658.2s to go
# on time step 553644 (time=553.644), 0.00139272 s/step
# Meep progress: 556.351/1000.0 = 55.6% done in 820.1s, 654.0s to go
# on time step 556448 (time=556.448), 0.00142685 s/step
# Meep progress: 559.191/1000.0 = 55.9% done in 824.1s, 649.7s to go
# on time step 559290 (time=559.29), 0.00140786 s/step
# Meep progress: 562.016/1000.0 = 56.2% done in 828.1s, 645.4s to go
# on time step 562114 (time=562.114), 0.00141684 s/step
# Meep progress: 564.8100000000001/1000.0 = 56.5% done in 832.1s, 641.2s to go
# on time step 564911 (time=564.911), 0.00143028 s/step
# Meep progress: 567.564/1000.0 = 56.8% done in 836.1s, 637.1s to go
# on time step 567665 (time=567.665), 0.00145248 s/step
# Meep progress: 570.371/1000.0 = 57.0% done in 840.1s, 632.8s to go
# on time step 570471 (time=570.471), 0.00142609 s/step
# Meep progress: 573.208/1000.0 = 57.3% done in 844.1s, 628.5s to go
# on time step 573312 (time=573.312), 0.00140827 s/step
# Meep progress: 576.043/1000.0 = 57.6% done in 848.1s, 624.2s to go
# on time step 576139 (time=576.139), 0.00141502 s/step
# Meep progress: 578.884/1000.0 = 57.9% done in 852.2s, 619.9s to go
# on time step 578984 (time=578.984), 0.00140614 s/step
# Meep progress: 581.777/1000.0 = 58.2% done in 856.2s, 615.5s to go
# on time step 581877 (time=581.877), 0.00138299 s/step
# Meep progress: 584.635/1000.0 = 58.5% done in 860.2s, 611.1s to go
# on time step 584740 (time=584.74), 0.00139732 s/step
# Meep progress: 587.439/1000.0 = 58.7% done in 864.2s, 606.9s to go
# on time step 587538 (time=587.538), 0.0014297 s/step
# Meep progress: 590.279/1000.0 = 59.0% done in 868.2s, 602.6s to go
# on time step 590385 (time=590.385), 0.00140526 s/step
# Meep progress: 593.128/1000.0 = 59.3% done in 872.2s, 598.3s to go
# on time step 593233 (time=593.233), 0.00140489 s/step
# Meep progress: 595.926/1000.0 = 59.6% done in 876.2s, 594.1s to go
# on time step 596028 (time=596.028), 0.00143137 s/step
# Meep progress: 598.729/1000.0 = 59.9% done in 880.2s, 589.9s to go
# on time step 598836 (time=598.836), 0.00142452 s/step
# Meep progress: 601.5360000000001/1000.0 = 60.2% done in 884.2s, 585.7s to go
# on time step 601643 (time=601.643), 0.00142506 s/step
# Meep progress: 604.343/1000.0 = 60.4% done in 888.2s, 581.5s to go
# on time step 604450 (time=604.45), 0.00142558 s/step
# Meep progress: 607.16/1000.0 = 60.7% done in 892.2s, 577.2s to go
# on time step 607268 (time=607.268), 0.0014197 s/step
# Meep progress: 609.968/1000.0 = 61.0% done in 896.2s, 573.0s to go
# on time step 610076 (time=610.076), 0.00142472 s/step
# Meep progress: 612.7860000000001/1000.0 = 61.3% done in 900.2s, 568.8s to go
# on time step 612885 (time=612.885), 0.00142416 s/step
# Meep progress: 615.613/1000.0 = 61.6% done in 904.2s, 564.6s to go
# on time step 615717 (time=615.717), 0.00141269 s/step
# Meep progress: 618.439/1000.0 = 61.8% done in 908.2s, 560.3s to go
# on time step 618552 (time=618.552), 0.00141103 s/step
# Meep progress: 621.282/1000.0 = 62.1% done in 912.2s, 556.0s to go
# on time step 621387 (time=621.387), 0.0014113 s/step
# Meep progress: 624.064/1000.0 = 62.4% done in 916.2s, 551.9s to go
# on time step 624178 (time=624.178), 0.00143335 s/step
# Meep progress: 626.913/1000.0 = 62.7% done in 920.2s, 547.6s to go
# on time step 627024 (time=627.024), 0.00140583 s/step
# Meep progress: 629.729/1000.0 = 63.0% done in 924.2s, 543.4s to go
# on time step 629834 (time=629.834), 0.00142384 s/step
# Meep progress: 632.604/1000.0 = 63.3% done in 928.2s, 539.0s to go
# on time step 632711 (time=632.711), 0.00139064 s/step
# Meep progress: 635.4010000000001/1000.0 = 63.5% done in 932.2s, 534.9s to go
# on time step 635505 (time=635.505), 0.00143175 s/step
# Meep progress: 638.225/1000.0 = 63.8% done in 936.2s, 530.7s to go
# on time step 638336 (time=638.336), 0.00141311 s/step
# Meep progress: 641.0120000000001/1000.0 = 64.1% done in 940.2s, 526.5s to go
# on time step 641126 (time=641.126), 0.00143387 s/step
# Meep progress: 643.862/1000.0 = 64.4% done in 944.2s, 522.2s to go
# on time step 643969 (time=643.969), 0.00140709 s/step
# Meep progress: 646.712/1000.0 = 64.7% done in 948.2s, 518.0s to go
# on time step 646820 (time=646.82), 0.00140359 s/step
# Meep progress: 649.575/1000.0 = 65.0% done in 952.2s, 513.7s to go
# on time step 649690 (time=649.69), 0.00139391 s/step
# Meep progress: 652.393/1000.0 = 65.2% done in 956.2s, 509.5s to go
# on time step 652502 (time=652.502), 0.00142261 s/step
# Meep progress: 655.245/1000.0 = 65.5% done in 960.2s, 505.2s to go
# on time step 655357 (time=655.357), 0.00140108 s/step
# Meep progress: 658.0980000000001/1000.0 = 65.8% done in 964.2s, 500.9s to go
# on time step 658214 (time=658.214), 0.00140016 s/step
# Meep progress: 660.967/1000.0 = 66.1% done in 968.2s, 496.6s to go
# on time step 661082 (time=661.082), 0.00139514 s/step
# Meep progress: 663.828/1000.0 = 66.4% done in 972.2s, 492.3s to go
# on time step 663938 (time=663.938), 0.00140067 s/step
# Meep progress: 666.67/1000.0 = 66.7% done in 976.2s, 488.1s to go
# on time step 666781 (time=666.781), 0.00140738 s/step
# Meep progress: 669.496/1000.0 = 66.9% done in 980.2s, 483.9s to go
# on time step 669612 (time=669.612), 0.00141323 s/step
# Meep progress: 672.332/1000.0 = 67.2% done in 984.2s, 479.6s to go
# on time step 672443 (time=672.443), 0.00141322 s/step
# Meep progress: 675.189/1000.0 = 67.5% done in 988.2s, 475.4s to go
# on time step 675301 (time=675.301), 0.00139969 s/step
# Meep progress: 678.016/1000.0 = 67.8% done in 992.2s, 471.2s to go
# on time step 678127 (time=678.127), 0.00141581 s/step
# Meep progress: 680.886/1000.0 = 68.1% done in 996.2s, 466.9s to go
# on time step 680999 (time=680.999), 0.00139294 s/step
# Meep progress: 683.691/1000.0 = 68.4% done in 1000.2s, 462.7s to go
# on time step 683806 (time=683.806), 0.00142535 s/step
# Meep progress: 686.563/1000.0 = 68.7% done in 1004.2s, 458.4s to go
# on time step 686682 (time=686.682), 0.00139099 s/step
# Meep progress: 689.403/1000.0 = 68.9% done in 1008.2s, 454.2s to go
# on time step 689522 (time=689.522), 0.00140846 s/step
# Meep progress: 692.227/1000.0 = 69.2% done in 1012.2s, 450.0s to go
# on time step 692341 (time=692.341), 0.00141966 s/step
# Meep progress: 695.047/1000.0 = 69.5% done in 1016.2s, 445.9s to go
# on time step 695165 (time=695.165), 0.0014167 s/step
# Meep progress: 697.931/1000.0 = 69.8% done in 1020.2s, 441.5s to go
# on time step 698041 (time=698.041), 0.00139085 s/step
# Meep progress: 700.738/1000.0 = 70.1% done in 1024.2s, 437.4s to go
# on time step 700852 (time=700.852), 0.00142313 s/step
# Meep progress: 703.553/1000.0 = 70.4% done in 1028.2s, 433.2s to go
# on time step 703662 (time=703.662), 0.0014235 s/step
# Meep progress: 706.352/1000.0 = 70.6% done in 1032.2s, 429.1s to go
# on time step 706474 (time=706.474), 0.00142263 s/step
# Meep progress: 709.226/1000.0 = 70.9% done in 1036.2s, 424.8s to go
# on time step 709339 (time=709.339), 0.00139625 s/step
# Meep progress: 712.059/1000.0 = 71.2% done in 1040.2s, 420.6s to go
# on time step 712175 (time=712.175), 0.00141047 s/step
# Meep progress: 714.871/1000.0 = 71.5% done in 1044.2s, 416.5s to go
# on time step 714983 (time=714.983), 0.00142451 s/step
# Meep progress: 717.724/1000.0 = 71.8% done in 1048.2s, 412.2s to go
# on time step 717844 (time=717.844), 0.00139831 s/step
# Meep progress: 720.5600000000001/1000.0 = 72.1% done in 1052.2s, 408.0s to go
# on time step 720676 (time=720.676), 0.00141266 s/step
# Meep progress: 723.349/1000.0 = 72.3% done in 1056.2s, 403.9s to go
# on time step 723466 (time=723.466), 0.00143385 s/step
# Meep progress: 726.15/1000.0 = 72.6% done in 1060.2s, 399.8s to go
# on time step 726267 (time=726.267), 0.00142829 s/step
# Meep progress: 728.9010000000001/1000.0 = 72.9% done in 1064.2s, 395.8s to go
# on time step 729021 (time=729.021), 0.00145284 s/step
# Meep progress: 731.681/1000.0 = 73.2% done in 1068.2s, 391.7s to go
# on time step 731801 (time=731.801), 0.00143908 s/step
# Meep progress: 734.479/1000.0 = 73.4% done in 1072.2s, 387.6s to go
# on time step 734589 (time=734.589), 0.00143496 s/step
# Meep progress: 737.162/1000.0 = 73.7% done in 1076.2s, 383.7s to go
# on time step 737282 (time=737.282), 0.0014855 s/step
# Meep progress: 739.909/1000.0 = 74.0% done in 1080.2s, 379.7s to go
# on time step 740011 (time=740.011), 0.00146609 s/step
# Meep progress: 742.607/1000.0 = 74.3% done in 1084.2s, 375.8s to go
# on time step 742725 (time=742.725), 0.00147406 s/step
# Meep progress: 745.4250000000001/1000.0 = 74.5% done in 1088.2s, 371.6s to go
# on time step 745543 (time=745.543), 0.00141958 s/step
# Meep progress: 748.268/1000.0 = 74.8% done in 1092.2s, 367.4s to go
# on time step 748391 (time=748.391), 0.00140478 s/step
# Meep progress: 751.105/1000.0 = 75.1% done in 1096.2s, 363.2s to go
# on time step 751229 (time=751.229), 0.00140964 s/step
# Meep progress: 753.936/1000.0 = 75.4% done in 1100.2s, 359.1s to go
# on time step 754060 (time=754.06), 0.00141301 s/step
# Meep progress: 756.778/1000.0 = 75.7% done in 1104.2s, 354.9s to go
# on time step 756899 (time=756.899), 0.00140944 s/step
# Meep progress: 759.642/1000.0 = 76.0% done in 1108.2s, 350.6s to go
# on time step 759764 (time=759.764), 0.00139657 s/step
# Meep progress: 762.427/1000.0 = 76.2% done in 1112.2s, 346.6s to go
# on time step 762551 (time=762.551), 0.0014356 s/step
# Meep progress: 765.277/1000.0 = 76.5% done in 1116.2s, 342.4s to go
# on time step 765397 (time=765.397), 0.0014055 s/step
# Meep progress: 768.1320000000001/1000.0 = 76.8% done in 1120.2s, 338.1s to go
# on time step 768257 (time=768.257), 0.0013988 s/step
# Meep progress: 770.97/1000.0 = 77.1% done in 1124.2s, 334.0s to go
# on time step 771093 (time=771.093), 0.00141104 s/step
# Meep progress: 773.7810000000001/1000.0 = 77.4% done in 1128.2s, 329.8s to go
# on time step 773904 (time=773.904), 0.00142335 s/step
# Meep progress: 776.634/1000.0 = 77.7% done in 1132.2s, 325.6s to go
# on time step 776755 (time=776.755), 0.00140328 s/step
# Meep progress: 779.4780000000001/1000.0 = 77.9% done in 1136.2s, 321.4s to go
# on time step 779599 (time=779.599), 0.00140677 s/step
# Meep progress: 782.303/1000.0 = 78.2% done in 1140.2s, 317.3s to go
# on time step 782428 (time=782.428), 0.00141403 s/step
# Meep progress: 785.139/1000.0 = 78.5% done in 1144.2s, 313.1s to go
# on time step 785266 (time=785.266), 0.00140988 s/step
# Meep progress: 787.936/1000.0 = 78.8% done in 1148.2s, 309.0s to go
# on time step 788063 (time=788.063), 0.00143023 s/step
# Meep progress: 790.784/1000.0 = 79.1% done in 1152.2s, 304.8s to go
# on time step 790910 (time=790.91), 0.00140525 s/step
# Meep progress: 793.583/1000.0 = 79.4% done in 1156.2s, 300.7s to go
# on time step 793714 (time=793.714), 0.0014266 s/step
# Meep progress: 796.434/1000.0 = 79.6% done in 1160.2s, 296.5s to go
# on time step 796556 (time=796.556), 0.00140784 s/step
# Meep progress: 799.26/1000.0 = 79.9% done in 1164.2s, 292.4s to go
# on time step 799387 (time=799.387), 0.00141346 s/step
# Meep progress: 802.078/1000.0 = 80.2% done in 1168.2s, 288.3s to go
# on time step 802209 (time=802.209), 0.00141793 s/step
# Meep progress: 804.846/1000.0 = 80.5% done in 1172.2s, 284.2s to go
# on time step 804973 (time=804.973), 0.00144752 s/step
# Meep progress: 807.643/1000.0 = 80.8% done in 1176.2s, 280.1s to go
# on time step 807771 (time=807.771), 0.0014296 s/step
# Meep progress: 810.4780000000001/1000.0 = 81.0% done in 1180.2s, 276.0s to go
# on time step 810608 (time=810.608), 0.00141002 s/step
# Meep progress: 813.296/1000.0 = 81.3% done in 1184.2s, 271.9s to go
# on time step 813424 (time=813.424), 0.00142077 s/step
# Meep progress: 816.124/1000.0 = 81.6% done in 1188.2s, 267.7s to go
# on time step 816257 (time=816.257), 0.00141258 s/step
# Meep progress: 818.977/1000.0 = 81.9% done in 1192.2s, 263.5s to go
# on time step 819110 (time=819.11), 0.00140214 s/step
# Meep progress: 821.797/1000.0 = 82.2% done in 1196.2s, 259.4s to go
# on time step 821931 (time=821.931), 0.00141848 s/step
# Meep progress: 824.6370000000001/1000.0 = 82.5% done in 1200.2s, 255.2s to go
# on time step 824770 (time=824.77), 0.00140907 s/step
# Meep progress: 827.469/1000.0 = 82.7% done in 1204.2s, 251.1s to go
# on time step 827607 (time=827.607), 0.00141043 s/step
# Meep progress: 830.3190000000001/1000.0 = 83.0% done in 1208.2s, 246.9s to go
# on time step 830452 (time=830.452), 0.00140618 s/step
# Meep progress: 833.142/1000.0 = 83.3% done in 1212.2s, 242.8s to go
# on time step 833278 (time=833.278), 0.00141591 s/step
# Meep progress: 835.969/1000.0 = 83.6% done in 1216.2s, 238.6s to go
# on time step 836109 (time=836.109), 0.00141295 s/step
# Meep progress: 838.8340000000001/1000.0 = 83.9% done in 1220.2s, 234.4s to go
# on time step 838970 (time=838.97), 0.0013983 s/step
# Meep progress: 841.679/1000.0 = 84.2% done in 1224.2s, 230.3s to go
# on time step 841810 (time=841.81), 0.00140866 s/step
# Meep progress: 844.528/1000.0 = 84.5% done in 1228.2s, 226.1s to go
# on time step 844662 (time=844.662), 0.00140284 s/step
# Meep progress: 847.33/1000.0 = 84.7% done in 1232.2s, 222.0s to go
# on time step 847468 (time=847.468), 0.00142558 s/step
# Meep progress: 850.179/1000.0 = 85.0% done in 1236.2s, 217.9s to go
# on time step 850314 (time=850.314), 0.00140561 s/step
# Meep progress: 852.961/1000.0 = 85.3% done in 1240.2s, 213.8s to go
# on time step 853103 (time=853.103), 0.00143453 s/step
# Meep progress: 855.799/1000.0 = 85.6% done in 1244.2s, 209.7s to go
# on time step 855933 (time=855.933), 0.00141394 s/step
# Meep progress: 858.629/1000.0 = 85.9% done in 1248.2s, 205.5s to go
# on time step 858771 (time=858.771), 0.00140977 s/step
# Meep progress: 861.445/1000.0 = 86.1% done in 1252.2s, 201.4s to go
# on time step 861587 (time=861.587), 0.00142079 s/step
# Meep progress: 864.278/1000.0 = 86.4% done in 1256.2s, 197.3s to go
# on time step 864412 (time=864.412), 0.00141615 s/step
# Meep progress: 867.105/1000.0 = 86.7% done in 1260.2s, 193.1s to go
# on time step 867238 (time=867.238), 0.00141561 s/step
# Meep progress: 869.904/1000.0 = 87.0% done in 1264.2s, 189.1s to go
# on time step 870043 (time=870.043), 0.00142633 s/step
# Meep progress: 872.726/1000.0 = 87.3% done in 1268.2s, 185.0s to go
# on time step 872865 (time=872.865), 0.00141786 s/step
# Meep progress: 875.562/1000.0 = 87.6% done in 1272.2s, 180.8s to go
# on time step 875698 (time=875.698), 0.00141225 s/step
# Meep progress: 878.378/1000.0 = 87.8% done in 1276.2s, 176.7s to go
# on time step 878522 (time=878.522), 0.00141675 s/step
# Meep progress: 881.217/1000.0 = 88.1% done in 1280.2s, 172.6s to go
# on time step 881355 (time=881.355), 0.00141223 s/step
# Meep progress: 884.071/1000.0 = 88.4% done in 1284.2s, 168.4s to go
# on time step 884207 (time=884.207), 0.0014028 s/step
# Meep progress: 886.907/1000.0 = 88.7% done in 1288.2s, 164.3s to go
# on time step 887046 (time=887.046), 0.00140929 s/step
# Meep progress: 889.726/1000.0 = 89.0% done in 1292.2s, 160.2s to go
# on time step 889861 (time=889.861), 0.00142107 s/step
# Meep progress: 892.537/1000.0 = 89.3% done in 1296.2s, 156.1s to go
# on time step 892680 (time=892.68), 0.001419 s/step
# Meep progress: 895.375/1000.0 = 89.5% done in 1300.2s, 151.9s to go
# on time step 895509 (time=895.509), 0.00141436 s/step
# Meep progress: 898.184/1000.0 = 89.8% done in 1304.2s, 147.8s to go
# on time step 898325 (time=898.325), 0.00142079 s/step
# Meep progress: 901.009/1000.0 = 90.1% done in 1308.2s, 143.7s to go
# on time step 901152 (time=901.152), 0.00141501 s/step
# Meep progress: 903.862/1000.0 = 90.4% done in 1312.2s, 139.6s to go
# on time step 904003 (time=904.003), 0.00140339 s/step
# Meep progress: 906.691/1000.0 = 90.7% done in 1316.2s, 135.5s to go
# on time step 906829 (time=906.829), 0.00141586 s/step
# Meep progress: 909.506/1000.0 = 91.0% done in 1320.2s, 131.4s to go
# on time step 909649 (time=909.649), 0.00141855 s/step
# Meep progress: 912.346/1000.0 = 91.2% done in 1324.2s, 127.2s to go
# on time step 912494 (time=912.494), 0.00140638 s/step
# Meep progress: 915.187/1000.0 = 91.5% done in 1328.2s, 123.1s to go
# on time step 915332 (time=915.332), 0.00140956 s/step
# Meep progress: 918.025/1000.0 = 91.8% done in 1332.2s, 119.0s to go
# on time step 918151 (time=918.151), 0.001419 s/step
# Meep progress: 920.798/1000.0 = 92.1% done in 1336.3s, 114.9s to go
# on time step 920943 (time=920.943), 0.00143313 s/step
# Meep progress: 923.62/1000.0 = 92.4% done in 1340.3s, 110.8s to go
# on time step 923765 (time=923.765), 0.00141785 s/step
# Meep progress: 926.48/1000.0 = 92.6% done in 1344.3s, 106.7s to go
# on time step 926619 (time=926.619), 0.00140159 s/step
# Meep progress: 929.29/1000.0 = 92.9% done in 1348.3s, 102.6s to go
# on time step 929443 (time=929.443), 0.00141673 s/step
# Meep progress: 932.1370000000001/1000.0 = 93.2% done in 1352.3s, 98.4s to go
# on time step 932284 (time=932.284), 0.00140815 s/step
# Meep progress: 934.9680000000001/1000.0 = 93.5% done in 1356.3s, 94.3s to go
# on time step 935113 (time=935.113), 0.00141435 s/step
# Meep progress: 937.793/1000.0 = 93.8% done in 1360.3s, 90.2s to go
# on time step 937941 (time=937.941), 0.00141445 s/step
# Meep progress: 940.614/1000.0 = 94.1% done in 1364.3s, 86.1s to go
# on time step 940759 (time=940.759), 0.0014197 s/step
# Meep progress: 943.441/1000.0 = 94.3% done in 1368.3s, 82.0s to go
# on time step 943590 (time=943.59), 0.00141326 s/step
# Meep progress: 946.2660000000001/1000.0 = 94.6% done in 1372.3s, 77.9s to go
# on time step 946404 (time=946.404), 0.00142176 s/step
# Meep progress: 949.077/1000.0 = 94.9% done in 1376.3s, 73.8s to go
# on time step 949219 (time=949.219), 0.00142156 s/step
# Meep progress: 951.863/1000.0 = 95.2% done in 1380.3s, 69.8s to go
# on time step 952011 (time=952.011), 0.00143283 s/step
# Meep progress: 954.716/1000.0 = 95.5% done in 1384.3s, 65.7s to go
# on time step 954867 (time=954.867), 0.00140106 s/step
# Meep progress: 957.381/1000.0 = 95.7% done in 1388.3s, 61.8s to go
# on time step 957520 (time=957.52), 0.00150798 s/step
# Meep progress: 960.148/1000.0 = 96.0% done in 1392.3s, 57.8s to go
# on time step 960294 (time=960.294), 0.00144207 s/step
# Meep progress: 963.004/1000.0 = 96.3% done in 1396.3s, 53.6s to go
# on time step 963157 (time=963.157), 0.00139795 s/step
# Meep progress: 965.8340000000001/1000.0 = 96.6% done in 1400.3s, 49.5s to go
# on time step 965986 (time=965.986), 0.00141417 s/step
# Meep progress: 968.6610000000001/1000.0 = 96.9% done in 1404.3s, 45.4s to go
# on time step 968814 (time=968.814), 0.00141492 s/step
# Meep progress: 971.5/1000.0 = 97.2% done in 1408.3s, 41.3s to go
# on time step 971656 (time=971.656), 0.00140794 s/step
# Meep progress: 974.294/1000.0 = 97.4% done in 1412.3s, 37.3s to go
# on time step 974446 (time=974.446), 0.00143398 s/step
# Meep progress: 977.115/1000.0 = 97.7% done in 1416.3s, 33.2s to go
# on time step 977264 (time=977.264), 0.00141993 s/step
# Meep progress: 979.934/1000.0 = 98.0% done in 1420.3s, 29.1s to go
# on time step 980078 (time=980.078), 0.0014217 s/step
# Meep progress: 982.744/1000.0 = 98.3% done in 1424.3s, 25.0s to go
# on time step 982902 (time=982.902), 0.00141694 s/step
# Meep progress: 985.568/1000.0 = 98.6% done in 1428.3s, 20.9s to go
# on time step 985725 (time=985.725), 0.00141703 s/step
# Meep progress: 988.405/1000.0 = 98.8% done in 1432.3s, 16.8s to go
# on time step 988560 (time=988.56), 0.00141235 s/step
# Meep progress: 991.225/1000.0 = 99.1% done in 1436.3s, 12.7s to go
# on time step 991382 (time=991.382), 0.00141775 s/step
# Meep progress: 994.073/1000.0 = 99.4% done in 1440.3s, 8.6s to go
# on time step 994228 (time=994.228), 0.00140599 s/step
# Meep progress: 996.885/1000.0 = 99.7% done in 1444.3s, 4.5s to go
# on time step 997052 (time=997.052), 0.00141671 s/step
# Meep progress: 999.682/1000.0 = 100.0% done in 1448.3s, 0.5s to go
# on time step 999834 (time=999.834), 0.00143816 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 1000.0 (1000000 timesteps)
#      block, center = (-0.61,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
ez_data_up = np.array(ez_data_up)
ez_data_cen = np.array(ez_data_cen)
ez_data_down = np.array(ez_data_down)


print(len(ez_data_cen))

print(1 + int(round(t_xx/dt)))
# Out:
# 76923
# 41

# %%
ez_data_cen = np.array(ez_data_cen)
ez_data_up = np.array(ez_data_up)
ez_data_down = np.array(ez_data_down)

#plt.subplot_adjust(hspace = .35)
plt.figure(dpi = 200)
start = round(len(ez_data_cen) / t *1)

for i in range(start,len(ez_data_cen),1):
    plt.subplot(3,1,1)
    plt.plot(i,ez_data_up[i],'k.')
    plt.subplot(3,1,2)
    plt.plot(i,ez_data_cen[i],'k.')
    plt.subplot(3,1,3)
    plt.plot(i,ez_data_down[i],'k.')
    if i ==  (len(ez_data_cen)-1):
        plt.subplot(3,1,1)
        plt.title('upper point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_up[i],'b .')
        plt.subplot(3,1,2)
        plt.title('center point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_cen[i],'b .')
        plt.subplot(3,1,3)
        plt.title('downer point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_down[i],'b .')

# %%
# index1 and index2 . When we find the target's Electric field amplitude, we want to know where is amplitude value in array. So we set up index variable before running simulation.
index1_up = 0
index1_cen = 0
index1_down = 0

index2_up = 0
index2_cen = 0
index2_down = 0
# Period_max , period_next_mat . I set up those variables because I plan to use variables to store max amplitude value in a peiod in the following simulation. 
period_max_up = 0
period_max_cen = 0
period_max_down = 0
period_next_max_up = 0
period_next_max_cen = 0
period_next_max_down = 0

# Intial_index , end_index. ==>  "for loop" index
initial_index = round(len(ez_data_cen) / t * 200 )
print(initial_index)
end_index = len(ez_data_cen) - 2*( 1 +int(round(t_xx/dt))) 
print(end_index)

for i in range(initial_index , end_index):
    plt.plot(ez_data_cen[i])

# %%
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_up[j])
        period_next.append(ez_data_up[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1 = np.where(ez_data_up == period_max)
        print(index1, '--- upper point index1')
        index2 = np.where(ez_data_up == period_next_max)
        print(index2, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('upper point 到達誤差範圍內的所需 meep time unit' , 23287 / len(ez_data_up) * 500 , '\n')
        print('-----------------------------------------------------')
        break

        
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_cen[j])
        period_next.append(ez_data_cen[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1 = np.where(ez_data_cen == period_max)
        print(index1, '--- upper point index1')
        index2 = np.where(ez_data_cen == period_next_max)
        print(index2, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t')
        print('center point 到達誤差範圍內的所需 meep time unit' , 73397 / len(ez_data_cen) * 500 , '\n')
        print('-----------------------------------------------------')
        break
        
    
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_down[j])
        period_next.append(ez_data_down[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- down point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- down point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1 = np.where(ez_data_down == period_max)
        print(index1, '--- down point index1')
        index2 = np.where(ez_data_down == period_next_max)
        print(index2, '--- down point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('down point 到達誤差範圍內的所需 meep time unit' , 18749 / len(ez_data_down) * 500 , '\n')
        print('-----------------------------------------------------')
        break


dt_ = str(dt)

# %%
plt.figure(dpi = 150)
plt.title('Upper point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_up[73320]
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_up[i] , 'b.')
    if max_value < ez_data_up[i] :
        max_value = ez_data_up[i]
        
print(max_value)

# %%
plt.figure(dpi = 150)
plt.title('center point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_cen[73320]
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_cen[i] , 'b.')
    if max_value < ez_data_cen[i] :
        max_value = ez_data_cen[i]

print(max_value)

# %%
plt.figure(dpi = 150)
plt.title('downner point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_down[i] , 'b.')
