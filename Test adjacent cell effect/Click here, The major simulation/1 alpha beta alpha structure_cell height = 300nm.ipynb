# %%
import meep as mp
import numpy as np
import math
import matplotlib.pyplot as plt

resolution = 500  # pixels/μm

dpml = 1.0  # PML thickness
dsub = 0.5  # substrate thickness
dcaa = 0.06  # air rigion for alpha structure
# alpha structure is that one period = 200nm，sigle cell width = 80nm locate at center
dcab = 0.025 # air rigion for beta structure 
# beta structure is that one period = 200nm，sigle cell width = 150nm locate at center
gp = 0.2  # grating periodicity
gh = 0.3  # grating height
gwa = 0.08 # alpha grating cell width
gwb = 0.15 # beta grating cell width

num_cells = 3  # number of grating unit cells

# air region thickness adjacent to grating
dair = 1

wvl = 0.532  # center wavelength
fcen = 1 / wvl  # center frequency


glass = mp.Medium(index= 2.6678)

pml_layers = [mp.PML(thickness=dpml, direction = mp.X )]

symmetries = [mp.Mirror(mp.Y)]

sx = dpml + dsub + gh + dair + dpml # Whole Enviroment size _ x direction
sy = num_cells*gp  # # Whole Enviroment size _ y direction
cell_size = mp.Vector3(sx, sy)

sources = [
    mp.Source(
        mp.ContinuousSource(frequency = fcen), # frequemcy = 2原因是 meep 的 C=1，所以 1/? = 0.5 um，?即是2
        component = mp.Ez,
        center = mp.Vector3(-0.5 * sx + dpml ), # Souce cetenr location
        size = mp.Vector3(y=sy),
    )
]

geometry = [
    mp.Block(
        material=glass,
        size=mp.Vector3(dsub, mp.inf, mp.inf),
        center=mp.Vector3(-0.5 * sx + dpml + 0.04 + dsub/2),
    )
]


for j in range(num_cells):
    geometry.append(
    mp.Block(
        material=glass,
        size=mp.Vector3(gh, gwa, mp.inf),
        center=mp.Vector3(
            -0.5 * sx + dpml + dsub + 0.5 * gh,
            -0.5 * sy + gp/2 + (j * 3 * gp),
            #-0.5 * sy + gp/2,
        ),
    )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + gp/2 + gp  , 
            ),
        )
    )

for j in range(num_cells):
    geometry.append(
    mp.Block(
        material=glass,
        size=mp.Vector3(gh, gwa, mp.inf),
        center=mp.Vector3(
            -0.5 * sx + dpml + dsub + 0.5 * gh,
            -0.5 * sy + 2*gp + gp/2  + (j * 3 * gp),
            #-0.5 * sy  + gp/2 + 2*gp ,
        ),
    )
    )

k_point = mp.Vector3()  # Gamma 點表示週期邊界條件
k_points = [k_point]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
    k_point = mp.Vector3(),
)

# %matplotlib inline
plt.figure(dpi = 125)
sim.plot2D()
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (-0.61,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
t_xx = (.532) # Air 光速跑完 波長 532 nm 入射光 所需的 meep unit time
dt = (t_xx / 40) # cut 40 sections in a period time
t = 1000 # Total simulation time

x_obs = -0.5 * sx + dpml + dsub + gh + 0.002 # Set up a x coordinate of observed point
# The meaning of down , cen , up are the cordinate in each cell structure. (Reference stucture diagram just show above)
y_obs_down = -0.5 * sy + gp/2
y_obs_cen = 0
y_obs_up = 0.5 * sy - gp/2

print(int((t_xx)/dt))
# Out:
# 40

# %%
# 儲存場量數值的列表
ez_data_cen = []
ez_data_up = []
ez_data_down = []
###
def get_slice(sim):
    ez_data_cen.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_cen) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_up.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_up) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_down.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_down) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))

sim.run(mp.at_every(dt , get_slice) , until = t)

plt.figure(dpi = 100)
sim.plot2D(fields=mp.Ez)
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000183105 s
# Working in 2D dimensions.
# Computational cell is 3.8 x 0.6 x 0 with resolution 500
#      block, center = (-0.61,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
# time for set_epsilon = 0.535122 s
# -----------
# Meep progress: 1.09/1000.0 = 0.1% done in 4.0s, 3668.9s to go
# on time step 1090 (time=1.09), 0.00367302 s/step
# Meep progress: 2.005/1000.0 = 0.2% done in 8.0s, 3984.8s to go
# on time step 2005 (time=2.005), 0.00437309 s/step
# Meep progress: 2.986/1000.0 = 0.3% done in 12.0s, 4008.7s to go
# on time step 2987 (time=2.987), 0.00407714 s/step
# Meep progress: 4.059/1000.0 = 0.4% done in 16.0s, 3928.0s to go
# on time step 4060 (time=4.06), 0.00373015 s/step
# Meep progress: 5.168/1000.0 = 0.5% done in 20.0s, 3852.1s to go
# on time step 5169 (time=5.169), 0.00360709 s/step
# Meep progress: 6.229/1000.0 = 0.6% done in 24.0s, 3831.0s to go
# on time step 6230 (time=6.23), 0.0037719 s/step
# Meep progress: 7.293/1000.0 = 0.7% done in 28.0s, 3813.2s to go
# on time step 7295 (time=7.295), 0.00375897 s/step
# Meep progress: 8.335/1000.0 = 0.8% done in 32.0s, 3809.0s to go
# on time step 8337 (time=8.337), 0.00384188 s/step
# Meep progress: 9.413/1000.0 = 0.9% done in 36.0s, 3790.3s to go
# on time step 9416 (time=9.416), 0.00371007 s/step
# Meep progress: 10.52/1000.0 = 1.1% done in 40.0s, 3764.0s to go
# on time step 10523 (time=10.523), 0.00361441 s/step
# Meep progress: 11.643/1000.0 = 1.2% done in 44.0s, 3736.7s to go
# on time step 11647 (time=11.647), 0.00356156 s/step
# Meep progress: 12.736/1000.0 = 1.3% done in 48.0s, 3722.5s to go
# on time step 12740 (time=12.74), 0.00366255 s/step
# Meep progress: 13.846/1000.0 = 1.4% done in 52.0s, 3705.2s to go
# on time step 13851 (time=13.851), 0.00360337 s/step
# Meep progress: 14.964/1000.0 = 1.5% done in 56.0s, 3688.1s to go
# on time step 14968 (time=14.968), 0.00358348 s/step
# Meep progress: 16.081/1000.0 = 1.6% done in 60.0s, 3673.0s to go
# on time step 16085 (time=16.085), 0.00358208 s/step
# Meep progress: 17.213/1000.0 = 1.7% done in 64.0s, 3656.0s to go
# on time step 17218 (time=17.218), 0.00353294 s/step
# Meep progress: 18.342/1000.0 = 1.8% done in 68.0s, 3641.2s to go
# on time step 18347 (time=18.347), 0.0035434 s/step
# Meep progress: 19.474/1000.0 = 1.9% done in 72.0s, 3627.0s to go
# on time step 19479 (time=19.479), 0.00353637 s/step
# Meep progress: 20.580000000000002/1000.0 = 2.1% done in 76.0s, 3618.8s to go
# on time step 20585 (time=20.585), 0.00361733 s/step
# Meep progress: 21.709/1000.0 = 2.2% done in 80.0s, 3606.9s to go
# on time step 21714 (time=21.714), 0.0035431 s/step
# Meep progress: 22.847/1000.0 = 2.3% done in 84.0s, 3594.4s to go
# on time step 22852 (time=22.852), 0.00351551 s/step
# Meep progress: 23.988/1000.0 = 2.4% done in 88.0s, 3582.2s to go
# on time step 23994 (time=23.994), 0.00350649 s/step
# Meep progress: 25.13/1000.0 = 2.5% done in 92.0s, 3570.6s to go
# on time step 25137 (time=25.137), 0.00350192 s/step
# Meep progress: 26.273/1000.0 = 2.6% done in 96.0s, 3559.6s to go
# on time step 26280 (time=26.28), 0.00350087 s/step
# Meep progress: 27.417/1000.0 = 2.7% done in 100.0s, 3549.0s to go
# on time step 27424 (time=27.424), 0.00349744 s/step
# Meep progress: 28.542/1000.0 = 2.9% done in 104.0s, 3541.3s to go
# on time step 28550 (time=28.55), 0.00355404 s/step
# Meep progress: 29.685000000000002/1000.0 = 3.0% done in 108.0s, 3531.8s to go
# on time step 29692 (time=29.692), 0.00350393 s/step
# Meep progress: 30.815/1000.0 = 3.1% done in 112.0s, 3524.1s to go
# on time step 30823 (time=30.823), 0.00353929 s/step
# Meep progress: 31.946/1000.0 = 3.2% done in 116.1s, 3516.7s to go
# on time step 31954 (time=31.954), 0.00353766 s/step
# Meep progress: 33.003/1000.0 = 3.3% done in 120.1s, 3517.6s to go
# on time step 33011 (time=33.011), 0.00378651 s/step
# Meep progress: 34.07/1000.0 = 3.4% done in 124.1s, 3517.1s to go
# on time step 34078 (time=34.078), 0.00374981 s/step
# Meep progress: 35.155/1000.0 = 3.5% done in 128.1s, 3514.6s to go
# on time step 35164 (time=35.164), 0.00368505 s/step
# Meep progress: 36.295/1000.0 = 3.6% done in 132.1s, 3506.4s to go
# on time step 36304 (time=36.304), 0.00351056 s/step
# Meep progress: 37.44/1000.0 = 3.7% done in 136.1s, 3498.1s to go
# on time step 37449 (time=37.449), 0.00349483 s/step
# Meep progress: 38.588/1000.0 = 3.9% done in 140.1s, 3489.7s to go
# on time step 38597 (time=38.597), 0.00348721 s/step
# Meep progress: 39.727000000000004/1000.0 = 4.0% done in 144.1s, 3482.3s to go
# on time step 39736 (time=39.736), 0.00351368 s/step
# Meep progress: 40.875/1000.0 = 4.1% done in 148.1s, 3474.4s to go
# on time step 40885 (time=40.885), 0.00348323 s/step
# Meep progress: 42.022/1000.0 = 4.2% done in 152.1s, 3466.7s to go
# on time step 42032 (time=42.032), 0.00348796 s/step
# Meep progress: 43.163000000000004/1000.0 = 4.3% done in 156.1s, 3459.8s to go
# on time step 43172 (time=43.172), 0.00350939 s/step
# Meep progress: 44.287/1000.0 = 4.4% done in 160.1s, 3454.4s to go
# on time step 44296 (time=44.296), 0.00356009 s/step
# Meep progress: 45.428000000000004/1000.0 = 4.5% done in 164.1s, 3447.7s to go
# on time step 45437 (time=45.437), 0.00350674 s/step
# Meep progress: 46.574/1000.0 = 4.7% done in 168.1s, 3440.8s to go
# on time step 46582 (time=46.582), 0.00349385 s/step
# Meep progress: 47.715/1000.0 = 4.8% done in 172.1s, 3434.4s to go
# on time step 47723 (time=47.723), 0.00350636 s/step
# Meep progress: 48.862/1000.0 = 4.9% done in 176.1s, 3427.6s to go
# on time step 48871 (time=48.871), 0.0034848 s/step
# Meep progress: 50.005/1000.0 = 5.0% done in 180.1s, 3421.3s to go
# on time step 50013 (time=50.013), 0.00350299 s/step
# Meep progress: 51.151/1000.0 = 5.1% done in 184.1s, 3414.8s to go
# on time step 51160 (time=51.16), 0.00348963 s/step
# Meep progress: 52.305/1000.0 = 5.2% done in 188.1s, 3407.9s to go
# on time step 52314 (time=52.314), 0.00346706 s/step
# Meep progress: 53.456/1000.0 = 5.3% done in 192.1s, 3401.3s to go
# on time step 53465 (time=53.465), 0.00347581 s/step
# Meep progress: 54.615/1000.0 = 5.5% done in 196.1s, 3394.3s to go
# on time step 54624 (time=54.624), 0.00345225 s/step
# Meep progress: 55.773/1000.0 = 5.6% done in 200.1s, 3387.5s to go
# on time step 55783 (time=55.783), 0.00345349 s/step
# Meep progress: 56.924/1000.0 = 5.7% done in 204.1s, 3381.3s to go
# on time step 56934 (time=56.934), 0.00347776 s/step
# Meep progress: 58.088/1000.0 = 5.8% done in 208.1s, 3374.3s to go
# on time step 58099 (time=58.099), 0.0034348 s/step
# Meep progress: 59.252/1000.0 = 5.9% done in 212.1s, 3367.5s to go
# on time step 59262 (time=59.262), 0.00343974 s/step
# Meep progress: 60.407000000000004/1000.0 = 6.0% done in 216.1s, 3361.2s to go
# on time step 60418 (time=60.418), 0.0034624 s/step
# Meep progress: 61.569/1000.0 = 6.2% done in 220.1s, 3354.7s to go
# on time step 61580 (time=61.58), 0.00344284 s/step
# Meep progress: 62.735/1000.0 = 6.3% done in 224.1s, 3348.1s to go
# on time step 62746 (time=62.746), 0.00343204 s/step
# Meep progress: 63.907000000000004/1000.0 = 6.4% done in 228.1s, 3341.2s to go
# on time step 63918 (time=63.918), 0.00341373 s/step
# Meep progress: 65.065/1000.0 = 6.5% done in 232.1s, 3335.2s to go
# on time step 65076 (time=65.076), 0.00345688 s/step
# Meep progress: 66.221/1000.0 = 6.6% done in 236.1s, 3329.3s to go
# on time step 66233 (time=66.233), 0.00345958 s/step
# Meep progress: 67.363/1000.0 = 6.7% done in 240.1s, 3324.2s to go
# on time step 67375 (time=67.375), 0.00350316 s/step
# Meep progress: 68.519/1000.0 = 6.9% done in 244.1s, 3318.5s to go
# on time step 68532 (time=68.532), 0.00345844 s/step
# Meep progress: 69.684/1000.0 = 7.0% done in 248.1s, 3312.4s to go
# on time step 69697 (time=69.697), 0.00343586 s/step
# Meep progress: 70.84400000000001/1000.0 = 7.1% done in 252.1s, 3306.6s to go
# on time step 70857 (time=70.857), 0.00344931 s/step
# Meep progress: 72.015/1000.0 = 7.2% done in 256.1s, 3300.3s to go
# on time step 72027 (time=72.027), 0.00341942 s/step
# Meep progress: 73.177/1000.0 = 7.3% done in 260.1s, 3294.5s to go
# on time step 73189 (time=73.189), 0.00344261 s/step
# Meep progress: 74.328/1000.0 = 7.4% done in 264.1s, 3289.3s to go
# on time step 74340 (time=74.34), 0.0034777 s/step
# Meep progress: 75.49/1000.0 = 7.5% done in 268.1s, 3283.6s to go
# on time step 75503 (time=75.503), 0.00343998 s/step
# Meep progress: 76.652/1000.0 = 7.7% done in 272.1s, 3277.9s to go
# on time step 76665 (time=76.665), 0.00344288 s/step
# Meep progress: 77.808/1000.0 = 7.8% done in 276.1s, 3272.6s to go
# on time step 77820 (time=77.82), 0.00346616 s/step
# Meep progress: 78.981/1000.0 = 7.9% done in 280.1s, 3266.6s to go
# on time step 78995 (time=78.995), 0.00340549 s/step
# Meep progress: 80.147/1000.0 = 8.0% done in 284.1s, 3260.9s to go
# on time step 80161 (time=80.161), 0.00343226 s/step
# Meep progress: 81.309/1000.0 = 8.1% done in 288.1s, 3255.5s to go
# on time step 81324 (time=81.324), 0.00344133 s/step
# Meep progress: 82.47200000000001/1000.0 = 8.2% done in 292.1s, 3250.0s to go
# on time step 82486 (time=82.486), 0.00344308 s/step
# Meep progress: 83.633/1000.0 = 8.4% done in 296.1s, 3244.7s to go
# on time step 83648 (time=83.648), 0.00344386 s/step
# Meep progress: 84.797/1000.0 = 8.5% done in 300.1s, 3239.3s to go
# on time step 84811 (time=84.811), 0.00344178 s/step
# Meep progress: 85.959/1000.0 = 8.6% done in 304.1s, 3234.0s to go
# on time step 85973 (time=85.973), 0.00344294 s/step
# Meep progress: 87.116/1000.0 = 8.7% done in 308.1s, 3228.9s to go
# on time step 87130 (time=87.13), 0.00345855 s/step
# Meep progress: 88.265/1000.0 = 8.8% done in 312.1s, 3224.2s to go
# on time step 88279 (time=88.279), 0.0034821 s/step
# Meep progress: 89.434/1000.0 = 8.9% done in 316.1s, 3218.8s to go
# on time step 89448 (time=89.448), 0.00342187 s/step
# Meep progress: 90.602/1000.0 = 9.1% done in 320.1s, 3213.3s to go
# on time step 90616 (time=90.616), 0.00342617 s/step
# Meep progress: 91.752/1000.0 = 9.2% done in 324.1s, 3208.7s to go
# on time step 91767 (time=91.767), 0.00347755 s/step
# Meep progress: 92.916/1000.0 = 9.3% done in 328.1s, 3203.5s to go
# on time step 92930 (time=92.93), 0.0034408 s/step
# Meep progress: 94.075/1000.0 = 9.4% done in 332.1s, 3198.5s to go
# on time step 94090 (time=94.09), 0.00345006 s/step
# Meep progress: 95.244/1000.0 = 9.5% done in 336.1s, 3193.2s to go
# on time step 95260 (time=95.26), 0.00342206 s/step
# Meep progress: 96.407/1000.0 = 9.6% done in 340.1s, 3188.1s to go
# on time step 96423 (time=96.423), 0.00344152 s/step
# Meep progress: 97.572/1000.0 = 9.8% done in 344.2s, 3183.0s to go
# on time step 97589 (time=97.589), 0.00343329 s/step
# Meep progress: 98.73700000000001/1000.0 = 9.9% done in 348.2s, 3177.9s to go
# on time step 98753 (time=98.753), 0.00343664 s/step
# Meep progress: 99.849/1000.0 = 10.0% done in 352.2s, 3174.7s to go
# on time step 99862 (time=99.862), 0.00360995 s/step
# Meep progress: 100.899/1000.0 = 10.1% done in 356.2s, 3173.7s to go
# on time step 100914 (time=100.914), 0.00380536 s/step
# Meep progress: 102.003/1000.0 = 10.2% done in 360.2s, 3170.7s to go
# on time step 102020 (time=102.02), 0.00361722 s/step
# Meep progress: 103.06400000000001/1000.0 = 10.3% done in 364.2s, 3169.2s to go
# on time step 103081 (time=103.081), 0.00377151 s/step
# Meep progress: 104.196/1000.0 = 10.4% done in 368.2s, 3165.2s to go
# on time step 104213 (time=104.213), 0.00353639 s/step
# Meep progress: 105.357/1000.0 = 10.5% done in 372.2s, 3160.3s to go
# on time step 105375 (time=105.375), 0.00344333 s/step
# Meep progress: 106.522/1000.0 = 10.7% done in 376.2s, 3155.2s to go
# on time step 106540 (time=106.54), 0.0034347 s/step
# Meep progress: 107.643/1000.0 = 10.8% done in 380.2s, 3151.6s to go
# on time step 107660 (time=107.66), 0.00357443 s/step
# Meep progress: 108.635/1000.0 = 10.9% done in 384.2s, 3152.2s to go
# on time step 108651 (time=108.651), 0.00403687 s/step
# Meep progress: 109.667/1000.0 = 11.0% done in 388.2s, 3151.4s to go
# on time step 109683 (time=109.683), 0.00387783 s/step
# Meep progress: 110.726/1000.0 = 11.1% done in 392.2s, 3149.6s to go
# on time step 110746 (time=110.746), 0.00376316 s/step
# Meep progress: 111.858/1000.0 = 11.2% done in 396.2s, 3145.6s to go
# on time step 111877 (time=111.877), 0.00353997 s/step
# Meep progress: 112.858/1000.0 = 11.3% done in 400.2s, 3145.7s to go
# on time step 112872 (time=112.872), 0.00402036 s/step
# Meep progress: 113.86/1000.0 = 11.4% done in 404.2s, 3145.6s to go
# on time step 113875 (time=113.875), 0.00399298 s/step
# Meep progress: 114.81/1000.0 = 11.5% done in 408.2s, 3147.1s to go
# on time step 114826 (time=114.826), 0.00420913 s/step
# Meep progress: 115.82600000000001/1000.0 = 11.6% done in 412.2s, 3146.5s to go
# on time step 115842 (time=115.842), 0.00394038 s/step
# Meep progress: 116.95/1000.0 = 11.7% done in 416.2s, 3142.5s to go
# on time step 116972 (time=116.972), 0.00354331 s/step
# Meep progress: 118.08800000000001/1000.0 = 11.8% done in 420.2s, 3138.1s to go
# on time step 118110 (time=118.11), 0.00351628 s/step
# Meep progress: 119.21000000000001/1000.0 = 11.9% done in 424.2s, 3134.1s to go
# on time step 119230 (time=119.23), 0.00357563 s/step
# Meep progress: 120.321/1000.0 = 12.0% done in 428.2s, 3130.5s to go
# on time step 120343 (time=120.343), 0.00359463 s/step
# Meep progress: 121.446/1000.0 = 12.1% done in 432.2s, 3126.5s to go
# on time step 121469 (time=121.469), 0.00355532 s/step
# Meep progress: 122.501/1000.0 = 12.3% done in 436.2s, 3124.5s to go
# on time step 122525 (time=122.525), 0.00378945 s/step
# Meep progress: 123.636/1000.0 = 12.4% done in 440.2s, 3120.2s to go
# on time step 123660 (time=123.66), 0.0035262 s/step
# Meep progress: 124.693/1000.0 = 12.5% done in 444.2s, 3118.1s to go
# on time step 124716 (time=124.716), 0.0037898 s/step
# Meep progress: 125.70100000000001/1000.0 = 12.6% done in 448.2s, 3117.4s to go
# on time step 125727 (time=125.727), 0.00395915 s/step
# Meep progress: 126.629/1000.0 = 12.7% done in 452.2s, 3118.9s to go
# on time step 126649 (time=126.649), 0.00434168 s/step
# Meep progress: 127.727/1000.0 = 12.8% done in 456.2s, 3115.5s to go
# on time step 127754 (time=127.754), 0.00362289 s/step
# Meep progress: 128.782/1000.0 = 12.9% done in 460.2s, 3113.3s to go
# on time step 128807 (time=128.807), 0.00380036 s/step
# Meep progress: 129.849/1000.0 = 13.0% done in 464.2s, 3110.8s to go
# on time step 129872 (time=129.872), 0.00375745 s/step
# Meep progress: 130.961/1000.0 = 13.1% done in 468.2s, 3107.0s to go
# on time step 130988 (time=130.988), 0.00358609 s/step
# Meep progress: 132.056/1000.0 = 13.2% done in 472.2s, 3103.6s to go
# on time step 132080 (time=132.08), 0.00366643 s/step
# Meep progress: 133.155/1000.0 = 13.3% done in 476.2s, 3100.2s to go
# on time step 133181 (time=133.181), 0.00363324 s/step
# Meep progress: 134.274/1000.0 = 13.4% done in 480.2s, 3096.2s to go
# on time step 134300 (time=134.3), 0.00357771 s/step
# Meep progress: 135.332/1000.0 = 13.5% done in 484.2s, 3093.8s to go
# on time step 135357 (time=135.357), 0.0037848 s/step
# Meep progress: 136.405/1000.0 = 13.6% done in 488.2s, 3091.0s to go
# on time step 136430 (time=136.43), 0.00372822 s/step
# Meep progress: 137.488/1000.0 = 13.7% done in 492.2s, 3087.9s to go
# on time step 137513 (time=137.513), 0.00369672 s/step
# Meep progress: 138.564/1000.0 = 13.9% done in 496.2s, 3085.0s to go
# on time step 138592 (time=138.592), 0.00370795 s/step
# Meep progress: 139.675/1000.0 = 14.0% done in 500.2s, 3081.1s to go
# on time step 139703 (time=139.703), 0.00360279 s/step
# Meep progress: 140.79500000000002/1000.0 = 14.1% done in 504.2s, 3077.0s to go
# on time step 140823 (time=140.823), 0.00357184 s/step
# Meep progress: 141.936/1000.0 = 14.2% done in 508.2s, 3072.4s to go
# on time step 141966 (time=141.966), 0.00350081 s/step
# Meep progress: 143.056/1000.0 = 14.3% done in 512.2s, 3068.4s to go
# on time step 143083 (time=143.083), 0.00358183 s/step
# Meep progress: 144.113/1000.0 = 14.4% done in 516.2s, 3065.9s to go
# on time step 144140 (time=144.14), 0.00378616 s/step
# Meep progress: 145.27100000000002/1000.0 = 14.5% done in 520.2s, 3060.9s to go
# on time step 145301 (time=145.301), 0.00344745 s/step
# Meep progress: 146.427/1000.0 = 14.6% done in 524.2s, 3055.9s to go
# on time step 146456 (time=146.456), 0.0034649 s/step
# Meep progress: 147.584/1000.0 = 14.8% done in 528.2s, 3051.0s to go
# on time step 147616 (time=147.616), 0.00345009 s/step
# Meep progress: 148.67600000000002/1000.0 = 14.9% done in 532.2s, 3047.6s to go
# on time step 148698 (time=148.698), 0.00369783 s/step
# Meep progress: 149.746/1000.0 = 15.0% done in 536.2s, 3044.7s to go
# on time step 149771 (time=149.771), 0.00372914 s/step
# Meep progress: 150.844/1000.0 = 15.1% done in 540.2s, 3041.2s to go
# on time step 150864 (time=150.864), 0.0036643 s/step
# Meep progress: 151.948/1000.0 = 15.2% done in 544.2s, 3037.5s to go
# on time step 151980 (time=151.98), 0.00358549 s/step
# Meep progress: 153.089/1000.0 = 15.3% done in 548.2s, 3033.0s to go
# on time step 153121 (time=153.121), 0.00350741 s/step
# Meep progress: 154.18800000000002/1000.0 = 15.4% done in 552.2s, 3029.4s to go
# on time step 154220 (time=154.22), 0.0036397 s/step
# Meep progress: 155.328/1000.0 = 15.5% done in 556.2s, 3024.9s to go
# on time step 155359 (time=155.359), 0.00351315 s/step
# Meep progress: 156.489/1000.0 = 15.6% done in 560.2s, 3019.9s to go
# on time step 156520 (time=156.52), 0.00344739 s/step
# Meep progress: 157.642/1000.0 = 15.8% done in 564.2s, 3015.1s to go
# on time step 157674 (time=157.674), 0.00346663 s/step
# Meep progress: 158.796/1000.0 = 15.9% done in 568.2s, 3010.2s to go
# on time step 158827 (time=158.827), 0.00346939 s/step
# Meep progress: 159.879/1000.0 = 16.0% done in 572.3s, 3007.0s to go
# on time step 159903 (time=159.903), 0.0037176 s/step
# Meep progress: 160.963/1000.0 = 16.1% done in 576.3s, 3003.8s to go
# on time step 160993 (time=160.993), 0.00367156 s/step
# Meep progress: 162.066/1000.0 = 16.2% done in 580.3s, 3000.1s to go
# on time step 162098 (time=162.098), 0.00362101 s/step
# Meep progress: 163.217/1000.0 = 16.3% done in 584.3s, 2995.4s to go
# on time step 163248 (time=163.248), 0.00347851 s/step
# Meep progress: 164.357/1000.0 = 16.4% done in 588.3s, 2990.9s to go
# on time step 164389 (time=164.389), 0.00350837 s/step
# Meep progress: 165.494/1000.0 = 16.5% done in 592.3s, 2986.5s to go
# on time step 165528 (time=165.528), 0.0035142 s/step
# Meep progress: 166.599/1000.0 = 16.7% done in 596.3s, 2982.8s to go
# on time step 166629 (time=166.629), 0.00363374 s/step
# Meep progress: 167.711/1000.0 = 16.8% done in 600.3s, 2978.9s to go
# on time step 167744 (time=167.744), 0.0035892 s/step
# Meep progress: 168.828/1000.0 = 16.9% done in 604.3s, 2974.9s to go
# on time step 168862 (time=168.862), 0.00358079 s/step
# Meep progress: 169.966/1000.0 = 17.0% done in 608.3s, 2970.5s to go
# on time step 169999 (time=169.999), 0.00352163 s/step
# Meep progress: 171.077/1000.0 = 17.1% done in 612.3s, 2966.6s to go
# on time step 171110 (time=171.11), 0.00360125 s/step
# Meep progress: 172.072/1000.0 = 17.2% done in 616.3s, 2965.2s to go
# on time step 172100 (time=172.1), 0.00404144 s/step
# Meep progress: 173.102/1000.0 = 17.3% done in 620.3s, 2963.0s to go
# on time step 173129 (time=173.129), 0.00388934 s/step
# Meep progress: 174.19400000000002/1000.0 = 17.4% done in 624.3s, 2959.5s to go
# on time step 174228 (time=174.228), 0.00364018 s/step
# Meep progress: 175.321/1000.0 = 17.5% done in 628.3s, 2955.3s to go
# on time step 175357 (time=175.357), 0.00354555 s/step
# Meep progress: 176.445/1000.0 = 17.6% done in 632.3s, 2951.2s to go
# on time step 176479 (time=176.479), 0.00356517 s/step
# Meep progress: 177.571/1000.0 = 17.8% done in 636.3s, 2947.0s to go
# on time step 177604 (time=177.604), 0.00355726 s/step
# Meep progress: 178.736/1000.0 = 17.9% done in 640.3s, 2942.0s to go
# on time step 178769 (time=178.769), 0.00343358 s/step
# Meep progress: 179.892/1000.0 = 18.0% done in 644.3s, 2937.2s to go
# on time step 179925 (time=179.925), 0.00346065 s/step
# Meep progress: 180.829/1000.0 = 18.1% done in 648.3s, 2936.8s to go
# on time step 180854 (time=180.854), 0.00430685 s/step
# Meep progress: 181.77/1000.0 = 18.2% done in 652.3s, 2936.2s to go
# on time step 181804 (time=181.804), 0.00421219 s/step
# Meep progress: 182.895/1000.0 = 18.3% done in 656.3s, 2932.0s to go
# on time step 182929 (time=182.929), 0.00355562 s/step
# Meep progress: 184.024/1000.0 = 18.4% done in 660.3s, 2927.8s to go
# on time step 184058 (time=184.058), 0.00354298 s/step
# Meep progress: 185.159/1000.0 = 18.5% done in 664.3s, 2923.4s to go
# on time step 185191 (time=185.191), 0.00353318 s/step
# Meep progress: 186.238/1000.0 = 18.6% done in 668.3s, 2920.1s to go
# on time step 186271 (time=186.271), 0.00370497 s/step
# Meep progress: 187.348/1000.0 = 18.7% done in 672.3s, 2916.2s to go
# on time step 187385 (time=187.385), 0.00359372 s/step
# Meep progress: 188.477/1000.0 = 18.8% done in 676.3s, 2911.9s to go
# on time step 188511 (time=188.511), 0.00355262 s/step
# Meep progress: 189.58700000000002/1000.0 = 19.0% done in 680.3s, 2908.0s to go
# on time step 189620 (time=189.62), 0.00360766 s/step
# Meep progress: 190.532/1000.0 = 19.1% done in 684.3s, 2907.2s to go
# on time step 190567 (time=190.567), 0.00422457 s/step
# Meep progress: 191.68800000000002/1000.0 = 19.2% done in 688.3s, 2902.4s to go
# on time step 191723 (time=191.723), 0.00346271 s/step
# Meep progress: 192.748/1000.0 = 19.3% done in 692.3s, 2899.5s to go
# on time step 192782 (time=192.782), 0.0037783 s/step
# Meep progress: 193.83700000000002/1000.0 = 19.4% done in 696.3s, 2895.9s to go
# on time step 193870 (time=193.87), 0.00367664 s/step
# Meep progress: 194.898/1000.0 = 19.5% done in 700.3s, 2892.9s to go
# on time step 194931 (time=194.931), 0.00377162 s/step
# Meep progress: 195.904/1000.0 = 19.6% done in 704.3s, 2890.9s to go
# on time step 195928 (time=195.928), 0.0040131 s/step
# Meep progress: 196.963/1000.0 = 19.7% done in 708.3s, 2887.9s to go
# on time step 196993 (time=196.993), 0.00375815 s/step
# Meep progress: 197.998/1000.0 = 19.8% done in 712.3s, 2885.3s to go
# on time step 198032 (time=198.032), 0.00384988 s/step
# Meep progress: 199.145/1000.0 = 19.9% done in 716.3s, 2880.6s to go
# on time step 199180 (time=199.18), 0.00348814 s/step
# Meep progress: 200.285/1000.0 = 20.0% done in 720.3s, 2876.1s to go
# on time step 200323 (time=200.323), 0.00350235 s/step
# Meep progress: 201.419/1000.0 = 20.1% done in 724.3s, 2871.8s to go
# on time step 201454 (time=201.454), 0.00353886 s/step
# Meep progress: 202.523/1000.0 = 20.3% done in 728.3s, 2867.9s to go
# on time step 202556 (time=202.556), 0.00363168 s/step
# Meep progress: 203.58100000000002/1000.0 = 20.4% done in 732.3s, 2864.9s to go
# on time step 203607 (time=203.607), 0.00380908 s/step
# Meep progress: 204.699/1000.0 = 20.5% done in 736.3s, 2860.8s to go
# on time step 204734 (time=204.734), 0.00355054 s/step
# Meep progress: 205.83/1000.0 = 20.6% done in 740.3s, 2856.5s to go
# on time step 205867 (time=205.867), 0.00353126 s/step
# Meep progress: 206.99/1000.0 = 20.7% done in 744.3s, 2851.6s to go
# on time step 207027 (time=207.027), 0.00344907 s/step
# Meep progress: 208.047/1000.0 = 20.8% done in 748.3s, 2848.6s to go
# on time step 208076 (time=208.076), 0.00381704 s/step
# Meep progress: 208.998/1000.0 = 20.9% done in 752.3s, 2847.4s to go
# on time step 209031 (time=209.031), 0.00418962 s/step
# Meep progress: 209.921/1000.0 = 21.0% done in 756.3s, 2846.6s to go
# on time step 209958 (time=209.958), 0.00431519 s/step
# Meep progress: 211.006/1000.0 = 21.1% done in 760.3s, 2843.1s to go
# on time step 211037 (time=211.037), 0.00371173 s/step
# Meep progress: 212.016/1000.0 = 21.2% done in 764.3s, 2840.8s to go
# on time step 212045 (time=212.045), 0.00397061 s/step
# Meep progress: 212.91/1000.0 = 21.3% done in 768.3s, 2840.4s to go
# on time step 212948 (time=212.948), 0.00442993 s/step
# Meep progress: 214.024/1000.0 = 21.4% done in 772.3s, 2836.3s to go
# on time step 214056 (time=214.056), 0.00361215 s/step
# Meep progress: 215.016/1000.0 = 21.5% done in 776.3s, 2834.3s to go
# on time step 215044 (time=215.044), 0.0040509 s/step
# Meep progress: 215.92600000000002/1000.0 = 21.6% done in 780.4s, 2833.6s to go
# on time step 215957 (time=215.957), 0.00438197 s/step
# Meep progress: 216.982/1000.0 = 21.7% done in 784.4s, 2830.5s to go
# on time step 217018 (time=217.018), 0.00377089 s/step
# Meep progress: 217.889/1000.0 = 21.8% done in 788.4s, 2829.8s to go
# on time step 217915 (time=217.915), 0.00446393 s/step
# Meep progress: 218.656/1000.0 = 21.9% done in 792.4s, 2831.4s to go
# on time step 218678 (time=218.678), 0.00524461 s/step
# Meep progress: 219.46200000000002/1000.0 = 21.9% done in 796.4s, 2832.3s to go
# on time step 219490 (time=219.49), 0.00492685 s/step
# Meep progress: 220.257/1000.0 = 22.0% done in 800.4s, 2833.4s to go
# on time step 220278 (time=220.278), 0.00507621 s/step
# Meep progress: 220.881/1000.0 = 22.1% done in 804.4s, 2837.3s to go
# on time step 220901 (time=220.901), 0.00642434 s/step
# Meep progress: 221.483/1000.0 = 22.1% done in 808.4s, 2841.5s to go
# on time step 221504 (time=221.504), 0.00663846 s/step
# Meep progress: 222.109/1000.0 = 22.2% done in 812.4s, 2845.2s to go
# on time step 222126 (time=222.126), 0.00643441 s/step
# Meep progress: 222.65800000000002/1000.0 = 22.3% done in 816.4s, 2850.2s to go
# on time step 222678 (time=222.678), 0.00725405 s/step
# Meep progress: 223.293/1000.0 = 22.3% done in 820.4s, 2853.7s to go
# on time step 223314 (time=223.314), 0.00629902 s/step
# Meep progress: 223.93800000000002/1000.0 = 22.4% done in 824.4s, 2856.9s to go
# on time step 223958 (time=223.958), 0.0062126 s/step
# Meep progress: 224.546/1000.0 = 22.5% done in 828.4s, 2860.8s to go
# on time step 224566 (time=224.566), 0.00658833 s/step
# Meep progress: 225.163/1000.0 = 22.5% done in 832.4s, 2864.5s to go
# on time step 225184 (time=225.184), 0.00648091 s/step
# Meep progress: 225.782/1000.0 = 22.6% done in 836.4s, 2868.0s to go
# on time step 225804 (time=225.804), 0.00645555 s/step
# Meep progress: 226.42000000000002/1000.0 = 22.6% done in 840.4s, 2871.3s to go
# on time step 226442 (time=226.442), 0.00628057 s/step
# Meep progress: 227.062/1000.0 = 22.7% done in 844.4s, 2874.4s to go
# on time step 227085 (time=227.085), 0.00622623 s/step
# Meep progress: 227.703/1000.0 = 22.8% done in 848.4s, 2877.5s to go
# on time step 227726 (time=227.726), 0.00624683 s/step
# Meep progress: 228.34/1000.0 = 22.8% done in 852.4s, 2880.6s to go
# on time step 228363 (time=228.363), 0.00628247 s/step
# Meep progress: 228.98000000000002/1000.0 = 22.9% done in 856.4s, 2883.7s to go
# on time step 229004 (time=229.004), 0.00625029 s/step
# Meep progress: 229.606/1000.0 = 23.0% done in 860.4s, 2886.9s to go
# on time step 229630 (time=229.63), 0.00639733 s/step
# Meep progress: 230.238/1000.0 = 23.0% done in 864.4s, 2890.0s to go
# on time step 230261 (time=230.261), 0.00634053 s/step
# Meep progress: 230.877/1000.0 = 23.1% done in 868.4s, 2893.0s to go
# on time step 230902 (time=230.902), 0.00624578 s/step
# Meep progress: 231.501/1000.0 = 23.2% done in 872.4s, 2896.1s to go
# on time step 231526 (time=231.526), 0.00641415 s/step
# Meep progress: 232.147/1000.0 = 23.2% done in 876.4s, 2898.9s to go
# on time step 232172 (time=232.172), 0.00619503 s/step
# Meep progress: 232.803/1000.0 = 23.3% done in 880.4s, 2901.4s to go
# on time step 232828 (time=232.828), 0.0060982 s/step
# Meep progress: 233.45600000000002/1000.0 = 23.3% done in 884.4s, 2904.0s to go
# on time step 233482 (time=233.482), 0.00611901 s/step
# Meep progress: 234.114/1000.0 = 23.4% done in 888.4s, 2906.5s to go
# on time step 234140 (time=234.14), 0.00608685 s/step
# Meep progress: 234.769/1000.0 = 23.5% done in 892.4s, 2908.9s to go
# on time step 234794 (time=234.794), 0.00612496 s/step
# Meep progress: 235.421/1000.0 = 23.5% done in 896.4s, 2911.4s to go
# on time step 235447 (time=235.447), 0.00613013 s/step
# Meep progress: 236.072/1000.0 = 23.6% done in 900.4s, 2913.8s to go
# on time step 236097 (time=236.097), 0.00616066 s/step
# Meep progress: 236.725/1000.0 = 23.7% done in 904.5s, 2916.2s to go
# on time step 236750 (time=236.75), 0.00612683 s/step
# Meep progress: 237.381/1000.0 = 23.7% done in 908.5s, 2918.5s to go
# on time step 237407 (time=237.407), 0.00609347 s/step
# Meep progress: 238.036/1000.0 = 23.8% done in 912.5s, 2920.8s to go
# on time step 238062 (time=238.062), 0.00611552 s/step
# Meep progress: 238.692/1000.0 = 23.9% done in 916.5s, 2923.1s to go
# on time step 238718 (time=238.718), 0.00610607 s/step
# Meep progress: 239.347/1000.0 = 23.9% done in 920.5s, 2925.3s to go
# on time step 239374 (time=239.374), 0.00610264 s/step
# Meep progress: 240.001/1000.0 = 24.0% done in 924.5s, 2927.5s to go
# on time step 240027 (time=240.027), 0.00612656 s/step
# Meep progress: 240.662/1000.0 = 24.1% done in 928.5s, 2929.5s to go
# on time step 240688 (time=240.688), 0.0060569 s/step
# Meep progress: 241.312/1000.0 = 24.1% done in 932.5s, 2931.7s to go
# on time step 241338 (time=241.338), 0.00615934 s/step
# Meep progress: 241.966/1000.0 = 24.2% done in 936.5s, 2933.8s to go
# on time step 241993 (time=241.993), 0.00611269 s/step
# Meep progress: 242.615/1000.0 = 24.3% done in 940.5s, 2936.0s to go
# on time step 242642 (time=242.642), 0.00617223 s/step
# Meep progress: 243.273/1000.0 = 24.3% done in 944.5s, 2937.9s to go
# on time step 243301 (time=243.301), 0.00607513 s/step
# Meep progress: 243.928/1000.0 = 24.4% done in 948.5s, 2939.9s to go
# on time step 243956 (time=243.956), 0.0061127 s/step
# Meep progress: 244.583/1000.0 = 24.5% done in 952.5s, 2941.9s to go
# on time step 244612 (time=244.612), 0.00610572 s/step
# Meep progress: 245.233/1000.0 = 24.5% done in 956.5s, 2943.9s to go
# on time step 245261 (time=245.261), 0.006167 s/step
# Meep progress: 245.88500000000002/1000.0 = 24.6% done in 960.5s, 2945.8s to go
# on time step 245914 (time=245.914), 0.00612753 s/step
# Meep progress: 246.544/1000.0 = 24.7% done in 964.5s, 2947.6s to go
# on time step 246572 (time=246.572), 0.00608285 s/step
# Meep progress: 247.199/1000.0 = 24.7% done in 968.5s, 2949.4s to go
# on time step 247228 (time=247.228), 0.00610541 s/step
# Meep progress: 247.853/1000.0 = 24.8% done in 972.5s, 2951.2s to go
# on time step 247881 (time=247.881), 0.00612894 s/step
# Meep progress: 248.506/1000.0 = 24.9% done in 976.5s, 2953.0s to go
# on time step 248535 (time=248.535), 0.00611798 s/step
# Meep progress: 249.162/1000.0 = 24.9% done in 980.5s, 2954.7s to go
# on time step 249191 (time=249.191), 0.00610305 s/step
# Meep progress: 249.793/1000.0 = 25.0% done in 984.5s, 2956.8s to go
# on time step 249822 (time=249.822), 0.00634533 s/step
# Meep progress: 250.44/1000.0 = 25.0% done in 988.5s, 2958.6s to go
# on time step 250469 (time=250.469), 0.00618585 s/step
# Meep progress: 251.091/1000.0 = 25.1% done in 992.5s, 2960.3s to go
# on time step 251121 (time=251.121), 0.00613633 s/step
# Meep progress: 251.746/1000.0 = 25.2% done in 996.5s, 2961.9s to go
# on time step 251776 (time=251.776), 0.00611734 s/step
# Meep progress: 252.401/1000.0 = 25.2% done in 1000.5s, 2963.5s to go
# on time step 252431 (time=252.431), 0.00611236 s/step
# Meep progress: 253.047/1000.0 = 25.3% done in 1004.5s, 2965.2s to go
# on time step 253077 (time=253.077), 0.00619858 s/step
# Meep progress: 253.697/1000.0 = 25.4% done in 1008.5s, 2966.8s to go
# on time step 253728 (time=253.728), 0.00614997 s/step
# Meep progress: 254.34900000000002/1000.0 = 25.4% done in 1012.5s, 2968.4s to go
# on time step 254380 (time=254.38), 0.00614049 s/step
# Meep progress: 254.995/1000.0 = 25.5% done in 1016.5s, 2970.0s to go
# on time step 255026 (time=255.026), 0.0061953 s/step
# Meep progress: 255.59/1000.0 = 25.6% done in 1020.5s, 2972.3s to go
# on time step 255620 (time=255.62), 0.00674369 s/step
# Meep progress: 256.197/1000.0 = 25.6% done in 1024.5s, 2974.5s to go
# on time step 256227 (time=256.227), 0.00659594 s/step
# Meep progress: 256.787/1000.0 = 25.7% done in 1028.6s, 2976.9s to go
# on time step 256817 (time=256.817), 0.00678828 s/step
# Meep progress: 257.406/1000.0 = 25.7% done in 1032.6s, 2978.8s to go
# on time step 257436 (time=257.436), 0.0064635 s/step
# Meep progress: 258.025/1000.0 = 25.8% done in 1036.6s, 2980.7s to go
# on time step 258051 (time=258.051), 0.00651295 s/step
# Meep progress: 258.64300000000003/1000.0 = 25.9% done in 1040.6s, 2982.6s to go
# on time step 258675 (time=258.675), 0.00641551 s/step
# Meep progress: 259.272/1000.0 = 25.9% done in 1044.6s, 2984.3s to go
# on time step 259304 (time=259.304), 0.00636511 s/step
# Meep progress: 259.922/1000.0 = 26.0% done in 1048.6s, 2985.6s to go
# on time step 259954 (time=259.954), 0.00615923 s/step
# Meep progress: 260.56600000000003/1000.0 = 26.1% done in 1052.6s, 2987.0s to go
# on time step 260597 (time=260.597), 0.0062265 s/step
# Meep progress: 261.207/1000.0 = 26.1% done in 1056.6s, 2988.4s to go
# on time step 261240 (time=261.24), 0.00622386 s/step
# Meep progress: 261.851/1000.0 = 26.2% done in 1060.6s, 2989.7s to go
# on time step 261883 (time=261.883), 0.00623107 s/step
# Meep progress: 262.485/1000.0 = 26.2% done in 1064.6s, 2991.2s to go
# on time step 262518 (time=262.518), 0.00630294 s/step
# Meep progress: 263.134/1000.0 = 26.3% done in 1068.6s, 2992.4s to go
# on time step 263168 (time=263.168), 0.006157 s/step
# Meep progress: 263.762/1000.0 = 26.4% done in 1072.6s, 2993.9s to go
# on time step 263793 (time=263.793), 0.00640488 s/step
# Meep progress: 264.407/1000.0 = 26.4% done in 1076.6s, 2995.1s to go
# on time step 264440 (time=264.44), 0.00618844 s/step
# Meep progress: 265.049/1000.0 = 26.5% done in 1080.6s, 2996.4s to go
# on time step 265083 (time=265.083), 0.00623028 s/step
# Meep progress: 265.68/1000.0 = 26.6% done in 1084.6s, 2997.7s to go
# on time step 265712 (time=265.712), 0.00636512 s/step
# Meep progress: 266.324/1000.0 = 26.6% done in 1088.6s, 2998.9s to go
# on time step 266359 (time=266.359), 0.0061882 s/step
# Meep progress: 266.968/1000.0 = 26.7% done in 1092.6s, 3000.0s to go
# on time step 267003 (time=267.003), 0.00621945 s/step
# Meep progress: 267.60200000000003/1000.0 = 26.8% done in 1096.6s, 3001.3s to go
# on time step 267638 (time=267.638), 0.00631008 s/step
# Meep progress: 268.254/1000.0 = 26.8% done in 1100.6s, 3002.2s to go
# on time step 268292 (time=268.292), 0.00611664 s/step
# Meep progress: 268.902/1000.0 = 26.9% done in 1104.6s, 3003.2s to go
# on time step 268939 (time=268.939), 0.00618683 s/step
# Meep progress: 269.545/1000.0 = 27.0% done in 1108.6s, 3004.3s to go
# on time step 269583 (time=269.583), 0.00622014 s/step
# Meep progress: 270.199/1000.0 = 27.0% done in 1112.6s, 3005.1s to go
# on time step 270238 (time=270.238), 0.0061146 s/step
# Meep progress: 270.843/1000.0 = 27.1% done in 1116.6s, 3006.1s to go
# on time step 270879 (time=270.879), 0.00624136 s/step
# Meep progress: 271.486/1000.0 = 27.1% done in 1120.6s, 3007.1s to go
# on time step 271523 (time=271.523), 0.00621982 s/step
# Meep progress: 272.132/1000.0 = 27.2% done in 1124.6s, 3008.0s to go
# on time step 272169 (time=272.169), 0.00619431 s/step
# Meep progress: 272.78000000000003/1000.0 = 27.3% done in 1128.6s, 3008.9s to go
# on time step 272818 (time=272.818), 0.00616528 s/step
# Meep progress: 273.424/1000.0 = 27.3% done in 1132.6s, 3009.7s to go
# on time step 273463 (time=273.463), 0.00620661 s/step
# Meep progress: 274.06600000000003/1000.0 = 27.4% done in 1136.6s, 3010.6s to go
# on time step 274106 (time=274.106), 0.00622645 s/step
# Meep progress: 274.714/1000.0 = 27.5% done in 1140.6s, 3011.4s to go
# on time step 274753 (time=274.753), 0.00618308 s/step
# Meep progress: 275.341/1000.0 = 27.5% done in 1144.6s, 3012.5s to go
# on time step 275380 (time=275.38), 0.00638067 s/step
# Meep progress: 275.983/1000.0 = 27.6% done in 1148.6s, 3013.3s to go
# on time step 276022 (time=276.022), 0.00623304 s/step
# Meep progress: 276.63100000000003/1000.0 = 27.7% done in 1152.6s, 3014.1s to go
# on time step 276670 (time=276.67), 0.00618109 s/step
# Meep progress: 277.282/1000.0 = 27.7% done in 1156.6s, 3014.7s to go
# on time step 277320 (time=277.32), 0.00616137 s/step
# Meep progress: 277.93/1000.0 = 27.8% done in 1160.6s, 3015.4s to go
# on time step 277969 (time=277.969), 0.00616611 s/step
# Meep progress: 278.579/1000.0 = 27.9% done in 1164.6s, 3016.0s to go
# on time step 278616 (time=278.616), 0.0061836 s/step
# Meep progress: 279.216/1000.0 = 27.9% done in 1168.7s, 3016.8s to go
# on time step 279255 (time=279.255), 0.00626682 s/step
# Meep progress: 279.855/1000.0 = 28.0% done in 1172.7s, 3017.6s to go
# on time step 279895 (time=279.895), 0.00625591 s/step
# Meep progress: 280.50100000000003/1000.0 = 28.1% done in 1176.7s, 3018.2s to go
# on time step 280540 (time=280.54), 0.00620425 s/step
# Meep progress: 281.147/1000.0 = 28.1% done in 1180.7s, 3018.8s to go
# on time step 281188 (time=281.188), 0.00617721 s/step
# Meep progress: 281.769/1000.0 = 28.2% done in 1184.7s, 3019.7s to go
# on time step 281810 (time=281.81), 0.00643812 s/step
# Meep progress: 282.419/1000.0 = 28.2% done in 1188.7s, 3020.2s to go
# on time step 282459 (time=282.459), 0.0061639 s/step
# Meep progress: 283.056/1000.0 = 28.3% done in 1192.7s, 3020.9s to go
# on time step 283095 (time=283.095), 0.00628961 s/step
# Meep progress: 283.698/1000.0 = 28.4% done in 1196.7s, 3021.5s to go
# on time step 283737 (time=283.737), 0.00623199 s/step
# Meep progress: 284.336/1000.0 = 28.4% done in 1200.7s, 3022.1s to go
# on time step 284375 (time=284.375), 0.0062771 s/step
# Meep progress: 284.975/1000.0 = 28.5% done in 1204.7s, 3022.7s to go
# on time step 285013 (time=285.013), 0.00627767 s/step
# Meep progress: 285.622/1000.0 = 28.6% done in 1208.7s, 3023.1s to go
# on time step 285660 (time=285.66), 0.00618363 s/step
# Meep progress: 286.261/1000.0 = 28.6% done in 1212.7s, 3023.6s to go
# on time step 286300 (time=286.3), 0.0062592 s/step
# Meep progress: 286.90500000000003/1000.0 = 28.7% done in 1216.7s, 3024.1s to go
# on time step 286943 (time=286.943), 0.00622491 s/step
# Meep progress: 287.556/1000.0 = 28.8% done in 1220.7s, 3024.4s to go
# on time step 287595 (time=287.595), 0.00613862 s/step
# Meep progress: 288.198/1000.0 = 28.8% done in 1224.7s, 3024.8s to go
# on time step 288236 (time=288.236), 0.00624081 s/step
# Meep progress: 288.838/1000.0 = 28.9% done in 1228.7s, 3025.3s to go
# on time step 288879 (time=288.879), 0.00622942 s/step
# Meep progress: 289.485/1000.0 = 28.9% done in 1232.7s, 3025.6s to go
# on time step 289525 (time=289.525), 0.00619389 s/step
# Meep progress: 290.122/1000.0 = 29.0% done in 1236.7s, 3026.0s to go
# on time step 290161 (time=290.161), 0.00629061 s/step
# Meep progress: 290.764/1000.0 = 29.1% done in 1240.7s, 3026.4s to go
# on time step 290804 (time=290.804), 0.00622688 s/step
# Meep progress: 291.409/1000.0 = 29.1% done in 1244.7s, 3026.6s to go
# on time step 291450 (time=291.45), 0.00619244 s/step
# Meep progress: 292.056/1000.0 = 29.2% done in 1248.7s, 3026.9s to go
# on time step 292096 (time=292.096), 0.00619934 s/step
# Meep progress: 292.701/1000.0 = 29.3% done in 1252.7s, 3027.1s to go
# on time step 292742 (time=292.742), 0.00619824 s/step
# Meep progress: 293.351/1000.0 = 29.3% done in 1256.7s, 3027.3s to go
# on time step 293390 (time=293.39), 0.00617368 s/step
# Meep progress: 293.995/1000.0 = 29.4% done in 1260.7s, 3027.5s to go
# on time step 294035 (time=294.035), 0.00620926 s/step
# Meep progress: 294.635/1000.0 = 29.5% done in 1264.7s, 3027.8s to go
# on time step 294675 (time=294.675), 0.00625313 s/step
# Meep progress: 295.272/1000.0 = 29.5% done in 1268.7s, 3028.1s to go
# on time step 295313 (time=295.313), 0.00627582 s/step
# Meep progress: 295.907/1000.0 = 29.6% done in 1272.7s, 3028.4s to go
# on time step 295948 (time=295.948), 0.00630016 s/step
# Meep progress: 296.56/1000.0 = 29.7% done in 1276.7s, 3028.4s to go
# on time step 296602 (time=296.602), 0.00612154 s/step
# Meep progress: 297.182/1000.0 = 29.7% done in 1280.7s, 3028.9s to go
# on time step 297221 (time=297.221), 0.00646412 s/step
# Meep progress: 297.805/1000.0 = 29.8% done in 1284.7s, 3029.3s to go
# on time step 297843 (time=297.843), 0.00643724 s/step
# Meep progress: 298.423/1000.0 = 29.8% done in 1288.7s, 3029.8s to go
# on time step 298460 (time=298.46), 0.00649156 s/step
# Meep progress: 299.048/1000.0 = 29.9% done in 1292.8s, 3030.1s to go
# on time step 299088 (time=299.088), 0.00637043 s/step
# Meep progress: 299.689/1000.0 = 30.0% done in 1296.8s, 3030.2s to go
# on time step 299731 (time=299.731), 0.00622779 s/step
# Meep progress: 300.322/1000.0 = 30.0% done in 1300.8s, 3030.5s to go
# on time step 300363 (time=300.363), 0.0063374 s/step
# Meep progress: 300.955/1000.0 = 30.1% done in 1304.8s, 3030.6s to go
# on time step 300996 (time=300.996), 0.0063192 s/step
# Meep progress: 301.595/1000.0 = 30.2% done in 1308.8s, 3030.7s to go
# on time step 301638 (time=301.638), 0.00623676 s/step
# Meep progress: 302.23900000000003/1000.0 = 30.2% done in 1312.8s, 3030.7s to go
# on time step 302281 (time=302.281), 0.00623081 s/step
# Meep progress: 302.857/1000.0 = 30.3% done in 1316.8s, 3031.1s to go
# on time step 302901 (time=302.901), 0.00645569 s/step
# Meep progress: 303.494/1000.0 = 30.3% done in 1320.8s, 3031.1s to go
# on time step 303537 (time=303.537), 0.00629531 s/step
# Meep progress: 304.133/1000.0 = 30.4% done in 1324.8s, 3031.1s to go
# on time step 304179 (time=304.179), 0.00623791 s/step
# Meep progress: 304.79/1000.0 = 30.5% done in 1328.8s, 3030.9s to go
# on time step 304835 (time=304.835), 0.00610338 s/step
# Meep progress: 305.438/1000.0 = 30.5% done in 1332.8s, 3030.7s to go
# on time step 305484 (time=305.484), 0.00616726 s/step
# Meep progress: 306.095/1000.0 = 30.6% done in 1336.8s, 3030.4s to go
# on time step 306142 (time=306.142), 0.00608709 s/step
# Meep progress: 306.75/1000.0 = 30.7% done in 1340.8s, 3030.2s to go
# on time step 306796 (time=306.796), 0.00611887 s/step
# Meep progress: 307.398/1000.0 = 30.7% done in 1344.8s, 3030.0s to go
# on time step 307444 (time=307.444), 0.00617815 s/step
# Meep progress: 308.049/1000.0 = 30.8% done in 1348.8s, 3029.7s to go
# on time step 308096 (time=308.096), 0.00614217 s/step
# Meep progress: 308.696/1000.0 = 30.9% done in 1352.8s, 3029.5s to go
# on time step 308744 (time=308.744), 0.00617973 s/step
# Meep progress: 309.348/1000.0 = 30.9% done in 1356.8s, 3029.2s to go
# on time step 309394 (time=309.394), 0.00615557 s/step
# Meep progress: 310.007/1000.0 = 31.0% done in 1360.8s, 3028.8s to go
# on time step 310054 (time=310.054), 0.00606404 s/step
# Meep progress: 310.66/1000.0 = 31.1% done in 1364.8s, 3028.4s to go
# on time step 310705 (time=310.705), 0.00615009 s/step
# Meep progress: 311.315/1000.0 = 31.1% done in 1368.8s, 3028.0s to go
# on time step 311362 (time=311.362), 0.00609401 s/step
# Meep progress: 311.966/1000.0 = 31.2% done in 1372.8s, 3027.7s to go
# on time step 312015 (time=312.015), 0.00613658 s/step
# Meep progress: 312.604/1000.0 = 31.3% done in 1376.8s, 3027.5s to go
# on time step 312652 (time=312.652), 0.00628705 s/step
# Meep progress: 313.257/1000.0 = 31.3% done in 1380.8s, 3027.1s to go
# on time step 313306 (time=313.306), 0.0061239 s/step
# Meep progress: 313.902/1000.0 = 31.4% done in 1384.8s, 3026.8s to go
# on time step 313951 (time=313.951), 0.0062026 s/step
# Meep progress: 314.544/1000.0 = 31.5% done in 1388.8s, 3026.5s to go
# on time step 314585 (time=314.585), 0.00631827 s/step
# Meep progress: 315.092/1000.0 = 31.5% done in 1392.8s, 3027.6s to go
# on time step 315133 (time=315.133), 0.00730513 s/step
# Meep progress: 315.714/1000.0 = 31.6% done in 1396.8s, 3027.5s to go
# on time step 315761 (time=315.761), 0.00637943 s/step
# Meep progress: 316.341/1000.0 = 31.6% done in 1400.8s, 3027.4s to go
# on time step 316389 (time=316.389), 0.0063755 s/step
# Meep progress: 316.96500000000003/1000.0 = 31.7% done in 1404.8s, 3027.3s to go
# on time step 317012 (time=317.012), 0.00642695 s/step
# Meep progress: 317.603/1000.0 = 31.8% done in 1408.8s, 3027.0s to go
# on time step 317654 (time=317.654), 0.00623306 s/step
# Meep progress: 318.19100000000003/1000.0 = 31.8% done in 1412.8s, 3027.4s to go
# on time step 318240 (time=318.24), 0.0068297 s/step
# Meep progress: 318.774/1000.0 = 31.9% done in 1416.8s, 3027.8s to go
# on time step 318826 (time=318.826), 0.00683404 s/step
# Meep progress: 319.415/1000.0 = 31.9% done in 1420.8s, 3027.4s to go
# on time step 319466 (time=319.466), 0.00625372 s/step
# Meep progress: 320.028/1000.0 = 32.0% done in 1424.9s, 3027.4s to go
# on time step 320077 (time=320.077), 0.00655427 s/step
# Meep progress: 320.609/1000.0 = 32.1% done in 1428.9s, 3027.8s to go
# on time step 320660 (time=320.66), 0.00686956 s/step
# Meep progress: 321.257/1000.0 = 32.1% done in 1432.9s, 3027.3s to go
# on time step 321309 (time=321.309), 0.006177 s/step
# Meep progress: 321.88/1000.0 = 32.2% done in 1436.9s, 3027.1s to go
# on time step 321934 (time=321.934), 0.00640579 s/step
# Meep progress: 322.515/1000.0 = 32.3% done in 1440.9s, 3026.7s to go
# on time step 322566 (time=322.566), 0.00633253 s/step
# Meep progress: 323.072/1000.0 = 32.3% done in 1444.9s, 3027.4s to go
# on time step 323121 (time=323.121), 0.00721774 s/step
# Meep progress: 323.673/1000.0 = 32.4% done in 1448.9s, 3027.5s to go
# on time step 323723 (time=323.723), 0.00664833 s/step
# Meep progress: 324.272/1000.0 = 32.4% done in 1452.9s, 3027.5s to go
# on time step 324325 (time=324.325), 0.00665299 s/step
# Meep progress: 324.823/1000.0 = 32.5% done in 1456.9s, 3028.3s to go
# on time step 324867 (time=324.867), 0.00739124 s/step
# Meep progress: 325.428/1000.0 = 32.5% done in 1460.9s, 3028.2s to go
# on time step 325483 (time=325.483), 0.00649529 s/step
# Meep progress: 326.021/1000.0 = 32.6% done in 1464.9s, 3028.3s to go
# on time step 326075 (time=326.075), 0.00676465 s/step
# Meep progress: 326.637/1000.0 = 32.7% done in 1468.9s, 3028.1s to go
# on time step 326689 (time=326.689), 0.00652481 s/step
# Meep progress: 327.249/1000.0 = 32.7% done in 1472.9s, 3027.9s to go
# on time step 327293 (time=327.293), 0.00663195 s/step
# Meep progress: 327.84000000000003/1000.0 = 32.8% done in 1476.9s, 3028.0s to go
# on time step 327898 (time=327.898), 0.0066173 s/step
# Meep progress: 328.487/1000.0 = 32.8% done in 1480.9s, 3027.3s to go
# on time step 328544 (time=328.544), 0.00619589 s/step
# Meep progress: 329.115/1000.0 = 32.9% done in 1484.9s, 3026.9s to go
# on time step 329171 (time=329.171), 0.0063859 s/step
# Meep progress: 329.73/1000.0 = 33.0% done in 1488.9s, 3026.6s to go
# on time step 329783 (time=329.783), 0.00654002 s/step
# Meep progress: 330.348/1000.0 = 33.0% done in 1492.9s, 3026.3s to go
# on time step 330394 (time=330.394), 0.00655566 s/step
# Meep progress: 330.927/1000.0 = 33.1% done in 1496.9s, 3026.5s to go
# on time step 330984 (time=330.984), 0.00678982 s/step
# Meep progress: 331.528/1000.0 = 33.2% done in 1500.9s, 3026.4s to go
# on time step 331575 (time=331.575), 0.00678016 s/step
# ...
# on time step 870794 (time=870.794), 0.00352131 s/step
# Meep progress: 871.7090000000001/1000.0 = 87.2% done in 4519.3s, 665.1s to go
# on time step 871959 (time=871.959), 0.00343451 s/step
# Meep progress: 872.8480000000001/1000.0 = 87.3% done in 4523.3s, 658.9s to go
# on time step 873093 (time=873.093), 0.00352759 s/step
# Meep progress: 873.999/1000.0 = 87.4% done in 4527.3s, 652.7s to go
# on time step 874250 (time=874.25), 0.00345885 s/step
# Meep progress: 875.147/1000.0 = 87.5% done in 4531.3s, 646.5s to go
# on time step 875395 (time=875.395), 0.00349362 s/step
# Meep progress: 876.304/1000.0 = 87.6% done in 4535.3s, 640.2s to go
# on time step 876557 (time=876.557), 0.00344328 s/step
# Meep progress: 877.378/1000.0 = 87.7% done in 4539.3s, 634.4s to go
# on time step 877629 (time=877.629), 0.0037337 s/step
# Meep progress: 878.538/1000.0 = 87.9% done in 4543.3s, 628.1s to go
# on time step 878786 (time=878.786), 0.00345814 s/step
# Meep progress: 879.688/1000.0 = 88.0% done in 4547.3s, 621.9s to go
# on time step 879939 (time=879.939), 0.0034708 s/step
# Meep progress: 880.849/1000.0 = 88.1% done in 4551.3s, 615.7s to go
# on time step 881097 (time=881.097), 0.003455 s/step
# Meep progress: 882.01/1000.0 = 88.2% done in 4555.3s, 609.4s to go
# on time step 882264 (time=882.264), 0.00342856 s/step
# Meep progress: 883.12/1000.0 = 88.3% done in 4559.3s, 603.4s to go
# on time step 883370 (time=883.37), 0.00361876 s/step
# Meep progress: 884.266/1000.0 = 88.4% done in 4563.3s, 597.3s to go
# on time step 884518 (time=884.518), 0.00348624 s/step
# Meep progress: 885.397/1000.0 = 88.5% done in 4567.3s, 591.2s to go
# on time step 885616 (time=885.616), 0.00364655 s/step
# Meep progress: 886.455/1000.0 = 88.6% done in 4571.3s, 585.5s to go
# on time step 886679 (time=886.679), 0.0037651 s/step
# Meep progress: 887.557/1000.0 = 88.8% done in 4575.3s, 579.6s to go
# on time step 887808 (time=887.808), 0.00354362 s/step
# Meep progress: 888.724/1000.0 = 88.9% done in 4579.3s, 573.4s to go
# on time step 888975 (time=888.975), 0.00342885 s/step
# Meep progress: 889.807/1000.0 = 89.0% done in 4583.4s, 567.6s to go
# on time step 890056 (time=890.056), 0.00370063 s/step
# Meep progress: 890.961/1000.0 = 89.1% done in 4587.4s, 561.4s to go
# on time step 891211 (time=891.211), 0.00346543 s/step
# Meep progress: 892.118/1000.0 = 89.2% done in 4591.4s, 555.2s to go
# on time step 892373 (time=892.373), 0.00344504 s/step
# Meep progress: 893.234/1000.0 = 89.3% done in 4595.4s, 549.3s to go
# on time step 893481 (time=893.481), 0.00361215 s/step
# Meep progress: 894.3770000000001/1000.0 = 89.4% done in 4599.4s, 543.2s to go
# on time step 894620 (time=894.62), 0.00351509 s/step
# Meep progress: 895.47/1000.0 = 89.5% done in 4603.4s, 537.4s to go
# on time step 895723 (time=895.723), 0.00362864 s/step
# Meep progress: 896.596/1000.0 = 89.7% done in 4607.4s, 531.4s to go
# on time step 896846 (time=896.846), 0.00356332 s/step
# Meep progress: 897.748/1000.0 = 89.8% done in 4611.4s, 525.2s to go
# on time step 898000 (time=898), 0.0034688 s/step
# Meep progress: 898.904/1000.0 = 89.9% done in 4615.4s, 519.1s to go
# on time step 899146 (time=899.146), 0.00349347 s/step
# Meep progress: 900.0310000000001/1000.0 = 90.0% done in 4619.4s, 513.1s to go
# on time step 900244 (time=900.244), 0.00364607 s/step
# Meep progress: 901.111/1000.0 = 90.1% done in 4623.4s, 507.4s to go
# on time step 901369 (time=901.369), 0.00355822 s/step
# Meep progress: 902.232/1000.0 = 90.2% done in 4627.4s, 501.4s to go
# on time step 902475 (time=902.475), 0.00361918 s/step
# Meep progress: 903.395/1000.0 = 90.3% done in 4631.4s, 495.3s to go
# on time step 903655 (time=903.655), 0.00339101 s/step
# Meep progress: 904.553/1000.0 = 90.5% done in 4635.4s, 489.1s to go
# on time step 904816 (time=904.816), 0.00344755 s/step
# Meep progress: 905.714/1000.0 = 90.6% done in 4639.4s, 483.0s to go
# on time step 905976 (time=905.976), 0.00345137 s/step
# Meep progress: 906.878/1000.0 = 90.7% done in 4643.4s, 476.8s to go
# on time step 907100 (time=907.1), 0.0035625 s/step
# Meep progress: 907.947/1000.0 = 90.8% done in 4647.4s, 471.2s to go
# on time step 908205 (time=908.205), 0.00362279 s/step
# Meep progress: 909.092/1000.0 = 90.9% done in 4651.4s, 465.1s to go
# on time step 909358 (time=909.358), 0.00347084 s/step
# Meep progress: 910.239/1000.0 = 91.0% done in 4655.4s, 459.1s to go
# on time step 910496 (time=910.496), 0.00351564 s/step
# Meep progress: 911.361/1000.0 = 91.1% done in 4659.4s, 453.2s to go
# on time step 911612 (time=911.612), 0.0035854 s/step
# Meep progress: 912.446/1000.0 = 91.2% done in 4663.4s, 447.5s to go
# on time step 912700 (time=912.7), 0.00367738 s/step
# Meep progress: 913.588/1000.0 = 91.4% done in 4667.4s, 441.5s to go
# on time step 913843 (time=913.843), 0.00350304 s/step
# Meep progress: 914.703/1000.0 = 91.5% done in 4671.4s, 435.6s to go
# on time step 914919 (time=914.919), 0.00372142 s/step
# Meep progress: 915.735/1000.0 = 91.6% done in 4675.4s, 430.2s to go
# on time step 915969 (time=915.969), 0.00381359 s/step
# Meep progress: 916.8240000000001/1000.0 = 91.7% done in 4679.4s, 424.5s to go
# on time step 917084 (time=917.084), 0.0035893 s/step
# Meep progress: 917.977/1000.0 = 91.8% done in 4683.4s, 418.5s to go
# on time step 918243 (time=918.243), 0.00345215 s/step
# Meep progress: 919.1460000000001/1000.0 = 91.9% done in 4687.4s, 412.3s to go
# on time step 919413 (time=919.413), 0.00341917 s/step
# Meep progress: 920.311/1000.0 = 92.0% done in 4691.4s, 406.2s to go
# on time step 920568 (time=920.568), 0.00346366 s/step
# Meep progress: 921.463/1000.0 = 92.1% done in 4695.4s, 400.2s to go
# on time step 921731 (time=921.731), 0.00344023 s/step
# Meep progress: 922.626/1000.0 = 92.3% done in 4699.4s, 394.1s to go
# on time step 922889 (time=922.889), 0.00345495 s/step
# Meep progress: 923.7710000000001/1000.0 = 92.4% done in 4703.4s, 388.1s to go
# on time step 924027 (time=924.027), 0.00351735 s/step
# Meep progress: 924.9010000000001/1000.0 = 92.5% done in 4707.4s, 382.2s to go
# on time step 925155 (time=925.155), 0.00354791 s/step
# Meep progress: 925.99/1000.0 = 92.6% done in 4711.4s, 376.6s to go
# on time step 926242 (time=926.242), 0.00368308 s/step
# Meep progress: 927.135/1000.0 = 92.7% done in 4715.4s, 370.6s to go
# on time step 927401 (time=927.401), 0.00345422 s/step
# Meep progress: 928.2230000000001/1000.0 = 92.8% done in 4719.4s, 364.9s to go
# on time step 928488 (time=928.488), 0.00368184 s/step
# Meep progress: 929.369/1000.0 = 92.9% done in 4723.4s, 359.0s to go
# on time step 929632 (time=929.632), 0.00349658 s/step
# Meep progress: 930.5210000000001/1000.0 = 93.1% done in 4727.4s, 353.0s to go
# on time step 930781 (time=930.781), 0.00348364 s/step
# Meep progress: 931.658/1000.0 = 93.2% done in 4731.4s, 347.1s to go
# on time step 931918 (time=931.918), 0.00352126 s/step
# Meep progress: 932.773/1000.0 = 93.3% done in 4735.4s, 341.3s to go
# on time step 933038 (time=933.038), 0.00357203 s/step
# Meep progress: 933.871/1000.0 = 93.4% done in 4739.4s, 335.6s to go
# on time step 934137 (time=934.137), 0.00364263 s/step
# Meep progress: 935.0360000000001/1000.0 = 93.5% done in 4743.4s, 329.6s to go
# on time step 935298 (time=935.298), 0.00344598 s/step
# Meep progress: 936.181/1000.0 = 93.6% done in 4747.4s, 323.6s to go
# on time step 936441 (time=936.441), 0.00350018 s/step
# Meep progress: 937.296/1000.0 = 93.7% done in 4751.4s, 317.9s to go
# on time step 937556 (time=937.556), 0.00358837 s/step
# Meep progress: 938.448/1000.0 = 93.8% done in 4755.4s, 311.9s to go
# on time step 938705 (time=938.705), 0.00348448 s/step
# Meep progress: 939.597/1000.0 = 94.0% done in 4759.4s, 306.0s to go
# on time step 939859 (time=939.859), 0.00346765 s/step
# Meep progress: 940.7330000000001/1000.0 = 94.1% done in 4763.4s, 300.1s to go
# on time step 940974 (time=940.974), 0.0035882 s/step
# Meep progress: 941.86/1000.0 = 94.2% done in 4767.4s, 294.3s to go
# on time step 942115 (time=942.115), 0.00350667 s/step
# Meep progress: 942.971/1000.0 = 94.3% done in 4771.4s, 288.6s to go
# on time step 943237 (time=943.237), 0.00356668 s/step
# Meep progress: 944.0210000000001/1000.0 = 94.4% done in 4775.4s, 283.2s to go
# on time step 944238 (time=944.238), 0.00399846 s/step
# Meep progress: 945.03/1000.0 = 94.5% done in 4779.4s, 278.0s to go
# on time step 945232 (time=945.232), 0.00402711 s/step
# Meep progress: 946.0600000000001/1000.0 = 94.6% done in 4783.4s, 272.7s to go
# on time step 946330 (time=946.33), 0.00364454 s/step
# Meep progress: 947.2090000000001/1000.0 = 94.7% done in 4787.4s, 266.8s to go
# on time step 947478 (time=947.478), 0.00348575 s/step
# Meep progress: 948.3720000000001/1000.0 = 94.8% done in 4791.4s, 260.8s to go
# on time step 948643 (time=948.643), 0.00343515 s/step
# Meep progress: 949.489/1000.0 = 94.9% done in 4795.4s, 255.1s to go
# on time step 949747 (time=949.747), 0.00362524 s/step
# Meep progress: 950.642/1000.0 = 95.1% done in 4799.4s, 249.2s to go
# on time step 950910 (time=950.91), 0.00344033 s/step
# Meep progress: 951.798/1000.0 = 95.2% done in 4803.4s, 243.3s to go
# on time step 952066 (time=952.066), 0.00346306 s/step
# Meep progress: 952.9440000000001/1000.0 = 95.3% done in 4807.4s, 237.4s to go
# on time step 953199 (time=953.199), 0.00353268 s/step
# Meep progress: 954.094/1000.0 = 95.4% done in 4811.4s, 231.5s to go
# on time step 954367 (time=954.367), 0.003427 s/step
# Meep progress: 955.246/1000.0 = 95.5% done in 4815.4s, 225.6s to go
# on time step 955524 (time=955.524), 0.00345973 s/step
# Meep progress: 956.376/1000.0 = 95.6% done in 4819.4s, 219.8s to go
# on time step 956626 (time=956.626), 0.00363049 s/step
# Meep progress: 957.496/1000.0 = 95.7% done in 4823.4s, 214.1s to go
# on time step 957772 (time=957.772), 0.00349327 s/step
# Meep progress: 958.6410000000001/1000.0 = 95.9% done in 4827.4s, 208.3s to go
# on time step 958908 (time=958.908), 0.0035213 s/step
# Meep progress: 959.769/1000.0 = 96.0% done in 4831.4s, 202.5s to go
# on time step 960046 (time=960.046), 0.00351635 s/step
# Meep progress: 960.938/1000.0 = 96.1% done in 4835.4s, 196.6s to go
# on time step 961217 (time=961.217), 0.00341667 s/step
# Meep progress: 962.088/1000.0 = 96.2% done in 4839.5s, 190.7s to go
# on time step 962366 (time=962.366), 0.00348362 s/step
# Meep progress: 963.241/1000.0 = 96.3% done in 4843.5s, 184.8s to go
# on time step 963505 (time=963.505), 0.00351313 s/step
# Meep progress: 964.338/1000.0 = 96.4% done in 4847.5s, 179.3s to go
# on time step 964610 (time=964.61), 0.00362251 s/step
# Meep progress: 965.4970000000001/1000.0 = 96.5% done in 4851.5s, 173.4s to go
# on time step 965776 (time=965.776), 0.003432 s/step
# Meep progress: 966.664/1000.0 = 96.7% done in 4855.5s, 167.4s to go
# on time step 966940 (time=966.94), 0.00343812 s/step
# Meep progress: 967.817/1000.0 = 96.8% done in 4859.5s, 161.6s to go
# on time step 968089 (time=968.089), 0.00348246 s/step
# Meep progress: 968.984/1000.0 = 96.9% done in 4863.5s, 155.7s to go
# on time step 969261 (time=969.261), 0.00341349 s/step
# Meep progress: 970.15/1000.0 = 97.0% done in 4867.5s, 149.8s to go
# on time step 970419 (time=970.419), 0.00345677 s/step
# Meep progress: 971.3100000000001/1000.0 = 97.1% done in 4871.5s, 143.9s to go
# on time step 971581 (time=971.581), 0.00344235 s/step
# Meep progress: 972.471/1000.0 = 97.2% done in 4875.5s, 138.0s to go
# on time step 972755 (time=972.755), 0.00340803 s/step
# Meep progress: 973.648/1000.0 = 97.4% done in 4879.5s, 132.1s to go
# on time step 973927 (time=973.927), 0.0034147 s/step
# Meep progress: 974.803/1000.0 = 97.5% done in 4883.5s, 126.2s to go
# on time step 975085 (time=975.085), 0.00345603 s/step
# Meep progress: 975.965/1000.0 = 97.6% done in 4887.5s, 120.4s to go
# on time step 976244 (time=976.244), 0.00345271 s/step
# Meep progress: 977.139/1000.0 = 97.7% done in 4891.5s, 114.4s to go
# on time step 977419 (time=977.419), 0.00340577 s/step
# Meep progress: 978.303/1000.0 = 97.8% done in 4895.5s, 108.6s to go
# on time step 978587 (time=978.587), 0.00342686 s/step
# Meep progress: 979.466/1000.0 = 97.9% done in 4899.5s, 102.7s to go
# on time step 979743 (time=979.743), 0.00346181 s/step
# Meep progress: 980.633/1000.0 = 98.1% done in 4903.5s, 96.8s to go
# on time step 980917 (time=980.917), 0.00340914 s/step
# Meep progress: 981.792/1000.0 = 98.2% done in 4907.5s, 91.0s to go
# on time step 982065 (time=982.065), 0.00348466 s/step
# Meep progress: 982.934/1000.0 = 98.3% done in 4911.5s, 85.3s to go
# on time step 983220 (time=983.22), 0.00346524 s/step
# Meep progress: 984.113/1000.0 = 98.4% done in 4915.5s, 79.4s to go
# on time step 984391 (time=984.391), 0.00341713 s/step
# Meep progress: 985.272/1000.0 = 98.5% done in 4919.5s, 73.5s to go
# on time step 985560 (time=985.56), 0.00342211 s/step
# Meep progress: 986.364/1000.0 = 98.6% done in 4923.5s, 68.1s to go
# on time step 986628 (time=986.628), 0.00374704 s/step
# Meep progress: 987.495/1000.0 = 98.7% done in 4927.5s, 62.4s to go
# on time step 987776 (time=987.776), 0.00348636 s/step
# Meep progress: 988.655/1000.0 = 98.9% done in 4931.5s, 56.6s to go
# on time step 988941 (time=988.941), 0.00343565 s/step
# Meep progress: 989.833/1000.0 = 99.0% done in 4935.5s, 50.7s to go
# on time step 990104 (time=990.104), 0.00343983 s/step
# Meep progress: 990.991/1000.0 = 99.1% done in 4939.5s, 44.9s to go
# on time step 991275 (time=991.275), 0.00341624 s/step
# Meep progress: 992.142/1000.0 = 99.2% done in 4943.5s, 39.2s to go
# on time step 992408 (time=992.408), 0.00353341 s/step
# Meep progress: 993.297/1000.0 = 99.3% done in 4947.5s, 33.4s to go
# on time step 993572 (time=993.572), 0.00343759 s/step
# Meep progress: 994.4590000000001/1000.0 = 99.4% done in 4951.5s, 27.6s to go
# on time step 994693 (time=994.693), 0.00357096 s/step
# Meep progress: 995.571/1000.0 = 99.6% done in 4955.5s, 22.0s to go
# on time step 995853 (time=995.853), 0.00345032 s/step
# Meep progress: 996.684/1000.0 = 99.7% done in 4959.5s, 16.5s to go
# on time step 996948 (time=996.948), 0.00365615 s/step
# Meep progress: 997.792/1000.0 = 99.8% done in 4963.5s, 11.0s to go
# on time step 998073 (time=998.073), 0.00355577 s/step
# Meep progress: 998.9540000000001/1000.0 = 99.9% done in 4967.5s, 5.2s to go
# on time step 999238 (time=999.238), 0.00343552 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 1000.0 (1000000 timesteps)
#      block, center = (-0.61,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
ez_data_up = np.array(ez_data_up)
ez_data_cen = np.array(ez_data_cen)
ez_data_down = np.array(ez_data_down)

print(len(ez_data_cen))

print(1 + int(round(t_xx/dt)))
# Out:
# 76923
# 41

# %%
plt.figure(dpi = 200)
start = round(len(ez_data_cen) / t *100)

for i in range(start,len(ez_data_cen),1):
    plt.subplot(3,1,1)
    plt.plot(i,ez_data_up[i],'k.')
    plt.subplot(3,1,2)
    plt.plot(i,ez_data_cen[i],'k.')
    plt.subplot(3,1,3)
    plt.plot(i,ez_data_down[i],'k.')
    if i ==  (len(ez_data_cen)-1):
        plt.subplot(3,1,1)
        plt.title('upper point')
        plt.ylabel('Electrical field amplitude')
        plt.xlabel('time (dt/point)')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_up[i],'b .')
        plt.subplot(3,1,2)
        plt.title('center point')
        plt.ylabel('Electrical field amplitude')
        plt.xlabel('time (dt/point)')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_cen[i],'b .')
        plt.subplot(3,1,3)
        plt.title('downer point')
        plt.ylabel('Electrical field amplitude')
        plt.xlabel('time (dt/point)')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_down[i],'b .')
# Out:
# /home/henry/miniconda3/envs/mp/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
# index1 and index2 . When we find the target's Electric field amplitude, we want to know where is amplitude value in array. So we set up index variable before running simulation.
index1_up = 0
index1_cen = 0
index1_down = 0

index2_up = 0
index2_cen = 0
index2_down = 0

# Period_max , period_next_mat . I set up those variables because I plan to use variables to store max amplitude value in a peiod in the following simulation. 
period_max_up = 0
period_max_cen = 0
period_max_down = 0
period_next_max_up = 0
period_next_max_cen = 0
period_next_max_down = 0

# Intial_index , end_index. ==>  "for loop" index
initial_index = round(len(ez_data_cen) / t * 200 )
print(initial_index)

end_index = len(ez_data_cen) - 2*( 1 +int(round(t_xx/dt))) 
print(end_index)
# Out:
# 15385
# 76841

# %%
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_up[j])
        period_next.append(ez_data_up[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if ((np.abs(period_max - period_next_max) / np.abs(min([period_max , period_next_max])) < 10**(-3))) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_up = np.where(ez_data_up == period_max)
        index1_up = index1_up[0]
        print(index1_up , '--- upper point index1')
        index2_up = np.where(ez_data_up == period_next_max)
        index2_up = index2_up[0]
        print(index2_up , '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('upper point 到達誤差範圍內的所需 meep time unit' , index2_up[0] / len(ez_data_up) * t , '\n')
        print('-----------------------------------------------------')
        break

        
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_cen[j])
        period_next.append(ez_data_cen[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if ((np.abs(period_max - period_next_max) / np.abs(min([period_max , period_next_max])) < 10**(-3))) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_cen = np.where(ez_data_cen == period_max)
        index1_cen = index1_cen[0]
        print(index1_cen, '--- upper point index1')
        index2_cen = np.where(ez_data_cen == period_next_max)
        index2_cen = index2_cen[0]
        print(index2_cen, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t')
        print('center point 到達誤差範圍內的所需 meep time unit' , index2_up[0] / len(ez_data_cen) * t , '\n')
        print('-----------------------------------------------------')
        break
        
    
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_down[j])
        period_next.append(ez_data_down[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if ((np.abs(period_max - period_next_max) / np.abs(min([period_max , period_next_max])) < 10**(-3))) :
        print(period_max, '-------- down point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- down point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_down = np.where(ez_data_down == period_max)
        index1_down = index1_down[0]
        print(index1_down, '--- down point index1')
        index2_down = np.where(ez_data_down == period_next_max)
        index2_down = index2_down[0]
        print(index2_down, '--- down point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('down point 到達誤差範圍內的所需 meep time unit' , index2_down[0] / len(ez_data_down) * t , '\n')
        print('-----------------------------------------------------')
        break

index1_max = index1_up[0]
index2_max = index2_up[0]
if index1_cen[0] > index1_max :
    index1_max = index1_cen[0]
elif index1_down[0] > index1_max :
    index1_max = index1_down[0]
print(index1_max)

if index2_cen[0] > index2_max :
    index2_max = index2_cen[0]
elif index2_down[0] > index2_max :
    index2_max = index2_down[0]
print(index2_max)
# Out:
# (0.07633408671947699+0j) -------- upper point one period 內最大振福
# (0.07633454082327452+0j) ------- upper point one next_period 內最大振福
# (-4.541037975369644e-07+0j) ----- 振幅誤差
# [15513] --- upper point index1
# [15554] --- upper point index2
# (0.07633408671947699+0j) 	 (0.07633454082327452+0j) 	 (-4.541037975369644e-07+0j)
# upper point 到達誤差範圍內的所需 meep time unit 101.1011011011011
#
# -----------------------------------------------------
# (0.19899027323597468+0j) -------- upper point one period 內最大振福
# (0.19915187369574358+0j) ------- upper point one next_period 內最大振福
# (-0.00016160045976890136+0j) ----- 振幅誤差
# [15439] --- upper point index1
# [15480] --- upper point index2
# (0.19899027323597468+0j) 	 (0.19915187369574358+0j) 	 (-0.00016160045976890136+0j)
# center point 到達誤差範圍內的所需 meep time unit 101.1011011011011
#
# -----------------------------------------------------
# (0.07730785695270494+0j) -------- down point one period 內最大振福
# (0.07736804515137703+0j) ------- down point one next_period 內最大振福
# (-6.018819867209535e-05+0j) ----- 振幅誤差
# [15758] --- down point index1
# [15799] --- down point index2
# (0.07730785695270494+0j) 	 (0.07736804515137703+0j) 	 (-6.018819867209535e-05+0j)
# down point 到達誤差範圍內的所需 meep time unit 102.6936026936027
#
# -----------------------------------------------------
# 15758
# 15799

# %%
plt.figure(dpi = 150)
plt.title('center point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_up[index1_max]
for i in range(index1_max , index2_max) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_up[i] , 'b.')
    if max_value < ez_data_up[i] :
        max_value = ez_data_up[i]

print(max_value)
# Out:
# (0.07676813866748299+0j)

# %%
plt.figure(dpi = 150)
plt.title('center point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_cen[index1_max]
for i in range(index1_max , index2_max) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_cen[i] , 'b.')
    if max_value < ez_data_cen[i] :
        max_value = ez_data_cen[i]

print(max_value)
# Out:
# (0.1987566396056151+0j)

# %%
plt.figure(dpi = 150)
plt.title('downner point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
for i in range(index1_max , index2_max) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_down[i] , 'b.')
    
max_value = ez_data_down[index1_max]
for i in range(index1_max , index2_max) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_down[i] , 'b.')
    if max_value < ez_data_down[i] :
        max_value = ez_data_down[i]

print(max_value)
# Out:
# (0.07730785695270494+0j)
