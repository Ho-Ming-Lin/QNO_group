# %% [markdown]
# Here, we want to how level that the electric near field just above cell affected by adjacent cells. In this simulation, we simulated the structure which we called "Beta_Alpha_Beta structure".

# %%
import meep as mp
import numpy as np
import math
import matplotlib.pyplot as plt

#sim.reset_meep()
resolution = 500  # pixels/μm

dpml = 1.0  # PML thickness
dsub = 0.5  # substrate thickness
dcaa = 0.06  # air rigion for alpha structure
# alpha structure is that one period = 200nm，sigle cell width = 80nm locate at center
dcab = 0.025 # air rigion for beta structure 
# beta structure is that one period = 200nm，sigle cell width = 150nm locate at center
gp = 0.2  # grating periodicity
gh = 0.6  # grating height
gwa = 0.08 # alpha grating cell width
gwb = 0.15 # beta grating cell width

num_cells = 3 # number of grating unit cells

# air region thickness adjacent to grating
dair = 1 

wvl = 0.532  # center wavelength
fcen = 1 / wvl  # center frequency

glass = mp.Medium(index= 2.6678)

pml_layers = [mp.PML(thickness=dpml, direction = mp.X )]

symmetries = [mp.Mirror(mp.Y)]

sx = dpml + dsub + gh + dair + dpml
sy = num_cells*gp
#sy = ((dcaa + gwa + dcaa)*2 + (dcab + gwb + dcab))*num_cells
cell_size = mp.Vector3(sx, sy)

sources = [
    mp.Source(
        mp.ContinuousSource(frequency = fcen), # frequemcy = 2原因是 meep 的 C=1，所以 1/? = 0.5 um，?即是2
        component = mp.Ez,
        center = mp.Vector3(-0.5 * sx + dpml ),
        size = mp.Vector3(y = sy),
    )
]

geometry = [
    mp.Block(
        material=glass,
        size=mp.Vector3(dsub, mp.inf, mp.inf),
        center=mp.Vector3(-0.5 * sx + dpml + 0.04 + dsub/2),
    )
]

# %%
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp/2 + (j * 3 * gp),
                #-0.5 * sy + gp/2,
            ),
        )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwa, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + gp + gp/2,
            ),
        )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + 2*gp + gp/2  + (j * 3 * gp),
                #0.5 * sy - gp/2,
            ),
        )
    )

# %%
k_point = mp.Vector3()  # Gamma 點表示週期邊界條件
k_points = [k_point]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
    symmetries=symmetries,
    k_point = mp.Vector3(),
)


# %matplotlib inline
plt.figure(dpi = 125)
sim.plot2D()
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (-0.76,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
t_xx = (.532) # Air 光速跑完 波長 532 nm 入射光 所需的 meep unit time
dt = (t_xx / 40) # cut 40 sections in a period time
t = 1000 # Total simulation time

x_obs = -0.5 * sx + dpml + dsub + gh + 0.002 # Set up a x coordinate of observed point
# The meaning of down , cen , up are the cordinate in each cell structure. (Reference stucture diagram just show above)
y_obs_down = -0.5 * sy + gp/2
y_obs_cen = -0.5 * sy + 3*gp/2
y_obs_up = 0.5 * sy - gp/2

print(int((t_xx)/dt))
# Out:
# 40

# %%
### ez_data_list = [[] for _ in range(int((t_xx)/dt))]

# 儲存場量數值的列表，定義為擁有 10 列的空二維陣列
ez_data_cen = []
ez_data_up = []
ez_data_down = []
###
def get_slice(sim):
    ez_data_cen.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_cen) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_up.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_up) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_down.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_down) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))

sim.run(mp.at_every(dt , get_slice) , until = t)

plt.figure(dpi = 100)
sim.plot2D(fields=mp.Ez)
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00131106 s
# Working in 2D dimensions.
# Computational cell is 4.1 x 0.6 x 0 with resolution 500
#      block, center = (-0.76,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
# time for set_epsilon = 0.299977 s
# -----------
# Meep progress: 1.76/1000.0 = 0.2% done in 4.0s, 2269.5s to go
# on time step 1760 (time=1.76), 0.00227355 s/step
# Meep progress: 3.253/1000.0 = 0.3% done in 8.0s, 2452.1s to go
# on time step 3253 (time=3.253), 0.00267993 s/step
# Meep progress: 5.059/1000.0 = 0.5% done in 12.0s, 2360.6s to go
# on time step 5060 (time=5.06), 0.00221431 s/step
# Meep progress: 6.454/1000.0 = 0.6% done in 16.0s, 2463.6s to go
# on time step 6455 (time=6.455), 0.00286774 s/step
# Meep progress: 7.599/1000.0 = 0.8% done in 20.0s, 2612.7s to go
# on time step 7600 (time=7.6), 0.00349539 s/step
# Meep progress: 8.813/1000.0 = 0.9% done in 24.0s, 2700.4s to go
# on time step 8814 (time=8.814), 0.00329908 s/step
# Meep progress: 9.966000000000001/1000.0 = 1.0% done in 28.0s, 2782.6s to go
# on time step 9967 (time=9.967), 0.00347004 s/step
# Meep progress: 11.086/1000.0 = 1.1% done in 32.0s, 2855.5s to go
# on time step 11089 (time=11.089), 0.00356765 s/step
# Meep progress: 12.35/1000.0 = 1.2% done in 36.0s, 2880.0s to go
# on time step 12353 (time=12.353), 0.00316463 s/step
# Meep progress: 13.577/1000.0 = 1.4% done in 40.0s, 2907.3s to go
# on time step 13580 (time=13.58), 0.00326046 s/step
# Meep progress: 14.757/1000.0 = 1.5% done in 44.0s, 2938.7s to go
# on time step 14760 (time=14.76), 0.003391 s/step
# Meep progress: 15.931000000000001/1000.0 = 1.6% done in 48.0s, 2966.2s to go
# on time step 15934 (time=15.934), 0.00340862 s/step
# Meep progress: 17.135/1000.0 = 1.7% done in 52.0s, 2984.1s to go
# on time step 17137 (time=17.137), 0.00332606 s/step
# Meep progress: 18.364/1000.0 = 1.8% done in 56.0s, 2994.8s to go
# on time step 18367 (time=18.367), 0.00325418 s/step
# Meep progress: 19.604/1000.0 = 2.0% done in 60.0s, 3002.0s to go
# on time step 19607 (time=19.607), 0.00322848 s/step
# Meep progress: 20.87/1000.0 = 2.1% done in 64.0s, 3003.9s to go
# on time step 20874 (time=20.874), 0.00315827 s/step
# Meep progress: 22.09/1000.0 = 2.2% done in 68.0s, 3011.6s to go
# on time step 22094 (time=22.094), 0.00327899 s/step
# Meep progress: 23.321/1000.0 = 2.3% done in 72.0s, 3016.6s to go
# on time step 23325 (time=23.325), 0.0032511 s/step
# Meep progress: 24.541/1000.0 = 2.5% done in 76.0s, 3022.1s to go
# on time step 24546 (time=24.546), 0.00327778 s/step
# Meep progress: 25.763/1000.0 = 2.6% done in 80.0s, 3026.5s to go
# on time step 25768 (time=25.768), 0.00327481 s/step
# Meep progress: 26.989/1000.0 = 2.7% done in 84.0s, 3029.6s to go
# on time step 26995 (time=26.995), 0.00326123 s/step
# Meep progress: 28.208000000000002/1000.0 = 2.8% done in 88.0s, 3032.9s to go
# on time step 28214 (time=28.214), 0.00328315 s/step
# Meep progress: 29.498/1000.0 = 2.9% done in 92.0s, 3028.1s to go
# on time step 29504 (time=29.504), 0.00310113 s/step
# Meep progress: 30.784/1000.0 = 3.1% done in 96.0s, 3023.8s to go
# on time step 30789 (time=30.789), 0.00311437 s/step
# Meep progress: 32.071/1000.0 = 3.2% done in 100.0s, 3019.4s to go
# on time step 32077 (time=32.077), 0.00310727 s/step
# Meep progress: 33.347/1000.0 = 3.3% done in 104.0s, 3016.0s to go
# on time step 33354 (time=33.354), 0.0031345 s/step
# Meep progress: 34.617/1000.0 = 3.5% done in 108.0s, 3013.1s to go
# on time step 34625 (time=34.625), 0.00314923 s/step
# Meep progress: 35.891/1000.0 = 3.6% done in 112.0s, 3009.8s to go
# on time step 35900 (time=35.9), 0.00313743 s/step
# Meep progress: 37.177/1000.0 = 3.7% done in 116.0s, 3005.4s to go
# on time step 37186 (time=37.186), 0.00311185 s/step
# Meep progress: 38.455/1000.0 = 3.8% done in 120.0s, 3001.7s to go
# on time step 38465 (time=38.465), 0.00312871 s/step
# Meep progress: 39.748/1000.0 = 4.0% done in 124.0s, 2996.8s to go
# on time step 39758 (time=39.758), 0.00309513 s/step
# Meep progress: 41.036/1000.0 = 4.1% done in 128.1s, 2992.4s to go
# on time step 41046 (time=41.046), 0.00310651 s/step
# Meep progress: 42.313/1000.0 = 4.2% done in 132.1s, 2988.8s to go
# on time step 42323 (time=42.323), 0.00313333 s/step
# Meep progress: 43.613/1000.0 = 4.4% done in 136.1s, 2983.5s to go
# on time step 43624 (time=43.624), 0.00307532 s/step
# Meep progress: 44.879/1000.0 = 4.5% done in 140.1s, 2980.7s to go
# on time step 44890 (time=44.89), 0.00316141 s/step
# Meep progress: 46.164/1000.0 = 4.6% done in 144.1s, 2976.5s to go
# on time step 46176 (time=46.176), 0.00311353 s/step
# Meep progress: 47.445/1000.0 = 4.7% done in 148.1s, 2972.6s to go
# on time step 47456 (time=47.456), 0.00312561 s/step
# Meep progress: 48.709/1000.0 = 4.9% done in 152.1s, 2969.8s to go
# on time step 48721 (time=48.721), 0.00316389 s/step
# Meep progress: 49.983000000000004/1000.0 = 5.0% done in 156.1s, 2966.2s to go
# on time step 49996 (time=49.996), 0.00313939 s/step
# Meep progress: 51.275/1000.0 = 5.1% done in 160.1s, 2961.6s to go
# on time step 51288 (time=51.288), 0.00309925 s/step
# Meep progress: 52.565/1000.0 = 5.3% done in 164.1s, 2957.2s to go
# on time step 52579 (time=52.579), 0.0031007 s/step
# Meep progress: 53.825/1000.0 = 5.4% done in 168.1s, 2954.5s to go
# on time step 53836 (time=53.836), 0.00318481 s/step
# Meep progress: 55.105000000000004/1000.0 = 5.5% done in 172.1s, 2950.5s to go
# on time step 55120 (time=55.12), 0.00311572 s/step
# Meep progress: 56.386/1000.0 = 5.6% done in 176.1s, 2946.5s to go
# on time step 56402 (time=56.402), 0.00312162 s/step
# Meep progress: 57.672000000000004/1000.0 = 5.8% done in 180.1s, 2942.3s to go
# on time step 57688 (time=57.688), 0.00311111 s/step
# Meep progress: 58.961/1000.0 = 5.9% done in 184.1s, 2937.9s to go
# on time step 58977 (time=58.977), 0.00310342 s/step
# Meep progress: 60.24/1000.0 = 6.0% done in 188.1s, 2934.0s to go
# on time step 60257 (time=60.257), 0.0031264 s/step
# Meep progress: 61.528/1000.0 = 6.2% done in 192.1s, 2929.7s to go
# on time step 61545 (time=61.545), 0.00310674 s/step
# Meep progress: 62.834/1000.0 = 6.3% done in 196.1s, 2924.5s to go
# on time step 62851 (time=62.851), 0.00306364 s/step
# Meep progress: 64.09/1000.0 = 6.4% done in 200.1s, 2921.8s to go
# on time step 64108 (time=64.108), 0.00318304 s/step
# Meep progress: 65.394/1000.0 = 6.5% done in 204.1s, 2916.7s to go
# on time step 65412 (time=65.412), 0.00306992 s/step
# Meep progress: 66.679/1000.0 = 6.7% done in 208.1s, 2912.6s to go
# on time step 66697 (time=66.697), 0.00311316 s/step
# Meep progress: 67.962/1000.0 = 6.8% done in 212.1s, 2908.5s to go
# on time step 67980 (time=67.98), 0.00311852 s/step
# Meep progress: 69.251/1000.0 = 6.9% done in 216.1s, 2904.3s to go
# on time step 69268 (time=69.268), 0.00310734 s/step
# Meep progress: 70.54/1000.0 = 7.1% done in 220.1s, 2900.0s to go
# on time step 70558 (time=70.558), 0.00310227 s/step
# Meep progress: 71.84/1000.0 = 7.2% done in 224.1s, 2895.2s to go
# on time step 71859 (time=71.859), 0.00307475 s/step
# Meep progress: 73.124/1000.0 = 7.3% done in 228.1s, 2891.1s to go
# on time step 73143 (time=73.143), 0.00311532 s/step
# Meep progress: 74.306/1000.0 = 7.4% done in 232.1s, 2891.4s to go
# on time step 74320 (time=74.32), 0.0034013 s/step
# Meep progress: 75.46900000000001/1000.0 = 7.5% done in 236.1s, 2892.3s to go
# on time step 75485 (time=75.485), 0.00343555 s/step
# Meep progress: 76.581/1000.0 = 7.7% done in 240.1s, 2895.1s to go
# on time step 76598 (time=76.598), 0.00359529 s/step
# Meep progress: 77.723/1000.0 = 7.8% done in 244.1s, 2896.5s to go
# on time step 77743 (time=77.743), 0.00349488 s/step
# Meep progress: 78.93/1000.0 = 7.9% done in 248.1s, 2895.2s to go
# on time step 78949 (time=78.949), 0.00331796 s/step
# Meep progress: 80.136/1000.0 = 8.0% done in 252.1s, 2893.8s to go
# on time step 80156 (time=80.156), 0.00331519 s/step
# Meep progress: 81.32300000000001/1000.0 = 8.1% done in 256.1s, 2893.1s to go
# on time step 81343 (time=81.343), 0.00337021 s/step
# Meep progress: 82.566/1000.0 = 8.3% done in 260.1s, 2890.2s to go
# on time step 82585 (time=82.585), 0.00322178 s/step
# Meep progress: 83.824/1000.0 = 8.4% done in 264.1s, 2886.7s to go
# on time step 83844 (time=83.844), 0.00317913 s/step
# Meep progress: 85.083/1000.0 = 8.5% done in 268.1s, 2883.1s to go
# on time step 85104 (time=85.104), 0.00317465 s/step
# Meep progress: 86.35000000000001/1000.0 = 8.6% done in 272.1s, 2879.2s to go
# on time step 86370 (time=86.37), 0.00316007 s/step
# Meep progress: 87.61/1000.0 = 8.8% done in 276.1s, 2875.5s to go
# on time step 87630 (time=87.63), 0.0031759 s/step
# Meep progress: 88.888/1000.0 = 8.9% done in 280.1s, 2871.2s to go
# on time step 88909 (time=88.909), 0.00312814 s/step
# Meep progress: 90.156/1000.0 = 9.0% done in 284.1s, 2867.3s to go
# on time step 90176 (time=90.176), 0.00315846 s/step
# Meep progress: 91.358/1000.0 = 9.1% done in 288.1s, 2865.6s to go
# on time step 91380 (time=91.38), 0.00332302 s/step
# Meep progress: 92.633/1000.0 = 9.3% done in 292.1s, 2861.4s to go
# on time step 92653 (time=92.653), 0.00314258 s/step
# Meep progress: 93.871/1000.0 = 9.4% done in 296.1s, 2858.4s to go
# on time step 93889 (time=93.889), 0.00323741 s/step
# Meep progress: 95.136/1000.0 = 9.5% done in 300.1s, 2854.6s to go
# on time step 95156 (time=95.156), 0.00315761 s/step
# Meep progress: 96.417/1000.0 = 9.6% done in 304.1s, 2850.2s to go
# on time step 96435 (time=96.435), 0.00312858 s/step
# Meep progress: 97.666/1000.0 = 9.8% done in 308.1s, 2846.8s to go
# on time step 97686 (time=97.686), 0.00319916 s/step
# Meep progress: 98.94200000000001/1000.0 = 9.9% done in 312.1s, 2842.6s to go
# on time step 98962 (time=98.962), 0.00313639 s/step
# Meep progress: 100.224/1000.0 = 10.0% done in 316.1s, 2838.1s to go
# on time step 100246 (time=100.246), 0.00311692 s/step
# Meep progress: 101.49300000000001/1000.0 = 10.1% done in 320.1s, 2834.1s to go
# on time step 101515 (time=101.515), 0.00315328 s/step
# Meep progress: 102.77/1000.0 = 10.3% done in 324.1s, 2829.9s to go
# on time step 102789 (time=102.789), 0.00314058 s/step
# Meep progress: 104.031/1000.0 = 10.4% done in 328.1s, 2826.1s to go
# on time step 104053 (time=104.053), 0.00316557 s/step
# Meep progress: 105.304/1000.0 = 10.5% done in 332.1s, 2822.0s to go
# on time step 105323 (time=105.323), 0.00315173 s/step
# Meep progress: 106.571/1000.0 = 10.7% done in 336.1s, 2818.0s to go
# on time step 106593 (time=106.593), 0.00315224 s/step
# Meep progress: 107.83500000000001/1000.0 = 10.8% done in 340.1s, 2814.2s to go
# on time step 107856 (time=107.856), 0.00316898 s/step
# Meep progress: 109.108/1000.0 = 10.9% done in 344.2s, 2810.1s to go
# on time step 109132 (time=109.132), 0.00313569 s/step
# Meep progress: 110.399/1000.0 = 11.0% done in 348.2s, 2805.4s to go
# on time step 110423 (time=110.423), 0.00309868 s/step
# Meep progress: 111.651/1000.0 = 11.2% done in 352.2s, 2801.9s to go
# on time step 111673 (time=111.673), 0.00320194 s/step
# Meep progress: 112.9/1000.0 = 11.3% done in 356.2s, 2798.4s to go
# on time step 112924 (time=112.924), 0.00319769 s/step
# Meep progress: 114.141/1000.0 = 11.4% done in 360.2s, 2795.2s to go
# on time step 114164 (time=114.164), 0.00322581 s/step
# Meep progress: 115.399/1000.0 = 11.5% done in 364.2s, 2791.5s to go
# on time step 115419 (time=115.419), 0.00318927 s/step
# Meep progress: 116.682/1000.0 = 11.7% done in 368.2s, 2787.1s to go
# on time step 116705 (time=116.705), 0.0031119 s/step
# Meep progress: 117.94/1000.0 = 11.8% done in 372.2s, 2783.3s to go
# on time step 117964 (time=117.964), 0.00317891 s/step
# Meep progress: 119.21600000000001/1000.0 = 11.9% done in 376.2s, 2779.1s to go
# on time step 119241 (time=119.241), 0.00313264 s/step
# Meep progress: 120.48700000000001/1000.0 = 12.0% done in 380.2s, 2775.1s to go
# on time step 120513 (time=120.513), 0.00314665 s/step
# Meep progress: 121.765/1000.0 = 12.2% done in 384.2s, 2770.8s to go
# on time step 121790 (time=121.79), 0.00313312 s/step
# Meep progress: 123.033/1000.0 = 12.3% done in 388.2s, 2766.8s to go
# on time step 123056 (time=123.056), 0.00316 s/step
# Meep progress: 124.31/1000.0 = 12.4% done in 392.2s, 2762.6s to go
# on time step 124335 (time=124.335), 0.003129 s/step
# Meep progress: 125.563/1000.0 = 12.6% done in 396.2s, 2759.0s to go
# on time step 125588 (time=125.588), 0.00319524 s/step
# Meep progress: 126.783/1000.0 = 12.7% done in 400.2s, 2756.2s to go
# on time step 126809 (time=126.809), 0.00327672 s/step
# Meep progress: 128.054/1000.0 = 12.8% done in 404.2s, 2752.1s to go
# on time step 128083 (time=128.083), 0.00314147 s/step
# Meep progress: 129.30100000000002/1000.0 = 12.9% done in 408.2s, 2748.6s to go
# on time step 129330 (time=129.33), 0.00320908 s/step
# Meep progress: 130.572/1000.0 = 13.1% done in 412.2s, 2744.5s to go
# on time step 130600 (time=130.6), 0.00315255 s/step
# Meep progress: 131.845/1000.0 = 13.2% done in 416.2s, 2740.4s to go
# on time step 131874 (time=131.874), 0.00314045 s/step
# Meep progress: 133.109/1000.0 = 13.3% done in 420.2s, 2736.5s to go
# on time step 133140 (time=133.14), 0.00316002 s/step
# Meep progress: 134.391/1000.0 = 13.4% done in 424.2s, 2732.1s to go
# on time step 134421 (time=134.421), 0.00312299 s/step
# Meep progress: 135.659/1000.0 = 13.6% done in 428.2s, 2728.1s to go
# on time step 135689 (time=135.689), 0.00315643 s/step
# Meep progress: 136.92600000000002/1000.0 = 13.7% done in 432.2s, 2724.2s to go
# on time step 136957 (time=136.957), 0.00315507 s/step
# Meep progress: 138.198/1000.0 = 13.8% done in 436.2s, 2720.1s to go
# on time step 138228 (time=138.228), 0.00314896 s/step
# Meep progress: 139.472/1000.0 = 13.9% done in 440.2s, 2715.9s to go
# on time step 139501 (time=139.501), 0.00314648 s/step
# Meep progress: 140.731/1000.0 = 14.1% done in 444.2s, 2712.1s to go
# on time step 140761 (time=140.761), 0.00317527 s/step
# Meep progress: 141.994/1000.0 = 14.2% done in 448.2s, 2708.2s to go
# on time step 142023 (time=142.023), 0.00317007 s/step
# Meep progress: 143.261/1000.0 = 14.3% done in 452.2s, 2704.2s to go
# on time step 143292 (time=143.292), 0.00315215 s/step
# Meep progress: 144.543/1000.0 = 14.5% done in 456.2s, 2699.9s to go
# on time step 144575 (time=144.575), 0.00311951 s/step
# Meep progress: 145.804/1000.0 = 14.6% done in 460.2s, 2696.1s to go
# on time step 145835 (time=145.835), 0.00317799 s/step
# Meep progress: 147.08/1000.0 = 14.7% done in 464.2s, 2691.9s to go
# on time step 147111 (time=147.111), 0.003135 s/step
# Meep progress: 148.342/1000.0 = 14.8% done in 468.2s, 2688.0s to go
# on time step 148374 (time=148.374), 0.00316799 s/step
# Meep progress: 149.636/1000.0 = 15.0% done in 472.2s, 2683.5s to go
# on time step 149669 (time=149.669), 0.00309198 s/step
# Meep progress: 150.91/1000.0 = 15.1% done in 476.2s, 2679.3s to go
# on time step 150945 (time=150.945), 0.00313776 s/step
# Meep progress: 152.193/1000.0 = 15.2% done in 480.2s, 2675.0s to go
# on time step 152227 (time=152.227), 0.00312181 s/step
# Meep progress: 153.458/1000.0 = 15.3% done in 484.2s, 2671.1s to go
# on time step 153492 (time=153.492), 0.00316402 s/step
# Meep progress: 154.659/1000.0 = 15.5% done in 488.2s, 2668.5s to go
# on time step 154695 (time=154.695), 0.00332694 s/step
# Meep progress: 155.929/1000.0 = 15.6% done in 492.2s, 2664.4s to go
# on time step 155967 (time=155.967), 0.00314642 s/step
# Meep progress: 157.15200000000002/1000.0 = 15.7% done in 496.2s, 2661.3s to go
# on time step 157188 (time=157.188), 0.00327775 s/step
# Meep progress: 158.337/1000.0 = 15.8% done in 500.2s, 2658.9s to go
# on time step 158374 (time=158.374), 0.00337304 s/step
# Meep progress: 159.522/1000.0 = 16.0% done in 504.2s, 2656.6s to go
# on time step 159561 (time=159.561), 0.00337208 s/step
# Meep progress: 160.774/1000.0 = 16.1% done in 508.2s, 2652.8s to go
# on time step 160812 (time=160.812), 0.00319848 s/step
# Meep progress: 162.018/1000.0 = 16.2% done in 512.2s, 2649.3s to go
# on time step 162058 (time=162.058), 0.00321192 s/step
# Meep progress: 163.273/1000.0 = 16.3% done in 516.2s, 2645.5s to go
# on time step 163310 (time=163.31), 0.00319627 s/step
# Meep progress: 164.505/1000.0 = 16.5% done in 520.2s, 2642.1s to go
# on time step 164544 (time=164.544), 0.00324356 s/step
# Meep progress: 165.772/1000.0 = 16.6% done in 524.2s, 2638.1s to go
# on time step 165813 (time=165.813), 0.00315233 s/step
# Meep progress: 167.023/1000.0 = 16.7% done in 528.2s, 2634.3s to go
# on time step 167065 (time=167.065), 0.00319647 s/step
# Meep progress: 168.219/1000.0 = 16.8% done in 532.2s, 2631.6s to go
# on time step 168259 (time=168.259), 0.00335194 s/step
# Meep progress: 169.464/1000.0 = 16.9% done in 536.2s, 2628.0s to go
# on time step 169505 (time=169.505), 0.00321218 s/step
# Meep progress: 170.747/1000.0 = 17.1% done in 540.2s, 2623.7s to go
# on time step 170789 (time=170.789), 0.00311712 s/step
# Meep progress: 172.034/1000.0 = 17.2% done in 544.2s, 2619.3s to go
# on time step 172079 (time=172.079), 0.003103 s/step
# Meep progress: 173.31300000000002/1000.0 = 17.3% done in 548.2s, 2615.0s to go
# on time step 173357 (time=173.357), 0.0031314 s/step
# Meep progress: 174.582/1000.0 = 17.5% done in 552.2s, 2610.9s to go
# on time step 174627 (time=174.627), 0.00314967 s/step
# Meep progress: 175.89000000000001/1000.0 = 17.6% done in 556.2s, 2606.1s to go
# on time step 175933 (time=175.933), 0.00306429 s/step
# Meep progress: 177.168/1000.0 = 17.7% done in 560.2s, 2601.9s to go
# on time step 177214 (time=177.214), 0.00312265 s/step
# Meep progress: 178.459/1000.0 = 17.8% done in 564.2s, 2597.5s to go
# on time step 178500 (time=178.5), 0.00311278 s/step
# Meep progress: 179.73/1000.0 = 18.0% done in 568.2s, 2593.4s to go
# on time step 179773 (time=179.773), 0.00314358 s/step
# Meep progress: 181.014/1000.0 = 18.1% done in 572.2s, 2589.1s to go
# on time step 181059 (time=181.059), 0.0031118 s/step
# Meep progress: 182.291/1000.0 = 18.2% done in 576.2s, 2584.9s to go
# on time step 182339 (time=182.339), 0.0031253 s/step
# Meep progress: 183.58100000000002/1000.0 = 18.4% done in 580.2s, 2580.5s to go
# on time step 183628 (time=183.628), 0.00310507 s/step
# Meep progress: 184.873/1000.0 = 18.5% done in 584.2s, 2576.0s to go
# on time step 184919 (time=184.919), 0.00309956 s/step
# Meep progress: 186.132/1000.0 = 18.6% done in 588.3s, 2572.1s to go
# on time step 186178 (time=186.178), 0.00317959 s/step
# Meep progress: 187.413/1000.0 = 18.7% done in 592.3s, 2567.9s to go
# on time step 187460 (time=187.46), 0.00312228 s/step
# Meep progress: 188.678/1000.0 = 18.9% done in 596.3s, 2563.9s to go
# on time step 188724 (time=188.724), 0.00316566 s/step
# Meep progress: 189.955/1000.0 = 19.0% done in 600.3s, 2559.7s to go
# on time step 189995 (time=189.995), 0.00315027 s/step
# Meep progress: 191.139/1000.0 = 19.1% done in 604.3s, 2557.1s to go
# on time step 191177 (time=191.177), 0.0033885 s/step
# Meep progress: 192.195/1000.0 = 19.2% done in 608.3s, 2556.6s to go
# on time step 192237 (time=192.237), 0.00377598 s/step
# Meep progress: 193.389/1000.0 = 19.3% done in 612.3s, 2553.7s to go
# on time step 193438 (time=193.438), 0.0033325 s/step
# Meep progress: 194.627/1000.0 = 19.5% done in 616.3s, 2550.1s to go
# on time step 194676 (time=194.676), 0.00323358 s/step
# Meep progress: 195.861/1000.0 = 19.6% done in 620.3s, 2546.6s to go
# on time step 195912 (time=195.912), 0.00323744 s/step
# Meep progress: 197.11/1000.0 = 19.7% done in 624.3s, 2542.8s to go
# on time step 197157 (time=197.157), 0.00321334 s/step
# Meep progress: 198.226/1000.0 = 19.8% done in 628.3s, 2541.2s to go
# on time step 198272 (time=198.272), 0.00358947 s/step
# Meep progress: 199.36/1000.0 = 19.9% done in 632.3s, 2539.2s to go
# on time step 199409 (time=199.409), 0.00351985 s/step
# Meep progress: 200.583/1000.0 = 20.1% done in 636.3s, 2535.8s to go
# on time step 200630 (time=200.63), 0.00327614 s/step
# Meep progress: 201.728/1000.0 = 20.2% done in 640.3s, 2533.7s to go
# on time step 201776 (time=201.776), 0.00349059 s/step
# Meep progress: 202.87/1000.0 = 20.3% done in 644.3s, 2531.5s to go
# on time step 202921 (time=202.921), 0.00349443 s/step
# Meep progress: 204.083/1000.0 = 20.4% done in 648.3s, 2528.3s to go
# on time step 204137 (time=204.137), 0.00329113 s/step
# Meep progress: 205.348/1000.0 = 20.5% done in 652.3s, 2524.2s to go
# on time step 205400 (time=205.4), 0.00316891 s/step
# Meep progress: 206.518/1000.0 = 20.7% done in 656.3s, 2521.6s to go
# on time step 206556 (time=206.556), 0.00346263 s/step
# Meep progress: 207.596/1000.0 = 20.8% done in 660.3s, 2520.3s to go
# on time step 207648 (time=207.648), 0.00366507 s/step
# Meep progress: 208.743/1000.0 = 20.9% done in 664.3s, 2518.0s to go
# on time step 208792 (time=208.792), 0.00349808 s/step
# Meep progress: 209.947/1000.0 = 21.0% done in 668.3s, 2514.8s to go
# on time step 209989 (time=209.989), 0.00334192 s/step
# Meep progress: 210.991/1000.0 = 21.1% done in 672.3s, 2514.1s to go
# on time step 211038 (time=211.038), 0.00381462 s/step
# Meep progress: 212.18200000000002/1000.0 = 21.2% done in 676.3s, 2511.0s to go
# on time step 212233 (time=212.233), 0.0033484 s/step
# Meep progress: 213.328/1000.0 = 21.3% done in 680.3s, 2508.7s to go
# on time step 213377 (time=213.377), 0.00349655 s/step
# Meep progress: 214.507/1000.0 = 21.5% done in 684.3s, 2505.8s to go
# on time step 214549 (time=214.549), 0.00341321 s/step
# Meep progress: 215.61700000000002/1000.0 = 21.6% done in 688.3s, 2503.9s to go
# on time step 215663 (time=215.663), 0.0035909 s/step
# Meep progress: 216.83700000000002/1000.0 = 21.7% done in 692.3s, 2500.4s to go
# on time step 216890 (time=216.89), 0.00326212 s/step
# Meep progress: 218.104/1000.0 = 21.8% done in 696.3s, 2496.2s to go
# on time step 218156 (time=218.156), 0.00316154 s/step
# Meep progress: 219.29/1000.0 = 21.9% done in 700.3s, 2493.2s to go
# on time step 219339 (time=219.339), 0.00338225 s/step
# Meep progress: 220.447/1000.0 = 22.0% done in 704.3s, 2490.6s to go
# on time step 220499 (time=220.499), 0.00344916 s/step
# Meep progress: 221.585/1000.0 = 22.2% done in 708.3s, 2488.3s to go
# on time step 221634 (time=221.634), 0.0035267 s/step
# Meep progress: 222.784/1000.0 = 22.3% done in 712.3s, 2485.0s to go
# on time step 222824 (time=222.824), 0.00336313 s/step
# Meep progress: 223.869/1000.0 = 22.4% done in 716.3s, 2483.4s to go
# on time step 223921 (time=223.921), 0.00364688 s/step
# Meep progress: 225.083/1000.0 = 22.5% done in 720.3s, 2479.9s to go
# on time step 225129 (time=225.129), 0.00331243 s/step
# Meep progress: 226.33/1000.0 = 22.6% done in 724.3s, 2476.0s to go
# on time step 226385 (time=226.385), 0.00318603 s/step
# Meep progress: 227.543/1000.0 = 22.8% done in 728.3s, 2472.5s to go
# on time step 227594 (time=227.594), 0.00331041 s/step
# Meep progress: 228.71/1000.0 = 22.9% done in 732.3s, 2469.6s to go
# on time step 228756 (time=228.756), 0.00344495 s/step
# Meep progress: 229.886/1000.0 = 23.0% done in 736.3s, 2466.7s to go
# on time step 229944 (time=229.944), 0.00336728 s/step
# Meep progress: 231.086/1000.0 = 23.1% done in 740.3s, 2463.3s to go
# on time step 231132 (time=231.132), 0.00336777 s/step
# Meep progress: 232.18200000000002/1000.0 = 23.2% done in 744.3s, 2461.5s to go
# on time step 232223 (time=232.223), 0.00366682 s/step
# Meep progress: 233.26500000000001/1000.0 = 23.3% done in 748.3s, 2459.7s to go
# on time step 233315 (time=233.315), 0.0036631 s/step
# Meep progress: 234.41400000000002/1000.0 = 23.4% done in 752.3s, 2457.1s to go
# on time step 234468 (time=234.468), 0.00346939 s/step
# Meep progress: 235.643/1000.0 = 23.6% done in 756.3s, 2453.3s to go
# on time step 235696 (time=235.696), 0.00325806 s/step
# Meep progress: 236.80100000000002/1000.0 = 23.7% done in 760.3s, 2450.5s to go
# on time step 236850 (time=236.85), 0.00346807 s/step
# Meep progress: 237.885/1000.0 = 23.8% done in 764.3s, 2448.7s to go
# on time step 237923 (time=237.923), 0.00372924 s/step
# Meep progress: 239.011/1000.0 = 23.9% done in 768.3s, 2446.3s to go
# on time step 239062 (time=239.062), 0.00351373 s/step
# Meep progress: 240.167/1000.0 = 24.0% done in 772.3s, 2443.5s to go
# on time step 240218 (time=240.218), 0.00346107 s/step
# Meep progress: 241.287/1000.0 = 24.1% done in 776.3s, 2441.2s to go
# on time step 241330 (time=241.33), 0.00359761 s/step
# Meep progress: 242.389/1000.0 = 24.2% done in 780.3s, 2439.0s to go
# on time step 242443 (time=242.443), 0.00359495 s/step
# Meep progress: 243.536/1000.0 = 24.4% done in 784.3s, 2436.3s to go
# on time step 243577 (time=243.577), 0.0035299 s/step
# Meep progress: 244.684/1000.0 = 24.5% done in 788.3s, 2433.5s to go
# on time step 244738 (time=244.738), 0.00344568 s/step
# Meep progress: 245.782/1000.0 = 24.6% done in 792.3s, 2431.4s to go
# on time step 245838 (time=245.838), 0.0036385 s/step
# Meep progress: 246.88/1000.0 = 24.7% done in 796.3s, 2429.3s to go
# on time step 246937 (time=246.937), 0.00364037 s/step
# Meep progress: 247.989/1000.0 = 24.8% done in 800.4s, 2427.0s to go
# on time step 248031 (time=248.031), 0.00365768 s/step
# Meep progress: 249.12/1000.0 = 24.9% done in 804.4s, 2424.4s to go
# on time step 249174 (time=249.174), 0.00350136 s/step
# Meep progress: 250.244/1000.0 = 25.0% done in 808.4s, 2421.9s to go
# on time step 250288 (time=250.288), 0.00359374 s/step
# Meep progress: 251.37900000000002/1000.0 = 25.1% done in 812.4s, 2419.3s to go
# on time step 251434 (time=251.434), 0.0034927 s/step
# Meep progress: 252.51500000000001/1000.0 = 25.3% done in 816.4s, 2416.6s to go
# on time step 252567 (time=252.567), 0.00353215 s/step
# Meep progress: 253.627/1000.0 = 25.4% done in 820.4s, 2414.2s to go
# on time step 253682 (time=253.682), 0.0035876 s/step
# Meep progress: 254.766/1000.0 = 25.5% done in 824.4s, 2411.4s to go
# on time step 254810 (time=254.81), 0.00354768 s/step
# Meep progress: 255.741/1000.0 = 25.6% done in 828.4s, 2410.7s to go
# on time step 255788 (time=255.788), 0.0040901 s/step
# Meep progress: 256.91/1000.0 = 25.7% done in 832.4s, 2407.6s to go
# on time step 256959 (time=256.959), 0.00341958 s/step
# Meep progress: 258.071/1000.0 = 25.8% done in 836.4s, 2404.5s to go
# on time step 258128 (time=258.128), 0.00342353 s/step
# Meep progress: 259.289/1000.0 = 25.9% done in 840.4s, 2400.7s to go
# on time step 259344 (time=259.344), 0.00329055 s/step
# Meep progress: 260.548/1000.0 = 26.1% done in 844.4s, 2396.4s to go
# on time step 260607 (time=260.607), 0.00316816 s/step
# Meep progress: 261.718/1000.0 = 26.2% done in 848.4s, 2393.2s to go
# on time step 261778 (time=261.778), 0.00341658 s/step
# Meep progress: 262.957/1000.0 = 26.3% done in 852.4s, 2389.1s to go
# on time step 263014 (time=263.014), 0.00323716 s/step
# Meep progress: 264.156/1000.0 = 26.4% done in 856.4s, 2385.6s to go
# on time step 264210 (time=264.21), 0.00334473 s/step
# Meep progress: 265.338/1000.0 = 26.5% done in 860.4s, 2382.2s to go
# on time step 265386 (time=265.386), 0.00340334 s/step
# Meep progress: 266.535/1000.0 = 26.7% done in 864.4s, 2378.7s to go
# on time step 266593 (time=266.593), 0.00331571 s/step
# Meep progress: 267.74/1000.0 = 26.8% done in 868.4s, 2375.0s to go
# on time step 267798 (time=267.798), 0.00332048 s/step
# Meep progress: 269.01/1000.0 = 26.9% done in 872.4s, 2370.6s to go
# on time step 269071 (time=269.071), 0.00314371 s/step
# Meep progress: 270.25/1000.0 = 27.0% done in 876.4s, 2366.5s to go
# on time step 270310 (time=270.31), 0.00322977 s/step
# Meep progress: 271.527/1000.0 = 27.2% done in 880.4s, 2362.0s to go
# on time step 271586 (time=271.586), 0.00313608 s/step
# Meep progress: 272.787/1000.0 = 27.3% done in 884.4s, 2357.7s to go
# on time step 272851 (time=272.851), 0.00316412 s/step
# Meep progress: 274.038/1000.0 = 27.4% done in 888.4s, 2353.5s to go
# on time step 274102 (time=274.102), 0.00319791 s/step
# Meep progress: 275.309/1000.0 = 27.5% done in 892.4s, 2349.0s to go
# on time step 275374 (time=275.374), 0.00314805 s/step
# Meep progress: 276.584/1000.0 = 27.7% done in 896.4s, 2344.6s to go
# on time step 276650 (time=276.65), 0.00313746 s/step
# Meep progress: 277.80400000000003/1000.0 = 27.8% done in 900.4s, 2340.7s to go
# on time step 277862 (time=277.862), 0.00330234 s/step
# Meep progress: 279.05400000000003/1000.0 = 27.9% done in 904.4s, 2336.5s to go
# on time step 279122 (time=279.122), 0.00317669 s/step
# Meep progress: 280.317/1000.0 = 28.0% done in 908.4s, 2332.2s to go
# on time step 280382 (time=280.382), 0.00317536 s/step
# Meep progress: 281.581/1000.0 = 28.2% done in 912.4s, 2327.9s to go
# on time step 281650 (time=281.65), 0.00315537 s/step
# Meep progress: 282.831/1000.0 = 28.3% done in 916.4s, 2323.7s to go
# on time step 282896 (time=282.896), 0.00321091 s/step
# Meep progress: 284.059/1000.0 = 28.4% done in 920.4s, 2319.8s to go
# on time step 284125 (time=284.125), 0.00325548 s/step
# Meep progress: 285.281/1000.0 = 28.5% done in 924.4s, 2315.9s to go
# on time step 285348 (time=285.348), 0.00327159 s/step
# Meep progress: 286.524/1000.0 = 28.7% done in 928.4s, 2311.8s to go
# on time step 286593 (time=286.593), 0.00321321 s/step
# Meep progress: 287.791/1000.0 = 28.8% done in 932.4s, 2307.5s to go
# on time step 287859 (time=287.859), 0.00316196 s/step
# Meep progress: 289.057/1000.0 = 28.9% done in 936.4s, 2303.1s to go
# on time step 289123 (time=289.123), 0.00316645 s/step
# Meep progress: 290.31/1000.0 = 29.0% done in 940.4s, 2298.9s to go
# on time step 290378 (time=290.378), 0.00318767 s/step
# Meep progress: 291.584/1000.0 = 29.2% done in 944.4s, 2294.5s to go
# on time step 291654 (time=291.654), 0.00313692 s/step
# Meep progress: 292.844/1000.0 = 29.3% done in 948.4s, 2290.2s to go
# on time step 292914 (time=292.914), 0.00317618 s/step
# Meep progress: 294.108/1000.0 = 29.4% done in 952.4s, 2285.9s to go
# on time step 294176 (time=294.176), 0.00316975 s/step
# Meep progress: 295.368/1000.0 = 29.5% done in 956.4s, 2281.6s to go
# on time step 295436 (time=295.436), 0.003176 s/step
# Meep progress: 296.598/1000.0 = 29.7% done in 960.4s, 2277.7s to go
# on time step 296670 (time=296.67), 0.00324256 s/step
# Meep progress: 297.826/1000.0 = 29.8% done in 964.4s, 2273.8s to go
# on time step 297895 (time=297.895), 0.00326613 s/step
# Meep progress: 299.087/1000.0 = 29.9% done in 968.4s, 2269.5s to go
# on time step 299157 (time=299.157), 0.00316979 s/step
# Meep progress: 300.338/1000.0 = 30.0% done in 972.4s, 2265.3s to go
# on time step 300402 (time=300.402), 0.00321354 s/step
# Meep progress: 301.608/1000.0 = 30.2% done in 976.4s, 2261.0s to go
# on time step 301674 (time=301.674), 0.00314481 s/step
# Meep progress: 302.853/1000.0 = 30.3% done in 980.4s, 2256.9s to go
# on time step 302922 (time=302.922), 0.00320549 s/step
# Meep progress: 304.095/1000.0 = 30.4% done in 984.4s, 2252.8s to go
# on time step 304164 (time=304.164), 0.00322253 s/step
# Meep progress: 305.329/1000.0 = 30.5% done in 988.4s, 2248.8s to go
# on time step 305394 (time=305.394), 0.00325422 s/step
# Meep progress: 306.57800000000003/1000.0 = 30.7% done in 992.4s, 2244.7s to go
# on time step 306649 (time=306.649), 0.00318926 s/step
# Meep progress: 307.829/1000.0 = 30.8% done in 996.4s, 2240.5s to go
# on time step 307899 (time=307.899), 0.00320199 s/step
# Meep progress: 309.062/1000.0 = 30.9% done in 1000.4s, 2236.6s to go
# on time step 309131 (time=309.131), 0.00324824 s/step
# Meep progress: 310.305/1000.0 = 31.0% done in 1004.4s, 2232.5s to go
# on time step 310377 (time=310.377), 0.00321259 s/step
# Meep progress: 311.53000000000003/1000.0 = 31.2% done in 1008.4s, 2228.6s to go
# on time step 311600 (time=311.6), 0.0032727 s/step
# Meep progress: 312.784/1000.0 = 31.3% done in 1012.4s, 2224.4s to go
# on time step 312850 (time=312.85), 0.00320219 s/step
# Meep progress: 314.019/1000.0 = 31.4% done in 1016.4s, 2220.4s to go
# on time step 314095 (time=314.095), 0.00321303 s/step
# Meep progress: 315.255/1000.0 = 31.5% done in 1020.4s, 2216.5s to go
# on time step 315325 (time=315.325), 0.00325274 s/step
# Meep progress: 316.50600000000003/1000.0 = 31.7% done in 1024.5s, 2212.3s to go
# on time step 316576 (time=316.576), 0.00319898 s/step
# Meep progress: 317.744/1000.0 = 31.8% done in 1028.5s, 2208.3s to go
# on time step 317815 (time=317.815), 0.00323035 s/step
# Meep progress: 318.984/1000.0 = 31.9% done in 1032.5s, 2204.2s to go
# on time step 319058 (time=319.058), 0.00321986 s/step
# Meep progress: 320.253/1000.0 = 32.0% done in 1036.5s, 2199.9s to go
# on time step 320325 (time=320.325), 0.0031579 s/step
# Meep progress: 321.46500000000003/1000.0 = 32.1% done in 1040.5s, 2196.2s to go
# on time step 321537 (time=321.537), 0.00330144 s/step
# Meep progress: 322.7/1000.0 = 32.3% done in 1044.5s, 2192.2s to go
# on time step 322771 (time=322.771), 0.00324185 s/step
# Meep progress: 323.931/1000.0 = 32.4% done in 1048.5s, 2188.2s to go
# on time step 324002 (time=324.002), 0.00325018 s/step
# Meep progress: 325.187/1000.0 = 32.5% done in 1052.5s, 2184.0s to go
# on time step 325262 (time=325.262), 0.00317571 s/step
# Meep progress: 326.444/1000.0 = 32.6% done in 1056.5s, 2179.8s to go
# on time step 326517 (time=326.517), 0.00318988 s/step
# Meep progress: 327.688/1000.0 = 32.8% done in 1060.5s, 2175.7s to go
# on time step 327761 (time=327.761), 0.00321563 s/step
# Meep progress: 328.962/1000.0 = 32.9% done in 1064.5s, 2171.4s to go
# on time step 329037 (time=329.037), 0.00313672 s/step
# Meep progress: 330.224/1000.0 = 33.0% done in 1068.5s, 2167.1s to go
# on time step 330286 (time=330.286), 0.00320456 s/step
# Meep progress: 331.446/1000.0 = 33.1% done in 1072.5s, 2163.3s to go
# on time step 331521 (time=331.521), 0.00323938 s/step
# Meep progress: 332.665/1000.0 = 33.3% done in 1076.5s, 2159.4s to go
# on time step 332741 (time=332.741), 0.00328004 s/step
# Meep progress: 333.886/1000.0 = 33.4% done in 1080.5s, 2155.6s to go
# on time step 333958 (time=333.958), 0.00328894 s/step
# Meep progress: 335.124/1000.0 = 33.5% done in 1084.5s, 2151.6s to go
# on time step 335201 (time=335.201), 0.00321928 s/step
# Meep progress: 336.37/1000.0 = 33.6% done in 1088.5s, 2147.5s to go
# on time step 336448 (time=336.448), 0.00320915 s/step
# Meep progress: 337.63100000000003/1000.0 = 33.8% done in 1092.5s, 2143.2s to go
# on time step 337705 (time=337.705), 0.00318487 s/step
# Meep progress: 338.865/1000.0 = 33.9% done in 1096.5s, 2139.3s to go
# on time step 338942 (time=338.942), 0.00323541 s/step
# Meep progress: 340.09000000000003/1000.0 = 34.0% done in 1100.5s, 2135.4s to go
# on time step 340167 (time=340.167), 0.00326595 s/step
# Meep progress: 341.309/1000.0 = 34.1% done in 1104.5s, 2131.5s to go
# on time step 341380 (time=341.38), 0.0033014 s/step
# Meep progress: 342.449/1000.0 = 34.2% done in 1108.5s, 2128.5s to go
# on time step 342527 (time=342.527), 0.00349033 s/step
# Meep progress: 343.624/1000.0 = 34.4% done in 1112.5s, 2125.0s to go
# on time step 343698 (time=343.698), 0.00341757 s/step
# Meep progress: 344.75600000000003/1000.0 = 34.5% done in 1116.5s, 2122.0s to go
# on time step 344832 (time=344.832), 0.00352735 s/step
# Meep progress: 346.02500000000003/1000.0 = 34.6% done in 1120.5s, 2117.7s to go
# on time step 346102 (time=346.102), 0.00315019 s/step
# Meep progress: 347.278/1000.0 = 34.7% done in 1124.5s, 2113.5s to go
# on time step 347358 (time=347.358), 0.0031869 s/step
# Meep progress: 348.53000000000003/1000.0 = 34.9% done in 1128.5s, 2109.4s to go
# on time step 348609 (time=348.609), 0.00319857 s/step
# Meep progress: 349.789/1000.0 = 35.0% done in 1132.5s, 2105.2s to go
# on time step 349870 (time=349.87), 0.00317345 s/step
# Meep progress: 351.047/1000.0 = 35.1% done in 1136.5s, 2101.0s to go
# on time step 351123 (time=351.123), 0.00319392 s/step
# Meep progress: 352.307/1000.0 = 35.2% done in 1140.5s, 2096.7s to go
# on time step 352387 (time=352.387), 0.00316613 s/step
# Meep progress: 353.523/1000.0 = 35.4% done in 1144.5s, 2092.9s to go
# on time step 353606 (time=353.606), 0.00328344 s/step
# Meep progress: 354.771/1000.0 = 35.5% done in 1148.5s, 2088.8s to go
# on time step 354857 (time=354.857), 0.00319921 s/step
# Meep progress: 356.043/1000.0 = 35.6% done in 1152.5s, 2084.5s to go
# on time step 356119 (time=356.119), 0.00317003 s/step
# Meep progress: 357.301/1000.0 = 35.7% done in 1156.5s, 2080.3s to go
# on time step 357386 (time=357.386), 0.00315927 s/step
# Meep progress: 358.564/1000.0 = 35.9% done in 1160.5s, 2076.0s to go
# on time step 358647 (time=358.647), 0.00317277 s/step
# Meep progress: 359.835/1000.0 = 36.0% done in 1164.5s, 2071.7s to go
# on time step 359918 (time=359.918), 0.00314963 s/step
# Meep progress: 361.103/1000.0 = 36.1% done in 1168.5s, 2067.4s to go
# on time step 361187 (time=361.187), 0.00315371 s/step
# Meep progress: 362.377/1000.0 = 36.2% done in 1172.5s, 2063.1s to go
# on time step 362462 (time=362.462), 0.00313881 s/step
# Meep progress: 363.649/1000.0 = 36.4% done in 1176.5s, 2058.8s to go
# on time step 363736 (time=363.736), 0.00314189 s/step
# Meep progress: 364.91200000000003/1000.0 = 36.5% done in 1180.5s, 2054.6s to go
# on time step 365003 (time=365.003), 0.00315946 s/step
# Meep progress: 366.18/1000.0 = 36.6% done in 1184.5s, 2050.3s to go
# on time step 366265 (time=366.265), 0.00316961 s/step
# Meep progress: 367.451/1000.0 = 36.7% done in 1188.5s, 2046.0s to go
# on time step 367534 (time=367.534), 0.00315403 s/step
# Meep progress: 368.72/1000.0 = 36.9% done in 1192.5s, 2041.7s to go
# on time step 368810 (time=368.81), 0.00313721 s/step
# Meep progress: 369.996/1000.0 = 37.0% done in 1196.5s, 2037.4s to go
# on time step 370081 (time=370.081), 0.00314809 s/step
# Meep progress: 371.254/1000.0 = 37.1% done in 1200.5s, 2033.2s to go
# on time step 371339 (time=371.339), 0.00318074 s/step
# Meep progress: 372.527/1000.0 = 37.3% done in 1204.5s, 2028.9s to go
# on time step 372615 (time=372.615), 0.00313598 s/step
# Meep progress: 373.789/1000.0 = 37.4% done in 1208.5s, 2024.7s to go
# on time step 373880 (time=373.88), 0.00316207 s/step
# Meep progress: 375.07300000000004/1000.0 = 37.5% done in 1212.5s, 2020.3s to go
# on time step 375159 (time=375.159), 0.00312763 s/step
# Meep progress: 376.279/1000.0 = 37.6% done in 1216.5s, 2016.5s to go
# on time step 376356 (time=376.356), 0.00334386 s/step
# Meep progress: 377.471/1000.0 = 37.7% done in 1220.5s, 2012.9s to go
# on time step 377559 (time=377.559), 0.0033257 s/step
# Meep progress: 378.731/1000.0 = 37.9% done in 1224.5s, 2008.7s to go
# on time step 378816 (time=378.816), 0.00318229 s/step
# Meep progress: 379.98/1000.0 = 38.0% done in 1228.5s, 2004.6s to go
# on time step 380064 (time=380.064), 0.00320769 s/step
# Meep progress: 381.16200000000003/1000.0 = 38.1% done in 1232.5s, 2001.1s to go
# on time step 381248 (time=381.248), 0.00337942 s/step
# Meep progress: 382.384/1000.0 = 38.2% done in 1236.5s, 1997.2s to go
# on time step 382475 (time=382.475), 0.00326172 s/step
# Meep progress: 383.657/1000.0 = 38.4% done in 1240.5s, 1992.9s to go
# on time step 383749 (time=383.749), 0.00314126 s/step
# Meep progress: 384.91700000000003/1000.0 = 38.5% done in 1244.5s, 1988.7s to go
# on time step 385009 (time=385.009), 0.00317683 s/step
# Meep progress: 386.175/1000.0 = 38.6% done in 1248.5s, 1984.6s to go
# on time step 386269 (time=386.269), 0.00317701 s/step
# Meep progress: 387.44800000000004/1000.0 = 38.7% done in 1252.5s, 1980.3s to go
# on time step 387543 (time=387.543), 0.00314146 s/step
# Meep progress: 388.71000000000004/1000.0 = 38.9% done in 1256.5s, 1976.1s to go
# on time step 388801 (time=388.801), 0.00318143 s/step
# Meep progress: 389.931/1000.0 = 39.0% done in 1260.5s, 1972.2s to go
# on time step 390013 (time=390.013), 0.00330156 s/step
# Meep progress: 391.12600000000003/1000.0 = 39.1% done in 1264.5s, 1968.5s to go
# on time step 391205 (time=391.205), 0.00335636 s/step
# Meep progress: 392.367/1000.0 = 39.2% done in 1268.5s, 1964.5s to go
# on time step 392461 (time=392.461), 0.00318552 s/step
# Meep progress: 393.57/1000.0 = 39.4% done in 1272.5s, 1960.8s to go
# on time step 393648 (time=393.648), 0.00337056 s/step
# Meep progress: 394.778/1000.0 = 39.5% done in 1276.5s, 1957.0s to go
# on time step 394869 (time=394.869), 0.00327906 s/step
# Meep progress: 396.011/1000.0 = 39.6% done in 1280.6s, 1953.1s to go
# on time step 396105 (time=396.105), 0.00323682 s/step
# Meep progress: 397.284/1000.0 = 39.7% done in 1284.6s, 1948.8s to go
# on time step 397380 (time=397.38), 0.00313834 s/step
# Meep progress: 398.55/1000.0 = 39.9% done in 1288.6s, 1944.6s to go
# on time step 398641 (time=398.641), 0.00317357 s/step
# Meep progress: 399.81/1000.0 = 40.0% done in 1292.6s, 1940.4s to go
# on time step 399907 (time=399.907), 0.003163 s/step
# Meep progress: 401.087/1000.0 = 40.1% done in 1296.6s, 1936.1s to go
# on time step 401183 (time=401.183), 0.00313645 s/step
# Meep progress: 402.361/1000.0 = 40.2% done in 1300.6s, 1931.8s to go
# on time step 402459 (time=402.459), 0.00313566 s/step
# Meep progress: 403.625/1000.0 = 40.4% done in 1304.6s, 1927.6s to go
# on time step 403724 (time=403.724), 0.00316358 s/step
# Meep progress: 404.898/1000.0 = 40.5% done in 1308.6s, 1923.3s to go
# on time step 404994 (time=404.994), 0.00315046 s/step
# Meep progress: 406.16200000000003/1000.0 = 40.6% done in 1312.6s, 1919.1s to go
# on time step 406261 (time=406.261), 0.00315836 s/step
# Meep progress: 407.438/1000.0 = 40.7% done in 1316.6s, 1914.8s to go
# on time step 407538 (time=407.538), 0.00313316 s/step
# Meep progress: 408.708/1000.0 = 40.9% done in 1320.6s, 1910.5s to go
# on time step 408807 (time=408.807), 0.00315264 s/step
# Meep progress: 409.982/1000.0 = 41.0% done in 1324.6s, 1906.2s to go
# on time step 410083 (time=410.083), 0.0031355 s/step
# Meep progress: 411.25100000000003/1000.0 = 41.1% done in 1328.6s, 1902.0s to go
# on time step 411350 (time=411.35), 0.00315845 s/step
# Meep progress: 412.51300000000003/1000.0 = 41.3% done in 1332.6s, 1897.8s to go
# on time step 412609 (time=412.609), 0.00317925 s/step
# Meep progress: 413.772/1000.0 = 41.4% done in 1336.6s, 1893.6s to go
# on time step 413873 (time=413.873), 0.00316612 s/step
# Meep progress: 415.015/1000.0 = 41.5% done in 1340.6s, 1889.6s to go
# on time step 415113 (time=415.113), 0.00322752 s/step
# Meep progress: 416.281/1000.0 = 41.6% done in 1344.6s, 1885.4s to go
# on time step 416383 (time=416.383), 0.00315078 s/step
# Meep progress: 417.545/1000.0 = 41.8% done in 1348.6s, 1881.2s to go
# on time step 417640 (time=417.64), 0.00318246 s/step
# Meep progress: 418.62/1000.0 = 41.9% done in 1352.6s, 1878.5s to go
# on time step 418709 (time=418.709), 0.00374228 s/step
# Meep progress: 419.69/1000.0 = 42.0% done in 1356.6s, 1875.8s to go
# on time step 419769 (time=419.769), 0.00377488 s/step
# Meep progress: 420.831/1000.0 = 42.1% done in 1360.6s, 1872.5s to go
# on time step 420908 (time=420.908), 0.00351193 s/step
# Meep progress: 421.85/1000.0 = 42.2% done in 1364.6s, 1870.2s to go
# on time step 421922 (time=421.922), 0.0039449 s/step
# Meep progress: 422.902/1000.0 = 42.3% done in 1368.6s, 1867.6s to go
# on time step 422977 (time=422.977), 0.00379311 s/step
# Meep progress: 424.089/1000.0 = 42.4% done in 1372.6s, 1864.0s to go
# on time step 424190 (time=424.19), 0.00329844 s/step
# Meep progress: 425.293/1000.0 = 42.5% done in 1376.6s, 1860.2s to go
# on time step 425393 (time=425.393), 0.00332681 s/step
# Meep progress: 426.521/1000.0 = 42.7% done in 1380.6s, 1856.3s to go
# on time step 426625 (time=426.625), 0.00324912 s/step
# Meep progress: 427.78000000000003/1000.0 = 42.8% done in 1384.6s, 1852.1s to go
# on time step 427879 (time=427.879), 0.00319181 s/step
# Meep progress: 429.03000000000003/1000.0 = 42.9% done in 1388.6s, 1848.0s to go
# on time step 429131 (time=429.131), 0.00319535 s/step
# Meep progress: 430.296/1000.0 = 43.0% done in 1392.6s, 1843.8s to go
# on time step 430401 (time=430.401), 0.00315152 s/step
# Meep progress: 431.52500000000003/1000.0 = 43.2% done in 1396.6s, 1839.8s to go
# on time step 431625 (time=431.625), 0.0032695 s/step
# Meep progress: 432.67400000000004/1000.0 = 43.3% done in 1400.6s, 1836.5s to go
# on time step 432777 (time=432.777), 0.00347411 s/step
# Meep progress: 433.913/1000.0 = 43.4% done in 1404.6s, 1832.5s to go
# on time step 434020 (time=434.02), 0.00321893 s/step
# Meep progress: 435.184/1000.0 = 43.5% done in 1408.6s, 1828.2s to go
# on time step 435292 (time=435.292), 0.00314615 s/step
# Meep progress: 436.43600000000004/1000.0 = 43.6% done in 1412.6s, 1824.1s to go
# on time step 436515 (time=436.515), 0.00327067 s/step
# Meep progress: 437.621/1000.0 = 43.8% done in 1416.6s, 1820.5s to go
# on time step 437724 (time=437.724), 0.00331002 s/step
# Meep progress: 438.87600000000003/1000.0 = 43.9% done in 1420.6s, 1816.3s to go
# on time step 438972 (time=438.972), 0.00320719 s/step
# Meep progress: 440.122/1000.0 = 44.0% done in 1424.6s, 1812.2s to go
# on time step 440230 (time=440.23), 0.00318097 s/step
# Meep progress: 441.372/1000.0 = 44.1% done in 1428.6s, 1808.1s to go
# on time step 441476 (time=441.476), 0.00321237 s/step
# Meep progress: 442.60200000000003/1000.0 = 44.3% done in 1432.6s, 1804.2s to go
# on time step 442687 (time=442.687), 0.00330465 s/step
# Meep progress: 443.8/1000.0 = 44.4% done in 1436.6s, 1800.5s to go
# on time step 443911 (time=443.911), 0.00326974 s/step
# Meep progress: 444.95300000000003/1000.0 = 44.5% done in 1440.6s, 1797.1s to go
# on time step 445034 (time=445.034), 0.00356235 s/step
# Meep progress: 446.141/1000.0 = 44.6% done in 1444.6s, 1793.4s to go
# on time step 446246 (time=446.246), 0.00330079 s/step
# Meep progress: 447.378/1000.0 = 44.7% done in 1448.6s, 1789.4s to go
# on time step 447479 (time=447.479), 0.0032459 s/step
# Meep progress: 448.619/1000.0 = 44.9% done in 1452.6s, 1785.4s to go
# on time step 448713 (time=448.713), 0.00324411 s/step
# Meep progress: 449.755/1000.0 = 45.0% done in 1456.6s, 1782.1s to go
# on time step 449840 (time=449.84), 0.00355117 s/step
# Meep progress: 450.91200000000003/1000.0 = 45.1% done in 1460.6s, 1778.6s to go
# on time step 451015 (time=451.015), 0.00340598 s/step
# Meep progress: 452.104/1000.0 = 45.2% done in 1464.6s, 1775.0s to go
# on time step 452210 (time=452.21), 0.00334766 s/step
# Meep progress: 453.218/1000.0 = 45.3% done in 1468.6s, 1771.8s to go
# on time step 453322 (time=453.322), 0.00359734 s/step
# Meep progress: 454.475/1000.0 = 45.4% done in 1472.6s, 1767.7s to go
# on time step 454575 (time=454.575), 0.00319501 s/step
# Meep progress: 455.708/1000.0 = 45.6% done in 1476.6s, 1763.7s to go
# on time step 455821 (time=455.821), 0.00321155 s/step
# Meep progress: 456.946/1000.0 = 45.7% done in 1480.6s, 1759.6s to go
# on time step 457055 (time=457.055), 0.00324194 s/step
# Meep progress: 458.19800000000004/1000.0 = 45.8% done in 1484.6s, 1755.5s to go
# on time step 458307 (time=458.307), 0.00319506 s/step
# Meep progress: 459.42/1000.0 = 45.9% done in 1488.6s, 1751.6s to go
# on time step 459528 (time=459.528), 0.00327636 s/step
# Meep progress: 460.65000000000003/1000.0 = 46.1% done in 1492.6s, 1747.6s to go
# on time step 460757 (time=460.757), 0.00325573 s/step
# ...
# on time step 842228 (time=842.228), 0.00407753 s/step
# Meep progress: 843.019/1000.0 = 84.3% done in 2757.2s, 513.4s to go
# on time step 843170 (time=843.17), 0.00424784 s/step
# Meep progress: 844.203/1000.0 = 84.4% done in 2761.2s, 509.6s to go
# on time step 844404 (time=844.404), 0.00324316 s/step
# Meep progress: 845.3340000000001/1000.0 = 84.5% done in 2765.2s, 505.9s to go
# on time step 845502 (time=845.502), 0.00364359 s/step
# Meep progress: 846.409/1000.0 = 84.6% done in 2769.2s, 502.5s to go
# on time step 846593 (time=846.593), 0.003667 s/step
# Meep progress: 847.407/1000.0 = 84.7% done in 2773.2s, 499.4s to go
# on time step 847598 (time=847.598), 0.00398216 s/step
# Meep progress: 848.453/1000.0 = 84.8% done in 2777.2s, 496.1s to go
# on time step 848637 (time=848.637), 0.00385088 s/step
# Meep progress: 849.624/1000.0 = 85.0% done in 2781.2s, 492.3s to go
# on time step 849822 (time=849.822), 0.00337568 s/step
# Meep progress: 850.814/1000.0 = 85.1% done in 2785.2s, 488.4s to go
# on time step 851003 (time=851.003), 0.00338924 s/step
# Meep progress: 852.0070000000001/1000.0 = 85.2% done in 2789.2s, 484.5s to go
# on time step 852204 (time=852.204), 0.00333064 s/step
# Meep progress: 853.24/1000.0 = 85.3% done in 2793.2s, 480.4s to go
# on time step 853441 (time=853.441), 0.00323487 s/step
# Meep progress: 854.516/1000.0 = 85.5% done in 2797.2s, 476.2s to go
# on time step 854720 (time=854.72), 0.0031277 s/step
# Meep progress: 855.751/1000.0 = 85.6% done in 2801.2s, 472.2s to go
# on time step 855946 (time=855.946), 0.00326499 s/step
# Meep progress: 856.982/1000.0 = 85.7% done in 2805.2s, 468.2s to go
# on time step 857185 (time=857.185), 0.00322965 s/step
# Meep progress: 858.2330000000001/1000.0 = 85.8% done in 2809.2s, 464.0s to go
# on time step 858440 (time=858.44), 0.00318867 s/step
# Meep progress: 859.264/1000.0 = 85.9% done in 2813.2s, 460.8s to go
# on time step 859420 (time=859.42), 0.00408304 s/step
# Meep progress: 860.28/1000.0 = 86.0% done in 2817.2s, 457.6s to go
# on time step 860455 (time=860.455), 0.00386754 s/step
# Meep progress: 861.2520000000001/1000.0 = 86.1% done in 2821.2s, 454.5s to go
# on time step 861396 (time=861.396), 0.00425337 s/step
# Meep progress: 862.202/1000.0 = 86.2% done in 2825.3s, 451.5s to go
# on time step 862349 (time=862.349), 0.00420029 s/step
# Meep progress: 863.157/1000.0 = 86.3% done in 2829.3s, 448.5s to go
# on time step 863312 (time=863.312), 0.00416008 s/step
# Meep progress: 864.092/1000.0 = 86.4% done in 2833.3s, 445.6s to go
# on time step 864242 (time=864.242), 0.00430252 s/step
# Meep progress: 865.024/1000.0 = 86.5% done in 2837.3s, 442.7s to go
# on time step 865182 (time=865.182), 0.00425648 s/step
# Meep progress: 866.004/1000.0 = 86.6% done in 2841.3s, 439.6s to go
# on time step 866166 (time=866.166), 0.0040683 s/step
# Meep progress: 866.941/1000.0 = 86.7% done in 2845.3s, 436.7s to go
# on time step 867102 (time=867.102), 0.00427376 s/step
# Meep progress: 867.891/1000.0 = 86.8% done in 2849.3s, 433.7s to go
# on time step 868049 (time=868.049), 0.00422883 s/step
# Meep progress: 868.831/1000.0 = 86.9% done in 2853.3s, 430.8s to go
# on time step 868991 (time=868.991), 0.00424954 s/step
# Meep progress: 869.78/1000.0 = 87.0% done in 2857.3s, 427.8s to go
# on time step 869920 (time=869.92), 0.00430936 s/step
# Meep progress: 870.671/1000.0 = 87.1% done in 2861.3s, 425.0s to go
# on time step 870827 (time=870.827), 0.00441476 s/step
# Meep progress: 871.601/1000.0 = 87.2% done in 2865.3s, 422.1s to go
# on time step 871757 (time=871.757), 0.00430262 s/step
# Meep progress: 872.559/1000.0 = 87.3% done in 2869.3s, 419.1s to go
# on time step 872723 (time=872.723), 0.00414079 s/step
# Meep progress: 873.503/1000.0 = 87.4% done in 2873.3s, 416.1s to go
# on time step 873669 (time=873.669), 0.00423073 s/step
# Meep progress: 874.488/1000.0 = 87.4% done in 2877.3s, 413.0s to go
# on time step 874659 (time=874.659), 0.00404096 s/step
# Meep progress: 875.463/1000.0 = 87.5% done in 2881.3s, 409.9s to go
# on time step 875634 (time=875.634), 0.00410311 s/step
# Meep progress: 876.4250000000001/1000.0 = 87.6% done in 2885.3s, 406.8s to go
# on time step 876585 (time=876.585), 0.00420949 s/step
# Meep progress: 877.418/1000.0 = 87.7% done in 2889.3s, 403.7s to go
# on time step 877583 (time=877.583), 0.00401109 s/step
# Meep progress: 878.422/1000.0 = 87.8% done in 2893.3s, 400.4s to go
# on time step 878589 (time=878.589), 0.00398083 s/step
# Meep progress: 879.4010000000001/1000.0 = 87.9% done in 2897.3s, 397.3s to go
# on time step 879565 (time=879.565), 0.00410118 s/step
# Meep progress: 880.36/1000.0 = 88.0% done in 2901.3s, 394.3s to go
# on time step 880522 (time=880.522), 0.00418322 s/step
# Meep progress: 881.2950000000001/1000.0 = 88.1% done in 2905.3s, 391.3s to go
# on time step 881439 (time=881.439), 0.00436566 s/step
# Meep progress: 882.192/1000.0 = 88.2% done in 2909.3s, 388.5s to go
# on time step 882357 (time=882.357), 0.00436153 s/step
# Meep progress: 883.118/1000.0 = 88.3% done in 2913.3s, 385.6s to go
# on time step 883284 (time=883.284), 0.00431599 s/step
# Meep progress: 884.082/1000.0 = 88.4% done in 2917.3s, 382.5s to go
# on time step 884266 (time=884.266), 0.00407419 s/step
# Meep progress: 885.277/1000.0 = 88.5% done in 2921.3s, 378.6s to go
# on time step 885477 (time=885.477), 0.00330492 s/step
# Meep progress: 886.417/1000.0 = 88.6% done in 2925.3s, 374.8s to go
# on time step 886586 (time=886.586), 0.00360712 s/step
# Meep progress: 887.4540000000001/1000.0 = 88.7% done in 2929.3s, 371.5s to go
# on time step 887637 (time=887.637), 0.00380886 s/step
# Meep progress: 888.519/1000.0 = 88.9% done in 2933.3s, 368.0s to go
# on time step 888714 (time=888.714), 0.00371658 s/step
# Meep progress: 889.636/1000.0 = 89.0% done in 2937.3s, 364.4s to go
# on time step 889832 (time=889.832), 0.00358013 s/step
# Meep progress: 890.749/1000.0 = 89.1% done in 2941.3s, 360.8s to go
# on time step 890928 (time=890.928), 0.00365188 s/step
# Meep progress: 891.903/1000.0 = 89.2% done in 2945.3s, 357.0s to go
# on time step 892090 (time=892.09), 0.00344403 s/step
# Meep progress: 893.034/1000.0 = 89.3% done in 2949.3s, 353.3s to go
# on time step 893251 (time=893.251), 0.00344562 s/step
# Meep progress: 894.291/1000.0 = 89.4% done in 2953.3s, 349.1s to go
# on time step 894503 (time=894.503), 0.00319688 s/step
# Meep progress: 895.432/1000.0 = 89.5% done in 2957.3s, 345.4s to go
# on time step 895657 (time=895.657), 0.00346658 s/step
# Meep progress: 896.6700000000001/1000.0 = 89.7% done in 2961.3s, 341.3s to go
# on time step 896893 (time=896.893), 0.00323765 s/step
# Meep progress: 897.871/1000.0 = 89.8% done in 2965.3s, 337.3s to go
# on time step 898057 (time=898.057), 0.00343824 s/step
# Meep progress: 899.0790000000001/1000.0 = 89.9% done in 2969.3s, 333.3s to go
# on time step 899361 (time=899.361), 0.00306782 s/step
# Meep progress: 900.731/1000.0 = 90.1% done in 2973.3s, 327.7s to go
# on time step 901060 (time=901.06), 0.00235501 s/step
# Meep progress: 902.625/1000.0 = 90.3% done in 2977.3s, 321.2s to go
# on time step 902956 (time=902.956), 0.00210989 s/step
# Meep progress: 904.519/1000.0 = 90.5% done in 2981.3s, 314.7s to go
# on time step 904852 (time=904.852), 0.00211 s/step
# Meep progress: 906.399/1000.0 = 90.6% done in 2985.3s, 308.3s to go
# on time step 906724 (time=906.724), 0.00213765 s/step
# Meep progress: 908.041/1000.0 = 90.8% done in 2989.3s, 302.7s to go
# on time step 908355 (time=908.355), 0.00245321 s/step
# Meep progress: 909.64/1000.0 = 91.0% done in 2993.3s, 297.3s to go
# on time step 909880 (time=909.88), 0.00262318 s/step
# Meep progress: 911.426/1000.0 = 91.1% done in 2997.3s, 291.3s to go
# on time step 911737 (time=911.737), 0.00215508 s/step
# Meep progress: 913.067/1000.0 = 91.3% done in 3001.3s, 285.8s to go
# on time step 913400 (time=913.4), 0.0024058 s/step
# Meep progress: 914.953/1000.0 = 91.5% done in 3005.3s, 279.4s to go
# on time step 915280 (time=915.28), 0.00212908 s/step
# Meep progress: 916.803/1000.0 = 91.7% done in 3009.3s, 273.1s to go
# on time step 917136 (time=917.136), 0.00215625 s/step
# Meep progress: 918.678/1000.0 = 91.9% done in 3013.3s, 266.7s to go
# on time step 919014 (time=919.014), 0.00213066 s/step
# Meep progress: 920.5690000000001/1000.0 = 92.1% done in 3017.3s, 260.4s to go
# on time step 920912 (time=920.912), 0.00210778 s/step
# Meep progress: 922.464/1000.0 = 92.2% done in 3021.3s, 254.0s to go
# on time step 922798 (time=922.798), 0.0021211 s/step
# Meep progress: 924.344/1000.0 = 92.4% done in 3025.3s, 247.6s to go
# on time step 924680 (time=924.68), 0.00212601 s/step
# Meep progress: 926.208/1000.0 = 92.6% done in 3029.3s, 241.4s to go
# on time step 926542 (time=926.542), 0.00214914 s/step
# Meep progress: 928.099/1000.0 = 92.8% done in 3033.3s, 235.0s to go
# on time step 928440 (time=928.44), 0.00210789 s/step
# Meep progress: 929.976/1000.0 = 93.0% done in 3037.3s, 228.7s to go
# on time step 930299 (time=930.299), 0.00215281 s/step
# Meep progress: 931.8430000000001/1000.0 = 93.2% done in 3041.3s, 222.5s to go
# on time step 932187 (time=932.187), 0.00211867 s/step
# Meep progress: 933.7420000000001/1000.0 = 93.4% done in 3045.3s, 216.1s to go
# on time step 934075 (time=934.075), 0.00211926 s/step
# Meep progress: 935.5980000000001/1000.0 = 93.6% done in 3049.3s, 209.9s to go
# on time step 935938 (time=935.938), 0.00214849 s/step
# Meep progress: 937.485/1000.0 = 93.7% done in 3053.4s, 203.6s to go
# on time step 937827 (time=937.827), 0.00211791 s/step
# Meep progress: 939.364/1000.0 = 93.9% done in 3057.4s, 197.4s to go
# on time step 939699 (time=939.699), 0.00213699 s/step
# Meep progress: 941.2280000000001/1000.0 = 94.1% done in 3061.4s, 191.2s to go
# on time step 941571 (time=941.571), 0.00213742 s/step
# Meep progress: 943.119/1000.0 = 94.3% done in 3065.4s, 184.9s to go
# on time step 943437 (time=943.437), 0.00214398 s/step
# Meep progress: 944.987/1000.0 = 94.5% done in 3069.4s, 178.7s to go
# on time step 945313 (time=945.313), 0.00213297 s/step
# Meep progress: 946.701/1000.0 = 94.7% done in 3073.4s, 173.0s to go
# on time step 946970 (time=946.97), 0.00241485 s/step
# Meep progress: 948.491/1000.0 = 94.8% done in 3077.4s, 167.1s to go
# on time step 948781 (time=948.781), 0.00220987 s/step
# Meep progress: 950.015/1000.0 = 95.0% done in 3081.4s, 162.1s to go
# on time step 950265 (time=950.265), 0.00269639 s/step
# Meep progress: 951.537/1000.0 = 95.2% done in 3085.4s, 157.1s to go
# on time step 951841 (time=951.841), 0.00253883 s/step
# Meep progress: 953.037/1000.0 = 95.3% done in 3089.4s, 152.2s to go
# on time step 953312 (time=953.312), 0.00272192 s/step
# Meep progress: 954.618/1000.0 = 95.5% done in 3093.4s, 147.1s to go
# on time step 954958 (time=954.958), 0.00243069 s/step
# Meep progress: 956.479/1000.0 = 95.6% done in 3097.4s, 140.9s to go
# on time step 956823 (time=956.823), 0.00214568 s/step
# Meep progress: 958.1460000000001/1000.0 = 95.8% done in 3101.4s, 135.5s to go
# on time step 958472 (time=958.472), 0.00242661 s/step
# Meep progress: 960.0/1000.0 = 96.0% done in 3105.4s, 129.4s to go
# on time step 960282 (time=960.282), 0.00221062 s/step
# Meep progress: 961.623/1000.0 = 96.2% done in 3109.4s, 124.1s to go
# on time step 961977 (time=961.977), 0.00236058 s/step
# Meep progress: 963.251/1000.0 = 96.3% done in 3113.4s, 118.8s to go
# on time step 963586 (time=963.586), 0.00248612 s/step
# Meep progress: 964.943/1000.0 = 96.5% done in 3117.4s, 113.3s to go
# on time step 965229 (time=965.229), 0.00243524 s/step
# Meep progress: 966.588/1000.0 = 96.7% done in 3121.4s, 107.9s to go
# on time step 966830 (time=966.83), 0.00249949 s/step
# Meep progress: 968.207/1000.0 = 96.8% done in 3125.4s, 102.6s to go
# on time step 968479 (time=968.479), 0.00242873 s/step
# Meep progress: 969.821/1000.0 = 97.0% done in 3129.4s, 97.4s to go
# on time step 970101 (time=970.101), 0.00246611 s/step
# Meep progress: 971.629/1000.0 = 97.2% done in 3133.4s, 91.5s to go
# on time step 971976 (time=971.976), 0.00213344 s/step
# Meep progress: 973.2810000000001/1000.0 = 97.3% done in 3137.4s, 86.1s to go
# on time step 973594 (time=973.594), 0.0024732 s/step
# Meep progress: 974.961/1000.0 = 97.5% done in 3141.4s, 80.7s to go
# on time step 975205 (time=975.205), 0.00248504 s/step
# Meep progress: 976.216/1000.0 = 97.6% done in 3145.4s, 76.6s to go
# on time step 976457 (time=976.457), 0.00319557 s/step
# Meep progress: 977.565/1000.0 = 97.8% done in 3149.4s, 72.3s to go
# on time step 977835 (time=977.835), 0.00290318 s/step
# Meep progress: 978.964/1000.0 = 97.9% done in 3153.4s, 67.8s to go
# on time step 979238 (time=979.238), 0.00285122 s/step
# Meep progress: 980.3000000000001/1000.0 = 98.0% done in 3157.4s, 63.5s to go
# on time step 980551 (time=980.551), 0.00304863 s/step
# Meep progress: 981.712/1000.0 = 98.2% done in 3161.4s, 58.9s to go
# on time step 981970 (time=981.97), 0.00282102 s/step
# Meep progress: 983.077/1000.0 = 98.3% done in 3165.4s, 54.5s to go
# on time step 983368 (time=983.368), 0.00286264 s/step
# Meep progress: 984.835/1000.0 = 98.5% done in 3169.4s, 48.8s to go
# on time step 985149 (time=985.149), 0.00224726 s/step
# Meep progress: 986.587/1000.0 = 98.7% done in 3173.4s, 43.1s to go
# on time step 986895 (time=986.895), 0.00229142 s/step
# Meep progress: 988.134/1000.0 = 98.8% done in 3177.4s, 38.2s to go
# on time step 988439 (time=988.439), 0.00259228 s/step
# Meep progress: 989.658/1000.0 = 99.0% done in 3181.4s, 33.2s to go
# on time step 990002 (time=990.002), 0.00256082 s/step
# Meep progress: 991.3340000000001/1000.0 = 99.1% done in 3185.4s, 27.8s to go
# on time step 991562 (time=991.562), 0.00256731 s/step
# Meep progress: 992.839/1000.0 = 99.3% done in 3189.4s, 23.0s to go
# on time step 993137 (time=993.137), 0.00254117 s/step
# Meep progress: 994.4440000000001/1000.0 = 99.4% done in 3193.4s, 17.8s to go
# on time step 994700 (time=994.7), 0.0025602 s/step
# Meep progress: 995.8340000000001/1000.0 = 99.6% done in 3197.4s, 13.4s to go
# on time step 996063 (time=996.063), 0.00293543 s/step
# Meep progress: 997.476/1000.0 = 99.7% done in 3201.4s, 8.1s to go
# on time step 997842 (time=997.842), 0.0022489 s/step
# Meep progress: 999.237/1000.0 = 99.9% done in 3205.4s, 2.4s to go
# on time step 999560 (time=999.56), 0.00232849 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 1000.0 (1000000 timesteps)
#      block, center = (-0.76,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
ez_data_up = np.array(ez_data_up)
ez_data_cen = np.array(ez_data_cen)
ez_data_down = np.array(ez_data_down)


print(len(ez_data_cen))

print(1 + int(round(t_xx/dt)))
# Out:
# 76923
# 41

# %%
ez_data_cen = np.array(ez_data_cen)
ez_data_up = np.array(ez_data_up)
ez_data_down = np.array(ez_data_down)

#plt.subplot_adjust(hspace = .35)
plt.figure(dpi = 300)
start = round(len(ez_data_cen) / t *1)

for i in range(start,round(len(ez_data_cen) / 75),1):
    plt.subplot(3,1,1)
    plt.plot(i,ez_data_up[i],'k.')
    plt.subplot(3,1,2)
    plt.plot(i,ez_data_cen[i],'k.')
    plt.subplot(3,1,3)
    plt.plot(i,ez_data_down[i],'k.')
    if i ==  (len(ez_data_cen)-1):
        plt.subplot(3,1,1)
        plt.title('upper point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_up[i],'b .')
        plt.subplot(3,1,2)
        plt.title('center point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_cen[i],'b .')
        plt.subplot(3,1,3)
        plt.title('downer point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_down[i],'b .')
# Out:
# /home/henry/miniconda3/envs/mp/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
# index1 and index2 . When we find the target's Electric field amplitude, we want to know where is amplitude value in array. So we set up index variable before running simulation.
index1_up = 0
index1_cen = 0
index1_down = 0

index2_up = 0
index2_cen = 0
index2_down = 0
# Period_max , period_next_mat . I set up those variables because I plan to use variables to store max amplitude value in a peiod in the following simulation. 
period_max_up = 0
period_max_cen = 0
period_max_down = 0
period_next_max_up = 0
period_next_max_cen = 0
period_next_max_down = 0

# Intial_index , end_index. ==>  "for loop" index
initial_index = round(len(ez_data_cen) / t * 200 )
print(initial_index)
end_index = len(ez_data_cen) - 2*( 1 +int(round(t_xx/dt))) 
print(end_index)
# Out:
# 15385
# 76841

# %%
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_up[j])
        period_next.append(ez_data_up[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if ((np.abs(period_max - period_next_max) / np.abs(min([period_max , period_next_max])) < 10**(-3))) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_up = np.where(ez_data_up == period_max)
        index1_up = index1_up[0]
        print(index1_up , '--- upper point index1')
        index2_up = np.where(ez_data_up == period_next_max)
        index2_up = index2_up[0]
        print(index2_up , '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('upper point 到達誤差範圍內的所需 meep time unit' , index2_up[0] / len(ez_data_up) * t , '\n')
        print('-----------------------------------------------------')
        break

        
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_cen[j])
        period_next.append(ez_data_cen[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if ((np.abs(period_max - period_next_max) / np.abs(min([period_max , period_next_max])) < 10**(-3))) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_cen = np.where(ez_data_cen == period_max)
        index1_cen = index1_cen[0]
        print(index1_cen, '--- upper point index1')
        index2_cen = np.where(ez_data_cen == period_next_max)
        index2_cen = index2_cen[0]
        print(index2_cen, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t')
        print('center point 到達誤差範圍內的所需 meep time unit' , index2_up[0] / len(ez_data_cen) * t , '\n')
        print('-----------------------------------------------------')
        break
        
    
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_down[j])
        period_next.append(ez_data_down[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if ((np.abs(period_max - period_next_max) / np.abs(min([period_max , period_next_max])) < 10**(-3))) :
        print(period_max, '-------- down point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- down point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_down = np.where(ez_data_down == period_max)
        index1_down = index1_down[0]
        print(index1_down, '--- down point index1')
        index2_down = np.where(ez_data_down == period_next_max)
        index2_down = index2_down[0]
        print(index2_down, '--- down point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('down point 到達誤差範圍內的所需 meep time unit' , index2_down[0] / len(ez_data_down) * t , '\n')
        print('-----------------------------------------------------')
        break

index1_max = index1_up[0]
index2_max = index2_up[0]
if index1_cen[0] > index1_max :
    index1_max = index1_up[0]
elif index1_down[0] > index1_max :
    index1_max = index1_down[0]
print(index1_max)

if index2_cen[0] > index2_max :
    index2_max = index2_up[0]
elif index2_down[0] > index2_max :
    index2_max = index2_down[0]
print(index2_max)
# Out:
# (0.15228385227978786+0j) -------- upper point one period 內最大振福
# (0.1521638030121309+0j) ------- upper point one next_period 內最大振福
# (0.00012004926765696311+0j) ----- 振幅誤差
# [15742] --- upper point index1
# [15783] --- upper point index2
# (0.15228385227978786+0j) 	 (0.1521638030121309+0j) 	 (0.00012004926765696311+0j)
# upper point 到達誤差範圍內的所需 meep time unit 102.58960258960259
#
# -----------------------------------------------------
# (0.20945437926328644+0j) -------- upper point one period 內最大振福
# (0.20933617533392737+0j) ------- upper point one next_period 內最大振福
# (0.00011820392935907309+0j) ----- 振幅誤差
# [15479] --- upper point index1
# [15520] --- upper point index2
# (0.20945437926328644+0j) 	 (0.20933617533392737+0j) 	 (0.00011820392935907309+0j)
# center point 到達誤差範圍內的所需 meep time unit 102.58960258960259
#
# -----------------------------------------------------
# (0.1535454503712309+0j) -------- down point one period 內最大振福
# (0.15340570204234535+0j) ------- down point one next_period 內最大振福
# (0.00013974832888555277+0j) ----- 振幅誤差
# [15660] --- down point index1
# [15701] --- down point index2
# (0.1535454503712309+0j) 	 (0.15340570204234535+0j) 	 (0.00013974832888555277+0j)
# down point 到達誤差範圍內的所需 meep time unit 102.05660205660206
#
# -----------------------------------------------------
# 15742
# 15783

# %%
plt.figure(dpi = 150)
plt.title('center point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_up[index1_max]
for i in range(index1_max , index2_max) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_up[i] , 'b.')
    if max_value < ez_data_up[i] :
        max_value = ez_data_up[i]

print(max_value)
# Out:
# (0.15228385227978786+0j)

# %%
plt.figure(dpi = 150)
plt.title('center point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_cen[index1_max]
for i in range(index1_max , index2_max) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_cen[i] , 'b.')
    if max_value < ez_data_cen[i] :
        max_value = ez_data_cen[i]

print(max_value)
# Out:
# (0.21004202901525532+0j)

# %%
plt.figure(dpi = 150)
plt.title('downner point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
for i in range(index1_max , index2_max) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_down[i] , 'b.')
    
max_value = ez_data_down[index1_max]
for i in range(index1_max , index2_max) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_down[i] , 'b.')
    if max_value < ez_data_down[i] :
        max_value = ez_data_down[i]

print(max_value)
# Out:
# (0.154155226047596+0j)

# %% [markdown]
# # Following is Simulation that Cell height = 300 nm

# %%
sim.reset_meep()
resolution = 500  # pixels/μm

dpml = 1.0  # PML thickness
dsub = 0.5  # substrate thickness
dcaa = 0.06  # air rigion for alpha structure
# alpha structure is that one period = 200nm，sigle cell width = 80nm locate at center
dcab = 0.025 # air rigion for beta structure 
# beta structure is that one period = 200nm，sigle cell width = 150nm locate at center
gp = 0.2  # grating periodicity
gh = 0.3  # grating height
gwa = 0.08 # alpha grating cell width
gwb = 0.15 # beta grating cell width

num_cells = 3 # number of grating unit cells

# air region thickness adjacent to grating
dair = 1 

wvl = 0.532  # center wavelength
fcen = 1 / wvl  # center frequency

glass = mp.Medium(index= 2.6678)

pml_layers = [mp.PML(thickness=dpml, direction = mp.X )]

symmetries = [mp.Mirror(mp.Y)]

sx = dpml + dsub + gh + dair + dpml
sy = num_cells*gp
#sy = ((dcaa + gwa + dcaa)*2 + (dcab + gwb + dcab))*num_cells
cell_size = mp.Vector3(sx, sy)

sources = [
    mp.Source(
        mp.ContinuousSource(frequency = 2), # frequemcy = 2原因是 meep 的 C=1，所以 1/? = 0.5 um，?即是2
        component = mp.Ez,
        center = mp.Vector3(-0.5 * sx + dpml ),
        size = mp.Vector3(y = sy),
    )
]

geometry = [
    mp.Block(
        material=glass,
        size=mp.Vector3(dsub, mp.inf, mp.inf),
        center=mp.Vector3(-0.5 * sx + dpml + 0.04 + dsub/2),
    )
]


for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp/2 + (j * 3 * gp),
                #-0.5 * sy + gp/2,
            ),
        )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwa, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + gp + gp/2,
            ),
        )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + 2*gp + gp/2  + (j * 3 * gp),
                #0.5 * sy - gp/2,
            ),
        )
    )

# %%
k_point = mp.Vector3()  # Gamma 點表示週期邊界條件
k_points = [k_point]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
    symmetries=symmetries,
    k_point = mp.Vector3(),
)


# %matplotlib inline
plt.figure(dpi = 125)
sim.plot2D()
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (-0.61,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
t_xx = (.532)
dt = (t_xx / 40)
t = 1000
x_obs = -0.5 * sx + dpml + dsub + gh + 0.002
y_obs_down = -0.5 * sy + gp/2
y_obs_cen = -0.5 * sy + 3*gp/2
y_obs_up = 0.5 * sy - gp/2

print(int((t_xx)/dt))
# Out:
# 40

# %%
# 儲存場量數值的列表
ez_data_cen = []
ez_data_up = []
ez_data_down = []
###
def get_slice(sim):
    ez_data_cen.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_cen) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_up.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_up) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_down.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_down) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))

sim.run(mp.at_every(dt , get_slice) , until = t)

plt.figure(dpi = 100)
sim.plot2D(fields=mp.Ez)
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000794888 s
# Working in 2D dimensions.
# Computational cell is 3.8 x 0.6 x 0 with resolution 500
#      block, center = (-0.61,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
# time for set_epsilon = 0.284423 s
# -----------
# Meep progress: 2.047/1000.0 = 0.2% done in 4.0s, 1950.4s to go
# on time step 2047 (time=2.047), 0.00195448 s/step
# Meep progress: 4.096/1000.0 = 0.4% done in 8.0s, 1945.4s to go
# on time step 4097 (time=4.097), 0.00195223 s/step
# Meep progress: 6.122/1000.0 = 0.6% done in 12.0s, 1948.4s to go
# on time step 6124 (time=6.124), 0.00197407 s/step
# Meep progress: 8.179/1000.0 = 0.8% done in 16.0s, 1940.5s to go
# on time step 8181 (time=8.181), 0.00194468 s/step
# Meep progress: 10.228/1000.0 = 1.0% done in 20.0s, 1935.7s to go
# on time step 10231 (time=10.231), 0.00195224 s/step
# Meep progress: 12.284/1000.0 = 1.2% done in 24.0s, 1930.0s to go
# on time step 12287 (time=12.287), 0.00194553 s/step
# Meep progress: 14.335/1000.0 = 1.4% done in 28.0s, 1925.6s to go
# on time step 14338 (time=14.338), 0.00195042 s/step
# Meep progress: 16.376/1000.0 = 1.6% done in 32.0s, 1922.4s to go
# on time step 16379 (time=16.379), 0.00195996 s/step
# Meep progress: 18.415/1000.0 = 1.8% done in 36.0s, 1919.3s to go
# on time step 18418 (time=18.418), 0.0019621 s/step
# Meep progress: 20.473/1000.0 = 2.0% done in 40.0s, 1914.1s to go
# on time step 20477 (time=20.477), 0.0019435 s/step
# Meep progress: 22.504/1000.0 = 2.3% done in 44.0s, 1911.5s to go
# on time step 22509 (time=22.509), 0.00196907 s/step
# Meep progress: 24.554000000000002/1000.0 = 2.5% done in 48.0s, 1907.2s to go
# on time step 24559 (time=24.559), 0.00195159 s/step
# Meep progress: 26.61/1000.0 = 2.7% done in 52.0s, 1902.5s to go
# on time step 26615 (time=26.615), 0.00194556 s/step
# Meep progress: 28.653000000000002/1000.0 = 2.9% done in 56.0s, 1898.7s to go
# on time step 28658 (time=28.658), 0.00195808 s/step
# Meep progress: 30.668/1000.0 = 3.1% done in 60.0s, 1896.8s to go
# on time step 30674 (time=30.674), 0.00198465 s/step
# Meep progress: 32.723/1000.0 = 3.3% done in 64.0s, 1892.1s to go
# on time step 32730 (time=32.73), 0.00194622 s/step
# Meep progress: 34.761/1000.0 = 3.5% done in 68.0s, 1888.5s to go
# on time step 34768 (time=34.768), 0.00196302 s/step
# Meep progress: 36.821/1000.0 = 3.7% done in 72.0s, 1883.7s to go
# on time step 36829 (time=36.829), 0.00194175 s/step
# Meep progress: 38.878/1000.0 = 3.9% done in 76.0s, 1879.1s to go
# on time step 38887 (time=38.887), 0.00194386 s/step
# Meep progress: 40.93/1000.0 = 4.1% done in 80.0s, 1874.9s to go
# on time step 40939 (time=40.939), 0.00194978 s/step
# Meep progress: 42.998/1000.0 = 4.3% done in 84.0s, 1869.9s to go
# on time step 43007 (time=43.007), 0.00193477 s/step
# Meep progress: 45.043/1000.0 = 4.5% done in 88.0s, 1866.0s to go
# on time step 45052 (time=45.052), 0.00195656 s/step
# Meep progress: 47.098/1000.0 = 4.7% done in 92.0s, 1861.7s to go
# on time step 47107 (time=47.107), 0.00194709 s/step
# Meep progress: 49.163000000000004/1000.0 = 4.9% done in 96.0s, 1857.0s to go
# on time step 49174 (time=49.174), 0.00193561 s/step
# Meep progress: 51.205/1000.0 = 5.1% done in 100.0s, 1853.3s to go
# on time step 51215 (time=51.215), 0.00196006 s/step
# Meep progress: 53.267/1000.0 = 5.3% done in 104.0s, 1848.7s to go
# on time step 53279 (time=53.279), 0.00193872 s/step
# Meep progress: 55.326/1000.0 = 5.5% done in 108.0s, 1844.4s to go
# on time step 55338 (time=55.338), 0.0019431 s/step
# Meep progress: 57.373000000000005/1000.0 = 5.7% done in 112.0s, 1840.5s to go
# on time step 57386 (time=57.386), 0.00195377 s/step
# Meep progress: 59.42/1000.0 = 5.9% done in 116.0s, 1836.5s to go
# on time step 59433 (time=59.433), 0.00195461 s/step
# Meep progress: 61.475/1000.0 = 6.1% done in 120.0s, 1832.3s to go
# on time step 61490 (time=61.49), 0.00194532 s/step
# Meep progress: 63.904/1000.0 = 6.4% done in 124.0s, 1816.7s to go
# on time step 63923 (time=63.923), 0.00164432 s/step
# Meep progress: 66.641/1000.0 = 6.7% done in 128.0s, 1793.0s to go
# on time step 66661 (time=66.661), 0.00146095 s/step
# Meep progress: 69.379/1000.0 = 6.9% done in 132.0s, 1770.9s to go
# on time step 69398 (time=69.398), 0.00146214 s/step
# Meep progress: 72.105/1000.0 = 7.2% done in 136.0s, 1750.4s to go
# on time step 72122 (time=72.122), 0.0014685 s/step
# Meep progress: 74.843/1000.0 = 7.5% done in 140.0s, 1730.9s to go
# on time step 74864 (time=74.864), 0.0014588 s/step
# Meep progress: 77.61/1000.0 = 7.8% done in 144.0s, 1711.7s to go
# on time step 77631 (time=77.631), 0.00144566 s/step
# Meep progress: 80.389/1000.0 = 8.0% done in 148.0s, 1693.3s to go
# on time step 80410 (time=80.41), 0.00143978 s/step
# Meep progress: 83.202/1000.0 = 8.3% done in 152.0s, 1675.2s to go
# on time step 83224 (time=83.224), 0.00142151 s/step
# Meep progress: 85.98100000000001/1000.0 = 8.6% done in 156.0s, 1658.6s to go
# on time step 86000 (time=86), 0.00144123 s/step
# Meep progress: 88.815/1000.0 = 8.9% done in 160.0s, 1641.8s to go
# on time step 88837 (time=88.837), 0.00141043 s/step
# Meep progress: 91.618/1000.0 = 9.2% done in 164.0s, 1626.3s to go
# on time step 91643 (time=91.643), 0.00142552 s/step
# Meep progress: 94.458/1000.0 = 9.4% done in 168.0s, 1610.8s to go
# on time step 94484 (time=94.484), 0.00140821 s/step
# Meep progress: 97.313/1000.0 = 9.7% done in 172.0s, 1595.8s to go
# on time step 97340 (time=97.34), 0.00140064 s/step
# Meep progress: 100.162/1000.0 = 10.0% done in 176.0s, 1581.4s to go
# on time step 100188 (time=100.188), 0.00140463 s/step
# Meep progress: 102.98700000000001/1000.0 = 10.3% done in 180.0s, 1568.1s to go
# on time step 103014 (time=103.014), 0.00141593 s/step
# Meep progress: 105.81700000000001/1000.0 = 10.6% done in 184.0s, 1555.1s to go
# on time step 105844 (time=105.844), 0.00141344 s/step
# Meep progress: 108.653/1000.0 = 10.9% done in 188.0s, 1542.5s to go
# on time step 108682 (time=108.682), 0.00140976 s/step
# Meep progress: 111.49300000000001/1000.0 = 11.1% done in 192.0s, 1530.3s to go
# on time step 111521 (time=111.521), 0.001409 s/step
# Meep progress: 114.342/1000.0 = 11.4% done in 196.0s, 1518.4s to go
# on time step 114368 (time=114.368), 0.00140505 s/step
# Meep progress: 117.197/1000.0 = 11.7% done in 200.0s, 1506.8s to go
# on time step 117226 (time=117.226), 0.00139962 s/step
# Meep progress: 120.042/1000.0 = 12.0% done in 204.0s, 1495.7s to go
# on time step 120069 (time=120.069), 0.00140718 s/step
# Meep progress: 122.82300000000001/1000.0 = 12.3% done in 208.0s, 1485.7s to go
# on time step 122851 (time=122.851), 0.00143847 s/step
# Meep progress: 125.649/1000.0 = 12.6% done in 212.0s, 1475.5s to go
# on time step 125677 (time=125.677), 0.00141572 s/step
# Meep progress: 128.479/1000.0 = 12.8% done in 216.0s, 1465.5s to go
# on time step 128508 (time=128.508), 0.00141297 s/step
# Meep progress: 131.328/1000.0 = 13.1% done in 220.0s, 1455.4s to go
# on time step 131357 (time=131.357), 0.00140401 s/step
# Meep progress: 134.166/1000.0 = 13.4% done in 224.0s, 1445.8s to go
# on time step 134195 (time=134.195), 0.00140955 s/step
# Meep progress: 137.04/1000.0 = 13.7% done in 228.0s, 1436.0s to go
# on time step 137071 (time=137.071), 0.00139113 s/step
# Meep progress: 139.873/1000.0 = 14.0% done in 232.0s, 1426.9s to go
# on time step 139902 (time=139.902), 0.00141333 s/step
# Meep progress: 142.75/1000.0 = 14.3% done in 236.0s, 1417.5s to go
# on time step 142781 (time=142.781), 0.0013896 s/step
# Meep progress: 145.594/1000.0 = 14.6% done in 240.0s, 1408.7s to go
# on time step 145626 (time=145.626), 0.00140661 s/step
# Meep progress: 148.412/1000.0 = 14.8% done in 244.0s, 1400.3s to go
# on time step 148444 (time=148.444), 0.00141968 s/step
# Meep progress: 151.227/1000.0 = 15.1% done in 248.0s, 1392.2s to go
# on time step 151260 (time=151.26), 0.00142073 s/step
# Meep progress: 154.082/1000.0 = 15.4% done in 252.0s, 1383.7s to go
# on time step 154114 (time=154.114), 0.00140208 s/step
# Meep progress: 156.849/1000.0 = 15.7% done in 256.0s, 1376.4s to go
# on time step 156883 (time=156.883), 0.00144493 s/step
# Meep progress: 159.679/1000.0 = 16.0% done in 260.0s, 1368.5s to go
# on time step 159715 (time=159.715), 0.00141252 s/step
# Meep progress: 162.536/1000.0 = 16.3% done in 264.0s, 1360.5s to go
# on time step 162568 (time=162.568), 0.00140214 s/step
# Meep progress: 165.276/1000.0 = 16.5% done in 268.0s, 1353.8s to go
# on time step 165309 (time=165.309), 0.0014594 s/step
# Meep progress: 168.03900000000002/1000.0 = 16.8% done in 272.0s, 1346.9s to go
# on time step 168075 (time=168.075), 0.00144641 s/step
# Meep progress: 170.852/1000.0 = 17.1% done in 276.0s, 1339.7s to go
# on time step 170888 (time=170.888), 0.00142233 s/step
# Meep progress: 173.698/1000.0 = 17.4% done in 280.0s, 1332.2s to go
# on time step 173735 (time=173.735), 0.00140514 s/step
# Meep progress: 176.516/1000.0 = 17.7% done in 284.0s, 1325.1s to go
# on time step 176554 (time=176.554), 0.00141949 s/step
# Meep progress: 179.353/1000.0 = 17.9% done in 288.0s, 1318.0s to go
# on time step 179389 (time=179.389), 0.00141103 s/step
# Meep progress: 182.173/1000.0 = 18.2% done in 292.0s, 1311.1s to go
# on time step 182211 (time=182.211), 0.00141786 s/step
# Meep progress: 185.029/1000.0 = 18.5% done in 296.1s, 1304.0s to go
# on time step 185068 (time=185.068), 0.00140019 s/step
# Meep progress: 187.841/1000.0 = 18.8% done in 300.1s, 1297.3s to go
# on time step 187879 (time=187.879), 0.00142338 s/step
# Meep progress: 190.65800000000002/1000.0 = 19.1% done in 304.1s, 1290.7s to go
# on time step 190694 (time=190.694), 0.00142145 s/step
# Meep progress: 193.52700000000002/1000.0 = 19.4% done in 308.1s, 1283.7s to go
# on time step 193569 (time=193.569), 0.00139159 s/step
# Meep progress: 196.37/1000.0 = 19.6% done in 312.1s, 1277.1s to go
# on time step 196409 (time=196.409), 0.00140881 s/step
# Meep progress: 199.193/1000.0 = 19.9% done in 316.1s, 1270.6s to go
# on time step 199232 (time=199.232), 0.00141732 s/step
# Meep progress: 202.04/1000.0 = 20.2% done in 320.1s, 1264.1s to go
# on time step 202085 (time=202.085), 0.00140231 s/step
# Meep progress: 204.88/1000.0 = 20.5% done in 324.1s, 1257.6s to go
# on time step 204919 (time=204.919), 0.00141154 s/step
# Meep progress: 207.748/1000.0 = 20.8% done in 328.1s, 1251.1s to go
# on time step 207791 (time=207.791), 0.00139314 s/step
# Meep progress: 210.596/1000.0 = 21.1% done in 332.1s, 1244.7s to go
# on time step 210639 (time=210.639), 0.00140452 s/step
# Meep progress: 213.437/1000.0 = 21.3% done in 336.1s, 1238.5s to go
# on time step 213482 (time=213.482), 0.00140732 s/step
# Meep progress: 216.294/1000.0 = 21.6% done in 340.1s, 1232.2s to go
# on time step 216340 (time=216.34), 0.00139979 s/step
# Meep progress: 219.15/1000.0 = 21.9% done in 344.1s, 1225.9s to go
# on time step 219193 (time=219.193), 0.00140209 s/step
# Meep progress: 221.981/1000.0 = 22.2% done in 348.1s, 1219.9s to go
# on time step 222026 (time=222.026), 0.00141212 s/step
# Meep progress: 224.86700000000002/1000.0 = 22.5% done in 352.1s, 1213.6s to go
# on time step 224912 (time=224.912), 0.00138641 s/step
# Meep progress: 227.773/1000.0 = 22.8% done in 356.1s, 1207.2s to go
# on time step 227820 (time=227.82), 0.00137582 s/step
# Meep progress: 230.648/1000.0 = 23.1% done in 360.1s, 1201.0s to go
# on time step 230687 (time=230.687), 0.00139565 s/step
# Meep progress: 233.461/1000.0 = 23.3% done in 364.1s, 1195.4s to go
# on time step 233505 (time=233.505), 0.00141991 s/step
# Meep progress: 236.368/1000.0 = 23.6% done in 368.1s, 1189.1s to go
# on time step 236416 (time=236.416), 0.00137414 s/step
# Meep progress: 239.23000000000002/1000.0 = 23.9% done in 372.1s, 1183.2s to go
# on time step 239275 (time=239.275), 0.00139914 s/step
# Meep progress: 242.08700000000002/1000.0 = 24.2% done in 376.1s, 1177.4s to go
# on time step 242137 (time=242.137), 0.00139798 s/step
# Meep progress: 244.976/1000.0 = 24.5% done in 380.1s, 1171.4s to go
# on time step 245026 (time=245.026), 0.00138483 s/step
# Meep progress: 247.836/1000.0 = 24.8% done in 384.1s, 1165.6s to go
# on time step 247886 (time=247.886), 0.00139868 s/step
# Meep progress: 250.703/1000.0 = 25.1% done in 388.1s, 1159.9s to go
# on time step 250748 (time=250.748), 0.00139763 s/step
# Meep progress: 253.544/1000.0 = 25.4% done in 392.1s, 1154.3s to go
# on time step 253592 (time=253.592), 0.00140647 s/step
# Meep progress: 256.412/1000.0 = 25.6% done in 396.1s, 1148.6s to go
# on time step 256460 (time=256.46), 0.00139479 s/step
# Meep progress: 259.27/1000.0 = 25.9% done in 400.1s, 1143.0s to go
# on time step 259319 (time=259.319), 0.00139934 s/step
# Meep progress: 262.128/1000.0 = 26.2% done in 404.1s, 1137.4s to go
# on time step 262175 (time=262.175), 0.00140092 s/step
# Meep progress: 264.982/1000.0 = 26.5% done in 408.1s, 1131.9s to go
# on time step 265031 (time=265.031), 0.00140089 s/step
# Meep progress: 267.85200000000003/1000.0 = 26.8% done in 412.1s, 1126.4s to go
# on time step 267900 (time=267.9), 0.00139446 s/step
# Meep progress: 270.693/1000.0 = 27.1% done in 416.1s, 1121.0s to go
# on time step 270741 (time=270.741), 0.00140818 s/step
# Meep progress: 273.54/1000.0 = 27.4% done in 420.1s, 1115.6s to go
# on time step 273585 (time=273.585), 0.00140648 s/step
# Meep progress: 276.408/1000.0 = 27.6% done in 424.1s, 1110.2s to go
# on time step 276458 (time=276.458), 0.00139231 s/step
# Meep progress: 279.299/1000.0 = 27.9% done in 428.1s, 1104.6s to go
# on time step 279351 (time=279.351), 0.00138271 s/step
# Meep progress: 282.175/1000.0 = 28.2% done in 432.1s, 1099.2s to go
# on time step 282221 (time=282.221), 0.00139389 s/step
# Meep progress: 285.049/1000.0 = 28.5% done in 436.1s, 1093.8s to go
# on time step 285101 (time=285.101), 0.00138948 s/step
# Meep progress: 287.895/1000.0 = 28.8% done in 440.1s, 1088.5s to go
# on time step 287947 (time=287.947), 0.00140573 s/step
# Meep progress: 290.79200000000003/1000.0 = 29.1% done in 444.1s, 1083.1s to go
# on time step 290846 (time=290.846), 0.00138024 s/step
# Meep progress: 293.69/1000.0 = 29.4% done in 448.1s, 1077.6s to go
# on time step 293741 (time=293.741), 0.00138176 s/step
# Meep progress: 296.526/1000.0 = 29.7% done in 452.1s, 1072.5s to go
# on time step 296582 (time=296.582), 0.00140811 s/step
# Meep progress: 299.426/1000.0 = 29.9% done in 456.1s, 1067.1s to go
# on time step 299479 (time=299.479), 0.00138093 s/step
# Meep progress: 302.3/1000.0 = 30.2% done in 460.1s, 1061.9s to go
# on time step 302355 (time=302.355), 0.00139098 s/step
# Meep progress: 305.154/1000.0 = 30.5% done in 464.1s, 1056.7s to go
# on time step 305211 (time=305.211), 0.00140094 s/step
# Meep progress: 308.028/1000.0 = 30.8% done in 468.1s, 1051.5s to go
# on time step 308084 (time=308.084), 0.00139236 s/step
# Meep progress: 310.849/1000.0 = 31.1% done in 472.1s, 1046.6s to go
# on time step 310896 (time=310.896), 0.00142259 s/step
# Meep progress: 313.716/1000.0 = 31.4% done in 476.1s, 1041.5s to go
# on time step 313772 (time=313.772), 0.00139129 s/step
# Meep progress: 316.61/1000.0 = 31.7% done in 480.1s, 1036.2s to go
# on time step 316669 (time=316.669), 0.00138127 s/step
# Meep progress: 319.348/1000.0 = 31.9% done in 484.1s, 1031.8s to go
# on time step 319402 (time=319.402), 0.0014636 s/step
# Meep progress: 322.132/1000.0 = 32.2% done in 488.1s, 1027.1s to go
# on time step 322192 (time=322.192), 0.00143372 s/step
# Meep progress: 325.01/1000.0 = 32.5% done in 492.1s, 1022.0s to go
# on time step 325067 (time=325.067), 0.00139175 s/step
# Meep progress: 327.889/1000.0 = 32.8% done in 496.1s, 1016.9s to go
# on time step 327951 (time=327.951), 0.0013871 s/step
# Meep progress: 330.613/1000.0 = 33.1% done in 500.1s, 1012.5s to go
# on time step 330666 (time=330.666), 0.00147338 s/step
# Meep progress: 333.466/1000.0 = 33.3% done in 504.1s, 1007.6s to go
# on time step 333525 (time=333.525), 0.00139912 s/step
# Meep progress: 336.273/1000.0 = 33.6% done in 508.1s, 1002.8s to go
# on time step 336330 (time=336.33), 0.00142647 s/step
# Meep progress: 339.002/1000.0 = 33.9% done in 512.1s, 998.5s to go
# on time step 339068 (time=339.068), 0.0014614 s/step
# Meep progress: 341.813/1000.0 = 34.2% done in 516.1s, 993.8s to go
# on time step 341876 (time=341.876), 0.00142462 s/step
# Meep progress: 344.67400000000004/1000.0 = 34.5% done in 520.1s, 988.8s to go
# on time step 344736 (time=344.736), 0.00139861 s/step
# Meep progress: 347.47700000000003/1000.0 = 34.7% done in 524.1s, 984.2s to go
# on time step 347539 (time=347.539), 0.00142736 s/step
# Meep progress: 350.293/1000.0 = 35.0% done in 528.1s, 979.5s to go
# on time step 350360 (time=350.36), 0.00141837 s/step
# Meep progress: 353.116/1000.0 = 35.3% done in 532.1s, 974.8s to go
# on time step 353180 (time=353.18), 0.00141885 s/step
# Meep progress: 355.927/1000.0 = 35.6% done in 536.1s, 970.1s to go
# on time step 355991 (time=355.991), 0.00142337 s/step
# Meep progress: 358.75/1000.0 = 35.9% done in 540.1s, 965.4s to go
# on time step 358800 (time=358.8), 0.00142451 s/step
# Meep progress: 361.572/1000.0 = 36.2% done in 544.1s, 960.7s to go
# on time step 361638 (time=361.638), 0.00140987 s/step
# Meep progress: 364.41200000000003/1000.0 = 36.4% done in 548.1s, 956.0s to go
# on time step 364476 (time=364.476), 0.0014097 s/step
# Meep progress: 367.25/1000.0 = 36.7% done in 552.1s, 951.2s to go
# on time step 367316 (time=367.316), 0.00140859 s/step
# Meep progress: 370.07800000000003/1000.0 = 37.0% done in 556.1s, 946.6s to go
# on time step 370145 (time=370.145), 0.00141433 s/step
# Meep progress: 372.925/1000.0 = 37.3% done in 560.1s, 941.8s to go
# on time step 372995 (time=372.995), 0.00140355 s/step
# Meep progress: 375.765/1000.0 = 37.6% done in 564.1s, 937.1s to go
# on time step 375835 (time=375.835), 0.00140853 s/step
# Meep progress: 378.532/1000.0 = 37.9% done in 568.1s, 932.7s to go
# on time step 378595 (time=378.595), 0.00144972 s/step
# Meep progress: 381.407/1000.0 = 38.1% done in 572.1s, 927.9s to go
# on time step 381478 (time=381.478), 0.00138761 s/step
# Meep progress: 384.225/1000.0 = 38.4% done in 576.1s, 923.3s to go
# on time step 384294 (time=384.294), 0.00142085 s/step
# Meep progress: 387.043/1000.0 = 38.7% done in 580.1s, 918.7s to go
# on time step 387115 (time=387.115), 0.00141803 s/step
# Meep progress: 389.919/1000.0 = 39.0% done in 584.1s, 913.9s to go
# on time step 389990 (time=389.99), 0.00139136 s/step
# Meep progress: 392.738/1000.0 = 39.3% done in 588.1s, 909.3s to go
# on time step 392804 (time=392.804), 0.00142183 s/step
# Meep progress: 395.584/1000.0 = 39.6% done in 592.1s, 904.7s to go
# on time step 395656 (time=395.656), 0.00140272 s/step
# Meep progress: 398.451/1000.0 = 39.8% done in 596.1s, 899.9s to go
# on time step 398521 (time=398.521), 0.00139648 s/step
# Meep progress: 401.237/1000.0 = 40.1% done in 600.1s, 895.5s to go
# on time step 401311 (time=401.311), 0.00143386 s/step
# Meep progress: 404.084/1000.0 = 40.4% done in 604.1s, 890.9s to go
# on time step 404154 (time=404.154), 0.00140746 s/step
# Meep progress: 406.88800000000003/1000.0 = 40.7% done in 608.1s, 886.4s to go
# on time step 406964 (time=406.964), 0.00142351 s/step
# Meep progress: 409.713/1000.0 = 41.0% done in 612.1s, 881.9s to go
# on time step 409786 (time=409.786), 0.00141792 s/step
# Meep progress: 412.487/1000.0 = 41.2% done in 616.1s, 877.5s to go
# on time step 412560 (time=412.56), 0.00144239 s/step
# Meep progress: 415.33/1000.0 = 41.5% done in 620.1s, 872.9s to go
# on time step 415401 (time=415.401), 0.00140831 s/step
# Meep progress: 418.181/1000.0 = 41.8% done in 624.1s, 868.3s to go
# on time step 418251 (time=418.251), 0.00140384 s/step
# Meep progress: 421.023/1000.0 = 42.1% done in 628.1s, 863.8s to go
# on time step 421099 (time=421.099), 0.00140486 s/step
# Meep progress: 423.822/1000.0 = 42.4% done in 632.1s, 859.3s to go
# on time step 423901 (time=423.901), 0.00142761 s/step
# Meep progress: 426.67400000000004/1000.0 = 42.7% done in 636.1s, 854.7s to go
# on time step 426750 (time=426.75), 0.00140401 s/step
# Meep progress: 429.551/1000.0 = 43.0% done in 640.1s, 850.1s to go
# on time step 429625 (time=429.625), 0.00139159 s/step
# Meep progress: 432.38100000000003/1000.0 = 43.2% done in 644.1s, 845.6s to go
# on time step 432462 (time=432.462), 0.00141011 s/step
# Meep progress: 435.228/1000.0 = 43.5% done in 648.1s, 841.0s to go
# on time step 435307 (time=435.307), 0.00140601 s/step
# Meep progress: 438.05400000000003/1000.0 = 43.8% done in 652.1s, 836.5s to go
# on time step 438134 (time=438.134), 0.00141515 s/step
# Meep progress: 440.927/1000.0 = 44.1% done in 656.1s, 831.9s to go
# on time step 441007 (time=441.007), 0.00139232 s/step
# Meep progress: 443.744/1000.0 = 44.4% done in 660.1s, 827.5s to go
# on time step 443816 (time=443.816), 0.00142413 s/step
# Meep progress: 446.53700000000003/1000.0 = 44.7% done in 664.1s, 823.1s to go
# on time step 446613 (time=446.613), 0.0014304 s/step
# Meep progress: 449.362/1000.0 = 44.9% done in 668.1s, 818.7s to go
# on time step 449434 (time=449.434), 0.00141813 s/step
# Meep progress: 452.16200000000003/1000.0 = 45.2% done in 672.1s, 814.3s to go
# on time step 452238 (time=452.238), 0.00142667 s/step
# Meep progress: 454.998/1000.0 = 45.5% done in 676.1s, 809.9s to go
# on time step 455075 (time=455.075), 0.00141035 s/step
# Meep progress: 457.821/1000.0 = 45.8% done in 680.1s, 805.4s to go
# on time step 457903 (time=457.903), 0.00141496 s/step
# Meep progress: 460.682/1000.0 = 46.1% done in 684.1s, 800.9s to go
# on time step 460756 (time=460.756), 0.00140224 s/step
# Meep progress: 463.47200000000004/1000.0 = 46.3% done in 688.1s, 796.6s to go
# on time step 463553 (time=463.553), 0.00143044 s/step
# Meep progress: 466.303/1000.0 = 46.6% done in 692.1s, 792.2s to go
# on time step 466380 (time=466.38), 0.00141496 s/step
# Meep progress: 469.10200000000003/1000.0 = 46.9% done in 696.1s, 787.8s to go
# on time step 469176 (time=469.176), 0.00143117 s/step
# Meep progress: 471.88800000000003/1000.0 = 47.2% done in 700.1s, 783.5s to go
# on time step 471967 (time=471.967), 0.00143355 s/step
# Meep progress: 474.70300000000003/1000.0 = 47.5% done in 704.1s, 779.2s to go
# on time step 474786 (time=474.786), 0.00141935 s/step
# Meep progress: 477.507/1000.0 = 47.8% done in 708.1s, 774.8s to go
# on time step 477590 (time=477.59), 0.00142719 s/step
# Meep progress: 480.331/1000.0 = 48.0% done in 712.1s, 770.4s to go
# on time step 480414 (time=480.414), 0.00141697 s/step
# Meep progress: 483.156/1000.0 = 48.3% done in 716.1s, 766.1s to go
# on time step 483242 (time=483.242), 0.00141458 s/step
# Meep progress: 486.02/1000.0 = 48.6% done in 720.1s, 761.6s to go
# on time step 486107 (time=486.107), 0.00139637 s/step
# Meep progress: 488.85900000000004/1000.0 = 48.9% done in 724.1s, 757.1s to go
# on time step 488946 (time=488.946), 0.00140938 s/step
# Meep progress: 491.713/1000.0 = 49.2% done in 728.1s, 752.7s to go
# on time step 491798 (time=491.798), 0.00140298 s/step
# Meep progress: 494.555/1000.0 = 49.5% done in 732.1s, 748.3s to go
# on time step 494638 (time=494.638), 0.0014087 s/step
# Meep progress: 497.407/1000.0 = 49.7% done in 736.1s, 743.8s to go
# on time step 497497 (time=497.497), 0.00139913 s/step
# Meep progress: 500.241/1000.0 = 50.0% done in 740.1s, 739.4s to go
# on time step 500332 (time=500.332), 0.00141123 s/step
# Meep progress: 503.052/1000.0 = 50.3% done in 744.1s, 735.1s to go
# on time step 503144 (time=503.144), 0.00142258 s/step
# Meep progress: 505.896/1000.0 = 50.6% done in 748.1s, 730.7s to go
# on time step 505986 (time=505.986), 0.00140772 s/step
# Meep progress: 508.731/1000.0 = 50.9% done in 752.1s, 726.3s to go
# on time step 508818 (time=508.818), 0.00141282 s/step
# Meep progress: 511.568/1000.0 = 51.2% done in 756.1s, 721.9s to go
# on time step 511655 (time=511.655), 0.00141002 s/step
# Meep progress: 514.376/1000.0 = 51.4% done in 760.1s, 717.6s to go
# on time step 514466 (time=514.466), 0.00142309 s/step
# Meep progress: 517.231/1000.0 = 51.7% done in 764.1s, 713.2s to go
# on time step 517316 (time=517.316), 0.00140354 s/step
# Meep progress: 520.08/1000.0 = 52.0% done in 768.1s, 708.8s to go
# on time step 520170 (time=520.17), 0.00140175 s/step
# Meep progress: 522.915/1000.0 = 52.3% done in 772.1s, 704.5s to go
# on time step 523007 (time=523.007), 0.00140995 s/step
# Meep progress: 525.746/1000.0 = 52.6% done in 776.1s, 700.1s to go
# on time step 525835 (time=525.835), 0.00141467 s/step
# Meep progress: 528.563/1000.0 = 52.9% done in 780.1s, 695.8s to go
# on time step 528652 (time=528.652), 0.00142011 s/step
# Meep progress: 531.361/1000.0 = 53.1% done in 784.1s, 691.6s to go
# on time step 531454 (time=531.454), 0.00142782 s/step
# Meep progress: 534.1510000000001/1000.0 = 53.4% done in 788.1s, 687.4s to go
# on time step 534241 (time=534.241), 0.00143562 s/step
# Meep progress: 537.004/1000.0 = 53.7% done in 792.1s, 683.0s to go
# on time step 537093 (time=537.093), 0.00140285 s/step
# Meep progress: 539.847/1000.0 = 54.0% done in 796.1s, 678.6s to go
# on time step 539945 (time=539.945), 0.00140272 s/step
# Meep progress: 542.7090000000001/1000.0 = 54.3% done in 800.1s, 674.2s to go
# on time step 542808 (time=542.808), 0.00139747 s/step
# Meep progress: 545.2090000000001/1000.0 = 54.5% done in 804.1s, 670.8s to go
# on time step 545293 (time=545.293), 0.00161012 s/step
# Meep progress: 547.87/1000.0 = 54.8% done in 808.1s, 666.9s to go
# on time step 547969 (time=547.969), 0.00149532 s/step
# Meep progress: 550.672/1000.0 = 55.1% done in 812.1s, 662.7s to go
# on time step 550771 (time=550.771), 0.00142809 s/step
# Meep progress: 553.551/1000.0 = 55.4% done in 816.1s, 658.2s to go
# on time step 553644 (time=553.644), 0.00139272 s/step
# Meep progress: 556.351/1000.0 = 55.6% done in 820.1s, 654.0s to go
# on time step 556448 (time=556.448), 0.00142685 s/step
# Meep progress: 559.191/1000.0 = 55.9% done in 824.1s, 649.7s to go
# on time step 559290 (time=559.29), 0.00140786 s/step
# Meep progress: 562.016/1000.0 = 56.2% done in 828.1s, 645.4s to go
# on time step 562114 (time=562.114), 0.00141684 s/step
# Meep progress: 564.8100000000001/1000.0 = 56.5% done in 832.1s, 641.2s to go
# on time step 564911 (time=564.911), 0.00143028 s/step
# Meep progress: 567.564/1000.0 = 56.8% done in 836.1s, 637.1s to go
# on time step 567665 (time=567.665), 0.00145248 s/step
# Meep progress: 570.371/1000.0 = 57.0% done in 840.1s, 632.8s to go
# on time step 570471 (time=570.471), 0.00142609 s/step
# Meep progress: 573.208/1000.0 = 57.3% done in 844.1s, 628.5s to go
# on time step 573312 (time=573.312), 0.00140827 s/step
# Meep progress: 576.043/1000.0 = 57.6% done in 848.1s, 624.2s to go
# on time step 576139 (time=576.139), 0.00141502 s/step
# Meep progress: 578.884/1000.0 = 57.9% done in 852.2s, 619.9s to go
# on time step 578984 (time=578.984), 0.00140614 s/step
# Meep progress: 581.777/1000.0 = 58.2% done in 856.2s, 615.5s to go
# on time step 581877 (time=581.877), 0.00138299 s/step
# Meep progress: 584.635/1000.0 = 58.5% done in 860.2s, 611.1s to go
# on time step 584740 (time=584.74), 0.00139732 s/step
# Meep progress: 587.439/1000.0 = 58.7% done in 864.2s, 606.9s to go
# on time step 587538 (time=587.538), 0.0014297 s/step
# Meep progress: 590.279/1000.0 = 59.0% done in 868.2s, 602.6s to go
# on time step 590385 (time=590.385), 0.00140526 s/step
# Meep progress: 593.128/1000.0 = 59.3% done in 872.2s, 598.3s to go
# on time step 593233 (time=593.233), 0.00140489 s/step
# Meep progress: 595.926/1000.0 = 59.6% done in 876.2s, 594.1s to go
# on time step 596028 (time=596.028), 0.00143137 s/step
# Meep progress: 598.729/1000.0 = 59.9% done in 880.2s, 589.9s to go
# on time step 598836 (time=598.836), 0.00142452 s/step
# Meep progress: 601.5360000000001/1000.0 = 60.2% done in 884.2s, 585.7s to go
# on time step 601643 (time=601.643), 0.00142506 s/step
# Meep progress: 604.343/1000.0 = 60.4% done in 888.2s, 581.5s to go
# on time step 604450 (time=604.45), 0.00142558 s/step
# Meep progress: 607.16/1000.0 = 60.7% done in 892.2s, 577.2s to go
# on time step 607268 (time=607.268), 0.0014197 s/step
# Meep progress: 609.968/1000.0 = 61.0% done in 896.2s, 573.0s to go
# on time step 610076 (time=610.076), 0.00142472 s/step
# Meep progress: 612.7860000000001/1000.0 = 61.3% done in 900.2s, 568.8s to go
# on time step 612885 (time=612.885), 0.00142416 s/step
# Meep progress: 615.613/1000.0 = 61.6% done in 904.2s, 564.6s to go
# on time step 615717 (time=615.717), 0.00141269 s/step
# Meep progress: 618.439/1000.0 = 61.8% done in 908.2s, 560.3s to go
# on time step 618552 (time=618.552), 0.00141103 s/step
# Meep progress: 621.282/1000.0 = 62.1% done in 912.2s, 556.0s to go
# on time step 621387 (time=621.387), 0.0014113 s/step
# Meep progress: 624.064/1000.0 = 62.4% done in 916.2s, 551.9s to go
# on time step 624178 (time=624.178), 0.00143335 s/step
# Meep progress: 626.913/1000.0 = 62.7% done in 920.2s, 547.6s to go
# on time step 627024 (time=627.024), 0.00140583 s/step
# Meep progress: 629.729/1000.0 = 63.0% done in 924.2s, 543.4s to go
# on time step 629834 (time=629.834), 0.00142384 s/step
# Meep progress: 632.604/1000.0 = 63.3% done in 928.2s, 539.0s to go
# on time step 632711 (time=632.711), 0.00139064 s/step
# Meep progress: 635.4010000000001/1000.0 = 63.5% done in 932.2s, 534.9s to go
# on time step 635505 (time=635.505), 0.00143175 s/step
# Meep progress: 638.225/1000.0 = 63.8% done in 936.2s, 530.7s to go
# on time step 638336 (time=638.336), 0.00141311 s/step
# Meep progress: 641.0120000000001/1000.0 = 64.1% done in 940.2s, 526.5s to go
# on time step 641126 (time=641.126), 0.00143387 s/step
# Meep progress: 643.862/1000.0 = 64.4% done in 944.2s, 522.2s to go
# on time step 643969 (time=643.969), 0.00140709 s/step
# Meep progress: 646.712/1000.0 = 64.7% done in 948.2s, 518.0s to go
# on time step 646820 (time=646.82), 0.00140359 s/step
# Meep progress: 649.575/1000.0 = 65.0% done in 952.2s, 513.7s to go
# on time step 649690 (time=649.69), 0.00139391 s/step
# Meep progress: 652.393/1000.0 = 65.2% done in 956.2s, 509.5s to go
# on time step 652502 (time=652.502), 0.00142261 s/step
# Meep progress: 655.245/1000.0 = 65.5% done in 960.2s, 505.2s to go
# on time step 655357 (time=655.357), 0.00140108 s/step
# Meep progress: 658.0980000000001/1000.0 = 65.8% done in 964.2s, 500.9s to go
# on time step 658214 (time=658.214), 0.00140016 s/step
# Meep progress: 660.967/1000.0 = 66.1% done in 968.2s, 496.6s to go
# on time step 661082 (time=661.082), 0.00139514 s/step
# Meep progress: 663.828/1000.0 = 66.4% done in 972.2s, 492.3s to go
# on time step 663938 (time=663.938), 0.00140067 s/step
# Meep progress: 666.67/1000.0 = 66.7% done in 976.2s, 488.1s to go
# on time step 666781 (time=666.781), 0.00140738 s/step
# Meep progress: 669.496/1000.0 = 66.9% done in 980.2s, 483.9s to go
# on time step 669612 (time=669.612), 0.00141323 s/step
# Meep progress: 672.332/1000.0 = 67.2% done in 984.2s, 479.6s to go
# on time step 672443 (time=672.443), 0.00141322 s/step
# Meep progress: 675.189/1000.0 = 67.5% done in 988.2s, 475.4s to go
# on time step 675301 (time=675.301), 0.00139969 s/step
# Meep progress: 678.016/1000.0 = 67.8% done in 992.2s, 471.2s to go
# on time step 678127 (time=678.127), 0.00141581 s/step
# Meep progress: 680.886/1000.0 = 68.1% done in 996.2s, 466.9s to go
# on time step 680999 (time=680.999), 0.00139294 s/step
# Meep progress: 683.691/1000.0 = 68.4% done in 1000.2s, 462.7s to go
# on time step 683806 (time=683.806), 0.00142535 s/step
# Meep progress: 686.563/1000.0 = 68.7% done in 1004.2s, 458.4s to go
# on time step 686682 (time=686.682), 0.00139099 s/step
# Meep progress: 689.403/1000.0 = 68.9% done in 1008.2s, 454.2s to go
# on time step 689522 (time=689.522), 0.00140846 s/step
# Meep progress: 692.227/1000.0 = 69.2% done in 1012.2s, 450.0s to go
# on time step 692341 (time=692.341), 0.00141966 s/step
# Meep progress: 695.047/1000.0 = 69.5% done in 1016.2s, 445.9s to go
# on time step 695165 (time=695.165), 0.0014167 s/step
# Meep progress: 697.931/1000.0 = 69.8% done in 1020.2s, 441.5s to go
# on time step 698041 (time=698.041), 0.00139085 s/step
# Meep progress: 700.738/1000.0 = 70.1% done in 1024.2s, 437.4s to go
# on time step 700852 (time=700.852), 0.00142313 s/step
# Meep progress: 703.553/1000.0 = 70.4% done in 1028.2s, 433.2s to go
# on time step 703662 (time=703.662), 0.0014235 s/step
# Meep progress: 706.352/1000.0 = 70.6% done in 1032.2s, 429.1s to go
# on time step 706474 (time=706.474), 0.00142263 s/step
# Meep progress: 709.226/1000.0 = 70.9% done in 1036.2s, 424.8s to go
# on time step 709339 (time=709.339), 0.00139625 s/step
# Meep progress: 712.059/1000.0 = 71.2% done in 1040.2s, 420.6s to go
# on time step 712175 (time=712.175), 0.00141047 s/step
# Meep progress: 714.871/1000.0 = 71.5% done in 1044.2s, 416.5s to go
# on time step 714983 (time=714.983), 0.00142451 s/step
# Meep progress: 717.724/1000.0 = 71.8% done in 1048.2s, 412.2s to go
# on time step 717844 (time=717.844), 0.00139831 s/step
# Meep progress: 720.5600000000001/1000.0 = 72.1% done in 1052.2s, 408.0s to go
# on time step 720676 (time=720.676), 0.00141266 s/step
# Meep progress: 723.349/1000.0 = 72.3% done in 1056.2s, 403.9s to go
# on time step 723466 (time=723.466), 0.00143385 s/step
# Meep progress: 726.15/1000.0 = 72.6% done in 1060.2s, 399.8s to go
# on time step 726267 (time=726.267), 0.00142829 s/step
# Meep progress: 728.9010000000001/1000.0 = 72.9% done in 1064.2s, 395.8s to go
# on time step 729021 (time=729.021), 0.00145284 s/step
# Meep progress: 731.681/1000.0 = 73.2% done in 1068.2s, 391.7s to go
# on time step 731801 (time=731.801), 0.00143908 s/step
# Meep progress: 734.479/1000.0 = 73.4% done in 1072.2s, 387.6s to go
# on time step 734589 (time=734.589), 0.00143496 s/step
# Meep progress: 737.162/1000.0 = 73.7% done in 1076.2s, 383.7s to go
# on time step 737282 (time=737.282), 0.0014855 s/step
# Meep progress: 739.909/1000.0 = 74.0% done in 1080.2s, 379.7s to go
# on time step 740011 (time=740.011), 0.00146609 s/step
# Meep progress: 742.607/1000.0 = 74.3% done in 1084.2s, 375.8s to go
# on time step 742725 (time=742.725), 0.00147406 s/step
# Meep progress: 745.4250000000001/1000.0 = 74.5% done in 1088.2s, 371.6s to go
# on time step 745543 (time=745.543), 0.00141958 s/step
# Meep progress: 748.268/1000.0 = 74.8% done in 1092.2s, 367.4s to go
# on time step 748391 (time=748.391), 0.00140478 s/step
# Meep progress: 751.105/1000.0 = 75.1% done in 1096.2s, 363.2s to go
# on time step 751229 (time=751.229), 0.00140964 s/step
# Meep progress: 753.936/1000.0 = 75.4% done in 1100.2s, 359.1s to go
# on time step 754060 (time=754.06), 0.00141301 s/step
# Meep progress: 756.778/1000.0 = 75.7% done in 1104.2s, 354.9s to go
# on time step 756899 (time=756.899), 0.00140944 s/step
# Meep progress: 759.642/1000.0 = 76.0% done in 1108.2s, 350.6s to go
# on time step 759764 (time=759.764), 0.00139657 s/step
# Meep progress: 762.427/1000.0 = 76.2% done in 1112.2s, 346.6s to go
# on time step 762551 (time=762.551), 0.0014356 s/step
# Meep progress: 765.277/1000.0 = 76.5% done in 1116.2s, 342.4s to go
# on time step 765397 (time=765.397), 0.0014055 s/step
# Meep progress: 768.1320000000001/1000.0 = 76.8% done in 1120.2s, 338.1s to go
# on time step 768257 (time=768.257), 0.0013988 s/step
# Meep progress: 770.97/1000.0 = 77.1% done in 1124.2s, 334.0s to go
# on time step 771093 (time=771.093), 0.00141104 s/step
# Meep progress: 773.7810000000001/1000.0 = 77.4% done in 1128.2s, 329.8s to go
# on time step 773904 (time=773.904), 0.00142335 s/step
# Meep progress: 776.634/1000.0 = 77.7% done in 1132.2s, 325.6s to go
# on time step 776755 (time=776.755), 0.00140328 s/step
# Meep progress: 779.4780000000001/1000.0 = 77.9% done in 1136.2s, 321.4s to go
# on time step 779599 (time=779.599), 0.00140677 s/step
# Meep progress: 782.303/1000.0 = 78.2% done in 1140.2s, 317.3s to go
# on time step 782428 (time=782.428), 0.00141403 s/step
# Meep progress: 785.139/1000.0 = 78.5% done in 1144.2s, 313.1s to go
# on time step 785266 (time=785.266), 0.00140988 s/step
# Meep progress: 787.936/1000.0 = 78.8% done in 1148.2s, 309.0s to go
# on time step 788063 (time=788.063), 0.00143023 s/step
# Meep progress: 790.784/1000.0 = 79.1% done in 1152.2s, 304.8s to go
# on time step 790910 (time=790.91), 0.00140525 s/step
# Meep progress: 793.583/1000.0 = 79.4% done in 1156.2s, 300.7s to go
# on time step 793714 (time=793.714), 0.0014266 s/step
# Meep progress: 796.434/1000.0 = 79.6% done in 1160.2s, 296.5s to go
# on time step 796556 (time=796.556), 0.00140784 s/step
# Meep progress: 799.26/1000.0 = 79.9% done in 1164.2s, 292.4s to go
# on time step 799387 (time=799.387), 0.00141346 s/step
# Meep progress: 802.078/1000.0 = 80.2% done in 1168.2s, 288.3s to go
# on time step 802209 (time=802.209), 0.00141793 s/step
# Meep progress: 804.846/1000.0 = 80.5% done in 1172.2s, 284.2s to go
# on time step 804973 (time=804.973), 0.00144752 s/step
# Meep progress: 807.643/1000.0 = 80.8% done in 1176.2s, 280.1s to go
# on time step 807771 (time=807.771), 0.0014296 s/step
# Meep progress: 810.4780000000001/1000.0 = 81.0% done in 1180.2s, 276.0s to go
# on time step 810608 (time=810.608), 0.00141002 s/step
# Meep progress: 813.296/1000.0 = 81.3% done in 1184.2s, 271.9s to go
# on time step 813424 (time=813.424), 0.00142077 s/step
# Meep progress: 816.124/1000.0 = 81.6% done in 1188.2s, 267.7s to go
# on time step 816257 (time=816.257), 0.00141258 s/step
# Meep progress: 818.977/1000.0 = 81.9% done in 1192.2s, 263.5s to go
# on time step 819110 (time=819.11), 0.00140214 s/step
# Meep progress: 821.797/1000.0 = 82.2% done in 1196.2s, 259.4s to go
# on time step 821931 (time=821.931), 0.00141848 s/step
# Meep progress: 824.6370000000001/1000.0 = 82.5% done in 1200.2s, 255.2s to go
# on time step 824770 (time=824.77), 0.00140907 s/step
# Meep progress: 827.469/1000.0 = 82.7% done in 1204.2s, 251.1s to go
# on time step 827607 (time=827.607), 0.00141043 s/step
# Meep progress: 830.3190000000001/1000.0 = 83.0% done in 1208.2s, 246.9s to go
# on time step 830452 (time=830.452), 0.00140618 s/step
# Meep progress: 833.142/1000.0 = 83.3% done in 1212.2s, 242.8s to go
# on time step 833278 (time=833.278), 0.00141591 s/step
# Meep progress: 835.969/1000.0 = 83.6% done in 1216.2s, 238.6s to go
# on time step 836109 (time=836.109), 0.00141295 s/step
# Meep progress: 838.8340000000001/1000.0 = 83.9% done in 1220.2s, 234.4s to go
# on time step 838970 (time=838.97), 0.0013983 s/step
# Meep progress: 841.679/1000.0 = 84.2% done in 1224.2s, 230.3s to go
# on time step 841810 (time=841.81), 0.00140866 s/step
# Meep progress: 844.528/1000.0 = 84.5% done in 1228.2s, 226.1s to go
# on time step 844662 (time=844.662), 0.00140284 s/step
# Meep progress: 847.33/1000.0 = 84.7% done in 1232.2s, 222.0s to go
# on time step 847468 (time=847.468), 0.00142558 s/step
# Meep progress: 850.179/1000.0 = 85.0% done in 1236.2s, 217.9s to go
# on time step 850314 (time=850.314), 0.00140561 s/step
# Meep progress: 852.961/1000.0 = 85.3% done in 1240.2s, 213.8s to go
# on time step 853103 (time=853.103), 0.00143453 s/step
# Meep progress: 855.799/1000.0 = 85.6% done in 1244.2s, 209.7s to go
# on time step 855933 (time=855.933), 0.00141394 s/step
# Meep progress: 858.629/1000.0 = 85.9% done in 1248.2s, 205.5s to go
# on time step 858771 (time=858.771), 0.00140977 s/step
# Meep progress: 861.445/1000.0 = 86.1% done in 1252.2s, 201.4s to go
# on time step 861587 (time=861.587), 0.00142079 s/step
# Meep progress: 864.278/1000.0 = 86.4% done in 1256.2s, 197.3s to go
# on time step 864412 (time=864.412), 0.00141615 s/step
# Meep progress: 867.105/1000.0 = 86.7% done in 1260.2s, 193.1s to go
# on time step 867238 (time=867.238), 0.00141561 s/step
# Meep progress: 869.904/1000.0 = 87.0% done in 1264.2s, 189.1s to go
# on time step 870043 (time=870.043), 0.00142633 s/step
# Meep progress: 872.726/1000.0 = 87.3% done in 1268.2s, 185.0s to go
# on time step 872865 (time=872.865), 0.00141786 s/step
# Meep progress: 875.562/1000.0 = 87.6% done in 1272.2s, 180.8s to go
# on time step 875698 (time=875.698), 0.00141225 s/step
# Meep progress: 878.378/1000.0 = 87.8% done in 1276.2s, 176.7s to go
# on time step 878522 (time=878.522), 0.00141675 s/step
# Meep progress: 881.217/1000.0 = 88.1% done in 1280.2s, 172.6s to go
# on time step 881355 (time=881.355), 0.00141223 s/step
# Meep progress: 884.071/1000.0 = 88.4% done in 1284.2s, 168.4s to go
# on time step 884207 (time=884.207), 0.0014028 s/step
# Meep progress: 886.907/1000.0 = 88.7% done in 1288.2s, 164.3s to go
# on time step 887046 (time=887.046), 0.00140929 s/step
# Meep progress: 889.726/1000.0 = 89.0% done in 1292.2s, 160.2s to go
# on time step 889861 (time=889.861), 0.00142107 s/step
# Meep progress: 892.537/1000.0 = 89.3% done in 1296.2s, 156.1s to go
# on time step 892680 (time=892.68), 0.001419 s/step
# Meep progress: 895.375/1000.0 = 89.5% done in 1300.2s, 151.9s to go
# on time step 895509 (time=895.509), 0.00141436 s/step
# Meep progress: 898.184/1000.0 = 89.8% done in 1304.2s, 147.8s to go
# on time step 898325 (time=898.325), 0.00142079 s/step
# Meep progress: 901.009/1000.0 = 90.1% done in 1308.2s, 143.7s to go
# on time step 901152 (time=901.152), 0.00141501 s/step
# Meep progress: 903.862/1000.0 = 90.4% done in 1312.2s, 139.6s to go
# on time step 904003 (time=904.003), 0.00140339 s/step
# Meep progress: 906.691/1000.0 = 90.7% done in 1316.2s, 135.5s to go
# on time step 906829 (time=906.829), 0.00141586 s/step
# Meep progress: 909.506/1000.0 = 91.0% done in 1320.2s, 131.4s to go
# on time step 909649 (time=909.649), 0.00141855 s/step
# Meep progress: 912.346/1000.0 = 91.2% done in 1324.2s, 127.2s to go
# on time step 912494 (time=912.494), 0.00140638 s/step
# Meep progress: 915.187/1000.0 = 91.5% done in 1328.2s, 123.1s to go
# on time step 915332 (time=915.332), 0.00140956 s/step
# Meep progress: 918.025/1000.0 = 91.8% done in 1332.2s, 119.0s to go
# on time step 918151 (time=918.151), 0.001419 s/step
# Meep progress: 920.798/1000.0 = 92.1% done in 1336.3s, 114.9s to go
# on time step 920943 (time=920.943), 0.00143313 s/step
# Meep progress: 923.62/1000.0 = 92.4% done in 1340.3s, 110.8s to go
# on time step 923765 (time=923.765), 0.00141785 s/step
# Meep progress: 926.48/1000.0 = 92.6% done in 1344.3s, 106.7s to go
# on time step 926619 (time=926.619), 0.00140159 s/step
# Meep progress: 929.29/1000.0 = 92.9% done in 1348.3s, 102.6s to go
# on time step 929443 (time=929.443), 0.00141673 s/step
# Meep progress: 932.1370000000001/1000.0 = 93.2% done in 1352.3s, 98.4s to go
# on time step 932284 (time=932.284), 0.00140815 s/step
# Meep progress: 934.9680000000001/1000.0 = 93.5% done in 1356.3s, 94.3s to go
# on time step 935113 (time=935.113), 0.00141435 s/step
# Meep progress: 937.793/1000.0 = 93.8% done in 1360.3s, 90.2s to go
# on time step 937941 (time=937.941), 0.00141445 s/step
# Meep progress: 940.614/1000.0 = 94.1% done in 1364.3s, 86.1s to go
# on time step 940759 (time=940.759), 0.0014197 s/step
# Meep progress: 943.441/1000.0 = 94.3% done in 1368.3s, 82.0s to go
# on time step 943590 (time=943.59), 0.00141326 s/step
# Meep progress: 946.2660000000001/1000.0 = 94.6% done in 1372.3s, 77.9s to go
# on time step 946404 (time=946.404), 0.00142176 s/step
# Meep progress: 949.077/1000.0 = 94.9% done in 1376.3s, 73.8s to go
# on time step 949219 (time=949.219), 0.00142156 s/step
# Meep progress: 951.863/1000.0 = 95.2% done in 1380.3s, 69.8s to go
# on time step 952011 (time=952.011), 0.00143283 s/step
# Meep progress: 954.716/1000.0 = 95.5% done in 1384.3s, 65.7s to go
# on time step 954867 (time=954.867), 0.00140106 s/step
# Meep progress: 957.381/1000.0 = 95.7% done in 1388.3s, 61.8s to go
# on time step 957520 (time=957.52), 0.00150798 s/step
# Meep progress: 960.148/1000.0 = 96.0% done in 1392.3s, 57.8s to go
# on time step 960294 (time=960.294), 0.00144207 s/step
# Meep progress: 963.004/1000.0 = 96.3% done in 1396.3s, 53.6s to go
# on time step 963157 (time=963.157), 0.00139795 s/step
# Meep progress: 965.8340000000001/1000.0 = 96.6% done in 1400.3s, 49.5s to go
# on time step 965986 (time=965.986), 0.00141417 s/step
# Meep progress: 968.6610000000001/1000.0 = 96.9% done in 1404.3s, 45.4s to go
# on time step 968814 (time=968.814), 0.00141492 s/step
# Meep progress: 971.5/1000.0 = 97.2% done in 1408.3s, 41.3s to go
# on time step 971656 (time=971.656), 0.00140794 s/step
# Meep progress: 974.294/1000.0 = 97.4% done in 1412.3s, 37.3s to go
# on time step 974446 (time=974.446), 0.00143398 s/step
# Meep progress: 977.115/1000.0 = 97.7% done in 1416.3s, 33.2s to go
# on time step 977264 (time=977.264), 0.00141993 s/step
# Meep progress: 979.934/1000.0 = 98.0% done in 1420.3s, 29.1s to go
# on time step 980078 (time=980.078), 0.0014217 s/step
# Meep progress: 982.744/1000.0 = 98.3% done in 1424.3s, 25.0s to go
# on time step 982902 (time=982.902), 0.00141694 s/step
# Meep progress: 985.568/1000.0 = 98.6% done in 1428.3s, 20.9s to go
# on time step 985725 (time=985.725), 0.00141703 s/step
# Meep progress: 988.405/1000.0 = 98.8% done in 1432.3s, 16.8s to go
# on time step 988560 (time=988.56), 0.00141235 s/step
# Meep progress: 991.225/1000.0 = 99.1% done in 1436.3s, 12.7s to go
# on time step 991382 (time=991.382), 0.00141775 s/step
# Meep progress: 994.073/1000.0 = 99.4% done in 1440.3s, 8.6s to go
# on time step 994228 (time=994.228), 0.00140599 s/step
# Meep progress: 996.885/1000.0 = 99.7% done in 1444.3s, 4.5s to go
# on time step 997052 (time=997.052), 0.00141671 s/step
# Meep progress: 999.682/1000.0 = 100.0% done in 1448.3s, 0.5s to go
# on time step 999834 (time=999.834), 0.00143816 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 1000.0 (1000000 timesteps)
#      block, center = (-0.61,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
ez_data_up = np.array(ez_data_up)
ez_data_cen = np.array(ez_data_cen)
ez_data_down = np.array(ez_data_down)


print(len(ez_data_cen))

print(1 + int(round(t_xx/dt)))
# Out:
# 76923
# 41

# %%
ez_data_cen = np.array(ez_data_cen)
ez_data_up = np.array(ez_data_up)
ez_data_down = np.array(ez_data_down)

#plt.subplot_adjust(hspace = .35)
plt.figure(dpi = 200)
start = round(len(ez_data_cen) / t *1)

for i in range(start,len(ez_data_cen),1):
    plt.subplot(3,1,1)
    plt.plot(i,ez_data_up[i],'k.')
    plt.subplot(3,1,2)
    plt.plot(i,ez_data_cen[i],'k.')
    plt.subplot(3,1,3)
    plt.plot(i,ez_data_down[i],'k.')
    if i ==  (len(ez_data_cen)-1):
        plt.subplot(3,1,1)
        plt.title('upper point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_up[i],'b .')
        plt.subplot(3,1,2)
        plt.title('center point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_cen[i],'b .')
        plt.subplot(3,1,3)
        plt.title('downer point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_down[i],'b .')

# %%
# index1 and index2 . When we find the target's Electric field amplitude, we want to know where is amplitude value in array. So we set up index variable before running simulation.
index1_up = 0
index1_cen = 0
index1_down = 0

index2_up = 0
index2_cen = 0
index2_down = 0
# Period_max , period_next_mat . I set up those variables because I plan to use variables to store max amplitude value in a peiod in the following simulation. 
period_max_up = 0
period_max_cen = 0
period_max_down = 0
period_next_max_up = 0
period_next_max_cen = 0
period_next_max_down = 0

# Intial_index , end_index. ==>  "for loop" index
initial_index = round(len(ez_data_cen) / t * 200 )
print(initial_index)
end_index = len(ez_data_cen) - 2*( 1 +int(round(t_xx/dt))) 
print(end_index)

for i in range(initial_index , end_index):
    plt.plot(ez_data_cen[i])

# %%
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_up[j])
        period_next.append(ez_data_up[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_up = np.where(ez_data_up == period_max)
        print(index1, '--- upper point index1')
        index2_up = np.where(ez_data_up == period_next_max)
        print(index2, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('upper point 到達誤差範圍內的所需 meep time unit' , 23287 / len(ez_data_up) * 500 , '\n')
        print('-----------------------------------------------------')
        break

        
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_cen[j])
        period_next.append(ez_data_cen[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_cen = np.where(ez_data_cen == period_max)
        print(index1, '--- upper point index1')
        index2_cen = np.where(ez_data_cen == period_next_max)
        print(index2, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t')
        print('center point 到達誤差範圍內的所需 meep time unit' , 73397 / len(ez_data_cen) * 500 , '\n')
        print('-----------------------------------------------------')
        break
        
    
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_down[j])
        period_next.append(ez_data_down[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- down point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- down point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_down = np.where(ez_data_down == period_max)
        print(index1, '--- down point index1')
        index2_down = np.where(ez_data_down == period_next_max)
        print(index2, '--- down point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('down point 到達誤差範圍內的所需 meep time unit' , 18749 / len(ez_data_down) * 500 , '\n')
        print('-----------------------------------------------------')
        break


dt_ = str(dt)

# %%
plt.figure(dpi = 150)
plt.title('Upper point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_up[73320]
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_up[i] , 'b.')
    if max_value < ez_data_up[i] :
        max_value = ez_data_up[i]
        
print(max_value)

# %%
plt.figure(dpi = 150)
plt.title('center point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_cen[73320]
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_cen[i] , 'b.')
    if max_value < ez_data_cen[i] :
        max_value = ez_data_cen[i]

print(max_value)

# %%
plt.figure(dpi = 150)
plt.title('downner point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_down[i] , 'b.')
