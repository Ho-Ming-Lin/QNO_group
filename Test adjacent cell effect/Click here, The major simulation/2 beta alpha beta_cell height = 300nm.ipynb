# %% [markdown]
# Here, we want to how level that the electric near field just above cell affected by adjacent cells. In this simulation, we simulated the structure which we called "Beta_Alpha_Beta structure".

# %% [markdown]
# # Following is Simulation that Cell height = 300 nm
# Factors
# PML thickness : 1 micrometer
#
# Cell height : 300 nm
#
# Cell width : 150_80_150 nm
#
# Substract thickness : 1 micrometer
#
# Substract refractive index : 2.6678
#
# y direction symmetry

# %%
import meep as mp
import numpy as np
import math
import matplotlib.pyplot as plt

#sim.reset_meep()
resolution = 500  # pixels/μm

dpml = 1.0  # PML thickness
dsub = 0.5  # substrate thickness
dcaa = 0.06  # air rigion for alpha structure
# alpha structure is that one period = 200nm，sigle cell width = 80nm locate at center
dcab = 0.025 # air rigion for beta structure 
# beta structure is that one period = 200nm，sigle cell width = 150nm locate at center
gp = 0.2  # grating periodicity
gh = 0.3  # grating height
gwa = 0.08 # alpha grating cell width
gwb = 0.15 # beta grating cell width

num_cells = 3 # number of grating unit cells

# air region thickness adjacent to grating
dair = 1 

wvl = 0.532  # center wavelength
fcen = 1 / wvl  # center frequency

glass = mp.Medium(index= 2.6678)

pml_layers = [mp.PML(thickness=dpml, direction = mp.X )]

symmetries = [mp.Mirror(mp.Y)]

sx = dpml + dsub + gh + dair + dpml
sy = num_cells*gp
#sy = ((dcaa + gwa + dcaa)*2 + (dcab + gwb + dcab))*num_cells
cell_size = mp.Vector3(sx, sy)

sources = [
    mp.Source(
        mp.ContinuousSource(frequency = fcen), # frequemcy = 2原因是 meep 的 C=1，所以 1/? = 0.5 um，?即是2
        component = mp.Ez,
        center = mp.Vector3(-0.5 * sx + dpml ),
        size = mp.Vector3(y = sy),
    )
]

geometry = [
    mp.Block(
        material=glass,
        size=mp.Vector3(dsub, mp.inf, mp.inf),
        center=mp.Vector3(-0.5 * sx + dpml + 0.04 + dsub/2),
    )
]

# %%
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp/2 + (j * 3 * gp),
                #-0.5 * sy + gp/2,
            ),
        )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwa, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + gp + gp/2,
            ),
        )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + 2*gp + gp/2  + (j * 3 * gp),
                #0.5 * sy - gp/2,
            ),
        )
    )

    
k_point = mp.Vector3()  # Gamma 點表示週期邊界條件
k_points = [k_point]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
    symmetries=symmetries,
    k_point = mp.Vector3(),
)


# %matplotlib inline
plt.figure(dpi = 125)
sim.plot2D()
plt.show()

# %%
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (-0.61,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
t_xx = (.532) # Air 光速跑完 波長 532 nm 入射光 所需的 meep unit time
dt = (t_xx / 40) # cut 40 sections in a period time
t = 1000 # Total simulation time

x_obs = -0.5 * sx + dpml + dsub + gh + 0.002 # Set up a x coordinate of observed point
# The meaning of down , cen , up are the cordinate in each cell structure. (Reference stucture diagram just show above)
y_obs_down = -0.5 * sy + gp/2
y_obs_cen = -0.5 * sy + 3*gp/2
y_obs_up = 0.5 * sy - gp/2

print(int((t_xx)/dt))
# Out:
# 40

# %%
# 儲存場量數值的列表，定義為擁有 10 列的空二維陣列
ez_data_cen = []
ez_data_up = []
ez_data_down = []
###
def get_slice(sim):
    ez_data_cen.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_cen) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_up.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_up) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_down.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_down) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))

sim.run(mp.at_every(dt , get_slice) , until = t)

plt.figure(dpi = 100)
sim.plot2D(fields=mp.Ez)
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.0011301 s
# Working in 2D dimensions.
# Computational cell is 3.8 x 0.6 x 0 with resolution 500
#      block, center = (-0.61,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
# time for set_epsilon = 0.283177 s
# -----------
# Meep progress: 1.323/1000.0 = 0.1% done in 4.0s, 3021.8s to go
# on time step 1323 (time=1.323), 0.00302594 s/step
# Meep progress: 2.563/1000.0 = 0.3% done in 8.0s, 3114.8s to go
# on time step 2564 (time=2.564), 0.00322546 s/step
# Meep progress: 3.8850000000000002/1000.0 = 0.4% done in 12.0s, 3077.9s to go
# on time step 3887 (time=3.887), 0.00302565 s/step
# Meep progress: 4.987/1000.0 = 0.5% done in 16.0s, 3193.4s to go
# on time step 4989 (time=4.989), 0.003631 s/step
# Meep progress: 6.369/1000.0 = 0.6% done in 20.0s, 3121.1s to go
# on time step 6372 (time=6.372), 0.00289329 s/step
# Meep progress: 7.78/1000.0 = 0.8% done in 24.0s, 3061.8s to go
# on time step 7783 (time=7.783), 0.00283494 s/step
# Meep progress: 9.065/1000.0 = 0.9% done in 28.0s, 3061.8s to go
# on time step 9068 (time=9.068), 0.00311353 s/step
# Meep progress: 10.388/1000.0 = 1.0% done in 32.0s, 3049.5s to go
# on time step 10391 (time=10.391), 0.00302422 s/step
# Meep progress: 11.717/1000.0 = 1.2% done in 36.0s, 3037.4s to go
# on time step 11721 (time=11.721), 0.00300822 s/step
# Meep progress: 13.066/1000.0 = 1.3% done in 40.0s, 3022.5s to go
# on time step 13070 (time=13.07), 0.0029657 s/step
# Meep progress: 14.424/1000.0 = 1.4% done in 44.0s, 3007.6s to go
# on time step 14427 (time=14.427), 0.00294899 s/step
# Meep progress: 15.805/1000.0 = 1.6% done in 48.0s, 2990.0s to go
# on time step 15809 (time=15.809), 0.00289528 s/step
# Meep progress: 17.154/1000.0 = 1.7% done in 52.0s, 2980.4s to go
# on time step 17158 (time=17.158), 0.00296793 s/step
# Meep progress: 18.531/1000.0 = 1.9% done in 56.0s, 2967.1s to go
# on time step 18535 (time=18.535), 0.00290554 s/step
# Meep progress: 19.869/1000.0 = 2.0% done in 60.0s, 2960.9s to go
# on time step 19874 (time=19.874), 0.00298826 s/step
# Meep progress: 21.205000000000002/1000.0 = 2.1% done in 64.0s, 2955.2s to go
# on time step 21210 (time=21.21), 0.00299417 s/step
# Meep progress: 22.55/1000.0 = 2.3% done in 68.0s, 2948.6s to go
# on time step 22554 (time=22.554), 0.00297646 s/step
# Meep progress: 23.891000000000002/1000.0 = 2.4% done in 72.0s, 2942.7s to go
# on time step 23896 (time=23.896), 0.00298199 s/step
# Meep progress: 25.289/1000.0 = 2.5% done in 76.0s, 2930.3s to go
# on time step 25296 (time=25.296), 0.00285899 s/step
# Meep progress: 26.719/1000.0 = 2.7% done in 80.0s, 2915.1s to go
# on time step 26727 (time=26.727), 0.00279701 s/step
# Meep progress: 28.143/1000.0 = 2.8% done in 84.0s, 2901.8s to go
# on time step 28150 (time=28.15), 0.00281195 s/step
# Meep progress: 29.574/1000.0 = 3.0% done in 88.0s, 2888.6s to go
# on time step 29582 (time=29.582), 0.00279423 s/step
# Meep progress: 31.011/1000.0 = 3.1% done in 92.0s, 2875.8s to go
# on time step 31019 (time=31.019), 0.00278372 s/step
# Meep progress: 32.442/1000.0 = 3.2% done in 96.0s, 2864.2s to go
# on time step 32450 (time=32.45), 0.00279667 s/step
# Meep progress: 33.867/1000.0 = 3.4% done in 100.0s, 2853.8s to go
# on time step 33876 (time=33.876), 0.00280663 s/step
# Meep progress: 35.295/1000.0 = 3.5% done in 104.0s, 2843.7s to go
# on time step 35304 (time=35.304), 0.00280257 s/step
# Meep progress: 36.721000000000004/1000.0 = 3.7% done in 108.0s, 2834.2s to go
# on time step 36730 (time=36.73), 0.00280628 s/step
# Meep progress: 38.143/1000.0 = 3.8% done in 112.0s, 2825.3s to go
# on time step 38153 (time=38.153), 0.00281178 s/step
# Meep progress: 39.552/1000.0 = 4.0% done in 116.0s, 2817.8s to go
# on time step 39564 (time=39.564), 0.00283655 s/step
# Meep progress: 40.986000000000004/1000.0 = 4.1% done in 120.0s, 2808.8s to go
# on time step 40996 (time=40.996), 0.00279343 s/step
# Meep progress: 42.412/1000.0 = 4.2% done in 124.0s, 2800.7s to go
# on time step 42422 (time=42.422), 0.00280549 s/step
# Meep progress: 43.841/1000.0 = 4.4% done in 128.0s, 2792.6s to go
# on time step 43852 (time=43.852), 0.00279874 s/step
# Meep progress: 45.249/1000.0 = 4.5% done in 132.0s, 2786.2s to go
# on time step 45261 (time=45.261), 0.0028403 s/step
# Meep progress: 46.654/1000.0 = 4.7% done in 136.0s, 2780.1s to go
# on time step 46665 (time=46.665), 0.0028491 s/step
# Meep progress: 48.063/1000.0 = 4.8% done in 140.0s, 2773.8s to go
# on time step 48076 (time=48.076), 0.00283534 s/step
# Meep progress: 49.492000000000004/1000.0 = 4.9% done in 144.1s, 2766.5s to go
# on time step 49503 (time=49.503), 0.00280575 s/step
# Meep progress: 50.910000000000004/1000.0 = 5.1% done in 148.1s, 2760.1s to go
# on time step 50923 (time=50.923), 0.00281762 s/step
# Meep progress: 52.312/1000.0 = 5.2% done in 152.1s, 2754.6s to go
# on time step 52326 (time=52.326), 0.00285133 s/step
# Meep progress: 53.701/1000.0 = 5.4% done in 156.1s, 2749.9s to go
# on time step 53716 (time=53.716), 0.00287902 s/step
# Meep progress: 55.132/1000.0 = 5.5% done in 160.1s, 2743.0s to go
# on time step 55148 (time=55.148), 0.00279432 s/step
# Meep progress: 56.546/1000.0 = 5.7% done in 164.1s, 2737.2s to go
# on time step 56562 (time=56.562), 0.0028291 s/step
# Meep progress: 57.976/1000.0 = 5.8% done in 168.1s, 2730.7s to go
# on time step 57992 (time=57.992), 0.00279844 s/step
# Meep progress: 59.38/1000.0 = 5.9% done in 172.1s, 2725.5s to go
# on time step 59396 (time=59.396), 0.00284939 s/step
# Meep progress: 60.81/1000.0 = 6.1% done in 176.1s, 2719.2s to go
# on time step 60826 (time=60.826), 0.00279802 s/step
# Meep progress: 62.234/1000.0 = 6.2% done in 180.1s, 2713.2s to go
# on time step 62250 (time=62.25), 0.00281159 s/step
# Meep progress: 63.625/1000.0 = 6.4% done in 184.1s, 2708.8s to go
# on time step 63644 (time=63.644), 0.0028695 s/step
# Meep progress: 65.052/1000.0 = 6.5% done in 188.1s, 2702.9s to go
# on time step 65071 (time=65.071), 0.00280386 s/step
# Meep progress: 66.465/1000.0 = 6.6% done in 192.1s, 2697.7s to go
# on time step 66482 (time=66.482), 0.00283582 s/step
# Meep progress: 67.891/1000.0 = 6.8% done in 196.1s, 2691.9s to go
# on time step 67908 (time=67.908), 0.00280558 s/step
# Meep progress: 69.322/1000.0 = 6.9% done in 200.1s, 2686.0s to go
# on time step 69340 (time=69.34), 0.0027946 s/step
# Meep progress: 70.735/1000.0 = 7.1% done in 204.1s, 2681.0s to go
# on time step 70751 (time=70.751), 0.00283551 s/step
# Meep progress: 72.15/1000.0 = 7.2% done in 208.1s, 2675.9s to go
# on time step 72167 (time=72.167), 0.00282644 s/step
# Meep progress: 73.56400000000001/1000.0 = 7.4% done in 212.1s, 2670.8s to go
# on time step 73582 (time=73.582), 0.002828 s/step
# Meep progress: 74.97/1000.0 = 7.5% done in 216.1s, 2666.1s to go
# on time step 74986 (time=74.986), 0.00284947 s/step
# Meep progress: 76.21600000000001/1000.0 = 7.6% done in 220.1s, 2667.5s to go
# on time step 76234 (time=76.234), 0.00320611 s/step
# Meep progress: 77.474/1000.0 = 7.7% done in 224.1s, 2668.3s to go
# on time step 77490 (time=77.49), 0.00318733 s/step
# Meep progress: 78.677/1000.0 = 7.9% done in 228.1s, 2670.9s to go
# on time step 78693 (time=78.693), 0.00332515 s/step
# Meep progress: 79.98100000000001/1000.0 = 8.0% done in 232.1s, 2669.7s to go
# on time step 80000 (time=80), 0.00306189 s/step
# Meep progress: 81.319/1000.0 = 8.1% done in 236.1s, 2667.1s to go
# on time step 81334 (time=81.334), 0.00300102 s/step
# Meep progress: 82.621/1000.0 = 8.3% done in 240.1s, 2665.8s to go
# on time step 82641 (time=82.641), 0.00306165 s/step
# Meep progress: 83.991/1000.0 = 8.4% done in 244.1s, 2662.0s to go
# on time step 84012 (time=84.012), 0.00291767 s/step
# Meep progress: 85.374/1000.0 = 8.5% done in 248.1s, 2657.8s to go
# on time step 85394 (time=85.394), 0.00289587 s/step
# Meep progress: 86.76/1000.0 = 8.7% done in 252.1s, 2653.5s to go
# on time step 86779 (time=86.779), 0.00288882 s/step
# Meep progress: 88.14/1000.0 = 8.8% done in 256.1s, 2649.4s to go
# on time step 88161 (time=88.161), 0.00289442 s/step
# Meep progress: 89.538/1000.0 = 9.0% done in 260.1s, 2644.7s to go
# on time step 89560 (time=89.56), 0.00285996 s/step
# Meep progress: 90.906/1000.0 = 9.1% done in 264.1s, 2641.0s to go
# on time step 90929 (time=90.929), 0.00292296 s/step
# Meep progress: 92.301/1000.0 = 9.2% done in 268.1s, 2636.5s to go
# on time step 92321 (time=92.321), 0.00287472 s/step
# Meep progress: 93.644/1000.0 = 9.4% done in 272.1s, 2633.6s to go
# on time step 93658 (time=93.658), 0.00299439 s/step
# Meep progress: 94.997/1000.0 = 9.5% done in 276.1s, 2630.3s to go
# on time step 95020 (time=95.02), 0.00293801 s/step
# Meep progress: 96.419/1000.0 = 9.6% done in 280.1s, 2624.9s to go
# on time step 96443 (time=96.443), 0.00281254 s/step
# Meep progress: 97.799/1000.0 = 9.8% done in 284.1s, 2620.9s to go
# on time step 97822 (time=97.822), 0.00290169 s/step
# Meep progress: 99.199/1000.0 = 9.9% done in 288.1s, 2616.2s to go
# on time step 99225 (time=99.225), 0.00285283 s/step
# Meep progress: 100.601/1000.0 = 10.1% done in 292.1s, 2611.5s to go
# on time step 100626 (time=100.626), 0.00285512 s/step
# Meep progress: 101.971/1000.0 = 10.2% done in 296.1s, 2607.7s to go
# on time step 101999 (time=101.999), 0.00291341 s/step
# Meep progress: 103.378/1000.0 = 10.3% done in 300.1s, 2602.9s to go
# on time step 103403 (time=103.403), 0.00285028 s/step
# Meep progress: 104.774/1000.0 = 10.5% done in 304.1s, 2598.4s to go
# on time step 104798 (time=104.798), 0.00286773 s/step
# Meep progress: 106.18/1000.0 = 10.6% done in 308.1s, 2593.7s to go
# on time step 106205 (time=106.205), 0.00284393 s/step
# Meep progress: 107.59100000000001/1000.0 = 10.8% done in 312.1s, 2588.8s to go
# on time step 107614 (time=107.614), 0.00283895 s/step
# Meep progress: 108.995/1000.0 = 10.9% done in 316.1s, 2584.1s to go
# on time step 109024 (time=109.024), 0.00283717 s/step
# Meep progress: 110.367/1000.0 = 11.0% done in 320.1s, 2580.3s to go
# on time step 110393 (time=110.393), 0.00292365 s/step
# Meep progress: 111.74600000000001/1000.0 = 11.2% done in 324.1s, 2576.3s to go
# on time step 111772 (time=111.772), 0.00290123 s/step
# Meep progress: 113.171/1000.0 = 11.3% done in 328.1s, 2571.2s to go
# on time step 113200 (time=113.2), 0.00280279 s/step
# Meep progress: 114.563/1000.0 = 11.5% done in 332.1s, 2566.9s to go
# on time step 114590 (time=114.59), 0.00287964 s/step
# Meep progress: 115.96900000000001/1000.0 = 11.6% done in 336.1s, 2562.2s to go
# on time step 115998 (time=115.998), 0.00284227 s/step
# Meep progress: 117.381/1000.0 = 11.7% done in 340.1s, 2557.5s to go
# on time step 117409 (time=117.409), 0.00283521 s/step
# Meep progress: 118.714/1000.0 = 11.9% done in 344.1s, 2554.6s to go
# on time step 118742 (time=118.742), 0.00300147 s/step
# Meep progress: 120.116/1000.0 = 12.0% done in 348.1s, 2550.1s to go
# on time step 120145 (time=120.145), 0.00285161 s/step
# Meep progress: 121.524/1000.0 = 12.2% done in 352.1s, 2545.5s to go
# on time step 121554 (time=121.554), 0.00283909 s/step
# Meep progress: 122.92/1000.0 = 12.3% done in 356.1s, 2541.1s to go
# on time step 122946 (time=122.946), 0.00287493 s/step
# Meep progress: 124.336/1000.0 = 12.4% done in 360.1s, 2536.3s to go
# on time step 124366 (time=124.366), 0.00281842 s/step
# Meep progress: 125.73700000000001/1000.0 = 12.6% done in 364.1s, 2531.8s to go
# on time step 125770 (time=125.77), 0.00285024 s/step
# Meep progress: 127.14/1000.0 = 12.7% done in 368.1s, 2527.3s to go
# on time step 127171 (time=127.171), 0.00285652 s/step
# Meep progress: 128.534/1000.0 = 12.9% done in 372.1s, 2523.1s to go
# on time step 128567 (time=128.567), 0.00286646 s/step
# Meep progress: 129.937/1000.0 = 13.0% done in 376.1s, 2518.6s to go
# on time step 129969 (time=129.969), 0.0028545 s/step
# Meep progress: 131.322/1000.0 = 13.1% done in 380.1s, 2514.5s to go
# on time step 131357 (time=131.357), 0.00288351 s/step
# Meep progress: 132.655/1000.0 = 13.3% done in 384.1s, 2511.6s to go
# on time step 132691 (time=132.691), 0.00300058 s/step
# Meep progress: 134.048/1000.0 = 13.4% done in 388.1s, 2507.4s to go
# on time step 134087 (time=134.087), 0.00286626 s/step
# Meep progress: 135.451/1000.0 = 13.5% done in 392.1s, 2502.9s to go
# on time step 135489 (time=135.489), 0.00285379 s/step
# Meep progress: 136.849/1000.0 = 13.7% done in 396.1s, 2498.6s to go
# on time step 136886 (time=136.886), 0.0028633 s/step
# Meep progress: 138.234/1000.0 = 13.8% done in 400.1s, 2494.5s to go
# on time step 138271 (time=138.271), 0.00288944 s/step
# Meep progress: 139.644/1000.0 = 14.0% done in 404.1s, 2489.9s to go
# on time step 139682 (time=139.682), 0.00283641 s/step
# Meep progress: 141.059/1000.0 = 14.1% done in 408.1s, 2485.3s to go
# on time step 141098 (time=141.098), 0.00282517 s/step
# Meep progress: 142.468/1000.0 = 14.2% done in 412.1s, 2480.7s to go
# on time step 142502 (time=142.502), 0.00284934 s/step
# Meep progress: 143.875/1000.0 = 14.4% done in 416.1s, 2476.3s to go
# on time step 143912 (time=143.912), 0.00283762 s/step
# Meep progress: 145.276/1000.0 = 14.5% done in 420.1s, 2471.9s to go
# on time step 145313 (time=145.313), 0.00285546 s/step
# Meep progress: 146.659/1000.0 = 14.7% done in 424.1s, 2467.9s to go
# on time step 146699 (time=146.699), 0.0028874 s/step
# Meep progress: 148.026/1000.0 = 14.8% done in 428.1s, 2464.2s to go
# on time step 148060 (time=148.06), 0.00294111 s/step
# Meep progress: 149.42600000000002/1000.0 = 14.9% done in 432.1s, 2459.9s to go
# on time step 149468 (time=149.468), 0.00284265 s/step
# Meep progress: 150.797/1000.0 = 15.1% done in 436.1s, 2456.1s to go
# on time step 150840 (time=150.84), 0.00291657 s/step
# Meep progress: 152.199/1000.0 = 15.2% done in 440.2s, 2451.8s to go
# on time step 152240 (time=152.24), 0.00285859 s/step
# Meep progress: 153.606/1000.0 = 15.4% done in 444.2s, 2447.4s to go
# on time step 153645 (time=153.645), 0.00284849 s/step
# Meep progress: 154.997/1000.0 = 15.5% done in 448.2s, 2443.2s to go
# on time step 155038 (time=155.038), 0.00287348 s/step
# Meep progress: 156.407/1000.0 = 15.6% done in 452.2s, 2438.7s to go
# on time step 156449 (time=156.449), 0.00283498 s/step
# Meep progress: 157.8/1000.0 = 15.8% done in 456.2s, 2434.6s to go
# on time step 157844 (time=157.844), 0.00286922 s/step
# Meep progress: 159.222/1000.0 = 15.9% done in 460.2s, 2429.9s to go
# on time step 159265 (time=159.265), 0.00281514 s/step
# Meep progress: 160.592/1000.0 = 16.1% done in 464.2s, 2426.1s to go
# on time step 160632 (time=160.632), 0.00292639 s/step
# Meep progress: 161.98/1000.0 = 16.2% done in 468.2s, 2422.1s to go
# on time step 162022 (time=162.022), 0.00287866 s/step
# Meep progress: 163.31900000000002/1000.0 = 16.3% done in 472.2s, 2418.9s to go
# on time step 163364 (time=163.364), 0.00298194 s/step
# Meep progress: 164.705/1000.0 = 16.5% done in 476.2s, 2414.9s to go
# on time step 164745 (time=164.745), 0.00289794 s/step
# Meep progress: 166.054/1000.0 = 16.6% done in 480.2s, 2411.5s to go
# on time step 166099 (time=166.099), 0.00295529 s/step
# Meep progress: 167.37800000000001/1000.0 = 16.7% done in 484.2s, 2408.5s to go
# on time step 167418 (time=167.418), 0.0030332 s/step
# Meep progress: 168.714/1000.0 = 16.9% done in 488.2s, 2405.3s to go
# on time step 168746 (time=168.746), 0.00301741 s/step
# Meep progress: 170.02100000000002/1000.0 = 17.0% done in 492.2s, 2402.6s to go
# on time step 170065 (time=170.065), 0.00303332 s/step
# Meep progress: 171.416/1000.0 = 17.1% done in 496.2s, 2398.4s to go
# on time step 171461 (time=171.461), 0.00286599 s/step
# Meep progress: 172.784/1000.0 = 17.3% done in 500.2s, 2394.6s to go
# on time step 172827 (time=172.827), 0.00292874 s/step
# Meep progress: 174.169/1000.0 = 17.4% done in 504.2s, 2390.6s to go
# on time step 174215 (time=174.215), 0.00288317 s/step
# Meep progress: 175.567/1000.0 = 17.6% done in 508.2s, 2386.3s to go
# on time step 175617 (time=175.617), 0.00285454 s/step
# Meep progress: 176.96800000000002/1000.0 = 17.7% done in 512.2s, 2382.0s to go
# on time step 177015 (time=177.015), 0.00286153 s/step
# Meep progress: 178.323/1000.0 = 17.8% done in 516.2s, 2378.5s to go
# on time step 178353 (time=178.353), 0.00299233 s/step
# Meep progress: 179.647/1000.0 = 18.0% done in 520.2s, 2375.4s to go
# on time step 179695 (time=179.695), 0.00298255 s/step
# Meep progress: 181.04500000000002/1000.0 = 18.1% done in 524.2s, 2371.2s to go
# on time step 181091 (time=181.091), 0.00286613 s/step
# Meep progress: 182.473/1000.0 = 18.2% done in 528.2s, 2366.4s to go
# on time step 182524 (time=182.524), 0.00279233 s/step
# Meep progress: 183.888/1000.0 = 18.4% done in 532.2s, 2361.9s to go
# on time step 183938 (time=183.938), 0.00283034 s/step
# Meep progress: 185.31900000000002/1000.0 = 18.5% done in 536.2s, 2357.2s to go
# on time step 185369 (time=185.369), 0.00279587 s/step
# Meep progress: 186.734/1000.0 = 18.7% done in 540.2s, 2352.7s to go
# on time step 186783 (time=186.783), 0.00283074 s/step
# Meep progress: 188.14000000000001/1000.0 = 18.8% done in 544.2s, 2348.3s to go
# on time step 188194 (time=188.194), 0.00283612 s/step
# Meep progress: 189.579/1000.0 = 19.0% done in 548.2s, 2343.5s to go
# on time step 189631 (time=189.631), 0.00278425 s/step
# Meep progress: 191.002/1000.0 = 19.1% done in 552.2s, 2338.9s to go
# on time step 191054 (time=191.054), 0.00281253 s/step
# Meep progress: 192.412/1000.0 = 19.2% done in 556.2s, 2334.5s to go
# on time step 192467 (time=192.467), 0.00283189 s/step
# Meep progress: 193.838/1000.0 = 19.4% done in 560.2s, 2329.8s to go
# on time step 193893 (time=193.893), 0.00280654 s/step
# Meep progress: 195.25300000000001/1000.0 = 19.5% done in 564.2s, 2325.4s to go
# on time step 195307 (time=195.307), 0.0028303 s/step
# Meep progress: 196.683/1000.0 = 19.7% done in 568.2s, 2320.7s to go
# on time step 196741 (time=196.741), 0.00278977 s/step
# Meep progress: 198.111/1000.0 = 19.8% done in 572.2s, 2316.1s to go
# on time step 198165 (time=198.165), 0.00280925 s/step
# Meep progress: 199.507/1000.0 = 20.0% done in 576.2s, 2311.9s to go
# on time step 199563 (time=199.563), 0.00286307 s/step
# Meep progress: 200.943/1000.0 = 20.1% done in 580.2s, 2307.2s to go
# on time step 201002 (time=201.002), 0.00278157 s/step
# Meep progress: 202.341/1000.0 = 20.2% done in 584.2s, 2303.0s to go
# on time step 202394 (time=202.394), 0.00287395 s/step
# Meep progress: 203.709/1000.0 = 20.4% done in 588.2s, 2299.3s to go
# on time step 203765 (time=203.765), 0.00291834 s/step
# Meep progress: 204.876/1000.0 = 20.5% done in 592.2s, 2298.4s to go
# on time step 204920 (time=204.92), 0.00346473 s/step
# Meep progress: 206.18/1000.0 = 20.6% done in 596.2s, 2295.5s to go
# on time step 206238 (time=206.238), 0.00303622 s/step
# Meep progress: 207.525/1000.0 = 20.8% done in 600.2s, 2292.0s to go
# on time step 207580 (time=207.58), 0.00298164 s/step
# Meep progress: 208.876/1000.0 = 20.9% done in 604.2s, 2288.5s to go
# on time step 208929 (time=208.929), 0.0029672 s/step
# Meep progress: 210.252/1000.0 = 21.0% done in 608.2s, 2284.6s to go
# on time step 210307 (time=210.307), 0.00290379 s/step
# Meep progress: 211.494/1000.0 = 21.1% done in 612.2s, 2282.5s to go
# on time step 211540 (time=211.54), 0.00324754 s/step
# Meep progress: 212.697/1000.0 = 21.3% done in 616.2s, 2281.0s to go
# on time step 212754 (time=212.754), 0.003296 s/step
# Meep progress: 214.054/1000.0 = 21.4% done in 620.2s, 2277.3s to go
# on time step 214113 (time=214.113), 0.00294438 s/step
# Meep progress: 215.34900000000002/1000.0 = 21.5% done in 624.2s, 2274.4s to go
# on time step 215406 (time=215.406), 0.00309532 s/step
# Meep progress: 216.54500000000002/1000.0 = 21.7% done in 628.2s, 2272.9s to go
# on time step 216596 (time=216.596), 0.00336322 s/step
# Meep progress: 217.928/1000.0 = 21.8% done in 632.2s, 2268.9s to go
# on time step 217988 (time=217.988), 0.00287386 s/step
# Meep progress: 219.27100000000002/1000.0 = 21.9% done in 636.2s, 2265.3s to go
# on time step 219330 (time=219.33), 0.00298072 s/step
# Meep progress: 220.656/1000.0 = 22.1% done in 640.2s, 2261.3s to go
# on time step 220707 (time=220.707), 0.002905 s/step
# Meep progress: 221.83/1000.0 = 22.2% done in 644.2s, 2260.0s to go
# on time step 221882 (time=221.882), 0.00340597 s/step
# Meep progress: 223.084/1000.0 = 22.3% done in 648.2s, 2257.6s to go
# on time step 223137 (time=223.137), 0.00318807 s/step
# Meep progress: 224.35500000000002/1000.0 = 22.4% done in 652.2s, 2254.9s to go
# on time step 224408 (time=224.408), 0.00314735 s/step
# Meep progress: 225.501/1000.0 = 22.6% done in 656.2s, 2253.9s to go
# on time step 225560 (time=225.56), 0.00347415 s/step
# Meep progress: 226.76/1000.0 = 22.7% done in 660.2s, 2251.4s to go
# on time step 226814 (time=226.814), 0.0031909 s/step
# Meep progress: 227.981/1000.0 = 22.8% done in 664.2s, 2249.4s to go
# on time step 228032 (time=228.032), 0.00328612 s/step
# Meep progress: 229.291/1000.0 = 22.9% done in 668.2s, 2246.2s to go
# on time step 229338 (time=229.338), 0.00306386 s/step
# Meep progress: 230.59/1000.0 = 23.1% done in 672.3s, 2243.1s to go
# on time step 230652 (time=230.652), 0.00304532 s/step
# Meep progress: 231.818/1000.0 = 23.2% done in 676.3s, 2240.9s to go
# on time step 231880 (time=231.88), 0.00325843 s/step
# Meep progress: 233.19/1000.0 = 23.3% done in 680.3s, 2236.9s to go
# on time step 233247 (time=233.247), 0.00292671 s/step
# Meep progress: 234.51500000000001/1000.0 = 23.5% done in 684.3s, 2233.5s to go
# on time step 234571 (time=234.571), 0.00302299 s/step
# Meep progress: 235.802/1000.0 = 23.6% done in 688.3s, 2230.6s to go
# on time step 235851 (time=235.851), 0.00312636 s/step
# Meep progress: 237.091/1000.0 = 23.7% done in 692.3s, 2227.6s to go
# on time step 237135 (time=237.135), 0.0031162 s/step
# Meep progress: 238.279/1000.0 = 23.8% done in 696.3s, 2225.8s to go
# on time step 238342 (time=238.342), 0.00331591 s/step
# Meep progress: 239.56900000000002/1000.0 = 24.0% done in 700.3s, 2222.8s to go
# on time step 239613 (time=239.613), 0.00314879 s/step
# Meep progress: 240.793/1000.0 = 24.1% done in 704.3s, 2220.5s to go
# on time step 240848 (time=240.848), 0.00323946 s/step
# Meep progress: 242.159/1000.0 = 24.2% done in 708.3s, 2216.6s to go
# on time step 242223 (time=242.223), 0.00291035 s/step
# Meep progress: 243.513/1000.0 = 24.4% done in 712.3s, 2212.7s to go
# on time step 243567 (time=243.567), 0.00297771 s/step
# Meep progress: 244.81/1000.0 = 24.5% done in 716.3s, 2209.6s to go
# on time step 244867 (time=244.867), 0.00307699 s/step
# Meep progress: 246.067/1000.0 = 24.6% done in 720.3s, 2206.9s to go
# on time step 246128 (time=246.128), 0.00317234 s/step
# Meep progress: 247.41/1000.0 = 24.7% done in 724.3s, 2203.2s to go
# on time step 247473 (time=247.473), 0.00297516 s/step
# Meep progress: 248.614/1000.0 = 24.9% done in 728.3s, 2201.1s to go
# on time step 248665 (time=248.665), 0.00335614 s/step
# Meep progress: 249.735/1000.0 = 25.0% done in 732.3s, 2200.0s to go
# on time step 249781 (time=249.781), 0.0035848 s/step
# Meep progress: 251.023/1000.0 = 25.1% done in 736.3s, 2196.9s to go
# on time step 251070 (time=251.07), 0.00310413 s/step
# Meep progress: 252.305/1000.0 = 25.2% done in 740.3s, 2193.8s to go
# on time step 252366 (time=252.366), 0.00308726 s/step
# Meep progress: 253.64000000000001/1000.0 = 25.4% done in 744.3s, 2190.1s to go
# on time step 253692 (time=253.692), 0.00301813 s/step
# Meep progress: 254.874/1000.0 = 25.5% done in 748.3s, 2187.6s to go
# on time step 254926 (time=254.926), 0.0032421 s/step
# Meep progress: 256.026/1000.0 = 25.6% done in 752.3s, 2186.0s to go
# on time step 256088 (time=256.088), 0.00344398 s/step
# Meep progress: 257.257/1000.0 = 25.7% done in 756.3s, 2183.5s to go
# on time step 257309 (time=257.309), 0.00327804 s/step
# Meep progress: 258.519/1000.0 = 25.9% done in 760.3s, 2180.7s to go
# on time step 258569 (time=258.569), 0.00317567 s/step
# Meep progress: 259.684/1000.0 = 26.0% done in 764.3s, 2178.9s to go
# on time step 259744 (time=259.744), 0.00340671 s/step
# Meep progress: 260.974/1000.0 = 26.1% done in 768.3s, 2175.7s to go
# on time step 261040 (time=261.04), 0.00308879 s/step
# Meep progress: 262.244/1000.0 = 26.2% done in 772.3s, 2172.7s to go
# on time step 262303 (time=262.303), 0.00316931 s/step
# Meep progress: 263.45/1000.0 = 26.3% done in 776.3s, 2170.4s to go
# on time step 263500 (time=263.5), 0.00334226 s/step
# Meep progress: 264.559/1000.0 = 26.5% done in 780.3s, 2169.2s to go
# on time step 264628 (time=264.628), 0.00354654 s/step
# Meep progress: 265.849/1000.0 = 26.6% done in 784.3s, 2165.9s to go
# on time step 265909 (time=265.909), 0.00312358 s/step
# Meep progress: 267.09000000000003/1000.0 = 26.7% done in 788.3s, 2163.2s to go
# on time step 267157 (time=267.157), 0.00320527 s/step
# Meep progress: 268.279/1000.0 = 26.8% done in 792.3s, 2161.0s to go
# on time step 268346 (time=268.346), 0.00336558 s/step
# Meep progress: 269.51800000000003/1000.0 = 27.0% done in 796.3s, 2158.3s to go
# on time step 269583 (time=269.583), 0.00323602 s/step
# Meep progress: 270.762/1000.0 = 27.1% done in 800.3s, 2155.5s to go
# on time step 270815 (time=270.815), 0.00324871 s/step
# Meep progress: 271.96/1000.0 = 27.2% done in 804.3s, 2153.2s to go
# on time step 272030 (time=272.03), 0.00329263 s/step
# Meep progress: 273.236/1000.0 = 27.3% done in 808.3s, 2150.0s to go
# on time step 273285 (time=273.285), 0.00318847 s/step
# Meep progress: 274.385/1000.0 = 27.4% done in 812.3s, 2148.2s to go
# on time step 274434 (time=274.434), 0.00348338 s/step
# Meep progress: 275.563/1000.0 = 27.6% done in 816.3s, 2146.1s to go
# on time step 275633 (time=275.633), 0.00333705 s/step
# Meep progress: 276.795/1000.0 = 27.7% done in 820.3s, 2143.3s to go
# on time step 276863 (time=276.863), 0.00325239 s/step
# Meep progress: 278.16700000000003/1000.0 = 27.8% done in 824.3s, 2139.1s to go
# on time step 278230 (time=278.23), 0.00292739 s/step
# Meep progress: 279.51800000000003/1000.0 = 28.0% done in 828.3s, 2135.1s to go
# on time step 279589 (time=279.589), 0.00294369 s/step
# Meep progress: 280.898/1000.0 = 28.1% done in 832.3s, 2130.8s to go
# on time step 280958 (time=280.958), 0.00292384 s/step
# Meep progress: 282.202/1000.0 = 28.2% done in 836.3s, 2127.2s to go
# on time step 282275 (time=282.275), 0.00303826 s/step
# Meep progress: 283.54/1000.0 = 28.4% done in 840.3s, 2123.4s to go
# on time step 283613 (time=283.613), 0.00299106 s/step
# Meep progress: 284.886/1000.0 = 28.5% done in 844.3s, 2119.4s to go
# on time step 284957 (time=284.957), 0.00297774 s/step
# Meep progress: 286.214/1000.0 = 28.6% done in 848.3s, 2115.6s to go
# on time step 286281 (time=286.281), 0.00302117 s/step
# Meep progress: 287.587/1000.0 = 28.8% done in 852.3s, 2111.4s to go
# on time step 287664 (time=287.664), 0.00289278 s/step
# Meep progress: 289.01800000000003/1000.0 = 28.9% done in 856.3s, 2106.6s to go
# on time step 289095 (time=289.095), 0.00279663 s/step
# Meep progress: 290.442/1000.0 = 29.0% done in 860.3s, 2101.8s to go
# on time step 290516 (time=290.516), 0.00281553 s/step
# Meep progress: 291.89/1000.0 = 29.2% done in 864.3s, 2096.8s to go
# on time step 291966 (time=291.966), 0.0027587 s/step
# Meep progress: 293.318/1000.0 = 29.3% done in 868.3s, 2092.0s to go
# on time step 293395 (time=293.395), 0.00279968 s/step
# Meep progress: 294.732/1000.0 = 29.5% done in 872.3s, 2087.4s to go
# on time step 294809 (time=294.809), 0.00283062 s/step
# Meep progress: 296.169/1000.0 = 29.6% done in 876.3s, 2082.6s to go
# on time step 296248 (time=296.248), 0.00278133 s/step
# Meep progress: 297.598/1000.0 = 29.8% done in 880.3s, 2077.8s to go
# on time step 297675 (time=297.675), 0.00280652 s/step
# Meep progress: 299.002/1000.0 = 29.9% done in 884.3s, 2073.3s to go
# on time step 299073 (time=299.073), 0.0028628 s/step
# Meep progress: 300.40000000000003/1000.0 = 30.0% done in 888.3s, 2068.9s to go
# on time step 300480 (time=300.48), 0.00284319 s/step
# Meep progress: 301.855/1000.0 = 30.2% done in 892.3s, 2063.9s to go
# on time step 301931 (time=301.931), 0.00275712 s/step
# Meep progress: 303.296/1000.0 = 30.3% done in 896.3s, 2059.0s to go
# on time step 303372 (time=303.372), 0.00277718 s/step
# Meep progress: 304.76300000000003/1000.0 = 30.5% done in 900.3s, 2053.9s to go
# on time step 304844 (time=304.844), 0.00271816 s/step
# Meep progress: 306.187/1000.0 = 30.6% done in 904.3s, 2049.2s to go
# on time step 306269 (time=306.269), 0.0028081 s/step
# Meep progress: 307.599/1000.0 = 30.8% done in 908.3s, 2044.7s to go
# on time step 307679 (time=307.679), 0.00283742 s/step
# Meep progress: 309.008/1000.0 = 30.9% done in 912.4s, 2040.2s to go
# on time step 309089 (time=309.089), 0.00283819 s/step
# Meep progress: 310.455/1000.0 = 31.0% done in 916.4s, 2035.3s to go
# on time step 310532 (time=310.532), 0.00277419 s/step
# Meep progress: 311.907/1000.0 = 31.2% done in 920.4s, 2030.4s to go
# on time step 311988 (time=311.988), 0.00274845 s/step
# Meep progress: 313.35200000000003/1000.0 = 31.3% done in 924.4s, 2025.5s to go
# on time step 313434 (time=313.434), 0.00276686 s/step
# Meep progress: 314.79/1000.0 = 31.5% done in 928.4s, 2020.8s to go
# on time step 314871 (time=314.871), 0.00278424 s/step
# Meep progress: 316.219/1000.0 = 31.6% done in 932.4s, 2016.1s to go
# on time step 316298 (time=316.298), 0.00280309 s/step
# Meep progress: 317.649/1000.0 = 31.8% done in 936.4s, 2011.4s to go
# on time step 317734 (time=317.734), 0.00278665 s/step
# Meep progress: 319.103/1000.0 = 31.9% done in 940.4s, 2006.5s to go
# on time step 319184 (time=319.184), 0.00275872 s/step
# Meep progress: 320.50600000000003/1000.0 = 32.1% done in 944.4s, 2002.1s to go
# on time step 320581 (time=320.581), 0.00286532 s/step
# Meep progress: 321.902/1000.0 = 32.2% done in 948.4s, 1997.8s to go
# on time step 321984 (time=321.984), 0.00285161 s/step
# Meep progress: 323.325/1000.0 = 32.3% done in 952.4s, 1993.2s to go
# on time step 323405 (time=323.405), 0.00281516 s/step
# Meep progress: 324.745/1000.0 = 32.5% done in 956.4s, 1988.6s to go
# on time step 324831 (time=324.831), 0.00280628 s/step
# Meep progress: 326.171/1000.0 = 32.6% done in 960.4s, 1984.0s to go
# on time step 326257 (time=326.257), 0.00280528 s/step
# Meep progress: 327.595/1000.0 = 32.8% done in 964.4s, 1979.4s to go
# on time step 327678 (time=327.678), 0.00281561 s/step
# Meep progress: 329.052/1000.0 = 32.9% done in 968.4s, 1974.5s to go
# on time step 329137 (time=329.137), 0.00274204 s/step
# Meep progress: 330.46/1000.0 = 33.0% done in 972.4s, 1970.1s to go
# on time step 330544 (time=330.544), 0.00284444 s/step
# Meep progress: 331.873/1000.0 = 33.2% done in 976.4s, 1965.6s to go
# on time step 331959 (time=331.959), 0.00282919 s/step
# Meep progress: 333.305/1000.0 = 33.3% done in 980.4s, 1961.0s to go
# on time step 333392 (time=333.392), 0.00279194 s/step
# Meep progress: 334.729/1000.0 = 33.5% done in 984.4s, 1956.4s to go
# on time step 334811 (time=334.811), 0.00282186 s/step
# Meep progress: 336.137/1000.0 = 33.6% done in 988.4s, 1952.0s to go
# on time step 336222 (time=336.222), 0.00283657 s/step
# Meep progress: 337.544/1000.0 = 33.8% done in 992.4s, 1947.6s to go
# on time step 337630 (time=337.63), 0.00284129 s/step
# Meep progress: 338.973/1000.0 = 33.9% done in 996.4s, 1943.0s to go
# on time step 339061 (time=339.061), 0.00279666 s/step
# Meep progress: 340.35200000000003/1000.0 = 34.0% done in 1000.4s, 1938.9s to go
# on time step 340434 (time=340.434), 0.00291354 s/step
# Meep progress: 341.747/1000.0 = 34.2% done in 1004.4s, 1934.6s to go
# on time step 341834 (time=341.834), 0.00285744 s/step
# Meep progress: 343.154/1000.0 = 34.3% done in 1008.4s, 1930.2s to go
# on time step 343246 (time=343.246), 0.00283389 s/step
# Meep progress: 344.575/1000.0 = 34.5% done in 1012.4s, 1925.7s to go
# on time step 344664 (time=344.664), 0.00282247 s/step
# Meep progress: 346.008/1000.0 = 34.6% done in 1016.4s, 1921.1s to go
# on time step 346094 (time=346.094), 0.00279752 s/step
# Meep progress: 347.459/1000.0 = 34.7% done in 1020.4s, 1916.3s to go
# on time step 347554 (time=347.554), 0.00274116 s/step
# Meep progress: 348.848/1000.0 = 34.9% done in 1024.4s, 1912.1s to go
# on time step 348933 (time=348.933), 0.00290259 s/step
# Meep progress: 350.25600000000003/1000.0 = 35.0% done in 1028.4s, 1907.7s to go
# on time step 350343 (time=350.343), 0.00283799 s/step
# Meep progress: 351.675/1000.0 = 35.2% done in 1032.4s, 1903.2s to go
# on time step 351763 (time=351.763), 0.00281851 s/step
# Meep progress: 353.091/1000.0 = 35.3% done in 1036.4s, 1898.8s to go
# on time step 353183 (time=353.183), 0.00281693 s/step
# Meep progress: 354.548/1000.0 = 35.5% done in 1040.4s, 1894.0s to go
# on time step 354640 (time=354.64), 0.00274651 s/step
# Meep progress: 356.005/1000.0 = 35.6% done in 1044.4s, 1889.3s to go
# on time step 356097 (time=356.097), 0.00274622 s/step
# Meep progress: 357.449/1000.0 = 35.7% done in 1048.4s, 1884.6s to go
# on time step 357543 (time=357.543), 0.00276787 s/step
# Meep progress: 358.884/1000.0 = 35.9% done in 1052.4s, 1880.0s to go
# on time step 358977 (time=358.977), 0.00278953 s/step
# Meep progress: 360.261/1000.0 = 36.0% done in 1056.4s, 1875.9s to go
# on time step 360357 (time=360.357), 0.00289882 s/step
# Meep progress: 361.669/1000.0 = 36.2% done in 1060.4s, 1871.6s to go
# on time step 361763 (time=361.763), 0.00284547 s/step
# Meep progress: 363.11400000000003/1000.0 = 36.3% done in 1064.4s, 1866.9s to go
# on time step 363201 (time=363.201), 0.00278334 s/step
# Meep progress: 364.51300000000003/1000.0 = 36.5% done in 1068.4s, 1862.6s to go
# on time step 364606 (time=364.606), 0.00284745 s/step
# Meep progress: 365.933/1000.0 = 36.6% done in 1072.4s, 1858.2s to go
# on time step 366024 (time=366.024), 0.00282229 s/step
# Meep progress: 367.346/1000.0 = 36.7% done in 1076.4s, 1853.8s to go
# on time step 367443 (time=367.443), 0.00281919 s/step
# Meep progress: 368.789/1000.0 = 36.9% done in 1080.4s, 1849.2s to go
# on time step 368882 (time=368.882), 0.00278083 s/step
# Meep progress: 370.175/1000.0 = 37.0% done in 1084.4s, 1845.0s to go
# on time step 370272 (time=370.272), 0.0028796 s/step
# Meep progress: 371.589/1000.0 = 37.2% done in 1088.4s, 1840.7s to go
# on time step 371685 (time=371.685), 0.00283131 s/step
# Meep progress: 372.875/1000.0 = 37.3% done in 1092.4s, 1837.3s to go
# on time step 372969 (time=372.969), 0.00311534 s/step
# Meep progress: 374.284/1000.0 = 37.4% done in 1096.4s, 1832.9s to go
# on time step 374364 (time=374.364), 0.00286975 s/step
# Meep progress: 375.55400000000003/1000.0 = 37.6% done in 1100.4s, 1829.7s to go
# on time step 375644 (time=375.644), 0.00312598 s/step
# Meep progress: 376.903/1000.0 = 37.7% done in 1104.4s, 1825.8s to go
# on time step 377004 (time=377.004), 0.00294204 s/step
# Meep progress: 378.338/1000.0 = 37.8% done in 1108.4s, 1821.3s to go
# on time step 378439 (time=378.439), 0.00278789 s/step
# Meep progress: 379.785/1000.0 = 38.0% done in 1112.4s, 1816.7s to go
# on time step 379882 (time=379.882), 0.00277347 s/step
# Meep progress: 381.209/1000.0 = 38.1% done in 1116.4s, 1812.2s to go
# on time step 381310 (time=381.31), 0.00280278 s/step
# Meep progress: 382.661/1000.0 = 38.3% done in 1120.4s, 1807.6s to go
# on time step 382763 (time=382.763), 0.00275326 s/step
# Meep progress: 384.092/1000.0 = 38.4% done in 1124.4s, 1803.1s to go
# on time step 384194 (time=384.194), 0.00279632 s/step
# Meep progress: 385.55/1000.0 = 38.6% done in 1128.4s, 1798.4s to go
# on time step 385654 (time=385.654), 0.00274063 s/step
# Meep progress: 386.975/1000.0 = 38.7% done in 1132.4s, 1793.9s to go
# on time step 387073 (time=387.073), 0.00281966 s/step
# Meep progress: 388.426/1000.0 = 38.8% done in 1136.4s, 1789.3s to go
# on time step 388524 (time=388.524), 0.00275708 s/step
# Meep progress: 389.901/1000.0 = 39.0% done in 1140.4s, 1784.5s to go
# on time step 390002 (time=390.002), 0.00270783 s/step
# Meep progress: 391.349/1000.0 = 39.1% done in 1144.4s, 1779.9s to go
# on time step 391446 (time=391.446), 0.00277184 s/step
# Meep progress: 392.801/1000.0 = 39.3% done in 1148.4s, 1775.3s to go
# on time step 392905 (time=392.905), 0.0027426 s/step
# Meep progress: 394.273/1000.0 = 39.4% done in 1152.4s, 1770.5s to go
# on time step 394379 (time=394.379), 0.00271546 s/step
# Meep progress: 395.718/1000.0 = 39.6% done in 1156.4s, 1765.9s to go
# on time step 395820 (time=395.82), 0.0027765 s/step
# Meep progress: 397.18/1000.0 = 39.7% done in 1160.4s, 1761.3s to go
# on time step 397281 (time=397.281), 0.00273913 s/step
# Meep progress: 398.627/1000.0 = 39.9% done in 1164.4s, 1756.7s to go
# on time step 398731 (time=398.731), 0.00275906 s/step
# Meep progress: 400.084/1000.0 = 40.0% done in 1168.4s, 1752.0s to go
# on time step 400188 (time=400.188), 0.00274662 s/step
# Meep progress: 401.535/1000.0 = 40.2% done in 1172.4s, 1747.5s to go
# on time step 401636 (time=401.636), 0.0027635 s/step
# Meep progress: 402.966/1000.0 = 40.3% done in 1176.4s, 1743.0s to go
# on time step 403069 (time=403.069), 0.00279175 s/step
# Meep progress: 404.41/1000.0 = 40.4% done in 1180.4s, 1738.5s to go
# on time step 404516 (time=404.516), 0.00276534 s/step
# Meep progress: 405.857/1000.0 = 40.6% done in 1184.4s, 1733.9s to go
# on time step 405964 (time=405.964), 0.00276419 s/step
# Meep progress: 407.308/1000.0 = 40.7% done in 1188.4s, 1729.4s to go
# on time step 407412 (time=407.412), 0.00276354 s/step
# Meep progress: 408.761/1000.0 = 40.9% done in 1192.4s, 1724.8s to go
# on time step 408867 (time=408.867), 0.00275156 s/step
# Meep progress: 410.196/1000.0 = 41.0% done in 1196.4s, 1720.3s to go
# on time step 410302 (time=410.302), 0.00278757 s/step
# Meep progress: 411.641/1000.0 = 41.2% done in 1200.5s, 1715.8s to go
# on time step 411743 (time=411.743), 0.00277587 s/step
# Meep progress: 412.96500000000003/1000.0 = 41.3% done in 1204.5s, 1712.1s to go
# on time step 413048 (time=413.048), 0.00306612 s/step
# Meep progress: 414.399/1000.0 = 41.4% done in 1208.5s, 1707.7s to go
# on time step 414508 (time=414.508), 0.00274036 s/step
# Meep progress: 415.818/1000.0 = 41.6% done in 1212.5s, 1703.4s to go
# on time step 415921 (time=415.921), 0.00283126 s/step
# Meep progress: 417.216/1000.0 = 41.7% done in 1216.5s, 1699.2s to go
# on time step 417321 (time=417.321), 0.0028579 s/step
# Meep progress: 418.56/1000.0 = 41.9% done in 1220.5s, 1695.4s to go
# on time step 418663 (time=418.663), 0.00298192 s/step
# Meep progress: 419.995/1000.0 = 42.0% done in 1224.5s, 1691.0s to go
# on time step 420107 (time=420.107), 0.00277054 s/step
# Meep progress: 421.452/1000.0 = 42.1% done in 1228.5s, 1686.4s to go
# on time step 421551 (time=421.551), 0.0027715 s/step
# Meep progress: 422.892/1000.0 = 42.3% done in 1232.5s, 1681.9s to go
# on time step 423001 (time=423.001), 0.00276016 s/step
# Meep progress: 424.344/1000.0 = 42.4% done in 1236.5s, 1677.4s to go
# on time step 424450 (time=424.45), 0.00276081 s/step
# Meep progress: 425.79900000000004/1000.0 = 42.6% done in 1240.5s, 1672.8s to go
# on time step 425904 (time=425.904), 0.00275146 s/step
# Meep progress: 427.211/1000.0 = 42.7% done in 1244.5s, 1668.5s to go
# on time step 427316 (time=427.316), 0.00283449 s/step
# Meep progress: 428.591/1000.0 = 42.9% done in 1248.5s, 1664.5s to go
# on time step 428695 (time=428.695), 0.00290191 s/step
# Meep progress: 429.918/1000.0 = 43.0% done in 1252.5s, 1660.8s to go
# on time step 430030 (time=430.03), 0.00299722 s/step
# Meep progress: 431.327/1000.0 = 43.1% done in 1256.5s, 1656.6s to go
# on time step 431438 (time=431.438), 0.00284192 s/step
# Meep progress: 432.689/1000.0 = 43.3% done in 1260.5s, 1652.6s to go
# on time step 432789 (time=432.789), 0.0029616 s/step
# Meep progress: 434.091/1000.0 = 43.4% done in 1264.5s, 1648.5s to go
# on time step 434197 (time=434.197), 0.00284171 s/step
# Meep progress: 435.494/1000.0 = 43.5% done in 1268.5s, 1644.3s to go
# on time step 435604 (time=435.604), 0.00284484 s/step
# Meep progress: 436.935/1000.0 = 43.7% done in 1272.5s, 1639.8s to go
# on time step 437045 (time=437.045), 0.00277632 s/step
# Meep progress: 438.391/1000.0 = 43.8% done in 1276.5s, 1635.3s to go
# on time step 438505 (time=438.505), 0.00274104 s/step
# Meep progress: 439.854/1000.0 = 44.0% done in 1280.5s, 1630.7s to go
# on time step 439970 (time=439.97), 0.00273112 s/step
# Meep progress: 441.313/1000.0 = 44.1% done in 1284.5s, 1626.1s to go
# on time step 441426 (time=441.426), 0.00274948 s/step
# Meep progress: 442.78700000000003/1000.0 = 44.3% done in 1288.5s, 1621.5s to go
# on time step 442902 (time=442.902), 0.00271026 s/step
# Meep progress: 444.243/1000.0 = 44.4% done in 1292.5s, 1616.9s to go
# on time step 444361 (time=444.361), 0.00274324 s/step
# Meep progress: 445.708/1000.0 = 44.6% done in 1296.5s, 1612.3s to go
# on time step 445818 (time=445.818), 0.00274626 s/step
# Meep progress: 447.166/1000.0 = 44.7% done in 1300.5s, 1607.8s to go
# on time step 447276 (time=447.276), 0.00274479 s/step
# Meep progress: 448.616/1000.0 = 44.9% done in 1304.5s, 1603.3s to go
# on time step 448725 (time=448.725), 0.0027615 s/step
# Meep progress: 450.06/1000.0 = 45.0% done in 1308.5s, 1598.9s to go
# on time step 450175 (time=450.175), 0.00275958 s/step
# Meep progress: 451.515/1000.0 = 45.2% done in 1312.5s, 1594.4s to go
# on time step 451629 (time=451.629), 0.00275132 s/step
# Meep progress: 452.95300000000003/1000.0 = 45.3% done in 1316.5s, 1590.0s to go
# on time step 453069 (time=453.069), 0.00277864 s/step
# Meep progress: 454.408/1000.0 = 45.4% done in 1320.5s, 1585.5s to go
# on time step 454526 (time=454.526), 0.00274618 s/step
# Meep progress: 455.833/1000.0 = 45.6% done in 1324.5s, 1581.2s to go
# on time step 455946 (time=455.946), 0.00281745 s/step
# Meep progress: 457.277/1000.0 = 45.7% done in 1328.5s, 1576.7s to go
# on time step 457399 (time=457.399), 0.00275422 s/step
# Meep progress: 458.709/1000.0 = 45.9% done in 1332.5s, 1572.4s to go
# on time step 458816 (time=458.816), 0.00282294 s/step
# Meep progress: 460.039/1000.0 = 46.0% done in 1336.5s, 1568.7s to go
# on time step 460132 (time=460.132), 0.00304001 s/step
# Meep progress: 461.26300000000003/1000.0 = 46.1% done in 1340.5s, 1565.7s to go
# on time step 461355 (time=461.355), 0.00327307 s/step
# Meep progress: 462.515/1000.0 = 46.3% done in 1344.5s, 1562.4s to go
# on time step 462628 (time=462.628), 0.00314274 s/step
# Meep progress: 463.765/1000.0 = 46.4% done in 1348.5s, 1559.2s to go
# on time step 463860 (time=463.86), 0.00324708 s/step
# Meep progress: 464.90500000000003/1000.0 = 46.5% done in 1352.5s, 1556.7s to go
# on time step 464998 (time=464.998), 0.00351729 s/step
# Meep progress: 466.218/1000.0 = 46.6% done in 1356.5s, 1553.1s to go
# on time step 466344 (time=466.344), 0.00297312 s/step
# Meep progress: 467.635/1000.0 = 46.8% done in 1360.5s, 1548.8s to go
# on time step 467722 (time=467.722), 0.00290285 s/step
# Meep progress: 469.003/1000.0 = 46.9% done in 1364.5s, 1544.9s to go
# on time step 469120 (time=469.12), 0.00286247 s/step
# Meep progress: 470.44100000000003/1000.0 = 47.0% done in 1368.5s, 1540.5s to go
# on time step 470557 (time=470.557), 0.00278503 s/step
# Meep progress: 471.84700000000004/1000.0 = 47.2% done in 1372.5s, 1536.3s to go
# on time step 471961 (time=471.961), 0.00284924 s/step
# Meep progress: 473.305/1000.0 = 47.3% done in 1376.5s, 1531.8s to go
# on time step 473420 (time=473.42), 0.00274249 s/step
# Meep progress: 474.738/1000.0 = 47.5% done in 1380.5s, 1527.4s to go
# on time step 474844 (time=474.844), 0.00281096 s/step
# Meep progress: 476.125/1000.0 = 47.6% done in 1384.5s, 1523.4s to go
# on time step 476224 (time=476.224), 0.00289914 s/step
# Meep progress: 477.43600000000004/1000.0 = 47.7% done in 1388.5s, 1519.8s to go
# on time step 477552 (time=477.552), 0.0030132 s/step
# Meep progress: 478.844/1000.0 = 47.9% done in 1392.5s, 1515.6s to go
# on time step 478964 (time=478.964), 0.00283305 s/step
# Meep progress: 480.29900000000004/1000.0 = 48.0% done in 1396.5s, 1511.1s to go
# on time step 480418 (time=480.418), 0.00275175 s/step
# Meep progress: 481.639/1000.0 = 48.2% done in 1400.5s, 1507.3s to go
# on time step 481762 (time=481.762), 0.00297679 s/step
# Meep progress: 483.068/1000.0 = 48.3% done in 1404.5s, 1503.0s to go
# on time step 483184 (time=483.184), 0.00281465 s/step
# Meep progress: 484.445/1000.0 = 48.4% done in 1408.5s, 1499.0s to go
# on time step 484567 (time=484.567), 0.0028935 s/step
# Meep progress: 485.87100000000004/1000.0 = 48.6% done in 1412.5s, 1494.7s to go
# on time step 485995 (time=485.995), 0.00280254 s/step
# Meep progress: 487.29900000000004/1000.0 = 48.7% done in 1416.5s, 1490.4s to go
# on time step 487412 (time=487.412), 0.00282391 s/step
# Meep progress: 488.677/1000.0 = 48.9% done in 1420.5s, 1486.4s to go
# on time step 488781 (time=488.781), 0.00292429 s/step
# Meep progress: 490.055/1000.0 = 49.0% done in 1424.5s, 1482.4s to go
# on time step 490179 (time=490.179), 0.0028623 s/step
# Meep progress: 491.333/1000.0 = 49.1% done in 1428.5s, 1478.9s to go
# on time step 491459 (time=491.459), 0.00312698 s/step
# Meep progress: 492.677/1000.0 = 49.3% done in 1432.5s, 1475.1s to go
# on time step 492797 (time=492.797), 0.00298992 s/step
# Meep progress: 494.104/1000.0 = 49.4% done in 1436.5s, 1470.8s to go
# on time step 494226 (time=494.226), 0.00280053 s/step
# Meep progress: 495.521/1000.0 = 49.6% done in 1440.5s, 1466.6s to go
# on time step 495641 (time=495.641), 0.0028293 s/step
# Meep progress: 496.736/1000.0 = 49.7% done in 1444.5s, 1463.5s to go
# on time step 496843 (time=496.843), 0.00332846 s/step
# Meep progress: 498.132/1000.0 = 49.8% done in 1448.5s, 1459.4s to go
# on time step 498260 (time=498.26), 0.0028234 s/step
# Meep progress: 499.357/1000.0 = 49.9% done in 1452.6s, 1456.3s to go
# on time step 499469 (time=499.469), 0.00330976 s/step
# Meep progress: 500.767/1000.0 = 50.1% done in 1456.6s, 1452.1s to go
# on time step 500896 (time=500.896), 0.00280409 s/step
# Meep progress: 502.217/1000.0 = 50.2% done in 1460.6s, 1447.7s to go
# on time step 502341 (time=502.341), 0.00276858 s/step
# Meep progress: 503.624/1000.0 = 50.4% done in 1464.6s, 1443.5s to go
# on time step 503747 (time=503.747), 0.00284583 s/step
# Meep progress: 505.067/1000.0 = 50.5% done in 1468.6s, 1439.1s to go
# on time step 505195 (time=505.195), 0.00276293 s/step
# Meep progress: 506.461/1000.0 = 50.6% done in 1472.6s, 1435.0s to go
# on time step 506591 (time=506.591), 0.00286562 s/step
# Meep progress: 507.879/1000.0 = 50.8% done in 1476.6s, 1430.8s to go
# on time step 508003 (time=508.003), 0.00283399 s/step
# Meep progress: 509.319/1000.0 = 50.9% done in 1480.6s, 1426.4s to go
# on time step 509439 (time=509.439), 0.00278737 s/step
# Meep progress: 510.742/1000.0 = 51.1% done in 1484.6s, 1422.1s to go
# on time step 510872 (time=510.872), 0.00279378 s/step
# Meep progress: 512.199/1000.0 = 51.2% done in 1488.6s, 1417.7s to go
# on time step 512325 (time=512.325), 0.00275331 s/step
# Meep progress: 513.639/1000.0 = 51.4% done in 1492.6s, 1413.3s to go
# on time step 513767 (time=513.767), 0.00277468 s/step
# ...
# on time step 867736 (time=867.736), 0.00387997 s/step
# Meep progress: 868.59/1000.0 = 86.9% done in 2505.0s, 379.0s to go
# on time step 868734 (time=868.734), 0.00401217 s/step
# Meep progress: 869.619/1000.0 = 87.0% done in 2509.0s, 376.2s to go
# on time step 869779 (time=869.779), 0.00382813 s/step
# Meep progress: 870.679/1000.0 = 87.1% done in 2513.0s, 373.2s to go
# on time step 870839 (time=870.839), 0.00377436 s/step
# Meep progress: 871.6940000000001/1000.0 = 87.2% done in 2517.0s, 370.5s to go
# on time step 871854 (time=871.854), 0.00394313 s/step
# Meep progress: 872.7620000000001/1000.0 = 87.3% done in 2521.0s, 367.5s to go
# on time step 872908 (time=872.908), 0.00379765 s/step
# Meep progress: 873.792/1000.0 = 87.4% done in 2525.0s, 364.7s to go
# on time step 873950 (time=873.95), 0.00383922 s/step
# Meep progress: 874.856/1000.0 = 87.5% done in 2529.0s, 361.8s to go
# on time step 875010 (time=875.01), 0.00377483 s/step
# Meep progress: 875.87/1000.0 = 87.6% done in 2533.0s, 359.0s to go
# on time step 876033 (time=876.033), 0.00391192 s/step
# Meep progress: 876.917/1000.0 = 87.7% done in 2537.0s, 356.1s to go
# on time step 877073 (time=877.073), 0.00384665 s/step
# Meep progress: 877.943/1000.0 = 87.8% done in 2541.0s, 353.3s to go
# on time step 878100 (time=878.1), 0.00389555 s/step
# Meep progress: 878.986/1000.0 = 87.9% done in 2545.0s, 350.4s to go
# on time step 879139 (time=879.139), 0.00385235 s/step
# Meep progress: 880.019/1000.0 = 88.0% done in 2549.0s, 347.5s to go
# on time step 880183 (time=880.183), 0.00383238 s/step
# Meep progress: 881.0930000000001/1000.0 = 88.1% done in 2553.0s, 344.5s to go
# on time step 881236 (time=881.236), 0.00379992 s/step
# Meep progress: 882.126/1000.0 = 88.2% done in 2557.0s, 341.7s to go
# on time step 882299 (time=882.299), 0.00376481 s/step
# Meep progress: 883.217/1000.0 = 88.3% done in 2561.0s, 338.6s to go
# on time step 883384 (time=883.384), 0.00368818 s/step
# Meep progress: 884.29/1000.0 = 88.4% done in 2565.0s, 335.6s to go
# on time step 884449 (time=884.449), 0.00375701 s/step
# Meep progress: 885.383/1000.0 = 88.5% done in 2569.0s, 332.6s to go
# on time step 885549 (time=885.549), 0.00363662 s/step
# Meep progress: 886.492/1000.0 = 88.6% done in 2573.0s, 329.5s to go
# on time step 886660 (time=886.66), 0.00360091 s/step
# Meep progress: 887.5930000000001/1000.0 = 88.8% done in 2577.0s, 326.4s to go
# on time step 887766 (time=887.766), 0.00361959 s/step
# Meep progress: 888.702/1000.0 = 88.9% done in 2581.0s, 323.2s to go
# on time step 888864 (time=888.864), 0.00364706 s/step
# Meep progress: 889.827/1000.0 = 89.0% done in 2585.0s, 320.1s to go
# on time step 889996 (time=889.996), 0.00353864 s/step
# Meep progress: 890.912/1000.0 = 89.1% done in 2589.0s, 317.0s to go
# on time step 891086 (time=891.086), 0.00367077 s/step
# Meep progress: 891.9730000000001/1000.0 = 89.2% done in 2593.0s, 314.0s to go
# on time step 892128 (time=892.128), 0.00383899 s/step
# Meep progress: 893.032/1000.0 = 89.3% done in 2597.0s, 311.1s to go
# on time step 893204 (time=893.204), 0.00371782 s/step
# Meep progress: 894.153/1000.0 = 89.4% done in 2601.0s, 307.9s to go
# on time step 894325 (time=894.325), 0.0035708 s/step
# Meep progress: 895.2810000000001/1000.0 = 89.5% done in 2605.0s, 304.7s to go
# on time step 895462 (time=895.462), 0.00352064 s/step
# Meep progress: 896.426/1000.0 = 89.6% done in 2609.0s, 301.4s to go
# on time step 896592 (time=896.592), 0.00354098 s/step
# Meep progress: 897.533/1000.0 = 89.8% done in 2613.0s, 298.3s to go
# on time step 897708 (time=897.708), 0.00358491 s/step
# Meep progress: 898.614/1000.0 = 89.9% done in 2617.0s, 295.3s to go
# on time step 898790 (time=898.79), 0.00369989 s/step
# Meep progress: 899.751/1000.0 = 90.0% done in 2621.0s, 292.0s to go
# on time step 899926 (time=899.926), 0.00352185 s/step
# Meep progress: 900.832/1000.0 = 90.1% done in 2625.0s, 289.0s to go
# on time step 901008 (time=901.008), 0.00369897 s/step
# Meep progress: 902.096/1000.0 = 90.2% done in 2629.0s, 285.3s to go
# on time step 902312 (time=902.312), 0.0030677 s/step
# Meep progress: 903.482/1000.0 = 90.3% done in 2633.0s, 281.3s to go
# on time step 903701 (time=903.701), 0.00288105 s/step
# Meep progress: 904.7810000000001/1000.0 = 90.5% done in 2637.0s, 277.5s to go
# on time step 904992 (time=904.992), 0.0030987 s/step
# Meep progress: 906.178/1000.0 = 90.6% done in 2641.0s, 273.4s to go
# on time step 906404 (time=906.404), 0.00283417 s/step
# Meep progress: 907.546/1000.0 = 90.8% done in 2645.0s, 269.5s to go
# on time step 907736 (time=907.736), 0.0030035 s/step
# Meep progress: 908.814/1000.0 = 90.9% done in 2649.0s, 265.8s to go
# on time step 908971 (time=908.971), 0.00324124 s/step
# Meep progress: 910.1270000000001/1000.0 = 91.0% done in 2653.0s, 262.0s to go
# on time step 910319 (time=910.319), 0.00296888 s/step
# Meep progress: 911.259/1000.0 = 91.1% done in 2657.0s, 258.7s to go
# on time step 911435 (time=911.435), 0.00358436 s/step
# Meep progress: 912.528/1000.0 = 91.3% done in 2661.0s, 255.1s to go
# on time step 912744 (time=912.744), 0.00305605 s/step
# Meep progress: 913.9490000000001/1000.0 = 91.4% done in 2665.0s, 250.9s to go
# on time step 914141 (time=914.141), 0.00286463 s/step
# Meep progress: 915.25/1000.0 = 91.5% done in 2669.0s, 247.1s to go
# on time step 915469 (time=915.469), 0.00301287 s/step
# Meep progress: 916.573/1000.0 = 91.7% done in 2673.0s, 243.3s to go
# on time step 916794 (time=916.794), 0.00302022 s/step
# Meep progress: 917.99/1000.0 = 91.8% done in 2677.0s, 239.2s to go
# on time step 918208 (time=918.208), 0.00282972 s/step
# Meep progress: 919.386/1000.0 = 91.9% done in 2681.0s, 235.1s to go
# on time step 919621 (time=919.621), 0.0028321 s/step
# Meep progress: 920.812/1000.0 = 92.1% done in 2685.0s, 230.9s to go
# on time step 921027 (time=921.027), 0.00284521 s/step
# Meep progress: 922.227/1000.0 = 92.2% done in 2689.0s, 226.8s to go
# on time step 922441 (time=922.441), 0.00282916 s/step
# Meep progress: 923.621/1000.0 = 92.4% done in 2693.0s, 222.7s to go
# on time step 923837 (time=923.837), 0.0028657 s/step
# Meep progress: 925.033/1000.0 = 92.5% done in 2697.0s, 218.6s to go
# on time step 925250 (time=925.25), 0.0028313 s/step
# Meep progress: 926.426/1000.0 = 92.6% done in 2701.1s, 214.5s to go
# on time step 926659 (time=926.659), 0.00284018 s/step
# Meep progress: 927.844/1000.0 = 92.8% done in 2705.1s, 210.4s to go
# on time step 928068 (time=928.068), 0.00283972 s/step
# Meep progress: 929.227/1000.0 = 92.9% done in 2709.1s, 206.3s to go
# on time step 929443 (time=929.443), 0.00290955 s/step
# Meep progress: 930.631/1000.0 = 93.1% done in 2713.1s, 202.2s to go
# on time step 930861 (time=930.861), 0.00282219 s/step
# Meep progress: 931.97/1000.0 = 93.2% done in 2717.1s, 198.3s to go
# on time step 932140 (time=932.14), 0.00312787 s/step
# Meep progress: 932.991/1000.0 = 93.3% done in 2721.1s, 195.4s to go
# on time step 933145 (time=933.145), 0.00398439 s/step
# Meep progress: 933.974/1000.0 = 93.4% done in 2725.1s, 192.6s to go
# on time step 934134 (time=934.134), 0.0040463 s/step
# Meep progress: 934.9780000000001/1000.0 = 93.5% done in 2729.1s, 189.8s to go
# on time step 935148 (time=935.148), 0.00394538 s/step
# Meep progress: 936.009/1000.0 = 93.6% done in 2733.1s, 186.8s to go
# on time step 936168 (time=936.168), 0.00392512 s/step
# Meep progress: 937.056/1000.0 = 93.7% done in 2737.1s, 183.9s to go
# on time step 937230 (time=937.23), 0.00376674 s/step
# Meep progress: 938.1/1000.0 = 93.8% done in 2741.1s, 180.9s to go
# on time step 938254 (time=938.254), 0.00390769 s/step
# Meep progress: 939.213/1000.0 = 93.9% done in 2745.1s, 177.7s to go
# on time step 939432 (time=939.432), 0.00339644 s/step
# Meep progress: 940.592/1000.0 = 94.1% done in 2749.1s, 173.6s to go
# on time step 940782 (time=940.782), 0.00296723 s/step
# Meep progress: 941.735/1000.0 = 94.2% done in 2753.1s, 170.3s to go
# on time step 941941 (time=941.941), 0.00345185 s/step
# Meep progress: 942.874/1000.0 = 94.3% done in 2757.1s, 167.0s to go
# on time step 943045 (time=943.045), 0.00362535 s/step
# Meep progress: 943.926/1000.0 = 94.4% done in 2761.1s, 164.0s to go
# on time step 944096 (time=944.096), 0.00380747 s/step
# Meep progress: 945.147/1000.0 = 94.5% done in 2765.1s, 160.5s to go
# on time step 945368 (time=945.368), 0.00314639 s/step
# Meep progress: 946.491/1000.0 = 94.6% done in 2769.1s, 156.5s to go
# on time step 946709 (time=946.709), 0.00298397 s/step
# Meep progress: 947.767/1000.0 = 94.8% done in 2773.1s, 152.8s to go
# on time step 948003 (time=948.003), 0.00309349 s/step
# Meep progress: 949.147/1000.0 = 94.9% done in 2777.1s, 148.8s to go
# on time step 949375 (time=949.375), 0.0029167 s/step
# Meep progress: 950.5210000000001/1000.0 = 95.1% done in 2781.1s, 144.8s to go
# on time step 950747 (time=950.747), 0.00291756 s/step
# Meep progress: 951.885/1000.0 = 95.2% done in 2785.1s, 140.8s to go
# on time step 952108 (time=952.108), 0.00294039 s/step
# Meep progress: 953.258/1000.0 = 95.3% done in 2789.1s, 136.8s to go
# on time step 953485 (time=953.485), 0.00290713 s/step
# Meep progress: 954.6410000000001/1000.0 = 95.5% done in 2793.1s, 132.7s to go
# on time step 954865 (time=954.865), 0.00289982 s/step
# Meep progress: 955.961/1000.0 = 95.6% done in 2797.1s, 128.9s to go
# on time step 956151 (time=956.151), 0.00311274 s/step
# Meep progress: 957.019/1000.0 = 95.7% done in 2801.1s, 125.8s to go
# on time step 957197 (time=957.197), 0.0038249 s/step
# Meep progress: 958.121/1000.0 = 95.8% done in 2805.1s, 122.6s to go
# on time step 958278 (time=958.278), 0.00370124 s/step
# Meep progress: 959.1080000000001/1000.0 = 95.9% done in 2809.1s, 119.8s to go
# on time step 959272 (time=959.272), 0.00402444 s/step
# Meep progress: 960.105/1000.0 = 96.0% done in 2813.1s, 116.9s to go
# on time step 960275 (time=960.275), 0.00399071 s/step
# Meep progress: 961.16/1000.0 = 96.1% done in 2817.1s, 113.8s to go
# on time step 961315 (time=961.315), 0.00384653 s/step
# Meep progress: 962.186/1000.0 = 96.2% done in 2821.1s, 110.9s to go
# on time step 962358 (time=962.358), 0.00383673 s/step
# Meep progress: 963.219/1000.0 = 96.3% done in 2825.1s, 107.9s to go
# on time step 963391 (time=963.391), 0.00387564 s/step
# Meep progress: 964.261/1000.0 = 96.4% done in 2829.1s, 104.9s to go
# on time step 964432 (time=964.432), 0.00384334 s/step
# Meep progress: 965.284/1000.0 = 96.5% done in 2833.1s, 101.9s to go
# on time step 965451 (time=965.451), 0.00392649 s/step
# Meep progress: 966.289/1000.0 = 96.6% done in 2837.1s, 99.0s to go
# on time step 966458 (time=966.458), 0.00397287 s/step
# Meep progress: 967.3190000000001/1000.0 = 96.7% done in 2841.1s, 96.0s to go
# on time step 967484 (time=967.484), 0.00390152 s/step
# Meep progress: 968.311/1000.0 = 96.8% done in 2845.1s, 93.1s to go
# on time step 968477 (time=968.477), 0.00402837 s/step
# Meep progress: 969.337/1000.0 = 96.9% done in 2849.1s, 90.1s to go
# on time step 969515 (time=969.515), 0.00385378 s/step
# Meep progress: 970.351/1000.0 = 97.0% done in 2853.1s, 87.2s to go
# on time step 970520 (time=970.52), 0.00398399 s/step
# Meep progress: 971.373/1000.0 = 97.1% done in 2857.1s, 84.2s to go
# on time step 971564 (time=971.564), 0.00383623 s/step
# Meep progress: 972.441/1000.0 = 97.2% done in 2861.1s, 81.1s to go
# on time step 972604 (time=972.604), 0.00384663 s/step
# Meep progress: 973.428/1000.0 = 97.3% done in 2865.1s, 78.2s to go
# on time step 973599 (time=973.599), 0.00402155 s/step
# Meep progress: 974.461/1000.0 = 97.4% done in 2869.1s, 75.2s to go
# on time step 974633 (time=974.633), 0.00387064 s/step
# Meep progress: 975.493/1000.0 = 97.5% done in 2873.1s, 72.2s to go
# on time step 975677 (time=975.677), 0.0038338 s/step
# Meep progress: 976.583/1000.0 = 97.7% done in 2877.1s, 69.0s to go
# on time step 976772 (time=976.772), 0.00365549 s/step
# Meep progress: 977.7040000000001/1000.0 = 97.8% done in 2881.1s, 65.7s to go
# on time step 977890 (time=977.89), 0.00357866 s/step
# Meep progress: 978.835/1000.0 = 97.9% done in 2885.1s, 62.4s to go
# on time step 979021 (time=979.021), 0.00353699 s/step
# Meep progress: 979.8670000000001/1000.0 = 98.0% done in 2889.1s, 59.4s to go
# on time step 980037 (time=980.037), 0.00394112 s/step
# Meep progress: 980.8480000000001/1000.0 = 98.1% done in 2893.1s, 56.5s to go
# on time step 981013 (time=981.013), 0.00409922 s/step
# Meep progress: 981.857/1000.0 = 98.2% done in 2897.1s, 53.5s to go
# on time step 982041 (time=982.041), 0.00389396 s/step
# Meep progress: 982.863/1000.0 = 98.3% done in 2901.1s, 50.6s to go
# on time step 983038 (time=983.038), 0.00401552 s/step
# Meep progress: 984.041/1000.0 = 98.4% done in 2905.1s, 47.1s to go
# on time step 984262 (time=984.262), 0.00326833 s/step
# Meep progress: 985.294/1000.0 = 98.5% done in 2909.1s, 43.4s to go
# on time step 985533 (time=985.533), 0.00314738 s/step
# Meep progress: 986.486/1000.0 = 98.6% done in 2913.2s, 39.9s to go
# on time step 986677 (time=986.677), 0.0034982 s/step
# Meep progress: 987.636/1000.0 = 98.8% done in 2917.2s, 36.5s to go
# on time step 987825 (time=987.825), 0.0034851 s/step
# Meep progress: 988.841/1000.0 = 98.9% done in 2921.2s, 33.0s to go
# on time step 989059 (time=989.059), 0.00324348 s/step
# Meep progress: 990.099/1000.0 = 99.0% done in 2925.2s, 29.3s to go
# on time step 990313 (time=990.313), 0.00319051 s/step
# Meep progress: 991.3340000000001/1000.0 = 99.1% done in 2929.2s, 25.6s to go
# on time step 991576 (time=991.576), 0.0031685 s/step
# Meep progress: 992.562/1000.0 = 99.3% done in 2933.2s, 22.0s to go
# on time step 992763 (time=992.763), 0.0033699 s/step
# Meep progress: 993.893/1000.0 = 99.4% done in 2937.2s, 18.0s to go
# on time step 994130 (time=994.13), 0.00292615 s/step
# Meep progress: 995.2090000000001/1000.0 = 99.5% done in 2941.2s, 14.2s to go
# on time step 995418 (time=995.418), 0.00310624 s/step
# Meep progress: 996.566/1000.0 = 99.7% done in 2945.2s, 10.1s to go
# on time step 996780 (time=996.78), 0.00293735 s/step
# Meep progress: 997.917/1000.0 = 99.8% done in 2949.2s, 6.2s to go
# on time step 998135 (time=998.135), 0.00295319 s/step
# Meep progress: 999.192/1000.0 = 99.9% done in 2953.2s, 2.4s to go
# on time step 999441 (time=999.441), 0.00306519 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 1000.0 (1000000 timesteps)
#      block, center = (-0.61,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
print(len(ez_data_cen))

print(1 + int(round(t_xx/dt)))
# Out:
# 76923
# 41

# %%
ez_data_cen = np.array(ez_data_cen)
ez_data_up = np.array(ez_data_up)
ez_data_down = np.array(ez_data_down)

#plt.subplot_adjust(hspace = .35)
plt.figure(dpi = 300)
start = round(len(ez_data_cen) / t *1)

for i in range(start,round(len(ez_data_cen) / 75),1):
    plt.subplot(3,1,1)
    plt.plot(i,ez_data_up[i],'k.')
    plt.subplot(3,1,2)
    plt.plot(i,ez_data_cen[i],'k.')
    plt.subplot(3,1,3)
    plt.plot(i,ez_data_down[i],'k.')
    if i ==  (len(ez_data_cen)-1):
        plt.subplot(3,1,1)
        plt.title('upper point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_up[i],'b .')
        plt.subplot(3,1,2)
        plt.title('center point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_cen[i],'b .')
        plt.subplot(3,1,3)
        plt.title('downer point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_down[i],'b .')

# %%
# index1 and index2 . When we find the target's Electric field amplitude, we want to know where is amplitude value in array. So we set up index variable before running simulation.
index1_up = 0
index1_cen = 0
index1_down = 0

index2_up = 0
index2_cen = 0
index2_down = 0
# Period_max , period_next_mat . I set up those variables because I plan to use variables to store max amplitude value in a peiod in the following simulation. 
period_max_up = 0
period_max_cen = 0
period_max_down = 0
period_next_max_up = 0
period_next_max_cen = 0
period_next_max_down = 0

# Intial_index , end_index. ==>  "for loop" index
initial_index = round(len(ez_data_cen) / t * 200 )
print(initial_index)
end_index = len(ez_data_cen) - 2*( 1 +int(round(t_xx/dt))) 
print(end_index)
# Out:
# 15385
# 76841

# %%
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_up[j])
        period_next.append(ez_data_up[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if ((np.abs(period_max - period_next_max) / np.abs(min([period_max , period_next_max])) < 10**(-3))) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_up = np.where(ez_data_up == period_max)
        index1_up = index1_up[0]
        print(index1_up , '--- upper point index1')
        index2_up = np.where(ez_data_up == period_next_max)
        index2_up = index2_up[0]
        print(index2_up , '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('upper point 到達誤差範圍內的所需 meep time unit' , index2_up[0] / len(ez_data_up) * t , '\n')
        print('-----------------------------------------------------')
        break

        
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_cen[j])
        period_next.append(ez_data_cen[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if ((np.abs(period_max - period_next_max) / np.abs(min([period_max , period_next_max])) < 10**(-3))) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_cen = np.where(ez_data_cen == period_max)
        index1_cen = index1_cen[0]
        print(index1_cen, '--- upper point index1')
        index2_cen = np.where(ez_data_cen == period_next_max)
        index2_cen = index2_cen[0]
        print(index2_cen, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t')
        print('center point 到達誤差範圍內的所需 meep time unit' , index2_up[0] / len(ez_data_cen) * t , '\n')
        print('-----------------------------------------------------')
        break
        
    
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_down[j])
        period_next.append(ez_data_down[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if ((np.abs(period_max - period_next_max) / np.abs(min([period_max , period_next_max])) < 10**(-3))) :
        print(period_max, '-------- down point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- down point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_down = np.where(ez_data_down == period_max)
        index1_down = index1_down[0]
        print(index1_down, '--- down point index1')
        index2_down = np.where(ez_data_down == period_next_max)
        index2_down = index2_down[0]
        print(index2_down, '--- down point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('down point 到達誤差範圍內的所需 meep time unit' , index2_down[0] / len(ez_data_down) * t , '\n')
        print('-----------------------------------------------------')
        break

index1_max = index1_up[0]
index2_max = index2_up[0]
if index1_cen[0] > index1_max :
    index1_max = index1_cen[0]
elif index1_down[0] > index1_max :
    index1_max = index1_down[0]
print(index1_max)

if index2_cen[0] > index2_max :
    index2_max = index2_cen[0]
elif index2_down[0] > index2_max :
    index2_max = index2_down[0]
print(index2_max)
# Out:
# (0.13203173573886748+0j) -------- upper point one period 內最大振福
# (0.13207548929411575+0j) ------- upper point one next_period 內最大振福
# (-4.3753555248271514e-05+0j) ----- 振幅誤差
# [15398] --- upper point index1
# [15439] --- upper point index2
# (0.13203173573886748+0j) 	 (0.13207548929411575+0j) 	 (-4.3753555248271514e-05+0j)
# upper point 到達誤差範圍內的所需 meep time unit 100.35360035360036
#
# -----------------------------------------------------
# (0.04741465992552904+0j) -------- upper point one period 內最大振福
# (0.04742829078503072+0j) ------- upper point one next_period 內最大振福
# (-1.363085950167875e-05+0j) ----- 振幅誤差
# [15429] --- upper point index1
# [15470] --- upper point index2
# (0.04741465992552904+0j) 	 (0.04742829078503072+0j) 	 (-1.363085950167875e-05+0j)
# center point 到達誤差範圍內的所需 meep time unit 100.35360035360036
#
# -----------------------------------------------------
# (0.1330010605388811+0j) -------- down point one period 內最大振福
# (0.13291353434978148+0j) ------- down point one next_period 內最大振福
# (8.752618909962928e-05+0j) ----- 振幅誤差
# [15562] --- down point index1
# [15603] --- down point index2
# (0.1330010605388811+0j) 	 (0.13291353434978148+0j) 	 (8.752618909962928e-05+0j)
# down point 到達誤差範圍內的所需 meep time unit 101.41960141960142
#
# -----------------------------------------------------
# 15429
# 15470

# %%
plt.figure(dpi = 150)
plt.title('center point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_up[index1_max]
for i in range(index1_max , index2_max) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_up[i] , 'b.')
    if max_value < ez_data_up[i] :
        max_value = ez_data_up[i]

print(max_value)
# Out:
# (0.13207548929411575+0j)

# %%
plt.figure(dpi = 150)
plt.title('center point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_cen[index1_max]
for i in range(index1_max , index2_max) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_cen[i] , 'b.')
    if max_value < ez_data_cen[i] :
        max_value = ez_data_cen[i]

print(max_value)
# Out:
# (0.04741465992552904+0j)

# %%
plt.figure(dpi = 150)
plt.title('downner point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
for i in range(index1_max , index2_max) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_down[i] , 'b.')
    
max_value = ez_data_down[index1_max]
for i in range(index1_max , index2_max) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_down[i] , 'b.')
    if max_value < ez_data_down[i] :
        max_value = ez_data_down[i]

print(max_value)
# Out:
# (0.13301605930528393+0j)

# %% [markdown]
# # Simulation for Phase changed value
# Next step, we want to know how value changing by cell structure .
# We set two obserbed points which locate at "source" position and the other locate at (x = above cell height 2 nanometer ,  y = cell center place )

# %%
sim.reset_meep()
resolution = 500  # pixels/μm

dpml = 1.0  # PML thickness
dsub = 0.5  # substrate thickness
dcaa = 0.06  # air rigion for alpha structure
# alpha structure is that one period = 200nm，sigle cell width = 80nm locate at center
dcab = 0.025 # air rigion for beta structure 
# beta structure is that one period = 200nm，sigle cell width = 150nm locate at center
gp = 0.2  # grating periodicity
gh = 0.3  # grating height
gwa = 0.08 # alpha grating cell width
gwb = 0.15 # beta grating cell width

num_cells = 3 # number of grating unit cells

# air region thickness adjacent to grating
dair = 1 

wvl = 0.532  # center wavelength
fcen = 1 / wvl  # center frequency

glass = mp.Medium(index= 2.6678)

pml_layers = [mp.PML(thickness=dpml, direction = mp.X )]

symmetries = [mp.Mirror(mp.Y)]

sx = dpml + dsub + gh + dair + dpml
sy = num_cells*gp
#sy = ((dcaa + gwa + dcaa)*2 + (dcab + gwb + dcab))*num_cells
cell_size = mp.Vector3(sx, sy)

sources = [
    mp.Source(
        mp.ContinuousSource(frequency = fcen), # frequemcy = 2原因是 meep 的 C=1，所以 1/? = 0.5 um，?即是2
        component = mp.Ez,
        center = mp.Vector3(-0.5 * sx + dpml ),
        size = mp.Vector3(y = sy),
    )
]

geometry = [
    mp.Block(
        material=glass,
        size=mp.Vector3(dsub, mp.inf, mp.inf),
        center=mp.Vector3(-0.5 * sx + dpml + 0.04 + dsub/2),
    )
]

# %%
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp/2 + (j * 3 * gp),
                #-0.5 * sy + gp/2,
            ),
        )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwa, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + gp + gp/2,
            ),
        )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + 2*gp + gp/2  + (j * 3 * gp),
                #0.5 * sy - gp/2,
            ),
        )
    )

    
k_point = mp.Vector3()  # Gamma 點表示週期邊界條件
k_points = [k_point]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
    symmetries=symmetries,
    k_point = mp.Vector3(),
)


# %matplotlib inline
plt.figure(dpi = 125)
sim.plot2D()
plt.show()

# %%
t_xx = (.532) # Air 光速跑完 波長 532 nm 入射光 所需的 meep unit time
dt = (t_xx / 40) # cut 40 sections in a period time
t = 1000 # Total simulation time

x_obs = -0.5 * sx + dpml + dsub + gh + 0.002 # Set up a x coordinate of observed point
x_obs_source = -0.5 * sx + dpml + dsub + gh + 0.002 # Set up a x coordinate of observed point
# The meaning of down , cen , up are the cordinate in each cell structure. (Reference stucture diagram just show above)
y_obs_down = -0.5 * sy + gp/2
y_obs_cen = -0.5 * sy + 3*gp/2
y_obs_up = 0.5 * sy - gp/2

print(int((t_xx)/dt))

# %%
# 儲存場量數值的列表，定義為擁有 10 列的空二維陣列

ez_data_cen = []
ez_data_up = []
ez_data_down = []
ez_data_source = []

###
def get_slice(sim):
    ez_data_cen.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_cen) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_up.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_up) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_down.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_down) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_source.append(sim.get_array(center = mp.Vector3(x_obs_source, 0) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))

sim.run(mp.at_every(dt , get_slice) , until = t)

plt.figure(dpi = 100)
sim.plot2D(fields=mp.Ez)
plt.show()

# %%
print(len(ez_data_cen))

print(1 + int(round(t_xx/dt)))

# %%
ez_data_cen = np.array(ez_data_cen)
ez_data_up = np.array(ez_data_up)
ez_data_down = np.array(ez_data_down)
ez_data_soruce = np.array(ez_data_source)


#plt.subplot_adjust(hspace = .35)
plt.figure(dpi = 300)
start = round(len(ez_data_cen) / t *1)

for i in range(start,round(len(ez_data_cen) / 75),1):
    plt.subplot(3,1,1)
    plt.plot(i,ez_data_up[i],'k.')
    plt.subplot(3,1,2)
    plt.plot(i,ez_data_cen[i],'k.')
    plt.subplot(3,1,3)
    plt.plot(i,ez_data_down[i],'k.')
    if i ==  (len(ez_data_cen)-1):
        plt.subplot(3,1,1)
        plt.title('upper point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_up[i],'b .')
        plt.subplot(3,1,2)
        plt.title('center point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_cen[i],'b .')
        plt.subplot(3,1,3)
        plt.title('downer point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_down[i],'b .')

# %%
# index1 and index2 . When we find the target's Electric field amplitude, we want to know where is amplitude value in array. So we set up index variable before running simulation.
index1_up = 0
index1_cen = 0
index1_down = 0
index1_source = 0

index2_up = 0
index2_cen = 0
index2_down = 0
index2_source = 0

# Period_max , period_next_mat . I set up those variables because I plan to use variables to store max amplitude value in a peiod in the following simulation. 
period_max_up = 0
period_max_cen = 0
period_max_down = 0
period_source = 0
period_next_max_up = 0
period_next_max_cen = 0
period_next_max_down = 0
period_next_source = 0

# Intial_index , end_index. ==>  "for loop" index
initial_index = round(len(ez_data_cen) / t * 200 )
print(initial_index)
end_index = len(ez_data_cen) - 2*( 1 +int(round(t_xx/dt))) 
print(end_index)

# %%
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_up[j])
        period_next.append(ez_data_up[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_up = np.where(ez_data_up == period_max)
        print(index1, '--- upper point index1')
        index2_up = np.where(ez_data_up == period_next_max)
        print(index2, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('upper point 到達誤差範圍內的所需 meep time unit' , 17690 / len(ez_data_up) * 500 , '\n')
        print('-----------------------------------------------------')
        break

        
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_cen[j])
        period_next.append(ez_data_cen[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_cen = np.where(ez_data_cen == period_max)
        print(index1, '--- upper point index1')
        index2_cen = np.where(ez_data_cen == period_next_max)
        print(index2, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t')
        print('center point 到達誤差範圍內的所需 meep time unit' , 53826 / len(ez_data_cen) * 500 , '\n')
        print('-----------------------------------------------------')
        break
        
    
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_down[j])
        period_next.append(ez_data_down[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- down point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- down point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_down = np.where(ez_data_down == period_max)
        print(index1, '--- down point index1')
        index2_down = np.where(ez_data_down == period_next_max)
        print(index2, '--- down point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('down point 到達誤差範圍內的所需 meep time unit' , 40267 / len(ez_data_down) * 500 , '\n')
        print('-----------------------------------------------------')
        break


for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_down[j])
        period_next.append(ez_data_down[j + (1 + round(t_xx/dt))])
    ### period_source = max(period)
    ### period_next_source = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- down point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '------- down point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '----- 振幅誤差')
        index1_source = np.where(ez_data_down == period_max)
        print(index1_source , '--- down point index1')
        index2_source = np.where(ez_data_down == period_next_max)
        print(index2_source , '--- down point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' )
        print('down point 到達誤差範圍內的所需 meep time unit' , 40267 / len(ez_data_down) * 500 , '\n')
        print('-----------------------------------------------------')
        break

# %%
plt.figure(dpi = 150)
plt.title('Upper point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_up[73320]
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_up[i] , 'b.')
    if max_value < ez_data_up[i] :
        max_value = ez_data_up[i]

print(max_value)

# %%
plt.figure(dpi = 150)
plt.title('center point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_cen[73320]
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_cen[i] , 'b.')
    if max_value < ez_data_cen[i] :
        max_value = ez_data_cen[i]

print(max_value)

# %%
plt.figure(dpi = 150)
plt.title('downner point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_down[i] , 'b.')
