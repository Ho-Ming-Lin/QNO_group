# %%
import meep as mp
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
resolution = 500  # pixels/μm

dpml = 1.0  # PML thickness
dsub = 0.5  # substrate thickness
dcaa = 0.06  # air rigion for alpha structure
# alpha structure is that one period = 200nm，sigle cell width = 80nm locate at center
dcab = 0.025 # air rigion for beta structure 
# beta structure is that one period = 200nm，sigle cell width = 150nm locate at center
gp = 0.2  # grating periodicity
gh = 0.6  # grating height
gwa = 0.08 # alpha grating cell width
gwb = 0.15 # beta grating cell width

num_cells = 9  # number of grating unit cells

# air region thickness adjacent to grating
dair = 14 

wvl = 0.532  # center wavelength
fcen = 1 / wvl  # center frequency


glass = mp.Medium(index= 2.6678)

pml_layers = [mp.PML(thickness=dpml, direction = mp.X )]

#symmetries = [mp.Mirror(mp.Y)]

sx = dpml + dsub + gh + dair + dpml
sy = gp*num_cells
cell_size = mp.Vector3(sx, sy)

sources = [
    mp.Source(
        mp.ContinuousSource(frequency = 2), # frequemcy = 2原因是 meep 的 C=1，所以 1/? = 0.5 um，?即是2
        component = mp.Ez,
        center = mp.Vector3(-0.5 * sx + dpml ),
        size = mp.Vector3(y=sy),
    )
]

geometry = [
    mp.Block(
        material=glass,
        size=mp.Vector3(dsub, mp.inf, mp.inf),
        center=mp.Vector3(-0.5 * sx + dpml + dsub/2),
    )
]

# %%
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwa, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp/2 + (j * 3 * gp),
                #-0.5 * sy + gp/2 ,
            ),
        )
    )

for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwa, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + gp/2 + gp ,
            ),
        )
    )

for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + 2*gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + gp/2 + 2*gp ,
            ),
        )
    )

# %%
# 設定週期邊界條件
k_point = mp.Vector3()  # Gamma 點表示週期邊界條件
k_points = [k_point]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
    k_point = mp.Vector3(),
)

# %matplotlib inline
plt.figure(dpi = 125)
sim.plot2D()
plt.show()
# Out:
#      block, center = (-7.3,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.8,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.6,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,2.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,2.8,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,3.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      ...(+ 18 objects not shown)...

# %%
sim.run(until = 100)
plt.figure(dpi = 100)
sim.plot2D(fields=mp.Ez)
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000785828 s
# Working in 2D dimensions.
# Computational cell is 17.1 x 1.8 x 0 with resolution 500
#      block, center = (-7.3,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.8,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.6,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,2.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,2.8,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,3.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      ...(+ 18 objects not shown)...
# time for set_epsilon = 7.97984 s
# -----------
# Meep progress: 0.11900000000000001/100.0 = 0.1% done in 4.0s, 3373.2s to go
# on time step 119 (time=0.119), 0.0337715 s/step
# Meep progress: 0.241/100.0 = 0.2% done in 8.0s, 3330.0s to go
# on time step 241 (time=0.241), 0.032993 s/step
# Meep progress: 0.365/100.0 = 0.4% done in 12.1s, 3289.8s to go
# on time step 365 (time=0.365), 0.032313 s/step
# Meep progress: 0.489/100.0 = 0.5% done in 16.1s, 3270.1s to go
# on time step 489 (time=0.489), 0.0323958 s/step
# Meep progress: 0.614/100.0 = 0.6% done in 20.1s, 3253.1s to go
# on time step 614 (time=0.614), 0.0322192 s/step
# Meep progress: 0.739/100.0 = 0.7% done in 24.1s, 3238.2s to go
# on time step 739 (time=0.739), 0.0320859 s/step
# Meep progress: 0.866/100.0 = 0.9% done in 28.1s, 3220.1s to go
# on time step 866 (time=0.866), 0.0316607 s/step
# Meep progress: 0.991/100.0 = 1.0% done in 32.1s, 3211.1s to go
# on time step 991 (time=0.991), 0.0320839 s/step
# Meep progress: 1.117/100.0 = 1.1% done in 36.2s, 3202.0s to go
# on time step 1117 (time=1.117), 0.0319787 s/step
# Meep progress: 1.24/100.0 = 1.2% done in 40.2s, 3199.8s to go
# on time step 1240 (time=1.24), 0.0325567 s/step
# Meep progress: 1.365/100.0 = 1.4% done in 44.2s, 3192.5s to go
# on time step 1365 (time=1.365), 0.0320375 s/step
# Meep progress: 1.488/100.0 = 1.5% done in 48.2s, 3190.8s to go
# on time step 1488 (time=1.488), 0.0326379 s/step
# Meep progress: 1.612/100.0 = 1.6% done in 52.2s, 3185.8s to go
# on time step 1612 (time=1.612), 0.0322636 s/step
# Meep progress: 1.736/100.0 = 1.7% done in 56.2s, 3181.8s to go
# on time step 1736 (time=1.736), 0.0323751 s/step
# Meep progress: 1.859/100.0 = 1.9% done in 60.2s, 3179.4s to go
# on time step 1859 (time=1.859), 0.0326165 s/step
# Meep progress: 1.983/100.0 = 2.0% done in 64.3s, 3176.0s to go
# on time step 1983 (time=1.983), 0.0324994 s/step
# Meep progress: 2.106/100.0 = 2.1% done in 68.3s, 3173.7s to go
# on time step 2106 (time=2.106), 0.0326856 s/step
# Meep progress: 2.23/100.0 = 2.2% done in 72.3s, 3169.8s to go
# on time step 2230 (time=2.23), 0.0324416 s/step
# Meep progress: 2.353/100.0 = 2.4% done in 76.3s, 3167.3s to go
# on time step 2353 (time=2.353), 0.0326996 s/step
# Meep progress: 2.476/100.0 = 2.5% done in 80.3s, 3164.1s to go
# on time step 2476 (time=2.476), 0.0325989 s/step
# Meep progress: 2.603/100.0 = 2.6% done in 84.4s, 3156.1s to go
# on time step 2603 (time=2.603), 0.03164 s/step
# Meep progress: 2.729/100.0 = 2.7% done in 88.4s, 3149.1s to go
# on time step 2729 (time=2.729), 0.0317523 s/step
# Meep progress: 2.856/100.0 = 2.9% done in 92.4s, 3141.4s to go
# on time step 2856 (time=2.856), 0.0315183 s/step
# Meep progress: 2.984/100.0 = 3.0% done in 96.4s, 3133.4s to go
# on time step 2984 (time=2.984), 0.0314149 s/step
# Meep progress: 3.112/100.0 = 3.1% done in 100.4s, 3125.9s to go
# on time step 3112 (time=3.112), 0.0314459 s/step
# Meep progress: 3.233/100.0 = 3.2% done in 104.4s, 3125.5s to go
# on time step 3233 (time=3.233), 0.033223 s/step
# Meep progress: 3.357/100.0 = 3.4% done in 108.4s, 3121.6s to go
# on time step 3357 (time=3.357), 0.0323381 s/step
# Meep progress: 3.479/100.0 = 3.5% done in 112.5s, 3120.0s to go
# on time step 3479 (time=3.479), 0.0329838 s/step
# Meep progress: 3.601/100.0 = 3.6% done in 116.5s, 3117.6s to go
# on time step 3601 (time=3.601), 0.0327971 s/step
# Meep progress: 3.719/100.0 = 3.7% done in 120.5s, 3118.6s to go
# on time step 3719 (time=3.719), 0.0339153 s/step
# Meep progress: 3.84/100.0 = 3.8% done in 124.5s, 3116.9s to go
# on time step 3840 (time=3.84), 0.0331144 s/step
# Meep progress: 3.9570000000000003/100.0 = 4.0% done in 128.5s, 3118.9s to go
# on time step 3957 (time=3.957), 0.0344615 s/step
# Meep progress: 4.074/100.0 = 4.1% done in 132.5s, 3120.0s to go
# on time step 4074 (time=4.074), 0.0342247 s/step
# Meep progress: 4.187/100.0 = 4.2% done in 136.5s, 3124.1s to go
# on time step 4187 (time=4.187), 0.0355382 s/step
# Meep progress: 4.304/100.0 = 4.3% done in 140.5s, 3124.9s to go
# on time step 4304 (time=4.304), 0.0343919 s/step
# Meep progress: 4.421/100.0 = 4.4% done in 144.6s, 3125.3s to go
# on time step 4421 (time=4.421), 0.0343183 s/step
# Meep progress: 4.54/100.0 = 4.5% done in 148.6s, 3124.2s to go
# on time step 4540 (time=4.54), 0.0337901 s/step
# Meep progress: 4.659/100.0 = 4.7% done in 152.6s, 3123.0s to go
# on time step 4659 (time=4.659), 0.0338382 s/step
# Meep progress: 4.776/100.0 = 4.8% done in 156.6s, 3122.7s to go
# on time step 4776 (time=4.776), 0.0342443 s/step
# Meep progress: 4.896/100.0 = 4.9% done in 160.6s, 3120.0s to go
# on time step 4896 (time=4.896), 0.0333525 s/step
# Meep progress: 5.014/100.0 = 5.0% done in 164.6s, 3118.9s to go
# on time step 5014 (time=5.014), 0.0340094 s/step
# Meep progress: 5.132/100.0 = 5.1% done in 168.6s, 3117.4s to go
# on time step 5132 (time=5.132), 0.0339134 s/step
# Meep progress: 5.252/100.0 = 5.3% done in 172.7s, 3114.9s to go
# on time step 5252 (time=5.252), 0.0335331 s/step
# Meep progress: 5.369/100.0 = 5.4% done in 176.7s, 3114.3s to go
# on time step 5369 (time=5.369), 0.0344484 s/step
# Meep progress: 5.487/100.0 = 5.5% done in 180.7s, 3112.8s to go
# on time step 5487 (time=5.487), 0.0340822 s/step
# Meep progress: 5.605/100.0 = 5.6% done in 184.7s, 3111.4s to go
# on time step 5605 (time=5.605), 0.0341752 s/step
# Meep progress: 5.723/100.0 = 5.7% done in 188.8s, 3109.7s to go
# on time step 5723 (time=5.723), 0.0341113 s/step
# Meep progress: 5.841/100.0 = 5.8% done in 192.8s, 3107.7s to go
# on time step 5841 (time=5.841), 0.0339442 s/step
# Meep progress: 5.96/100.0 = 6.0% done in 196.8s, 3105.2s to go
# on time step 5960 (time=5.96), 0.0337474 s/step
# Meep progress: 6.079/100.0 = 6.1% done in 200.8s, 3102.3s to go
# on time step 6079 (time=6.079), 0.0336192 s/step
# Meep progress: 6.198/100.0 = 6.2% done in 204.8s, 3099.8s to go
# on time step 6198 (time=6.198), 0.0337978 s/step
# Meep progress: 6.3180000000000005/100.0 = 6.3% done in 208.8s, 3096.7s to go
# on time step 6318 (time=6.318), 0.0335446 s/step
# Meep progress: 6.437/100.0 = 6.4% done in 212.9s, 3094.0s to go
# on time step 6437 (time=6.437), 0.0337614 s/step
# Meep progress: 6.557/100.0 = 6.6% done in 216.9s, 3091.0s to go
# on time step 6557 (time=6.557), 0.0336051 s/step
# Meep progress: 6.678/100.0 = 6.7% done in 220.9s, 3087.2s to go
# on time step 6678 (time=6.678), 0.0332151 s/step
# Meep progress: 6.796/100.0 = 6.8% done in 224.9s, 3084.9s to go
# on time step 6796 (time=6.796), 0.0340528 s/step
# Meep progress: 6.916/100.0 = 6.9% done in 229.0s, 3081.5s to go
# on time step 6916 (time=6.916), 0.0334677 s/step
# Meep progress: 7.035/100.0 = 7.0% done in 233.0s, 3078.4s to go
# on time step 7035 (time=7.035), 0.0336413 s/step
# Meep progress: 7.1530000000000005/100.0 = 7.2% done in 237.0s, 3076.0s to go
# on time step 7153 (time=7.153), 0.0340902 s/step
# Meep progress: 7.272/100.0 = 7.3% done in 241.0s, 3073.2s to go
# on time step 7272 (time=7.272), 0.0338764 s/step
# Meep progress: 7.388/100.0 = 7.4% done in 245.0s, 3071.7s to go
# on time step 7388 (time=7.388), 0.0347068 s/step
# Meep progress: 7.507000000000001/100.0 = 7.5% done in 249.1s, 3068.7s to go
# on time step 7507 (time=7.507), 0.0338489 s/step
# Meep progress: 7.627/100.0 = 7.6% done in 253.1s, 3065.3s to go
# on time step 7627 (time=7.627), 0.0335415 s/step
# Meep progress: 7.744/100.0 = 7.7% done in 257.1s, 3063.0s to go
# on time step 7744 (time=7.744), 0.034315 s/step
# Meep progress: 7.861/100.0 = 7.9% done in 261.1s, 3060.7s to go
# on time step 7861 (time=7.861), 0.0343646 s/step
# Meep progress: 7.98/100.0 = 8.0% done in 265.1s, 3057.5s to go
# on time step 7980 (time=7.98), 0.0337355 s/step
# Meep progress: 8.096/100.0 = 8.1% done in 269.1s, 3055.3s to go
# on time step 8096 (time=8.096), 0.0345124 s/step
# Meep progress: 8.213000000000001/100.0 = 8.2% done in 273.1s, 3052.7s to go
# on time step 8213 (time=8.213), 0.0342059 s/step
# Meep progress: 8.333/100.0 = 8.3% done in 277.2s, 3048.9s to go
# on time step 8333 (time=8.333), 0.0334086 s/step
# Meep progress: 8.449/100.0 = 8.4% done in 281.2s, 3046.9s to go
# on time step 8449 (time=8.449), 0.034752 s/step
# Meep progress: 8.565/100.0 = 8.6% done in 285.2s, 3044.8s to go
# on time step 8565 (time=8.565), 0.0346794 s/step
# Meep progress: 8.682/100.0 = 8.7% done in 289.2s, 3042.2s to go
# on time step 8682 (time=8.682), 0.0343751 s/step
# Meep progress: 8.797/100.0 = 8.8% done in 293.2s, 3040.2s to go
# on time step 8797 (time=8.797), 0.0348329 s/step
# Meep progress: 8.913/100.0 = 8.9% done in 297.3s, 3037.8s to go
# on time step 8913 (time=8.913), 0.0345967 s/step
# Meep progress: 9.031/100.0 = 9.0% done in 301.3s, 3034.9s to go
# on time step 9031 (time=9.031), 0.0341507 s/step
# Meep progress: 9.149000000000001/100.0 = 9.1% done in 305.3s, 3031.6s to go
# on time step 9149 (time=9.149), 0.0339139 s/step
# Meep progress: 9.264/100.0 = 9.3% done in 309.3s, 3029.4s to go
# on time step 9264 (time=9.264), 0.0348218 s/step
# Meep progress: 9.382/100.0 = 9.4% done in 313.3s, 3026.1s to go
# on time step 9382 (time=9.382), 0.0339242 s/step
# Meep progress: 9.499/100.0 = 9.5% done in 317.3s, 3023.2s to go
# on time step 9499 (time=9.499), 0.0343016 s/step
# Meep progress: 9.615/100.0 = 9.6% done in 321.3s, 3020.8s to go
# on time step 9615 (time=9.615), 0.0348008 s/step
# Meep progress: 9.734/100.0 = 9.7% done in 325.4s, 3017.3s to go
# on time step 9734 (time=9.734), 0.0338459 s/step
# Meep progress: 9.848/100.0 = 9.8% done in 329.4s, 3015.5s to go
# on time step 9848 (time=9.848), 0.0353186 s/step
# Meep progress: 9.962/100.0 = 10.0% done in 333.4s, 3013.7s to go
# on time step 9962 (time=9.962), 0.0353769 s/step
# Meep progress: 10.076/100.0 = 10.1% done in 337.5s, 3011.7s to go
# on time step 10076 (time=10.076), 0.0353052 s/step
# Meep progress: 10.192/100.0 = 10.2% done in 341.5s, 3008.9s to go
# on time step 10192 (time=10.192), 0.0345441 s/step
# Meep progress: 10.306000000000001/100.0 = 10.3% done in 345.5s, 3006.7s to go
# on time step 10306 (time=10.306), 0.0350983 s/step
# Meep progress: 10.425/100.0 = 10.4% done in 349.5s, 3003.0s to go
# on time step 10425 (time=10.425), 0.0338339 s/step
# Meep progress: 10.541/100.0 = 10.5% done in 353.5s, 3000.4s to go
# on time step 10541 (time=10.541), 0.0347701 s/step
# Meep progress: 10.661/100.0 = 10.7% done in 357.5s, 2996.1s to go
# on time step 10661 (time=10.661), 0.0333395 s/step
# Meep progress: 10.783/100.0 = 10.8% done in 361.6s, 2991.6s to go
# on time step 10783 (time=10.783), 0.0330646 s/step
# Meep progress: 10.902000000000001/100.0 = 10.9% done in 365.6s, 2987.7s to go
# on time step 10902 (time=10.902), 0.033649 s/step
# Meep progress: 11.021/100.0 = 11.0% done in 369.6s, 2983.9s to go
# on time step 11021 (time=11.021), 0.0337435 s/step
# Meep progress: 11.139/100.0 = 11.1% done in 373.6s, 2980.6s to go
# on time step 11139 (time=11.139), 0.0341762 s/step
# Meep progress: 11.257/100.0 = 11.3% done in 377.6s, 2977.1s to go
# on time step 11257 (time=11.257), 0.0340376 s/step
# Meep progress: 11.372/100.0 = 11.4% done in 381.6s, 2974.3s to go
# on time step 11372 (time=11.372), 0.0347838 s/step
# Meep progress: 11.491/100.0 = 11.5% done in 385.7s, 2970.6s to go
# on time step 11491 (time=11.491), 0.0338236 s/step
# Meep progress: 11.608/100.0 = 11.6% done in 389.7s, 2967.3s to go
# on time step 11608 (time=11.608), 0.0342577 s/step
# Meep progress: 11.726/100.0 = 11.7% done in 393.7s, 2963.7s to go
# on time step 11726 (time=11.726), 0.0339643 s/step
# Meep progress: 11.845/100.0 = 11.8% done in 397.7s, 2959.8s to go
# on time step 11845 (time=11.845), 0.033665 s/step
# Meep progress: 11.964/100.0 = 12.0% done in 401.7s, 2956.0s to go
# on time step 11964 (time=11.964), 0.0337803 s/step
# Meep progress: 12.083/100.0 = 12.1% done in 405.7s, 2952.2s to go
# on time step 12083 (time=12.083), 0.0338095 s/step
# Meep progress: 12.202/100.0 = 12.2% done in 409.7s, 2948.3s to go
# on time step 12202 (time=12.202), 0.0337241 s/step
# Meep progress: 12.316/100.0 = 12.3% done in 413.8s, 2945.8s to go
# on time step 12316 (time=12.316), 0.0351609 s/step
# Meep progress: 12.437/100.0 = 12.4% done in 417.8s, 2941.4s to go
# on time step 12437 (time=12.437), 0.0332936 s/step
# Meep progress: 12.556000000000001/100.0 = 12.6% done in 421.8s, 2937.7s to go
# on time step 12556 (time=12.556), 0.0338857 s/step
# Meep progress: 12.676/100.0 = 12.7% done in 425.9s, 2933.7s to go
# on time step 12676 (time=12.676), 0.0336026 s/step
# Meep progress: 12.799/100.0 = 12.8% done in 429.9s, 2928.8s to go
# on time step 12799 (time=12.799), 0.0327764 s/step
# Meep progress: 12.923/100.0 = 12.9% done in 433.9s, 2923.8s to go
# on time step 12923 (time=12.923), 0.0325041 s/step
# Meep progress: 13.044/100.0 = 13.0% done in 437.9s, 2919.5s to go
# on time step 13044 (time=13.044), 0.033328 s/step
# Meep progress: 13.167/100.0 = 13.2% done in 442.0s, 2914.6s to go
# on time step 13167 (time=13.167), 0.0326076 s/step
# Meep progress: 13.290000000000001/100.0 = 13.3% done in 446.0s, 2909.6s to go
# on time step 13290 (time=13.29), 0.0325323 s/step
# Meep progress: 13.411/100.0 = 13.4% done in 450.0s, 2905.2s to go
# on time step 13411 (time=13.411), 0.0330673 s/step
# Meep progress: 13.527000000000001/100.0 = 13.5% done in 454.0s, 2902.1s to go
# on time step 13527 (time=13.527), 0.0345434 s/step
# Meep progress: 13.647/100.0 = 13.6% done in 458.0s, 2898.0s to go
# on time step 13647 (time=13.647), 0.0334734 s/step
# Meep progress: 13.766/100.0 = 13.8% done in 462.0s, 2894.1s to go
# on time step 13766 (time=13.766), 0.0337813 s/step
# Meep progress: 13.885/100.0 = 13.9% done in 466.0s, 2890.2s to go
# on time step 13885 (time=13.885), 0.0336767 s/step
# Meep progress: 14.006/100.0 = 14.0% done in 470.0s, 2886.0s to go
# on time step 14006 (time=14.006), 0.0332691 s/step
# Meep progress: 14.127/100.0 = 14.1% done in 474.0s, 2881.6s to go
# on time step 14127 (time=14.127), 0.0331107 s/step
# Meep progress: 14.25/100.0 = 14.2% done in 478.1s, 2876.9s to go
# on time step 14250 (time=14.25), 0.0327474 s/step
# Meep progress: 14.371/100.0 = 14.4% done in 482.1s, 2872.6s to go
# on time step 14371 (time=14.371), 0.0333481 s/step
# Meep progress: 14.489/100.0 = 14.5% done in 486.1s, 2869.0s to go
# on time step 14489 (time=14.489), 0.0340354 s/step
# Meep progress: 14.606/100.0 = 14.6% done in 490.2s, 2865.7s to go
# on time step 14606 (time=14.606), 0.0344186 s/step
# Meep progress: 14.724/100.0 = 14.7% done in 494.2s, 2862.0s to go
# on time step 14724 (time=14.724), 0.0339474 s/step
# Meep progress: 14.845/100.0 = 14.8% done in 498.2s, 2857.6s to go
# on time step 14845 (time=14.845), 0.0331091 s/step
# Meep progress: 14.967/100.0 = 15.0% done in 502.2s, 2853.2s to go
# on time step 14967 (time=14.967), 0.0330192 s/step
# Meep progress: 15.091000000000001/100.0 = 15.1% done in 506.2s, 2848.2s to go
# on time step 15091 (time=15.091), 0.0324093 s/step
# Meep progress: 15.216000000000001/100.0 = 15.2% done in 510.2s, 2843.0s to go
# on time step 15216 (time=15.216), 0.032029 s/step
# Meep progress: 15.34/100.0 = 15.3% done in 514.2s, 2838.1s to go
# on time step 15340 (time=15.34), 0.0324089 s/step
# Meep progress: 15.463000000000001/100.0 = 15.5% done in 518.2s, 2833.3s to go
# on time step 15464 (time=15.464), 0.0324902 s/step
# Meep progress: 15.589/100.0 = 15.6% done in 522.3s, 2828.0s to go
# on time step 15589 (time=15.589), 0.0320036 s/step
# Meep progress: 15.716000000000001/100.0 = 15.7% done in 526.3s, 2822.5s to go
# on time step 15716 (time=15.716), 0.031716 s/step
# Meep progress: 15.84/100.0 = 15.8% done in 530.3s, 2817.7s to go
# on time step 15840 (time=15.84), 0.0324145 s/step
# Meep progress: 15.961/100.0 = 16.0% done in 534.3s, 2813.4s to go
# on time step 15961 (time=15.961), 0.0330761 s/step
# Meep progress: 16.082/100.0 = 16.1% done in 538.4s, 2809.2s to go
# on time step 16082 (time=16.082), 0.0333082 s/step
# Meep progress: 16.205000000000002/100.0 = 16.2% done in 542.4s, 2804.6s to go
# on time step 16205 (time=16.205), 0.0326479 s/step
# Meep progress: 16.325/100.0 = 16.3% done in 546.4s, 2800.5s to go
# on time step 16325 (time=16.325), 0.0333874 s/step
# Meep progress: 16.446/100.0 = 16.4% done in 550.4s, 2796.3s to go
# on time step 16446 (time=16.446), 0.0332284 s/step
# Meep progress: 16.566/100.0 = 16.6% done in 554.4s, 2792.3s to go
# on time step 16566 (time=16.566), 0.0335354 s/step
# Meep progress: 16.687/100.0 = 16.7% done in 558.4s, 2788.0s to go
# on time step 16687 (time=16.687), 0.0330752 s/step
# Meep progress: 16.811/100.0 = 16.8% done in 562.5s, 2783.3s to go
# on time step 16811 (time=16.811), 0.0325202 s/step
# Meep progress: 16.934/100.0 = 16.9% done in 566.5s, 2778.8s to go
# on time step 16934 (time=16.934), 0.0327569 s/step
# Meep progress: 17.059/100.0 = 17.1% done in 570.5s, 2773.9s to go
# on time step 17059 (time=17.059), 0.0322435 s/step
# Meep progress: 17.185/100.0 = 17.2% done in 574.5s, 2768.7s to go
# on time step 17185 (time=17.185), 0.03193 s/step
# Meep progress: 17.309/100.0 = 17.3% done in 578.6s, 2764.0s to go
# on time step 17309 (time=17.309), 0.0324336 s/step
# Meep progress: 17.432/100.0 = 17.4% done in 582.6s, 2759.4s to go
# on time step 17432 (time=17.432), 0.032542 s/step
# Meep progress: 17.559/100.0 = 17.6% done in 586.6s, 2754.1s to go
# on time step 17559 (time=17.559), 0.0317522 s/step
# Meep progress: 17.685/100.0 = 17.7% done in 590.6s, 2749.1s to go
# on time step 17685 (time=17.685), 0.031934 s/step
# Meep progress: 17.814/100.0 = 17.8% done in 594.6s, 2743.4s to go
# on time step 17814 (time=17.814), 0.0311331 s/step
# Meep progress: 17.941/100.0 = 17.9% done in 598.7s, 2738.2s to go
# on time step 17941 (time=17.941), 0.0316305 s/step
# Meep progress: 18.067/100.0 = 18.1% done in 602.7s, 2733.1s to go
# on time step 18067 (time=18.067), 0.0317954 s/step
# Meep progress: 18.194/100.0 = 18.2% done in 606.7s, 2727.9s to go
# on time step 18194 (time=18.194), 0.0316733 s/step
# Meep progress: 18.318/100.0 = 18.3% done in 610.7s, 2723.2s to go
# on time step 18318 (time=18.318), 0.0323805 s/step
# Meep progress: 18.438/100.0 = 18.4% done in 614.7s, 2719.2s to go
# on time step 18438 (time=18.438), 0.0334241 s/step
# Meep progress: 18.565/100.0 = 18.6% done in 618.7s, 2714.0s to go
# on time step 18565 (time=18.565), 0.031588 s/step
# Meep progress: 18.69/100.0 = 18.7% done in 622.8s, 2709.3s to go
# on time step 18690 (time=18.69), 0.03219 s/step
# Meep progress: 18.813/100.0 = 18.8% done in 626.8s, 2704.8s to go
# on time step 18813 (time=18.813), 0.0326302 s/step
# Meep progress: 18.938/100.0 = 18.9% done in 630.8s, 2700.0s to go
# on time step 18938 (time=18.938), 0.032155 s/step
# Meep progress: 19.065/100.0 = 19.1% done in 634.8s, 2694.8s to go
# on time step 19065 (time=19.065), 0.0315144 s/step
# Meep progress: 19.188/100.0 = 19.2% done in 638.8s, 2690.4s to go
# on time step 19188 (time=19.188), 0.0326412 s/step
# Meep progress: 19.314/100.0 = 19.3% done in 642.8s, 2685.4s to go
# on time step 19314 (time=19.314), 0.0317599 s/step
# Meep progress: 19.439/100.0 = 19.4% done in 646.8s, 2680.7s to go
# on time step 19439 (time=19.439), 0.0322155 s/step
# Meep progress: 19.565/100.0 = 19.6% done in 650.9s, 2675.8s to go
# on time step 19565 (time=19.565), 0.0319645 s/step
# Meep progress: 19.691/100.0 = 19.7% done in 654.9s, 2670.9s to go
# on time step 19691 (time=19.691), 0.0318524 s/step
# Meep progress: 19.817/100.0 = 19.8% done in 658.9s, 2666.0s to go
# on time step 19817 (time=19.817), 0.0319824 s/step
# Meep progress: 19.942/100.0 = 19.9% done in 662.9s, 2661.4s to go
# on time step 19942 (time=19.942), 0.0322065 s/step
# Meep progress: 20.067/100.0 = 20.1% done in 666.9s, 2656.6s to go
# on time step 20067 (time=20.067), 0.032072 s/step
# Meep progress: 20.191/100.0 = 20.2% done in 671.0s, 2652.1s to go
# on time step 20191 (time=20.191), 0.0323304 s/step
# Meep progress: 20.314/100.0 = 20.3% done in 675.0s, 2647.7s to go
# on time step 20314 (time=20.314), 0.0325907 s/step
# Meep progress: 20.438/100.0 = 20.4% done in 679.0s, 2643.2s to go
# on time step 20438 (time=20.438), 0.0325084 s/step
# Meep progress: 20.564/100.0 = 20.6% done in 683.0s, 2638.4s to go
# on time step 20564 (time=20.564), 0.0318956 s/step
# Meep progress: 20.692/100.0 = 20.7% done in 687.0s, 2633.3s to go
# on time step 20692 (time=20.692), 0.0314734 s/step
# Meep progress: 20.82/100.0 = 20.8% done in 691.0s, 2628.1s to go
# on time step 20820 (time=20.82), 0.0312802 s/step
# Meep progress: 20.948/100.0 = 20.9% done in 695.1s, 2622.9s to go
# on time step 20948 (time=20.948), 0.0313115 s/step
# Meep progress: 21.075/100.0 = 21.1% done in 699.1s, 2617.9s to go
# on time step 21075 (time=21.075), 0.0315129 s/step
# Meep progress: 21.203/100.0 = 21.2% done in 703.1s, 2612.9s to go
# on time step 21203 (time=21.203), 0.0314381 s/step
# Meep progress: 21.330000000000002/100.0 = 21.3% done in 707.1s, 2608.0s to go
# on time step 21330 (time=21.33), 0.031694 s/step
# Meep progress: 21.458000000000002/100.0 = 21.5% done in 711.1s, 2602.9s to go
# on time step 21458 (time=21.458), 0.03127 s/step
# Meep progress: 21.583000000000002/100.0 = 21.6% done in 715.1s, 2598.2s to go
# on time step 21583 (time=21.583), 0.0320597 s/step
# Meep progress: 21.707/100.0 = 21.7% done in 719.1s, 2593.8s to go
# on time step 21707 (time=21.707), 0.0323427 s/step
# Meep progress: 21.828/100.0 = 21.8% done in 723.1s, 2589.8s to go
# on time step 21828 (time=21.828), 0.0331522 s/step
# Meep progress: 21.952/100.0 = 22.0% done in 727.2s, 2585.3s to go
# on time step 21952 (time=21.952), 0.0324109 s/step
# Meep progress: 22.074/100.0 = 22.1% done in 731.2s, 2581.2s to go
# on time step 22074 (time=22.074), 0.032904 s/step
# Meep progress: 22.198/100.0 = 22.2% done in 735.2s, 2576.7s to go
# on time step 22198 (time=22.198), 0.0322903 s/step
# Meep progress: 22.323/100.0 = 22.3% done in 739.2s, 2572.2s to go
# on time step 22323 (time=22.323), 0.0321208 s/step
# Meep progress: 22.451/100.0 = 22.5% done in 743.2s, 2567.2s to go
# on time step 22451 (time=22.451), 0.0314356 s/step
# Meep progress: 22.576/100.0 = 22.6% done in 747.2s, 2562.6s to go
# on time step 22576 (time=22.576), 0.0320038 s/step
# Meep progress: 22.704/100.0 = 22.7% done in 751.2s, 2557.6s to go
# on time step 22704 (time=22.704), 0.0314094 s/step
# Meep progress: 22.831/100.0 = 22.8% done in 755.2s, 2552.7s to go
# on time step 22831 (time=22.831), 0.031534 s/step
# Meep progress: 22.957/100.0 = 23.0% done in 759.3s, 2548.1s to go
# on time step 22957 (time=22.957), 0.0318664 s/step
# Meep progress: 23.085/100.0 = 23.1% done in 763.3s, 2543.1s to go
# on time step 23085 (time=23.085), 0.0312596 s/step
# Meep progress: 23.211000000000002/100.0 = 23.2% done in 767.3s, 2538.4s to go
# on time step 23211 (time=23.211), 0.0317812 s/step
# Meep progress: 23.337/100.0 = 23.3% done in 771.3s, 2533.7s to go
# on time step 23337 (time=23.337), 0.0318761 s/step
# Meep progress: 23.459/100.0 = 23.5% done in 775.3s, 2529.6s to go
# on time step 23459 (time=23.459), 0.0328496 s/step
# Meep progress: 23.579/100.0 = 23.6% done in 779.3s, 2525.8s to go
# on time step 23579 (time=23.579), 0.0335115 s/step
# Meep progress: 23.702/100.0 = 23.7% done in 783.3s, 2521.6s to go
# on time step 23702 (time=23.702), 0.0327443 s/step
# Meep progress: 23.826/100.0 = 23.8% done in 787.3s, 2517.2s to go
# on time step 23826 (time=23.826), 0.0322583 s/step
# Meep progress: 23.952/100.0 = 24.0% done in 791.4s, 2512.6s to go
# on time step 23952 (time=23.952), 0.0318316 s/step
# Meep progress: 24.073/100.0 = 24.1% done in 795.4s, 2508.6s to go
# on time step 24073 (time=24.073), 0.0331682 s/step
# Meep progress: 24.199/100.0 = 24.2% done in 799.4s, 2504.1s to go
# on time step 24199 (time=24.199), 0.0319894 s/step
# Meep progress: 24.323/100.0 = 24.3% done in 803.4s, 2499.7s to go
# on time step 24323 (time=24.323), 0.0323411 s/step
# Meep progress: 24.448/100.0 = 24.4% done in 807.4s, 2495.3s to go
# on time step 24448 (time=24.448), 0.0322302 s/step
# Meep progress: 24.573/100.0 = 24.6% done in 811.5s, 2490.8s to go
# on time step 24573 (time=24.573), 0.0321342 s/step
# Meep progress: 24.698/100.0 = 24.7% done in 815.5s, 2486.3s to go
# on time step 24698 (time=24.698), 0.032195 s/step
# Meep progress: 24.824/100.0 = 24.8% done in 819.5s, 2481.8s to go
# on time step 24824 (time=24.824), 0.0319578 s/step
# Meep progress: 24.947/100.0 = 24.9% done in 823.5s, 2477.6s to go
# on time step 24947 (time=24.947), 0.0327092 s/step
# Meep progress: 25.07/100.0 = 25.1% done in 827.5s, 2473.4s to go
# on time step 25070 (time=25.07), 0.0325835 s/step
# Meep progress: 25.196/100.0 = 25.2% done in 831.6s, 2468.9s to go
# on time step 25196 (time=25.196), 0.0319929 s/step
# Meep progress: 25.317/100.0 = 25.3% done in 835.6s, 2464.9s to go
# on time step 25317 (time=25.317), 0.0331325 s/step
# Meep progress: 25.439/100.0 = 25.4% done in 839.6s, 2460.9s to go
# on time step 25439 (time=25.439), 0.0329602 s/step
# Meep progress: 25.558/100.0 = 25.6% done in 843.6s, 2457.2s to go
# on time step 25558 (time=25.558), 0.0337307 s/step
# Meep progress: 25.68/100.0 = 25.7% done in 847.6s, 2453.1s to go
# on time step 25680 (time=25.68), 0.0329228 s/step
# Meep progress: 25.805/100.0 = 25.8% done in 851.7s, 2448.7s to go
# on time step 25805 (time=25.805), 0.0322237 s/step
# Meep progress: 25.928/100.0 = 25.9% done in 855.7s, 2444.6s to go
# on time step 25928 (time=25.928), 0.0326816 s/step
# Meep progress: 26.047/100.0 = 26.0% done in 859.7s, 2440.9s to go
# on time step 26047 (time=26.047), 0.0337178 s/step
# Meep progress: 26.17/100.0 = 26.2% done in 863.7s, 2436.6s to go
# on time step 26170 (time=26.17), 0.0325283 s/step
# Meep progress: 26.293/100.0 = 26.3% done in 867.7s, 2432.4s to go
# on time step 26293 (time=26.293), 0.0325454 s/step
# Meep progress: 26.415/100.0 = 26.4% done in 871.7s, 2428.4s to go
# on time step 26415 (time=26.415), 0.0330425 s/step
# Meep progress: 26.538/100.0 = 26.5% done in 875.7s, 2424.2s to go
# on time step 26538 (time=26.538), 0.0325608 s/step
# Meep progress: 26.661/100.0 = 26.7% done in 879.8s, 2420.1s to go
# on time step 26661 (time=26.661), 0.0327822 s/step
# Meep progress: 26.784/100.0 = 26.8% done in 883.8s, 2415.9s to go
# on time step 26784 (time=26.784), 0.032614 s/step
# Meep progress: 26.91/100.0 = 26.9% done in 887.8s, 2411.4s to go
# on time step 26910 (time=26.91), 0.0318761 s/step
# Meep progress: 27.033/100.0 = 27.0% done in 891.8s, 2407.2s to go
# on time step 27033 (time=27.033), 0.0326863 s/step
# Meep progress: 27.153000000000002/100.0 = 27.2% done in 895.8s, 2403.4s to go
# on time step 27153 (time=27.153), 0.033424 s/step
# Meep progress: 27.275000000000002/100.0 = 27.3% done in 899.9s, 2399.3s to go
# on time step 27275 (time=27.275), 0.032937 s/step
# Meep progress: 27.397000000000002/100.0 = 27.4% done in 903.9s, 2395.3s to go
# on time step 27397 (time=27.397), 0.0329523 s/step
# Meep progress: 27.518/100.0 = 27.5% done in 907.9s, 2391.4s to go
# on time step 27518 (time=27.518), 0.0332762 s/step
# Meep progress: 27.639/100.0 = 27.6% done in 911.9s, 2387.5s to go
# on time step 27639 (time=27.639), 0.0331882 s/step
# Meep progress: 27.76/100.0 = 27.8% done in 915.9s, 2383.5s to go
# on time step 27760 (time=27.76), 0.0331191 s/step
# Meep progress: 27.881/100.0 = 27.9% done in 919.9s, 2379.6s to go
# on time step 27881 (time=27.881), 0.0332082 s/step
# Meep progress: 28.003/100.0 = 28.0% done in 924.0s, 2375.6s to go
# on time step 28003 (time=28.003), 0.0330359 s/step
# Meep progress: 28.125/100.0 = 28.1% done in 928.0s, 2371.5s to go
# on time step 28125 (time=28.125), 0.0328118 s/step
# Meep progress: 28.247/100.0 = 28.2% done in 932.0s, 2367.5s to go
# on time step 28247 (time=28.247), 0.032949 s/step
# Meep progress: 28.369/100.0 = 28.4% done in 936.0s, 2363.4s to go
# on time step 28369 (time=28.369), 0.0328171 s/step
# Meep progress: 28.492/100.0 = 28.5% done in 940.0s, 2359.2s to go
# on time step 28492 (time=28.492), 0.0325393 s/step
# Meep progress: 28.616/100.0 = 28.6% done in 944.0s, 2354.9s to go
# on time step 28616 (time=28.616), 0.0323077 s/step
# Meep progress: 28.740000000000002/100.0 = 28.7% done in 948.0s, 2350.6s to go
# on time step 28740 (time=28.74), 0.0323854 s/step
# Meep progress: 28.86/100.0 = 28.9% done in 952.0s, 2346.8s to go
# on time step 28860 (time=28.86), 0.0333804 s/step
# Meep progress: 28.981/100.0 = 29.0% done in 956.0s, 2342.8s to go
# on time step 28981 (time=28.981), 0.0330594 s/step
# Meep progress: 29.102/100.0 = 29.1% done in 960.0s, 2338.8s to go
# on time step 29102 (time=29.102), 0.0331048 s/step
# Meep progress: 29.223/100.0 = 29.2% done in 964.1s, 2334.9s to go
# on time step 29223 (time=29.223), 0.0332583 s/step
# Meep progress: 29.345/100.0 = 29.3% done in 968.1s, 2330.9s to go
# on time step 29346 (time=29.346), 0.032784 s/step
# Meep progress: 29.466/100.0 = 29.5% done in 972.1s, 2326.9s to go
# on time step 29467 (time=29.467), 0.0331924 s/step
# Meep progress: 29.587/100.0 = 29.6% done in 976.1s, 2323.0s to go
# on time step 29588 (time=29.588), 0.0332967 s/step
# Meep progress: 29.707/100.0 = 29.7% done in 980.1s, 2319.2s to go
# on time step 29708 (time=29.708), 0.0333586 s/step
# Meep progress: 29.831/100.0 = 29.8% done in 984.1s, 2314.9s to go
# on time step 29832 (time=29.832), 0.0322633 s/step
# Meep progress: 29.954/100.0 = 30.0% done in 988.1s, 2310.7s to go
# on time step 29955 (time=29.955), 0.032609 s/step
# Meep progress: 30.076/100.0 = 30.1% done in 992.1s, 2306.7s to go
# on time step 30077 (time=30.077), 0.0329264 s/step
# Meep progress: 30.2/100.0 = 30.2% done in 996.2s, 2302.4s to go
# on time step 30201 (time=30.201), 0.0322839 s/step
# Meep progress: 30.323/100.0 = 30.3% done in 1000.2s, 2298.2s to go
# on time step 30324 (time=30.324), 0.0326408 s/step
# Meep progress: 30.445/100.0 = 30.4% done in 1004.2s, 2294.1s to go
# on time step 30447 (time=30.447), 0.0327651 s/step
# Meep progress: 30.567/100.0 = 30.6% done in 1008.2s, 2290.1s to go
# on time step 30569 (time=30.569), 0.0329855 s/step
# Meep progress: 30.685000000000002/100.0 = 30.7% done in 1012.2s, 2286.5s to go
# on time step 30687 (time=30.687), 0.0340366 s/step
# Meep progress: 30.805/100.0 = 30.8% done in 1016.2s, 2282.7s to go
# on time step 30807 (time=30.807), 0.033577 s/step
# Meep progress: 30.927/100.0 = 30.9% done in 1020.2s, 2278.6s to go
# on time step 30930 (time=30.93), 0.0327854 s/step
# Meep progress: 31.05/100.0 = 31.1% done in 1024.2s, 2274.5s to go
# on time step 31053 (time=31.053), 0.0326781 s/step
# Meep progress: 31.171/100.0 = 31.2% done in 1028.3s, 2270.5s to go
# on time step 31174 (time=31.174), 0.0332541 s/step
# Meep progress: 31.292/100.0 = 31.3% done in 1032.3s, 2266.6s to go
# on time step 31294 (time=31.294), 0.0334017 s/step
# Meep progress: 31.414/100.0 = 31.4% done in 1036.3s, 2262.6s to go
# on time step 31417 (time=31.417), 0.0326195 s/step
# Meep progress: 31.536/100.0 = 31.5% done in 1040.3s, 2258.5s to go
# on time step 31539 (time=31.539), 0.0330179 s/step
# Meep progress: 31.66/100.0 = 31.7% done in 1044.3s, 2254.3s to go
# on time step 31663 (time=31.663), 0.0322927 s/step
# Meep progress: 31.785/100.0 = 31.8% done in 1048.4s, 2249.9s to go
# on time step 31788 (time=31.788), 0.0321495 s/step
# Meep progress: 31.909/100.0 = 31.9% done in 1052.4s, 2245.7s to go
# on time step 31912 (time=31.912), 0.0323357 s/step
# Meep progress: 32.031/100.0 = 32.0% done in 1056.4s, 2241.6s to go
# on time step 32034 (time=32.034), 0.0328779 s/step
# Meep progress: 32.154/100.0 = 32.2% done in 1060.4s, 2237.5s to go
# on time step 32157 (time=32.157), 0.0326545 s/step
# Meep progress: 32.278/100.0 = 32.3% done in 1064.4s, 2233.2s to go
# on time step 32282 (time=32.282), 0.0322262 s/step
# Meep progress: 32.404/100.0 = 32.4% done in 1068.4s, 2228.8s to go
# on time step 32408 (time=32.408), 0.0319169 s/step
# Meep progress: 32.527/100.0 = 32.5% done in 1072.4s, 2224.6s to go
# on time step 32531 (time=32.531), 0.0325288 s/step
# Meep progress: 32.647/100.0 = 32.6% done in 1076.4s, 2220.7s to go
# on time step 32651 (time=32.651), 0.0334274 s/step
# Meep progress: 32.766/100.0 = 32.8% done in 1080.5s, 2217.1s to go
# on time step 32769 (time=32.769), 0.0340321 s/step
# Meep progress: 32.885/100.0 = 32.9% done in 1084.5s, 2213.3s to go
# on time step 32889 (time=32.889), 0.0335497 s/step
# Meep progress: 33.005/100.0 = 33.0% done in 1088.5s, 2209.5s to go
# on time step 33009 (time=33.009), 0.0334387 s/step
# Meep progress: 33.128/100.0 = 33.1% done in 1092.5s, 2205.3s to go
# on time step 33132 (time=33.132), 0.0326802 s/step
# Meep progress: 33.249/100.0 = 33.2% done in 1096.5s, 2201.4s to go
# on time step 33253 (time=33.253), 0.0332719 s/step
# Meep progress: 33.371/100.0 = 33.4% done in 1100.6s, 2197.4s to go
# on time step 33375 (time=33.375), 0.0329623 s/step
# Meep progress: 33.495/100.0 = 33.5% done in 1104.6s, 2193.1s to go
# on time step 33499 (time=33.499), 0.0323382 s/step
# Meep progress: 33.619/100.0 = 33.6% done in 1108.6s, 2188.9s to go
# on time step 33623 (time=33.623), 0.0323136 s/step
# Meep progress: 33.743/100.0 = 33.7% done in 1112.6s, 2184.6s to go
# on time step 33748 (time=33.748), 0.0322044 s/step
# Meep progress: 33.866/100.0 = 33.9% done in 1116.6s, 2180.5s to go
# on time step 33870 (time=33.87), 0.0327881 s/step
# Meep progress: 33.987/100.0 = 34.0% done in 1120.6s, 2176.6s to go
# on time step 33991 (time=33.991), 0.033122 s/step
# Meep progress: 34.103/100.0 = 34.1% done in 1124.6s, 2173.1s to go
# on time step 34107 (time=34.107), 0.0345541 s/step
# Meep progress: 34.226/100.0 = 34.2% done in 1128.6s, 2168.9s to go
# on time step 34231 (time=34.231), 0.0323834 s/step
# Meep progress: 34.352000000000004/100.0 = 34.4% done in 1132.6s, 2164.5s to go
# on time step 34357 (time=34.357), 0.031796 s/step
# Meep progress: 34.475/100.0 = 34.5% done in 1136.6s, 2160.3s to go
# on time step 34480 (time=34.48), 0.0326205 s/step
# Meep progress: 34.599000000000004/100.0 = 34.6% done in 1140.6s, 2156.1s to go
# on time step 34604 (time=34.604), 0.0324247 s/step
# Meep progress: 34.725/100.0 = 34.7% done in 1144.7s, 2151.7s to go
# on time step 34730 (time=34.73), 0.0318584 s/step
# Meep progress: 34.848/100.0 = 34.8% done in 1148.7s, 2147.5s to go
# on time step 34853 (time=34.853), 0.0326341 s/step
# Meep progress: 34.97/100.0 = 35.0% done in 1152.7s, 2143.5s to go
# on time step 34976 (time=34.976), 0.032657 s/step
# Meep progress: 35.097/100.0 = 35.1% done in 1156.7s, 2139.0s to go
# on time step 35103 (time=35.103), 0.0317214 s/step
# Meep progress: 35.219/100.0 = 35.2% done in 1160.7s, 2135.0s to go
# on time step 35225 (time=35.225), 0.0328991 s/step
# Meep progress: 35.345/100.0 = 35.3% done in 1164.7s, 2130.5s to go
# on time step 35351 (time=35.351), 0.0317489 s/step
# Meep progress: 35.471000000000004/100.0 = 35.5% done in 1168.7s, 2126.2s to go
# on time step 35476 (time=35.476), 0.0320828 s/step
# Meep progress: 35.594/100.0 = 35.6% done in 1172.7s, 2122.0s to go
# on time step 35599 (time=35.599), 0.032629 s/step
# Meep progress: 35.716/100.0 = 35.7% done in 1176.8s, 2118.0s to go
# on time step 35721 (time=35.721), 0.0328396 s/step
# Meep progress: 35.839/100.0 = 35.8% done in 1180.8s, 2113.9s to go
# on time step 35843 (time=35.843), 0.0328143 s/step
# Meep progress: 35.964/100.0 = 36.0% done in 1184.8s, 2109.7s to go
# on time step 35967 (time=35.967), 0.0323352 s/step
# Meep progress: 36.089/100.0 = 36.1% done in 1188.8s, 2105.4s to go
# on time step 36093 (time=36.093), 0.0319305 s/step
# Meep progress: 36.214/100.0 = 36.2% done in 1192.8s, 2101.0s to go
# on time step 36218 (time=36.218), 0.0321196 s/step
# Meep progress: 36.338/100.0 = 36.3% done in 1196.9s, 2096.8s to go
# on time step 36342 (time=36.342), 0.0323677 s/step
# Meep progress: 36.463/100.0 = 36.5% done in 1200.9s, 2092.5s to go
# on time step 36468 (time=36.468), 0.031919 s/step
# Meep progress: 36.588/100.0 = 36.6% done in 1204.9s, 2088.2s to go
# on time step 36592 (time=36.592), 0.0323003 s/step
# Meep progress: 36.711/100.0 = 36.7% done in 1208.9s, 2084.1s to go
# on time step 36716 (time=36.716), 0.03245 s/step
# Meep progress: 36.839/100.0 = 36.8% done in 1212.9s, 2079.5s to go
# on time step 36844 (time=36.844), 0.0312955 s/step
# Meep progress: 36.965/100.0 = 37.0% done in 1216.9s, 2075.1s to go
# on time step 36970 (time=36.97), 0.0317853 s/step
# Meep progress: 37.09/100.0 = 37.1% done in 1220.9s, 2070.8s to go
# on time step 37095 (time=37.095), 0.0321707 s/step
# Meep progress: 37.216/100.0 = 37.2% done in 1224.9s, 2066.5s to go
# on time step 37222 (time=37.222), 0.0316995 s/step
# Meep progress: 37.342/100.0 = 37.3% done in 1229.0s, 2062.1s to go
# on time step 37347 (time=37.347), 0.0321673 s/step
# Meep progress: 37.465/100.0 = 37.5% done in 1233.0s, 2058.0s to go
# on time step 37470 (time=37.47), 0.0325368 s/step
# Meep progress: 37.59/100.0 = 37.6% done in 1237.0s, 2053.7s to go
# on time step 37595 (time=37.595), 0.0321366 s/step
# Meep progress: 37.717/100.0 = 37.7% done in 1241.0s, 2049.3s to go
# on time step 37722 (time=37.722), 0.0316458 s/step
# Meep progress: 37.842/100.0 = 37.8% done in 1245.0s, 2045.0s to go
# on time step 37847 (time=37.847), 0.0320477 s/step
# Meep progress: 37.969/100.0 = 38.0% done in 1249.0s, 2040.6s to go
# on time step 37974 (time=37.974), 0.0317093 s/step
# Meep progress: 38.096000000000004/100.0 = 38.1% done in 1253.0s, 2036.1s to go
# on time step 38102 (time=38.102), 0.031437 s/step
# Meep progress: 38.224000000000004/100.0 = 38.2% done in 1257.1s, 2031.6s to go
# on time step 38229 (time=38.229), 0.0315266 s/step
# Meep progress: 38.35/100.0 = 38.4% done in 1261.1s, 2027.3s to go
# on time step 38355 (time=38.355), 0.0317793 s/step
# Meep progress: 38.476/100.0 = 38.5% done in 1265.1s, 2022.9s to go
# on time step 38480 (time=38.48), 0.0320076 s/step
# Meep progress: 38.6/100.0 = 38.6% done in 1269.1s, 2018.7s to go
# on time step 38605 (time=38.605), 0.0321666 s/step
# Meep progress: 38.722/100.0 = 38.7% done in 1273.1s, 2014.7s to go
# on time step 38727 (time=38.727), 0.0327946 s/step
# Meep progress: 38.843/100.0 = 38.8% done in 1277.1s, 2010.8s to go
# on time step 38848 (time=38.848), 0.0333354 s/step
# Meep progress: 38.967/100.0 = 39.0% done in 1281.1s, 2006.6s to go
# on time step 38972 (time=38.972), 0.0323432 s/step
# Meep progress: 39.095/100.0 = 39.1% done in 1285.2s, 2002.1s to go
# on time step 39100 (time=39.1), 0.0314776 s/step
# Meep progress: 39.221000000000004/100.0 = 39.2% done in 1289.2s, 1997.8s to go
# on time step 39226 (time=39.226), 0.0318661 s/step
# Meep progress: 39.346000000000004/100.0 = 39.3% done in 1293.2s, 1993.5s to go
# on time step 39351 (time=39.351), 0.0322427 s/step
# Meep progress: 39.472/100.0 = 39.5% done in 1297.2s, 1989.2s to go
# on time step 39477 (time=39.477), 0.0317639 s/step
# Meep progress: 39.598/100.0 = 39.6% done in 1301.2s, 1984.9s to go
# on time step 39603 (time=39.603), 0.0318353 s/step
# Meep progress: 39.724000000000004/100.0 = 39.7% done in 1305.3s, 1980.6s to go
# on time step 39729 (time=39.729), 0.0318229 s/step
# Meep progress: 39.852000000000004/100.0 = 39.9% done in 1309.3s, 1976.1s to go
# on time step 39856 (time=39.856), 0.031497 s/step
# Meep progress: 39.975/100.0 = 40.0% done in 1313.3s, 1972.0s to go
# on time step 39979 (time=39.979), 0.032604 s/step
# Meep progress: 40.099000000000004/100.0 = 40.1% done in 1317.3s, 1967.8s to go
# on time step 40103 (time=40.103), 0.032363 s/step
# Meep progress: 40.223/100.0 = 40.2% done in 1321.3s, 1963.6s to go
# on time step 40228 (time=40.228), 0.0322137 s/step
# Meep progress: 40.347/100.0 = 40.3% done in 1325.3s, 1959.5s to go
# on time step 40352 (time=40.352), 0.0323355 s/step
# Meep progress: 40.47/100.0 = 40.5% done in 1329.3s, 1955.4s to go
# on time step 40475 (time=40.475), 0.0325994 s/step
# Meep progress: 40.594/100.0 = 40.6% done in 1333.3s, 1951.2s to go
# on time step 40599 (time=40.599), 0.0323907 s/step
# Meep progress: 40.717/100.0 = 40.7% done in 1337.3s, 1947.1s to go
# on time step 40723 (time=40.723), 0.0324818 s/step
# Meep progress: 40.84/100.0 = 40.8% done in 1341.4s, 1943.1s to go
# on time step 40846 (time=40.846), 0.0326281 s/step
# Meep progress: 40.964/100.0 = 41.0% done in 1345.4s, 1938.9s to go
# on time step 40969 (time=40.969), 0.0325683 s/step
# Meep progress: 41.09/100.0 = 41.1% done in 1349.4s, 1934.6s to go
# on time step 41095 (time=41.095), 0.031821 s/step
# Meep progress: 41.215/100.0 = 41.2% done in 1353.4s, 1930.4s to go
# on time step 41220 (time=41.22), 0.0321486 s/step
# Meep progress: 41.341/100.0 = 41.3% done in 1357.4s, 1926.0s to go
# on time step 41346 (time=41.346), 0.0317558 s/step
# Meep progress: 41.47/100.0 = 41.5% done in 1361.4s, 1921.5s to go
# on time step 41476 (time=41.476), 0.0309434 s/step
# Meep progress: 41.598/100.0 = 41.6% done in 1365.4s, 1917.0s to go
# on time step 41604 (time=41.604), 0.0313505 s/step
# Meep progress: 41.726/100.0 = 41.7% done in 1369.4s, 1912.5s to go
# on time step 41732 (time=41.732), 0.0313577 s/step
# Meep progress: 41.854/100.0 = 41.9% done in 1373.5s, 1908.1s to go
# on time step 41859 (time=41.859), 0.0315991 s/step
# Meep progress: 41.980000000000004/100.0 = 42.0% done in 1377.5s, 1903.8s to go
# on time step 41985 (time=41.985), 0.0318573 s/step
# Meep progress: 42.106/100.0 = 42.1% done in 1381.5s, 1899.5s to go
# on time step 42110 (time=42.11), 0.0321487 s/step
# Meep progress: 42.229/100.0 = 42.2% done in 1385.5s, 1895.5s to go
# on time step 42233 (time=42.233), 0.0325555 s/step
# Meep progress: 42.354/100.0 = 42.4% done in 1389.6s, 1891.3s to go
# on time step 42358 (time=42.358), 0.0322157 s/step
# Meep progress: 42.476/100.0 = 42.5% done in 1393.6s, 1887.3s to go
# on time step 42480 (time=42.48), 0.0330347 s/step
# Meep progress: 42.6/100.0 = 42.6% done in 1397.6s, 1883.2s to go
# on time step 42604 (time=42.604), 0.0323453 s/step
# Meep progress: 42.725/100.0 = 42.7% done in 1401.6s, 1879.0s to go
# on time step 42729 (time=42.729), 0.0320429 s/step
# Meep progress: 42.852000000000004/100.0 = 42.9% done in 1405.7s, 1874.6s to go
# on time step 42856 (time=42.856), 0.0316915 s/step
# Meep progress: 42.978/100.0 = 43.0% done in 1409.7s, 1870.3s to go
# on time step 42982 (time=42.982), 0.0318553 s/step
# Meep progress: 43.102000000000004/100.0 = 43.1% done in 1413.7s, 1866.2s to go
# on time step 43106 (time=43.106), 0.0323893 s/step
# Meep progress: 43.228/100.0 = 43.2% done in 1417.7s, 1861.9s to go
# on time step 43232 (time=43.232), 0.0319146 s/step
# Meep progress: 43.354/100.0 = 43.4% done in 1421.7s, 1857.6s to go
# on time step 43358 (time=43.358), 0.0317776 s/step
# Meep progress: 43.478/100.0 = 43.5% done in 1425.7s, 1853.5s to go
# on time step 43481 (time=43.481), 0.032581 s/step
# Meep progress: 43.603/100.0 = 43.6% done in 1429.8s, 1849.3s to go
# on time step 43606 (time=43.606), 0.0320227 s/step
# Meep progress: 43.729/100.0 = 43.7% done in 1433.8s, 1845.0s to go
# on time step 43731 (time=43.731), 0.0320476 s/step
# Meep progress: 43.853/100.0 = 43.9% done in 1437.8s, 1840.9s to go
# on time step 43854 (time=43.854), 0.0325283 s/step
# Meep progress: 43.975/100.0 = 44.0% done in 1441.8s, 1836.9s to go
# on time step 43976 (time=43.976), 0.0328898 s/step
# Meep progress: 44.1/100.0 = 44.1% done in 1445.8s, 1832.7s to go
# on time step 44101 (time=44.101), 0.0320303 s/step
# Meep progress: 44.221000000000004/100.0 = 44.2% done in 1449.8s, 1828.8s to go
# on time step 44223 (time=44.223), 0.0330086 s/step
# Meep progress: 44.347/100.0 = 44.3% done in 1453.9s, 1824.5s to go
# on time step 44349 (time=44.349), 0.0319847 s/step
# Meep progress: 44.471000000000004/100.0 = 44.5% done in 1457.9s, 1820.4s to go
# on time step 44473 (time=44.473), 0.0323412 s/step
# Meep progress: 44.595/100.0 = 44.6% done in 1461.9s, 1816.3s to go
# on time step 44597 (time=44.597), 0.0323546 s/step
# Meep progress: 44.719/100.0 = 44.7% done in 1465.9s, 1812.1s to go
# on time step 44721 (time=44.721), 0.0325003 s/step
# Meep progress: 44.841/100.0 = 44.8% done in 1469.9s, 1808.1s to go
# on time step 44844 (time=44.844), 0.0326584 s/step
# Meep progress: 44.965/100.0 = 45.0% done in 1473.9s, 1804.0s to go
# on time step 44968 (time=44.968), 0.0322997 s/step
# Meep progress: 45.093/100.0 = 45.1% done in 1477.9s, 1799.6s to go
# on time step 45096 (time=45.096), 0.0312789 s/step
# Meep progress: 45.219/100.0 = 45.2% done in 1481.9s, 1795.3s to go
# on time step 45221 (time=45.221), 0.0320311 s/step
# Meep progress: 45.343/100.0 = 45.3% done in 1486.0s, 1791.2s to go
# on time step 45345 (time=45.345), 0.0323616 s/step
# Meep progress: 45.47/100.0 = 45.5% done in 1490.0s, 1786.9s to go
# on time step 45472 (time=45.472), 0.0316445 s/step
# Meep progress: 45.595/100.0 = 45.6% done in 1494.0s, 1782.7s to go
# on time step 45597 (time=45.597), 0.0320664 s/step
# Meep progress: 45.72/100.0 = 45.7% done in 1498.0s, 1778.5s to go
# on time step 45722 (time=45.722), 0.0321506 s/step
# Meep progress: 45.842/100.0 = 45.8% done in 1502.0s, 1774.5s to go
# on time step 45844 (time=45.844), 0.0328517 s/step
# Meep progress: 45.966/100.0 = 46.0% done in 1506.0s, 1770.4s to go
# on time step 45968 (time=45.968), 0.0322687 s/step
# Meep progress: 46.089/100.0 = 46.1% done in 1510.0s, 1766.3s to go
# on time step 46091 (time=46.091), 0.0326638 s/step
# Meep progress: 46.212/100.0 = 46.2% done in 1514.1s, 1762.3s to go
# on time step 46214 (time=46.214), 0.0326908 s/step
# Meep progress: 46.334/100.0 = 46.3% done in 1518.1s, 1758.3s to go
# on time step 46336 (time=46.336), 0.0328358 s/step
# Meep progress: 46.46/100.0 = 46.5% done in 1522.1s, 1754.0s to go
# on time step 46462 (time=46.462), 0.0318301 s/step
# Meep progress: 46.586/100.0 = 46.6% done in 1526.1s, 1749.8s to go
# on time step 46588 (time=46.588), 0.0319296 s/step
# Meep progress: 46.713/100.0 = 46.7% done in 1530.1s, 1745.5s to go
# on time step 46715 (time=46.715), 0.0316597 s/step
# Meep progress: 46.839/100.0 = 46.8% done in 1534.1s, 1741.2s to go
# on time step 46841 (time=46.841), 0.031904 s/step
# Meep progress: 46.966/100.0 = 47.0% done in 1538.1s, 1736.9s to go
# on time step 46969 (time=46.969), 0.0314349 s/step
# Meep progress: 47.092/100.0 = 47.1% done in 1542.2s, 1732.6s to go
# on time step 47094 (time=47.094), 0.0320124 s/step
# Meep progress: 47.216/100.0 = 47.2% done in 1546.2s, 1728.5s to go
# on time step 47218 (time=47.218), 0.0323315 s/step
# Meep progress: 47.345/100.0 = 47.3% done in 1550.2s, 1724.1s to go
# on time step 47347 (time=47.347), 0.0312239 s/step
# Meep progress: 47.471000000000004/100.0 = 47.5% done in 1554.2s, 1719.8s to go
# on time step 47473 (time=47.473), 0.0317615 s/step
# Meep progress: 47.593/100.0 = 47.6% done in 1558.2s, 1715.8s to go
# on time step 47595 (time=47.595), 0.0328282 s/step
# Meep progress: 47.718/100.0 = 47.7% done in 1562.2s, 1711.7s to go
# on time step 47720 (time=47.72), 0.0321917 s/step
# Meep progress: 47.842/100.0 = 47.8% done in 1566.3s, 1707.6s to go
# on time step 47844 (time=47.844), 0.0324992 s/step
# Meep progress: 47.965/100.0 = 48.0% done in 1570.3s, 1703.5s to go
# on time step 47967 (time=47.967), 0.0326359 s/step
# ...
# Meep progress: 85.459/100.0 = 85.5% done in 2775.2s, 472.2s to go
# on time step 85468 (time=85.468), 0.0323809 s/step
# Meep progress: 85.58200000000001/100.0 = 85.6% done in 2779.2s, 468.2s to go
# on time step 85590 (time=85.59), 0.0328885 s/step
# Meep progress: 85.708/100.0 = 85.7% done in 2783.2s, 464.1s to go
# on time step 85716 (time=85.716), 0.0318007 s/step
# Meep progress: 85.834/100.0 = 85.8% done in 2787.3s, 460.0s to go
# on time step 85842 (time=85.842), 0.0318232 s/step
# Meep progress: 85.96000000000001/100.0 = 86.0% done in 2791.3s, 455.9s to go
# on time step 85968 (time=85.968), 0.0319579 s/step
# Meep progress: 86.089/100.0 = 86.1% done in 2795.3s, 451.7s to go
# on time step 86097 (time=86.097), 0.0311312 s/step
# Meep progress: 86.217/100.0 = 86.2% done in 2799.3s, 447.5s to go
# on time step 86226 (time=86.226), 0.0312326 s/step
# Meep progress: 86.346/100.0 = 86.3% done in 2803.3s, 443.3s to go
# on time step 86355 (time=86.355), 0.0312146 s/step
# Meep progress: 86.474/100.0 = 86.5% done in 2807.4s, 439.1s to go
# on time step 86482 (time=86.482), 0.031528 s/step
# Meep progress: 86.601/100.0 = 86.6% done in 2811.4s, 435.0s to go
# on time step 86609 (time=86.609), 0.0316981 s/step
# Meep progress: 86.72500000000001/100.0 = 86.7% done in 2815.4s, 431.0s to go
# on time step 86733 (time=86.733), 0.0324579 s/step
# Meep progress: 86.84700000000001/100.0 = 86.8% done in 2819.4s, 427.0s to go
# on time step 86856 (time=86.856), 0.0327593 s/step
# Meep progress: 86.97/100.0 = 87.0% done in 2823.4s, 423.0s to go
# on time step 86979 (time=86.979), 0.0325263 s/step
# Meep progress: 87.093/100.0 = 87.1% done in 2827.4s, 419.0s to go
# on time step 87102 (time=87.102), 0.0326268 s/step
# Meep progress: 87.21600000000001/100.0 = 87.2% done in 2831.4s, 415.0s to go
# on time step 87225 (time=87.225), 0.0325676 s/step
# Meep progress: 87.339/100.0 = 87.3% done in 2835.4s, 411.0s to go
# on time step 87348 (time=87.348), 0.0325832 s/step
# Meep progress: 87.462/100.0 = 87.5% done in 2839.5s, 407.0s to go
# on time step 87471 (time=87.471), 0.0326894 s/step
# Meep progress: 87.58800000000001/100.0 = 87.6% done in 2843.5s, 402.9s to go
# on time step 87597 (time=87.597), 0.0319438 s/step
# Meep progress: 87.71600000000001/100.0 = 87.7% done in 2847.5s, 398.8s to go
# on time step 87725 (time=87.725), 0.0314879 s/step
# Meep progress: 87.842/100.0 = 87.8% done in 2851.5s, 394.7s to go
# on time step 87851 (time=87.851), 0.0319168 s/step
# Meep progress: 87.96900000000001/100.0 = 88.0% done in 2855.6s, 390.5s to go
# on time step 87978 (time=87.978), 0.0316767 s/step
# Meep progress: 88.096/100.0 = 88.1% done in 2859.6s, 386.4s to go
# on time step 88106 (time=88.106), 0.031463 s/step
# Meep progress: 88.224/100.0 = 88.2% done in 2863.6s, 382.2s to go
# on time step 88234 (time=88.234), 0.0314455 s/step
# Meep progress: 88.351/100.0 = 88.4% done in 2867.6s, 378.1s to go
# on time step 88360 (time=88.36), 0.0319912 s/step
# Meep progress: 88.48/100.0 = 88.5% done in 2871.6s, 373.9s to go
# on time step 88490 (time=88.49), 0.0310144 s/step
# Meep progress: 88.60600000000001/100.0 = 88.6% done in 2875.7s, 369.8s to go
# on time step 88616 (time=88.616), 0.0319166 s/step
# Meep progress: 88.73100000000001/100.0 = 88.7% done in 2879.7s, 365.7s to go
# on time step 88741 (time=88.741), 0.0320013 s/step
# Meep progress: 88.855/100.0 = 88.9% done in 2883.7s, 361.7s to go
# on time step 88865 (time=88.865), 0.0323192 s/step
# Meep progress: 88.98100000000001/100.0 = 89.0% done in 2887.7s, 357.6s to go
# on time step 88991 (time=88.991), 0.0318161 s/step
# Meep progress: 89.10600000000001/100.0 = 89.1% done in 2891.7s, 353.5s to go
# on time step 89117 (time=89.117), 0.0318699 s/step
# Meep progress: 89.23400000000001/100.0 = 89.2% done in 2895.7s, 349.4s to go
# on time step 89244 (time=89.244), 0.0317264 s/step
# Meep progress: 89.358/100.0 = 89.4% done in 2899.8s, 345.3s to go
# on time step 89368 (time=89.368), 0.0324165 s/step
# Meep progress: 89.485/100.0 = 89.5% done in 2903.8s, 341.2s to go
# on time step 89495 (time=89.495), 0.0316501 s/step
# Meep progress: 89.612/100.0 = 89.6% done in 2907.8s, 337.1s to go
# on time step 89622 (time=89.622), 0.0317182 s/step
# Meep progress: 89.737/100.0 = 89.7% done in 2911.8s, 333.0s to go
# on time step 89747 (time=89.747), 0.0320132 s/step
# Meep progress: 89.863/100.0 = 89.9% done in 2915.8s, 328.9s to go
# on time step 89873 (time=89.873), 0.0318079 s/step
# Meep progress: 89.989/100.0 = 90.0% done in 2919.8s, 324.8s to go
# on time step 89999 (time=89.999), 0.03194 s/step
# Meep progress: 90.114/100.0 = 90.1% done in 2923.8s, 320.8s to go
# on time step 90124 (time=90.124), 0.0320369 s/step
# Meep progress: 90.238/100.0 = 90.2% done in 2927.9s, 316.7s to go
# on time step 90248 (time=90.248), 0.0323252 s/step
# Meep progress: 90.363/100.0 = 90.4% done in 2931.9s, 312.7s to go
# on time step 90372 (time=90.372), 0.0323742 s/step
# Meep progress: 90.486/100.0 = 90.5% done in 2935.9s, 308.7s to go
# on time step 90496 (time=90.496), 0.0324936 s/step
# Meep progress: 90.61/100.0 = 90.6% done in 2939.9s, 304.7s to go
# on time step 90620 (time=90.62), 0.0325294 s/step
# Meep progress: 90.732/100.0 = 90.7% done in 2943.9s, 300.7s to go
# on time step 90743 (time=90.743), 0.0327283 s/step
# Meep progress: 90.855/100.0 = 90.9% done in 2947.9s, 296.7s to go
# on time step 90866 (time=90.866), 0.0326763 s/step
# Meep progress: 90.979/100.0 = 91.0% done in 2952.0s, 292.7s to go
# on time step 90990 (time=90.99), 0.0324665 s/step
# Meep progress: 91.105/100.0 = 91.1% done in 2956.0s, 288.6s to go
# on time step 91117 (time=91.117), 0.0317175 s/step
# Meep progress: 91.23/100.0 = 91.2% done in 2960.0s, 284.5s to go
# on time step 91241 (time=91.241), 0.0324691 s/step
# Meep progress: 91.35300000000001/100.0 = 91.4% done in 2964.0s, 280.6s to go
# on time step 91365 (time=91.365), 0.0325143 s/step
# Meep progress: 91.476/100.0 = 91.5% done in 2968.1s, 276.6s to go
# on time step 91487 (time=91.487), 0.0328866 s/step
# Meep progress: 91.599/100.0 = 91.6% done in 2972.1s, 272.6s to go
# on time step 91611 (time=91.611), 0.0324635 s/step
# Meep progress: 91.72200000000001/100.0 = 91.7% done in 2976.1s, 268.6s to go
# on time step 91735 (time=91.735), 0.0323044 s/step
# Meep progress: 91.85000000000001/100.0 = 91.9% done in 2980.1s, 264.4s to go
# on time step 91862 (time=91.862), 0.0317005 s/step
# Meep progress: 91.97200000000001/100.0 = 92.0% done in 2984.1s, 260.5s to go
# on time step 91984 (time=91.984), 0.0328657 s/step
# Meep progress: 92.096/100.0 = 92.1% done in 2988.1s, 256.5s to go
# on time step 92108 (time=92.108), 0.0324135 s/step
# Meep progress: 92.21900000000001/100.0 = 92.2% done in 2992.1s, 252.5s to go
# on time step 92231 (time=92.231), 0.0326396 s/step
# Meep progress: 92.343/100.0 = 92.3% done in 2996.2s, 248.4s to go
# on time step 92355 (time=92.355), 0.0324668 s/step
# Meep progress: 92.46600000000001/100.0 = 92.5% done in 3000.2s, 244.5s to go
# on time step 92478 (time=92.478), 0.0327351 s/step
# Meep progress: 92.589/100.0 = 92.6% done in 3004.2s, 240.5s to go
# on time step 92601 (time=92.601), 0.0327618 s/step
# Meep progress: 92.712/100.0 = 92.7% done in 3008.2s, 236.5s to go
# on time step 92724 (time=92.724), 0.0325956 s/step
# Meep progress: 92.83500000000001/100.0 = 92.8% done in 3012.2s, 232.5s to go
# on time step 92847 (time=92.847), 0.0325561 s/step
# Meep progress: 92.959/100.0 = 93.0% done in 3016.3s, 228.5s to go
# on time step 92971 (time=92.971), 0.0324568 s/step
# Meep progress: 93.08200000000001/100.0 = 93.1% done in 3020.3s, 224.5s to go
# on time step 93094 (time=93.094), 0.0326158 s/step
# Meep progress: 93.209/100.0 = 93.2% done in 3024.3s, 220.3s to go
# on time step 93222 (time=93.222), 0.0314706 s/step
# Meep progress: 93.334/100.0 = 93.3% done in 3028.3s, 216.3s to go
# on time step 93346 (time=93.346), 0.0322637 s/step
# Meep progress: 93.461/100.0 = 93.5% done in 3032.3s, 212.2s to go
# on time step 93474 (time=93.474), 0.0314256 s/step
# Meep progress: 93.587/100.0 = 93.6% done in 3036.3s, 208.1s to go
# on time step 93600 (time=93.6), 0.0317747 s/step
# Meep progress: 93.715/100.0 = 93.7% done in 3040.4s, 203.9s to go
# on time step 93727 (time=93.727), 0.0316077 s/step
# Meep progress: 93.84100000000001/100.0 = 93.8% done in 3044.4s, 199.8s to go
# on time step 93854 (time=93.854), 0.0316036 s/step
# Meep progress: 93.968/100.0 = 94.0% done in 3048.4s, 195.7s to go
# on time step 93981 (time=93.981), 0.031665 s/step
# Meep progress: 94.093/100.0 = 94.1% done in 3052.4s, 191.6s to go
# on time step 94105 (time=94.105), 0.0322591 s/step
# Meep progress: 94.215/100.0 = 94.2% done in 3056.4s, 187.7s to go
# on time step 94227 (time=94.227), 0.0327899 s/step
# Meep progress: 94.337/100.0 = 94.3% done in 3060.4s, 183.7s to go
# on time step 94349 (time=94.349), 0.0329972 s/step
# Meep progress: 94.461/100.0 = 94.5% done in 3064.4s, 179.7s to go
# on time step 94474 (time=94.474), 0.0322349 s/step
# Meep progress: 94.584/100.0 = 94.6% done in 3068.4s, 175.7s to go
# on time step 94596 (time=94.596), 0.0327921 s/step
# Meep progress: 94.705/100.0 = 94.7% done in 3072.5s, 171.8s to go
# on time step 94717 (time=94.717), 0.0332146 s/step
# Meep progress: 94.82600000000001/100.0 = 94.8% done in 3076.5s, 167.9s to go
# on time step 94839 (time=94.839), 0.032961 s/step
# Meep progress: 94.955/100.0 = 95.0% done in 3080.5s, 163.7s to go
# on time step 94967 (time=94.967), 0.0313883 s/step
# Meep progress: 95.08200000000001/100.0 = 95.1% done in 3084.5s, 159.5s to go
# on time step 95094 (time=95.094), 0.0315194 s/step
# Meep progress: 95.208/100.0 = 95.2% done in 3088.5s, 155.5s to go
# on time step 95220 (time=95.22), 0.031805 s/step
# Meep progress: 95.334/100.0 = 95.3% done in 3092.6s, 151.4s to go
# on time step 95346 (time=95.346), 0.0319117 s/step
# Meep progress: 95.459/100.0 = 95.5% done in 3096.6s, 147.3s to go
# on time step 95471 (time=95.471), 0.0322281 s/step
# Meep progress: 95.583/100.0 = 95.6% done in 3100.6s, 143.3s to go
# on time step 95595 (time=95.595), 0.0322961 s/step
# Meep progress: 95.70700000000001/100.0 = 95.7% done in 3104.6s, 139.3s to go
# on time step 95718 (time=95.718), 0.032563 s/step
# Meep progress: 95.828/100.0 = 95.8% done in 3108.6s, 135.3s to go
# on time step 95839 (time=95.839), 0.0332179 s/step
# Meep progress: 95.949/100.0 = 95.9% done in 3112.7s, 131.4s to go
# on time step 95960 (time=95.96), 0.0331561 s/step
# Meep progress: 96.072/100.0 = 96.1% done in 3116.7s, 127.4s to go
# on time step 96082 (time=96.082), 0.0329115 s/step
# Meep progress: 96.19/100.0 = 96.2% done in 3120.7s, 123.6s to go
# on time step 96200 (time=96.2), 0.0340403 s/step
# Meep progress: 96.307/100.0 = 96.3% done in 3124.7s, 119.8s to go
# on time step 96317 (time=96.317), 0.0343046 s/step
# Meep progress: 96.424/100.0 = 96.4% done in 3128.7s, 116.0s to go
# on time step 96435 (time=96.435), 0.0341579 s/step
# Meep progress: 96.543/100.0 = 96.5% done in 3132.7s, 112.2s to go
# on time step 96554 (time=96.554), 0.0338825 s/step
# Meep progress: 96.665/100.0 = 96.7% done in 3136.7s, 108.2s to go
# on time step 96676 (time=96.676), 0.032811 s/step
# Meep progress: 96.783/100.0 = 96.8% done in 3140.7s, 104.4s to go
# on time step 96795 (time=96.795), 0.0337118 s/step
# Meep progress: 96.906/100.0 = 96.9% done in 3144.8s, 100.4s to go
# on time step 96918 (time=96.918), 0.0326797 s/step
# Meep progress: 97.033/100.0 = 97.0% done in 3148.8s, 96.3s to go
# on time step 97046 (time=97.046), 0.0314213 s/step
# Meep progress: 97.158/100.0 = 97.2% done in 3152.8s, 92.2s to go
# on time step 97171 (time=97.171), 0.0321382 s/step
# Meep progress: 97.283/100.0 = 97.3% done in 3156.8s, 88.2s to go
# on time step 97295 (time=97.295), 0.0323019 s/step
# Meep progress: 97.404/100.0 = 97.4% done in 3160.8s, 84.2s to go
# on time step 97417 (time=97.417), 0.0329605 s/step
# Meep progress: 97.528/100.0 = 97.5% done in 3164.8s, 80.2s to go
# on time step 97540 (time=97.54), 0.0326224 s/step
# Meep progress: 97.652/100.0 = 97.7% done in 3168.9s, 76.2s to go
# on time step 97664 (time=97.664), 0.0325198 s/step
# Meep progress: 97.774/100.0 = 97.8% done in 3172.9s, 72.2s to go
# on time step 97785 (time=97.785), 0.0331389 s/step
# Meep progress: 97.893/100.0 = 97.9% done in 3176.9s, 68.4s to go
# on time step 97904 (time=97.904), 0.0336296 s/step
# Meep progress: 98.013/100.0 = 98.0% done in 3180.9s, 64.5s to go
# on time step 98024 (time=98.024), 0.0333755 s/step
# Meep progress: 98.134/100.0 = 98.1% done in 3184.9s, 60.6s to go
# on time step 98145 (time=98.145), 0.0330683 s/step
# Meep progress: 98.256/100.0 = 98.3% done in 3189.0s, 56.6s to go
# on time step 98266 (time=98.266), 0.033165 s/step
# Meep progress: 98.375/100.0 = 98.4% done in 3193.0s, 52.7s to go
# on time step 98384 (time=98.384), 0.0339615 s/step
# Meep progress: 98.492/100.0 = 98.5% done in 3197.0s, 48.9s to go
# on time step 98502 (time=98.502), 0.0341653 s/step
# Meep progress: 98.611/100.0 = 98.6% done in 3201.0s, 45.1s to go
# on time step 98622 (time=98.622), 0.0335548 s/step
# Meep progress: 98.732/100.0 = 98.7% done in 3205.0s, 41.2s to go
# on time step 98743 (time=98.743), 0.0332803 s/step
# Meep progress: 98.85300000000001/100.0 = 98.9% done in 3209.0s, 37.2s to go
# on time step 98864 (time=98.864), 0.0332184 s/step
# Meep progress: 98.974/100.0 = 99.0% done in 3213.1s, 33.3s to go
# on time step 98985 (time=98.985), 0.0332513 s/step
# Meep progress: 99.095/100.0 = 99.1% done in 3217.1s, 29.4s to go
# on time step 99107 (time=99.107), 0.0330408 s/step
# Meep progress: 99.21600000000001/100.0 = 99.2% done in 3221.1s, 25.5s to go
# on time step 99227 (time=99.227), 0.0333348 s/step
# Meep progress: 99.339/100.0 = 99.3% done in 3225.1s, 21.5s to go
# on time step 99350 (time=99.35), 0.0326874 s/step
# Meep progress: 99.462/100.0 = 99.5% done in 3229.2s, 17.5s to go
# on time step 99473 (time=99.473), 0.0325876 s/step
# Meep progress: 99.584/100.0 = 99.6% done in 3233.2s, 13.5s to go
# on time step 99595 (time=99.595), 0.0328569 s/step
# Meep progress: 99.709/100.0 = 99.7% done in 3237.2s, 9.4s to go
# on time step 99719 (time=99.719), 0.0324148 s/step
# Meep progress: 99.83/100.0 = 99.8% done in 3241.2s, 5.5s to go
# on time step 99840 (time=99.84), 0.0330749 s/step
# Meep progress: 99.95100000000001/100.0 = 100.0% done in 3245.2s, 1.6s to go
# on time step 99960 (time=99.96), 0.0333472 s/step
# run 0 finished at t = 100.0 (100000 timesteps)
#      block, center = (-7.3,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.8,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.6,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,2.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,2.8,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,3.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      ...(+ 18 objects not shown)...

# %%
# 取得 Ez 場量在指定位置的振福資訊
amplitude_data = sim.get_array(component=mp.Ez,cmplx = True)

# 計算觀測點的相對座標
x_obs = -0.5 * sx + dpml + dsub + gh + 0.01
y_obs_start = -0.5 * sy + gp/2

# 儲存振福資訊的列表
amplitude_list = []

# 遍歷每個觀測點
for j in range(num_cells):
    y_obs = y_obs_start + (j * gp)
    # 計算觀測點在陣列中的索引位置
    x_index = int(round((x_obs) * sim.resolution))
    y_index = int(round((y_obs) * sim.resolution))
    # 取得振福資訊
    amplitude = np.abs(amplitude_data[x_index, y_index])
    amplitude_list.append(amplitude)
    
   
# 印出觀測點的振福資訊
'''
for j, amplitude in enumerate(amplitude_list):
    print(f"觀測點 {j+1} 的振福資訊: {amplitude/np.max(amplitude_list)}")'''

print(amplitude_list)
# Out:
# [0.02664316802206948, 0.02764490983993126, 0.5625308904368567, 0.020910414066141393, 0.025415664724047708, 0.5747552007127661, 0.03775478971106455, 0.03094068707874085, 0.5749753096360157]

# %%
# 取得 Ez 場量在指定位置的相位資訊
phase_data = np.fft.fft(np.array(sim.get_array(component = mp.Ez , cmplx = True)))
# = sim.get_array(component=mp.Ez, cmplx=True)

# 計算觀測點的相對座標
x_obs = -0.5 * sx + dpml + dsub + gh + 0.01
y_obs_start = -0.5 * sy + gp / 2

# 儲存相位資訊的列表
phase_list = []

# 遍歷每個觀測點
for j in range(3):
    y_obs = y_obs_start + j * gp
    # 計算觀測點在陣列中的索引位置
    x_index = int(round((x_obs ) * sim.resolution))
    y_index = int(round((y_obs ) * sim.resolution))
    # 取得相位資訊，加上參考相位
    phase = np.angle(phase_data[x_index, y_index])
    phase_list.append(phase)

print(phase_list)

'''
# 取得 Ez 場量在指定位置的相位資訊
phase_data = np.fft.fft(np.array(sim.get_array(component = mp.Ez , cmplx = True)))
#phase_data = sim.get_array(component = mp.Ez)

# 計算觀測點的相對座標
x_obs = -0.5 * sx + dpml + dsub + gh +0.01
y_obs_start = -0.5 * sy #+ gp/2 

# 儲存相位資訊的列表
phase_list = []

# 遍歷每個觀測點
for j in range(240):
    y_obs = y_obs_start + (j * 0.0025)
    # 計算觀測點在陣列中的索引位置
    x_index = int(round((x_obs / sim.cell_size.x ) * sim.resolution))
    y_index = int(round((y_obs / sim.cell_size.y ) * sim.resolution))
    # 取得相位資訊
    phase = np.angle(phase_data[x_index, y_index])
    phase_list.append(phase)

# 印出觀測點的相位資訊
for j, phase in enumerate(phase_list):
    print(f"觀測點 {j+1} 的相位資訊: {phase}")'''
# Out:
# [-2.963595614886371, -2.610489650240004, -2.2540430043038624]
# '\n# 取得 Ez 場量在指定位置的相位資訊\nphase_data = np.fft.fft(np.array(sim.get_array(component = mp.Ez , cmplx = True)))\n#phase_data = sim.get_array(component = mp.Ez)\n\n# 計算觀測點的相對座標\nx_obs = -0.5 * sx + dpml + dsub + gh +0.01\ny_obs_start = -0.5 * sy #+ gp/2 \n\n# 儲存相位資訊的列表\nphase_list = []\n\n# 遍歷每個觀測點\nfor j in range(240):\n    y_obs = y_obs_start + (j * 0.0025)\n    # 計算觀測點在陣列中的索引位置\n    x_index = int(round((x_obs / sim.cell_size.x ) * sim.resolution))\n    y_index = int(round((y_obs / sim.cell_size.y ) * sim.resolution))\n    # 取得相位資訊\n    phase = np.angle(phase_data[x_index, y_index])\n    phase_list.append(phase)\n\n# 印出觀測點的相位資訊\nfor j, phase in enumerate(phase_list):\n    print(f"觀測點 {j+1} 的相位資訊: {phase}")'

# %%
sim.reset_meep()
f = plt.figure(dpi = 100)
Animate = mp.Animate2D(fields=mp.Ez, f=f, realtime=False, normalize=True)
plt.close()

sim.run(mp.at_every(1, Animate), until = 50)
plt.close()

filename = "1 alpha alpha beta structure.mp4"
Animate.to_mp4(10, filename)

from IPython.display import Video

Video(filename)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000109196 s
# Working in 2D dimensions.
# Computational cell is 17.1 x 6 x 0 with resolution 50
#      block, center = (-7.26,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.9,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.3,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-1.7,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-1.1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.5,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.7,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.3,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.9,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      ...(+ 21 objects not shown)...
# time for set_epsilon = 0.329889 s
# -----------
# Meep: using complex fields.
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (-7.26,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.9,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.3,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-1.7,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-1.1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.5,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.7,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.3,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.9,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      ...(+ 21 objects not shown)...
# Meep progress: 19.56/50.0 = 39.1% done in 4.0s, 6.2s to go
# on time step 1956 (time=19.56), 0.00204583 s/step
# Meep progress: 37.72/50.0 = 75.4% done in 8.0s, 2.6s to go
# on time step 3772 (time=37.72), 0.00220346 s/step
# Normalizing field data...
# run 3 finished at t = 50.0 (5000 timesteps)
# Generating MP4...
# <video src="1 alpha alpha beta structure.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
