# %%
import meep as mp
import numpy as np
import math
import matplotlib.pyplot as plt

resolution = 500  # pixels/μm

dpml = 1.0  # PML thickness
dsub = 0.5  # substrate thickness
dcaa = 0.06  # air rigion for alpha structure
# alpha structure is that one period = 200nm，sigle cell width = 80nm locate at center
dcab = 0.025 # air rigion for beta structure 
# beta structure is that one period = 200nm，sigle cell width = 150nm locate at center
gp = 0.2  # grating periodicity
gh = 0.6  # grating height
gwa = 0.08 # alpha grating cell width
gwb = 0.15 # beta grating cell width

num_cells = 3  # number of grating unit cells

# air region thickness adjacent to grating
dair = 14 

wvl = 0.532  # center wavelength
fcen = 1 / wvl  # center frequency

k_point = mp.Vector3()

glass = mp.Medium(index= 2.6678)

pml_layers = [mp.PML(thickness=dpml, direction = mp.X )]

symmetries = [mp.Mirror(mp.Y)]

sx = dpml + dsub + gh + dair + dpml
sy = gp*num_cells
cell_size = mp.Vector3(sx, sy)

sources = [
    mp.Source(
        mp.ContinuousSource(frequency = 2), # frequemcy = 2原因是 meep 的 C=1，所以 1/? = 0.5 um，?即是2
        component = mp.Ez,
        center = mp.Vector3(-0.5 * sx + dpml ),
        size = mp.Vector3(y=sy),
    )
]

geometry = [
    mp.Block(
        material=glass,
        size=mp.Vector3(dsub, mp.inf, mp.inf),
        center=mp.Vector3(-0.5 * sx + dpml + 0.04 + dsub/2),
    )
]

# %%
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp/2 + (j * 3 * gp),
                #-0.5 * sy + gp/2 ,
            ),
        )
    )

for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwa, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + gp + gp/2 ,
            ),
        )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwa, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + 2*gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + 2*gp + gp/2 ,
            ),
        )
    )

# %%
sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
    k_point = mp.Vector3(),
)

# %matplotlib inline
plt.figure(dpi = 125)
sim.plot2D()
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (-7.26,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.77556e-17,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.6,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.8,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
sim.run(until = 100)
plt.figure(dpi = 100)
sim.plot2D(fields=mp.Ez)
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000765085 s
# Working in 2D dimensions.
# Computational cell is 17.1 x 0.6 x 0 with resolution 500
#      block, center = (-7.26,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.77556e-17,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.6,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.8,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
# time for set_epsilon = 2.65499 s
# -----------
# Meep progress: 0.14200000000000002/100.0 = 0.1% done in 4.0s, 2818.1s to go
# on time step 142 (time=0.142), 0.0282222 s/step
# Meep progress: 0.295/100.0 = 0.3% done in 8.0s, 2709.2s to go
# on time step 295 (time=0.295), 0.0261937 s/step
# Meep progress: 0.445/100.0 = 0.4% done in 12.0s, 2692.9s to go
# on time step 445 (time=0.445), 0.0268057 s/step
# Meep progress: 0.593/100.0 = 0.6% done in 16.0s, 2690.5s to go
# on time step 593 (time=0.593), 0.0271078 s/step
# Meep progress: 0.738/100.0 = 0.7% done in 20.1s, 2698.2s to go
# on time step 738 (time=0.738), 0.0276567 s/step
# Meep progress: 0.873/100.0 = 0.9% done in 24.1s, 2733.7s to go
# on time step 873 (time=0.873), 0.0297282 s/step
# Meep progress: 0.996/100.0 = 1.0% done in 28.1s, 2790.9s to go
# on time step 996 (time=0.996), 0.0325283 s/step
# Meep progress: 1.116/100.0 = 1.1% done in 32.1s, 2844.1s to go
# on time step 1116 (time=1.116), 0.0335027 s/step
# Meep progress: 1.238/100.0 = 1.2% done in 36.1s, 2881.6s to go
# on time step 1238 (time=1.238), 0.0329709 s/step
# Meep progress: 1.357/100.0 = 1.4% done in 40.1s, 2917.5s to go
# on time step 1357 (time=1.357), 0.0337258 s/step
# Meep progress: 1.468/100.0 = 1.5% done in 44.1s, 2962.9s to go
# on time step 1468 (time=1.468), 0.036093 s/step
# Meep progress: 1.571/100.0 = 1.6% done in 48.2s, 3016.8s to go
# on time step 1571 (time=1.571), 0.0388967 s/step
# Meep progress: 1.669/100.0 = 1.7% done in 52.2s, 3074.1s to go
# on time step 1669 (time=1.669), 0.0410902 s/step
# Meep progress: 1.774/100.0 = 1.8% done in 56.2s, 3111.1s to go
# on time step 1774 (time=1.774), 0.0381787 s/step
# Meep progress: 1.867/100.0 = 1.9% done in 60.2s, 3166.5s to go
# on time step 1867 (time=1.867), 0.0436051 s/step
# Meep progress: 1.958/100.0 = 2.0% done in 64.3s, 3217.8s to go
# on time step 1958 (time=1.958), 0.0441522 s/step
# Meep progress: 2.044/100.0 = 2.0% done in 68.3s, 3272.7s to go
# on time step 2044 (time=2.044), 0.0468061 s/step
# Meep progress: 2.134/100.0 = 2.1% done in 72.3s, 3316.3s to go
# on time step 2134 (time=2.134), 0.0447081 s/step
# Meep progress: 2.222/100.0 = 2.2% done in 76.3s, 3359.2s to go
# on time step 2222 (time=2.222), 0.045713 s/step
# Meep progress: 2.312/100.0 = 2.3% done in 80.4s, 3395.4s to go
# on time step 2312 (time=2.312), 0.0446857 s/step
# Meep progress: 2.399/100.0 = 2.4% done in 84.4s, 3432.4s to go
# on time step 2399 (time=2.399), 0.0460336 s/step
# Meep progress: 2.488/100.0 = 2.5% done in 88.4s, 3463.6s to go
# on time step 2488 (time=2.488), 0.0450134 s/step
# Meep progress: 2.576/100.0 = 2.6% done in 92.4s, 3494.1s to go
# on time step 2576 (time=2.576), 0.0456072 s/step
# Meep progress: 2.6630000000000003/100.0 = 2.7% done in 96.4s, 3523.2s to go
# on time step 2663 (time=2.663), 0.0459805 s/step
# Meep progress: 2.749/100.0 = 2.7% done in 100.4s, 3551.6s to go
# on time step 2749 (time=2.749), 0.0465436 s/step
# Meep progress: 2.841/100.0 = 2.8% done in 104.4s, 3571.3s to go
# on time step 2841 (time=2.841), 0.0438176 s/step
# Meep progress: 2.93/100.0 = 2.9% done in 108.5s, 3593.0s to go
# on time step 2930 (time=2.93), 0.0452252 s/step
# Meep progress: 3.012/100.0 = 3.0% done in 112.5s, 3621.6s to go
# on time step 3012 (time=3.012), 0.0489936 s/step
# Meep progress: 3.097/100.0 = 3.1% done in 116.5s, 3645.1s to go
# on time step 3097 (time=3.097), 0.0473639 s/step
# Meep progress: 3.1790000000000003/100.0 = 3.2% done in 120.5s, 3671.3s to go
# on time step 3179 (time=3.179), 0.0493251 s/step
# Meep progress: 3.262/100.0 = 3.3% done in 124.6s, 3694.7s to go
# on time step 3262 (time=3.262), 0.048669 s/step
# Meep progress: 3.349/100.0 = 3.3% done in 128.6s, 3711.7s to go
# on time step 3349 (time=3.349), 0.0462805 s/step
# Meep progress: 3.4370000000000003/100.0 = 3.4% done in 132.7s, 3726.8s to go
# on time step 3437 (time=3.437), 0.0458769 s/step
# Meep progress: 3.52/100.0 = 3.5% done in 136.7s, 3745.7s to go
# on time step 3520 (time=3.52), 0.0482637 s/step
# Meep progress: 3.608/100.0 = 3.6% done in 140.7s, 3758.7s to go
# on time step 3608 (time=3.608), 0.0458253 s/step
# Meep progress: 3.693/100.0 = 3.7% done in 144.7s, 3774.5s to go
# on time step 3693 (time=3.693), 0.0475894 s/step
# Meep progress: 3.778/100.0 = 3.8% done in 148.8s, 3788.6s to go
# on time step 3778 (time=3.778), 0.0472472 s/step
# Meep progress: 3.865/100.0 = 3.9% done in 152.8s, 3799.8s to go
# on time step 3865 (time=3.865), 0.0461031 s/step
# Meep progress: 3.955/100.0 = 4.0% done in 156.8s, 3807.8s to go
# on time step 3955 (time=3.955), 0.0447939 s/step
# Meep progress: 4.043/100.0 = 4.0% done in 160.8s, 3817.3s to go
# on time step 4043 (time=4.043), 0.0458826 s/step
# Meep progress: 4.13/100.0 = 4.1% done in 164.9s, 3827.1s to go
# on time step 4130 (time=4.13), 0.0463032 s/step
# Meep progress: 4.218/100.0 = 4.2% done in 168.9s, 3835.0s to go
# on time step 4218 (time=4.218), 0.0456279 s/step
# Meep progress: 4.303/100.0 = 4.3% done in 172.9s, 3845.5s to go
# on time step 4303 (time=4.303), 0.0473692 s/step
# Meep progress: 4.385/100.0 = 4.4% done in 176.9s, 3857.8s to go
# on time step 4385 (time=4.385), 0.0489296 s/step
# Meep progress: 4.465/100.0 = 4.5% done in 181.0s, 3872.3s to go
# on time step 4465 (time=4.465), 0.0506634 s/step
# Meep progress: 4.547/100.0 = 4.5% done in 185.0s, 3883.5s to go
# on time step 4547 (time=4.547), 0.0489568 s/step
# Meep progress: 4.631/100.0 = 4.6% done in 189.0s, 3892.8s to go
# on time step 4631 (time=4.631), 0.0480069 s/step
# Meep progress: 4.711/100.0 = 4.7% done in 193.1s, 3905.4s to go
# on time step 4711 (time=4.711), 0.0505998 s/step
# Meep progress: 4.792/100.0 = 4.8% done in 197.1s, 3915.9s to go
# on time step 4792 (time=4.792), 0.0496135 s/step
# Meep progress: 4.875/100.0 = 4.9% done in 201.1s, 3924.4s to go
# on time step 4875 (time=4.875), 0.0484456 s/step
# Meep progress: 4.96/100.0 = 5.0% done in 205.1s, 3930.9s to go
# on time step 4960 (time=4.96), 0.0473523 s/step
# Meep progress: 5.045/100.0 = 5.0% done in 209.1s, 3936.5s to go
# on time step 5045 (time=5.045), 0.0470831 s/step
# Meep progress: 5.133/100.0 = 5.1% done in 213.2s, 3939.8s to go
# on time step 5133 (time=5.133), 0.045737 s/step
# Meep progress: 5.219/100.0 = 5.2% done in 217.2s, 3944.6s to go
# on time step 5219 (time=5.219), 0.0468766 s/step
# Meep progress: 5.306/100.0 = 5.3% done in 221.2s, 3948.2s to go
# on time step 5306 (time=5.306), 0.0461925 s/step
# Meep progress: 5.389/100.0 = 5.4% done in 225.3s, 3954.6s to go
# on time step 5389 (time=5.389), 0.0484592 s/step
# Meep progress: 5.474/100.0 = 5.5% done in 229.3s, 3959.4s to go
# on time step 5474 (time=5.474), 0.0475044 s/step
# Meep progress: 5.556/100.0 = 5.6% done in 233.3s, 3966.0s to go
# on time step 5556 (time=5.556), 0.0490507 s/step
# Meep progress: 5.643/100.0 = 5.6% done in 237.4s, 3968.9s to go
# on time step 5643 (time=5.643), 0.0464844 s/step
# Meep progress: 5.728/100.0 = 5.7% done in 241.4s, 3972.8s to go
# on time step 5728 (time=5.728), 0.0474041 s/step
# Meep progress: 5.809/100.0 = 5.8% done in 245.5s, 3979.9s to go
# on time step 5809 (time=5.809), 0.0501792 s/step
# Meep progress: 5.88/100.0 = 5.9% done in 249.5s, 3993.2s to go
# on time step 5880 (time=5.88), 0.0565451 s/step
# Meep progress: 5.947/100.0 = 5.9% done in 253.5s, 4008.9s to go
# on time step 5947 (time=5.947), 0.0599299 s/step
# Meep progress: 6.024/100.0 = 6.0% done in 257.5s, 4017.8s to go
# on time step 6024 (time=6.024), 0.0527056 s/step
# Meep progress: 6.094/100.0 = 6.1% done in 261.6s, 4030.9s to go
# on time step 6094 (time=6.094), 0.057697 s/step
# Meep progress: 6.164/100.0 = 6.2% done in 265.6s, 4043.3s to go
# on time step 6164 (time=6.164), 0.0573414 s/step
# Meep progress: 6.2330000000000005/100.0 = 6.2% done in 269.6s, 4056.0s to go
# on time step 6233 (time=6.233), 0.0581282 s/step
# Meep progress: 6.303/100.0 = 6.3% done in 273.6s, 4067.5s to go
# on time step 6303 (time=6.303), 0.0572659 s/step
# Meep progress: 6.376/100.0 = 6.4% done in 277.7s, 4077.4s to go
# on time step 6376 (time=6.376), 0.0554826 s/step
# Meep progress: 6.445/100.0 = 6.4% done in 281.7s, 4089.0s to go
# on time step 6445 (time=6.445), 0.058135 s/step
# Meep progress: 6.514/100.0 = 6.5% done in 285.7s, 4100.2s to go
# on time step 6514 (time=6.514), 0.0580349 s/step
# Meep progress: 6.596/100.0 = 6.6% done in 289.7s, 4102.5s to go
# on time step 6596 (time=6.596), 0.0489178 s/step
# Meep progress: 6.679/100.0 = 6.7% done in 293.7s, 4104.3s to go
# on time step 6679 (time=6.679), 0.0486169 s/step
# Meep progress: 6.752/100.0 = 6.8% done in 297.8s, 4112.1s to go
# on time step 6752 (time=6.752), 0.0549021 s/step
# Meep progress: 6.824/100.0 = 6.8% done in 301.8s, 4120.4s to go
# on time step 6824 (time=6.824), 0.0557615 s/step
# Meep progress: 6.902/100.0 = 6.9% done in 305.8s, 4124.7s to go
# on time step 6902 (time=6.902), 0.0515316 s/step
# Meep progress: 6.977/100.0 = 7.0% done in 309.8s, 4130.8s to go
# on time step 6977 (time=6.977), 0.0537047 s/step
# Meep progress: 7.049/100.0 = 7.0% done in 313.8s, 4138.3s to go
# on time step 7049 (time=7.049), 0.0557143 s/step
# Meep progress: 7.123/100.0 = 7.1% done in 317.8s, 4144.2s to go
# on time step 7123 (time=7.123), 0.0540551 s/step
# Meep progress: 7.197/100.0 = 7.2% done in 321.9s, 4150.5s to go
# on time step 7197 (time=7.197), 0.0545848 s/step
# Meep progress: 7.2700000000000005/100.0 = 7.3% done in 325.9s, 4157.4s to go
# on time step 7270 (time=7.27), 0.0557024 s/step
# Meep progress: 7.343/100.0 = 7.3% done in 330.0s, 4163.5s to go
# on time step 7343 (time=7.343), 0.0549068 s/step
# Meep progress: 7.413/100.0 = 7.4% done in 334.0s, 4171.0s to go
# on time step 7413 (time=7.413), 0.0571629 s/step
# Meep progress: 7.487/100.0 = 7.5% done in 338.0s, 4176.2s to go
# on time step 7487 (time=7.487), 0.054387 s/step
# Meep progress: 7.5600000000000005/100.0 = 7.6% done in 342.0s, 4182.0s to go
# on time step 7560 (time=7.56), 0.0552077 s/step
# Meep progress: 7.634/100.0 = 7.6% done in 346.0s, 4186.8s to go
# on time step 7634 (time=7.634), 0.0543623 s/step
# Meep progress: 7.707/100.0 = 7.7% done in 350.1s, 4192.4s to go
# on time step 7707 (time=7.707), 0.0555051 s/step
# Meep progress: 7.779/100.0 = 7.8% done in 354.1s, 4198.1s to go
# on time step 7779 (time=7.779), 0.055885 s/step
# Meep progress: 7.855/100.0 = 7.9% done in 358.1s, 4201.2s to go
# on time step 7855 (time=7.855), 0.0528835 s/step
# Meep progress: 7.9270000000000005/100.0 = 7.9% done in 362.2s, 4206.7s to go
# on time step 7927 (time=7.927), 0.0560752 s/step
# Meep progress: 8.001/100.0 = 8.0% done in 366.2s, 4210.9s to go
# on time step 8001 (time=8.001), 0.0545802 s/step
# Meep progress: 8.071/100.0 = 8.1% done in 370.2s, 4216.9s to go
# on time step 8071 (time=8.071), 0.0573223 s/step
# Meep progress: 8.143/100.0 = 8.1% done in 374.2s, 4221.6s to go
# on time step 8143 (time=8.143), 0.0556719 s/step
# Meep progress: 8.216/100.0 = 8.2% done in 378.2s, 4225.5s to go
# on time step 8216 (time=8.216), 0.0548553 s/step
# Meep progress: 8.286/100.0 = 8.3% done in 382.3s, 4231.1s to go
# on time step 8286 (time=8.286), 0.0574925 s/step
# Meep progress: 8.36/100.0 = 8.4% done in 386.3s, 4234.4s to go
# on time step 8360 (time=8.36), 0.0543478 s/step
# Meep progress: 8.434000000000001/100.0 = 8.4% done in 390.3s, 4237.8s to go
# on time step 8434 (time=8.434), 0.0547029 s/step
# Meep progress: 8.509/100.0 = 8.5% done in 394.3s, 4240.1s to go
# on time step 8509 (time=8.509), 0.0534558 s/step
# Meep progress: 8.582/100.0 = 8.6% done in 398.4s, 4243.5s to go
# on time step 8582 (time=8.582), 0.0550117 s/step
# Meep progress: 8.657/100.0 = 8.7% done in 402.4s, 4245.8s to go
# on time step 8657 (time=8.657), 0.0537407 s/step
# Meep progress: 8.726/100.0 = 8.7% done in 406.4s, 4251.3s to go
# on time step 8726 (time=8.726), 0.0585127 s/step
# Meep progress: 8.798/100.0 = 8.8% done in 410.4s, 4254.8s to go
# on time step 8798 (time=8.798), 0.055657 s/step
# Meep progress: 8.870000000000001/100.0 = 8.9% done in 414.5s, 4258.0s to go
# on time step 8870 (time=8.87), 0.0556135 s/step
# Meep progress: 8.941/100.0 = 8.9% done in 418.5s, 4261.8s to go
# on time step 8941 (time=8.941), 0.0564927 s/step
# Meep progress: 9.012/100.0 = 9.0% done in 422.5s, 4265.7s to go
# on time step 9012 (time=9.012), 0.0568301 s/step
# Meep progress: 9.085/100.0 = 9.1% done in 426.5s, 4268.1s to go
# on time step 9085 (time=9.085), 0.0548569 s/step
# Meep progress: 9.161/100.0 = 9.2% done in 430.5s, 4269.2s to go
# on time step 9161 (time=9.161), 0.053133 s/step
# Meep progress: 9.229000000000001/100.0 = 9.2% done in 434.6s, 4274.2s to go
# on time step 9229 (time=9.229), 0.0592601 s/step
# Meep progress: 9.299/100.0 = 9.3% done in 438.6s, 4278.0s to go
# on time step 9299 (time=9.299), 0.0574926 s/step
# Meep progress: 9.367/100.0 = 9.4% done in 442.6s, 4282.5s to go
# on time step 9367 (time=9.367), 0.0588369 s/step
# Meep progress: 9.436/100.0 = 9.4% done in 446.7s, 4286.9s to go
# on time step 9436 (time=9.436), 0.0587721 s/step
# Meep progress: 9.512/100.0 = 9.5% done in 450.7s, 4287.7s to go
# on time step 9512 (time=9.512), 0.0533057 s/step
# Meep progress: 9.586/100.0 = 9.6% done in 454.7s, 4289.0s to go
# on time step 9586 (time=9.586), 0.0543603 s/step
# Meep progress: 9.659/100.0 = 9.7% done in 458.8s, 4290.8s to go
# on time step 9659 (time=9.659), 0.0551024 s/step
# Meep progress: 9.734/100.0 = 9.7% done in 462.8s, 4291.7s to go
# on time step 9734 (time=9.734), 0.0538638 s/step
# Meep progress: 9.808/100.0 = 9.8% done in 466.9s, 4293.2s to go
# on time step 9808 (time=9.808), 0.0549712 s/step
# Meep progress: 9.88/100.0 = 9.9% done in 470.9s, 4295.5s to go
# on time step 9880 (time=9.88), 0.0562973 s/step
# Meep progress: 9.951/100.0 = 10.0% done in 475.0s, 4298.0s to go
# on time step 9951 (time=9.951), 0.0568078 s/step
# Meep progress: 10.022/100.0 = 10.0% done in 479.0s, 4300.2s to go
# on time step 10022 (time=10.022), 0.056469 s/step
# Meep progress: 10.096/100.0 = 10.1% done in 483.0s, 4301.0s to go
# on time step 10096 (time=10.096), 0.0542134 s/step
# Meep progress: 10.171/100.0 = 10.2% done in 487.0s, 4301.0s to go
# on time step 10172 (time=10.172), 0.0533221 s/step
# Meep progress: 10.245000000000001/100.0 = 10.2% done in 491.0s, 4301.9s to go
# on time step 10246 (time=10.246), 0.0548234 s/step
# Meep progress: 10.319/100.0 = 10.3% done in 495.1s, 4302.6s to go
# on time step 10320 (time=10.32), 0.0542813 s/step
# Meep progress: 10.397/100.0 = 10.4% done in 499.1s, 4301.5s to go
# on time step 10398 (time=10.398), 0.0521363 s/step
# Meep progress: 10.471/100.0 = 10.5% done in 503.2s, 4302.1s to go
# on time step 10472 (time=10.472), 0.0543883 s/step
# Meep progress: 10.544/100.0 = 10.5% done in 507.2s, 4303.0s to go
# on time step 10545 (time=10.545), 0.0552752 s/step
# Meep progress: 10.617/100.0 = 10.6% done in 511.2s, 4303.9s to go
# on time step 10618 (time=10.618), 0.0551819 s/step
# Meep progress: 10.691/100.0 = 10.7% done in 515.3s, 4304.2s to go
# on time step 10692 (time=10.692), 0.0545186 s/step
# Meep progress: 10.761000000000001/100.0 = 10.8% done in 519.3s, 4306.3s to go
# on time step 10762 (time=10.762), 0.0571995 s/step
# Meep progress: 10.838000000000001/100.0 = 10.8% done in 523.3s, 4305.2s to go
# on time step 10839 (time=10.839), 0.052468 s/step
# Meep progress: 10.914/100.0 = 10.9% done in 527.3s, 4304.4s to go
# on time step 10915 (time=10.915), 0.0530536 s/step
# Meep progress: 10.986/100.0 = 11.0% done in 531.4s, 4305.3s to go
# on time step 10987 (time=10.987), 0.0557737 s/step
# Meep progress: 11.06/100.0 = 11.1% done in 535.4s, 4305.4s to go
# on time step 11061 (time=11.061), 0.0543704 s/step
# Meep progress: 11.134/100.0 = 11.1% done in 539.4s, 4305.2s to go
# on time step 11135 (time=11.135), 0.0543915 s/step
# Meep progress: 11.212/100.0 = 11.2% done in 543.4s, 4303.5s to go
# on time step 11213 (time=11.213), 0.051639 s/step
# Meep progress: 11.285/100.0 = 11.3% done in 547.5s, 4303.8s to go
# on time step 11286 (time=11.286), 0.0549934 s/step
# Meep progress: 11.358/100.0 = 11.4% done in 551.5s, 4303.9s to go
# on time step 11359 (time=11.359), 0.0553317 s/step
# Meep progress: 11.431000000000001/100.0 = 11.4% done in 555.5s, 4304.2s to go
# on time step 11432 (time=11.432), 0.0551397 s/step
# Meep progress: 11.505/100.0 = 11.5% done in 559.6s, 4304.2s to go
# on time step 11505 (time=11.505), 0.0548665 s/step
# Meep progress: 11.578/100.0 = 11.6% done in 563.6s, 4304.2s to go
# on time step 11578 (time=11.578), 0.0549964 s/step
# Meep progress: 11.652000000000001/100.0 = 11.7% done in 567.6s, 4303.6s to go
# on time step 11653 (time=11.653), 0.0537975 s/step
# Meep progress: 11.727/100.0 = 11.7% done in 571.6s, 4302.7s to go
# on time step 11728 (time=11.728), 0.0540353 s/step
# Meep progress: 11.798/100.0 = 11.8% done in 575.7s, 4303.6s to go
# on time step 11799 (time=11.799), 0.0566662 s/step
# Meep progress: 11.875/100.0 = 11.9% done in 579.7s, 4301.7s to go
# on time step 11877 (time=11.877), 0.0520088 s/step
# Meep progress: 11.946/100.0 = 11.9% done in 583.7s, 4302.3s to go
# on time step 11948 (time=11.948), 0.0565422 s/step
# Meep progress: 12.017/100.0 = 12.0% done in 587.7s, 4302.9s to go
# on time step 12019 (time=12.019), 0.0565052 s/step
# Meep progress: 12.09/100.0 = 12.1% done in 591.7s, 4302.5s to go
# on time step 12092 (time=12.092), 0.0548423 s/step
# Meep progress: 12.164/100.0 = 12.2% done in 595.8s, 4301.9s to go
# on time step 12165 (time=12.165), 0.0549392 s/step
# Meep progress: 12.237/100.0 = 12.2% done in 599.8s, 4301.6s to go
# on time step 12238 (time=12.238), 0.0551576 s/step
# Meep progress: 12.308/100.0 = 12.3% done in 603.8s, 4302.1s to go
# on time step 12309 (time=12.309), 0.0568285 s/step
# Meep progress: 12.381/100.0 = 12.4% done in 607.9s, 4301.7s to go
# on time step 12382 (time=12.382), 0.0550979 s/step
# Meep progress: 12.455/100.0 = 12.5% done in 611.9s, 4300.7s to go
# on time step 12456 (time=12.456), 0.0542383 s/step
# Meep progress: 12.527000000000001/100.0 = 12.5% done in 615.9s, 4300.7s to go
# on time step 12528 (time=12.528), 0.0561811 s/step
# Meep progress: 12.6/100.0 = 12.6% done in 619.9s, 4300.1s to go
# on time step 12601 (time=12.601), 0.0551191 s/step
# Meep progress: 12.668000000000001/100.0 = 12.7% done in 623.9s, 4301.3s to go
# on time step 12670 (time=12.67), 0.0585259 s/step
# Meep progress: 12.74/100.0 = 12.7% done in 628.0s, 4301.1s to go
# on time step 12741 (time=12.741), 0.056409 s/step
# Meep progress: 12.812/100.0 = 12.8% done in 632.0s, 4300.9s to go
# on time step 12813 (time=12.813), 0.0558303 s/step
# Meep progress: 12.884/100.0 = 12.9% done in 636.0s, 4300.4s to go
# on time step 12885 (time=12.885), 0.0556636 s/step
# Meep progress: 12.957/100.0 = 13.0% done in 640.0s, 4299.7s to go
# on time step 12958 (time=12.958), 0.0554871 s/step
# Meep progress: 13.029/100.0 = 13.0% done in 644.1s, 4299.4s to go
# on time step 13030 (time=13.03), 0.0560835 s/step
# Meep progress: 13.1/100.0 = 13.1% done in 648.1s, 4299.4s to go
# on time step 13101 (time=13.101), 0.0564551 s/step
# Meep progress: 13.173/100.0 = 13.2% done in 652.1s, 4298.5s to go
# on time step 13174 (time=13.174), 0.0552447 s/step
# Meep progress: 13.249/100.0 = 13.2% done in 656.2s, 4296.5s to go
# on time step 13250 (time=13.25), 0.0530706 s/step
# Meep progress: 13.322000000000001/100.0 = 13.3% done in 660.2s, 4295.6s to go
# on time step 13323 (time=13.323), 0.05518 s/step
# Meep progress: 13.396/100.0 = 13.4% done in 664.2s, 4294.2s to go
# on time step 13397 (time=13.397), 0.0543799 s/step
# Meep progress: 13.468/100.0 = 13.5% done in 668.2s, 4293.5s to go
# on time step 13469 (time=13.469), 0.0555893 s/step
# Meep progress: 13.543000000000001/100.0 = 13.5% done in 672.3s, 4291.9s to go
# on time step 13543 (time=13.543), 0.0541598 s/step
# Meep progress: 13.614/100.0 = 13.6% done in 676.4s, 4291.7s to go
# on time step 13614 (time=13.614), 0.0571947 s/step
# Meep progress: 13.69/100.0 = 13.7% done in 680.4s, 4289.6s to go
# on time step 13690 (time=13.69), 0.0529836 s/step
# Meep progress: 13.765/100.0 = 13.8% done in 684.4s, 4287.6s to go
# on time step 13765 (time=13.765), 0.0535027 s/step
# Meep progress: 13.84/100.0 = 13.8% done in 688.4s, 4285.6s to go
# on time step 13840 (time=13.84), 0.0533583 s/step
# Meep progress: 13.913/100.0 = 13.9% done in 692.4s, 4284.3s to go
# on time step 13913 (time=13.913), 0.0548447 s/step
# Meep progress: 13.986/100.0 = 14.0% done in 696.4s, 4283.0s to go
# on time step 13986 (time=13.986), 0.0550768 s/step
# Meep progress: 14.058/100.0 = 14.1% done in 700.4s, 4282.1s to go
# on time step 14058 (time=14.058), 0.0557251 s/step
# Meep progress: 14.13/100.0 = 14.1% done in 704.5s, 4281.1s to go
# on time step 14130 (time=14.13), 0.0557101 s/step
# Meep progress: 14.204/100.0 = 14.2% done in 708.5s, 4279.6s to go
# on time step 14204 (time=14.204), 0.0546804 s/step
# Meep progress: 14.274000000000001/100.0 = 14.3% done in 712.6s, 4279.4s to go
# on time step 14274 (time=14.274), 0.0578898 s/step
# Meep progress: 14.347/100.0 = 14.3% done in 716.6s, 4278.0s to go
# on time step 14347 (time=14.347), 0.0549842 s/step
# Meep progress: 14.419/100.0 = 14.4% done in 720.6s, 4277.0s to go
# on time step 14419 (time=14.419), 0.055948 s/step
# Meep progress: 14.493/100.0 = 14.5% done in 724.6s, 4275.3s to go
# on time step 14493 (time=14.493), 0.0544972 s/step
# Meep progress: 14.565/100.0 = 14.6% done in 728.7s, 4274.2s to go
# on time step 14565 (time=14.565), 0.0560825 s/step
# Meep progress: 14.639000000000001/100.0 = 14.6% done in 732.7s, 4272.4s to go
# on time step 14639 (time=14.639), 0.0543617 s/step
# Meep progress: 14.708/100.0 = 14.7% done in 736.7s, 4272.3s to go
# on time step 14708 (time=14.708), 0.0583304 s/step
# Meep progress: 14.786/100.0 = 14.8% done in 740.7s, 4269.1s to go
# on time step 14786 (time=14.786), 0.0515764 s/step
# Meep progress: 14.866/100.0 = 14.9% done in 744.8s, 4265.3s to go
# on time step 14866 (time=14.866), 0.0505854 s/step
# Meep progress: 14.948/100.0 = 14.9% done in 748.8s, 4260.7s to go
# on time step 14948 (time=14.948), 0.049123 s/step
# Meep progress: 15.034/100.0 = 15.0% done in 752.9s, 4255.0s to go
# on time step 15034 (time=15.034), 0.0471558 s/step
# Meep progress: 15.11/100.0 = 15.1% done in 756.9s, 4252.4s to go
# on time step 15110 (time=15.11), 0.0529427 s/step
# Meep progress: 15.182/100.0 = 15.2% done in 760.9s, 4251.1s to go
# on time step 15182 (time=15.182), 0.0558227 s/step
# Meep progress: 15.255/100.0 = 15.3% done in 765.0s, 4249.6s to go
# on time step 15255 (time=15.255), 0.0554643 s/step
# Meep progress: 15.324/100.0 = 15.3% done in 769.0s, 4249.2s to go
# on time step 15324 (time=15.324), 0.057973 s/step
# Meep progress: 15.394/100.0 = 15.4% done in 773.0s, 4248.4s to go
# on time step 15394 (time=15.394), 0.0572624 s/step
# Meep progress: 15.476/100.0 = 15.5% done in 777.0s, 4243.6s to go
# on time step 15477 (time=15.477), 0.0488053 s/step
# Meep progress: 15.565/100.0 = 15.6% done in 781.0s, 4236.8s to go
# on time step 15566 (time=15.566), 0.0453172 s/step
# Meep progress: 15.651/100.0 = 15.7% done in 785.1s, 4231.0s to go
# on time step 15652 (time=15.652), 0.0468901 s/step
# Meep progress: 15.736/100.0 = 15.7% done in 789.1s, 4225.3s to go
# on time step 15738 (time=15.738), 0.0470479 s/step
# Meep progress: 15.817/100.0 = 15.8% done in 793.1s, 4221.2s to go
# on time step 15819 (time=15.819), 0.0499439 s/step
# Meep progress: 15.902000000000001/100.0 = 15.9% done in 797.1s, 4215.7s to go
# on time step 15904 (time=15.904), 0.0472459 s/step
# Meep progress: 15.986/100.0 = 16.0% done in 801.1s, 4210.4s to go
# on time step 15989 (time=15.989), 0.0476611 s/step
# Meep progress: 16.068/100.0 = 16.1% done in 805.2s, 4205.8s to go
# on time step 16071 (time=16.071), 0.0492713 s/step
# Meep progress: 16.151/100.0 = 16.2% done in 809.2s, 4200.9s to go
# on time step 16155 (time=16.155), 0.0478157 s/step
# Meep progress: 16.233/100.0 = 16.2% done in 813.2s, 4196.3s to go
# on time step 16237 (time=16.237), 0.0493249 s/step
# Meep progress: 16.315/100.0 = 16.3% done in 817.2s, 4191.6s to go
# on time step 16319 (time=16.319), 0.0491392 s/step
# Meep progress: 16.397000000000002/100.0 = 16.4% done in 821.2s, 4187.1s to go
# on time step 16402 (time=16.402), 0.0487596 s/step
# Meep progress: 16.477/100.0 = 16.5% done in 825.3s, 4183.3s to go
# on time step 16482 (time=16.482), 0.050581 s/step
# Meep progress: 16.559/100.0 = 16.6% done in 829.3s, 4178.7s to go
# on time step 16566 (time=16.566), 0.0480881 s/step
# Meep progress: 16.644000000000002/100.0 = 16.6% done in 833.3s, 4173.4s to go
# on time step 16650 (time=16.65), 0.0480775 s/step
# Meep progress: 16.724/100.0 = 16.7% done in 837.3s, 4169.5s to go
# on time step 16729 (time=16.729), 0.0507929 s/step
# Meep progress: 16.813/100.0 = 16.8% done in 841.3s, 4162.8s to go
# on time step 16818 (time=16.818), 0.0450851 s/step
# Meep progress: 16.899/100.0 = 16.9% done in 845.4s, 4157.1s to go
# on time step 16904 (time=16.904), 0.0465439 s/step
# Meep progress: 16.987000000000002/100.0 = 17.0% done in 849.4s, 4150.8s to go
# on time step 16992 (time=16.992), 0.0455353 s/step
# Meep progress: 17.074/100.0 = 17.1% done in 853.4s, 4144.8s to go
# on time step 17079 (time=17.079), 0.0461548 s/step
# Meep progress: 17.164/100.0 = 17.2% done in 857.4s, 4138.1s to go
# on time step 17169 (time=17.169), 0.0448168 s/step
# Meep progress: 17.25/100.0 = 17.2% done in 861.5s, 4132.6s to go
# on time step 17255 (time=17.255), 0.0469175 s/step
# Meep progress: 17.321/100.0 = 17.3% done in 865.5s, 4131.3s to go
# on time step 17326 (time=17.326), 0.057151 s/step
# Meep progress: 17.397000000000002/100.0 = 17.4% done in 869.5s, 4128.5s to go
# on time step 17403 (time=17.403), 0.0524639 s/step
# Meep progress: 17.47/100.0 = 17.5% done in 873.5s, 4126.5s to go
# on time step 17477 (time=17.477), 0.0545349 s/step
# Meep progress: 17.542/100.0 = 17.5% done in 877.5s, 4124.8s to go
# on time step 17548 (time=17.548), 0.0568868 s/step
# Meep progress: 17.612000000000002/100.0 = 17.6% done in 881.6s, 4123.9s to go
# on time step 17618 (time=17.618), 0.0574378 s/step
# Meep progress: 17.685/100.0 = 17.7% done in 885.6s, 4121.9s to go
# on time step 17692 (time=17.692), 0.0546183 s/step
# Meep progress: 17.759/100.0 = 17.8% done in 889.6s, 4119.6s to go
# on time step 17766 (time=17.766), 0.0546703 s/step
# Meep progress: 17.830000000000002/100.0 = 17.8% done in 893.6s, 4118.3s to go
# on time step 17838 (time=17.838), 0.0560724 s/step
# Meep progress: 17.907/100.0 = 17.9% done in 897.7s, 4115.2s to go
# on time step 17915 (time=17.915), 0.0524597 s/step
# Meep progress: 17.981/100.0 = 18.0% done in 901.7s, 4113.0s to go
# on time step 17989 (time=17.989), 0.0546496 s/step
# Meep progress: 18.055/100.0 = 18.1% done in 905.7s, 4110.8s to go
# on time step 18063 (time=18.063), 0.0545756 s/step
# Meep progress: 18.127/100.0 = 18.1% done in 909.8s, 4109.0s to go
# on time step 18136 (time=18.136), 0.0549321 s/step
# Meep progress: 18.198/100.0 = 18.2% done in 913.8s, 4107.5s to go
# on time step 18206 (time=18.206), 0.0579472 s/step
# Meep progress: 18.266000000000002/100.0 = 18.3% done in 917.8s, 4106.8s to go
# on time step 18274 (time=18.274), 0.0591247 s/step
# Meep progress: 18.34/100.0 = 18.3% done in 921.8s, 4104.4s to go
# on time step 18349 (time=18.349), 0.0539069 s/step
# Meep progress: 18.41/100.0 = 18.4% done in 925.8s, 4103.1s to go
# on time step 18419 (time=18.419), 0.0576899 s/step
# Meep progress: 18.481/100.0 = 18.5% done in 929.9s, 4101.7s to go
# on time step 18490 (time=18.49), 0.0565078 s/step
# Meep progress: 18.553/100.0 = 18.6% done in 933.9s, 4099.9s to go
# on time step 18560 (time=18.56), 0.0572395 s/step
# Meep progress: 18.626/100.0 = 18.6% done in 937.9s, 4097.7s to go
# on time step 18634 (time=18.634), 0.0550625 s/step
# Meep progress: 18.697/100.0 = 18.7% done in 942.0s, 4096.3s to go
# on time step 18705 (time=18.705), 0.0569908 s/step
# Meep progress: 18.77/100.0 = 18.8% done in 946.0s, 4094.1s to go
# on time step 18778 (time=18.778), 0.055244 s/step
# Meep progress: 18.841/100.0 = 18.8% done in 950.1s, 4092.6s to go
# on time step 18849 (time=18.849), 0.0567092 s/step
# Meep progress: 18.916/100.0 = 18.9% done in 954.1s, 4089.9s to go
# on time step 18924 (time=18.924), 0.05336 s/step
# Meep progress: 18.989/100.0 = 19.0% done in 958.2s, 4087.8s to go
# on time step 18996 (time=18.996), 0.0560169 s/step
# Meep progress: 19.056/100.0 = 19.1% done in 962.2s, 4087.0s to go
# on time step 19064 (time=19.064), 0.0592349 s/step
# Meep progress: 19.126/100.0 = 19.1% done in 966.2s, 4085.6s to go
# on time step 19134 (time=19.134), 0.0577519 s/step
# Meep progress: 19.195/100.0 = 19.2% done in 970.2s, 4084.3s to go
# on time step 19203 (time=19.203), 0.0582083 s/step
# Meep progress: 19.264/100.0 = 19.3% done in 974.2s, 4083.1s to go
# on time step 19273 (time=19.273), 0.0577235 s/step
# Meep progress: 19.337/100.0 = 19.3% done in 978.2s, 4080.7s to go
# on time step 19347 (time=19.347), 0.0546313 s/step
# Meep progress: 19.408/100.0 = 19.4% done in 982.3s, 4078.8s to go
# on time step 19419 (time=19.419), 0.0558818 s/step
# Meep progress: 19.482/100.0 = 19.5% done in 986.3s, 4076.3s to go
# on time step 19491 (time=19.491), 0.0556378 s/step
# Meep progress: 19.551000000000002/100.0 = 19.6% done in 990.3s, 4074.9s to go
# on time step 19561 (time=19.561), 0.0575108 s/step
# Meep progress: 19.624/100.0 = 19.6% done in 994.3s, 4072.5s to go
# on time step 19634 (time=19.634), 0.0550204 s/step
# Meep progress: 19.696/100.0 = 19.7% done in 998.3s, 4070.4s to go
# on time step 19705 (time=19.705), 0.0569436 s/step
# Meep progress: 19.768/100.0 = 19.8% done in 1002.4s, 4068.4s to go
# on time step 19778 (time=19.778), 0.055724 s/step
# Meep progress: 19.841/100.0 = 19.8% done in 1006.4s, 4066.0s to go
# on time step 19851 (time=19.851), 0.0547962 s/step
# Meep progress: 19.914/100.0 = 19.9% done in 1010.4s, 4063.5s to go
# on time step 19925 (time=19.925), 0.0549378 s/step
# Meep progress: 19.986/100.0 = 20.0% done in 1014.4s, 4061.3s to go
# on time step 19997 (time=19.997), 0.055982 s/step
# Meep progress: 20.058/100.0 = 20.1% done in 1018.5s, 4059.2s to go
# on time step 20070 (time=20.07), 0.0555126 s/step
# Meep progress: 20.131/100.0 = 20.1% done in 1022.5s, 4056.8s to go
# on time step 20142 (time=20.142), 0.0560882 s/step
# Meep progress: 20.203/100.0 = 20.2% done in 1026.5s, 4054.5s to go
# on time step 20214 (time=20.214), 0.0558749 s/step
# Meep progress: 20.277/100.0 = 20.3% done in 1030.6s, 4051.9s to go
# on time step 20288 (time=20.288), 0.0543463 s/step
# Meep progress: 20.35/100.0 = 20.4% done in 1034.6s, 4049.3s to go
# on time step 20363 (time=20.363), 0.0542402 s/step
# Meep progress: 20.424/100.0 = 20.4% done in 1038.6s, 4046.5s to go
# on time step 20438 (time=20.438), 0.0540518 s/step
# Meep progress: 20.498/100.0 = 20.5% done in 1042.6s, 4043.8s to go
# on time step 20511 (time=20.511), 0.0555332 s/step
# Meep progress: 20.567/100.0 = 20.6% done in 1046.6s, 4042.3s to go
# on time step 20580 (time=20.58), 0.0584353 s/step
# Meep progress: 20.636/100.0 = 20.6% done in 1050.7s, 4040.7s to go
# on time step 20650 (time=20.65), 0.0579718 s/step
# Meep progress: 20.706/100.0 = 20.7% done in 1054.7s, 4038.9s to go
# on time step 20722 (time=20.722), 0.0560553 s/step
# Meep progress: 20.778/100.0 = 20.8% done in 1058.7s, 4036.5s to go
# on time step 20794 (time=20.794), 0.0560383 s/step
# Meep progress: 20.851/100.0 = 20.9% done in 1062.7s, 4034.0s to go
# on time step 20866 (time=20.866), 0.0558093 s/step
# Meep progress: 20.927/100.0 = 20.9% done in 1066.8s, 4030.8s to go
# on time step 20941 (time=20.941), 0.0537216 s/step
# Meep progress: 21.0/100.0 = 21.0% done in 1070.8s, 4028.2s to go
# on time step 21015 (time=21.015), 0.0542222 s/step
# Meep progress: 21.075/100.0 = 21.1% done in 1074.8s, 4025.2s to go
# on time step 21090 (time=21.09), 0.0537289 s/step
# Meep progress: 21.145/100.0 = 21.1% done in 1078.8s, 4023.3s to go
# on time step 21160 (time=21.16), 0.0579815 s/step
# Meep progress: 21.215/100.0 = 21.2% done in 1082.9s, 4021.5s to go
# on time step 21231 (time=21.231), 0.0569377 s/step
# Meep progress: 21.287/100.0 = 21.3% done in 1086.9s, 4019.1s to go
# on time step 21300 (time=21.3), 0.0579831 s/step
# Meep progress: 21.36/100.0 = 21.4% done in 1091.0s, 4016.6s to go
# on time step 21374 (time=21.374), 0.054374 s/step
# Meep progress: 21.433/100.0 = 21.4% done in 1095.0s, 4014.0s to go
# on time step 21446 (time=21.446), 0.0557342 s/step
# Meep progress: 21.506/100.0 = 21.5% done in 1099.1s, 4011.5s to go
# on time step 21519 (time=21.519), 0.0554712 s/step
# Meep progress: 21.580000000000002/100.0 = 21.6% done in 1103.1s, 4008.6s to go
# on time step 21597 (time=21.597), 0.051657 s/step
# Meep progress: 21.665/100.0 = 21.7% done in 1107.1s, 4003.0s to go
# on time step 21683 (time=21.683), 0.0469207 s/step
# Meep progress: 21.751/100.0 = 21.8% done in 1111.2s, 3997.4s to go
# on time step 21768 (time=21.768), 0.0476788 s/step
# Meep progress: 21.839000000000002/100.0 = 21.8% done in 1115.2s, 3991.2s to go
# on time step 21857 (time=21.857), 0.0450399 s/step
# Meep progress: 21.928/100.0 = 21.9% done in 1119.2s, 3984.8s to go
# on time step 21947 (time=21.947), 0.0446785 s/step
# Meep progress: 22.018/100.0 = 22.0% done in 1123.2s, 3978.2s to go
# on time step 22034 (time=22.034), 0.0461215 s/step
# Meep progress: 22.103/100.0 = 22.1% done in 1127.3s, 3972.8s to go
# on time step 22121 (time=22.121), 0.0460036 s/step
# Meep progress: 22.19/100.0 = 22.2% done in 1131.3s, 3966.9s to go
# on time step 22206 (time=22.206), 0.0473077 s/step
# Meep progress: 22.277/100.0 = 22.3% done in 1135.3s, 3961.0s to go
# on time step 22295 (time=22.295), 0.0453403 s/step
# Meep progress: 22.368000000000002/100.0 = 22.4% done in 1139.3s, 3954.1s to go
# on time step 22382 (time=22.382), 0.045993 s/step
# Meep progress: 22.453/100.0 = 22.5% done in 1143.3s, 3948.7s to go
# on time step 22470 (time=22.47), 0.0456847 s/step
# Meep progress: 22.541/100.0 = 22.5% done in 1147.3s, 3942.7s to go
# on time step 22556 (time=22.556), 0.0468317 s/step
# Meep progress: 22.627/100.0 = 22.6% done in 1151.3s, 3937.0s to go
# on time step 22646 (time=22.646), 0.044733 s/step
# Meep progress: 22.716/100.0 = 22.7% done in 1155.4s, 3930.8s to go
# on time step 22736 (time=22.736), 0.0448329 s/step
# Meep progress: 22.808/100.0 = 22.8% done in 1159.4s, 3923.9s to go
# on time step 22826 (time=22.826), 0.0446642 s/step
# Meep progress: 22.896/100.0 = 22.9% done in 1163.4s, 3917.9s to go
# on time step 22915 (time=22.915), 0.0453823 s/step
# Meep progress: 22.984/100.0 = 23.0% done in 1167.4s, 3911.9s to go
# on time step 23003 (time=23.003), 0.045573 s/step
# Meep progress: 23.074/100.0 = 23.1% done in 1171.5s, 3905.5s to go
# on time step 23093 (time=23.093), 0.0446428 s/step
# Meep progress: 23.16/100.0 = 23.2% done in 1175.5s, 3900.1s to go
# on time step 23177 (time=23.177), 0.04801 s/step
# Meep progress: 23.245/100.0 = 23.2% done in 1179.6s, 3894.9s to go
# on time step 23263 (time=23.263), 0.0468115 s/step
# Meep progress: 23.339000000000002/100.0 = 23.3% done in 1183.6s, 3887.7s to go
# on time step 23356 (time=23.356), 0.0430958 s/step
# Meep progress: 23.428/100.0 = 23.4% done in 1187.6s, 3881.6s to go
# on time step 23444 (time=23.444), 0.04563 s/step
# Meep progress: 23.515/100.0 = 23.5% done in 1191.6s, 3875.8s to go
# on time step 23532 (time=23.532), 0.0458633 s/step
# Meep progress: 23.602/100.0 = 23.6% done in 1195.6s, 3870.2s to go
# on time step 23620 (time=23.62), 0.045908 s/step
# Meep progress: 23.689/100.0 = 23.7% done in 1199.6s, 3864.5s to go
# on time step 23708 (time=23.708), 0.0454556 s/step
# Meep progress: 23.778000000000002/100.0 = 23.8% done in 1203.7s, 3858.5s to go
# on time step 23794 (time=23.794), 0.0467262 s/step
# Meep progress: 23.866/100.0 = 23.9% done in 1207.7s, 3852.7s to go
# on time step 23882 (time=23.882), 0.0456173 s/step
# Meep progress: 23.948/100.0 = 23.9% done in 1211.8s, 3848.2s to go
# on time step 23962 (time=23.962), 0.0503056 s/step
# Meep progress: 24.022000000000002/100.0 = 24.0% done in 1215.8s, 3845.3s to go
# on time step 24035 (time=24.035), 0.0548184 s/step
# Meep progress: 24.104/100.0 = 24.1% done in 1219.8s, 3840.8s to go
# on time step 24120 (time=24.12), 0.0475498 s/step
# Meep progress: 24.195/100.0 = 24.2% done in 1223.8s, 3834.3s to go
# on time step 24212 (time=24.212), 0.0435996 s/step
# Meep progress: 24.284/100.0 = 24.3% done in 1227.9s, 3828.4s to go
# on time step 24301 (time=24.301), 0.0451635 s/step
# Meep progress: 24.363/100.0 = 24.4% done in 1231.9s, 3824.5s to go
# on time step 24376 (time=24.376), 0.0534936 s/step
# Meep progress: 24.436/100.0 = 24.4% done in 1235.9s, 3821.8s to go
# on time step 24452 (time=24.452), 0.0529739 s/step
# Meep progress: 24.518/100.0 = 24.5% done in 1239.9s, 3817.2s to go
# on time step 24534 (time=24.534), 0.0489001 s/step
# Meep progress: 24.596/100.0 = 24.6% done in 1243.9s, 3813.5s to go
# on time step 24610 (time=24.61), 0.0533587 s/step
# Meep progress: 24.669/100.0 = 24.7% done in 1247.9s, 3810.8s to go
# on time step 24682 (time=24.682), 0.0561036 s/step
# Meep progress: 24.739/100.0 = 24.7% done in 1252.0s, 3808.8s to go
# on time step 24753 (time=24.753), 0.0569414 s/step
# Meep progress: 24.812/100.0 = 24.8% done in 1256.0s, 3806.1s to go
# on time step 24826 (time=24.826), 0.0548369 s/step
# Meep progress: 24.884/100.0 = 24.9% done in 1260.0s, 3803.6s to go
# on time step 24896 (time=24.896), 0.0573909 s/step
# Meep progress: 24.955000000000002/100.0 = 25.0% done in 1264.0s, 3801.2s to go
# on time step 24969 (time=24.969), 0.0555488 s/step
# Meep progress: 25.026/100.0 = 25.0% done in 1268.1s, 3798.9s to go
# on time step 25040 (time=25.04), 0.0564152 s/step
# Meep progress: 25.098/100.0 = 25.1% done in 1272.1s, 3796.4s to go
# on time step 25112 (time=25.112), 0.0561543 s/step
# Meep progress: 25.169/100.0 = 25.2% done in 1276.1s, 3794.0s to go
# on time step 25182 (time=25.182), 0.0574709 s/step
# Meep progress: 25.246000000000002/100.0 = 25.2% done in 1280.1s, 3790.5s to go
# on time step 25264 (time=25.264), 0.0491512 s/step
# Meep progress: 25.334/100.0 = 25.3% done in 1284.2s, 3784.8s to go
# on time step 25354 (time=25.354), 0.0448297 s/step
# Meep progress: 25.425/100.0 = 25.4% done in 1288.2s, 3778.3s to go
# on time step 25444 (time=25.444), 0.0447882 s/step
# Meep progress: 25.509/100.0 = 25.5% done in 1292.2s, 3773.5s to go
# on time step 25527 (time=25.527), 0.0485941 s/step
# Meep progress: 25.596/100.0 = 25.6% done in 1296.3s, 3768.0s to go
# on time step 25616 (time=25.616), 0.0451224 s/step
# Meep progress: 25.686/100.0 = 25.7% done in 1300.3s, 3761.9s to go
# on time step 25703 (time=25.703), 0.0459828 s/step
# Meep progress: 25.773/100.0 = 25.8% done in 1304.3s, 3756.5s to go
# on time step 25790 (time=25.79), 0.0462043 s/step
# Meep progress: 25.861/100.0 = 25.9% done in 1308.3s, 3750.8s to go
# on time step 25880 (time=25.88), 0.0447866 s/step
# Meep progress: 25.949/100.0 = 25.9% done in 1312.4s, 3745.1s to go
# on time step 25967 (time=25.967), 0.0464051 s/step
# Meep progress: 26.037/100.0 = 26.0% done in 1316.4s, 3739.5s to go
# on time step 26055 (time=26.055), 0.0458983 s/step
# Meep progress: 26.122/100.0 = 26.1% done in 1320.4s, 3734.5s to go
# on time step 26139 (time=26.139), 0.0481085 s/step
# Meep progress: 26.209/100.0 = 26.2% done in 1324.5s, 3729.0s to go
# on time step 26228 (time=26.228), 0.0453595 s/step
# Meep progress: 26.299/100.0 = 26.3% done in 1328.5s, 3723.0s to go
# on time step 26317 (time=26.317), 0.045129 s/step
# Meep progress: 26.389/100.0 = 26.4% done in 1332.5s, 3717.0s to go
# on time step 26407 (time=26.407), 0.0446145 s/step
# Meep progress: 26.476/100.0 = 26.5% done in 1336.5s, 3711.5s to go
# on time step 26493 (time=26.493), 0.0467718 s/step
# Meep progress: 26.560000000000002/100.0 = 26.6% done in 1340.5s, 3706.6s to go
# on time step 26578 (time=26.578), 0.0472112 s/step
# Meep progress: 26.643/100.0 = 26.6% done in 1344.5s, 3702.0s to go
# on time step 26663 (time=26.663), 0.0471448 s/step
# Meep progress: 26.734/100.0 = 26.7% done in 1348.6s, 3695.8s to go
# on time step 26752 (time=26.752), 0.0452545 s/step
# Meep progress: 26.817/100.0 = 26.8% done in 1352.6s, 3691.2s to go
# on time step 26835 (time=26.835), 0.0482711 s/step
# Meep progress: 26.904/100.0 = 26.9% done in 1356.6s, 3685.8s to go
# on time step 26921 (time=26.921), 0.0468846 s/step
# Meep progress: 26.988/100.0 = 27.0% done in 1360.6s, 3680.9s to go
# on time step 27007 (time=27.007), 0.0465319 s/step
# Meep progress: 27.071/100.0 = 27.1% done in 1364.6s, 3676.4s to go
# on time step 27090 (time=27.09), 0.0486248 s/step
# Meep progress: 27.154/100.0 = 27.2% done in 1368.7s, 3671.7s to go
# on time step 27173 (time=27.173), 0.0482797 s/step
# Meep progress: 27.237000000000002/100.0 = 27.2% done in 1372.7s, 3667.1s to go
# on time step 27256 (time=27.256), 0.0487158 s/step
# Meep progress: 27.319/100.0 = 27.3% done in 1376.7s, 3662.6s to go
# on time step 27335 (time=27.335), 0.0508415 s/step
# Meep progress: 27.396/100.0 = 27.4% done in 1380.7s, 3659.1s to go
# on time step 27416 (time=27.416), 0.0493831 s/step
# Meep progress: 27.479/100.0 = 27.5% done in 1384.7s, 3654.5s to go
# on time step 27494 (time=27.494), 0.0518604 s/step
# Meep progress: 27.549/100.0 = 27.5% done in 1388.7s, 3652.2s to go
# on time step 27563 (time=27.563), 0.0580805 s/step
# Meep progress: 27.621000000000002/100.0 = 27.6% done in 1392.8s, 3649.7s to go
# on time step 27635 (time=27.635), 0.0557739 s/step
# Meep progress: 27.695/100.0 = 27.7% done in 1396.8s, 3646.8s to go
# on time step 27710 (time=27.71), 0.0533792 s/step
# Meep progress: 27.77/100.0 = 27.8% done in 1400.9s, 3643.7s to go
# on time step 27785 (time=27.785), 0.0534819 s/step
# Meep progress: 27.842000000000002/100.0 = 27.8% done in 1404.9s, 3641.1s to go
# on time step 27855 (time=27.855), 0.0573198 s/step
# Meep progress: 27.912/100.0 = 27.9% done in 1408.9s, 3638.8s to go
# on time step 27928 (time=27.928), 0.0552839 s/step
# Meep progress: 27.990000000000002/100.0 = 28.0% done in 1412.9s, 3635.1s to go
# on time step 28004 (time=28.004), 0.0532245 s/step
# Meep progress: 28.059/100.0 = 28.1% done in 1417.0s, 3633.0s to go
# on time step 28073 (time=28.073), 0.0582647 s/step
# Meep progress: 28.129/100.0 = 28.1% done in 1421.0s, 3630.6s to go
# on time step 28146 (time=28.146), 0.0554486 s/step
# Meep progress: 28.2/100.0 = 28.2% done in 1425.0s, 3628.2s to go
# on time step 28216 (time=28.216), 0.0578323 s/step
# Meep progress: 28.273/100.0 = 28.3% done in 1429.0s, 3625.4s to go
# on time step 28289 (time=28.289), 0.0553252 s/step
# Meep progress: 28.346/100.0 = 28.3% done in 1433.1s, 3622.6s to go
# on time step 28361 (time=28.361), 0.0558328 s/step
# Meep progress: 28.421/100.0 = 28.4% done in 1437.1s, 3619.4s to go
# on time step 28436 (time=28.436), 0.0538542 s/step
# Meep progress: 28.492/100.0 = 28.5% done in 1441.2s, 3617.0s to go
# on time step 28507 (time=28.507), 0.0564292 s/step
# Meep progress: 28.565/100.0 = 28.6% done in 1445.2s, 3614.2s to go
# on time step 28580 (time=28.58), 0.0549575 s/step
# Meep progress: 28.637/100.0 = 28.6% done in 1449.2s, 3611.4s to go
# on time step 28651 (time=28.651), 0.0571207 s/step
# Meep progress: 28.706/100.0 = 28.7% done in 1453.2s, 3609.2s to go
# on time step 28722 (time=28.722), 0.0567896 s/step
# Meep progress: 28.779/100.0 = 28.8% done in 1457.3s, 3606.4s to go
# on time step 28794 (time=28.794), 0.0557973 s/step
# Meep progress: 28.852/100.0 = 28.9% done in 1461.3s, 3603.4s to go
# on time step 28869 (time=28.869), 0.0537125 s/step
# Meep progress: 28.924/100.0 = 28.9% done in 1465.3s, 3600.7s to go
# on time step 28940 (time=28.94), 0.0569659 s/step
# Meep progress: 28.999000000000002/100.0 = 29.0% done in 1469.3s, 3597.5s to go
# on time step 29014 (time=29.014), 0.0542324 s/step
# Meep progress: 29.069/100.0 = 29.1% done in 1473.3s, 3595.1s to go
# on time step 29084 (time=29.084), 0.0575837 s/step
# Meep progress: 29.14/100.0 = 29.1% done in 1477.4s, 3592.6s to go
# on time step 29156 (time=29.156), 0.0560684 s/step
# Meep progress: 29.213/100.0 = 29.2% done in 1481.4s, 3589.7s to go
# on time step 29229 (time=29.229), 0.0551204 s/step
# Meep progress: 29.286/100.0 = 29.3% done in 1485.5s, 3586.9s to go
# on time step 29301 (time=29.301), 0.0557865 s/step
# Meep progress: 29.357/100.0 = 29.4% done in 1489.5s, 3584.2s to go
# on time step 29371 (time=29.371), 0.0577742 s/step
# Meep progress: 29.428/100.0 = 29.4% done in 1493.5s, 3581.6s to go
# on time step 29443 (time=29.443), 0.0559317 s/step
# Meep progress: 29.502/100.0 = 29.5% done in 1497.5s, 3578.5s to go
# on time step 29519 (time=29.519), 0.0529908 s/step
# Meep progress: 29.573/100.0 = 29.6% done in 1501.5s, 3575.9s to go
# on time step 29589 (time=29.589), 0.0571594 s/step
# Meep progress: 29.645/100.0 = 29.6% done in 1505.6s, 3573.1s to go
# on time step 29660 (time=29.66), 0.0566555 s/step
# Meep progress: 29.716/100.0 = 29.7% done in 1509.6s, 3570.4s to go
# on time step 29732 (time=29.732), 0.0564416 s/step
# Meep progress: 29.783/100.0 = 29.8% done in 1513.6s, 3568.5s to go
# on time step 29799 (time=29.799), 0.0597127 s/step
# Meep progress: 29.856/100.0 = 29.9% done in 1517.6s, 3565.6s to go
# on time step 29872 (time=29.872), 0.0554811 s/step
# Meep progress: 29.927/100.0 = 29.9% done in 1521.7s, 3563.0s to go
# on time step 29944 (time=29.944), 0.0556245 s/step
# Meep progress: 29.998/100.0 = 30.0% done in 1525.7s, 3560.3s to go
# on time step 30013 (time=30.013), 0.0587253 s/step
# Meep progress: 30.071/100.0 = 30.1% done in 1529.7s, 3557.3s to go
# on time step 30089 (time=30.089), 0.0532525 s/step
# Meep progress: 30.146/100.0 = 30.1% done in 1533.7s, 3554.0s to go
# on time step 30165 (time=30.165), 0.0532772 s/step
# Meep progress: 30.218/100.0 = 30.2% done in 1537.8s, 3551.2s to go
# on time step 30236 (time=30.236), 0.0569987 s/step
# Meep progress: 30.289/100.0 = 30.3% done in 1541.8s, 3548.5s to go
# on time step 30307 (time=30.307), 0.057111 s/step
# Meep progress: 30.359/100.0 = 30.4% done in 1545.8s, 3546.0s to go
# on time step 30376 (time=30.376), 0.0582469 s/step
# Meep progress: 30.427/100.0 = 30.4% done in 1549.9s, 3543.9s to go
# on time step 30446 (time=30.446), 0.0576849 s/step
# Meep progress: 30.498/100.0 = 30.5% done in 1553.9s, 3541.2s to go
# on time step 30515 (time=30.515), 0.0580487 s/step
# Meep progress: 30.57/100.0 = 30.6% done in 1557.9s, 3538.4s to go
# on time step 30586 (time=30.586), 0.0565095 s/step
# Meep progress: 30.635/100.0 = 30.6% done in 1562.0s, 3536.7s to go
# on time step 30651 (time=30.651), 0.0623769 s/step
# Meep progress: 30.707/100.0 = 30.7% done in 1566.0s, 3533.9s to go
# on time step 30725 (time=30.725), 0.0544203 s/step
# Meep progress: 30.78/100.0 = 30.8% done in 1570.1s, 3530.9s to go
# on time step 30796 (time=30.796), 0.0570238 s/step
# Meep progress: 30.851/100.0 = 30.9% done in 1574.1s, 3528.2s to go
# on time step 30869 (time=30.869), 0.0550505 s/step
# ...
# on time step 84793 (time=84.793), 0.0375388 s/step
# Meep progress: 84.867/100.0 = 84.9% done in 3855.0s, 687.4s to go
# on time step 84902 (time=84.902), 0.0369131 s/step
# Meep progress: 84.976/100.0 = 85.0% done in 3859.1s, 682.3s to go
# on time step 85011 (time=85.011), 0.0369618 s/step
# Meep progress: 85.086/100.0 = 85.1% done in 3863.1s, 677.1s to go
# on time step 85118 (time=85.118), 0.0374292 s/step
# Meep progress: 85.19200000000001/100.0 = 85.2% done in 3867.1s, 672.2s to go
# on time step 85224 (time=85.224), 0.0379589 s/step
# Meep progress: 85.299/100.0 = 85.3% done in 3871.2s, 667.2s to go
# on time step 85333 (time=85.333), 0.0369481 s/step
# Meep progress: 85.407/100.0 = 85.4% done in 3875.2s, 662.1s to go
# on time step 85443 (time=85.443), 0.0367188 s/step
# Meep progress: 85.518/100.0 = 85.5% done in 3879.2s, 656.9s to go
# on time step 85553 (time=85.553), 0.0365487 s/step
# Meep progress: 85.625/100.0 = 85.6% done in 3883.2s, 651.9s to go
# on time step 85659 (time=85.659), 0.0382091 s/step
# Meep progress: 85.732/100.0 = 85.7% done in 3887.2s, 646.9s to go
# on time step 85769 (time=85.769), 0.0366265 s/step
# Meep progress: 85.842/100.0 = 85.8% done in 3891.2s, 641.8s to go
# on time step 85878 (time=85.878), 0.0370019 s/step
# Meep progress: 85.952/100.0 = 86.0% done in 3895.3s, 636.6s to go
# on time step 85988 (time=85.988), 0.0366592 s/step
# Meep progress: 86.06/100.0 = 86.1% done in 3899.3s, 631.6s to go
# on time step 86096 (time=86.096), 0.0370495 s/step
# Meep progress: 86.168/100.0 = 86.2% done in 3903.3s, 626.6s to go
# on time step 86202 (time=86.202), 0.0377878 s/step
# Meep progress: 86.276/100.0 = 86.3% done in 3907.4s, 621.5s to go
# on time step 86312 (time=86.312), 0.0366382 s/step
# Meep progress: 86.385/100.0 = 86.4% done in 3911.4s, 616.5s to go
# on time step 86420 (time=86.42), 0.037442 s/step
# Meep progress: 86.49/100.0 = 86.5% done in 3915.4s, 611.6s to go
# on time step 86526 (time=86.526), 0.03806 s/step
# Meep progress: 86.596/100.0 = 86.6% done in 3919.4s, 606.7s to go
# on time step 86630 (time=86.63), 0.0384723 s/step
# Meep progress: 86.705/100.0 = 86.7% done in 3923.4s, 601.6s to go
# on time step 86741 (time=86.741), 0.0363002 s/step
# Meep progress: 86.816/100.0 = 86.8% done in 3927.5s, 596.4s to go
# on time step 86850 (time=86.85), 0.0367129 s/step
# Meep progress: 86.921/100.0 = 86.9% done in 3931.5s, 591.6s to go
# on time step 86958 (time=86.958), 0.03707 s/step
# Meep progress: 87.03/100.0 = 87.0% done in 3935.5s, 586.5s to go
# on time step 87067 (time=87.067), 0.0370137 s/step
# Meep progress: 87.144/100.0 = 87.1% done in 3939.5s, 581.2s to go
# on time step 87179 (time=87.179), 0.0357285 s/step
# Meep progress: 87.251/100.0 = 87.3% done in 3943.5s, 576.2s to go
# on time step 87288 (time=87.288), 0.036793 s/step
# Meep progress: 87.362/100.0 = 87.4% done in 3947.6s, 571.1s to go
# on time step 87397 (time=87.397), 0.0369553 s/step
# Meep progress: 87.471/100.0 = 87.5% done in 3951.6s, 566.0s to go
# on time step 87505 (time=87.505), 0.0373279 s/step
# Meep progress: 87.577/100.0 = 87.6% done in 3955.6s, 561.1s to go
# on time step 87612 (time=87.612), 0.037415 s/step
# Meep progress: 87.685/100.0 = 87.7% done in 3959.6s, 556.1s to go
# on time step 87720 (time=87.72), 0.0371592 s/step
# Meep progress: 87.795/100.0 = 87.8% done in 3963.6s, 551.0s to go
# on time step 87831 (time=87.831), 0.0361378 s/step
# Meep progress: 87.904/100.0 = 87.9% done in 3967.7s, 546.0s to go
# on time step 87937 (time=87.937), 0.0378108 s/step
# Meep progress: 88.012/100.0 = 88.0% done in 3971.7s, 541.0s to go
# on time step 88046 (time=88.046), 0.0367389 s/step
# Meep progress: 88.121/100.0 = 88.1% done in 3975.7s, 535.9s to go
# on time step 88154 (time=88.154), 0.0373244 s/step
# Meep progress: 88.22800000000001/100.0 = 88.2% done in 3979.7s, 531.0s to go
# on time step 88262 (time=88.262), 0.0372596 s/step
# Meep progress: 88.337/100.0 = 88.3% done in 3983.8s, 526.0s to go
# on time step 88369 (time=88.369), 0.0376406 s/step
# Meep progress: 88.44200000000001/100.0 = 88.4% done in 3987.8s, 521.1s to go
# on time step 88476 (time=88.476), 0.0375157 s/step
# Meep progress: 88.55/100.0 = 88.5% done in 3991.8s, 516.2s to go
# on time step 88583 (time=88.583), 0.0374681 s/step
# Meep progress: 88.656/100.0 = 88.7% done in 3995.8s, 511.3s to go
# on time step 88690 (time=88.69), 0.037422 s/step
# Meep progress: 88.766/100.0 = 88.8% done in 3999.8s, 506.2s to go
# on time step 88802 (time=88.802), 0.0358748 s/step
# Meep progress: 88.878/100.0 = 88.9% done in 4003.8s, 501.0s to go
# on time step 88911 (time=88.911), 0.0369412 s/step
# Meep progress: 88.98400000000001/100.0 = 89.0% done in 4007.9s, 496.2s to go
# on time step 89019 (time=89.019), 0.0372279 s/step
# Meep progress: 89.095/100.0 = 89.1% done in 4011.9s, 491.0s to go
# on time step 89127 (time=89.127), 0.0370737 s/step
# Meep progress: 89.202/100.0 = 89.2% done in 4015.9s, 486.1s to go
# on time step 89235 (time=89.235), 0.0371284 s/step
# Meep progress: 89.31/100.0 = 89.3% done in 4019.9s, 481.2s to go
# on time step 89343 (time=89.343), 0.0371499 s/step
# Meep progress: 89.417/100.0 = 89.4% done in 4023.9s, 476.3s to go
# on time step 89451 (time=89.451), 0.0370891 s/step
# Meep progress: 89.529/100.0 = 89.5% done in 4028.0s, 471.1s to go
# on time step 89560 (time=89.56), 0.0368795 s/step
# Meep progress: 89.634/100.0 = 89.6% done in 4032.0s, 466.3s to go
# on time step 89668 (time=89.668), 0.0372113 s/step
# Meep progress: 89.744/100.0 = 89.7% done in 4036.1s, 461.2s to go
# on time step 89774 (time=89.774), 0.03798 s/step
# Meep progress: 89.85000000000001/100.0 = 89.9% done in 4040.1s, 456.4s to go
# on time step 89883 (time=89.883), 0.0369557 s/step
# Meep progress: 89.959/100.0 = 90.0% done in 4044.1s, 451.4s to go
# on time step 89991 (time=89.991), 0.0372573 s/step
# Meep progress: 90.06700000000001/100.0 = 90.1% done in 4048.1s, 446.4s to go
# on time step 90099 (time=90.099), 0.037128 s/step
# Meep progress: 90.173/100.0 = 90.2% done in 4052.1s, 441.6s to go
# on time step 90205 (time=90.205), 0.0377921 s/step
# Meep progress: 90.282/100.0 = 90.3% done in 4056.1s, 436.6s to go
# on time step 90314 (time=90.314), 0.0369561 s/step
# Meep progress: 90.39/100.0 = 90.4% done in 4060.1s, 431.7s to go
# on time step 90422 (time=90.422), 0.0373505 s/step
# Meep progress: 90.496/100.0 = 90.5% done in 4064.1s, 426.8s to go
# on time step 90530 (time=90.53), 0.0372614 s/step
# Meep progress: 90.60300000000001/100.0 = 90.6% done in 4068.2s, 421.9s to go
# on time step 90638 (time=90.638), 0.0373775 s/step
# Meep progress: 90.711/100.0 = 90.7% done in 4072.2s, 417.0s to go
# on time step 90747 (time=90.747), 0.0369927 s/step
# Meep progress: 90.819/100.0 = 90.8% done in 4076.2s, 412.1s to go
# on time step 90855 (time=90.855), 0.0372044 s/step
# Meep progress: 90.928/100.0 = 90.9% done in 4080.2s, 407.1s to go
# on time step 90962 (time=90.962), 0.0374482 s/step
# Meep progress: 91.036/100.0 = 91.0% done in 4084.2s, 402.2s to go
# on time step 91073 (time=91.073), 0.036307 s/step
# Meep progress: 91.145/100.0 = 91.1% done in 4088.2s, 397.2s to go
# on time step 91181 (time=91.181), 0.0373972 s/step
# Meep progress: 91.259/100.0 = 91.3% done in 4092.2s, 392.0s to go
# on time step 91300 (time=91.3), 0.0336146 s/step
# Meep progress: 91.384/100.0 = 91.4% done in 4096.2s, 386.2s to go
# on time step 91427 (time=91.427), 0.0317331 s/step
# Meep progress: 91.512/100.0 = 91.5% done in 4100.3s, 380.3s to go
# on time step 91556 (time=91.556), 0.0310088 s/step
# Meep progress: 91.642/100.0 = 91.6% done in 4104.3s, 374.3s to go
# on time step 91686 (time=91.686), 0.0308909 s/step
# Meep progress: 91.771/100.0 = 91.8% done in 4108.3s, 368.4s to go
# on time step 91815 (time=91.815), 0.0311643 s/step
# Meep progress: 91.902/100.0 = 91.9% done in 4112.3s, 362.4s to go
# on time step 91946 (time=91.946), 0.0306332 s/step
# Meep progress: 92.033/100.0 = 92.0% done in 4116.3s, 356.3s to go
# on time step 92077 (time=92.077), 0.0305653 s/step
# Meep progress: 92.163/100.0 = 92.2% done in 4120.3s, 350.4s to go
# on time step 92205 (time=92.205), 0.0313766 s/step
# Meep progress: 92.292/100.0 = 92.3% done in 4124.3s, 344.5s to go
# on time step 92335 (time=92.335), 0.0308348 s/step
# Meep progress: 92.422/100.0 = 92.4% done in 4128.4s, 338.5s to go
# on time step 92464 (time=92.464), 0.031189 s/step
# Meep progress: 92.552/100.0 = 92.6% done in 4132.4s, 332.6s to go
# on time step 92594 (time=92.594), 0.0309392 s/step
# Meep progress: 92.682/100.0 = 92.7% done in 4136.4s, 326.6s to go
# on time step 92725 (time=92.725), 0.030622 s/step
# Meep progress: 92.81/100.0 = 92.8% done in 4140.4s, 320.8s to go
# on time step 92851 (time=92.851), 0.0317891 s/step
# Meep progress: 92.931/100.0 = 92.9% done in 4144.5s, 315.3s to go
# on time step 92968 (time=92.968), 0.0342754 s/step
# Meep progress: 93.052/100.0 = 93.1% done in 4148.5s, 309.8s to go
# on time step 93100 (time=93.1), 0.0304597 s/step
# Meep progress: 93.19800000000001/100.0 = 93.2% done in 4152.5s, 303.1s to go
# on time step 93248 (time=93.248), 0.0271632 s/step
# Meep progress: 93.349/100.0 = 93.3% done in 4156.5s, 296.1s to go
# on time step 93402 (time=93.402), 0.02613 s/step
# Meep progress: 93.507/100.0 = 93.5% done in 4160.5s, 288.9s to go
# on time step 93559 (time=93.559), 0.0256001 s/step
# Meep progress: 93.66/100.0 = 93.7% done in 4164.5s, 281.9s to go
# on time step 93714 (time=93.714), 0.0258629 s/step
# Meep progress: 93.81700000000001/100.0 = 93.8% done in 4168.5s, 274.7s to go
# on time step 93869 (time=93.869), 0.0258511 s/step
# Meep progress: 93.974/100.0 = 94.0% done in 4172.5s, 267.6s to go
# on time step 94027 (time=94.027), 0.0253395 s/step
# Meep progress: 94.133/100.0 = 94.1% done in 4176.5s, 260.3s to go
# on time step 94186 (time=94.186), 0.0251577 s/step
# Meep progress: 94.293/100.0 = 94.3% done in 4180.6s, 253.0s to go
# on time step 94346 (time=94.346), 0.0250706 s/step
# Meep progress: 94.453/100.0 = 94.5% done in 4184.6s, 245.7s to go
# on time step 94506 (time=94.506), 0.0251409 s/step
# Meep progress: 94.61200000000001/100.0 = 94.6% done in 4188.6s, 238.5s to go
# on time step 94665 (time=94.665), 0.0252722 s/step
# Meep progress: 94.771/100.0 = 94.8% done in 4192.6s, 231.3s to go
# on time step 94825 (time=94.825), 0.025034 s/step
# Meep progress: 94.931/100.0 = 94.9% done in 4196.6s, 224.1s to go
# on time step 94985 (time=94.985), 0.0251271 s/step
# Meep progress: 95.09100000000001/100.0 = 95.1% done in 4200.6s, 216.9s to go
# on time step 95145 (time=95.145), 0.0250702 s/step
# Meep progress: 95.251/100.0 = 95.3% done in 4204.6s, 209.6s to go
# on time step 95305 (time=95.305), 0.0250373 s/step
# Meep progress: 95.41/100.0 = 95.4% done in 4208.6s, 202.5s to go
# on time step 95464 (time=95.464), 0.0252376 s/step
# Meep progress: 95.56700000000001/100.0 = 95.6% done in 4212.6s, 195.4s to go
# on time step 95620 (time=95.62), 0.0256418 s/step
# Meep progress: 95.72500000000001/100.0 = 95.7% done in 4216.7s, 188.3s to go
# on time step 95779 (time=95.779), 0.0252997 s/step
# Meep progress: 95.884/100.0 = 95.9% done in 4220.7s, 181.2s to go
# on time step 95939 (time=95.939), 0.0250851 s/step
# Meep progress: 96.044/100.0 = 96.0% done in 4224.7s, 174.0s to go
# on time step 96098 (time=96.098), 0.0252529 s/step
# Meep progress: 96.203/100.0 = 96.2% done in 4228.7s, 166.9s to go
# on time step 96258 (time=96.258), 0.0251044 s/step
# Meep progress: 96.363/100.0 = 96.4% done in 4232.7s, 159.8s to go
# on time step 96418 (time=96.418), 0.0251357 s/step
# Meep progress: 96.521/100.0 = 96.5% done in 4236.7s, 152.7s to go
# on time step 96576 (time=96.576), 0.0254599 s/step
# Meep progress: 96.678/100.0 = 96.7% done in 4240.7s, 145.7s to go
# on time step 96734 (time=96.734), 0.0253191 s/step
# Meep progress: 96.837/100.0 = 96.8% done in 4244.7s, 138.6s to go
# on time step 96893 (time=96.893), 0.025224 s/step
# Meep progress: 96.997/100.0 = 97.0% done in 4248.7s, 131.5s to go
# on time step 97054 (time=97.054), 0.0249356 s/step
# Meep progress: 97.158/100.0 = 97.2% done in 4252.7s, 124.4s to go
# on time step 97214 (time=97.214), 0.0251278 s/step
# Meep progress: 97.318/100.0 = 97.3% done in 4256.8s, 117.3s to go
# on time step 97374 (time=97.374), 0.0250857 s/step
# Meep progress: 97.47800000000001/100.0 = 97.5% done in 4260.8s, 110.2s to go
# on time step 97533 (time=97.533), 0.0251916 s/step
# Meep progress: 97.637/100.0 = 97.6% done in 4264.8s, 103.2s to go
# on time step 97692 (time=97.692), 0.0251964 s/step
# Meep progress: 97.796/100.0 = 97.8% done in 4268.8s, 96.2s to go
# on time step 97852 (time=97.852), 0.0250774 s/step
# Meep progress: 97.956/100.0 = 98.0% done in 4272.8s, 89.2s to go
# on time step 98011 (time=98.011), 0.0252442 s/step
# Meep progress: 98.11500000000001/100.0 = 98.1% done in 4276.8s, 82.2s to go
# on time step 98171 (time=98.171), 0.0250889 s/step
# Meep progress: 98.275/100.0 = 98.3% done in 4280.8s, 75.1s to go
# on time step 98331 (time=98.331), 0.0250468 s/step
# Meep progress: 98.435/100.0 = 98.4% done in 4284.8s, 68.1s to go
# on time step 98491 (time=98.491), 0.025068 s/step
# Meep progress: 98.595/100.0 = 98.6% done in 4288.9s, 61.1s to go
# on time step 98651 (time=98.651), 0.0251129 s/step
# Meep progress: 98.754/100.0 = 98.8% done in 4292.9s, 54.2s to go
# on time step 98810 (time=98.81), 0.0251896 s/step
# Meep progress: 98.914/100.0 = 98.9% done in 4296.9s, 47.2s to go
# on time step 98971 (time=98.971), 0.0249821 s/step
# Meep progress: 99.074/100.0 = 99.1% done in 4300.9s, 40.2s to go
# on time step 99129 (time=99.129), 0.0253729 s/step
# Meep progress: 99.22800000000001/100.0 = 99.2% done in 4304.9s, 33.5s to go
# on time step 99280 (time=99.28), 0.026655 s/step
# Meep progress: 99.369/100.0 = 99.4% done in 4308.9s, 27.4s to go
# on time step 99417 (time=99.417), 0.0292302 s/step
# Meep progress: 99.505/100.0 = 99.5% done in 4312.9s, 21.5s to go
# on time step 99552 (time=99.552), 0.0297399 s/step
# Meep progress: 99.639/100.0 = 99.6% done in 4317.0s, 15.6s to go
# on time step 99687 (time=99.687), 0.0297416 s/step
# Meep progress: 99.775/100.0 = 99.8% done in 4321.0s, 9.7s to go
# on time step 99821 (time=99.821), 0.0298557 s/step
# Meep progress: 99.909/100.0 = 99.9% done in 4325.0s, 3.9s to go
# on time step 99961 (time=99.961), 0.0286762 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 100.0 (100000 timesteps)
#      block, center = (-7.26,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.4,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.77556e-17,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.6,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.8,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
# 取得 Ez 場量在指定位置的振福資訊
amplitude_data = sim.get_array(component=mp.Ez)

# 計算觀測點的相對座標
x_obs = -0.5 * sx + dpml + dsub + gh + 0.01##
y_obs_start = -0.5 * sy + gp/2

# 儲存振福資訊的列表
amplitude_list = []

# 遍歷每個觀測點
for j in range(num_cells):
    y_obs = y_obs_start + (j * gp)
    # 計算觀測點在陣列中的索引位置
    x_index = int(round((x_obs) * sim.resolution))
    y_index = int(round((y_obs) * sim.resolution))
    # 取得振福資訊
    amplitude = np.abs(amplitude_data[x_index, y_index])
    amplitude_list.append(amplitude)
    
   
# 印出觀測點的振福資訊
'''
for j, amplitude in enumerate(amplitude_list):
    print(f"觀測點 {j+1} 的振福資訊: {amplitude/np.max(amplitude_list)}")'''

print(amplitude_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 取得 Ez 場量在指定位置的振福資訊
# ----> 2 amplitude_data = sim.get_array(component=mp.Ez)
#       4 # 計算觀測點的相對座標
#       5 x_obs = -0.5 * sx + dpml + dsub + gh + 0.01##
#
# File ~/miniconda3/envs/mp/lib/python3.11/site-packages/meep/simulation.py:3936, in Simulation.get_array(self, component, vol, center, size, cmplx, arr, frequency, snap)
#    3933 dim_sizes = np.zeros(3, dtype=np.uintp)
#    3935 if vol is None and center is None and size is None:
# -> 3936     v = self.fields.total_volume()
#    3937 else:
#    3938     v = self._volume_from_kwargs(vol, center, size)
#
# AttributeError: 'NoneType' object has no attribute 'total_volume'

# %%
# 取得 Ez 場量在指定位置的相位資訊
phase_data = np.fft.fft(np.array(sim.get_array(component = mp.Ez , cmplx = True)))

# 計算觀測點的相對座標
x_obs = -0.5 * sx + dpml + dsub + gh +0.01
y_obs_start = -0.5 * sy #+ gp/2 

# 儲存相位資訊的列表
phase_list = []

# 遍歷每個觀測點
for j in range(300):
    y_obs = y_obs_start + (j * 0.002)
    # 計算觀測點在陣列中的索引位置
    x_index = int(round((x_obs) * sim.resolution))
    y_index = int(round((y_obs) * sim.resolution))
    # 取得相位資訊
    phase = np.angle(phase_data[x_index, y_index])
    phase_list.append(phase)

# 印出觀測點的相位資訊
'''
for j, phase in enumerate(phase_list):
    print(f"觀測點 {j+1} 的相位資訊: {phase}")'''
    
print(phase_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 # 取得 Ez 場量在指定位置的相位資訊
# ----> 2 phase_data = np.fft.fft(np.array(sim.get_array(component = mp.Ez , cmplx = True)))
#       4 # 計算觀測點的相對座標
#       5 x_obs = -0.5 * sx + dpml + dsub + gh +0.01
#
# File ~/miniconda3/envs/mp/lib/python3.11/site-packages/meep/simulation.py:3936, in Simulation.get_array(self, component, vol, center, size, cmplx, arr, frequency, snap)
#    3933 dim_sizes = np.zeros(3, dtype=np.uintp)
#    3935 if vol is None and center is None and size is None:
# -> 3936     v = self.fields.total_volume()
#    3937 else:
#    3938     v = self._volume_from_kwargs(vol, center, size)
#
# AttributeError: 'NoneType' object has no attribute 'total_volume'

# %%
sim.reset_meep()
f = plt.figure(dpi = 100)
Animate = mp.Animate2D(fields=mp.Ez, f=f, realtime=False, normalize=True)
plt.close()

sim.run(mp.at_every(1, Animate), until = 50)
plt.close()

filename = "1 beta alpha alpha structure.mp4"
Animate.to_mp4(10, filename)

from IPython.display import Video

Video(filename)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000113964 s
# Working in 2D dimensions.
# Computational cell is 17.1 x 6 x 0 with resolution 50
#      block, center = (-7.26,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.9,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.3,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-1.7,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-1.1,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.5,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.1,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.7,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.3,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.9,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      ...(+ 21 objects not shown)...
# time for set_epsilon = 0.330334 s
# -----------
# Meep: using complex fields.
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (-7.26,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.9,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.3,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-1.7,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-1.1,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.5,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.1,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.7,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.3,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.9,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      ...(+ 21 objects not shown)...
# Meep progress: 18.63/50.0 = 37.3% done in 4.0s, 6.7s to go
# on time step 1863 (time=18.63), 0.00214744 s/step
# Meep progress: 36.300000000000004/50.0 = 72.6% done in 8.0s, 3.0s to go
# on time step 3630 (time=36.3), 0.00226383 s/step
# Normalizing field data...
# run 1 finished at t = 50.0 (5000 timesteps)
# Generating MP4...
# <video src="1 beta alpha alpha structure.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
