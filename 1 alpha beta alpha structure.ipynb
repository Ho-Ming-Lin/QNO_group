# %%
import meep as mp
import numpy as np
import math
import matplotlib.pyplot as plt

#sim.reset_meep()
resolution = 500  # pixels/μm

dpml = 1.0  # PML thickness
dsub = 0.5  # substrate thickness
dcaa = 0.06  # air rigion for alpha structure
# alpha structure is that one period = 200nm，sigle cell width = 80nm locate at center
dcab = 0.025 # air rigion for beta structure 
# beta structure is that one period = 200nm，sigle cell width = 150nm locate at center
gp = 0.2  # grating periodicity
gh = 0.6  # grating height
gwa = 0.08 # alpha grating cell width
gwb = 0.15 # beta grating cell width

num_cells = 3  # number of grating unit cells

# air region thickness adjacent to grating
dair = 1

wvl = 0.532  # center wavelength
fcen = 1 / wvl  # center frequency


glass = mp.Medium(index= 2.6678)

pml_layers = [mp.PML(thickness=dpml, direction = mp.X )]

symmetries = [mp.Mirror(mp.Y)]

sx = dpml + dsub + gh + dair + dpml
sy = num_cells*gp
cell_size = mp.Vector3(sx, sy)

sources = [
    mp.Source(
        mp.ContinuousSource(frequency = 2), # frequemcy = 2原因是 meep 的 C=1，所以 1/? = 0.5 um，?即是2
        component = mp.Ez,
        center = mp.Vector3(-0.5 * sx + dpml ),
        size = mp.Vector3(y=sy),
    )
]

geometry = [
    mp.Block(
        material=glass,
        size=mp.Vector3(dsub, mp.inf, mp.inf),
        center=mp.Vector3(-0.5 * sx + dpml + 0.04 + dsub/2),
    )
]

# %%
for j in range(num_cells):
    geometry.append(
    mp.Block(
        material=glass,
        size=mp.Vector3(gh, gwa, mp.inf),
        center=mp.Vector3(
            -0.5 * sx + dpml + dsub + 0.5 * gh,
            -0.5 * sy + gp/2 + (j * 3 * gp),
            #-0.5 * sy + gp/2,
        ),
    )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + gp/2 + gp  , 
            ),
        )
    )

for j in range(num_cells):
    geometry.append(
    mp.Block(
        material=glass,
        size=mp.Vector3(gh, gwa, mp.inf),
        center=mp.Vector3(
            -0.5 * sx + dpml + dsub + 0.5 * gh,
            -0.5 * sy + 2*gp + gp/2  + (j * 3 * gp),
            #-0.5 * sy  + gp/2 + 2*gp ,
        ),
    )
    )

# %%
k_point = mp.Vector3()  # Gamma 點表示週期邊界條件
k_points = [k_point]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
    k_point = mp.Vector3(),
)

# %matplotlib inline
plt.figure(dpi = 125)
sim.plot2D()
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (-0.76,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
t_xx = (.532)
dt = (t_xx / 40)
t = 1000
x_obs = -0.5 * sx + dpml + dsub + gh + 0.002
y_obs_down = -0.5 * sy + gp/2
y_obs_cen = -0.5 * sy + 3*gp/2
y_obs_up = 0.5 * sy - gp/2

print(int((t_xx)/dt))
# Out:
# 40

# %%
# 儲存場量數值的列表
ez_data_cen = []
ez_data_up = []
ez_data_down = []
###
def get_slice(sim):
    ez_data_cen.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_cen) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_up.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_up) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_down.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_down) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))

sim.run(mp.at_every(dt , get_slice) , until = t)

plt.figure(dpi = 100)
sim.plot2D(fields=mp.Ez)
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00019598 s
# Working in 2D dimensions.
# Computational cell is 4.1 x 0.6 x 0 with resolution 500
#      block, center = (-0.76,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
# time for set_epsilon = 0.557363 s
# -----------
# Meep progress: 1.424/1000.0 = 0.1% done in 4.0s, 2806.8s to go
# on time step 1424 (time=1.424), 0.00281092 s/step
# Meep progress: 2.689/1000.0 = 0.3% done in 8.0s, 2968.1s to go
# on time step 2690 (time=2.69), 0.00316151 s/step
# Meep progress: 4.122/1000.0 = 0.4% done in 12.0s, 2900.1s to go
# on time step 4124 (time=4.124), 0.00279175 s/step
# Meep progress: 5.517/1000.0 = 0.6% done in 16.0s, 2884.8s to go
# on time step 5520 (time=5.52), 0.00286704 s/step
# Meep progress: 6.9/1000.0 = 0.7% done in 20.0s, 2879.3s to go
# on time step 6903 (time=6.903), 0.00289347 s/step
# Meep progress: 8.144/1000.0 = 0.8% done in 24.0s, 2923.9s to go
# on time step 8146 (time=8.146), 0.00321869 s/step
# Meep progress: 9.359/1000.0 = 0.9% done in 28.0s, 2964.8s to go
# on time step 9362 (time=9.362), 0.00328999 s/step
# Meep progress: 10.646/1000.0 = 1.1% done in 32.0s, 2974.9s to go
# on time step 10648 (time=10.648), 0.00311223 s/step
# Meep progress: 11.968/1000.0 = 1.2% done in 36.0s, 2973.1s to go
# on time step 11971 (time=11.971), 0.00302451 s/step
# Meep progress: 13.326/1000.0 = 1.3% done in 40.0s, 2962.6s to go
# on time step 13330 (time=13.33), 0.00294518 s/step
# Meep progress: 14.65/1000.0 = 1.5% done in 44.0s, 2960.4s to go
# on time step 14654 (time=14.654), 0.00302362 s/step
# Meep progress: 15.922/1000.0 = 1.6% done in 48.0s, 2967.7s to go
# on time step 15927 (time=15.927), 0.00314366 s/step
# Meep progress: 17.277/1000.0 = 1.7% done in 52.0s, 2958.9s to go
# on time step 17282 (time=17.282), 0.00295217 s/step
# Meep progress: 18.627/1000.0 = 1.9% done in 56.0s, 2951.5s to go
# on time step 18632 (time=18.632), 0.00296482 s/step
# Meep progress: 19.939/1000.0 = 2.0% done in 60.0s, 2950.2s to go
# on time step 19944 (time=19.944), 0.00304933 s/step
# Meep progress: 21.204/1000.0 = 2.1% done in 64.0s, 2955.3s to go
# on time step 21210 (time=21.21), 0.00316151 s/step
# Meep progress: 22.476/1000.0 = 2.2% done in 68.0s, 2958.4s to go
# on time step 22483 (time=22.483), 0.00314434 s/step
# Meep progress: 23.747/1000.0 = 2.4% done in 72.0s, 2961.0s to go
# on time step 23753 (time=23.753), 0.00315052 s/step
# Meep progress: 25.062/1000.0 = 2.5% done in 76.0s, 2957.5s to go
# on time step 25070 (time=25.07), 0.00303859 s/step
# Meep progress: 26.351/1000.0 = 2.6% done in 80.0s, 2957.0s to go
# on time step 26358 (time=26.358), 0.00310714 s/step
# Meep progress: 27.535/1000.0 = 2.8% done in 84.0s, 2967.7s to go
# on time step 27543 (time=27.543), 0.00337838 s/step
# Meep progress: 28.917/1000.0 = 2.9% done in 88.0s, 2956.2s to go
# on time step 28924 (time=28.924), 0.00289713 s/step
# Meep progress: 30.044/1000.0 = 3.0% done in 92.0s, 2971.2s to go
# on time step 30051 (time=30.051), 0.0035502 s/step
# Meep progress: 31.195/1000.0 = 3.1% done in 96.0s, 2982.5s to go
# on time step 31203 (time=31.203), 0.00347313 s/step
# Meep progress: 32.501/1000.0 = 3.3% done in 100.0s, 2977.9s to go
# on time step 32508 (time=32.508), 0.00306718 s/step
# Meep progress: 33.812/1000.0 = 3.4% done in 104.0s, 2972.9s to go
# on time step 33821 (time=33.821), 0.00304656 s/step
# Meep progress: 35.079/1000.0 = 3.5% done in 108.0s, 2971.8s to go
# on time step 35087 (time=35.087), 0.0031611 s/step
# Meep progress: 36.389/1000.0 = 3.6% done in 112.0s, 2966.9s to go
# on time step 36400 (time=36.4), 0.00304782 s/step
# Meep progress: 37.757/1000.0 = 3.8% done in 116.0s, 2957.3s to go
# on time step 37768 (time=37.768), 0.00292443 s/step
# Meep progress: 39.160000000000004/1000.0 = 3.9% done in 120.0s, 2945.4s to go
# on time step 39171 (time=39.171), 0.00285243 s/step
# Meep progress: 40.446/1000.0 = 4.0% done in 124.0s, 2942.8s to go
# on time step 40456 (time=40.456), 0.00311433 s/step
# Meep progress: 41.678000000000004/1000.0 = 4.2% done in 128.0s, 2944.1s to go
# on time step 41690 (time=41.69), 0.00324188 s/step
# Meep progress: 43.026/1000.0 = 4.3% done in 132.0s, 2936.9s to go
# on time step 43038 (time=43.038), 0.0029689 s/step
# Meep progress: 44.405/1000.0 = 4.4% done in 136.0s, 2927.7s to go
# on time step 44414 (time=44.414), 0.00290842 s/step
# Meep progress: 45.783/1000.0 = 4.6% done in 140.0s, 2918.8s to go
# on time step 45796 (time=45.796), 0.00289466 s/step
# Meep progress: 47.216/1000.0 = 4.7% done in 144.0s, 2906.8s to go
# on time step 47230 (time=47.23), 0.00279018 s/step
# Meep progress: 48.629/1000.0 = 4.9% done in 148.0s, 2896.4s to go
# on time step 48641 (time=48.641), 0.00283514 s/step
# Meep progress: 49.993/1000.0 = 5.0% done in 152.1s, 2889.4s to go
# on time step 50005 (time=50.005), 0.00293442 s/step
# Meep progress: 51.358000000000004/1000.0 = 5.1% done in 156.1s, 2882.5s to go
# on time step 51371 (time=51.371), 0.00292974 s/step
# Meep progress: 52.712/1000.0 = 5.3% done in 160.1s, 2876.3s to go
# on time step 52725 (time=52.725), 0.00295429 s/step
# Meep progress: 54.067/1000.0 = 5.4% done in 164.1s, 2870.3s to go
# on time step 54079 (time=54.079), 0.00295434 s/step
# Meep progress: 55.422000000000004/1000.0 = 5.5% done in 168.1s, 2864.2s to go
# on time step 55435 (time=55.435), 0.00295109 s/step
# Meep progress: 56.792/1000.0 = 5.7% done in 172.1s, 2857.5s to go
# on time step 56805 (time=56.805), 0.00291973 s/step
# Meep progress: 58.144/1000.0 = 5.8% done in 176.1s, 2851.9s to go
# on time step 58157 (time=58.157), 0.00295883 s/step
# Meep progress: 59.517/1000.0 = 6.0% done in 180.1s, 2845.3s to go
# on time step 59530 (time=59.53), 0.00291354 s/step
# Meep progress: 60.799/1000.0 = 6.1% done in 184.1s, 2843.3s to go
# on time step 60809 (time=60.809), 0.00312853 s/step
# Meep progress: 62.172000000000004/1000.0 = 6.2% done in 188.1s, 2836.8s to go
# on time step 62184 (time=62.184), 0.00290917 s/step
# Meep progress: 63.549/1000.0 = 6.4% done in 192.1s, 2830.2s to go
# on time step 63561 (time=63.561), 0.00290635 s/step
# Meep progress: 64.929/1000.0 = 6.5% done in 196.1s, 2823.6s to go
# on time step 64943 (time=64.943), 0.00289499 s/step
# Meep progress: 66.294/1000.0 = 6.6% done in 200.1s, 2817.8s to go
# on time step 66309 (time=66.309), 0.00293048 s/step
# Meep progress: 67.677/1000.0 = 6.8% done in 204.1s, 2811.2s to go
# on time step 67691 (time=67.691), 0.00289467 s/step
# Meep progress: 69.052/1000.0 = 6.9% done in 208.1s, 2805.1s to go
# on time step 69066 (time=69.066), 0.00290978 s/step
# Meep progress: 70.368/1000.0 = 7.0% done in 212.1s, 2801.7s to go
# on time step 70381 (time=70.381), 0.00304229 s/step
# Meep progress: 71.749/1000.0 = 7.2% done in 216.1s, 2795.4s to go
# on time step 71762 (time=71.762), 0.00289712 s/step
# Meep progress: 73.074/1000.0 = 7.3% done in 220.1s, 2791.6s to go
# on time step 73087 (time=73.087), 0.00302036 s/step
# Meep progress: 74.393/1000.0 = 7.4% done in 224.1s, 2788.0s to go
# on time step 74408 (time=74.408), 0.00302978 s/step
# Meep progress: 75.736/1000.0 = 7.6% done in 228.1s, 2783.4s to go
# on time step 75749 (time=75.749), 0.0029834 s/step
# Meep progress: 77.084/1000.0 = 7.7% done in 232.1s, 2778.7s to go
# on time step 77097 (time=77.097), 0.00296897 s/step
# Meep progress: 78.468/1000.0 = 7.8% done in 236.1s, 2772.6s to go
# on time step 78481 (time=78.481), 0.00289042 s/step
# Meep progress: 79.87/1000.0 = 8.0% done in 240.1s, 2765.9s to go
# on time step 79885 (time=79.885), 0.00285053 s/step
# Meep progress: 81.27/1000.0 = 8.1% done in 244.1s, 2759.3s to go
# on time step 81284 (time=81.284), 0.00286038 s/step
# Meep progress: 82.663/1000.0 = 8.3% done in 248.1s, 2753.1s to go
# on time step 82679 (time=82.679), 0.00286886 s/step
# Meep progress: 84.056/1000.0 = 8.4% done in 252.1s, 2747.0s to go
# on time step 84071 (time=84.071), 0.00287532 s/step
# Meep progress: 85.45100000000001/1000.0 = 8.5% done in 256.1s, 2740.8s to go
# on time step 85467 (time=85.467), 0.00286597 s/step
# Meep progress: 86.83500000000001/1000.0 = 8.7% done in 260.1s, 2735.2s to go
# on time step 86852 (time=86.852), 0.00288979 s/step
# Meep progress: 88.223/1000.0 = 8.8% done in 264.1s, 2729.4s to go
# on time step 88240 (time=88.24), 0.00288257 s/step
# Meep progress: 89.532/1000.0 = 9.0% done in 268.1s, 2726.3s to go
# on time step 89549 (time=89.549), 0.00305628 s/step
# Meep progress: 90.899/1000.0 = 9.1% done in 272.1s, 2721.3s to go
# on time step 90915 (time=90.915), 0.00292858 s/step
# Meep progress: 92.278/1000.0 = 9.2% done in 276.1s, 2715.9s to go
# on time step 92295 (time=92.295), 0.00290045 s/step
# Meep progress: 93.643/1000.0 = 9.4% done in 280.1s, 2711.0s to go
# on time step 93660 (time=93.66), 0.00293124 s/step
# Meep progress: 94.956/1000.0 = 9.5% done in 284.1s, 2707.8s to go
# on time step 94973 (time=94.973), 0.00304783 s/step
# Meep progress: 96.23700000000001/1000.0 = 9.6% done in 288.1s, 2705.5s to go
# on time step 96255 (time=96.255), 0.00312061 s/step
# Meep progress: 97.601/1000.0 = 9.8% done in 292.1s, 2700.7s to go
# on time step 97617 (time=97.617), 0.00293694 s/step
# Meep progress: 98.94200000000001/1000.0 = 9.9% done in 296.1s, 2696.6s to go
# on time step 98962 (time=98.962), 0.00297559 s/step
# Meep progress: 100.327/1000.0 = 10.0% done in 300.1s, 2691.1s to go
# on time step 100345 (time=100.345), 0.0028924 s/step
# Meep progress: 101.702/1000.0 = 10.2% done in 304.1s, 2686.0s to go
# on time step 101722 (time=101.722), 0.00290549 s/step
# Meep progress: 103.09700000000001/1000.0 = 10.3% done in 308.1s, 2680.4s to go
# on time step 103117 (time=103.117), 0.00286932 s/step
# Meep progress: 104.49000000000001/1000.0 = 10.4% done in 312.1s, 2674.8s to go
# on time step 104508 (time=104.508), 0.00287728 s/step
# Meep progress: 105.857/1000.0 = 10.6% done in 316.1s, 2670.1s to go
# on time step 105880 (time=105.88), 0.00291753 s/step
# Meep progress: 107.249/1000.0 = 10.7% done in 320.1s, 2664.6s to go
# on time step 107270 (time=107.27), 0.0028785 s/step
# Meep progress: 108.62/1000.0 = 10.9% done in 324.1s, 2659.8s to go
# on time step 108642 (time=108.642), 0.00291679 s/step
# Meep progress: 109.973/1000.0 = 11.0% done in 328.1s, 2655.4s to go
# on time step 109996 (time=109.996), 0.0029556 s/step
# Meep progress: 111.3/1000.0 = 11.1% done in 332.1s, 2651.8s to go
# on time step 111321 (time=111.321), 0.00302042 s/step
# Meep progress: 112.62400000000001/1000.0 = 11.3% done in 336.1s, 2648.3s to go
# on time step 112646 (time=112.646), 0.00302096 s/step
# Meep progress: 113.99000000000001/1000.0 = 11.4% done in 340.1s, 2643.6s to go
# on time step 114012 (time=114.012), 0.00293027 s/step
# Meep progress: 115.351/1000.0 = 11.5% done in 344.1s, 2639.1s to go
# on time step 115370 (time=115.37), 0.00294614 s/step
# Meep progress: 116.736/1000.0 = 11.7% done in 348.1s, 2634.0s to go
# on time step 116762 (time=116.762), 0.0028752 s/step
# Meep progress: 118.12100000000001/1000.0 = 11.8% done in 352.1s, 2628.9s to go
# on time step 118145 (time=118.145), 0.00289262 s/step
# Meep progress: 119.483/1000.0 = 11.9% done in 356.1s, 2624.4s to go
# on time step 119509 (time=119.509), 0.00293276 s/step
# Meep progress: 120.87100000000001/1000.0 = 12.1% done in 360.1s, 2619.2s to go
# on time step 120892 (time=120.892), 0.00289312 s/step
# Meep progress: 122.245/1000.0 = 12.2% done in 364.1s, 2614.5s to go
# on time step 122270 (time=122.27), 0.00290352 s/step
# Meep progress: 123.626/1000.0 = 12.4% done in 368.1s, 2609.6s to go
# on time step 123652 (time=123.652), 0.00289532 s/step
# Meep progress: 125.006/1000.0 = 12.5% done in 372.1s, 2604.7s to go
# on time step 125032 (time=125.032), 0.00289947 s/step
# Meep progress: 126.411/1000.0 = 12.6% done in 376.1s, 2599.3s to go
# on time step 126436 (time=126.436), 0.0028508 s/step
# Meep progress: 127.79/1000.0 = 12.8% done in 380.1s, 2594.5s to go
# on time step 127817 (time=127.817), 0.00289646 s/step
# Meep progress: 129.179/1000.0 = 12.9% done in 384.1s, 2589.5s to go
# on time step 129205 (time=129.205), 0.00288305 s/step
# Meep progress: 130.566/1000.0 = 13.1% done in 388.1s, 2584.6s to go
# on time step 130592 (time=130.592), 0.00288403 s/step
# Meep progress: 131.995/1000.0 = 13.2% done in 392.1s, 2578.7s to go
# on time step 132020 (time=132.02), 0.00280263 s/step
# Meep progress: 133.361/1000.0 = 13.3% done in 396.1s, 2574.3s to go
# on time step 133390 (time=133.39), 0.00292182 s/step
# Meep progress: 134.718/1000.0 = 13.5% done in 400.1s, 2570.1s to go
# on time step 134741 (time=134.741), 0.00296101 s/step
# Meep progress: 136.093/1000.0 = 13.6% done in 404.1s, 2565.4s to go
# on time step 136121 (time=136.121), 0.00290021 s/step
# Meep progress: 137.474/1000.0 = 13.7% done in 408.1s, 2560.7s to go
# on time step 137500 (time=137.5), 0.00290227 s/step
# Meep progress: 138.85/1000.0 = 13.9% done in 412.1s, 2556.1s to go
# on time step 138876 (time=138.876), 0.0029088 s/step
# Meep progress: 140.223/1000.0 = 14.0% done in 416.1s, 2551.6s to go
# on time step 140252 (time=140.252), 0.0029078 s/step
# Meep progress: 141.552/1000.0 = 14.2% done in 420.1s, 2548.0s to go
# on time step 141580 (time=141.58), 0.00301333 s/step
# Meep progress: 142.923/1000.0 = 14.3% done in 424.1s, 2543.5s to go
# on time step 142948 (time=142.948), 0.00292556 s/step
# Meep progress: 144.321/1000.0 = 14.4% done in 428.2s, 2538.5s to go
# on time step 144349 (time=144.349), 0.00285595 s/step
# Meep progress: 145.727/1000.0 = 14.6% done in 432.2s, 2533.3s to go
# on time step 145755 (time=145.755), 0.00284573 s/step
# Meep progress: 147.141/1000.0 = 14.7% done in 436.2s, 2528.0s to go
# on time step 147169 (time=147.169), 0.0028289 s/step
# Meep progress: 148.536/1000.0 = 14.9% done in 440.2s, 2523.1s to go
# on time step 148564 (time=148.564), 0.00286914 s/step
# Meep progress: 149.907/1000.0 = 15.0% done in 444.2s, 2518.7s to go
# on time step 149939 (time=149.939), 0.00291043 s/step
# Meep progress: 151.288/1000.0 = 15.1% done in 448.2s, 2514.1s to go
# on time step 151319 (time=151.319), 0.00290021 s/step
# Meep progress: 152.642/1000.0 = 15.3% done in 452.2s, 2510.0s to go
# on time step 152673 (time=152.673), 0.00295507 s/step
# Meep progress: 153.98/1000.0 = 15.4% done in 456.2s, 2506.3s to go
# on time step 154007 (time=154.007), 0.00299962 s/step
# Meep progress: 155.344/1000.0 = 15.5% done in 460.2s, 2502.0s to go
# on time step 155377 (time=155.377), 0.00292045 s/step
# Meep progress: 156.704/1000.0 = 15.7% done in 464.2s, 2497.9s to go
# on time step 156731 (time=156.731), 0.00295489 s/step
# Meep progress: 158.032/1000.0 = 15.8% done in 468.2s, 2494.3s to go
# on time step 158061 (time=158.061), 0.00300908 s/step
# Meep progress: 159.39600000000002/1000.0 = 15.9% done in 472.2s, 2490.0s to go
# on time step 159426 (time=159.426), 0.00293057 s/step
# Meep progress: 160.758/1000.0 = 16.1% done in 476.2s, 2485.8s to go
# on time step 160789 (time=160.789), 0.00293483 s/step
# Meep progress: 162.133/1000.0 = 16.2% done in 480.2s, 2481.4s to go
# on time step 162167 (time=162.167), 0.00290788 s/step
# Meep progress: 163.502/1000.0 = 16.4% done in 484.2s, 2477.1s to go
# on time step 163535 (time=163.535), 0.00292508 s/step
# Meep progress: 164.858/1000.0 = 16.5% done in 488.2s, 2473.0s to go
# on time step 164891 (time=164.891), 0.00295178 s/step
# Meep progress: 166.233/1000.0 = 16.6% done in 492.2s, 2468.6s to go
# on time step 166267 (time=166.267), 0.00290787 s/step
# Meep progress: 167.58100000000002/1000.0 = 16.8% done in 496.2s, 2464.6s to go
# on time step 167615 (time=167.615), 0.00296929 s/step
# Meep progress: 168.904/1000.0 = 16.9% done in 500.2s, 2461.1s to go
# on time step 168938 (time=168.938), 0.00302353 s/step
# Meep progress: 170.269/1000.0 = 17.0% done in 504.2s, 2456.9s to go
# on time step 170304 (time=170.304), 0.00292849 s/step
# Meep progress: 171.647/1000.0 = 17.2% done in 508.2s, 2452.4s to go
# on time step 171682 (time=171.682), 0.00290415 s/step
# Meep progress: 173.024/1000.0 = 17.3% done in 512.2s, 2448.0s to go
# on time step 173056 (time=173.056), 0.00291148 s/step
# Meep progress: 174.359/1000.0 = 17.4% done in 516.2s, 2444.3s to go
# on time step 174391 (time=174.391), 0.00299845 s/step
# Meep progress: 175.699/1000.0 = 17.6% done in 520.2s, 2440.5s to go
# on time step 175732 (time=175.732), 0.00298333 s/step
# Meep progress: 177.025/1000.0 = 17.7% done in 524.2s, 2436.9s to go
# on time step 177057 (time=177.057), 0.00302031 s/step
# Meep progress: 178.352/1000.0 = 17.8% done in 528.2s, 2433.3s to go
# on time step 178385 (time=178.385), 0.0030124 s/step
# Meep progress: 179.68800000000002/1000.0 = 18.0% done in 532.2s, 2429.5s to go
# on time step 179728 (time=179.728), 0.00298057 s/step
# Meep progress: 181.04/1000.0 = 18.1% done in 536.2s, 2425.5s to go
# on time step 181071 (time=181.071), 0.00298027 s/step
# Meep progress: 182.395/1000.0 = 18.2% done in 540.2s, 2421.5s to go
# on time step 182432 (time=182.432), 0.00293906 s/step
# Meep progress: 183.78900000000002/1000.0 = 18.4% done in 544.2s, 2416.8s to go
# on time step 183824 (time=183.824), 0.00287398 s/step
# Meep progress: 185.16400000000002/1000.0 = 18.5% done in 548.2s, 2412.4s to go
# on time step 185197 (time=185.197), 0.00291386 s/step
# Meep progress: 186.517/1000.0 = 18.7% done in 552.2s, 2408.4s to go
# on time step 186552 (time=186.552), 0.00295309 s/step
# Meep progress: 187.862/1000.0 = 18.8% done in 556.2s, 2404.5s to go
# on time step 187898 (time=187.898), 0.00297287 s/step
# Meep progress: 189.243/1000.0 = 18.9% done in 560.2s, 2400.0s to go
# on time step 189282 (time=189.282), 0.00289081 s/step
# Meep progress: 190.617/1000.0 = 19.1% done in 564.2s, 2395.6s to go
# on time step 190654 (time=190.654), 0.0029168 s/step
# Meep progress: 192.013/1000.0 = 19.2% done in 568.2s, 2391.0s to go
# on time step 192053 (time=192.053), 0.00285999 s/step
# Meep progress: 193.394/1000.0 = 19.3% done in 572.2s, 2386.5s to go
# on time step 193432 (time=193.432), 0.0029013 s/step
# Meep progress: 194.71800000000002/1000.0 = 19.5% done in 576.2s, 2383.0s to go
# on time step 194753 (time=194.753), 0.00303038 s/step
# Meep progress: 196.028/1000.0 = 19.6% done in 580.2s, 2379.6s to go
# on time step 196067 (time=196.067), 0.0030464 s/step
# Meep progress: 197.366/1000.0 = 19.7% done in 584.2s, 2375.8s to go
# on time step 197400 (time=197.4), 0.00300212 s/step
# Meep progress: 198.714/1000.0 = 19.9% done in 588.2s, 2371.8s to go
# on time step 198752 (time=198.752), 0.00296037 s/step
# Meep progress: 200.05/1000.0 = 20.0% done in 592.2s, 2368.1s to go
# on time step 200088 (time=200.088), 0.00299455 s/step
# Meep progress: 201.379/1000.0 = 20.1% done in 596.2s, 2364.4s to go
# on time step 201418 (time=201.418), 0.00300953 s/step
# Meep progress: 202.761/1000.0 = 20.3% done in 600.2s, 2360.0s to go
# on time step 202803 (time=202.803), 0.00288882 s/step
# Meep progress: 204.157/1000.0 = 20.4% done in 604.2s, 2355.3s to go
# on time step 204198 (time=204.198), 0.00286741 s/step
# Meep progress: 205.55700000000002/1000.0 = 20.6% done in 608.2s, 2350.6s to go
# on time step 205598 (time=205.598), 0.00285768 s/step
# Meep progress: 206.93/1000.0 = 20.7% done in 612.2s, 2346.3s to go
# on time step 206970 (time=206.97), 0.00291655 s/step
# Meep progress: 208.329/1000.0 = 20.8% done in 616.2s, 2341.7s to go
# on time step 208371 (time=208.371), 0.00285643 s/step
# Meep progress: 209.725/1000.0 = 21.0% done in 620.2s, 2337.1s to go
# on time step 209766 (time=209.766), 0.00286859 s/step
# Meep progress: 211.129/1000.0 = 21.1% done in 624.2s, 2332.4s to go
# on time step 211170 (time=211.17), 0.00285093 s/step
# Meep progress: 212.519/1000.0 = 21.3% done in 628.2s, 2327.8s to go
# on time step 212560 (time=212.56), 0.00287822 s/step
# Meep progress: 213.912/1000.0 = 21.4% done in 632.2s, 2323.3s to go
# on time step 213955 (time=213.955), 0.00286913 s/step
# Meep progress: 215.327/1000.0 = 21.5% done in 636.2s, 2318.4s to go
# on time step 215367 (time=215.367), 0.00283438 s/step
# Meep progress: 216.692/1000.0 = 21.7% done in 640.2s, 2314.3s to go
# on time step 216732 (time=216.732), 0.0029312 s/step
# Meep progress: 218.064/1000.0 = 21.8% done in 644.2s, 2310.1s to go
# on time step 218102 (time=218.102), 0.00291972 s/step
# Meep progress: 219.41400000000002/1000.0 = 21.9% done in 648.2s, 2306.1s to go
# on time step 219455 (time=219.455), 0.00295869 s/step
# Meep progress: 220.751/1000.0 = 22.1% done in 652.2s, 2302.4s to go
# on time step 220791 (time=220.791), 0.0029941 s/step
# Meep progress: 222.096/1000.0 = 22.2% done in 656.2s, 2298.5s to go
# on time step 222140 (time=222.14), 0.00296654 s/step
# Meep progress: 223.494/1000.0 = 22.3% done in 660.2s, 2293.9s to go
# on time step 223530 (time=223.53), 0.00287892 s/step
# Meep progress: 224.84900000000002/1000.0 = 22.5% done in 664.2s, 2289.9s to go
# on time step 224892 (time=224.892), 0.00293797 s/step
# Meep progress: 226.19/1000.0 = 22.6% done in 668.2s, 2286.1s to go
# on time step 226231 (time=226.231), 0.00298788 s/step
# Meep progress: 227.435/1000.0 = 22.7% done in 672.2s, 2283.5s to go
# on time step 227479 (time=227.479), 0.003207 s/step
# Meep progress: 228.793/1000.0 = 22.9% done in 676.2s, 2279.4s to go
# on time step 228830 (time=228.83), 0.00296226 s/step
# Meep progress: 230.07/1000.0 = 23.0% done in 680.2s, 2276.4s to go
# on time step 230113 (time=230.113), 0.00311968 s/step
# Meep progress: 231.417/1000.0 = 23.1% done in 684.2s, 2272.5s to go
# on time step 231460 (time=231.46), 0.00297102 s/step
# Meep progress: 232.731/1000.0 = 23.3% done in 688.2s, 2269.0s to go
# on time step 232775 (time=232.775), 0.00304303 s/step
# Meep progress: 234.071/1000.0 = 23.4% done in 692.2s, 2265.2s to go
# on time step 234115 (time=234.115), 0.00298554 s/step
# Meep progress: 235.382/1000.0 = 23.5% done in 696.2s, 2261.7s to go
# on time step 235423 (time=235.423), 0.00305904 s/step
# Meep progress: 236.68800000000002/1000.0 = 23.7% done in 700.2s, 2258.3s to go
# on time step 236730 (time=236.73), 0.00306239 s/step
# Meep progress: 237.984/1000.0 = 23.8% done in 704.3s, 2255.0s to go
# on time step 238028 (time=238.028), 0.00308349 s/step
# Meep progress: 239.284/1000.0 = 23.9% done in 708.3s, 2251.6s to go
# on time step 239322 (time=239.322), 0.0030937 s/step
# Meep progress: 240.567/1000.0 = 24.1% done in 712.3s, 2248.5s to go
# on time step 240612 (time=240.612), 0.00310091 s/step
# Meep progress: 241.865/1000.0 = 24.2% done in 716.3s, 2245.1s to go
# on time step 241904 (time=241.904), 0.0030961 s/step
# Meep progress: 243.184/1000.0 = 24.3% done in 720.3s, 2241.5s to go
# on time step 243227 (time=243.227), 0.00302417 s/step
# Meep progress: 244.49800000000002/1000.0 = 24.4% done in 724.3s, 2238.0s to go
# on time step 244540 (time=244.54), 0.00304895 s/step
# Meep progress: 245.841/1000.0 = 24.6% done in 728.3s, 2234.1s to go
# on time step 245886 (time=245.886), 0.00297186 s/step
# Meep progress: 247.15200000000002/1000.0 = 24.7% done in 732.3s, 2230.5s to go
# on time step 247197 (time=247.197), 0.00305118 s/step
# Meep progress: 248.488/1000.0 = 24.8% done in 736.3s, 2226.7s to go
# on time step 248531 (time=248.531), 0.00300147 s/step
# Meep progress: 249.803/1000.0 = 25.0% done in 740.3s, 2223.1s to go
# on time step 249850 (time=249.85), 0.00303356 s/step
# Meep progress: 251.13400000000001/1000.0 = 25.1% done in 744.3s, 2219.4s to go
# on time step 251180 (time=251.18), 0.00300925 s/step
# Meep progress: 252.436/1000.0 = 25.2% done in 748.3s, 2215.9s to go
# on time step 252481 (time=252.481), 0.00307487 s/step
# Meep progress: 253.752/1000.0 = 25.4% done in 752.3s, 2212.3s to go
# on time step 253794 (time=253.794), 0.00304668 s/step
# Meep progress: 255.048/1000.0 = 25.5% done in 756.3s, 2209.0s to go
# on time step 255094 (time=255.094), 0.00307788 s/step
# Meep progress: 256.37/1000.0 = 25.6% done in 760.3s, 2205.3s to go
# on time step 256413 (time=256.413), 0.00303317 s/step
# Meep progress: 257.672/1000.0 = 25.8% done in 764.3s, 2201.8s to go
# on time step 257714 (time=257.714), 0.00307508 s/step
# Meep progress: 258.94/1000.0 = 25.9% done in 768.3s, 2198.7s to go
# on time step 258980 (time=258.98), 0.00316043 s/step
# Meep progress: 260.248/1000.0 = 26.0% done in 772.3s, 2195.2s to go
# on time step 260285 (time=260.285), 0.00306575 s/step
# Meep progress: 261.52/1000.0 = 26.2% done in 776.3s, 2192.1s to go
# on time step 261564 (time=261.564), 0.00312948 s/step
# Meep progress: 262.833/1000.0 = 26.3% done in 780.3s, 2188.5s to go
# on time step 262878 (time=262.878), 0.00304524 s/step
# Meep progress: 264.17900000000003/1000.0 = 26.4% done in 784.3s, 2184.5s to go
# on time step 264222 (time=264.222), 0.00297816 s/step
# Meep progress: 265.534/1000.0 = 26.6% done in 788.3s, 2180.4s to go
# on time step 265579 (time=265.579), 0.00294876 s/step
# Meep progress: 266.859/1000.0 = 26.7% done in 792.3s, 2176.7s to go
# on time step 266903 (time=266.903), 0.00302263 s/step
# Meep progress: 268.189/1000.0 = 26.8% done in 796.3s, 2172.9s to go
# on time step 268232 (time=268.232), 0.00300979 s/step
# Meep progress: 269.507/1000.0 = 27.0% done in 800.3s, 2169.2s to go
# on time step 269550 (time=269.55), 0.0030368 s/step
# Meep progress: 270.803/1000.0 = 27.1% done in 804.3s, 2165.7s to go
# on time step 270844 (time=270.844), 0.00309355 s/step
# Meep progress: 272.099/1000.0 = 27.2% done in 808.3s, 2162.3s to go
# on time step 272146 (time=272.146), 0.00307424 s/step
# Meep progress: 273.383/1000.0 = 27.3% done in 812.3s, 2159.0s to go
# on time step 273429 (time=273.429), 0.00311874 s/step
# Meep progress: 274.648/1000.0 = 27.5% done in 816.3s, 2155.9s to go
# on time step 274696 (time=274.696), 0.00315819 s/step
# Meep progress: 275.92900000000003/1000.0 = 27.6% done in 820.3s, 2152.6s to go
# on time step 275971 (time=275.971), 0.00313913 s/step
# Meep progress: 277.238/1000.0 = 27.7% done in 824.3s, 2149.0s to go
# on time step 277286 (time=277.286), 0.00304419 s/step
# Meep progress: 278.553/1000.0 = 27.9% done in 828.3s, 2145.3s to go
# on time step 278602 (time=278.602), 0.00303981 s/step
# Meep progress: 279.867/1000.0 = 28.0% done in 832.3s, 2141.6s to go
# on time step 279914 (time=279.914), 0.00304942 s/step
# Meep progress: 281.164/1000.0 = 28.1% done in 836.3s, 2138.1s to go
# on time step 281210 (time=281.21), 0.00308815 s/step
# Meep progress: 282.496/1000.0 = 28.2% done in 840.3s, 2134.3s to go
# on time step 282548 (time=282.548), 0.00299104 s/step
# Meep progress: 283.823/1000.0 = 28.4% done in 844.3s, 2130.5s to go
# on time step 283869 (time=283.869), 0.00302843 s/step
# Meep progress: 285.152/1000.0 = 28.5% done in 848.3s, 2126.6s to go
# on time step 285201 (time=285.201), 0.00300432 s/step
# Meep progress: 286.438/1000.0 = 28.6% done in 852.3s, 2123.2s to go
# on time step 286485 (time=286.485), 0.00311538 s/step
# Meep progress: 287.72700000000003/1000.0 = 28.8% done in 856.3s, 2119.8s to go
# on time step 287773 (time=287.773), 0.0031061 s/step
# Meep progress: 289.034/1000.0 = 28.9% done in 860.3s, 2116.2s to go
# on time step 289081 (time=289.081), 0.00305938 s/step
# Meep progress: 290.336/1000.0 = 29.0% done in 864.3s, 2112.6s to go
# on time step 290384 (time=290.384), 0.00307032 s/step
# Meep progress: 291.652/1000.0 = 29.2% done in 868.3s, 2108.9s to go
# on time step 291700 (time=291.7), 0.00304054 s/step
# Meep progress: 292.94/1000.0 = 29.3% done in 872.3s, 2105.5s to go
# on time step 292992 (time=292.992), 0.00309765 s/step
# Meep progress: 294.269/1000.0 = 29.4% done in 876.3s, 2101.6s to go
# on time step 294321 (time=294.321), 0.00300992 s/step
# Meep progress: 295.543/1000.0 = 29.6% done in 880.3s, 2098.3s to go
# on time step 295594 (time=295.594), 0.00314413 s/step
# Meep progress: 296.842/1000.0 = 29.7% done in 884.3s, 2094.8s to go
# on time step 296894 (time=296.894), 0.00307831 s/step
# Meep progress: 298.142/1000.0 = 29.8% done in 888.3s, 2091.2s to go
# on time step 298193 (time=298.193), 0.00307953 s/step
# Meep progress: 299.437/1000.0 = 29.9% done in 892.3s, 2087.7s to go
# on time step 299491 (time=299.491), 0.00308258 s/step
# Meep progress: 300.74/1000.0 = 30.1% done in 896.3s, 2084.1s to go
# on time step 300792 (time=300.792), 0.0030763 s/step
# Meep progress: 302.059/1000.0 = 30.2% done in 900.3s, 2080.3s to go
# on time step 302113 (time=302.113), 0.0030289 s/step
# Meep progress: 303.39300000000003/1000.0 = 30.3% done in 904.3s, 2076.4s to go
# on time step 303445 (time=303.445), 0.0030039 s/step
# Meep progress: 304.721/1000.0 = 30.5% done in 908.3s, 2072.5s to go
# on time step 304778 (time=304.778), 0.0030019 s/step
# Meep progress: 306.071/1000.0 = 30.6% done in 912.3s, 2068.5s to go
# on time step 306120 (time=306.12), 0.00298148 s/step
# Meep progress: 307.392/1000.0 = 30.7% done in 916.3s, 2064.7s to go
# on time step 307446 (time=307.446), 0.00301983 s/step
# Meep progress: 308.704/1000.0 = 30.9% done in 920.3s, 2061.0s to go
# on time step 308759 (time=308.759), 0.00304941 s/step
# Meep progress: 310.014/1000.0 = 31.0% done in 924.3s, 2057.3s to go
# on time step 310060 (time=310.06), 0.00307515 s/step
# Meep progress: 311.318/1000.0 = 31.1% done in 928.3s, 2053.6s to go
# on time step 311372 (time=311.372), 0.00305068 s/step
# Meep progress: 312.628/1000.0 = 31.3% done in 932.3s, 2049.9s to go
# on time step 312682 (time=312.682), 0.00305455 s/step
# Meep progress: 313.909/1000.0 = 31.4% done in 936.3s, 2046.5s to go
# on time step 313966 (time=313.966), 0.00311721 s/step
# Meep progress: 315.197/1000.0 = 31.5% done in 940.3s, 2043.0s to go
# on time step 315250 (time=315.25), 0.00311632 s/step
# Meep progress: 316.485/1000.0 = 31.6% done in 944.3s, 2039.5s to go
# on time step 316537 (time=316.537), 0.00310865 s/step
# Meep progress: 317.796/1000.0 = 31.8% done in 948.3s, 2035.8s to go
# on time step 317851 (time=317.851), 0.00304588 s/step
# Meep progress: 319.104/1000.0 = 31.9% done in 952.3s, 2032.1s to go
# on time step 319160 (time=319.16), 0.00305751 s/step
# Meep progress: 320.419/1000.0 = 32.0% done in 956.4s, 2028.3s to go
# on time step 320477 (time=320.477), 0.00303932 s/step
# Meep progress: 321.714/1000.0 = 32.2% done in 960.4s, 2024.8s to go
# on time step 321771 (time=321.771), 0.00309296 s/step
# Meep progress: 323.031/1000.0 = 32.3% done in 964.4s, 2021.0s to go
# on time step 323089 (time=323.089), 0.00303549 s/step
# Meep progress: 324.297/1000.0 = 32.4% done in 968.4s, 2017.7s to go
# on time step 324345 (time=324.345), 0.00318704 s/step
# Meep progress: 325.59000000000003/1000.0 = 32.6% done in 972.4s, 2014.1s to go
# on time step 325648 (time=325.648), 0.00307141 s/step
# Meep progress: 326.911/1000.0 = 32.7% done in 976.4s, 2010.3s to go
# on time step 326967 (time=326.967), 0.00303346 s/step
# Meep progress: 328.101/1000.0 = 32.8% done in 980.4s, 2007.6s to go
# on time step 328155 (time=328.155), 0.00336731 s/step
# Meep progress: 329.386/1000.0 = 32.9% done in 984.4s, 2004.1s to go
# on time step 329443 (time=329.443), 0.00310746 s/step
# Meep progress: 330.696/1000.0 = 33.1% done in 988.4s, 2000.4s to go
# on time step 330754 (time=330.754), 0.00305127 s/step
# Meep progress: 332.075/1000.0 = 33.2% done in 992.4s, 1996.0s to go
# on time step 332129 (time=332.129), 0.00291049 s/step
# Meep progress: 333.398/1000.0 = 33.3% done in 996.4s, 1992.1s to go
# on time step 333456 (time=333.456), 0.00301463 s/step
# Meep progress: 334.74/1000.0 = 33.5% done in 1000.4s, 1988.1s to go
# on time step 334797 (time=334.797), 0.00298349 s/step
# Meep progress: 336.09000000000003/1000.0 = 33.6% done in 1004.4s, 1984.0s to go
# on time step 336149 (time=336.149), 0.00296023 s/step
# Meep progress: 337.372/1000.0 = 33.7% done in 1008.4s, 1980.5s to go
# on time step 337432 (time=337.432), 0.00311949 s/step
# Meep progress: 338.64/1000.0 = 33.9% done in 1012.4s, 1977.2s to go
# on time step 338699 (time=338.699), 0.00315868 s/step
# Meep progress: 339.963/1000.0 = 34.0% done in 1016.4s, 1973.3s to go
# on time step 340021 (time=340.021), 0.00302622 s/step
# Meep progress: 341.306/1000.0 = 34.1% done in 1020.4s, 1969.2s to go
# on time step 341370 (time=341.37), 0.00296532 s/step
# Meep progress: 342.613/1000.0 = 34.3% done in 1024.4s, 1965.5s to go
# on time step 342674 (time=342.674), 0.0030696 s/step
# Meep progress: 343.896/1000.0 = 34.4% done in 1028.4s, 1962.0s to go
# on time step 343960 (time=343.96), 0.0031126 s/step
# Meep progress: 345.25/1000.0 = 34.5% done in 1032.4s, 1957.9s to go
# on time step 345311 (time=345.311), 0.00296107 s/step
# Meep progress: 346.553/1000.0 = 34.7% done in 1036.4s, 1954.2s to go
# on time step 346613 (time=346.613), 0.00307544 s/step
# Meep progress: 347.883/1000.0 = 34.8% done in 1040.4s, 1950.2s to go
# on time step 347947 (time=347.947), 0.00300029 s/step
# Meep progress: 349.197/1000.0 = 34.9% done in 1044.4s, 1946.4s to go
# on time step 349258 (time=349.258), 0.00305151 s/step
# Meep progress: 350.524/1000.0 = 35.1% done in 1048.4s, 1942.5s to go
# on time step 350585 (time=350.585), 0.00301437 s/step
# Meep progress: 351.82/1000.0 = 35.2% done in 1052.4s, 1938.9s to go
# on time step 351883 (time=351.883), 0.00308174 s/step
# Meep progress: 353.137/1000.0 = 35.3% done in 1056.4s, 1935.1s to go
# on time step 353198 (time=353.198), 0.00304402 s/step
# Meep progress: 354.46/1000.0 = 35.4% done in 1060.4s, 1931.2s to go
# on time step 354521 (time=354.521), 0.00302408 s/step
# Meep progress: 355.75600000000003/1000.0 = 35.6% done in 1064.4s, 1927.5s to go
# on time step 355817 (time=355.817), 0.0030884 s/step
# Meep progress: 357.067/1000.0 = 35.7% done in 1068.4s, 1923.8s to go
# on time step 357128 (time=357.128), 0.00305359 s/step
# Meep progress: 358.356/1000.0 = 35.8% done in 1072.4s, 1920.2s to go
# on time step 358416 (time=358.416), 0.00310665 s/step
# Meep progress: 359.66700000000003/1000.0 = 36.0% done in 1076.4s, 1916.4s to go
# on time step 359723 (time=359.723), 0.00306099 s/step
# Meep progress: 360.956/1000.0 = 36.1% done in 1080.4s, 1912.8s to go
# on time step 361015 (time=361.015), 0.00309682 s/step
# Meep progress: 362.249/1000.0 = 36.2% done in 1084.4s, 1909.1s to go
# on time step 362312 (time=362.312), 0.00308421 s/step
# Meep progress: 363.599/1000.0 = 36.4% done in 1088.4s, 1905.0s to go
# on time step 363662 (time=363.662), 0.00296376 s/step
# Meep progress: 364.935/1000.0 = 36.5% done in 1092.4s, 1901.0s to go
# on time step 364996 (time=364.996), 0.00299882 s/step
# Meep progress: 366.25100000000003/1000.0 = 36.6% done in 1096.4s, 1897.2s to go
# on time step 366307 (time=366.307), 0.00305313 s/step
# Meep progress: 367.574/1000.0 = 36.8% done in 1100.4s, 1893.3s to go
# on time step 367634 (time=367.634), 0.00301621 s/step
# Meep progress: 368.901/1000.0 = 36.9% done in 1104.4s, 1889.4s to go
# on time step 368961 (time=368.961), 0.00301519 s/step
# Meep progress: 370.19100000000003/1000.0 = 37.0% done in 1108.4s, 1885.8s to go
# on time step 370253 (time=370.253), 0.00309682 s/step
# Meep progress: 371.495/1000.0 = 37.1% done in 1112.4s, 1882.0s to go
# on time step 371559 (time=371.559), 0.00306527 s/step
# Meep progress: 372.801/1000.0 = 37.3% done in 1116.4s, 1878.3s to go
# on time step 372865 (time=372.865), 0.00306344 s/step
# Meep progress: 374.116/1000.0 = 37.4% done in 1120.4s, 1874.4s to go
# on time step 374180 (time=374.18), 0.00304276 s/step
# Meep progress: 375.425/1000.0 = 37.5% done in 1124.4s, 1870.6s to go
# on time step 375488 (time=375.488), 0.00305904 s/step
# Meep progress: 376.732/1000.0 = 37.7% done in 1128.4s, 1866.9s to go
# on time step 376792 (time=376.792), 0.00306875 s/step
# Meep progress: 378.055/1000.0 = 37.8% done in 1132.4s, 1863.0s to go
# on time step 378117 (time=378.117), 0.00302067 s/step
# Meep progress: 379.349/1000.0 = 37.9% done in 1136.4s, 1859.3s to go
# on time step 379414 (time=379.414), 0.00308524 s/step
# Meep progress: 380.644/1000.0 = 38.1% done in 1140.4s, 1855.6s to go
# on time step 380706 (time=380.706), 0.00309635 s/step
# Meep progress: 381.981/1000.0 = 38.2% done in 1144.4s, 1851.6s to go
# on time step 382046 (time=382.046), 0.00298733 s/step
# Meep progress: 383.326/1000.0 = 38.3% done in 1148.4s, 1847.5s to go
# on time step 383394 (time=383.394), 0.00296927 s/step
# Meep progress: 384.632/1000.0 = 38.5% done in 1152.4s, 1843.8s to go
# on time step 384701 (time=384.701), 0.00306292 s/step
# Meep progress: 385.956/1000.0 = 38.6% done in 1156.4s, 1839.8s to go
# on time step 386022 (time=386.022), 0.00302976 s/step
# Meep progress: 387.254/1000.0 = 38.7% done in 1160.4s, 1836.1s to go
# on time step 387319 (time=387.319), 0.00308531 s/step
# Meep progress: 388.563/1000.0 = 38.9% done in 1164.4s, 1832.3s to go
# on time step 388627 (time=388.627), 0.00305967 s/step
# Meep progress: 389.86/1000.0 = 39.0% done in 1168.4s, 1828.6s to go
# on time step 389931 (time=389.931), 0.00306752 s/step
# Meep progress: 391.152/1000.0 = 39.1% done in 1172.4s, 1825.0s to go
# on time step 391221 (time=391.221), 0.00310249 s/step
# Meep progress: 392.47/1000.0 = 39.2% done in 1176.4s, 1821.1s to go
# on time step 392536 (time=392.536), 0.00304303 s/step
# Meep progress: 393.765/1000.0 = 39.4% done in 1180.4s, 1817.4s to go
# on time step 393838 (time=393.838), 0.00307298 s/step
# Meep progress: 395.093/1000.0 = 39.5% done in 1184.4s, 1813.4s to go
# on time step 395164 (time=395.164), 0.00301849 s/step
# Meep progress: 396.40500000000003/1000.0 = 39.6% done in 1188.4s, 1809.6s to go
# on time step 396474 (time=396.474), 0.00305528 s/step
# Meep progress: 397.68/1000.0 = 39.8% done in 1192.4s, 1806.1s to go
# on time step 397748 (time=397.748), 0.00314137 s/step
# Meep progress: 398.988/1000.0 = 39.9% done in 1196.4s, 1802.3s to go
# on time step 399057 (time=399.057), 0.00305647 s/step
# Meep progress: 400.309/1000.0 = 40.0% done in 1200.4s, 1798.4s to go
# on time step 400380 (time=400.38), 0.0030243 s/step
# Meep progress: 401.634/1000.0 = 40.2% done in 1204.4s, 1794.4s to go
# on time step 401697 (time=401.697), 0.00303892 s/step
# Meep progress: 402.954/1000.0 = 40.3% done in 1208.4s, 1790.5s to go
# on time step 403025 (time=403.025), 0.00301353 s/step
# Meep progress: 404.293/1000.0 = 40.4% done in 1212.4s, 1786.5s to go
# on time step 404359 (time=404.359), 0.0029999 s/step
# Meep progress: 405.618/1000.0 = 40.6% done in 1216.5s, 1782.6s to go
# on time step 405686 (time=405.686), 0.00301575 s/step
# Meep progress: 406.92/1000.0 = 40.7% done in 1220.5s, 1778.8s to go
# on time step 406991 (time=406.991), 0.00306627 s/step
# Meep progress: 408.262/1000.0 = 40.8% done in 1224.5s, 1774.7s to go
# on time step 408332 (time=408.332), 0.0029851 s/step
# Meep progress: 409.586/1000.0 = 41.0% done in 1228.5s, 1770.8s to go
# on time step 409658 (time=409.658), 0.00301759 s/step
# Meep progress: 410.866/1000.0 = 41.1% done in 1232.5s, 1767.2s to go
# on time step 410940 (time=410.94), 0.00312096 s/step
# Meep progress: 412.187/1000.0 = 41.2% done in 1236.5s, 1763.3s to go
# on time step 412262 (time=412.262), 0.00302708 s/step
# Meep progress: 413.475/1000.0 = 41.3% done in 1240.5s, 1759.6s to go
# on time step 413541 (time=413.541), 0.00312981 s/step
# Meep progress: 414.81100000000004/1000.0 = 41.5% done in 1244.5s, 1755.6s to go
# on time step 414883 (time=414.883), 0.00298086 s/step
# Meep progress: 416.164/1000.0 = 41.6% done in 1248.5s, 1751.5s to go
# on time step 416242 (time=416.242), 0.00294423 s/step
# Meep progress: 417.514/1000.0 = 41.8% done in 1252.5s, 1747.3s to go
# on time step 417594 (time=417.594), 0.00295986 s/step
# Meep progress: 418.858/1000.0 = 41.9% done in 1256.5s, 1743.3s to go
# on time step 418934 (time=418.934), 0.00298705 s/step
# Meep progress: 420.247/1000.0 = 42.0% done in 1260.5s, 1738.9s to go
# on time step 420331 (time=420.331), 0.00286367 s/step
# Meep progress: 421.685/1000.0 = 42.2% done in 1264.5s, 1734.1s to go
# on time step 421765 (time=421.765), 0.00279103 s/step
# Meep progress: 423.086/1000.0 = 42.3% done in 1268.5s, 1729.7s to go
# on time step 423167 (time=423.167), 0.00285514 s/step
# Meep progress: 424.47200000000004/1000.0 = 42.4% done in 1272.5s, 1725.3s to go
# on time step 424548 (time=424.548), 0.00289713 s/step
# Meep progress: 425.863/1000.0 = 42.6% done in 1276.5s, 1720.9s to go
# on time step 425949 (time=425.949), 0.00285514 s/step
# Meep progress: 427.252/1000.0 = 42.7% done in 1280.5s, 1716.5s to go
# on time step 427335 (time=427.335), 0.00288627 s/step
# Meep progress: 428.61400000000003/1000.0 = 42.9% done in 1284.5s, 1712.3s to go
# on time step 428697 (time=428.697), 0.00293804 s/step
# Meep progress: 429.961/1000.0 = 43.0% done in 1288.5s, 1708.2s to go
# on time step 430048 (time=430.048), 0.00296171 s/step
# Meep progress: 431.31100000000004/1000.0 = 43.1% done in 1292.5s, 1704.1s to go
# on time step 431389 (time=431.389), 0.00298477 s/step
# Meep progress: 432.636/1000.0 = 43.3% done in 1296.5s, 1700.2s to go
# on time step 432718 (time=432.718), 0.00301147 s/step
# Meep progress: 433.964/1000.0 = 43.4% done in 1300.5s, 1696.3s to go
# on time step 434037 (time=434.037), 0.00303373 s/step
# Meep progress: 435.229/1000.0 = 43.5% done in 1304.5s, 1692.8s to go
# on time step 435308 (time=435.308), 0.00315079 s/step
# Meep progress: 436.551/1000.0 = 43.7% done in 1308.5s, 1688.8s to go
# on time step 436633 (time=436.633), 0.00302899 s/step
# Meep progress: 437.88800000000003/1000.0 = 43.8% done in 1312.5s, 1684.8s to go
# on time step 437971 (time=437.971), 0.00298988 s/step
# Meep progress: 439.194/1000.0 = 43.9% done in 1316.5s, 1681.0s to go
# on time step 439275 (time=439.275), 0.00306814 s/step
# Meep progress: 440.512/1000.0 = 44.1% done in 1320.5s, 1677.1s to go
# on time step 440592 (time=440.592), 0.0030384 s/step
# Meep progress: 441.843/1000.0 = 44.2% done in 1324.5s, 1673.2s to go
# on time step 441925 (time=441.925), 0.00300306 s/step
# Meep progress: 443.144/1000.0 = 44.3% done in 1328.5s, 1669.4s to go
# on time step 443227 (time=443.227), 0.00307352 s/step
# Meep progress: 444.492/1000.0 = 44.4% done in 1332.5s, 1665.3s to go
# on time step 444578 (time=444.578), 0.00296193 s/step
# Meep progress: 445.836/1000.0 = 44.6% done in 1336.5s, 1661.2s to go
# on time step 445917 (time=445.917), 0.00298889 s/step
# Meep progress: 447.17/1000.0 = 44.7% done in 1340.5s, 1657.2s to go
# on time step 447253 (time=447.253), 0.00299416 s/step
# Meep progress: 448.469/1000.0 = 44.8% done in 1344.5s, 1653.5s to go
# on time step 448548 (time=448.548), 0.00309077 s/step
# Meep progress: 449.77500000000003/1000.0 = 45.0% done in 1348.5s, 1649.7s to go
# on time step 449863 (time=449.863), 0.00304221 s/step
# Meep progress: 451.086/1000.0 = 45.1% done in 1352.5s, 1645.8s to go
# on time step 451161 (time=451.161), 0.00308346 s/step
# Meep progress: 452.358/1000.0 = 45.2% done in 1356.5s, 1642.2s to go
# on time step 452435 (time=452.435), 0.00314227 s/step
# Meep progress: 453.524/1000.0 = 45.4% done in 1360.5s, 1639.3s to go
# on time step 453597 (time=453.597), 0.00344369 s/step
# Meep progress: 454.79900000000004/1000.0 = 45.5% done in 1364.5s, 1635.7s to go
# on time step 454874 (time=454.874), 0.00313397 s/step
# Meep progress: 456.088/1000.0 = 45.6% done in 1368.5s, 1632.0s to go
# on time step 456174 (time=456.174), 0.00307927 s/step
# Meep progress: 457.33500000000004/1000.0 = 45.7% done in 1372.5s, 1628.6s to go
# on time step 457425 (time=457.425), 0.00319874 s/step
# Meep progress: 458.663/1000.0 = 45.9% done in 1376.5s, 1624.6s to go
# on time step 458746 (time=458.746), 0.00302995 s/step
# Meep progress: 459.939/1000.0 = 46.0% done in 1380.5s, 1621.0s to go
# on time step 460028 (time=460.028), 0.00312275 s/step
# Meep progress: 461.262/1000.0 = 46.1% done in 1384.5s, 1617.1s to go
# on time step 461350 (time=461.35), 0.00302676 s/step
# Meep progress: 462.60900000000004/1000.0 = 46.3% done in 1388.5s, 1613.0s to go
# on time step 462695 (time=462.695), 0.00297408 s/step
# Meep progress: 463.922/1000.0 = 46.4% done in 1392.5s, 1609.1s to go
# on time step 464013 (time=464.013), 0.00303585 s/step
# Meep progress: 465.228/1000.0 = 46.5% done in 1396.5s, 1605.3s to go
# on time step 465322 (time=465.322), 0.00305618 s/step
# Meep progress: 466.483/1000.0 = 46.6% done in 1400.5s, 1601.8s to go
# on time step 466559 (time=466.559), 0.00323628 s/step
# Meep progress: 467.789/1000.0 = 46.8% done in 1404.5s, 1597.9s to go
# on time step 467877 (time=467.877), 0.00303675 s/step
# Meep progress: 469.074/1000.0 = 46.9% done in 1408.5s, 1594.3s to go
# on time step 469166 (time=469.166), 0.00310465 s/step
# Meep progress: 470.367/1000.0 = 47.0% done in 1412.5s, 1590.5s to go
# on time step 470447 (time=470.447), 0.00312489 s/step
# Meep progress: 471.62600000000003/1000.0 = 47.2% done in 1416.5s, 1587.0s to go
# on time step 471706 (time=471.706), 0.00317872 s/step
# Meep progress: 472.90500000000003/1000.0 = 47.3% done in 1420.5s, 1583.3s to go
# on time step 472980 (time=472.98), 0.00314103 s/step
# Meep progress: 474.201/1000.0 = 47.4% done in 1424.5s, 1579.5s to go
# on time step 474277 (time=474.277), 0.00308594 s/step
# Meep progress: 475.451/1000.0 = 47.5% done in 1428.5s, 1576.1s to go
# on time step 475531 (time=475.531), 0.00319033 s/step
# Meep progress: 476.74600000000004/1000.0 = 47.7% done in 1432.5s, 1572.3s to go
# on time step 476835 (time=476.835), 0.00306829 s/step
# Meep progress: 478.04200000000003/1000.0 = 47.8% done in 1436.5s, 1568.5s to go
# on time step 478132 (time=478.132), 0.00308457 s/step
# Meep progress: 479.374/1000.0 = 47.9% done in 1440.5s, 1564.5s to go
# on time step 479470 (time=479.47), 0.00299054 s/step
# Meep progress: 480.718/1000.0 = 48.1% done in 1444.5s, 1560.4s to go
# on time step 480811 (time=480.811), 0.00298381 s/step
# Meep progress: 482.011/1000.0 = 48.2% done in 1448.5s, 1556.7s to go
# on time step 482101 (time=482.101), 0.00310331 s/step
# Meep progress: 483.317/1000.0 = 48.3% done in 1452.5s, 1552.8s to go
# on time step 483409 (time=483.409), 0.00305843 s/step
# Meep progress: 484.63100000000003/1000.0 = 48.5% done in 1456.5s, 1548.9s to go
# on time step 484729 (time=484.729), 0.00303215 s/step
# Meep progress: 485.94800000000004/1000.0 = 48.6% done in 1460.5s, 1545.0s to go
# on time step 486032 (time=486.032), 0.00307088 s/step
# Meep progress: 487.209/1000.0 = 48.7% done in 1464.6s, 1541.4s to go
# on time step 487308 (time=487.308), 0.00313554 s/step
# Meep progress: 488.523/1000.0 = 48.9% done in 1468.6s, 1537.6s to go
# on time step 488618 (time=488.618), 0.00305562 s/step
# Meep progress: 489.831/1000.0 = 49.0% done in 1472.6s, 1533.7s to go
# on time step 489924 (time=489.924), 0.00306391 s/step
# Meep progress: 491.13/1000.0 = 49.1% done in 1476.6s, 1529.9s to go
# on time step 491222 (time=491.222), 0.00308296 s/step
# Meep progress: 492.43/1000.0 = 49.2% done in 1480.6s, 1526.1s to go
# on time step 492522 (time=492.522), 0.00307813 s/step
# Meep progress: 493.708/1000.0 = 49.4% done in 1484.6s, 1522.4s to go
# on time step 493799 (time=493.799), 0.00313255 s/step
# Meep progress: 494.98400000000004/1000.0 = 49.5% done in 1488.6s, 1518.7s to go
# on time step 495074 (time=495.074), 0.00313905 s/step
# Meep progress: 496.241/1000.0 = 49.6% done in 1492.6s, 1515.2s to go
# on time step 496332 (time=496.332), 0.00318127 s/step
# Meep progress: 497.541/1000.0 = 49.8% done in 1496.6s, 1511.4s to go
# ...
# on time step 847543 (time=847.543), 0.00292171 s/step
# Meep progress: 848.739/1000.0 = 84.9% done in 2541.0s, 452.8s to go
# on time step 848897 (time=848.897), 0.00295469 s/step
# Meep progress: 850.101/1000.0 = 85.0% done in 2545.0s, 448.8s to go
# on time step 850258 (time=850.258), 0.00293981 s/step
# Meep progress: 851.4350000000001/1000.0 = 85.1% done in 2549.0s, 444.8s to go
# on time step 851590 (time=851.59), 0.00300548 s/step
# Meep progress: 852.7470000000001/1000.0 = 85.3% done in 2553.0s, 440.8s to go
# on time step 852904 (time=852.904), 0.00304651 s/step
# Meep progress: 854.07/1000.0 = 85.4% done in 2557.0s, 436.9s to go
# on time step 854225 (time=854.225), 0.00302833 s/step
# Meep progress: 855.36/1000.0 = 85.5% done in 2561.0s, 433.1s to go
# on time step 855503 (time=855.503), 0.00313224 s/step
# Meep progress: 856.663/1000.0 = 85.7% done in 2565.0s, 429.2s to go
# on time step 856823 (time=856.823), 0.0030308 s/step
# Meep progress: 857.992/1000.0 = 85.8% done in 2569.0s, 425.2s to go
# on time step 858150 (time=858.15), 0.00301441 s/step
# Meep progress: 859.288/1000.0 = 85.9% done in 2573.0s, 421.3s to go
# on time step 859443 (time=859.443), 0.00309443 s/step
# Meep progress: 860.62/1000.0 = 86.1% done in 2577.0s, 417.3s to go
# on time step 860780 (time=860.78), 0.00299384 s/step
# Meep progress: 862.0/1000.0 = 86.2% done in 2581.0s, 413.2s to go
# on time step 862165 (time=862.165), 0.00289009 s/step
# Meep progress: 863.371/1000.0 = 86.3% done in 2585.0s, 409.1s to go
# on time step 863537 (time=863.537), 0.00291615 s/step
# Meep progress: 864.7280000000001/1000.0 = 86.5% done in 2589.0s, 405.0s to go
# on time step 864895 (time=864.895), 0.00294591 s/step
# Meep progress: 866.083/1000.0 = 86.6% done in 2593.0s, 400.9s to go
# on time step 866250 (time=866.25), 0.00295223 s/step
# Meep progress: 867.4680000000001/1000.0 = 86.7% done in 2597.0s, 396.8s to go
# on time step 867632 (time=867.632), 0.00289496 s/step
# Meep progress: 868.845/1000.0 = 86.9% done in 2601.0s, 392.6s to go
# on time step 868999 (time=868.999), 0.00292741 s/step
# Meep progress: 870.171/1000.0 = 87.0% done in 2605.0s, 388.7s to go
# on time step 870337 (time=870.337), 0.00299099 s/step
# Meep progress: 871.528/1000.0 = 87.2% done in 2609.0s, 384.6s to go
# on time step 871697 (time=871.697), 0.00294328 s/step
# Meep progress: 872.8530000000001/1000.0 = 87.3% done in 2613.0s, 380.6s to go
# on time step 872993 (time=872.993), 0.00308701 s/step
# Meep progress: 874.09/1000.0 = 87.4% done in 2617.0s, 377.0s to go
# on time step 874257 (time=874.257), 0.00316523 s/step
# Meep progress: 875.45/1000.0 = 87.5% done in 2621.0s, 372.9s to go
# on time step 875604 (time=875.604), 0.00296976 s/step
# Meep progress: 876.778/1000.0 = 87.7% done in 2625.0s, 368.9s to go
# on time step 876950 (time=876.95), 0.00297284 s/step
# Meep progress: 878.1460000000001/1000.0 = 87.8% done in 2629.0s, 364.8s to go
# on time step 878306 (time=878.306), 0.002951 s/step
# Meep progress: 879.4830000000001/1000.0 = 87.9% done in 2633.0s, 360.8s to go
# on time step 879630 (time=879.63), 0.00302237 s/step
# Meep progress: 880.8720000000001/1000.0 = 88.1% done in 2637.0s, 356.6s to go
# on time step 881056 (time=881.056), 0.00280649 s/step
# Meep progress: 882.2950000000001/1000.0 = 88.2% done in 2641.0s, 352.3s to go
# on time step 882469 (time=882.469), 0.00283224 s/step
# Meep progress: 883.654/1000.0 = 88.4% done in 2645.0s, 348.3s to go
# on time step 883816 (time=883.816), 0.00297003 s/step
# Meep progress: 884.9830000000001/1000.0 = 88.5% done in 2649.0s, 344.3s to go
# on time step 885125 (time=885.125), 0.00305597 s/step
# Meep progress: 886.287/1000.0 = 88.6% done in 2653.0s, 340.4s to go
# on time step 886442 (time=886.442), 0.00303909 s/step
# Meep progress: 887.607/1000.0 = 88.8% done in 2657.0s, 336.4s to go
# on time step 887762 (time=887.762), 0.00303144 s/step
# Meep progress: 888.886/1000.0 = 88.9% done in 2661.0s, 332.6s to go
# on time step 889050 (time=889.05), 0.00310624 s/step
# Meep progress: 890.196/1000.0 = 89.0% done in 2665.0s, 328.7s to go
# on time step 890361 (time=890.361), 0.00305121 s/step
# Meep progress: 891.53/1000.0 = 89.2% done in 2669.0s, 324.7s to go
# on time step 891692 (time=891.692), 0.00300558 s/step
# Meep progress: 892.908/1000.0 = 89.3% done in 2673.0s, 320.6s to go
# on time step 893074 (time=893.074), 0.00289464 s/step
# Meep progress: 894.263/1000.0 = 89.4% done in 2677.0s, 316.5s to go
# on time step 894424 (time=894.424), 0.00296442 s/step
# Meep progress: 895.6080000000001/1000.0 = 89.6% done in 2681.0s, 312.5s to go
# on time step 895772 (time=895.772), 0.00296883 s/step
# Meep progress: 896.931/1000.0 = 89.7% done in 2685.0s, 308.5s to go
# on time step 897091 (time=897.091), 0.00303481 s/step
# Meep progress: 898.278/1000.0 = 89.8% done in 2689.0s, 304.5s to go
# on time step 898440 (time=898.44), 0.00296566 s/step
# Meep progress: 899.505/1000.0 = 90.0% done in 2693.0s, 300.9s to go
# on time step 899668 (time=899.668), 0.00325741 s/step
# Meep progress: 900.815/1000.0 = 90.1% done in 2697.0s, 297.0s to go
# on time step 900975 (time=900.975), 0.00306066 s/step
# Meep progress: 902.1220000000001/1000.0 = 90.2% done in 2701.0s, 293.1s to go
# on time step 902270 (time=902.27), 0.0030907 s/step
# Meep progress: 903.481/1000.0 = 90.3% done in 2705.0s, 289.0s to go
# on time step 903631 (time=903.631), 0.00294168 s/step
# Meep progress: 904.841/1000.0 = 90.5% done in 2709.0s, 284.9s to go
# on time step 904994 (time=904.994), 0.00293593 s/step
# Meep progress: 906.176/1000.0 = 90.6% done in 2713.0s, 280.9s to go
# on time step 906347 (time=906.347), 0.00295672 s/step
# Meep progress: 907.537/1000.0 = 90.8% done in 2717.0s, 276.8s to go
# on time step 907694 (time=907.694), 0.0029709 s/step
# Meep progress: 908.8670000000001/1000.0 = 90.9% done in 2721.0s, 272.8s to go
# on time step 909036 (time=909.036), 0.00298135 s/step
# Meep progress: 910.239/1000.0 = 91.0% done in 2725.0s, 268.7s to go
# on time step 910415 (time=910.415), 0.00290189 s/step
# Meep progress: 911.631/1000.0 = 91.2% done in 2729.0s, 264.5s to go
# on time step 911798 (time=911.798), 0.00289346 s/step
# Meep progress: 912.931/1000.0 = 91.3% done in 2733.1s, 260.7s to go
# on time step 913095 (time=913.095), 0.00308602 s/step
# Meep progress: 914.231/1000.0 = 91.4% done in 2737.1s, 256.8s to go
# on time step 914390 (time=914.39), 0.00308988 s/step
# Meep progress: 915.5020000000001/1000.0 = 91.6% done in 2741.1s, 253.0s to go
# on time step 915662 (time=915.662), 0.00314661 s/step
# Meep progress: 916.785/1000.0 = 91.7% done in 2745.1s, 249.2s to go
# on time step 916936 (time=916.936), 0.00314096 s/step
# Meep progress: 918.063/1000.0 = 91.8% done in 2749.1s, 245.4s to go
# on time step 918222 (time=918.222), 0.00311209 s/step
# Meep progress: 919.337/1000.0 = 91.9% done in 2753.1s, 241.6s to go
# on time step 919495 (time=919.495), 0.00314395 s/step
# Meep progress: 920.639/1000.0 = 92.1% done in 2757.1s, 237.7s to go
# on time step 920806 (time=920.806), 0.00305117 s/step
# Meep progress: 921.986/1000.0 = 92.2% done in 2761.1s, 233.6s to go
# on time step 922152 (time=922.152), 0.00297212 s/step
# Meep progress: 923.3430000000001/1000.0 = 92.3% done in 2765.1s, 229.6s to go
# on time step 923530 (time=923.53), 0.00290398 s/step
# Meep progress: 924.739/1000.0 = 92.5% done in 2769.1s, 225.4s to go
# on time step 924907 (time=924.907), 0.00290526 s/step
# Meep progress: 926.087/1000.0 = 92.6% done in 2773.1s, 221.3s to go
# on time step 926250 (time=926.25), 0.00297858 s/step
# Meep progress: 927.413/1000.0 = 92.7% done in 2777.1s, 217.4s to go
# on time step 927584 (time=927.584), 0.00299941 s/step
# Meep progress: 928.7710000000001/1000.0 = 92.9% done in 2781.1s, 213.3s to go
# on time step 928937 (time=928.937), 0.00295644 s/step
# Meep progress: 930.142/1000.0 = 93.0% done in 2785.1s, 209.2s to go
# on time step 930313 (time=930.313), 0.0029073 s/step
# Meep progress: 931.474/1000.0 = 93.1% done in 2789.1s, 205.2s to go
# on time step 931635 (time=931.635), 0.00302776 s/step
# Meep progress: 932.778/1000.0 = 93.3% done in 2793.1s, 201.3s to go
# on time step 932943 (time=932.943), 0.00305999 s/step
# Meep progress: 934.101/1000.0 = 93.4% done in 2797.1s, 197.3s to go
# on time step 934273 (time=934.273), 0.00300925 s/step
# Meep progress: 935.441/1000.0 = 93.5% done in 2801.1s, 193.3s to go
# on time step 935609 (time=935.609), 0.00299635 s/step
# Meep progress: 936.756/1000.0 = 93.7% done in 2805.1s, 189.4s to go
# on time step 936922 (time=936.922), 0.00304672 s/step
# Meep progress: 938.071/1000.0 = 93.8% done in 2809.1s, 185.4s to go
# on time step 938236 (time=938.236), 0.00304582 s/step
# Meep progress: 939.3870000000001/1000.0 = 93.9% done in 2813.1s, 181.5s to go
# on time step 939553 (time=939.553), 0.0030382 s/step
# Meep progress: 940.683/1000.0 = 94.1% done in 2817.1s, 177.6s to go
# on time step 940845 (time=940.845), 0.00309613 s/step
# Meep progress: 942.0360000000001/1000.0 = 94.2% done in 2821.1s, 173.6s to go
# on time step 942205 (time=942.205), 0.00294226 s/step
# Meep progress: 943.39/1000.0 = 94.3% done in 2825.1s, 169.5s to go
# on time step 943553 (time=943.553), 0.00296759 s/step
# Meep progress: 944.746/1000.0 = 94.5% done in 2829.1s, 165.5s to go
# on time step 944912 (time=944.912), 0.00294474 s/step
# Meep progress: 946.097/1000.0 = 94.6% done in 2833.1s, 161.4s to go
# on time step 946269 (time=946.269), 0.0029498 s/step
# Meep progress: 947.46/1000.0 = 94.7% done in 2837.1s, 157.3s to go
# on time step 947632 (time=947.632), 0.00293482 s/step
# Meep progress: 948.816/1000.0 = 94.9% done in 2841.1s, 153.3s to go
# on time step 948987 (time=948.987), 0.00295417 s/step
# Meep progress: 950.159/1000.0 = 95.0% done in 2845.1s, 149.2s to go
# on time step 950331 (time=950.331), 0.00297799 s/step
# Meep progress: 951.491/1000.0 = 95.1% done in 2849.1s, 145.3s to go
# on time step 951658 (time=951.658), 0.00301684 s/step
# Meep progress: 952.801/1000.0 = 95.3% done in 2853.1s, 141.3s to go
# on time step 952968 (time=952.968), 0.00305377 s/step
# Meep progress: 954.11/1000.0 = 95.4% done in 2857.1s, 137.4s to go
# on time step 954279 (time=954.279), 0.00305269 s/step
# Meep progress: 955.436/1000.0 = 95.5% done in 2861.1s, 133.4s to go
# on time step 955604 (time=955.604), 0.0030189 s/step
# Meep progress: 956.7660000000001/1000.0 = 95.7% done in 2865.1s, 129.5s to go
# on time step 956933 (time=956.933), 0.00301171 s/step
# Meep progress: 958.085/1000.0 = 95.8% done in 2869.1s, 125.5s to go
# on time step 958254 (time=958.254), 0.00302852 s/step
# Meep progress: 959.408/1000.0 = 95.9% done in 2873.1s, 121.6s to go
# on time step 959577 (time=959.577), 0.00302385 s/step
# Meep progress: 960.748/1000.0 = 96.1% done in 2877.1s, 117.5s to go
# on time step 960920 (time=960.92), 0.00298027 s/step
# Meep progress: 962.125/1000.0 = 96.2% done in 2881.1s, 113.4s to go
# on time step 962305 (time=962.305), 0.00288884 s/step
# Meep progress: 963.524/1000.0 = 96.4% done in 2885.1s, 109.2s to go
# on time step 963701 (time=963.701), 0.0028655 s/step
# Meep progress: 964.9060000000001/1000.0 = 96.5% done in 2889.1s, 105.1s to go
# on time step 965086 (time=965.086), 0.00288932 s/step
# Meep progress: 966.294/1000.0 = 96.6% done in 2893.1s, 100.9s to go
# on time step 966472 (time=966.472), 0.00288743 s/step
# Meep progress: 967.618/1000.0 = 96.8% done in 2897.1s, 97.0s to go
# on time step 967790 (time=967.79), 0.003037 s/step
# Meep progress: 968.863/1000.0 = 96.9% done in 2901.1s, 93.2s to go
# on time step 969016 (time=969.016), 0.00326284 s/step
# Meep progress: 970.085/1000.0 = 97.0% done in 2905.1s, 89.6s to go
# on time step 970250 (time=970.25), 0.00324375 s/step
# Meep progress: 971.313/1000.0 = 97.1% done in 2909.1s, 85.9s to go
# on time step 971488 (time=971.488), 0.00323281 s/step
# Meep progress: 972.5930000000001/1000.0 = 97.3% done in 2913.1s, 82.1s to go
# on time step 972765 (time=972.765), 0.0031325 s/step
# Meep progress: 973.952/1000.0 = 97.4% done in 2917.1s, 78.0s to go
# on time step 974138 (time=974.138), 0.00291364 s/step
# Meep progress: 975.221/1000.0 = 97.5% done in 2921.1s, 74.2s to go
# on time step 975379 (time=975.379), 0.00322414 s/step
# Meep progress: 976.552/1000.0 = 97.7% done in 2925.1s, 70.2s to go
# on time step 976743 (time=976.743), 0.00293311 s/step
# Meep progress: 977.922/1000.0 = 97.8% done in 2929.1s, 66.1s to go
# on time step 978100 (time=978.1), 0.00294881 s/step
# Meep progress: 979.29/1000.0 = 97.9% done in 2933.1s, 62.0s to go
# on time step 979465 (time=979.465), 0.00293203 s/step
# Meep progress: 980.666/1000.0 = 98.1% done in 2937.1s, 57.9s to go
# on time step 980839 (time=980.839), 0.00291249 s/step
# Meep progress: 982.087/1000.0 = 98.2% done in 2941.1s, 53.6s to go
# on time step 982269 (time=982.269), 0.00279854 s/step
# Meep progress: 983.518/1000.0 = 98.4% done in 2945.1s, 49.4s to go
# on time step 983710 (time=983.71), 0.00277585 s/step
# Meep progress: 984.975/1000.0 = 98.5% done in 2949.1s, 45.0s to go
# on time step 985161 (time=985.161), 0.00275874 s/step
# Meep progress: 986.41/1000.0 = 98.6% done in 2953.1s, 40.7s to go
# on time step 986593 (time=986.593), 0.00279453 s/step
# Meep progress: 987.85/1000.0 = 98.8% done in 2957.1s, 36.4s to go
# on time step 988035 (time=988.035), 0.00277553 s/step
# Meep progress: 989.303/1000.0 = 98.9% done in 2961.1s, 32.0s to go
# on time step 989487 (time=989.487), 0.00275546 s/step
# Meep progress: 990.741/1000.0 = 99.1% done in 2965.1s, 27.7s to go
# on time step 990921 (time=990.921), 0.00279067 s/step
# Meep progress: 992.1320000000001/1000.0 = 99.2% done in 2969.1s, 23.5s to go
# on time step 992308 (time=992.308), 0.00288518 s/step
# Meep progress: 993.494/1000.0 = 99.3% done in 2973.1s, 19.5s to go
# on time step 993669 (time=993.669), 0.00293973 s/step
# Meep progress: 994.847/1000.0 = 99.5% done in 2977.1s, 15.4s to go
# on time step 995024 (time=995.024), 0.0029532 s/step
# Meep progress: 996.201/1000.0 = 99.6% done in 2981.1s, 11.4s to go
# on time step 996378 (time=996.378), 0.00295547 s/step
# Meep progress: 997.558/1000.0 = 99.8% done in 2985.2s, 7.3s to go
# on time step 997737 (time=997.737), 0.00294412 s/step
# Meep progress: 998.913/1000.0 = 99.9% done in 2989.2s, 3.3s to go
# on time step 999094 (time=999.094), 0.0029483 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 1000.0 (1000000 timesteps)
#      block, center = (-0.76,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.6,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
ez_data_up = np.array(ez_data_up)
ez_data_cen = np.array(ez_data_cen)
ez_data_down = np.array(ez_data_down)

print(len(ez_data_cen))

print(1 + int(round(t_xx/dt)))
# Out:
# 76923
# 41

# %%
ez_data_cen = np.array(ez_data_cen)
ez_data_up = np.array(ez_data_up)
ez_data_down = np.array(ez_data_down)
'''
#plt.subplot_adjust(hspace = .35)
plt.figure(dpi = 200)
start = round(len(ez_data_cen) / t *1)

for i in range(start,len(ez_data_cen),1):
    plt.subplot(3,1,1)
    plt.plot(i,ez_data_up[i],'k.')
    plt.subplot(3,1,2)
    plt.plot(i,ez_data_cen[i],'k.')
    plt.subplot(3,1,3)
    plt.plot(i,ez_data_down[i],'k.')
    if i ==  (len(ez_data_cen)-1):
        plt.subplot(3,1,1)
        plt.title('upper point')
        plt.ylabel('Electrical field amplitude')
        plt.xlabel('time (dt/point)')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_up[i],'b .')
        plt.subplot(3,1,2)
        plt.title('center point')
        plt.ylabel('Electrical field amplitude')
        plt.xlabel('time (dt/point)')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_cen[i],'b .')
        plt.subplot(3,1,3)
        plt.title('downer point')
        plt.ylabel('Electrical field amplitude')
        plt.xlabel('time (dt/point)')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_down[i],'b .')
'''
# Out:
# "\n#plt.subplot_adjust(hspace = .35)\nplt.figure(dpi = 200)\nstart = round(len(ez_data_cen) / t *1)\n\nfor i in range(start,len(ez_data_cen),1):\n    plt.subplot(3,1,1)\n    plt.plot(i,ez_data_up[i],'k.')\n    plt.subplot(3,1,2)\n    plt.plot(i,ez_data_cen[i],'k.')\n    plt.subplot(3,1,3)\n    plt.plot(i,ez_data_down[i],'k.')\n    if i ==  (len(ez_data_cen)-1):\n        plt.subplot(3,1,1)\n        plt.title('upper point')\n        plt.ylabel('Electrical field amplitude')\n        plt.xlabel('time (dt/point)')\n        plt.xlim(start,len(ez_data_cen))\n        plt.plot(ez_data_up[i],'b .')\n        plt.subplot(3,1,2)\n        plt.title('center point')\n        plt.ylabel('Electrical field amplitude')\n        plt.xlabel('time (dt/point)')\n        plt.xlim(start,len(ez_data_cen))\n        plt.plot(ez_data_cen[i],'b .')\n        plt.subplot(3,1,3)\n        plt.title('downer point')\n        plt.ylabel('Electrical field amplitude')\n        plt.xlabel('time (dt/point)')\n        plt.xlim(start,len(ez_data_cen))\n        plt.plot(ez_data_down[i],'b .')\n"

# %%
index1_up = 0
index1_cen = 0
index1_down = 0

index2_up = 0
index2_cen = 0
index2_down = 0

period_max_up = 0
period_max_cen = 0
period_max_down = 0
period_next_max_up = 0
period_next_max_cen = 0
period_next_max_down = 0

initial_index = round(len(ez_data_cen) / t * 200 )
print(initial_index)

end_index = len(ez_data_cen) - 2*( 1 +int(round(t_xx/dt))) 
print(end_index)
# Out:
# 15385
# 76841

# %%
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_up[j])
        period_next.append(ez_data_up[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '-------upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '-----振幅誤差')
        index1 = np.where(ez_data_up == period_max)
        print(index1, '--- upper point index1')
        index2 = np.where(ez_data_up == period_next_max)
        print(index2, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' , index1  , '\t' ,  index2 ,'\n\n' )
        print('upper point 到達誤差範圍內的所需 meep time unit' , 38944 / len(ez_data_up) * 500 , '\n')
        print('------------------------------------------------------')
        break


for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_cen[j])
        period_next.append(ez_data_cen[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '-------upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '-----振幅誤差')
        index1 = np.where(ez_data_cen == period_max)
        print(index1, '--- upper point index1')
        index2 = np.where(ez_data_cen == period_next_max)
        print(index2, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' , index1  , '\t' ,  index2 ,'\n\n' )
        print('center point 到達誤差範圍內的所需 meep time unit' , 38944 / len(ez_data_cen) * 500 , '\n')
        print('-----------------------------------------------------')
        break
        

for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_down[j])
        period_next.append(ez_data_down[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- down point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '-------down point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '-----振幅誤差')
        index1 = np.where(ez_data_down == period_max)
        print(index1, '--- down point index1')
        index2 = np.where(ez_data_down == period_next_max)
        print(index2, '--- down point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' , index1  , '\t' ,  index2 ,'\n\n' )
        print('down point 到達誤差範圍內的所需 meep time unit' , 38944 / len(ez_data_down) * 500 , '\n')
        print('---------------------------------------------------')
        break



dt_ = str(dt)
# Out:
# (0.1613575865172849+0j) -------- upper point one period 內最大振福
# (0.16135710409182313+0j) -------upper point one next_period 內最大振福
# (4.824254617730173e-07+0j) -----振幅誤差
# (array([23790]),) --- upper point index1
# (array([23867]),) --- upper point index2
# (0.1613575865172849+0j) 	 (0.16135710409182313+0j) 	 (4.824254617730173e-07+0j) 	 (array([23790]),) 	 (array([23867]),)
#
#
# upper point 到達誤差範圍內的所需 meep time unit 253.13625313625315
#
# ------------------------------------------------------
# (0.19762406825023046+0j) -------- upper point one period 內最大振福
# (0.19762429505168796+0j) -------upper point one next_period 內最大振福
# (-2.2680145750353375e-07+0j) -----振幅誤差
# (array([30306]),) --- upper point index1
# (array([30344]),) --- upper point index2
# (0.19762406825023046+0j) 	 (0.19762429505168796+0j) 	 (-2.2680145750353375e-07+0j) 	 (array([30306]),) 	 (array([30344]),)
#
#
# center point 到達誤差範圍內的所需 meep time unit 253.13625313625315
#
# -----------------------------------------------------
# (0.16350402677123754+0j) -------- down point one period 內最大振福
# (0.16350337094091272+0j) -------down point one next_period 內最大振福
# (6.558303248249686e-07+0j) -----振幅誤差
# (array([38905]),) --- down point index1
# (array([38944]),) --- down point index2
# (0.16350402677123754+0j) 	 (0.16350337094091272+0j) 	 (6.558303248249686e-07+0j) 	 (array([38905]),) 	 (array([38944]),)
#
#
# down point 到達誤差範圍內的所需 meep time unit 253.13625313625315
#
# ---------------------------------------------------

# %%
plt.figure(dpi = 150)
plt.title('Upper point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
for i in range(38905 , 38944) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_up[i] , 'b.')

# %%
plt.figure(dpi = 150)
plt.title('center point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_cen[73320]
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_cen[i] , 'b.')
    if max_value < ez_data_cen[i] :
        max_value = ez_data_cen[i]

print(max_value)
# Out:
# (0.19722704344532221+0j)

# %%
plt.figure(dpi = 150)
plt.title('downnerr point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_down[i] , 'b.')

# %% [markdown]
# # Phase for Cell height = 600nm

# %%
t_xx = (.532)
dt = (t_xx / 40)
t = 1000
x_obs = -0.5 * sx + dpml + dsub + gh + 0.002
y_obs_down = -0.5 * sy + gp/2
y_obs_cen = -0.5 * sy + 3*gp/2
y_obs_up = 0.5 * sy - gp/2

print(int((t_xx)/dt))

# %% [markdown]
# # Following is Simulation that Cell height = 300 nm

# %%
sim.reset_meep()
resolution = 500  # pixels/μm

dpml = 1.0  # PML thickness
dsub = 0.5  # substrate thickness
dcaa = 0.06  # air rigion for alpha structure
# alpha structure is that one period = 200nm，sigle cell width = 80nm locate at center
dcab = 0.025 # air rigion for beta structure 
# beta structure is that one period = 200nm，sigle cell width = 150nm locate at center
gp = 0.2  # grating periodicity
gh = 0.3  # grating height
gwa = 0.08 # alpha grating cell width
gwb = 0.15 # beta grating cell width

num_cells = 3  # number of grating unit cells

# air region thickness adjacent to grating
dair = 1

wvl = 0.532  # center wavelength
fcen = 1 / wvl  # center frequency


glass = mp.Medium(index= 2.6678)

pml_layers = [mp.PML(thickness=dpml, direction = mp.X )]

symmetries = [mp.Mirror(mp.Y)]

sx = dpml + dsub + gh + dair + dpml
sy = num_cells*gp
cell_size = mp.Vector3(sx, sy)

sources = [
    mp.Source(
        mp.ContinuousSource(frequency = 2), # frequemcy = 2原因是 meep 的 C=1，所以 1/? = 0.5 um，?即是2
        component = mp.Ez,
        center = mp.Vector3(-0.5 * sx + dpml ),
        size = mp.Vector3(y=sy),
    )
]

geometry = [
    mp.Block(
        material=glass,
        size=mp.Vector3(dsub, mp.inf, mp.inf),
        center=mp.Vector3(-0.5 * sx + dpml + 0.04 + dsub/2),
    )
]

# %%
for j in range(num_cells):
    geometry.append(
    mp.Block(
        material=glass,
        size=mp.Vector3(gh, gwa, mp.inf),
        center=mp.Vector3(
            -0.5 * sx + dpml + dsub + 0.5 * gh,
            -0.5 * sy + gp/2 + (j * 3 * gp),
            #-0.5 * sy + gp/2,
        ),
    )
    )
for j in range(num_cells):
    geometry.append(
        mp.Block(
            material=glass,
            size=mp.Vector3(gh, gwb, mp.inf),
            center=mp.Vector3(
                -0.5 * sx + dpml + dsub + 0.5 * gh,
                -0.5 * sy + gp + gp/2  + (j * 3 * gp),
                #-0.5 * sy + gp/2 + gp  , 
            ),
        )
    )

for j in range(num_cells):
    geometry.append(
    mp.Block(
        material=glass,
        size=mp.Vector3(gh, gwa, mp.inf),
        center=mp.Vector3(
            -0.5 * sx + dpml + dsub + 0.5 * gh,
            -0.5 * sy + 2*gp + gp/2  + (j * 3 * gp),
            #-0.5 * sy  + gp/2 + 2*gp ,
        ),
    )
    )

# %%
k_point = mp.Vector3()  # Gamma 點表示週期邊界條件
k_points = [k_point]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
    k_point = mp.Vector3(),
)

# %matplotlib inline
plt.figure(dpi = 125)
sim.plot2D()
plt.show()

# %%
t_xx = (.532)
dt = (t_xx / 40)
t = 1000
x_obs = -0.5 * sx + dpml + dsub + gh + 0.002
y_obs_down = -0.5 * sy + gp/2
y_obs_cen = -0.5 * sy + 3*gp/2
y_obs_up = 0.5 * sy - gp/2

print(int((t_xx)/dt))

# %%
# 儲存場量數值的列表
ez_data_cen = []
ez_data_up = []
ez_data_down = []
###
def get_slice(sim):
    ez_data_cen.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_cen) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_up.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_up) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))
    ez_data_down.append(sim.get_array(center = mp.Vector3(x_obs,y_obs_down) , size = mp.Vector3(0,0) , component = mp.Ez , cmplx = True))

sim.run(mp.at_every(dt , get_slice) , until = t)

plt.figure(dpi = 100)
sim.plot2D(fields=mp.Ez)
plt.show()

# %%
ez_data_up = np.array(ez_data_up)
ez_data_cen = np.array(ez_data_cen)
ez_data_down = np.array(ez_data_down)

print(len(ez_data_cen))

print(1 + int(round(t_xx/dt)))

# %%
ez_data_cen = np.array(ez_data_cen)
ez_data_up = np.array(ez_data_up)
ez_data_down = np.array(ez_data_down)

#plt.subplot_adjust(hspace = .35)
plt.figure(dpi = 200)
start = round(len(ez_data_cen) / t *1)

for i in range(start,len(ez_data_cen),1):
    plt.subplot(3,1,1)
    plt.plot(i,ez_data_up[i],'k.')
    plt.subplot(3,1,2)
    plt.plot(i,ez_data_cen[i],'k.')
    plt.subplot(3,1,3)
    plt.plot(i,ez_data_down[i],'k.')
    if i ==  (len(ez_data_cen)-1):
        plt.subplot(3,1,1)
        plt.title('upper point')
        plt.xlabel('time point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_up[i],'b .')
        plt.subplot(3,1,2)
        plt.title('center point')
        plt.xlabel('time point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_cen[i],'b .')
        plt.subplot(3,1,3)
        plt.title('downer point')
        plt.xlabel('time point')
        plt.xlim(start,len(ez_data_cen))
        plt.plot(ez_data_down[i],'b .')

# %%
index1_up = 0
index1_cen = 0
index1_down = 0

index2_up = 0
index2_cen = 0
index2_down = 0

period_max_up = 0
period_max_cen = 0
period_max_down = 0
period_next_max_up = 0
period_next_max_cen = 0
period_next_max_down = 0

initial_index = round(len(ez_data_cen) / t * 200 )
print(initial_index)

end_index = len(ez_data_cen) - 2*( 1 +int(round(t_xx/dt))) 
print(end_index)

# %%
for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_up[j])
        period_next.append(ez_data_up[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '-------upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '-----振幅誤差')
        index1 = np.where(ez_data_up == period_max)
        print(index1, '--- upper point index1')
        index2 = np.where(ez_data_up == period_next_max)
        print(index2, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' , index1  , '\t' ,  index2 ,'\n\n' )
        print('upper point 到達誤差範圍內的所需 meep time unit' , 31396 / len(ez_data_up) * 500 , '\n')
        print('------------------------------------------------------')
        break


for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_cen[j])
        period_next.append(ez_data_cen[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- upper point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '-------upper point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '-----振幅誤差')
        index1 = np.where(ez_data_cen == period_max)
        print(index1, '--- upper point index1')
        index2 = np.where(ez_data_cen == period_next_max)
        print(index2, '--- upper point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' , index1  , '\t' ,  index2 ,'\n\n' )
        print('center point 到達誤差範圍內的所需 meep time unit' , 43326 / len(ez_data_cen) * 500 , '\n')
        print('-----------------------------------------------------')
        break
        

for i in range( initial_index , end_index , 1 + int(round(t_xx/dt)) ) :
    period = []
    period_next = []
    for j in range( i , i + 41 ) :
        period.append(ez_data_down[j])
        period_next.append(ez_data_down[j + (1 + round(t_xx/dt))])
    period_max = max(period)
    period_next_max = max(period_next)
    if (np.abs(period_max - period_next_max) < 10**(-6)) :
        print(period_max, '-------- down point one period 內最大振福')
        #print(period, '\n')
        print(period_next_max , '-------down point one next_period 內最大振福')
        #print(period_next, '\n')
        print(period_max - period_next_max , '-----振幅誤差')
        index1 = np.where(ez_data_down == period_max)
        print(index1, '--- down point index1')
        index2 = np.where(ez_data_down == period_next_max)
        print(index2, '--- down point index2')
        print(period_max ,'\t' , period_next_max , '\t' , period_max - period_next_max , '\t' , index1  , '\t' ,  index2 ,'\n\n' )
        print('down point 到達誤差範圍內的所需 meep time unit' , 38944 / len(ez_data_down) * 500 , '\n')
        print('---------------------------------------------------')
        print((period_max + period_next_max)/2,'\t Average')
        break



dt_ = str(dt)

# %%
plt.figure(dpi = 150)
plt.title('Upper point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_up[i] , 'b.')

# %%
plt.figure(dpi = 150)
plt.title('center point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_cen[73320]
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_cen[i] , 'b.')
    if max_value < ez_data_cen[i] :
        max_value = ez_data_cen[i]

print(max_value)

# %%
plt.figure(dpi = 150)
plt.title('downnerr point')
plt.xlabel('time point (dt = )')
plt.ylabel('E - amplitude')
max_value = ez_data_down[73320]
for i in range(73320 , 73397) : #len(ez_data_list)) :       
    plt.plot(i , ez_data_down[i] , 'b.')
    if max_value < ez_data_down[i] :
        max_value = ez_data_down[i]

print(max_value)

# %%
ez_data_1period_up = []
ez_data_1period_cen = []
ez_data_1period_down = []

for i in range(len(ez_data_up) - int(t_xx/dt)-4 , len(ez_data_up)):
    ez_data_1period_up.append(ez_data_up[i])
#print(ez_data_1period)

ez_data_1period_up_ = []
for i in range(len(ez_data_1period_up)):
    ez_data_1period_up_.append(ez_data_1period_up[i])
    plt.plot(i,ez_data_1period_up_[i],'b.')
###
for i in range(len(ez_data_cen) - int(t_xx/dt)-4 , len(ez_data_cen)):
    ez_data_1period_cen.append(ez_data_cen[i])
#print(ez_data_1period)

ez_data_1period_cen_ = []
for i in range(len(ez_data_1period_cen)):
    ez_data_1period_cen_.append(ez_data_1period_cen[i])
    plt.plot(i,ez_data_1period_cen_[i],'b.')
###
for i in range(len(ez_data_down) - int(t_xx/dt)-4 , len(ez_data_down)):
    ez_data_1period_down.append(ez_data_down[i])
#print(ez_data_1period)

ez_data_1period_down_ = []
for i in range(len(ez_data_1period_down)):
    ez_data_1period_down_.append(ez_data_1period_down[i])
    plt.plot(i,ez_data_1period_down_[i],'b.')
    
###
ma_x = max(ez_data_1period_)
mi_n = min(ez_data_1period_)
print((ma_x - mi_n)/2.0)

# %%
# 儲存擷取的電場振福數值
extracted_amplitudes = []

for j in range(int(sy / 0.002)):
    y_obs = y_obs_start + (j * 0.002)
    # 計算觀測點在陣列中的索引位置
    x_index = int(round(x_obs * resolution))
    y_index = int(round(y_obs * resolution))
    
    # 檢查索引是否在範圍內
    if 0 <= x_index < len(ez_data_list) and 0 <= y_index < len(ez_data_list[0]):
        # 取得振幅資訊
        extracted_amplitudes.append(np.abs(ez_data_list[x_index][y_index]))
    else:
        extracted_amplitudes.append(0)  # 或者使用其他值來代表無效的索引

# 將擷取的電場振福數值作圖
plt.figure()
plt.plot(np.arange(len(extracted_amplitudes)), extracted_amplitudes)
plt.xlabel('Sample Points')
plt.ylabel('Electric Field Amplitude')
plt.title('Electric Field Amplitude Along y-direction')
plt.show()

# %%
# 儲存振福資訊的列表，定義為擁有 10 列的空二維陣列
ez_amplitude_list = [[] for _ in range(int(round(t/dt)))]

# 計算觀測點的相對座標
x_obs = -0.5 * sx + dpml + dsub + gh + 0.002
y_obs_start = -0.5 * sy

for i in range(0, int(round(t / dt))):
    amplitude = []
    for j in range(int(sy / 0.002)):
        y_obs = y_obs_start + (j * 0.002)
        # 計算觀測點在陣列中的索引位置
        x_index = int(round(x_obs * sim.resolution))
        y_index = int(round(y_obs * sim.resolution))
        
        # 取得振幅資訊
        amplitude.append(np.abs(ez_data_list[x_index][y_index]))
        
        # 將振幅資訊加入到對應時間步長的列表中
        ez_amplitude_list[i].append(amplitude)
    
for i in range(0, int(round(t / dt))):
    print(ez_amplitude_list[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 17
#      14 y_index = int(round(y_obs * sim.resolution))
#      16 # 取得振幅資訊
# ---> 17 amplitude.append(np.abs(ez_data_list[x_index][y_index]))
#      19 # 將振幅資訊加入到對應時間步長的列表中
#      20 ez_amplitude_list[i].append(amplitude)
#
# IndexError: list index out of range

# %%
# 這裡的 Code 單個觀測點 電場E - 時間t 的點狀圖

# 儲存振福資訊的列表，定義為擁有 10 列的空二維陣列
ez_amplitude_list = [[] for _ in range(int(round(t/dt)))]

# 計算觀測點的相對座標
x_obs = -0.5 * sx + dpml + dsub + gh + 0.002
y_obs_start = -0.5 * sy #+ gp/2
#y_obs = y_obs_start


for i in range(0,int(round(t / dt))):
    amplitude = []
    for j in range(int(sy / 0.002)):
        y_obs = y_obs_start + (j * 0.002)
        # 計算觀測點在陣列中的索引位置
        x_index = int(round(x_obs * sim.resolution))
        y_index = int(round(y_obs * sim.resolution))
        print(x_index,y_index)
        # 取得振幅資訊
        amplitude.append(np.abs(ez_data_list[x_index][y_index]))
        # 將振幅資訊加入到對應時間步長的列表中
        ez_amplitude_list[i].append(amplitude)

    
for i in range(0, int(round(t / dt))):
    print(ez_amplitude_list[i])
# Out:
# 26 -150
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 21
#      19 print(x_index,y_index)
#      20 # 取得振幅資訊
# ---> 21 amplitude.append(np.abs(ez_data_list[x_index][y_index]))
#      22 # 將振幅資訊加入到對應時間步長的列表中
#      23 ez_amplitude_list[i].append(amplitude)
#
# IndexError: list index out of range

# %%
# 儲存場量數值的列表，定義為擁有 10 列的空二維陣列


# 遍歷每個時間步長，並檢查是否在指定的時間範圍內
t = time_start
for i in range(0 , int((time_end - time_start) / dt)):
    print(t)
    sim.run(until=t)
    # 取得 Ez 場量數值，並加入到對應的列表中
    ez_data_list[i].append(np.array(sim.get_array(component=mp.Ez, cmplx=True)))
    t = t + dt

# 將每一個列表轉換為 NumPy 數組
'''for i in range(0,int((time_end - time_start) / dt)):
    ez_data_list[i] = np.array(ez_data_list[i])
'''
plt.figure(dpi = 100)
sim.plot2D(fields=mp.Ez)
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# 10
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000178099 s
# Working in 2D dimensions.
# Computational cell is 3.8 x 0.6 x 0 with resolution 500
#      block, center = (-0.61,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
# time for set_epsilon = 0.508456 s
# -----------
# Meep progress: 1.187/10.0 = 11.9% done in 4.0s, 29.7s to go
# on time step 1187 (time=1.187), 0.00337106 s/step
# Meep progress: 2.406/10.0 = 24.1% done in 8.0s, 25.3s to go
# on time step 2407 (time=2.407), 0.00328095 s/step
# Meep progress: 3.569/10.0 = 35.7% done in 12.0s, 21.6s to go
# on time step 3570 (time=3.57), 0.00343974 s/step
# Meep progress: 4.805/10.0 = 48.0% done in 16.0s, 17.3s to go
# on time step 4806 (time=4.806), 0.00323697 s/step
# Meep progress: 6.049/10.0 = 60.5% done in 20.0s, 13.1s to go
# on time step 6051 (time=6.051), 0.00321526 s/step
# Meep progress: 7.261/10.0 = 72.6% done in 24.0s, 9.1s to go
# on time step 7264 (time=7.264), 0.00329893 s/step
# Meep progress: 8.483/10.0 = 84.8% done in 28.0s, 5.0s to go
# on time step 8497 (time=8.497), 0.00324467 s/step
# Meep progress: 9.715/10.0 = 97.1% done in 32.0s, 0.9s to go
# on time step 9731 (time=9.731), 0.00324239 s/step
# run 0 finished at t = 10.0 (10000 timesteps)
# 10.0133
# on time step 10935 (time=10.935), 0.00332364 s/step
# Meep progress: 1.2070000000000007/20.0133 = 6.0% done in 4.0s, 62.3s to go
# on time step 12135 (time=12.135), 0.0033358 s/step
# Meep progress: 2.405000000000001/20.0133 = 12.0% done in 8.0s, 58.6s to go
# on time step 13361 (time=13.361), 0.00326505 s/step
# Meep progress: 3.630000000000001/20.0133 = 18.1% done in 12.0s, 54.2s to go
# on time step 14593 (time=14.593), 0.00324886 s/step
# Meep progress: 4.878/20.0133 = 24.4% done in 16.0s, 49.7s to go
# on time step 15845 (time=15.845), 0.00319498 s/step
# Meep progress: 6.123000000000001/20.0133 = 30.6% done in 20.0s, 45.4s to go
# on time step 17061 (time=17.061), 0.0032911 s/step
# Meep progress: 7.34/20.0133 = 36.7% done in 24.0s, 41.5s to go
# on time step 18324 (time=18.324), 0.00316898 s/step
# Meep progress: 8.586000000000002/20.0133 = 42.9% done in 28.0s, 37.3s to go
# on time step 19566 (time=19.566), 0.00322169 s/step
# Meep progress: 9.841999999999999/20.0133 = 49.2% done in 32.0s, 33.1s to go
# run 1 finished at t = 20.014 (20014 timesteps)
# 10.026599999999998
# on time step 20836 (time=20.836), 0.00315152 s/step
# Meep progress: 1.2760000610351554/30.040599938964842 = 4.2% done in 4.0s, 90.2s to go
# on time step 22103 (time=22.103), 0.00315884 s/step
# Meep progress: 2.5300000610351567/30.040599938964842 = 8.4% done in 8.0s, 87.0s to go
# on time step 23359 (time=23.359), 0.00318598 s/step
# Meep progress: 3.8010000610351575/30.040599938964842 = 12.7% done in 12.0s, 82.9s to go
# on time step 24624 (time=24.624), 0.00316278 s/step
# Meep progress: 5.066000061035158/30.040599938964842 = 16.9% done in 16.0s, 78.9s to go
# on time step 25888 (time=25.888), 0.00316591 s/step
# Meep progress: 6.338000061035157/30.040599938964842 = 21.1% done in 20.0s, 74.8s to go
# on time step 27138 (time=27.138), 0.00320017 s/step
# Meep progress: 7.572000061035158/30.040599938964842 = 25.2% done in 24.0s, 71.2s to go
# on time step 28379 (time=28.379), 0.0032252 s/step
# Meep progress: 8.806000061035157/30.040599938964842 = 29.3% done in 28.0s, 67.5s to go
# on time step 29605 (time=29.605), 0.00326374 s/step
# Meep progress: 10.019000061035158/30.040599938964842 = 33.4% done in 32.0s, 64.0s to go
# run 2 finished at t = 30.041 (30041 timesteps)
# 10.039899999999998
# on time step 30819 (time=30.819), 0.00329519 s/step
# Meep progress: 1.2319996337890622/40.08090036621093 = 3.1% done in 4.0s, 126.1s to go
# on time step 32041 (time=32.041), 0.00327408 s/step
# Meep progress: 2.4489996337890645/40.08090036621093 = 6.1% done in 8.0s, 123.0s to go
# on time step 33249 (time=33.249), 0.00331225 s/step
# Meep progress: 3.653999633789063/40.08090036621093 = 9.1% done in 12.0s, 119.7s to go
# on time step 34464 (time=34.464), 0.00329402 s/step
# Meep progress: 4.896999633789065/40.08090036621093 = 12.2% done in 16.0s, 115.0s to go
# on time step 35727 (time=35.727), 0.00316953 s/step
# Meep progress: 6.13699963378906/40.08090036621093 = 15.3% done in 20.0s, 110.6s to go
# on time step 36954 (time=36.954), 0.00326051 s/step
# Meep progress: 7.351999633789063/40.08090036621093 = 18.3% done in 24.0s, 106.9s to go
# on time step 38160 (time=38.16), 0.00331687 s/step
# Meep progress: 8.562999633789062/40.08090036621093 = 21.4% done in 28.0s, 103.1s to go
# on time step 39389 (time=39.389), 0.0032574 s/step
# Meep progress: 9.787999633789063/40.08090036621093 = 24.4% done in 32.0s, 99.1s to go
# run 3 finished at t = 40.081 (40081 timesteps)
# 10.053199999999997
# on time step 40601 (time=40.601), 0.00330096 s/step
# Meep progress: 1.2179987182617182/50.13420128173828 = 2.4% done in 4.0s, 160.7s to go
# on time step 41829 (time=41.829), 0.0032592 s/step
# Meep progress: 2.45199871826172/50.13420128173828 = 4.9% done in 8.0s, 155.6s to go
# on time step 43045 (time=43.045), 0.00329174 s/step
# Meep progress: 3.6599987182617184/50.13420128173828 = 7.3% done in 12.0s, 152.4s to go
# on time step 44256 (time=44.256), 0.00330369 s/step
# Meep progress: 4.876998718261717/50.13420128173828 = 9.7% done in 16.0s, 148.5s to go
# on time step 45420 (time=45.42), 0.00343654 s/step
# Meep progress: 6.020998718261723/50.13420128173828 = 12.0% done in 20.0s, 146.6s to go
# on time step 46634 (time=46.634), 0.00329595 s/step
# Meep progress: 7.280998718261721/50.13420128173828 = 14.5% done in 24.0s, 141.3s to go
# on time step 47917 (time=47.917), 0.00311994 s/step
# Meep progress: 8.55899871826172/50.13420128173828 = 17.1% done in 28.0s, 136.1s to go
# on time step 49186 (time=49.186), 0.00315233 s/step
# Meep progress: 9.837998718261723/50.13420128173828 = 19.6% done in 32.0s, 131.1s to go
# run 4 finished at t = 50.135 (50135 timesteps)
# 10.066499999999996
# on time step 50457 (time=50.457), 0.00314952 s/step
# Meep progress: 1.270001678466798/60.2014983215332 = 2.1% done in 4.0s, 185.6s to go
# on time step 51731 (time=51.731), 0.00314022 s/step
# Meep progress: 2.5660016784667974/60.2014983215332 = 4.3% done in 8.0s, 179.8s to go
# on time step 53014 (time=53.014), 0.00311804 s/step
# Meep progress: 3.8520016784667988/60.2014983215332 = 6.4% done in 12.0s, 175.6s to go
# on time step 54315 (time=54.315), 0.00307687 s/step
# Meep progress: 5.137001678466795/60.2014983215332 = 8.5% done in 16.0s, 171.6s to go
# on time step 55603 (time=55.603), 0.00310696 s/step
# Meep progress: 6.4240016784668015/60.2014983215332 = 10.7% done in 20.0s, 167.5s to go
# on time step 56890 (time=56.89), 0.00310969 s/step
# Meep progress: 7.713001678466796/60.2014983215332 = 12.8% done in 24.0s, 163.4s to go
# on time step 58179 (time=58.179), 0.00310532 s/step
# Meep progress: 9.011001678466798/60.2014983215332 = 15.0% done in 28.0s, 159.1s to go
# on time step 59474 (time=59.474), 0.00308912 s/step
# run 5 finished at t = 60.202 (60202 timesteps)
# 10.079799999999995
# on time step 60771 (time=60.771), 0.00308415 s/step
# Meep progress: 1.3010003356933595/70.28179966430663 = 1.9% done in 4.0s, 212.2s to go
# on time step 62058 (time=62.058), 0.00310893 s/step
# Meep progress: 2.5740003356933627/70.28179966430663 = 3.7% done in 8.0s, 210.5s to go
# on time step 63334 (time=63.334), 0.00313711 s/step
# Meep progress: 3.8270003356933557/70.28179966430663 = 5.4% done in 12.0s, 208.4s to go
# on time step 64584 (time=64.584), 0.0032025 s/step
# Meep progress: 5.102000335693361/70.28179966430663 = 7.3% done in 16.0s, 204.5s to go
# on time step 65847 (time=65.847), 0.00316877 s/step
# Meep progress: 6.3550003356933615/70.28179966430663 = 9.0% done in 20.0s, 201.3s to go
# on time step 67117 (time=67.117), 0.00315083 s/step
# Meep progress: 7.639000335693368/70.28179966430663 = 10.9% done in 24.0s, 196.9s to go
# on time step 68400 (time=68.4), 0.00311845 s/step
# Meep progress: 8.92000033569336/70.28179966430663 = 12.7% done in 28.0s, 192.7s to go
# on time step 69683 (time=69.683), 0.00311852 s/step
# run 6 finished at t = 70.282 (70282 timesteps)
# 10.093099999999994
# on time step 70947 (time=70.947), 0.00316589 s/step
# Meep progress: 1.2470023193359339/80.37509768066406 = 1.6% done in 4.0s, 253.8s to go
# on time step 72216 (time=72.216), 0.00315345 s/step
# Meep progress: 2.5290023193359445/80.37509768066406 = 3.1% done in 8.0s, 246.3s to go
# on time step 73492 (time=73.492), 0.0031365 s/step
# Meep progress: 3.7920023193359356/80.37509768066406 = 4.7% done in 12.0s, 242.4s to go
# on time step 74737 (time=74.737), 0.00321518 s/step
# Meep progress: 5.033002319335935/80.37509768066406 = 6.3% done in 16.0s, 239.6s to go
# on time step 75992 (time=75.992), 0.00318917 s/step
# Meep progress: 6.28400231933594/80.37509768066406 = 7.8% done in 20.0s, 235.9s to go
# on time step 77231 (time=77.231), 0.0032294 s/step
# Meep progress: 7.5150023193359345/80.37509768066406 = 9.3% done in 24.0s, 232.7s to go
# on time step 78478 (time=78.478), 0.00320906 s/step
# Meep progress: 8.79000231933594/80.37509768066406 = 10.9% done in 28.0s, 228.1s to go
# on time step 79754 (time=79.754), 0.00313651 s/step
# Meep progress: 10.053002319335945/80.37509768066406 = 12.5% done in 32.0s, 223.9s to go
# run 7 finished at t = 80.376 (80376 timesteps)
# 10.106399999999994
# on time step 81011 (time=81.011), 0.00318295 s/step
# Meep progress: 1.2550005493164065/90.48239945068359 = 1.4% done in 4.0s, 284.6s to go
# on time step 82257 (time=82.257), 0.00321199 s/step
# Meep progress: 2.5040005493164017/90.48239945068359 = 2.8% done in 8.0s, 281.2s to go
# on time step 83526 (time=83.526), 0.0031545 s/step
# Meep progress: 3.7880005493164077/90.48239945068359 = 4.2% done in 12.0s, 274.8s to go
# on time step 84800 (time=84.8), 0.00313998 s/step
# Meep progress: 5.048000549316413/90.48239945068359 = 5.6% done in 16.0s, 271.0s to go
# on time step 86056 (time=86.056), 0.00318653 s/step
# Meep progress: 6.304000549316413/90.48239945068359 = 7.0% done in 20.0s, 267.2s to go
# on time step 87319 (time=87.319), 0.00316754 s/step
# Meep progress: 7.576000549316404/90.48239945068359 = 8.4% done in 24.0s, 262.8s to go
# on time step 88586 (time=88.586), 0.00315779 s/step
# Meep progress: 8.843000549316415/90.48239945068359 = 9.8% done in 28.0s, 258.6s to go
# on time step 89860 (time=89.86), 0.00314086 s/step
# run 8 finished at t = 90.483 (90483 timesteps)
# 10.119699999999993
# on time step 91129 (time=91.129), 0.00315296 s/step
# Meep progress: 1.2849982910156257/100.60270170898437 = 1.3% done in 4.0s, 309.3s to go
# on time step 92418 (time=92.418), 0.00310531 s/step
# Meep progress: 2.563998291015622/100.60270170898437 = 2.5% done in 8.0s, 306.1s to go
# on time step 93701 (time=93.701), 0.00311806 s/step
# Meep progress: 3.8659982910156288/100.60270170898437 = 3.8% done in 12.0s, 300.4s to go
# on time step 94993 (time=94.993), 0.00309721 s/step
# Meep progress: 5.14099829101562/100.60270170898437 = 5.1% done in 16.0s, 297.2s to go
# on time step 96262 (time=96.262), 0.00315328 s/step
# Meep progress: 6.4239982910156215/100.60270170898437 = 6.4% done in 20.0s, 293.3s to go
# on time step 97551 (time=97.551), 0.00310398 s/step
# Meep progress: 7.693998291015632/100.60270170898437 = 7.6% done in 24.0s, 289.9s to go
# on time step 98836 (time=98.836), 0.00311407 s/step
# Meep progress: 8.977998291015624/100.60270170898437 = 8.9% done in 28.0s, 285.8s to go
# on time step 100107 (time=100.107), 0.00314868 s/step
# run 9 finished at t = 100.60300000000001 (100603 timesteps)
# 10.132999999999992
# on time step 101384 (time=101.384), 0.00313358 s/step
# Meep progress: 1.2780031738281252/110.73599682617187 = 1.2% done in 4.0s, 342.7s to go
# on time step 102633 (time=102.633), 0.00320488 s/step
# Meep progress: 2.5100031738281245/110.73599682617187 = 2.3% done in 8.0s, 345.0s to go
# on time step 103883 (time=103.883), 0.00320134 s/step
# Meep progress: 3.7710031738281202/110.73599682617187 = 3.4% done in 12.0s, 340.5s to go
# on time step 105131 (time=105.131), 0.00320568 s/step
# Meep progress: 5.01800317382812/110.73599682617187 = 4.5% done in 16.0s, 337.2s to go
# on time step 106391 (time=106.391), 0.003177 s/step
# Meep progress: 6.28500317382813/110.73599682617187 = 5.7% done in 20.0s, 332.5s to go
# on time step 107638 (time=107.638), 0.0032094 s/step
# Meep progress: 7.528003173828125/110.73599682617187 = 6.8% done in 24.0s, 329.1s to go
# on time step 108899 (time=108.899), 0.00317408 s/step
# Meep progress: 8.77600317382813/110.73599682617187 = 7.9% done in 28.0s, 325.4s to go
# on time step 110148 (time=110.148), 0.003205 s/step
# Meep progress: 10.031003173828125/110.73599682617187 = 9.1% done in 32.0s, 321.4s to go
# run 10 finished at t = 110.736 (110736 timesteps)
# 10.146299999999991
# on time step 111387 (time=111.387), 0.00323083 s/step
# Meep progress: 1.2479999389648526/120.88230006103515 = 1.0% done in 4.0s, 383.7s to go
# on time step 112637 (time=112.637), 0.00320014 s/step
# Meep progress: 2.4979999389648526/120.88230006103515 = 2.1% done in 8.0s, 379.3s to go
# on time step 113889 (time=113.889), 0.00319623 s/step
# Meep progress: 3.7449999389648525/120.88230006103515 = 3.1% done in 12.0s, 375.6s to go
# on time step 115134 (time=115.134), 0.00321506 s/step
# Meep progress: 4.985999938964852/120.88230006103515 = 4.1% done in 16.0s, 372.1s to go
# on time step 116393 (time=116.393), 0.00317837 s/step
# Meep progress: 6.247999938964853/120.88230006103515 = 5.2% done in 20.0s, 367.1s to go
# on time step 117643 (time=117.643), 0.00320079 s/step
# Meep progress: 7.505999938964848/120.88230006103515 = 6.2% done in 24.0s, 362.7s to go
# on time step 118907 (time=118.907), 0.00316549 s/step
# Meep progress: 8.766999938964844/120.88230006103515 = 7.3% done in 28.0s, 358.2s to go
# on time step 120164 (time=120.164), 0.00318302 s/step
# Meep progress: 10.02499993896484/120.88230006103515 = 8.3% done in 32.0s, 354.0s to go
# run 11 finished at t = 120.883 (120883 timesteps)
# 10.15959999999999
# on time step 121422 (time=121.422), 0.00318071 s/step
# Meep progress: 1.278996765136725/131.04260323486326 = 1.0% done in 4.0s, 405.9s to go
# on time step 122700 (time=122.7), 0.00312998 s/step
# Meep progress: 2.5609967651367214/131.04260323486326 = 2.0% done in 8.0s, 401.5s to go
# on time step 123986 (time=123.986), 0.00311247 s/step
# Meep progress: 3.849996765136723/131.04260323486326 = 2.9% done in 12.0s, 396.7s to go
# on time step 125275 (time=125.275), 0.0031033 s/step
# Meep progress: 5.131996765136719/131.04260323486326 = 3.9% done in 16.0s, 392.7s to go
# on time step 126548 (time=126.548), 0.00314312 s/step
# Meep progress: 6.412996765136725/131.04260323486326 = 4.9% done in 20.0s, 388.9s to go
# on time step 127837 (time=127.837), 0.00310589 s/step
# Meep progress: 7.690996765136731/131.04260323486326 = 5.9% done in 24.0s, 385.1s to go
# on time step 129113 (time=129.113), 0.00313541 s/step
# Meep progress: 8.985996765136719/131.04260323486326 = 6.9% done in 28.0s, 380.5s to go
# on time step 130401 (time=130.401), 0.0031056 s/step
# run 12 finished at t = 131.043 (131043 timesteps)
# 10.17289999999999
# on time step 131692 (time=131.692), 0.0030997 s/step
# Meep progress: 1.2960007324218736/141.21589926757812 = 0.9% done in 4.0s, 432.1s to go
# on time step 132987 (time=132.987), 0.00308949 s/step
# Meep progress: 2.58900073242188/141.21589926757812 = 1.8% done in 8.0s, 428.5s to go
# on time step 134278 (time=134.278), 0.00309897 s/step
# Meep progress: 3.877000732421891/141.21589926757812 = 2.7% done in 12.0s, 425.2s to go
# on time step 135568 (time=135.568), 0.00310268 s/step
# Meep progress: 5.158000732421868/141.21589926757812 = 3.7% done in 16.0s, 422.2s to go
# on time step 136803 (time=136.803), 0.00324104 s/step
# Meep progress: 6.379000732421872/141.21589926757812 = 4.5% done in 20.0s, 422.9s to go
# on time step 138056 (time=138.056), 0.00319295 s/step
# Meep progress: 7.646000732421868/141.21589926757812 = 5.4% done in 24.0s, 419.4s to go
# on time step 139315 (time=139.315), 0.00317856 s/step
# Meep progress: 8.885000732421872/141.21589926757812 = 6.3% done in 28.0s, 417.1s to go
# on time step 140557 (time=140.557), 0.00322191 s/step
# Meep progress: 10.148000732421878/141.21589926757812 = 7.2% done in 32.0s, 413.4s to go
# run 13 finished at t = 141.216 (141216 timesteps)
# 10.186199999999989
# on time step 141813 (time=141.813), 0.00318569 s/step
# Meep progress: 1.2569965820312632/151.40220341796874 = 0.8% done in 4.0s, 478.0s to go
# on time step 143069 (time=143.069), 0.00318681 s/step
# Meep progress: 2.5189965820312636/151.40220341796874 = 1.7% done in 8.0s, 473.2s to go
# on time step 144355 (time=144.355), 0.00311227 s/step
# Meep progress: 3.8039965820312602/151.40220341796874 = 2.5% done in 12.0s, 465.8s to go
# on time step 145612 (time=145.612), 0.00318423 s/step
# Meep progress: 5.04799658203126/151.40220341796874 = 3.3% done in 16.0s, 464.2s to go
# on time step 146864 (time=146.864), 0.00319617 s/step
# Meep progress: 6.312996582031246/151.40220341796874 = 4.2% done in 20.0s, 459.9s to go
# on time step 148129 (time=148.129), 0.00316369 s/step
# Meep progress: 7.575996582031252/151.40220341796874 = 5.0% done in 24.0s, 455.8s to go
# on time step 149393 (time=149.393), 0.00316669 s/step
# Meep progress: 8.821996582031261/151.40220341796874 = 5.8% done in 28.0s, 452.8s to go
# on time step 150637 (time=150.637), 0.00321671 s/step
# Meep progress: 10.066996582031265/151.40220341796874 = 6.6% done in 32.0s, 449.5s to go
# run 14 finished at t = 151.403 (151403 timesteps)
# 10.199499999999988
# on time step 151843 (time=151.843), 0.00331815 s/step
# Meep progress: 1.2130001220703264/161.6024998779297 = 0.8% done in 4.0s, 529.1s to go
# on time step 153071 (time=153.071), 0.00325909 s/step
# Meep progress: 2.4000001220703098/161.6024998779297 = 1.5% done in 8.0s, 530.9s to go
# on time step 154245 (time=154.245), 0.00340917 s/step
# Meep progress: 3.6170001220703227/161.6024998779297 = 2.2% done in 12.0s, 524.4s to go
# on time step 155484 (time=155.484), 0.00322934 s/step
# Meep progress: 4.842000122070317/161.6024998779297 = 3.0% done in 16.0s, 518.2s to go
# on time step 156696 (time=156.696), 0.00330038 s/step
# Meep progress: 6.03900012207032/161.6024998779297 = 3.7% done in 20.0s, 515.4s to go
# on time step 157798 (time=157.798), 0.00363162 s/step
# Meep progress: 7.153000122070324/161.6024998779297 = 4.4% done in 24.0s, 518.4s to go
# on time step 159010 (time=159.01), 0.00330205 s/step
# Meep progress: 8.363000122070304/161.6024998779297 = 5.2% done in 28.0s, 513.3s to go
# on time step 160218 (time=160.218), 0.00331265 s/step
# Meep progress: 9.476000122070303/161.6024998779297 = 5.9% done in 32.0s, 513.9s to go
# on time step 161336 (time=161.336), 0.00358036 s/step
# run 15 finished at t = 161.603 (161603 timesteps)
# 10.212799999999987
# on time step 162420 (time=162.42), 0.00369034 s/step
# Meep progress: 1.0330031738281207/171.81579682617186 = 0.6% done in 4.0s, 661.3s to go
# on time step 163415 (time=163.415), 0.00402295 s/step
# Meep progress: 2.036003173828135/171.81579682617186 = 1.2% done in 8.0s, 667.3s to go
# on time step 164426 (time=164.426), 0.00396017 s/step
# Meep progress: 3.067003173828141/171.81579682617186 = 1.8% done in 12.0s, 660.6s to go
# on time step 165505 (time=165.505), 0.00370932 s/step
# Meep progress: 4.136003173828129/171.81579682617186 = 2.4% done in 16.0s, 648.9s to go
# on time step 166572 (time=166.572), 0.00375055 s/step
# Meep progress: 5.209003173828137/171.81579682617186 = 3.0% done in 20.0s, 640.0s to go
# on time step 167643 (time=167.643), 0.00373497 s/step
# Meep progress: 6.28500317382813/171.81579682617186 = 3.7% done in 24.0s, 632.4s to go
# on time step 168741 (time=168.741), 0.00364435 s/step
# Meep progress: 7.379003173828124/171.81579682617186 = 4.3% done in 28.0s, 624.2s to go
# on time step 169839 (time=169.839), 0.00364593 s/step
# Meep progress: 8.480003173828123/171.81579682617186 = 4.9% done in 32.0s, 616.6s to go
# on time step 170938 (time=170.938), 0.00364333 s/step
# Meep progress: 9.568003173828117/171.81579682617186 = 5.6% done in 36.0s, 610.7s to go
# run 16 finished at t = 171.816 (171816 timesteps)
# 10.226099999999986
# on time step 172015 (time=172.015), 0.00371404 s/step
# Meep progress: 1.0970057373046984/182.0420942626953 = 0.6% done in 4.0s, 660.3s to go
# on time step 173112 (time=173.112), 0.00364913 s/step
# Meep progress: 2.195005737304683/182.0420942626953 = 1.2% done in 8.0s, 655.8s to go
# on time step 174211 (time=174.211), 0.003642 s/step
# Meep progress: 3.298005737304692/182.0420942626953 = 1.8% done in 12.0s, 650.8s to go
# on time step 175304 (time=175.304), 0.00366259 s/step
# Meep progress: 4.400005737304696/182.0420942626953 = 2.4% done in 16.0s, 646.3s to go
# on time step 176422 (time=176.422), 0.00357964 s/step
# Meep progress: 5.507005737304695/182.0420942626953 = 3.0% done in 20.0s, 641.4s to go
# on time step 177518 (time=177.518), 0.00365067 s/step
# Meep progress: 6.597005737304698/182.0420942626953 = 3.6% done in 24.0s, 638.5s to go
# on time step 178614 (time=178.614), 0.00365199 s/step
# Meep progress: 7.695005737304683/182.0420942626953 = 4.2% done in 28.0s, 634.6s to go
# on time step 179710 (time=179.71), 0.00365263 s/step
# Meep progress: 8.781005737304696/182.0420942626953 = 4.8% done in 32.0s, 631.7s to go
# on time step 180800 (time=180.8), 0.00367149 s/step
# Meep progress: 9.87900573730468/182.0420942626953 = 5.4% done in 36.0s, 627.6s to go
# on time step 181898 (time=181.898), 0.00364447 s/step
# run 17 finished at t = 182.043 (182043 timesteps)
# 10.239399999999986
# on time step 182986 (time=182.986), 0.00367806 s/step
# Meep progress: 1.0930007324218707/192.2823992675781 = 0.6% done in 4.0s, 700.1s to go
# on time step 184092 (time=184.092), 0.003621 s/step
# Meep progress: 2.193000732421865/192.2823992675781 = 1.1% done in 8.0s, 693.7s to go
# on time step 185090 (time=185.09), 0.0040086 s/step
# Meep progress: 3.176000732421869/192.2823992675781 = 1.7% done in 12.0s, 714.8s to go
# on time step 186040 (time=186.04), 0.00421061 s/step
# Meep progress: 4.133000732421891/192.2823992675781 = 2.1% done in 16.0s, 728.7s to go
# on time step 187120 (time=187.12), 0.00370639 s/step
# Meep progress: 5.218000732421871/192.2823992675781 = 2.7% done in 20.0s, 717.3s to go
# on time step 188243 (time=188.243), 0.00356587 s/step
# Meep progress: 6.324000732421865/192.2823992675781 = 3.3% done in 24.0s, 706.1s to go
# on time step 189336 (time=189.336), 0.00366135 s/step
# Meep progress: 7.45800073242188/192.2823992675781 = 3.9% done in 28.0s, 694.2s to go
# on time step 190558 (time=190.558), 0.00327503 s/step
# Meep progress: 8.672000732421878/192.2823992675781 = 4.5% done in 32.0s, 677.8s to go
# on time step 191709 (time=191.709), 0.0034757 s/step
# Meep progress: 9.803000732421879/192.2823992675781 = 5.1% done in 36.0s, 670.4s to go
# run 18 finished at t = 192.28300000000002 (192283 timesteps)
# 10.252699999999985
# on time step 192853 (time=192.853), 0.00349766 s/step
# Meep progress: 1.2089952392578027/202.53570476074216 = 0.6% done in 4.0s, 666.4s to go
# on time step 194096 (time=194.096), 0.00321961 s/step
# Meep progress: 2.4439952392578164/202.53570476074216 = 1.2% done in 8.0s, 655.1s to go
# on time step 195331 (time=195.331), 0.00323919 s/step
# Meep progress: 3.6929952392578116/202.53570476074216 = 1.8% done in 12.0s, 646.3s to go
# on time step 196577 (time=196.577), 0.00321124 s/step
# Meep progress: 4.745995239257809/202.53570476074216 = 2.3% done in 16.0s, 667.1s to go
# on time step 197477 (time=197.477), 0.00444566 s/step
# Meep progress: 5.677995239257825/202.53570476074216 = 2.8% done in 20.0s, 693.7s to go
# on time step 198435 (time=198.435), 0.00417803 s/step
# Meep progress: 6.634995239257819/202.53570476074216 = 3.3% done in 24.0s, 708.9s to go
# on time step 199388 (time=199.388), 0.00419991 s/step
# Meep progress: 7.603995239257813/202.53570476074216 = 3.8% done in 28.0s, 718.1s to go
# on time step 200359 (time=200.359), 0.00412293 s/step
# Meep progress: 8.568995239257816/202.53570476074216 = 4.2% done in 32.0s, 724.7s to go
# on time step 201355 (time=201.355), 0.00401677 s/step
# Meep progress: 9.631995239257805/202.53570476074216 = 4.8% done in 36.0s, 721.4s to go
# on time step 202435 (time=202.435), 0.0037051 s/step
# run 19 finished at t = 202.536 (202536 timesteps)
# 10.265999999999984
# on time step 203511 (time=203.511), 0.00371754 s/step
# Meep progress: 1.0760045166015573/212.80199548339843 = 0.5% done in 4.0s, 787.2s to go
# on time step 204592 (time=204.592), 0.00370234 s/step
# Meep progress: 2.16200451660157/212.80199548339843 = 1.0% done in 8.0s, 779.7s to go
# on time step 205675 (time=205.675), 0.00369351 s/step
# Meep progress: 3.249004516601559/212.80199548339843 = 1.5% done in 12.0s, 774.3s to go
# on time step 206758 (time=206.758), 0.00369479 s/step
# Meep progress: 4.333004516601562/212.80199548339843 = 2.0% done in 16.0s, 770.2s to go
# on time step 207854 (time=207.854), 0.00365008 s/step
# Meep progress: 5.423004516601566/212.80199548339843 = 2.5% done in 20.0s, 765.2s to go
# on time step 208933 (time=208.933), 0.00370736 s/step
# Meep progress: 6.508004516601574/212.80199548339843 = 3.1% done in 24.0s, 761.1s to go
# on time step 210015 (time=210.015), 0.00369788 s/step
# Meep progress: 7.588004516601558/212.80199548339843 = 3.6% done in 28.0s, 757.6s to go
# on time step 211112 (time=211.112), 0.00364869 s/step
# Meep progress: 8.689004516601557/212.80199548339843 = 4.1% done in 32.0s, 752.0s to go
# on time step 212272 (time=212.272), 0.00344892 s/step
# Meep progress: 9.860004516601578/212.80199548339843 = 4.6% done in 36.0s, 741.3s to go
# run 20 finished at t = 212.802 (212802 timesteps)
# 10.279299999999983
# on time step 213485 (time=213.485), 0.00330034 s/step
# Meep progress: 1.1999980468750095/223.08130195312498 = 0.5% done in 4.0s, 740.2s to go
# on time step 214643 (time=214.643), 0.00345675 s/step
# Meep progress: 2.33699804687501/223.08130195312498 = 1.0% done in 8.0s, 756.0s to go
# on time step 215800 (time=215.8), 0.00346006 s/step
# Meep progress: 3.5219980468750123/223.08130195312498 = 1.6% done in 12.0s, 748.4s to go
# on time step 217012 (time=217.012), 0.00330073 s/step
# Meep progress: 4.744998046874997/223.08130195312498 = 2.1% done in 16.0s, 736.6s to go
# on time step 218250 (time=218.25), 0.00323133 s/step
# Meep progress: 5.968998046875015/223.08130195312498 = 2.7% done in 20.0s, 727.7s to go
# on time step 219481 (time=219.481), 0.00325074 s/step
# Meep progress: 7.2169980468750055/223.08130195312498 = 3.2% done in 24.0s, 718.1s to go
# on time step 220723 (time=220.723), 0.00322145 s/step
# Meep progress: 8.460998046875005/223.08130195312498 = 3.8% done in 28.0s, 710.5s to go
# on time step 221971 (time=221.971), 0.00320734 s/step
# Meep progress: 9.697998046875/223.08130195312498 = 4.3% done in 32.0s, 704.3s to go
# run 21 finished at t = 223.082 (223082 timesteps)
# 10.292599999999982
# on time step 223206 (time=223.206), 0.00324174 s/step
# Meep progress: 1.2009992675781405/233.37460073242187 = 0.5% done in 4.0s, 773.4s to go
# on time step 224402 (time=224.402), 0.00334465 s/step
# Meep progress: 2.4369992675781305/233.37460073242187 = 1.0% done in 8.0s, 758.4s to go
# on time step 225646 (time=225.646), 0.00321557 s/step
# Meep progress: 3.6769992675781396/233.37460073242187 = 1.6% done in 12.0s, 749.9s to go
# on time step 226877 (time=226.877), 0.00325147 s/step
# Meep progress: 4.93899926757814/233.37460073242187 = 2.1% done in 16.0s, 740.3s to go
# on time step 228149 (time=228.149), 0.00314682 s/step
# Meep progress: 6.190999267578121/233.37460073242187 = 2.7% done in 20.0s, 734.3s to go
# on time step 229394 (time=229.394), 0.0032141 s/step
# Meep progress: 7.451999267578117/233.37460073242187 = 3.2% done in 24.0s, 728.0s to go
# on time step 230660 (time=230.66), 0.00316163 s/step
# Meep progress: 8.724999267578141/233.37460073242187 = 3.7% done in 28.0s, 721.3s to go
# on time step 231924 (time=231.924), 0.00316631 s/step
# Meep progress: 9.974999267578141/233.37460073242187 = 4.3% done in 32.0s, 717.1s to go
# on time step 233180 (time=233.18), 0.00318691 s/step
# run 22 finished at t = 233.375 (233375 timesteps)
# 10.305899999999982
# on time step 234415 (time=234.415), 0.00323888 s/step
# Meep progress: 1.2379999999999995/243.68089999999998 = 0.5% done in 4.0s, 783.7s to go
# on time step 235679 (time=235.679), 0.00316547 s/step
# Meep progress: 2.507000000000005/243.68089999999998 = 1.0% done in 8.0s, 770.0s to go
# on time step 236945 (time=236.945), 0.00316017 s/step
# Meep progress: 3.7700000000000102/243.68089999999998 = 1.5% done in 12.0s, 764.0s to go
# on time step 238211 (time=238.211), 0.00316112 s/step
# Meep progress: 5.030000000000001/243.68089999999998 = 2.1% done in 16.0s, 759.4s to go
# on time step 239477 (time=239.477), 0.00315984 s/step
# Meep progress: 6.300000000000011/243.68089999999998 = 2.6% done in 20.0s, 753.9s to go
# on time step 240709 (time=240.709), 0.00324884 s/step
# Meep progress: 7.516999999999996/243.68089999999998 = 3.1% done in 24.0s, 754.4s to go
# on time step 241799 (time=241.799), 0.00367262 s/step
# Meep progress: 8.569999999999993/243.68089999999998 = 3.5% done in 28.0s, 768.5s to go
# on time step 242916 (time=242.916), 0.00358206 s/step
# Meep progress: 9.732/243.68089999999998 = 4.0% done in 32.0s, 769.6s to go
# run 23 finished at t = 243.681 (243681 timesteps)
# 10.31919999999998
# on time step 243982 (time=243.982), 0.0037535 s/step
# Meep progress: 1.1450002441406184/254.00019975585934 = 0.5% done in 4.0s, 883.9s to go
# on time step 245198 (time=245.198), 0.00328975 s/step
# Meep progress: 2.3620002441406314/254.00019975585934 = 0.9% done in 8.0s, 852.7s to go
# on time step 246430 (time=246.43), 0.00324782 s/step
# Meep progress: 3.5870002441406257/254.00019975585934 = 1.4% done in 12.0s, 838.1s to go
# on time step 247668 (time=247.668), 0.00323155 s/step
# Meep progress: 4.835000244140616/254.00019975585934 = 1.9% done in 16.0s, 824.9s to go
# on time step 248914 (time=248.914), 0.00321164 s/step
# Meep progress: 6.073000244140644/254.00019975585934 = 2.4% done in 20.0s, 816.9s to go
# on time step 250144 (time=250.144), 0.00325269 s/step
# Meep progress: 7.303000244140634/254.00019975585934 = 2.9% done in 24.0s, 811.1s to go
# on time step 251381 (time=251.381), 0.00323488 s/step
# Meep progress: 8.54400024414062/254.00019975585934 = 3.4% done in 28.0s, 804.8s to go
# on time step 252631 (time=252.631), 0.00320116 s/step
# Meep progress: 9.782000244140619/254.00019975585934 = 3.9% done in 32.0s, 799.3s to go
# on time step 253850 (time=253.85), 0.00328298 s/step
# run 24 finished at t = 254.001 (254001 timesteps)
# 10.33249999999998
# on time step 255081 (time=255.081), 0.00325081 s/step
# Meep progress: 1.2449929199218843/264.3335070800781 = 0.5% done in 4.0s, 845.7s to go
# on time step 256298 (time=256.298), 0.0032879 s/step
# Meep progress: 2.421992919921877/264.3335070800781 = 0.9% done in 8.0s, 865.5s to go
# on time step 257276 (time=257.276), 0.00409438 s/step
# Meep progress: 3.3999929199218855/264.3335070800781 = 1.3% done in 12.0s, 921.3s to go
# on time step 258348 (time=258.348), 0.00373147 s/step
# Meep progress: 4.4799929199218695/264.3335070800781 = 1.7% done in 16.0s, 928.4s to go
# on time step 259445 (time=259.445), 0.00364723 s/step
# Meep progress: 5.582992919921878/264.3335070800781 = 2.1% done in 20.0s, 927.5s to go
# on time step 260547 (time=260.547), 0.00363051 s/step
# Meep progress: 6.687992919921896/264.3335070800781 = 2.5% done in 24.0s, 925.1s to go
# on time step 261629 (time=261.629), 0.00369912 s/step
# Meep progress: 7.7649929199218946/264.3335070800781 = 2.9% done in 28.0s, 925.7s to go
# on time step 262707 (time=262.707), 0.00371318 s/step
# Meep progress: 8.842992919921869/264.3335070800781 = 3.3% done in 32.0s, 925.1s to go
# on time step 263770 (time=263.77), 0.00376431 s/step
# Meep progress: 9.899992919921885/264.3335070800781 = 3.7% done in 36.0s, 925.8s to go
# run 25 finished at t = 264.334 (264334 timesteps)
# 10.34579999999998
# on time step 264835 (time=264.835), 0.00375801 s/step
# Meep progress: 1.0779851074218527/274.6798148925781 = 0.4% done in 4.0s, 1015.9s to go
# on time step 265910 (time=265.91), 0.00372215 s/step
# Meep progress: 2.1549851074219077/274.6798148925781 = 0.8% done in 8.0s, 1012.1s to go
# on time step 266981 (time=266.981), 0.003736 s/step
# Meep progress: 3.2199851074219055/274.6798148925781 = 1.2% done in 12.0s, 1012.2s to go
# on time step 268046 (time=268.046), 0.00375642 s/step
# Meep progress: 4.28398510742187/274.6798148925781 = 1.6% done in 16.0s, 1010.3s to go
# on time step 269119 (time=269.119), 0.00372829 s/step
# Meep progress: 5.353985107421863/274.6798148925781 = 1.9% done in 20.0s, 1006.7s to go
# on time step 270187 (time=270.187), 0.00374637 s/step
# Meep progress: 6.437985107421866/274.6798148925781 = 2.3% done in 24.0s, 1000.5s to go
# on time step 271285 (time=271.285), 0.0036452 s/step
# Meep progress: 7.536985107421856/274.6798148925781 = 2.7% done in 28.0s, 993.0s to go
# on time step 272379 (time=272.379), 0.00365836 s/step
# Meep progress: 8.634985107421869/274.6798148925781 = 3.1% done in 32.0s, 986.4s to go
# on time step 273465 (time=273.465), 0.0036841 s/step
# Meep progress: 9.702985107421853/274.6798148925781 = 3.5% done in 36.0s, 983.7s to go
# on time step 274552 (time=274.552), 0.00368216 s/step
# run 26 finished at t = 274.68 (274680 timesteps)
# 10.359099999999978
# on time step 275637 (time=275.637), 0.00369017 s/step
# Meep progress: 1.0920073242187414/285.0390926757812 = 0.4% done in 4.0s, 1040.9s to go
# on time step 276719 (time=276.719), 0.00369928 s/step
# Meep progress: 2.168007324218763/285.0390926757812 = 0.8% done in 8.0s, 1044.6s to go
# on time step 277800 (time=277.8), 0.00370186 s/step
# Meep progress: 3.251007324218733/285.0390926757812 = 1.1% done in 12.0s, 1040.9s to go
# on time step 278891 (time=278.891), 0.00366877 s/step
# Meep progress: 4.344007324218751/285.0390926757812 = 1.5% done in 16.0s, 1034.6s to go
# on time step 279963 (time=279.963), 0.00373146 s/step
# Meep progress: 5.408007324218772/285.0390926757812 = 1.9% done in 20.0s, 1034.8s to go
# on time step 281043 (time=281.043), 0.00370374 s/step
# Meep progress: 6.4920073242187755/285.0390926757812 = 2.3% done in 24.0s, 1030.4s to go
# on time step 282129 (time=282.129), 0.00368433 s/step
# Meep progress: 7.5790073242187646/285.0390926757812 = 2.7% done in 28.0s, 1025.6s to go
# on time step 283210 (time=283.21), 0.00370244 s/step
# Meep progress: 8.654007324218753/285.0390926757812 = 3.0% done in 32.0s, 1022.5s to go
# on time step 284285 (time=284.285), 0.00372256 s/step
# Meep progress: 9.733007324218761/285.0390926757812 = 3.4% done in 36.0s, 1018.9s to go
# run 27 finished at t = 285.04 (285040 timesteps)
# 10.372399999999978
# on time step 285362 (time=285.362), 0.00371457 s/step
# Meep progress: 1.0829914550781155/295.41240854492185 = 0.4% done in 4.0s, 1087.6s to go
# on time step 286446 (time=286.446), 0.00369209 s/step
# Meep progress: 2.168991455078128/295.41240854492185 = 0.7% done in 8.0s, 1082.0s to go
# on time step 287532 (time=287.532), 0.003684 s/step
# Meep progress: 3.2559914550781173/295.41240854492185 = 1.1% done in 12.0s, 1077.2s to go
# on time step 288646 (time=288.646), 0.00359145 s/step
# Meep progress: 4.3019914550781095/295.41240854492185 = 1.5% done in 16.0s, 1083.1s to go
# on time step 289653 (time=289.653), 0.00397391 s/step
# Meep progress: 5.36999145507815/295.41240854492185 = 1.8% done in 20.0s, 1080.6s to go
# on time step 290701 (time=290.701), 0.00382194 s/step
# Meep progress: 6.420991455078138/295.41240854492185 = 2.2% done in 24.0s, 1080.6s to go
# on time step 291788 (time=291.788), 0.00368167 s/step
# Meep progress: 7.498991455078112/295.41240854492185 = 2.5% done in 28.0s, 1075.4s to go
# on time step 292851 (time=292.851), 0.00376313 s/step
# Meep progress: 8.490991455078131/295.41240854492185 = 2.9% done in 32.0s, 1081.7s to go
# on time step 293849 (time=293.849), 0.00400809 s/step
# Meep progress: 9.474991455078111/295.41240854492185 = 3.2% done in 36.0s, 1086.8s to go
# on time step 294840 (time=294.84), 0.00403878 s/step
# run 28 finished at t = 295.413 (295413 timesteps)
# 10.385699999999977
# on time step 295899 (time=295.899), 0.00378144 s/step
# Meep progress: 1.014005615234396/305.7986943847656 = 0.3% done in 4.0s, 1203.4s to go
# on time step 296909 (time=296.909), 0.0039604 s/step
# Meep progress: 2.077005615234384/305.7986943847656 = 0.7% done in 8.0s, 1170.8s to go
# on time step 298065 (time=298.065), 0.0034603 s/step
# Meep progress: 3.33000561523437/305.7986943847656 = 1.1% done in 12.0s, 1090.8s to go
# on time step 299310 (time=299.31), 0.00321365 s/step
# Meep progress: 4.5780056152343604/305.7986943847656 = 1.5% done in 16.0s, 1053.4s to go
# on time step 300556 (time=300.556), 0.00321111 s/step
# Meep progress: 5.823005615234365/305.7986943847656 = 1.9% done in 20.0s, 1030.9s to go
# on time step 301800 (time=301.8), 0.00321725 s/step
# Meep progress: 7.062005615234398/305.7986943847656 = 2.3% done in 24.0s, 1015.8s to go
# on time step 303055 (time=303.055), 0.00318749 s/step
# Meep progress: 8.327005615234384/305.7986943847656 = 2.7% done in 28.0s, 1000.9s to go
# on time step 304307 (time=304.307), 0.00319666 s/step
# Meep progress: 9.507005615234391/305.7986943847656 = 3.1% done in 32.0s, 997.9s to go
# on time step 305359 (time=305.359), 0.003804 s/step
# run 29 finished at t = 305.799 (305799 timesteps)
# 10.398999999999976
# on time step 306357 (time=306.357), 0.00401165 s/step
# Meep progress: 0.9949887695312327/316.19801123046875 = 0.3% done in 4.0s, 1267.5s to go
# on time step 307427 (time=307.427), 0.00373846 s/step
# Meep progress: 2.0979887695312414/316.19801123046875 = 0.7% done in 8.0s, 1198.1s to go
# on time step 308529 (time=308.529), 0.00363029 s/step
# Meep progress: 3.204988769531269/316.19801123046875 = 1.0% done in 12.0s, 1172.4s to go
# on time step 309639 (time=309.639), 0.00360664 s/step
# Meep progress: 4.280988769531234/316.19801123046875 = 1.4% done in 16.0s, 1166.5s to go
# on time step 310680 (time=310.68), 0.00384478 s/step
# Meep progress: 5.319988769531278/316.19801123046875 = 1.7% done in 20.0s, 1169.7s to go
# on time step 311721 (time=311.721), 0.00384414 s/step
# Meep progress: 6.3659887695312705/316.19801123046875 = 2.0% done in 24.0s, 1169.0s to go
# on time step 312754 (time=312.754), 0.00387437 s/step
# Meep progress: 7.3729887695312755/316.19801123046875 = 2.3% done in 28.0s, 1173.7s to go
# on time step 313746 (time=313.746), 0.00403339 s/step
# Meep progress: 8.363988769531261/316.19801123046875 = 2.6% done in 32.0s, 1178.5s to go
# on time step 314740 (time=314.74), 0.00402767 s/step
# Meep progress: 9.360988769531275/316.19801123046875 = 3.0% done in 36.0s, 1180.8s to go
# on time step 315753 (time=315.753), 0.00395057 s/step
# Meep progress: 10.371988769531242/316.19801123046875 = 3.3% done in 40.0s, 1180.1s to go
# run 30 finished at t = 316.199 (316199 timesteps)
# 10.412299999999975
# on time step 316752 (time=316.752), 0.00400579 s/step
# Meep progress: 1.0699948730468805/326.6113051269531 = 0.3% done in 4.0s, 1217.3s to go
# on time step 317792 (time=317.792), 0.00384723 s/step
# Meep progress: 2.0399948730469077/326.6113051269531 = 0.6% done in 8.0s, 1273.8s to go
# on time step 318765 (time=318.765), 0.00411599 s/step
# Meep progress: 3.0529948730468845/326.6113051269531 = 0.9% done in 12.0s, 1272.7s to go
# on time step 319868 (time=319.868), 0.00362766 s/step
# Meep progress: 4.237994873046887/326.6113051269531 = 1.3% done in 16.0s, 1217.8s to go
# on time step 321098 (time=321.098), 0.00325238 s/step
# Meep progress: 5.4419948730468946/326.6113051269531 = 1.7% done in 20.0s, 1181.1s to go
# on time step 322319 (time=322.319), 0.00327834 s/step
# Meep progress: 6.692994873046871/326.6113051269531 = 2.0% done in 24.0s, 1147.8s to go
# on time step 323536 (time=323.536), 0.00328766 s/step
# Meep progress: 7.9099948730468554/326.6113051269531 = 2.4% done in 28.0s, 1128.8s to go
# on time step 324755 (time=324.755), 0.00328414 s/step
# Meep progress: 9.113994873046863/326.6113051269531 = 2.8% done in 32.0s, 1115.4s to go
# on time step 325967 (time=325.967), 0.0033015 s/step
# Meep progress: 10.331994873046881/326.6113051269531 = 3.2% done in 36.0s, 1102.6s to go
# run 31 finished at t = 326.612 (326612 timesteps)
# 10.425599999999974
# on time step 327178 (time=327.178), 0.00330399 s/step
# Meep progress: 1.2160004882812814/337.0375995117187 = 0.4% done in 4.0s, 1105.2s to go
# on time step 328403 (time=328.403), 0.00326752 s/step
# Meep progress: 2.4690004882812673/337.0375995117187 = 0.7% done in 8.0s, 1084.3s to go
# on time step 329661 (time=329.661), 0.00318165 s/step
# Meep progress: 3.7120004882812623/337.0375995117187 = 1.1% done in 12.0s, 1077.9s to go
# on time step 330909 (time=330.909), 0.00320548 s/step
# Meep progress: 4.966000488281281/337.0375995117187 = 1.5% done in 16.0s, 1070.2s to go
# on time step 332139 (time=332.139), 0.0032538 s/step
# Meep progress: 6.198000488281252/337.0375995117187 = 1.8% done in 20.0s, 1067.9s to go
# on time step 333372 (time=333.372), 0.00324534 s/step
# Meep progress: 7.415000488281237/337.0375995117187 = 2.2% done in 24.0s, 1067.2s to go
# on time step 334599 (time=334.599), 0.00326041 s/step
# Meep progress: 8.603000488281282/337.0375995117187 = 2.6% done in 28.0s, 1069.3s to go
# on time step 335781 (time=335.781), 0.00338515 s/step
# Meep progress: 9.764000488281283/337.0375995117187 = 2.9% done in 32.0s, 1073.0s to go
# on time step 336817 (time=336.817), 0.00386131 s/step
# run 32 finished at t = 337.038 (337038 timesteps)
# 10.438899999999974
# on time step 337803 (time=337.803), 0.00405944 s/step
# Meep progress: 0.9780056152343946/347.4768943847656 = 0.3% done in 4.0s, 1417.8s to go
# on time step 338785 (time=338.785), 0.00407382 s/step
# Meep progress: 1.9630056152344082/347.4768943847656 = 0.6% done in 8.0s, 1408.8s to go
# on time step 339783 (time=339.783), 0.00401107 s/step
# Meep progress: 2.9880056152343855/347.4768943847656 = 0.9% done in 12.0s, 1384.3s to go
# on time step 340796 (time=340.796), 0.0039491 s/step
# Meep progress: 3.986005615234376/347.4768943847656 = 1.1% done in 16.0s, 1379.7s to go
# on time step 341847 (time=341.847), 0.00380655 s/step
# Meep progress: 5.039005615234373/347.4768943847656 = 1.5% done in 20.0s, 1360.1s to go
# on time step 342836 (time=342.836), 0.00404836 s/step
# Meep progress: 6.024005615234387/347.4768943847656 = 1.7% done in 24.0s, 1361.3s to go
# on time step 343827 (time=343.827), 0.00403679 s/step
# Meep progress: 7.012005615234386/347.4768943847656 = 2.0% done in 28.0s, 1360.3s to go
# on time step 344806 (time=344.806), 0.00408743 s/step
# Meep progress: 7.987005615234409/347.4768943847656 = 2.3% done in 32.0s, 1361.1s to go
# on time step 345854 (time=345.854), 0.0038198 s/step
# Meep progress: 9.06600561523436/347.4768943847656 = 2.6% done in 36.0s, 1344.6s to go
# on time step 346959 (time=346.959), 0.00362004 s/step
# Meep progress: 10.170005615234402/347.4768943847656 = 2.9% done in 40.0s, 1327.5s to go
# run 33 finished at t = 347.47700000000003 (347477 timesteps)
# 10.452199999999973
# on time step 348056 (time=348.056), 0.00364739 s/step
# Meep progress: 1.1260102539062586/357.9291897460937 = 0.3% done in 4.0s, 1267.6s to go
# on time step 349181 (time=349.181), 0.00355712 s/step
# Meep progress: 2.231010253906277/357.9291897460937 = 0.6% done in 8.0s, 1275.7s to go
# on time step 350292 (time=350.292), 0.00360362 s/step
# Meep progress: 3.3550102539062436/357.9291897460937 = 0.9% done in 12.0s, 1268.7s to go
# on time step 351404 (time=351.404), 0.00359895 s/step
# Meep progress: 4.463010253906248/357.9291897460937 = 1.2% done in 16.0s, 1267.8s to go
# on time step 352538 (time=352.538), 0.00352985 s/step
# Meep progress: 5.587010253906271/357.9291897460937 = 1.6% done in 20.0s, 1262.0s to go
# on time step 353646 (time=353.646), 0.00361058 s/step
# Meep progress: 6.679010253906256/357.9291897460937 = 1.9% done in 24.0s, 1262.9s to go
# on time step 354667 (time=354.667), 0.00392116 s/step
# Meep progress: 7.712010253906271/357.9291897460937 = 2.2% done in 28.0s, 1272.3s to go
# on time step 355767 (time=355.767), 0.00363658 s/step
# Meep progress: 8.817010253906233/357.9291897460937 = 2.5% done in 32.0s, 1267.8s to go
# on time step 356852 (time=356.852), 0.00368739 s/step
# Meep progress: 9.90001025390626/357.9291897460937 = 2.8% done in 36.0s, 1266.3s to go
# run 34 finished at t = 357.93 (357930 timesteps)
# 10.465499999999972
# on time step 357949 (time=357.949), 0.00364896 s/step
# Meep progress: 1.095007324218784/368.3954926757812 = 0.3% done in 4.0s, 1341.8s to go
# on time step 359043 (time=359.043), 0.00365698 s/step
# Meep progress: 2.1970073242187595/368.3954926757812 = 0.6% done in 8.0s, 1333.9s to go
# on time step 360146 (time=360.146), 0.00362755 s/step
# Meep progress: 3.3080073242187495/368.3954926757812 = 0.9% done in 12.0s, 1324.7s to go
# on time step 361256 (time=361.256), 0.00360573 s/step
# Meep progress: 4.416007324218754/368.3954926757812 = 1.2% done in 16.0s, 1319.0s to go
# on time step 362365 (time=362.365), 0.0036073 s/step
# Meep progress: 5.525007324218734/368.3954926757812 = 1.5% done in 20.0s, 1313.8s to go
# on time step 363474 (time=363.474), 0.00360892 s/step
# Meep progress: 6.654007324218753/368.3954926757812 = 1.8% done in 24.0s, 1305.1s to go
# on time step 364604 (time=364.604), 0.00354205 s/step
# Meep progress: 7.768007324218786/368.3954926757812 = 2.1% done in 28.0s, 1300.2s to go
# on time step 365718 (time=365.718), 0.00359315 s/step
# Meep progress: 8.890007324218743/368.3954926757812 = 2.4% done in 32.0s, 1294.4s to go
# on time step 366842 (time=366.842), 0.00356079 s/step
# Meep progress: 9.998007324218747/368.3954926757812 = 2.7% done in 36.0s, 1290.9s to go
# on time step 367949 (time=367.949), 0.0036158 s/step
# run 35 finished at t = 368.396 (368396 timesteps)
# 10.478799999999971
# on time step 369034 (time=369.034), 0.00368949 s/step
# Meep progress: 1.101003906250014/378.87479609375 = 0.3% done in 4.0s, 1372.6s to go
# on time step 370140 (time=370.14), 0.00361861 s/step
# Meep progress: 2.2070039062500086/378.87479609375 = 0.6% done in 8.0s, 1365.9s to go
# on time step 371246 (time=371.246), 0.00361915 s/step
# Meep progress: 3.3150039062500127/378.87479609375 = 0.9% done in 12.0s, 1360.0s to go
# on time step 372356 (time=372.356), 0.00360513 s/step
# Meep progress: 4.428003906250012/378.87479609375 = 1.2% done in 16.0s, 1353.5s to go
# on time step 373478 (time=373.478), 0.0035665 s/step
# Meep progress: 5.553003906250012/378.87479609375 = 1.5% done in 20.0s, 1345.0s to go
# on time step 374608 (time=374.608), 0.00354187 s/step
# Meep progress: 6.671003906250007/378.87479609375 = 1.8% done in 24.0s, 1339.5s to go
# on time step 375721 (time=375.721), 0.00359711 s/step
# Meep progress: 7.7690039062500205/378.87479609375 = 2.1% done in 28.0s, 1338.1s to go
# on time step 376819 (time=376.819), 0.00364651 s/step
# Meep progress: 8.892003906250011/378.87479609375 = 2.3% done in 32.0s, 1332.1s to go
# on time step 377927 (time=377.927), 0.0036133 s/step
# Meep progress: 9.986003906250005/378.87479609375 = 2.6% done in 36.0s, 1330.5s to go
# run 36 finished at t = 378.875 (378875 timesteps)
# 10.49209999999997
# on time step 379025 (time=379.025), 0.00364492 s/step
# Meep progress: 1.01400000000001/389.3671 = 0.3% done in 4.0s, 1532.4s to go
# on time step 380019 (time=380.019), 0.00402616 s/step
# Meep progress: 2.0610000000000355/389.3671 = 0.5% done in 8.0s, 1503.6s to go
# on time step 381075 (time=381.075), 0.00379137 s/step
# Meep progress: 3.180000000000007/389.3671 = 0.8% done in 12.0s, 1457.6s to go
# on time step 382189 (time=382.189), 0.00359212 s/step
# Meep progress: 4.206000000000017/389.3671 = 1.1% done in 16.0s, 1465.8s to go
# on time step 383218 (time=383.218), 0.00388973 s/step
# Meep progress: 5.247000000000014/389.3671 = 1.3% done in 20.0s, 1464.9s to go
# on time step 384257 (time=384.257), 0.00384987 s/step
# Meep progress: 6.393000000000029/389.3671 = 1.6% done in 24.0s, 1438.5s to go
# on time step 385433 (time=385.433), 0.00340225 s/step
# Meep progress: 7.593000000000018/389.3671 = 2.0% done in 28.0s, 1408.5s to go
# on time step 386628 (time=386.628), 0.00334923 s/step
# Meep progress: 8.761000000000024/389.3671 = 2.3% done in 32.0s, 1390.8s to go
# on time step 387805 (time=387.805), 0.00340129 s/step
# Meep progress: 10.01400000000001/389.3671 = 2.6% done in 36.0s, 1364.4s to go
# on time step 389060 (time=389.06), 0.00318736 s/step
# run 37 finished at t = 389.368 (389368 timesteps)
# 10.50539999999997
# on time step 390283 (time=390.283), 0.00327076 s/step
# Meep progress: 1.2369885253906432/399.8734114746093 = 0.3% done in 4.0s, 1289.5s to go
# on time step 391513 (time=391.513), 0.00325369 s/step
# Meep progress: 2.4629885253906423/399.8734114746093 = 0.6% done in 8.0s, 1291.1s to go
# on time step 392767 (time=392.767), 0.00319118 s/step
# Meep progress: 3.7489885253906436/399.8734114746093 = 0.9% done in 12.0s, 1268.4s to go
# on time step 394064 (time=394.064), 0.0030857 s/step
# Meep progress: 5.017988525390649/399.8734114746093 = 1.3% done in 16.0s, 1259.6s to go
# on time step 395336 (time=395.336), 0.00314523 s/step
# Meep progress: 6.283988525390612/399.8734114746093 = 1.6% done in 20.0s, 1253.2s to go
# on time step 396614 (time=396.614), 0.003132 s/step
# Meep progress: 7.569988525390613/399.8734114746093 = 1.9% done in 24.0s, 1244.4s to go
# on time step 397901 (time=397.901), 0.00310903 s/step
# Meep progress: 8.853988525390605/399.8734114746093 = 2.2% done in 28.0s, 1237.2s to go
# on time step 399163 (time=399.163), 0.00317183 s/step
# Meep progress: 10.119988525390625/399.8734114746093 = 2.5% done in 32.0s, 1233.0s to go
# run 38 finished at t = 399.874 (399874 timesteps)
# 10.518699999999969
# on time step 400441 (time=400.441), 0.00313237 s/step
# Meep progress: 1.27200708007814/410.39269291992184 = 0.3% done in 4.0s, 1287.4s to go
# on time step 401720 (time=401.72), 0.00312755 s/step
# Meep progress: 2.5620070800781605/410.39269291992184 = 0.6% done in 8.0s, 1274.2s to go
# on time step 402995 (time=402.995), 0.00313836 s/step
# Meep progress: 3.8260070800781136/410.39269291992184 = 0.9% done in 12.0s, 1275.8s to go
# on time step 404278 (time=404.278), 0.00311909 s/step
# Meep progress: 5.108007080078153/410.39269291992184 = 1.2% done in 16.0s, 1270.1s to go
# on time step 405548 (time=405.548), 0.00315121 s/step
# Meep progress: 6.3810070800781205/410.39269291992184 = 1.6% done in 20.0s, 1266.9s to go
# on time step 406822 (time=406.822), 0.00314086 s/step
# Meep progress: 7.648007080078116/410.39269291992184 = 1.9% done in 24.0s, 1264.3s to go
# on time step 408085 (time=408.085), 0.00316787 s/step
# Meep progress: 8.91100708007815/410.39269291992184 = 2.2% done in 28.0s, 1262.0s to go
# on time step 409355 (time=409.355), 0.00314972 s/step
# Meep progress: 10.197007080078151/410.39269291992184 = 2.5% done in 32.0s, 1256.4s to go
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 39 finished at t = 410.39300000000003 (410393 timesteps)
#      block, center = (-0.61,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-0.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.4,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,-2.77556e-17,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.6,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.2,0)
#           size (0.3,0.15,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.2,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,0.8,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-0.25,1.4,0)
#           size (0.3,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)

# %%
# 這裡的 Code 單個觀測點 電場E - 時間t 的點狀圖

# 儲存振福資訊的列表，定義為擁有 10 列的空二維陣列
ez_amplitude_list = [[] for _ in range(int((time_end - time_start) / dt))]

# 計算觀測點的相對座標
x_obs = -0.5 * sx + dpml + dsub + gh + 0.002
y_obs_start = -0.5 * sy #+ gp/2
y_obs = y_obs_start

for i in range(0, int((time_end - time_start) / dt)):
    for j in range(300):
        y_obs = y_obs_start + (j * 0.002)
        # 計算觀測點在陣列中的索引位置
        x_index = int(round(x_obs * sim.resolution))
        y_index = int(round(y_obs * sim.resolution))
        # 取得振幅資訊
        amplitude = np.abs(ez_data_list[i][0][x_index, y_index])
        # 將振幅資訊加入到對應時間步長的列表中
        ez_amplitude_list[i].append(amplitude)

    
for i in range(0, int((time_end - time_start) / dt)):
    print(ez_amplitude_list[i])
    

'''sim.run(until = 100)

plt.figure(dpi = 100)
sim.plot2D(fields=mp.Ez)
plt.show()
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 18
#      16 y_index = int(round(y_obs * sim.resolution))
#      17 # 取得振幅資訊
# ---> 18 amplitude = np.abs(ez_data_list[i][0][x_index, y_index])
#      19 # 將振幅資訊加入到對應時間步長的列表中
#      20 ez_amplitude_list[i].append(amplitude)
#
# NameError: name 'ez_data_list' is not defined

# %%
# Out:
# [0.6890663527475407, 0.6887059150137753, 0.6880815423953489, 0.6871608637108948, 0.6858963192278242, 0.684238688873049, 0.6821538189613102, 0.6796376506572595, 0.6767239010977864, 0.6734801831361501, 0.6699918864092397, 0.6663376805793259, 0.6625642764473696, 0.6586693769245257, 0.654599682566414, 0.6502658247654696, 0.6455699030165917, 0.6404362898149809, 0.6348346428116589, 0.6287865438513007, 0.6223531289854543, 0.6156082926546139, 0.6086077264006406, 0.6013658710575116, 0.593849974227218, 0.5859938741629727, 0.57772641063023, 0.5690035468329703, 0.5598317172243876, 0.5502732599504618, 0.5404317429112502, 0.530422778971859, 0.5203414325811995, 0.510238354673144, 0.5001129757782004, 0.4899250445736053, 0.4796184392127338, 0.4691465261312928, 0.4584882739228297, 0.4476488042782019, 0.4366451358828588, 0.42548452702099077, 0.41414621227128134, 0.40257600069456106, 0.39069769375121843, 0.37843790121101784, 0.36575470246424946, 0.35265834211487823, 0.3392147869912619, 0.32552949598243536, 0.3117165304986141, 0.29786399365195554, 0.2840083389741281, 0.270126706514392, 0.2561495131433327, 0.24198786437124228, 0.22756504567796448, 0.2128404602828629, 0.19781812725085232, 0.18253855010259323, 0.16705954901668657, 0.15143569703348086, 0.13570571126684694, 0.11989279623830802, 0.10401651875438857, 0.0881091679513661, 0.0722272036293487, 0.05645037163668769, 0.04086653898841121, 0.0255469205051331, 0.010521255333948954, 0.0042365329711880565, 0.01880514445901763, 0.033294750161112927, 0.047814541884873746, 0.062440312216300614, 0.07719369251670152, 0.09204043518645744, 0.1069079999018181, 0.12171550184966519, 0.13640462209051393, 0.15096005977380506, 0.16541243171863118, 0.1798233959889057, 0.19425944625630095, 0.20876472577035207, 0.22334297205455095, 0.23795464738530725, 0.25252924294415324, 0.2669871590031162, 0.28126259646952684, 0.29531948457604396, 0.30915604989322565, 0.32279846905058374, 0.33628804217219505, 0.34966792074982206, 0.36297423453115596, 0.3762333497992407, 0
, 0.8283453144489604, 0.8283453144489604, 0.8282043455588288, 0.8276233931869056, 0.8266385450901589, 0.8253057551583328, 0.8236807125483641, 0.8217986601359446, 0.8196626387103956, 0.8172451079992231, 0.8145021210078123, 0.8113937856953258, 0.8079020904760059, 0.804038486256272, 0.799838283460752, 0.7953447963803277, 0.7905905893502605, 0.7855841993271393, 0.7803079664411823, 0.7747274536962643, 0.7688077821185733, 0.7625293648861127, 0.755896167143492, 0.7489332888182433, 0.7416755589930257, 0.7341526804860441, 0.7263776141782841, 0.7183430119179338, 0.7100266542328202, 0.701402894292376, 0.692454815040596, 0.6831820283176051, 0.6736014201154534, 0.6637413771155928, 0.6536325817905237, 0.643299307480709, 0.6327541814359283, 0.6219973718143258, 0.6110192274730313, 0.5998044497711023, 0.5883361343856164, 0.5765990294178147, 0.564582310004478, 0.5522824222641984, 0.5397059835242616, 0.5268717979429389, 0.5138104908809531, 0.5005606337999069, 0.48716153568381315, 0.4736 ...

# %%
# 取得 Ez 場量在指定位置的相位資訊
phase_data = np.fft.fft(np.array(sim.get_array(component = mp.Ez , cmplx = True)))

# 計算觀測點的相對座標
x_obs = -0.5 * sx + dpml + dsub + gh + 0.01
y_obs_start = -0.5 * sy + gp/2 

# 儲存相位資訊的列表
phase_list = []

# 遍歷每個觀測點
for j in range(num_cells):
    y_obs = y_obs_start + (j * gp)
    # 計算觀測點在陣列中的索引位置
    x_index = int(round((x_obs) * sim.resolution))
    y_index = int(round((y_obs) * sim.resolution))
    # 取得相位資訊
    phase = np.angle(phase_data[x_index, y_index])
    phase_list.append(phase)

# 印出觀測點的相位資訊
'''
for j, phase in enumerate(phase_list):
    print(f"觀測點 {j+1} 的相位資訊: {phase}")'''
    
print(phase_list)
# Out:
# [2.3077927447350057, 0.0, -2.307792744735097]

# %%
sim.reset_meep()
f = plt.figure(dpi = 100)
Animate = mp.Animate2D(fields=mp.Ez, f=f, realtime=False, normalize=True)
plt.close()

sim.run(mp.at_every(1, Animate), until = 50)
plt.close()

filename = "1 alpha beta alpha structure.mp4"
Animate.to_mp4(10, filename)

from IPython.display import Video

Video(filename)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000115156 s
# Working in 2D dimensions.
# Computational cell is 17.1 x 6 x 0 with resolution 50
#      block, center = (-7.26,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.9,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.3,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-1.7,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-1.1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.5,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.7,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.3,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.9,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      ...(+ 21 objects not shown)...
# time for set_epsilon = 0.338902 s
# -----------
# Meep: using complex fields.
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (-7.26,0,0)
#           size (0.5,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.9,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-2.3,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-1.7,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-1.1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,-0.5,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.1,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,0.7,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.3,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      block, center = (-6.75,1.9,0)
#           size (0.6,0.08,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (7.11716,7.11716,7.11716)
#      ...(+ 21 objects not shown)...
# Meep progress: 17.96/50.0 = 35.9% done in 4.0s, 7.1s to go
# on time step 1796 (time=17.96), 0.00222809 s/step
# Meep progress: 36.25/50.0 = 72.5% done in 8.0s, 3.0s to go
# on time step 3625 (time=36.25), 0.00218793 s/step
# Normalizing field data...
# run 2 finished at t = 50.0 (5000 timesteps)
# Generating MP4...
# <video src="1 alpha beta alpha structure.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
